# %%
import numpy as np
import gym
import pybulletgym
import torch
import os
from spinup.env_wrapper.pomdp_wrapper import POMDPWrapper
from spinup.algos.pytorch.lstm_td3.lstm_td3 import MLPCritic, MLPActor, MLPActorCritic
import json
import matplotlib.pyplot as plt

# %%
MDP_to_POMDP = {}

# %% [markdown]
# ## MDP-> POMDP:
# ### Baselines

# %%
root_dir = r"D:\POMDP_Data\clean_spinup_MDP_Baselines"
tasks = ['AntPyBulletEnv-v0']

for sub_dir in os.listdir(root_dir):
    # print(sub_dir)
    # print(sub_dir.split('_'))
    params = sub_dir.split('_')
    alg_name = params[1]
    task_name = params[2]
    seed = params[4]
    if task_name in tasks:
        if alg_name not in MDP_to_POMDP:
            MDP_to_POMDP[alg_name] = {}
        if task_name not in MDP_to_POMDP[alg_name]:
            MDP_to_POMDP[alg_name][task_name] = {}
        if seed not in MDP_to_POMDP[alg_name][task_name]:
            MDP_to_POMDP[alg_name][task_name][seed] = {}
        #
        print("********************************************************************")
        for exp_run in os.listdir(os.path.join(root_dir, sub_dir)):
            print(exp_run)
            # Load pre-trained model
            config_path = os.path.join(root_dir, sub_dir, exp_run, 'config.json')
            with open(config_path, 'r') as config_file:
                config_json = json.load(config_file)
            model_path = os.path.join(root_dir, sub_dir, exp_run, 'pyt_save', 'model.pt')
            ac = torch.load(model_path)
            # print(ac)

            # Retrive hyper-parameters
            env_name = config_json['env_name']
            num_test_episodes = config_json['num_test_episodes']
            max_ep_len = config_json['max_ep_len']
            if alg_name == 'TD3-OW' or alg_name == 'TD3-OW-AddPastAct':
                observation_window_size = config_json['observation_window_size']
            
            for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
                print("\t{}".format(pomdp_type))
                MDP_to_POMDP[alg_name][task_name][seed][pomdp_type] = []
                # Create environment
                if pomdp_type == 'MDP':
                    test_env = gym.make(env_name)
                else:
                    test_env = POMDPWrapper(env_name, pomdp_type, flicker_prob, random_noise_sigma, random_sensor_missing_prob)
                obs_dim = test_env.observation_space.shape[0]
                act_dim = test_env.action_space.shape[0]
                act_limit = test_env.action_space.high[0]
                
                # Evaluation
                for j in range(num_test_episodes):
                    # Reset environment
                    o, d, ep_ret, ep_len = test_env.reset(), False, 0, 0
                    if alg_name == 'TD3-OW':
                        ow_o = np.zeros([int(observation_window_size * obs_dim)])
                        ow_o[-obs_dim:] = o
                    elif alg_name == 'TD3-OW-AddPastAct':
                        ow_o = np.zeros([int((observation_window_size - 1) * (obs_dim + act_dim) + obs_dim)])
                        ow_o[-obs_dim:] = o
                    elif alg_name == 'LSTM-TD3':
                        pass
                    else:
                        pass

                    # Interact
                    while not(d or (ep_len == max_ep_len)):
                        # Take deterministic actions at test time 
                        if alg_name == 'TD3-OW' or alg_name == 'TD3-OW-AddPastAct':
                            action = ac.act(torch.as_tensor(ow_o, dtype=torch.float32))
                        elif alg_name == 'SAC':
                            action = ac.act(torch.as_tensor(o, dtype=torch.float32), True)
                        else:
                            action = ac.act(torch.as_tensor(o, dtype=torch.float32))
                        o, r, d, _ = test_env.step(action)
                        ep_ret += r
                        ep_len += 1

                        # Construct Observation-Window-based observation for TD3-OW and TD3-OW-AddPastAct
                        if alg_name == 'TD3-OW':
                            ow_o[:-obs_dim] = ow_o[obs_dim:]
                            ow_o[-obs_dim:] = o
                        elif alg_name == 'TD3-OW-AddPastAct':
                            ow_o[:-(obs_dim + act_dim)] = ow_o[(obs_dim + act_dim):]
                            ow_o[-(obs_dim + act_dim):] = np.concatenate((action, o))

                    print('\t  Episod-{}: Ep_Return={}, Ep_Len={}'.format(j, ep_ret, ep_len))
                    MDP_to_POMDP[alg_name][task_name][seed][pomdp_type].append(ep_ret)
# Out:
# ********************************************************************
# 2020-10-27_00-00-00_DDPG_AntPyBulletEnv-v0_MDP_s0
# 	MDP
# WalkerBase::__init__
# options=
# C:\ProgramData\Anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 	  Episod-0: Ep_Return=1649.3961464245865, Ep_Len=1000
# 	  Episod-1: Ep_Return=1550.8576863037258, Ep_Len=1000
# 	  Episod-2: Ep_Return=1539.0337597957216, Ep_Len=1000
# 	  Episod-3: Ep_Return=1660.9765205983103, Ep_Len=1000
# 	  Episod-4: Ep_Return=1603.0214171930845, Ep_Len=1000
# 	  Episod-5: Ep_Return=1624.0046345261671, Ep_Len=1000
# 	  Episod-6: Ep_Return=1601.7122303802578, Ep_Len=1000
# 	  Episod-7: Ep_Return=1586.685397737716, Ep_Len=1000
# 	  Episod-8: Ep_Return=1581.4631776511008, Ep_Len=1000
# 	  Episod-9: Ep_Return=1614.3450561939326, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=989.025076231745, Ep_Len=1000
# 	  Episod-1: Ep_Return=1214.6074294171747, Ep_Len=1000
# 	  Episod-2: Ep_Return=1002.7500231868306, Ep_Len=1000
# 	  Episod-3: Ep_Return=1029.6751794485717, Ep_Len=1000
# 	  Episod-4: Ep_Return=1054.4257834860691, Ep_Len=1000
# 	  Episod-5: Ep_Return=1101.092917747644, Ep_Len=1000
# 	  Episod-6: Ep_Return=1006.4677348592902, Ep_Len=1000
# 	  Episod-7: Ep_Return=1073.2400384192008, Ep_Len=1000
# 	  Episod-8: Ep_Return=1139.8840444648447, Ep_Len=1000
# 	  Episod-9: Ep_Return=1055.2190957937069, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1484.7956614564666, Ep_Len=1000
# 	  Episod-1: Ep_Return=1596.0360548612673, Ep_Len=1000
# 	  Episod-2: Ep_Return=1481.8333941109463, Ep_Len=1000
# 	  Episod-3: Ep_Return=1498.0437082045826, Ep_Len=1000
# 	  Episod-4: Ep_Return=1537.597583392577, Ep_Len=1000
# 	  Episod-5: Ep_Return=1493.4761772494362, Ep_Len=1000
# 	  Episod-6: Ep_Return=1513.1945281020492, Ep_Len=1000
# 	  Episod-7: Ep_Return=1487.1942048072374, Ep_Len=1000
# 	  Episod-8: Ep_Return=1529.4098290104625, Ep_Len=1000
# 	  Episod-9: Ep_Return=1509.123751596649, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1298.9486353183156, Ep_Len=1000
# 	  Episod-1: Ep_Return=1290.9416704517805, Ep_Len=1000
# 	  Episod-2: Ep_Return=1398.6341898398837, Ep_Len=1000
# 	  Episod-3: Ep_Return=1383.7802915419286, Ep_Len=1000
# 	  Episod-4: Ep_Return=1365.0834018249377, Ep_Len=1000
# 	  Episod-5: Ep_Return=1390.291796799432, Ep_Len=1000
# 	  Episod-6: Ep_Return=1345.1054933526527, Ep_Len=1000
# 	  Episod-7: Ep_Return=1383.9110529824754, Ep_Len=1000
# 	  Episod-8: Ep_Return=1285.2138882094368, Ep_Len=1000
# 	  Episod-9: Ep_Return=1417.389143153402, Ep_Len=1000
# ********************************************************************
# 2020-10-27_00-00-00_DDPG_AntPyBulletEnv-v0_MDP_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=-1.2560832594143, Ep_Len=20
# 	  Episod-1: Ep_Return=-1.1300629652774665, Ep_Len=20
# 	  Episod-2: Ep_Return=-0.33322519820067154, Ep_Len=20
# 	  Episod-3: Ep_Return=-1.119615195713414, Ep_Len=20
# 	  Episod-4: Ep_Return=-0.8386402235249997, Ep_Len=20
# 	  Episod-5: Ep_Return=-0.8227697733294925, Ep_Len=20
# 	  Episod-6: Ep_Return=-0.730788330976794, Ep_Len=20
# 	  Episod-7: Ep_Return=-0.9261521579930565, Ep_Len=20
# 	  Episod-8: Ep_Return=-1.440217212590506, Ep_Len=20
# 	  Episod-9: Ep_Return=-0.7450844241815511, Ep_Len=20
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return
Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=809.5708642922817, Ep_Len=1000
# 	  Episod-1: Ep_Return=777.5383913815416, Ep_Len=1000
# 	  Episod-2: Ep_Return=770.2768637550344, Ep_Len=1000
# 	  Episod-3: Ep_Return=792.6140199094023, Ep_Len=1000
# 	  Episod-4: Ep_Return=773.0654180226857, Ep_Len=1000
# 	  Episod-5: Ep_Return=886.2344582677746, Ep_Len=1000
# 	  Episod-6: Ep_Return=872.246250380064, Ep_Len=1000
# 	  Episod-7: Ep_Return=750.8626947373618, Ep_Len=1000
# 	  Episod-8: Ep_Return=800.1206772154618, Ep_Len=1000
# 	  Episod-9: Ep_Return=833.4844743961294, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=876.1565235098126, Ep_Len=1000
# 	  Episod-1: Ep_Return=897.69685822236, Ep_Len=1000
# 	  Episod-2: Ep_Return=891.2269411304137, Ep_Len=1000
# 	  Episod-3: Ep_Return=892.4733064661708, Ep_Len=1000
# 	  Episod-4: Ep_Return=807.279755395916, Ep_Len=1000
# 	  Episod-5: Ep_Return=899.4344611912875, Ep_Len=1000
# 	  Episod-6: Ep_Return=910.2547641877612, Ep_Len=1000
# 	  Episod-7: Ep_Return=893.2004769832326, Ep_Len=1000
# 	  Episod-8: Ep_Return=904.5657554243722, Ep_Len=1000
# 	  Episod-9: Ep_Return=760.1763162254377, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=880.7864674736064, Ep_Len=1000
# 	  Episod-1: Ep_Return=957.2583496083591, Ep_Len=1000
# 	  Episod-2: Ep_Return=963.6006607250376, Ep_Len=1000
# 	  Episod-3: Ep_Return=918.838414306363, Ep_Len=1000
# 	  Episod-4: Ep_Return=929.3937355039524, Ep_Len=1000
# 	  Episod-5: Ep_Return=919.7119817917234, Ep_Len=1000
# 	  Episod-6: Ep_Return=824.3432359127547, Ep_Len=1000
# 	  Episod-7: Ep_Return=865.4663046236902, Ep_Len=1000
# 	  Episod-8: Ep_Return=818.9491519959801, Ep_Len=1000
# 	  Episod-9: Ep_Return=904.8861487767444, Ep_Len=1000
# ********************************************************************
# 2020-10-27_00-00-00_SAC_AntPyBulletEnv-v0_MDP_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=831.9889330796454, Ep_Len=1000
# 	  Episod-1: Ep_Return=818.7240971102349, Ep_Len=1000
# 	  Episod-2: Ep_Return=792.5996386544973, Ep_Len=1000
# 	  Episod-3: Ep_Return=743.9987508264952, Ep_Len=1000
# 	  Episod-4: Ep_Return=735.1720807452601, Ep_Len=1000
# 	  Episod-5: Ep_Return=746.7427166018476, Ep_Len=1000
# 	  Episod-6: Ep_Return=794.8437770566094, Ep_Len=1000
# 	  Episod-7: Ep_Return=753.8129027935686, Ep_Len=1000
# 	  Episod-8: Ep_Return=799.0347495801229, Ep_Len=1000
# 	  Episod-9: Ep_Return=839.5480453122436, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=790.6071056267854, Ep_Len=1000
# 	  Episod-1: Ep_Return=720.672120350802, Ep_Len=1000
# 	  Episod-2: Ep_Return=694.6081133794112, Ep_Len=1000
# 	  Episod-3: Ep_Return=782.5940926360797, Ep_Len=1000
# 	  Episod-4: Ep_Return=704.379621553045, Ep_Len=1000
# 	  Episod-5: Ep_Return=688.5443136662218, Ep_Len=1000
# 	  Episod-6: Ep_Return=698.2918670394782, Ep_Len=1000
# 	  Episod-7: Ep_Return=630.2764197232462, Ep_Len=1000
# 	  Episod-8: Ep_Return=710.4576804961682, Ep_Len=1000
# 	  Episod-9: Ep_Return=816.4095901375167, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=736.9955717814556, Ep_Len=1000
# 	  Episod-1: Ep_Return=863.6096742158578, Ep_Len=1000
# 	  Episod-2: Ep_Return=864.0184714881302, Ep_Len=1000
# 	  Episod-3: Ep_Return=846.264333011159, Ep_Len=1000
# 	  Episod-4: Ep_Return=848.4063156993267, Ep_Len=1000
# 	  Episod-5: Ep_Return=902.0149541363243, Ep_Len=1000
# 	  Episod-6: Ep_Return=757.4958848730026, Ep_Len=1000
# 	  Episod-7: Ep_Return=843.7257395069211, Ep_Len=1000
# 	  Episod-8: Ep_Return=910.8894715736768, Ep_Len=1000
# 	  Episod-9: Ep_Return=877.4509511163984, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=868.2002849099568, Ep_Len=1000
# 	  Episod-1: Ep_Return=862.9284722806043, Ep_Len=1000
# 	  Episod-2: Ep_Return=828.6845240338256, Ep_Len=1000
# 	  Episod-3: Ep_Return=820.3446565141776, Ep_Len=1000
# 	  Episod-4: Ep_Return=741.3233493986752, Ep_Len=1000
# 	  Episod-5: Ep_Return=851.4878361320654, Ep_Len=1000
# 	  Episod-6: Ep_Return=693.98688874374, Ep_Len=1000
# 	  Episod-7: Ep_Return=775.1041969372966, Ep_Len=1000
# 	  Episod-8: Ep_Return=841.2593917233124, Ep_Len=1000
# 	  Episod-9: Ep_Return=893.2371582761015, Ep_Len=1000
# ********************************************************************
# 2020-10-28_00-00-00_TD3_AntPyBulletEnv-v0_MDP_s0
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2746.1792300032207, Ep_Len=1000
# 	  Episod-1: Ep_Return=2734.771192309855, Ep_Len=1000
# 	  Episod-2: Ep_Return=2708.5074074834465, Ep_Len=1000
# 	  Episod-3: Ep_Return=2711.3840894372074, Ep_Len=1000
# 	  Episod-4: Ep_Return=2723.913350933688, Ep_Len=1000
# 	  Episod-5: Ep_Return=2704.526379421045, Ep_Len=1000
# 	  Episod-6: Ep_Return=2720.559055223023, Ep_Len=1000
# 	  Episod-7: Ep_Return=2704.532731124192, Ep_Len=1000
# 	  Episod-8: Ep_Return=2705.9266979718054, Ep_Len=1000
# 	  Episod-9: Ep_Return=2715.2530225645082, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2136.634093632361, Ep_Len=1000
# 	  Episod-1: Ep_Return=2022.7400054529865, Ep_Len=1000
# 	  Episod-2: Ep_Return=2114.8932394710614, Ep_Len=1000
# 	  Episod-3: Ep_Return=2141.5083472052174, Ep_Len=1000
# 	  Episod-4: Ep_Return=2132.57296993391, Ep_Len=1000
# 	  Episod-5: Ep_Return=2044.1612243500163, Ep_Len=1000
# 	  Episod-6: Ep_Return=2077.4055213519355, Ep_Len=1000
# 	  Episod-7: Ep_Return=2152.3676331915367, Ep_Len=1000
# 	  Episod-8: Ep_Return=1949.0016921287483, Ep_Len=1000
# 	  Episod-9: Ep_Return=2101.014383273728, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2363.5625390172963, Ep_Len=1000
# 	  Episod-1: Ep_Return=2434.478960298739, Ep_Len=1000
# 	  Episod-2: Ep_Return=2351.5714984586775, Ep_Len=1000
# 	  Episod-3: Ep_Return=2292.051470445875, Ep_Len=1000
# 	  Episod-4: Ep_Return=2337.7875625458028, Ep_Len=1000
# 	  Episod-5: Ep_Return=2340.7946836665237, Ep_Len=1000
# 	  Episod-6: Ep_Return=2345.6926643456736, Ep_Len=1000
# 	  Episod-7: Ep_Return=2337.105584473442, Ep_Len=1000
# 	  Episod-8: Ep_Return=2344.377143746806, Ep_Len=1000
# 	  Episod-9: Ep_Return=2299.4987745425856, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1968.5065423601282, Ep_Len=1000
# 	  Episod-1: Ep_Return=2162.49143333324, Ep_Len=1000
# 	  Episod-2: Ep_Return=1992.2527370735959, Ep_Len=1000
# 	  Episod-3: Ep_Return=1982.3887944908874, Ep_Len=1000
# 	  Episod-4: Ep_Return=1934.679674026053, Ep_Len=1000
# 	  Episod-5: Ep_Return=2051.095722298306, Ep_Len=1000
# 	  Episod-6: Ep_Return=1978.5973505279574, Ep_Len=1000
# 	  Episod-7: Ep_Return=1996.2504450808829, Ep_Len=1000
# 	  Episod-8: Ep_Return=1988.8795001886065, Ep_Len=1000
# 	  Episod-9: Ep_Return=2002.1715674188274, Ep_Len=1000
# ********************************************************************
# 2020-10-28_00-00-00_TD3_AntPyBulletEnv-v0_MDP_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2535.6654749623426, Ep_Len=1000
# 	  Episod-1: Ep_Return=2556.952425220076, Ep_Len=1000
# 	  Episod-2: Ep_Return=2556.7742955959043, Ep_Len=1000
# 	  Episod-3: Ep_Return=2559.144738268228, Ep_Len=1000
# 	  Episod-4: Ep_Return=2554.3412799187176, Ep_Len=1000
# 	  Episod-5: Ep_Return=2541.9173650660914, Ep_Len=1000
# 	  Episod-6: Ep_Return=2542.5472758127407, Ep_Len=1000
# 	  Episod-7: Ep_Return=2546.566942273045, Ep_Len=1000
# 	  Episod-8: Ep_Return=2552.027499457162, Ep_Len=1000
# 	  Episod-9: Ep_Return=2545.348816630521, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1976.7584294708106, Ep_Len=1000
# 	  Episod-1: Ep_Return=2118.2636549653535, Ep_Len=1000
# 	  Episod-2: Ep_Return=2008.9051797135312, Ep_Len=1000
# 	  Episod-3: Ep_Return=2088.9021464411944, Ep_Len=1000
# 	  Episod-4: Ep_Return=2050.03433230698, Ep_Len=1000
# 	  Episod-5: Ep_Return=2067.9014347488433, Ep_Len=1000
# 	  Episod-6: Ep_Return=2150.8388405054725, Ep_Len=1000
# 	  Episod-7: Ep_Return=2065.1403479873406, Ep_Len=1000
# 	  Episod-8: Ep_Return=1995.4114949240668, Ep_Len=1000
# 	  Episod-9: Ep_Return=2067.613551680138, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2035.12551204615, Ep_Len=1000
# 	  Episod-1: Ep_Return=2035.9439666340288, Ep_Len=1000
# 	  Episod-2: Ep_Return=2030.6807804256225, Ep_Len=1000
# 	  Episod-3: Ep_Return=2081.5138478371628, Ep_Len=1000
# 	  Episod-4: Ep_Return=2024.637469399683, Ep_Len=1000
# 	  Episod-5: Ep_Return=2024.385969289356, Ep_Len=1000
# 	  Episod-6: Ep_Return=2034.3616822532483, Ep_Len=1000
# 	  Episod-7: Ep_Return=2012.7345094070854, Ep_Len=1000
# 	  Episod-8: Ep_Return=1993.4517476611534, Ep_Len=1000
# 	  Episod-9: Ep_Return=2067.196715126597, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2042.1184765985722, Ep_Len=1000
# 	  Episod-1: Ep_Return=2071.4320737720145, Ep_Len=1000
# 	  Episod-2: Ep_Return=2066.234301241927, Ep_Len=1000
# 	  Episod-3: Ep_Return=1967.0788766065898, Ep_Len=1000
# 	  Episod-4: Ep_Return=2007.709664963272, Ep_Len=1000
# 	  Episod-5: Ep_Return=2067.511235945378, Ep_Len=1000
# 	  Episod-6: Ep_Return=2029.3601433994083, Ep_Len=1000
# 	  Episod-7: Ep_Return=2062.874852082665, Ep_Len=1000
# 	  Episod-8: Ep_Return=2019.6811362382145, Ep_Len=1000
# 	  Episod-9: Ep_Return=2059.996427432842, Ep_Len=1000
# ********************************************************************
# 2020-10-29_00-00-00_TD3-OW-AddPastAct_AntPyBulletEnv-v0_MDP_s0
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2104.811457563259, Ep_Len=1000
# 	  Episod-1: Ep_Return=2094.1690083306944, Ep_Len=1000
# 	  Episod-2: Ep_Return=2192.3820647262805, Ep_Len=1000
# 	  Episod-3: Ep_Return=2103.0411407398983, Ep_Len=1000
# 	  Episod-4: Ep_Return=2141.0741225759552, Ep_Len=1000
# 	  Episod-5: Ep_Return=2136.544818797069, Ep_Len=1000
# 	  Episod-6: Ep_Return=2127.502656099735, Ep_Len=1000
# 	  Episod-7: Ep_Return=2098.803501410973, Ep_Len=1000
# 	  Episod-8: Ep_Return=2143.8303862979733, Ep_Len=1000
# 	  Episod-9: Ep_Return=2076.1914427217084, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2043.777443499688, Ep_Len=1000
# 	  Episod-1: Ep_Return=2041.7736906728182, Ep_Len=1000
# 	  Episod-2: Ep_Return=1967.4524021284335, Ep_Len=1000
# 	  Episod-3: Ep_Return=2016.3320055724787, Ep_Len=1000
# 	  Episod-4: Ep_Return=1871.5600332617762, Ep_Len=1000
# 	  Episod-5: Ep_Return=1941.079141063494, Ep_Len=1000
# 	  Episod-6: Ep_Return=1939.0170328742279, Ep_Len=1000
# 	  Episod-7: Ep_Return=1994.6948482328528, Ep_Len=1000
# 	  Episod-8: Ep_Return=2058.143855043579, Ep_Len=1000
# 	  Episod-9: Ep_Return=2057.2568114430537, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1974.7731690831458, Ep_Len=1000
# 	  Episod-1: Ep_Return=2088.73488673776, Ep_Len=1000
# 	  Episod-2: Ep_Return=1996.4009839676917, Ep_Len=1000
# 	  Episod-3: Ep_Return=2034.1301988024854, Ep_Len=1000
# 	  Episod-4: Ep_Return=2046.2771964025897, Ep_Len=1000
# 	  Episod-5: Ep_Return=2072.0800986522386, Ep_Len=1000
# 	  Episod-6: Ep_Return=1952.071137818688, Ep_Len=1000
# 	  Episod-7: Ep_Return=2015.897139946599, Ep_Len=1000
# 	  Episod-8: Ep_Return=1934.7928548089264, Ep_Len=1000
# 	  Episod-9: Ep_Return=2020.7616114006976, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2023.9002937179846, Ep_Len=1000
# 	  Episod-1: Ep_Return=1959.3055780558516, Ep_Len=1000
# 	  Episod-2: Ep_Return=2015.4527542185645, Ep_Len=1000
# 	  Episod-3: Ep_Return=1974.126786132405, Ep_Len=1000
# 	  Episod-4: Ep_Return=2051.68699452954, Ep_Len=1000
# 	  Episod-5: Ep_Return=2006.1868732707374, Ep_Len=1000
# 	  Episod-6: Ep_Return=1975.705101185154, Ep_Len=1000
# 	  Episod-7: Ep_Return=1992.057481330108, Ep_Len=1000
# 	  Episod-8: Ep_Return=2028.8295006457129, Ep_Len=1000
# 	  Episod-9: Ep_Return=1984.6339066518462, Ep_Len=1000
# ********************************************************************
# 2020-10-29_00-00-00_TD3-OW-AddPastAct_AntPyBulletEnv-v0_MDP_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2148.090086478399, Ep_Len=1000
# 	  Episod-1: Ep_Return=2098.605325349188, Ep_Len=1000
# 	  Episod-2: Ep_Return=2091.3014670924445, Ep_Len=1000
# 	  Episod-3: Ep_Return=2118.7491264702207, Ep_Len=1000
# 	  Episod-4: Ep_Return=2185.2656749230273, Ep_Len=1000
# 	  Episod-5: Ep_Return=2113.9538003690845, Ep_Len=1000
# 	  Episod-6: Ep_Return=2168.88179851164, Ep_Len=1000
# 	  Episod-7: Ep_Return=2139.940961420544, Ep_Len=1000
# 	  Episod-8: Ep_Return=2123.081890156423, Ep_Len=1000
# 	  Episod-9: Ep_Return=2180.0429343681444, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2041.5052298386356, Ep_Len=1000
# 	  Episod-1: Ep_Return=1946.5444780669523, Ep_Len=1000
# 	  Episod-2: Ep_Return=1933.9870690247485, Ep_Len=1000
# 	  Episod-3: Ep_Return=1993.0084015822542, Ep_Len=1000
# 	  Episod-4: Ep_Return=1968.1750938650775, Ep_Len=1000
# 	  Episod-5: Ep_Return=1967.9444808782437, Ep_Len=1000
# 	  Episod-6: Ep_Return=2002.5480415769357, Ep_Len=1000
# 	  Episod-7: Ep_Return=2009.4201711808555, Ep_Len=1000
# 	  Episod-8: Ep_Return=1967.2582204562443, Ep_Len=1000
# 	  Episod-9: Ep_Return=2032.6545413608758, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2107.9340205965614, Ep_Len=1000
# 	  Episod-1: Ep_Return=2089.353229212423, Ep_Len=1000
# 	  Episod-2: Ep_Return=1979.4635046928556, Ep_Len=1000
# 	  Episod-3: Ep_Return=2055.885449127957, Ep_Len=1000
# 	  Episod-4: Ep_Return=2082.7884597712464, Ep_Len=1000
# 	  Episod-5: Ep_Return=2016.825812673797, Ep_Len=1000
# 	  Episod-6: Ep_Return=2150.455281853843, Ep_Len=1000
# 	  Episod-7: Ep_Return=2031.0997858503201, Ep_Len=1000
# 	  Episod-8: Ep_Return=2070.4051635757605, Ep_Len=1000
# 	  Episod-9: Ep_Return=2099.176249964348, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2000.752980002769, Ep_Len=1000
# 	  Episod-1: Ep_Return=1981.708893846521, Ep_Len=1000
# 	  Episod-2: Ep_Return=1956.5145247048633, Ep_Len=1000
# 	  Episod-3: Ep_Return=1977.1610358386918, Ep_Len=1000
# 	  Episod-4: Ep_Return=2011.99347474649, Ep_Len=1000
# 	  Episod-5: Ep_Return=1996.9571136340653, Ep_Len=1000
# 	  Episod-6: Ep_Return=2057.259357862406, Ep_Len=1000
# 	  Episod-7: Ep_Return=1998.186650692284, Ep_Len=1000
# 	  Episod-8: Ep_Return=2062.720306581388, Ep_Len=1000
# 	  Episod-9: Ep_Return=2026.8328767866083, Ep_Len=1000
# ********************************************************************
# 2021-01-29_17-49-22_TD3-OW-AddPastAct_AntPyBulletEnv-v0_MDP_s0
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1934.7931126732108, Ep_Len=1000
# 	  Episod-1: Ep_Return=1949.8497876032773, Ep_Len=1000
# 	  Episod-2: Ep_Return=1941.5605947781626, Ep_Len=1000
# 	  Episod-3: Ep_Return=1890.4743950101426, Ep_Len=1000
# 	  Episod-4: Ep_Return=1875.0845623833811, Ep_Len=1000
# 	  Episod-5: Ep_Return=1972.6056425007253, Ep_Len=1000
# 	  Episod-6: Ep_Return=1979.0429440576218, Ep_Len=1000
# 	  Episod-7: Ep_Return=1931.0016489994198, Ep_Len=1000
# 	  Episod-8: Ep_Return=1896.5037232356124, Ep_Len=1000
# 	  Episod-9: Ep_Return=1956.4090015067115, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1820.9670331937386, Ep_Len=1000
# 	  Episod-1: Ep_Return=1852.2131114239864, Ep_Len=1000
# 	  Episod-2: Ep_Return=1764.3372657350533, Ep_Len=1000
# 	  Episod-3: Ep_Return=1738.176313898817, Ep_Len=1000
# 	  Episod-4: Ep_Return=1839.7348536951772, Ep_Len=1000
# 	  Episod-5: Ep_Return=1787.3105498839836, Ep_Len=1000
# 	  Episod-6: Ep_Return=1816.3240571965623, Ep_Len=1000
# 	  Episod-7: Ep_Return=1790.073378255438, Ep_Len=1000
# 	  Episod-8: Ep_Return=1901.2706207575463, Ep_Len=1000
# 	  Episod-9: Ep_Return=1823.7139948150873, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1878.2675719953213, Ep_Len=1000
# 	  Episod-1: Ep_Return=1876.7042437983966, Ep_Len=1000
# 	  Episod-2: Ep_Return=1871.564857065196, Ep_Len=1000
# 	  Episod-3: Ep_Return=1919.1174318875387, Ep_Len=1000
# 	  Episod-4: Ep_Return=1927.4373508874705, Ep_Len=1000
# 	  Episod-5: Ep_Return=1840.0846744635385, Ep_Len=1000
# 	  Episod-6: Ep_Return=1893.1593254764202, Ep_Len=1000
# 	  Episod-7: Ep_Return=1886.7530092191475, Ep_Len=1000
# 	  Episod-8: Ep_Return=1888.5750299804129, Ep_Len=1000
# 	  Episod-9: Ep_Return=1794.0257412541393, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1872.0592361572292, Ep_Len=1000
# 	  Episod-1: Ep_Return=1747.0508429203105, Ep_Len=1000
# 	  Episod-2: Ep_Return=1862.7785272459594, Ep_Len=1000
# 	  Episod-3: Ep_Return=1774.6767570196394, Ep_Len=1000
# 	  Episod-4: Ep_Return=1784.1808681728096, Ep_Len=1000
# 	  Episod-5: Ep_Return=1870.2036203842272, Ep_Len=1000
# 	  Episod-6: Ep_Return=1831.284887551212, Ep_Len=1000
# 	  Episod-7: Ep_Return=1798.1647546325967, Ep_Len=1000
# 	  Episod-8: Ep_Return=1822.4927681295126, Ep_Len=1000
# 	  Episod-9: Ep_Return=1852.2086267230338, Ep_Len=1000
# ********************************************************************
# 2021-01-29_17-49-21_TD3-OW-AddPastAct_AntPyBulletEnv-v0_MDP_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=77.72219407564681, Ep_Len=1000
# 	  Episod-1: Ep_Return=80.4284148711111, Ep_Len=1000
# 	  Episod-2: Ep_Return=81.52526803223262, Ep_Len=1000
# 	  Episod-3: Ep_Return=68.93122965888513, Ep_Len=1000
# 	  Episod-4: Ep_Return=76.19063899908643, Ep_Len=1000
# 	  Episod-5: Ep_Return=71.24386417110532, Ep_Len=1000
# 	  Episod-6: Ep_Return=79.47439515563865, Ep_Len=1000
# 	  Episod-7: Ep_Return=182.70678060778692, Ep_Len=1000
# 	  Episod-8: Ep_Return=83.86960573139896, Ep_Len=1000
# 	  Episod-9: Ep_Return=68.4490347558215, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=82.0591656306434, Ep_Len=1000
# 	  Episod-1: Ep_Return=77.91386134154435, Ep_Len=1000
# 	  Episod-2: Ep_Return=81.527741515313, Ep_Len=1000
# 	  Episod-3: Ep_Return=69.1251545708441, Ep_Len=1000
# 	  Episod-4: Ep_Return=82.16561347056658, Ep_Len=1000
# 	  Episod-5: Ep_Return=69.51034274718296, Ep_Len=1000
# 	  Episod-6: Ep_Return=81.75196052834322, Ep_Len=1000
# 	  Episod-7: Ep_Return=74.49123816582726, Ep_Len=1000
# 	  Episod-8: Ep_Return=81.40974966733442, Ep_Len=1000
# 	  Episod-9: Ep_Return=66.91761508232648, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=72.0427828448943, Ep_Len=1000
# 	  Episod-1: Ep_Return=169.72872291512064, Ep_Len=1000
# 	  Episod-2: Ep_Return=68.45780475344843, Ep_Len=1000
# 	  Episod-3: Ep_Return=73.65929801325555, Ep_Len=1000
# 	  Episod-4: Ep_Return=69.37374549018313, Ep_Len=1000
# 	  Episod-5: Ep_Return=71.12097240626923, Ep_Len=1000
# 	  Episod-6: Ep_Return=80.58673401780217, Ep_Len=1000
# 	  Episod-7: Ep_Return=63.24811417066597, Ep_Len=1000
# 	  Episod-8: Ep_Return=73.72730847576469, Ep_Len=1000
# 	  Episod-9: Ep_Return=83.03798296681003, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=80.41533042983761, Ep_Len=1000
# 	  Episod-1: Ep_Return=72.20073450236687, Ep_Len=1000
# 	  Episod-2: Ep_Return=76.789762579018, Ep_Len=1000
# 	  Episod-3: Ep_Return=72.58017492470985, Ep_Len=1000
# 	  Episod-4: Ep_Return=72.6442846612817, Ep_Len=1000
# 	  Episod-5: Ep_Return=79.28616600563083, Ep_Len=1000
# 	  Episod-6: Ep_Return=77.86470689495312, Ep_Len=1000
# 	  Episod-7: Ep_Return=82.243154354962, Ep_Len=1000
# 	  Episod-8: Ep_Return=63.27225253659927, Ep_Len=1000
# 	  Episod-9: Ep_Return=73.81294959803934, Ep_Len=1000
# ********************************************************************
# 2021-01-29_17-49-23_TD3-OW-AddPastAct_AntPyBulletEnv-v0_MDP_s2
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2217.0664737755906, Ep_Len=1000
# 	  Episod-1: Ep_Return=2196.3037406587096, Ep_Len=1000
# 	  Episod-2: Ep_Return=2181.1597348227, Ep_Len=1000
# 	  Episod-3: Ep_Return=2225.756961187465, Ep_Len=1000
# 	  Episod-4: Ep_Return=2191.1749531450573, Ep_Len=1000
# 	  Episod-5: Ep_Return=2180.1781428037366, Ep_Len=1000
# 	  Episod-6: Ep_Return=2174.1327531687516, Ep_Len=1000
# 	  Episod-7: Ep_Return=2170.188133729547, Ep_Len=1000
# 	  Episod-8: Ep_Return=2200.982008959839, Ep_Len=1000
# 	  Episod-9: Ep_Return=2197.3664949823687, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2097.5998557632165, Ep_Len=1000
# 	  Episod-1: Ep_Return=2118.0491448375687, Ep_Len=1000
# 	  Episod-2: Ep_Return=2076.9382683620724, Ep_Len=1000
# 	  Episod-3: Ep_Return=2025.0595391546772, Ep_Len=1000
# 	  Episod-4: Ep_Return=2061.312117956954, Ep_Len=1000
# 	  Episod-5: Ep_Return=2100.6432816352008, Ep_Len=1000
# 	  Episod-6: Ep_Return=2076.1381123944643, Ep_Len=1000
# 	  Episod-7: Ep_Return=2055.552942718558, Ep_Len=1000
# 	  Episod-8: Ep_Return=2073.953916019784, Ep_Len=1000
# 	  Episod-9: Ep_Return=2064.5632635885445, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2099.1271118724635, Ep_Len=1000
# 	  Episod-1: Ep_Return=2097.2521505177406, Ep_Len=1000
# 	  Episod-2: Ep_Return=2132.6368019891856, Ep_Len=1000
# 	  Episod-3: Ep_Return=2146.5780879767717, Ep_Len=1000
# 	  Episod-4: Ep_Return=2145.252431562066, Ep_Len=1000
# 	  Episod-5: Ep_Return=2137.7699822918935, Ep_Len=1000
# 	  Episod-6: Ep_Return=2119.815995669736, Ep_Len=1000
# 	  Episod-7: Ep_Return=2119.5835728208417, Ep_Len=1000
# 	  Episod-8: Ep_Return=2181.513450915433, Ep_Len=1000
# 	  Episod-9: Ep_Return=2067.662825169622, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2106.131067576291, Ep_Len=1000
# 	  Episod-1: Ep_Return=2138.453708011599, Ep_Len=1000
# 	  Episod-2: Ep_Return=2145.656389308613, Ep_Len=1000
# 	  Episod-3: Ep_Return=2122.464547710438, Ep_Len=1000
# 	  Episod-4: Ep_Return=2101.9532845442686, Ep_Len=1000
# 	  Episod-5: Ep_Return=2090.411120897389, Ep_Len=1000
# 	  Episod-6: Ep_Return=2122.5344328200895, Ep_Len=1000
# 	  Episod-7: Ep_Return=2091.408014989049, Ep_Len=1000
# 	  Episod-8: Ep_Return=2108.331307452176, Ep_Len=1000
# 	  Episod-9: Ep_Return=2112.712293871957, Ep_Len=1000
# ********************************************************************
# 2021-01-29_17-49-20_TD3-OW-AddPastAct_AntPyBulletEnv-v0_MDP_s3
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2345.081494866967, Ep_Len=1000
# 	  Episod-1: Ep_Return=2460.649907549956, Ep_Len=1000
# 	  Episod-2: Ep_Return=2504.6517778354096, Ep_Len=1000
# 	  Episod-3: Ep_Return=2454.28000217233, Ep_Len=1000
# 	  Episod-4: Ep_Return=2526.5600058550185, Ep_Len=1000
# 	  Episod-5: Ep_Return=2432.1821075512294, Ep_Len=1000
# 	  Episod-6: Ep_Return=2476.5435524786117, Ep_Len=1000
# 	  Episod-7: Ep_Return=2375.7202123053567, Ep_Len=1000
# 	  Episod-8: Ep_Return=2504.9825093063273, Ep_Len=1000
# 	  Episod-9: Ep_Return=2455.6017916925866, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2238.0411325755426, Ep_Len=1000
# 	  Episod-1: Ep_Return=2225.517687391834, Ep_Len=1000
# 	  Episod-2: Ep_Return=2255.4726765637447, Ep_Len=1000
# 	  Episod-3: Ep_Return=2279.340905847964, Ep_Len=1000
# 	  Episod-4: Ep_Return=2298.131409239187, Ep_Len=1000
# 	  Episod-5: Ep_Return=2167.9229746225383, Ep_Len=1000
# 	  Episod-6: Ep_Return=2367.0432944889435, Ep_Len=1000
# 	  Episod-7: Ep_Return=2334.2722935356364, Ep_Len=1000
# 	  Episod-8: Ep_Return=2290.9987859088365, Ep_Len=1000
# 	  Episod-9: Ep_Return=2214.580884662751, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2427.535550248419, Ep_Len=1000
# 	  Episod-1: Ep_Return=2414.8878905155907, Ep_Len=1000
# 	  Episod-2: Ep_Return=2301.877877315012, Ep_Len=1000
# 	  Episod-3: Ep_Return=2338.6076123098374, Ep_Len=1000
# 	  Episod-4: Ep_Return=2462.8425675794283, Ep_Len=1000
# 	  Episod-5: Ep_Return=2300.848363350669, Ep_Len=1000
# 	  Episod-6: Ep_Return=2335.897312875588, Ep_Len=1000
# 	  Episod-7: Ep_Return=2280.6564041273277, Ep_Len=1000
# 	  Episod-8: Ep_Return=2338.741468597539, Ep_Len=1000
# 	  Episod-9: Ep_Return=2414.3595343152756, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2213.754549059297, Ep_Len=1000
# 	  Episod-1: Ep_Return=2210.0609402812006, Ep_Len=1000
# 	  Episod-2: Ep_Return=2299.2401001626436, Ep_Len=1000
# 	  Episod-3: Ep_Return=2255.206234724648, Ep_Len=1000
# 	  Episod-4: Ep_Return=2277.2184045475456, Ep_Len=1000
# 	  Episod-5: Ep_Return=2285.8710152330127, Ep_Len=1000
# 	  Episod-6: Ep_Return=2360.9418221828855, Ep_Len=1000
# 	  Episod-7: Ep_Return=2258.7930532122577, Ep_Len=1000
# 	  Episod-8: Ep_Return=2278.9348018003916, Ep_Len=1000
# 	  Episod-9: Ep_Return=2243.94635431745, Ep_Len=1000
# ********************************************************************
# 2021-01-29_22-39-05_TD3-OW_AntPyBulletEnv-v0_MDP_s0
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2367.4747765153993, Ep_Len=1000
# 	  Episod-1: Ep_Return=2362.511694361408, Ep_Len=1000
# 	  Episod-2: Ep_Return=2372.1014865049356, Ep_Len=1000
# 	  Episod-3: Ep_Return=2390.2597576987578, Ep_Len=1000
# 	  Episod-4: Ep_Return=2415.43764234302, Ep_Len=1000
# 	  Episod-5: Ep_Return=2448.0408365965195, Ep_Len=1000
# 	  Episod-6: Ep_Return=2282.7509898640606, Ep_Len=1000
# 	  Episod-7: Ep_Return=2305.088627269478, Ep_Len=1000
# 	  Episod-8: Ep_Return=2349.1495437243098, Ep_Len=1000
# 	  Episod-9: Ep_Return=2365.8577893141423, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2066.7393720057007, Ep_Len=1000
# 	  Episod-1: Ep_Return=2134.535295954798, Ep_Len=1000
# 	  Episod-2: Ep_Return=2127.0101913470394, Ep_Len=1000
# 	  Episod-3: Ep_Return=2110.773308877799, Ep_Len=1000
# 	  Episod-4: Ep_Return=2234.746804419273, Ep_Len=1000
# 	  Episod-5: Ep_Return=2119.784561620452, Ep_Len=1000
# 	  Episod-6: Ep_Return=2174.7711187876453, Ep_Len=1000
# 	  Episod-7: Ep_Return=2214.009545096681, Ep_Len=1000
# 	  Episod-8: Ep_Return=2145.7508836013076, Ep_Len=1000
# 	  Episod-9: Ep_Return=2124.1894581601086, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2110.455736535237, Ep_Len=1000
# 	  Episod-1: Ep_Return=2142.1565751361986, Ep_Len=1000
# 	  Episod-2: Ep_Return=2190.313856786598, Ep_Len=1000
# 	  Episod-3: Ep_Return=2133.275289499832, Ep_Len=1000
# 	  Episod-4: Ep_Return=2159.0424470811563, Ep_Len=1000
# 	  Episod-5: Ep_Return=2156.775912087977, Ep_Len=1000
# 	  Episod-6: Ep_Return=2170.5379231143143, Ep_Len=1000
# 	  Episod-7: Ep_Return=2104.1570645091365, Ep_Len=1000
# 	  Episod-8: Ep_Return=2270.4545494399886, Ep_Len=1000
# 	  Episod-9: Ep_Return=2252.1009974688013, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2082.4236696513826, Ep_Len=1000
# 	  Episod-1: Ep_Return=2118.277660082126, Ep_Len=1000
# 	  Episod-2: Ep_Return=2069.7037829490214, Ep_Len=1000
# 	  Episod-3: Ep_Return=2147.401926263398, Ep_Len=1000
# 	  Episod-4: Ep_Return=2170.4659260279586, Ep_Len=1000
# 	  Episod-5: Ep_Return=2176.778236831657, Ep_Len=1000
# 	  Episod-6: Ep_Return=2200.871441921605, Ep_Len=1000
# 	  Episod-7: Ep_Return=2101.4396530900003, Ep_Len=1000
# 	  Episod-8: Ep_Return=2024.4741810133849, Ep_Len=1000
# 	  Episod-9: Ep_Return=2170.6969109941415, Ep_Len=1000
# ********************************************************************
# 2021-01-29_22-39-05_TD3-OW_AntPyBulletEnv-v0_MDP_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2491.552327458053, Ep_Len=1000
# 	  Episod-1: Ep_Return=2463.9134792451996, Ep_Len=1000
# 	  Episod-2: Ep_Return=2481.5664899765266, Ep_Len=1000
# 	  Episod-3: Ep_Return=2469.8744334146395, Ep_Len=1000
# 	  Episod-4: Ep_Return=2477.6709823173915, Ep_Len=1000
# 	  Episod-5: Ep_Return=2493.9163069647143, Ep_Len=1000
# 	  Episod-6: Ep_Return=2413.193799110098, Ep_Len=1000
# 	  Episod-7: Ep_Return=2483.2793080964498, Ep_Len=1000
# 	  Episod-8: Ep_Return=2512.2085614727384, Ep_Len=1000
# 	  Episod-9: Ep_Return=2470.0785647042544, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2238.2090470254843, Ep_Len=1000
# 	  Episod-1: Ep_Return=2119.0762465804432, Ep_Len=1000
# 	  Episod-2: Ep_Return=2192.4885452274975, Ep_Len=1000
# 	  Episod-3: Ep_Return=2212.4345874222195, Ep_Len=1000
# 	  Episod-4: Ep_Return=2206.8065938409995, Ep_Len=1000
# 	  Episod-5: Ep_Return=2223.8962150236202, Ep_Len=1000
# 	  Episod-6: Ep_Return=2190.330308200089, Ep_Len=1000
# 	  Episod-7: Ep_Return=2209.4470544626915, Ep_Len=1000
# 	  Episod-8: Ep_Return=2224.5639937001492, Ep_Len=1000
# 	  Episod-9: Ep_Return=2191.8281483713545, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2251.143443096755, Ep_Len=1000
# 	  Episod-1: Ep_Return=2219.9837308132564, Ep_Len=1000
# 	  Episod-2: Ep_Return=2236.3787465090372, Ep_Len=1000
# 	  Episod-3: Ep_Return=2275.758307592516, Ep_Len=1000
# 	  Episod-4: Ep_Return=2242.198459375818, Ep_Len=1000
# 	  Episod-5: Ep_Return=2159.3847033557163, Ep_Len=1000
# 	  Episod-6: Ep_Return=2202.6734771653987, Ep_Len=1000
# 	  Episod-7: Ep_Return=2337.7615282353618, Ep_Len=1000
# 	  Episod-8: Ep_Return=2316.4535418868795, Ep_Len=1000
# 	  Episod-9: Ep_Return=2170.1941480456417, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2177.502231852246, Ep_Len=1000
# 	  Episod-1: Ep_Return=2134.7897969584646, Ep_Len=1000
# 	  Episod-2: Ep_Return=2139.19429617487, Ep_Len=1000
# 	  Episod-3: Ep_Return=2117.58213755486, Ep_Len=1000
# 	  Episod-4: Ep_Return=2194.4855020828977, Ep_Len=1000
# 	  Episod-5: Ep_Return=2231.26534995347, Ep_Len=1000
# 	  Episod-6: Ep_Return=2175.9895396577735, Ep_Len=1000
# 	  Episod-7: Ep_Return=2145.988022615058, Ep_Len=1000
# 	  Episod-8: Ep_Return=2143.6884164121902, Ep_Len=1000
# 	  Episod-9: Ep_Return=2230.2474649288033, Ep_Len=1000
# ********************************************************************
# 2021-01-29_22-39-02_TD3-OW_AntPyBulletEnv-v0_MDP_s2
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2059.188228386963, Ep_Len=1000
# 	  Episod-1: Ep_Return=2062.470723971522, Ep_Len=1000
# 	  Episod-2: Ep_Return=2100.2236462101455, Ep_Len=1000
# 	  Episod-3: Ep_Return=2062.812041210052, Ep_Len=1000
# 	  Episod-4: Ep_Return=2069.9195099877365, Ep_Len=1000
# 	  Episod-5: Ep_Return=2088.2766752205216, Ep_Len=1000
# 	  Episod-6: Ep_Return=2059.5079158072813, Ep_Len=1000
# 	  Episod-7: Ep_Return=2114.231766260919, Ep_Len=1000
# 	  Episod-8: Ep_Return=2088.8041763674332, Ep_Len=1000
# 	  Episod-9: Ep_Return=2058.1280077604893, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1988.4950967933137, Ep_Len=1000
# 	  Episod-1: Ep_Return=2011.7193208813098, Ep_Len=1000
# 	  Episod-2: Ep_Return=2009.3659039385307, Ep_Len=1000
# 	  Episod-3: Ep_Return=1987.652820318964, Ep_Len=1000
# 	  Episod-4: Ep_Return=1863.7638268490778, Ep_Len=1000
# 	  Episod-5: Ep_Return=2040.4456093931933, Ep_Len=1000
# 	  Episod-6: Ep_Return=1959.6074103219553, Ep_Len=1000
# 	  Episod-7: Ep_Return=1932.026025627026, Ep_Len=1000
# 	  Episod-8: Ep_Return=1937.8257307510946, Ep_Len=1000
# 	  Episod-9: Ep_Return=2032.8651258367076, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1921.8982906569909, Ep_Len=1000
# 	  Episod-1: Ep_Return=1971.1490019362595, Ep_Len=1000
# 	  Episod-2: Ep_Return=1924.151516375031, Ep_Len=1000
# 	  Episod-3: Ep_Return=1904.6365591166057, Ep_Len=1000
# 	  Episod-4: Ep_Return=1971.0600678063583, Ep_Len=1000
# 	  Episod-5: Ep_Return=2021.5755420192868, Ep_Len=1000
# 	  Episod-6: Ep_Return=1927.132891950459, Ep_Len=1000
# 	  Episod-7: Ep_Return=1947.9773907666204, Ep_Len=1000
# 	  Episod-8: Ep_Return=1971.5539939948555, Ep_Len=1000
# 	  Episod-9: Ep_Return=1940.3070886231112, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1779.5963874657723, Ep_Len=1000
# 	  Episod-1: Ep_Return=1954.305688849769, Ep_Len=1000
# 	  Episod-2: Ep_Return=1953.7943699379243, Ep_Len=1000
# 	  Episod-3: Ep_Return=1933.6895652485773, Ep_Len=1000
# 	  Episod-4: Ep_Return=1922.3324208209563, Ep_Len=1000
# 	  Episod-5: Ep_Return=1774.3562493766458, Ep_Len=1000
# 	  Episod-6: Ep_Return=1941.7968605276296, Ep_Len=1000
# 	  Episod-7: Ep_Return=1905.0257592330863, Ep_Len=1000
# 	  Episod-8: Ep_Return=1964.2170476890594, Ep_Len=1000
# 	  Episod-9: Ep_Return=1872.0353445530168, Ep_Len=1000
# ********************************************************************
# 2021-01-29_22-39-04_TD3-OW_AntPyBulletEnv-v0_MDP_s3
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2366.6399584227047, Ep_Len=1000
# 	  Episod-1: Ep_Return=2347.5222814682347, Ep_Len=1000
# 	  Episod-2: Ep_Return=2355.396517537557, Ep_Len=1000
# 	  Episod-3: Ep_Return=2334.3865794924213, Ep_Len=1000
# 	  Episod-4: Ep_Return=2356.22035208726, Ep_Len=1000
# 	  Episod-5: Ep_Return=2375.01355852141, Ep_Len=1000
# 	  Episod-6: Ep_Return=2386.652228029591, Ep_Len=1000
# 	  Episod-7: Ep_Return=2422.1823707197677, Ep_Len=1000
# 	  Episod-8: Ep_Return=2364.7350588763593, Ep_Len=1000
# 	  Episod-9: Ep_Return=2294.5707812124865, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2215.3689546257515, Ep_Len=1000
# 	  Episod-1: Ep_Return=2140.5443330333246, Ep_Len=1000
# 	  Episod-2: Ep_Return=2175.380907314286, Ep_Len=1000
# 	  Episod-3: Ep_Return=2257.658851532152, Ep_Len=1000
# 	  Episod-4: Ep_Return=2117.1217498275087, Ep_Len=1000
# 	  Episod-5: Ep_Return=2173.280672230658, Ep_Len=1000
# 	  Episod-6: Ep_Return=2125.4872047240146, Ep_Len=1000
# 	  Episod-7: Ep_Return=2171.0165207319305, Ep_Len=1000
# 	  Episod-8: Ep_Return=2187.2858738683817, Ep_Len=1000
# 	  Episod-9: Ep_Return=2212.548000363207, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2214.042429529995, Ep_Len=1000
# 	  Episod-1: Ep_Return=2191.6133452734616, Ep_Len=1000
# 	  Episod-2: Ep_Return=2190.7022782689833, Ep_Len=1000
# 	  Episod-3: Ep_Return=2188.562352697892, Ep_Len=1000
# 	  Episod-4: Ep_Return=2266.0914785600335, Ep_Len=1000
# 	  Episod-5: Ep_Return=2266.4995041138022, Ep_Len=1000
# 	  Episod-6: Ep_Return=2220.347495856699, Ep_Len=1000
# 	  Episod-7: Ep_Return=2175.847457297163, Ep_Len=1000
# 	  Episod-8: Ep_Return=2151.2911692947937, Ep_Len=1000
# 	  Episod-9: Ep_Return=2142.9930404520646, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2074.1936679659725, Ep_Len=1000
# 	  Episod-1: Ep_Return=2083.429652837007, Ep_Len=1000
# 	  Episod-2: Ep_Return=2098.6340918071405, Ep_Len=1000
# 	  Episod-3: Ep_Return=2037.335254880488, Ep_Len=1000
# 	  Episod-4: Ep_Return=2104.649138837398, Ep_Len=1000
# 	  Episod-5: Ep_Return=2090.1772677293266, Ep_Len=1000
# 	  Episod-6: Ep_Return=2105.166437155295, Ep_Len=1000
# 	  Episod-7: Ep_Return=2081.791615552435, Ep_Len=1000
# 	  Episod-8: Ep_Return=2072.0911741809773, Ep_Len=1000
# 	  Episod-9: Ep_Return=2020.8833636284246, Ep_Len=1000

# %% [markdown]
# ## MDP-> POMDP:
# ### LSTM-TD3

# %%
root_dir = r"D:\POMDP_Data\new_spinup_resumable_MDP_LSTM_TD3"
DEVICE = "cpu"  # "cuda"
lstm_td3_MDP_to_POMDP = {}
for sub_dir in os.listdir(root_dir):
    print(sub_dir)
    print(sub_dir.split('_'))
    params = sub_dir.split('_')
    alg_name = params[1]
    task_name = params[2]
    seed = params[4]
    hist_len = params[5]
    if task_name in tasks:
        if alg_name not in lstm_td3_MDP_to_POMDP:
            lstm_td3_MDP_to_POMDP[alg_name] = {}
        if task_name not in lstm_td3_MDP_to_POMDP[alg_name]:
            lstm_td3_MDP_to_POMDP[alg_name][task_name] = {}
        if hist_len not in lstm_td3_MDP_to_POMDP[alg_name][task_name]:
            lstm_td3_MDP_to_POMDP[alg_name][task_name][hist_len] = {}
        if seed not in lstm_td3_MDP_to_POMDP[alg_name][task_name][hist_len]:
            lstm_td3_MDP_to_POMDP[alg_name][task_name][hist_len][seed] = {}
        #
        print("********************************************************************")
        for exp_run in os.listdir(os.path.join(root_dir, sub_dir)):
            print(exp_run)
            # Load pre-trained model
            config_path = os.path.join(root_dir, sub_dir, exp_run, 'config.json')
            with open(config_path, 'r') as config_file:
                config_json = json.load(config_file)
            # Retrive hyper-parameters
            env_name = config_json['env_name']
            num_test_episodes = config_json['num_test_episodes']
            max_ep_len = config_json['max_ep_len']
            max_hist_len = config_json['max_hist_len']
            
            #
            env = gym.make(task_name)
            obs_dim = env.observation_space.shape[0]
            act_dim = env.action_space.shape[0]
            act_limit = env.action_space.high[0]
            critic_mem_pre_lstm_hid_sizes = config_json['critic_mem_pre_lstm_hid_sizes']
            critic_mem_lstm_hid_sizes = config_json['critic_mem_lstm_hid_sizes']
            critic_mem_after_lstm_hid_size = config_json['critic_mem_after_lstm_hid_size']
            critic_cur_feature_hid_sizes = config_json['critic_cur_feature_hid_sizes']
            critic_post_comb_hid_sizes = config_json['critic_post_comb_hid_sizes']
            critic_mem_gate = config_json['critic_mem_gate']
            critic_mem_gate_before_current_feature_extraction = config_json['critic_mem_gate_before_current_feature_extraction']
            critic_hist_with_past_act = config_json['critic_hist_with_past_act']
            critic_use_hist_mask = config_json['critic_use_hist_mask']
            actor_mem_pre_lstm_hid_sizes = config_json['actor_mem_pre_lstm_hid_sizes']
            actor_mem_lstm_hid_sizes = config_json['actor_mem_lstm_hid_sizes']
            actor_mem_after_lstm_hid_size = config_json['actor_mem_after_lstm_hid_size']
            actor_cur_feature_hid_sizes = config_json['actor_cur_feature_hid_sizes']
            actor_post_comb_hid_sizes = config_json['actor_post_comb_hid_sizes']
            actor_mem_gate = config_json['actor_mem_gate']
            actor_mem_gate_before_current_feature_extraction = config_json['actor_mem_gate_before_current_feature_extraction']
            actor_hist_with_past_act = config_json['actor_hist_with_past_act']
            actor_use_hist_mask = config_json['actor_use_hist_mask']    
            ac = MLPActorCritic(obs_dim, act_dim, act_limit,
                                critic_mem_pre_lstm_hid_sizes=critic_mem_pre_lstm_hid_sizes,
                                critic_mem_lstm_hid_sizes=critic_mem_lstm_hid_sizes,
                                critic_mem_after_lstm_hid_size=critic_mem_after_lstm_hid_size,
                                critic_cur_feature_hid_sizes=critic_cur_feature_hid_sizes,
                                critic_post_comb_hid_sizes=critic_post_comb_hid_sizes,
                                critic_mem_gate=critic_mem_gate,
                                critic_mem_gate_before_current_feature_extraction=critic_mem_gate_before_current_feature_extraction,
                                critic_hist_with_past_act=critic_hist_with_past_act,
                                critic_use_hist_mask=critic_use_hist_mask,
                                actor_mem_pre_lstm_hid_sizes=actor_mem_pre_lstm_hid_sizes,
                                actor_mem_lstm_hid_sizes=actor_mem_lstm_hid_sizes,
                                actor_mem_after_lstm_hid_size=actor_mem_after_lstm_hid_size,
                                actor_cur_feature_hid_sizes=actor_cur_feature_hid_sizes,
                                actor_post_comb_hid_sizes=actor_post_comb_hid_sizes,
                                actor_mem_gate=actor_mem_gate,
                                actor_mem_gate_before_current_feature_extraction=actor_mem_gate_before_current_feature_extraction,
                                actor_hist_with_past_act=actor_hist_with_past_act,
                                actor_use_hist_mask=actor_use_hist_mask)
            # Load model
            resume_checkpoint_path = os.path.join(root_dir, sub_dir, exp_run, "pyt_save")
            checkpoint_files = os.listdir(resume_checkpoint_path)
            latest_model_checkpoint_file_path = os.path.join(resume_checkpoint_path, checkpoint_files[-1])
            
            model_checkpoint = torch.load(latest_model_checkpoint_file_path)
            ac.load_state_dict(model_checkpoint['ac_state_dict'])
            
            # print(ac)

            
            # Not include POMDP-RV, because POMDP-RV changed the dimension of observation.
            for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
                print("\t{}".format(pomdp_type))
                lstm_td3_MDP_to_POMDP[alg_name][task_name][hist_len][seed][pomdp_type] = []
                # Create environment
                if pomdp_type == 'MDP':
                    test_env = gym.make(env_name)
                else:
                    test_env = POMDPWrapper(env_name, pomdp_type, flicker_prob, random_noise_sigma, random_sensor_missing_prob)
                obs_dim = test_env.observation_space.shape[0]
                act_dim = test_env.action_space.shape[0]
                act_limit = test_env.action_space.high[0]
                
                # Evaluation
                for j in range(num_test_episodes):
                    # Reset environment
                    o, d, ep_ret, ep_len = test_env.reset(), False, 0, 0
                    if max_hist_len > 0:
                        o_buff = np.zeros([max_hist_len, obs_dim])
                        a_buff = np.zeros([max_hist_len, act_dim])
                        o_buff[0, :] = o
                        o_buff_len = 0
                    else:
                        o_buff = np.zeros([1, obs_dim])
                        a_buff = np.zeros([1, act_dim])
                        o_buff_len = 0

                    # Interact
                    while not(d or (ep_len == max_ep_len)):
                        # Take deterministic actions at test time 
                        h_o = torch.tensor(o_buff).view(1, o_buff.shape[0], o_buff.shape[1]).float().to(DEVICE)
                        h_a = torch.tensor(a_buff).view(1, a_buff.shape[0], a_buff.shape[1]).float().to(DEVICE)
                        h_l = torch.tensor([o_buff_len]).float().to(DEVICE)
                        a = ac.act(torch.as_tensor(o, dtype=torch.float32).view(1, -1).to(DEVICE),
                                   h_o, h_a, h_l).reshape(act_dim)
                        
                        o2, r, d, _ = test_env.step(a)
                        ep_ret += r
                        ep_len += 1

                        # Add short history
                        if max_hist_len != 0:
                            if o_buff_len == max_hist_len:
                                o_buff[:max_hist_len - 1] = o_buff[1:]
                                a_buff[:max_hist_len - 1] = a_buff[1:]
                                o_buff[max_hist_len - 1] = list(o)
                                a_buff[max_hist_len - 1] = list(a)
                            else:
                                o_buff[o_buff_len + 1 - 1] = list(o)
                                a_buff[o_buff_len + 1 - 1] = list(a)
                                o_buff_len += 1
                        o = o2
                    print('\t  Episod-{}: Ep_Return={}, Ep_Len={}'.format(j, ep_ret, ep_len))
                    lstm_td3_MDP_to_POMDP[alg_name][task_name][hist_len][seed][pomdp_type].append(ep_ret)
# Out:
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '0', '0']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_0_0_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2638.225176572201, Ep_Len=1000
# 	  Episod-1: Ep_Return=2643.72699688457, Ep_Len=1000
# 	  Episod-2: Ep_Return=2650.5558052045953, Ep_Len=1000
# 	  Episod-3: Ep_Return=2623.2402099836922, Ep_Len=1000
# 	  Episod-4: Ep_Return=2616.6986713276697, Ep_Len=1000
# 	  Episod-5: Ep_Return=2645.3815427727845, Ep_Len=1000
# 	  Episod-6: Ep_Return=2625.853581851642, Ep_Len=1000
# 	  Episod-7: Ep_Return=2653.196027895093, Ep_Len=1000
# 	  Episod-8: Ep_Return=2628.7765952180725, Ep_Len=1000
# 	  Episod-9: Ep_Return=2642.2256296661726, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1521.7925794814062, Ep_Len=1000
# 	  Episod-1: Ep_Return=1641.9213489104568, Ep_Len=1000
# 	  Episod-2: Ep_Return=1794.322840341195, Ep_Len=1000
# 	  Episod-3: Ep_Return=1759.70738300137, Ep_Len=1000
# 	  Episod-4: Ep_Return=1675.4540786108803, Ep_Len=1000
# 	  Episod-5: Ep_Return=1960.1356253952397, Ep_Len=1000
# 	  Episod-6: Ep_Return=1663.6623340972553, Ep_Len=1000
# 	  Episod-7: Ep_Return=1803.1451442980037, Ep_Len=1000
# 	  Episod-8: Ep_Return=1472.088727819629, Ep_Len=1000
# 	  Episod-9: Ep_Return=1958.4668467922156, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2111.268303182166, Ep_Len=1000
# 	  Episod-1: Ep_Return=2072.3839552853806, Ep_Len=1000
# 	  Episod-2: Ep_Return=2103.7044951841017, Ep_Len=1000
# 	  Episod-3: Ep_Return=2063.301177724563, Ep_Len=1000
# 	  Episod-4: Ep_Return=2053.9363400865177, Ep_Len=1000
# 	  Episod-5: Ep_Return=1897.6174915694992, Ep_Len=1000
# 	  Episod-6: Ep_Return=2054.23047595875, Ep_Len=1000
# 	  Episod-7: Ep_Return=2167.801303035617, Ep_Len=1000
# 	  Episod-8: Ep_Return=2053.27915614984, Ep_Len=1000
# 	  Episod-9: Ep_Return=2140.7948963958456, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1841.3122357894931, Ep_Len=1000
# 	  Episod-1: Ep_Return=1969.7467808273398, Ep_Len=1000
# 	  Episod-2: Ep_Return=2015.2632063467727, Ep_Len=1000
# 	  Episod-3: Ep_Return=2013.4818803177563, Ep_Len=1000
# 	  Episod-4: Ep_Return=1746.9027528040965, Ep_Len=1000
# 	  Episod-5: Ep_Return=1961.3086419360009, Ep_Len=1000
# 	  Episod-6: Ep_Return=1977.4333449126016, Ep_Len=1000
# 	  Episod-7: Ep_Return=2112.2839075265497, Ep_Len=1000
# 	  Episod-8: Ep_Return=1973.840511424007, Ep_Len=1000
# 	  Episod-9: Ep_Return=1955.0832716285938, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '0', '1']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_0_1_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2623.861436471869, Ep_Len=1000
# 	  Episod-1: Ep_Return=2675.2137991875516, Ep_Len=1000
# 	  Episod-2: Ep_Return=2651.989748619266, Ep_Len=1000
# 	  Episod-3: Ep_Return=2658.175656988276, Ep_Len=1000
# 	  Episod-4: Ep_Return=2649.6328056301227, Ep_Len=1000
# 	  Episod-5: Ep_Return=2696.2193010491414, Ep_Len=1000
# 	  Episod-6: Ep_Return=2723.5404514294455, Ep_Len=1000
# 	  Episod-7: Ep_Return=2554.0451743595777, Ep_Len=1000
# 	  Episod-8: Ep_Return=2690.812731821157, Ep_Len=1000
# 	  Episod-9: Ep_Return=2605.731023557604, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1759.526194214782, Ep_Len=1000
# 	  Episod-1: Ep_Return=1701.967606692534, Ep_Len=1000
# 	  Episod-2: Ep_Return=1843.5391317873646, Ep_Len=1000
# 	  Episod-3: Ep_Return=1895.7399433848736, Ep_Len=1000
# 	  Episod-4: Ep_Return=1518.315150922412, Ep_Len=1000
# 	  Episod-5: Ep_Return=1667.7674610541455, Ep_Len=1000
# 	  Episod-6: Ep_Return=1722.3295001110769, Ep_Len=1000
# 	  Episod-7: Ep_Return=1570.7672357630545, Ep_Len=1000
# 	  Episod-8: Ep_Return=696.1003062611734, Ep_Len=1000
# 	  Episod-9: Ep_Return=1855.49213449356, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2357.478642576894, Ep_Len=1000
# 	  Episod-1: Ep_Return=2299.407084915926, Ep_Len=1000
# 	  Episod-2: Ep_Return=2270.484329360669, Ep_Len=1000
# 	  Episod-3: Ep_Return=2275.4866798520584, Ep_Len=1000
# 	  Episod-4: Ep_Return=2284.6965799834343, Ep_Len=1000
# 	  Episod-5: Ep_Return=2286.905349865139, Ep_Len=1000
# 	  Episod-6: Ep_Return=2091.8507041414146, Ep_Len=1000
# 	  Episod-7: Ep_Return=2236.693595374786, Ep_Len=1000
# 	  Episod-8: Ep_Return=2313.3618240313976, Ep_Len=1000
# 	  Episod-9: Ep_Return=2283.2276773365775, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2207.5117377496513, Ep_Len=1000
# 	  Episod-1: Ep_Return=2252.1340231960958, Ep_Len=1000
# 	  Episod-2: Ep_Return=2191.7729343374326, Ep_Len=1000
# 	  Episod-3: Ep_Return=2212.0284198987897, Ep_Len=1000
# 	  Episod-4: Ep_Return=2283.1673488752904, Ep_Len=1000
# 	  Episod-5: Ep_Return=656.5896870444807, Ep_Len=1000
# 	  Episod-6: Ep_Return=2022.9116879094902, Ep_Len=1000
# 	  Episod-7: Ep_Return=2229.6903990776223, Ep_Len=1000
# 	  Episod-8: Ep_Return=1822.7058951840352, Ep_Len=1000
# 	  Episod-9: Ep_Return=2002.5483663648847, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '0', '3']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_0_3_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2738.7231444795134, Ep_Len=1000
# 	  Episod-1: Ep_Return=2693.3013882559217, Ep_Len=1000
# 	  Episod-2: Ep_Return=2753.86972952132, Ep_Len=1000
# 	  Episod-3: Ep_Return=2713.947117153824, Ep_Len=1000
# 	  Episod-4: Ep_Return=2661.6529453058793, Ep_Len=1000
# 	  Episod-5: Ep_Return=2738.8766124178414, Ep_Len=1000
# 	  Episod-6: Ep_Return=2749.6571223697915, Ep_Len=1000
# 	  Episod-7: Ep_Return=2779.582661396454, Ep_Len=1000
# 	  Episod-8: Ep_Return=2606.4641921444518, Ep_Len=1000
# 	  Episod-9: Ep_Return=2748.839344020933, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2456.4209998007987, Ep_Len=1000
# 	  Episod-1: Ep_Return=2509.1196160821246, Ep_Len=1000
# 	  Episod-2: Ep_Return=2503.568487750063, Ep_Len=1000
# 	  Episod-3: Ep_Return=2596.525172523774, Ep_Len=1000
# 	  Episod-4: Ep_Return=2393.08705471199, Ep_Len=1000
# 	  Episod-5: Ep_Return=2606.505379479947, Ep_Len=1000
# 	  Episod-6: Ep_Return=2583.540698396202, Ep_Len=1000
# 	  Episod-7: Ep_Return=2477.626688917292, Ep_Len=1000
# 	  Episod-8: Ep_Return=2683.35915588094, Ep_Len=1000
# 	  Episod-9: Ep_Return=2400.3057037257354, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2453.1896868331073, Ep_Len=1000
# 	  Episod-1: Ep_Return=2393.0391538367094, Ep_Len=1000
# 	  Episod-2: Ep_Return=2341.3254225316805, Ep_Len=1000
# 	  Episod-3: Ep_Return=2361.619796681898, Ep_Len=1000
# 	  Episod-4: Ep_Return=2423.6556880051276, Ep_Len=1000
# 	  Episod-5: Ep_Return=2383.8761325417154, Ep_Len=1000
# 	  Episod-6: Ep_Return=2334.5564976409537, Ep_Len=1000
# 	  Episod-7: Ep_Return=2397.7603162826354, Ep_Len=1000
# 	  Episod-8: Ep_Return=2444.554305925311, Ep_Len=1000
# 	  Episod-9: Ep_Return=2464.4977953979496, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2351.6808714373087, Ep_Len=1000
# 	  Episod-1: Ep_Return=2251.9662623529234, Ep_Len=1000
# 	  Episod-2: Ep_Return=2284.578923454847, Ep_Len=1000
# 	  Episod-3: Ep_Return=2438.302476901644, Ep_Len=1000
# 	  Episod-4: Ep_Return=2300.772618662219, Ep_Len=1000
# 	  Episod-5: Ep_Return=2344.3508200305187, Ep_Len=1000
# 	  Episod-6: Ep_Return=2355.6182564803144, Ep_Len=1000
# 	  Episod-7: Ep_Return=2302.9125662426654, Ep_Len=1000
# 	  Episod-8: Ep_Return=2384.2379849924573, Ep_Len=1000
# 	  Episod-9: Ep_Return=2401.8941109486627, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '0', '5']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_0_5_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2468.957948796593, Ep_Len=1000
# 	  Episod-1: Ep_Return=2457.2956039070687, Ep_Len=1000
# 	  Episod-2: Ep_Return=2466.196430217275, Ep_Len=1000
# 	  Episod-3: Ep_Return=2483.3567160314847, Ep_Len=1000
# 	  Episod-4: Ep_Return=2468.923068048721, Ep_Len=1000
# 	  Episod-5: Ep_Return=2472.1509786291645, Ep_Len=1000
# 	  Episod-6: Ep_Return=2463.9909138100165, Ep_Len=1000
# 	  Episod-7: Ep_Return=2468.137545662411, Ep_Len=1000
# 	  Episod-8: Ep_Return=2488.6339516160488, Ep_Len=1000
# 	  Episod-9: Ep_Return=2480.337517485557, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1970.946954766413, Ep_Len=1000
# 	  Episod-1: Ep_Return=2127.454284825027, Ep_Len=1000
# 	  Episod-2: Ep_Return=2173.150978289677, Ep_Len=1000
# 	  Episod-3: Ep_Return=2006.9899503501674, Ep_Len=1000
# 	  Episod-4: Ep_Return=1988.8149646593902, Ep_Len=1000
# 	  Episod-5: Ep_Return=2028.0742413144337, Ep_Len=1000
# 	  Episod-6: Ep_Return=2144.375466823039, Ep_Len=1000
# 	  Episod-7: Ep_Return=2142.7841409920184, Ep_Len=1000
# 	  Episod-8: Ep_Return=2099.91576477265, Ep_Len=1000
# 	  Episod-9: Ep_Return=2092.192543248804, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2123.9302017355462, Ep_Len=1000
# 	  Episod-1: Ep_Return=2171.7967924498503, Ep_Len=1000
# 	  Episod-2: Ep_Return=2099.5358979384396, Ep_Len=1000
# 	  Episod-3: Ep_Return=2206.78122686453, Ep_Len=1000
# 	  Episod-4: Ep_Return=1963.8625584960064, Ep_Len=1000
# 	  Episod-5: Ep_Return=2203.186840019895, Ep_Len=1000
# 	  Episod-6: Ep_Return=2145.113144152291, Ep_Len=1000
# 	  Episod-7: Ep_Return=2170.4655864938904, Ep_Len=1000
# 	  Episod-8: Ep_Return=2217.9519977814984, Ep_Len=1000
# 	  Episod-9: Ep_Return=2119.762313548243, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2189.853692990411, Ep_Len=1000
# 	  Episod-1: Ep_Return=2115.614666217706, Ep_Len=1000
# 	  Episod-2: Ep_Return=2116.5481372220133, Ep_Len=1000
# 	  Episod-3: Ep_Return=2119.9008051871983, Ep_Len=1000
# 	  Episod-4: Ep_Return=2103.953989297434, Ep_Len=1000
# 	  Episod-5: Ep_Return=2097.7502044526664, Ep_Len=1000
# 	  Episod-6: Ep_Return=1927.268687564293, Ep_Len=1000
# 	  Episod-7: Ep_Return=2060.7867448671927, Ep_Len=1000
# 	  Episod-8: Ep_Return=2081.9994888621677, Ep_Len=1000
# 	  Episod-9: Ep_Return=2007.4448613650734, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '1', '0']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_1_0_s1
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2740.981025256198, Ep_Len=1000
# 	  Episod-1: Ep_Return=2733.1545057683875, Ep_Len=1000
# 	  Episod-2: Ep_Return=2716.9925227020804, Ep_Len=1000
# 	  Episod-3: Ep_Return=2731.842342112986, Ep_Len=1000
# 	  Episod-4: Ep_Return=2723.9876105415096, Ep_Len=1000
# 	  Episod-5: Ep_Return=2716.6799062925893, Ep_Len=1000
# 	  Episod-6: Ep_Return=2727.3207166470015, Ep_Len=1000
# 	  Episod-7: Ep_Return=2748.43164794844, Ep_Len=1000
# 	  Episod-8: Ep_Return=2716.5139408977248, Ep_Len=1000
# 	  Episod-9: Ep_Return=2747.4423983045162, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1787.0841246503214, Ep_Len=1000
# 	  Episod-1: Ep_Return=1784.1661340169744, Ep_Len=1000
# 	  Episod-2: Ep_Return=2068.3136099521016, Ep_Len=1000
# 	  Episod-3: Ep_Return=1920.3266575464465, Ep_Len=1000
# 	  Episod-4: Ep_Return=1891.6573582528106, Ep_Len=1000
# 	  Episod-5: Ep_Return=2020.1136340876872, Ep_Len=1000
# 	  Episod-6: Ep_Return=1780.6261432673348, Ep_Len=1000
# 	  Episod-7: Ep_Return=1608.3367327894077, Ep_Len=1000
# 	  Episod-8: Ep_Return=1782.915178498455, Ep_Len=1000
# 	  Episod-9: Ep_Return=1736.583303789202, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1778.4507373407855, Ep_Len=1000
# 	  Episod-1: Ep_Return=1840.8297228986005, Ep_Len=1000
# 	  Episod-2: Ep_Return=1887.8126707674503, Ep_Len=1000
# 	  Episod-3: Ep_Return=1756.0433109774842, Ep_Len=1000
# 	  Episod-4: Ep_Return=1797.7356615728186, Ep_Len=1000
# 	  Episod-5: Ep_Return=1883.736966880991, Ep_Len=1000
# 	  Episod-6: Ep_Return=1795.0798367713833, Ep_Len=1000
# 	  Episod-7: Ep_Return=1829.2018308914014, Ep_Len=1000
# 	  Episod-8: Ep_Return=1915.0380465884894, Ep_Len=1000
# 	  Episod-9: Ep_Return=1793.2468515894254, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1702.8890815839818, Ep_Len=1000
# 	  Episod-1: Ep_Return=1843.2095949208535, Ep_Len=1000
# 	  Episod-2: Ep_Return=1758.0041984969603, Ep_Len=1000
# 	  Episod-3: Ep_Return=1895.283170705881, Ep_Len=1000
# 	  Episod-4: Ep_Return=1807.7443604496243, Ep_Len=1000
# 	  Episod-5: Ep_Return=1893.3890281769466, Ep_Len=1000
# 	  Episod-6: Ep_Return=1805.314664534634, Ep_Len=1000
# 	  Episod-7: Ep_Return=1860.8032689475235, Ep_Len=1000
# 	  Episod-8: Ep_Return=1828.1651679883055, Ep_Len=1000
# 	  Episod-9: Ep_Return=1832.7697557679526, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '1', '1']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_1_1_s1
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2680.545415964357, Ep_Len=1000
# 	  Episod-1: Ep_Return=2635.15770943094, Ep_Len=1000
# 	  Episod-2: Ep_Return=2692.401398116906, Ep_Len=1000
# 	  Episod-3: Ep_Return=2678.565442320468, Ep_Len=1000
# 	  Episod-4: Ep_Return=2688.1910457048334, Ep_Len=1000
# 	  Episod-5: Ep_Return=2690.0963551374084, Ep_Len=1000
# 	  Episod-6: Ep_Return=2643.129071084027, Ep_Len=1000
# 	  Episod-7: Ep_Return=2674.1633989294096, Ep_Len=1000
# 	  Episod-8: Ep_Return=2670.601592081395, Ep_Len=1000
# 	  Episod-9: Ep_Return=2648.0804117899374, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1750.0681602460622, Ep_Len=1000
# 	  Episod-1: Ep_Return=1723.6663802428848, Ep_Len=1000
# 	  Episod-2: Ep_Return=1443.5905069390285, Ep_Len=1000
# 	  Episod-3: Ep_Return=1799.9834737825008, Ep_Len=1000
# 	  Episod-4: Ep_Return=2028.8732134992892, Ep_Len=1000
# 	  Episod-5: Ep_Return=1843.634073703532, Ep_Len=1000
# 	  Episod-6: Ep_Return=1888.8517180248177, Ep_Len=1000
# 	  Episod-7: Ep_Return=1655.007629690943, Ep_Len=1000
# 	  Episod-8: Ep_Return=1862.9815497926975, Ep_Len=1000
# 	  Episod-9: Ep_Return=1622.997597128924, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2260.9296531001805, Ep_Len=1000
# 	  Episod-1: Ep_Return=2272.8867307095725, Ep_Len=1000
# 	  Episod-2: Ep_Return=2147.2259511158154, Ep_Len=1000
# 	  Episod-3: Ep_Return=2171.889866238593, Ep_Len=1000
# 	  Episod-4: Ep_Return=2244.646633639961, Ep_Len=1000
# 	  Episod-5: Ep_Return=2300.9406879826756, Ep_Len=1000
# 	  Episod-6: Ep_Return=2295.775004709909, Ep_Len=1000
# 	  Episod-7: Ep_Return=2214.679014200906, Ep_Len=1000
# 	  Episod-8: Ep_Return=2249.536121466336, Ep_Len=1000
# 	  Episod-9: Ep_Return=2232.5693769512086, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1855.6351696729096, Ep_Len=1000
# 	  Episod-1: Ep_Return=2053.007846989832, Ep_Len=1000
# 	  Episod-2: Ep_Return=2169.9253009009, Ep_Len=1000
# 	  Episod-3: Ep_Return=1912.5676584486757, Ep_Len=1000
# 	  Episod-4: Ep_Return=2097.9538263827258, Ep_Len=1000
# 	  Episod-5: Ep_Return=2028.6717640953987, Ep_Len=1000
# 	  Episod-6: Ep_Return=1895.700141568159, Ep_Len=1000
# 	  Episod-7: Ep_Return=2048.5187569295617, Ep_Len=1000
# 	  Episod-8: Ep_Return=1971.0213577803881, Ep_Len=1000
# 	  Episod-9: Ep_Return=2032.5091979224856, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '1', '3']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_1_3_s1
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2826.5768960980363, Ep_Len=1000
# 	  Episod-1: Ep_Return=2806.4468600013065, Ep_Len=1000
# 	  Episod-2: Ep_Return=2845.490637177695, Ep_Len=1000
# 	  Episod-3: Ep_Return=2822.1815162398693, Ep_Len=1000
# 	  Episod-4: Ep_Return=2824.4145147493696, Ep_Len=1000
# 	  Episod-5: Ep_Return=2816.3907875884465, Ep_Len=1000
# 	  Episod-6: Ep_Return=2797.6623348035787, Ep_Len=1000
# 	  Episod-7: Ep_Return=2824.214324160134, Ep_Len=1000
# 	  Episod-8: Ep_Return=2822.6797470579445, Ep_Len=1000
# 	  Episod-9: Ep_Return=2813.316740344107, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2245.41436237369, Ep_Len=1000
# 	  Episod-1: Ep_Return=2147.215737920843, Ep_Len=1000
# 	  Episod-2: Ep_Return=1977.4690133935921, Ep_Len=1000
# 	  Episod-3: Ep_Return=2279.2326018020262, Ep_Len=1000
# 	  Episod-4: Ep_Return=2206.7943103905086, Ep_Len=1000
# 	  Episod-5: Ep_Return=1986.3373952550655, Ep_Len=1000
# 	  Episod-6: Ep_Return=2188.404296144641, Ep_Len=1000
# 	  Episod-7: Ep_Return=2259.6998575368953, Ep_Len=1000
# 	  Episod-8: Ep_Return=2193.3809007197683, Ep_Len=1000
# 	  Episod-9: Ep_Return=2228.278569111396, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2334.9144893687057, Ep_Len=1000
# 	  Episod-1: Ep_Return=2274.3438024548004, Ep_Len=1000
# 	  Episod-2: Ep_Return=2346.8512393830656, Ep_Len=1000
# 	  Episod-3: Ep_Return=2389.8311231951816, Ep_Len=1000
# 	  Episod-4: Ep_Return=2352.0405202516313, Ep_Len=1000
# 	  Episod-5: Ep_Return=2060.27582548992, Ep_Len=1000
# 	  Episod-6: Ep_Return=2385.556344658493, Ep_Len=1000
# 	  Episod-7: Ep_Return=2392.8151088504433, Ep_Len=1000
# 	  Episod-8: Ep_Return=2357.7554077822974, Ep_Len=1000
# 	  Episod-9: Ep_Return=2342.565604498215, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2128.5652197963723, Ep_Len=1000
# 	  Episod-1: Ep_Return=2244.4040066482044, Ep_Len=1000
# 	  Episod-2: Ep_Return=2195.9512022843605, Ep_Len=1000
# 	  Episod-3: Ep_Return=2262.514053649519, Ep_Len=1000
# 	  Episod-4: Ep_Return=2195.1522913172157, Ep_Len=1000
# 	  Episod-5: Ep_Return=2268.3179192328585, Ep_Len=1000
# 	  Episod-6: Ep_Return=2117.4463298748406, Ep_Len=1000
# 	  Episod-7: Ep_Return=2207.9341659496613, Ep_Len=1000
# 	  Episod-8: Ep_Return=2201.95775205215, Ep_Len=1000
# 	  Episod-9: Ep_Return=2248.9006758222517, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '1', '5']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_1_5_s1
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2651.863955268984, Ep_Len=1000
# 	  Episod-1: Ep_Return=2598.3894104040564, Ep_Len=1000
# 	  Episod-2: Ep_Return=2585.8478226742536, Ep_Len=1000
# 	  Episod-3: Ep_Return=2652.1921076511494, Ep_Len=1000
# 	  Episod-4: Ep_Return=2628.6457648828164, Ep_Len=1000
# 	  Episod-5: Ep_Return=2603.01414471505, Ep_Len=1000
# 	  Episod-6: Ep_Return=2626.6406484479858, Ep_Len=1000
# 	  Episod-7: Ep_Return=2630.962537827308, Ep_Len=1000
# 	  Episod-8: Ep_Return=2704.9821163805113, Ep_Len=1000
# 	  Episod-9: Ep_Return=2588.23285033348, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2437.6018172386553, Ep_Len=1000
# 	  Episod-1: Ep_Return=2286.567489439728, Ep_Len=1000
# 	  Episod-2: Ep_Return=2355.622675536239, Ep_Len=1000
# 	  Episod-3: Ep_Return=2322.7077965438293, Ep_Len=1000
# 	  Episod-4: Ep_Return=2406.342991939916, Ep_Len=1000
# 	  Episod-5: Ep_Return=2381.2147362131514, Ep_Len=1000
# 	  Episod-6: Ep_Return=2365.902132364429, Ep_Len=1000
# 	  Episod-7: Ep_Return=2399.364909526742, Ep_Len=1000
# 	  Episod-8: Ep_Return=2292.47383535208, Ep_Len=1000
# 	  Episod-9: Ep_Return=2341.6797945296253, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2374.934523944561, Ep_Len=1000
# 	  Episod-1: Ep_Return=2384.3459171503832, Ep_Len=1000
# 	  Episod-2: Ep_Return=2330.3745527347055, Ep_Len=1000
# 	  Episod-3: Ep_Return=2397.0723627506673, Ep_Len=1000
# 	  Episod-4: Ep_Return=2346.0758680280696, Ep_Len=1000
# 	  Episod-5: Ep_Return=2353.158509275495, Ep_Len=1000
# 	  Episod-6: Ep_Return=2361.228542850187, Ep_Len=1000
# 	  Episod-7: Ep_Return=2349.8735954264025, Ep_Len=1000
# 	  Episod-8: Ep_Return=2372.1763581920195, Ep_Len=1000
# 	  Episod-9: Ep_Return=2336.1343941002815, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2242.84389944504, Ep_Len=1000
# 	  Episod-1: Ep_Return=2290.2627760483856, Ep_Len=1000
# 	  Episod-2: Ep_Return=2184.812224983603, Ep_Len=1000
# 	  Episod-3: Ep_Return=2254.8211507518467, Ep_Len=1000
# 	  Episod-4: Ep_Return=2233.811012468479, Ep_Len=1000
# 	  Episod-5: Ep_Return=2186.926547202246, Ep_Len=1000
# 	  Episod-6: Ep_Return=2252.5968957596892, Ep_Len=1000
# 	  Episod-7: Ep_Return=2192.8091765345544, Ep_Len=1000
# 	  Episod-8: Ep_Return=2232.238844458673, Ep_Len=1000
# 	  Episod-9: Ep_Return=2157.299599225309, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '2', '0']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_2_0_s2
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2319.699884707825, Ep_Len=1000
# 	  Episod-1: Ep_Return=2343.6481296609873, Ep_Len=1000
# 	  Episod-2: Ep_Return=2295.62797323712, Ep_Len=1000
# 	  Episod-3: Ep_Return=2315.701834249985, Ep_Len=1000
# 	  Episod-4: Ep_Return=2337.067720294555, Ep_Len=1000
# 	  Episod-5: Ep_Return=2280.3197624849913, Ep_Len=1000
# 	  Episod-6: Ep_Return=2263.683931306385, Ep_Len=1000
# 	  Episod-7: Ep_Return=2333.0267915245468, Ep_Len=1000
# 	  Episod-8: Ep_Return=2346.9632209815113, Ep_Len=1000
# 	  Episod-9: Ep_Return=2344.116134969792, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1445.0094871308668, Ep_Len=1000
# 	  Episod-1: Ep_Return=1622.2320779195034, Ep_Len=1000
# 	  Episod-2: Ep_Return=1654.1337097460682, Ep_Len=1000
# 	  Episod-3: Ep_Return=1692.4496450772958, Ep_Len=1000
# 	  Episod-4: Ep_Return=1518.5991362253344, Ep_Len=1000
# 	  Episod-5: Ep_Return=1537.4710097848088, Ep_Len=1000
# 	  Episod-6: Ep_Return=1578.2464178937505, Ep_Len=1000
# 	  Episod-7: Ep_Return=1440.8879942419971, Ep_Len=1000
# 	  Episod-8: Ep_Return=1724.0952367400619, Ep_Len=1000
# 	  Episod-9: Ep_Return=1456.3114426955676, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2213.0087372703797, Ep_Len=1000
# 	  Episod-1: Ep_Return=2131.71595484258, Ep_Len=1000
# 	  Episod-2: Ep_Return=2190.5211285142877, Ep_Len=1000
# 	  Episod-3: Ep_Return=2209.1642690345107, Ep_Len=1000
# 	  Episod-4: Ep_Return=2097.026725882136, Ep_Len=1000
# 	  Episod-5: Ep_Return=2196.7483381445923, Ep_Len=1000
# 	  Episod-6: Ep_Return=2224.082174216066, Ep_Len=1000
# 	  Episod-7: Ep_Return=2135.064896697239, Ep_Len=1000
# 	  Episod-8: Ep_Return=2169.4290462568456, Ep_Len=1000
# 	  Episod-9: Ep_Return=2179.5926152039515, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2092.9511948220193, Ep_Len=1000
# 	  Episod-1: Ep_Return=2169.641635209283, Ep_Len=1000
# 	  Episod-2: Ep_Return=2079.443972833179, Ep_Len=1000
# 	  Episod-3: Ep_Return=1926.2146188901938, Ep_Len=1000
# 	  Episod-4: Ep_Return=2123.206245509716, Ep_Len=1000
# 	  Episod-5: Ep_Return=2119.8918978984193, Ep_Len=1000
# 	  Episod-6: Ep_Return=2079.6807918852314, Ep_Len=1000
# 	  Episod-7: Ep_Return=1934.2094132756426, Ep_Len=1000
# 	  Episod-8: Ep_Return=2176.0941443532142, Ep_Len=1000
# 	  Episod-9: Ep_Return=2088.5558679993214, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '2', '3']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_2_3_s2
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2741.198908866079, Ep_Len=1000
# 	  Episod-1: Ep_Return=2791.443834225326, Ep_Len=1000
# 	  Episod-2: Ep_Return=2785.4850094370663, Ep_Len=1000
# 	  Episod-3: Ep_Return=2770.2602963200325, Ep_Len=1000
# 	  Episod-4: Ep_Return=2778.174102865225, Ep_Len=1000
# 	  Episod-5: Ep_Return=2782.7540148520034, Ep_Len=1000
# 	  Episod-6: Ep_Return=2750.499523079207, Ep_Len=1000
# 	  Episod-7: Ep_Return=2780.4656337040706, Ep_Len=1000
# 	  Episod-8: Ep_Return=2778.6228488510537, Ep_Len=1000
# 	  Episod-9: Ep_Return=2754.0779859024733, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2480.375499000817, Ep_Len=1000
# 	  Episod-1: Ep_Return=2497.2087753398814, Ep_Len=1000
# 	  Episod-2: Ep_Return=2444.16060805397, Ep_Len=1000
# 	  Episod-3: Ep_Return=2389.7384824453206, Ep_Len=1000
# 	  Episod-4: Ep_Return=2366.2717274385936, Ep_Len=1000
# 	  Episod-5: Ep_Return=2527.34777341266, Ep_Len=1000
# 	  Episod-6: Ep_Return=2475.6576493456837, Ep_Len=1000
# 	  Episod-7: Ep_Return=2382.775164915121, Ep_Len=1000
# 	  Episod-8: Ep_Return=2412.3649204695985, Ep_Len=1000
# 	  Episod-9: Ep_Return=2464.551566047665, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2273.4959098339064, Ep_Len=1000
# 	  Episod-1: Ep_Return=2306.502039010138, Ep_Len=1000
# 	  Episod-2: Ep_Return=2316.354417388145, Ep_Len=1000
# 	  Episod-3: Ep_Return=2246.668541306761, Ep_Len=1000
# 	  Episod-4: Ep_Return=2250.9133565057227, Ep_Len=1000
# 	  Episod-5: Ep_Return=2324.5412224344336, Ep_Len=1000
# 	  Episod-6: Ep_Return=2304.3575274499094, Ep_Len=1000
# 	  Episod-7: Ep_Return=2337.957523845461, Ep_Len=1000
# 	  Episod-8: Ep_Return=2307.6095757525304, Ep_Len=1000
# 	  Episod-9: Ep_Return=2314.3345664343774, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2221.00976640765, Ep_Len=1000
# 	  Episod-1: Ep_Return=2228.109233306916, Ep_Len=1000
# 	  Episod-2: Ep_Return=2207.7515925177554, Ep_Len=1000
# 	  Episod-3: Ep_Return=2134.9511975605105, Ep_Len=1000
# 	  Episod-4: Ep_Return=2173.254201319553, Ep_Len=1000
# 	  Episod-5: Ep_Return=2186.165391700807, Ep_Len=1000
# 	  Episod-6: Ep_Return=2267.0879249642503, Ep_Len=1000
# 	  Episod-7: Ep_Return=2144.997450167018, Ep_Len=1000
# 	  Episod-8: Ep_Return=2175.5358088169837, Ep_Len=1000
# 	  Episod-9: Ep_Return=2212.8542582351934, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '2', '5']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_2_5_s2
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2594.2121165701296, Ep_Len=1000
# 	  Episod-1: Ep_Return=2600.1997207907225, Ep_Len=1000
# 	  Episod-2: Ep_Return=2606.9689426284344, Ep_Len=1000
# 	  Episod-3: Ep_Return=2565.3175309626313, Ep_Len=1000
# 	  Episod-4: Ep_Return=2600.942159558289, Ep_Len=1000
# 	  Episod-5: Ep_Return=2542.206133048102, Ep_Len=1000
# 	  Episod-6: Ep_Return=2582.8958610704135, Ep_Len=1000
# 	  Episod-7: Ep_Return=2608.2029639529997, Ep_Len=1000
# 	  Episod-8: Ep_Return=2607.7213358121935, Ep_Len=1000
# 	  Episod-9: Ep_Return=2587.62460991687, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2122.135455597279, Ep_Len=1000
# 	  Episod-1: Ep_Return=2092.53721635894, Ep_Len=1000
# 	  Episod-2: Ep_Return=1893.4768731997015, Ep_Len=1000
# 	  Episod-3: Ep_Return=1988.3151084175838, Ep_Len=1000
# 	  Episod-4: Ep_Return=2065.187475697414, Ep_Len=1000
# 	  Episod-5: Ep_Return=2087.6990023439375, Ep_Len=1000
# 	  Episod-6: Ep_Return=1964.0163187910591, Ep_Len=1000
# 	  Episod-7: Ep_Return=2138.1010614037614, Ep_Len=1000
# 	  Episod-8: Ep_Return=2171.3647166140745, Ep_Len=1000
# 	  Episod-9: Ep_Return=2041.7297551721554, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2169.337036561454, Ep_Len=1000
# 	  Episod-1: Ep_Return=2232.0604653866762, Ep_Len=1000
# 	  Episod-2: Ep_Return=2287.417571199844, Ep_Len=1000
# 	  Episod-3: Ep_Return=2231.296402468261, Ep_Len=1000
# 	  Episod-4: Ep_Return=2217.2756542427583, Ep_Len=1000
# 	  Episod-5: Ep_Return=2167.7063292114703, Ep_Len=1000
# 	  Episod-6: Ep_Return=2201.5868222096137, Ep_Len=1000
# 	  Episod-7: Ep_Return=2260.5582838122227, Ep_Len=1000
# 	  Episod-8: Ep_Return=2217.252423579558, Ep_Len=1000
# 	  Episod-9: Ep_Return=2199.5980480967423, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2061.2899659936975, Ep_Len=1000
# 	  Episod-1: Ep_Return=2107.1417294198845, Ep_Len=1000
# 	  Episod-2: Ep_Return=2101.8434288696576, Ep_Len=1000
# 	  Episod-3: Ep_Return=2042.340441254032, Ep_Len=1000
# 	  Episod-4: Ep_Return=2126.8349026193946, Ep_Len=1000
# 	  Episod-5: Ep_Return=2017.0635941746448, Ep_Len=1000
# 	  Episod-6: Ep_Return=2132.1631622767054, Ep_Len=1000
# 	  Episod-7: Ep_Return=2079.574939107354, Ep_Len=1000
# 	  Episod-8: Ep_Return=2127.6014660798164, Ep_Len=1000
# 	  Episod-9: Ep_Return=2103.821763653359, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '3', '0']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_3_0_s3
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2250.6738393445567, Ep_Len=1000
# 	  Episod-1: Ep_Return=2315.477087158846, Ep_Len=1000
# 	  Episod-2: Ep_Return=2271.0805680744834, Ep_Len=1000
# 	  Episod-3: Ep_Return=2236.6407893603227, Ep_Len=1000
# 	  Episod-4: Ep_Return=2275.924541437972, Ep_Len=1000
# 	  Episod-5: Ep_Return=2184.0876168845875, Ep_Len=1000
# 	  Episod-6: Ep_Return=2202.123242213937, Ep_Len=1000
# 	  Episod-7: Ep_Return=2299.4173742309176, Ep_Len=1000
# 	  Episod-8: Ep_Return=2291.7246204543944, Ep_Len=1000
# 	  Episod-9: Ep_Return=2289.138328776963, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1191.2719840832965, Ep_Len=1000
# 	  Episod-1: Ep_Return=1027.5329961915932, Ep_Len=1000
# 	  Episod-2: Ep_Return=1254.5047715668354, Ep_Len=1000
# 	  Episod-3: Ep_Return=585.5777411767668, Ep_Len=1000
# 	  Episod-4: Ep_Return=975.5608965497272, Ep_Len=1000
# 	  Episod-5: Ep_Return=1103.805214248345, Ep_Len=1000
# 	  Episod-6: Ep_Return=1072.460845300116, Ep_Len=1000
# 	  Episod-7: Ep_Return=1097.0575320752935, Ep_Len=1000
# 	  Episod-8: Ep_Return=681.3326028765644, Ep_Len=1000
# 	  Episod-9: Ep_Return=1158.9993972491818, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1774.211333208495, Ep_Len=1000
# 	  Episod-1: Ep_Return=1622.1710780959104, Ep_Len=1000
# 	  Episod-2: Ep_Return=1557.1879344194806, Ep_Len=1000
# 	  Episod-3: Ep_Return=1816.937626935628, Ep_Len=1000
# 	  Episod-4: Ep_Return=1809.7228353291002, Ep_Len=1000
# 	  Episod-5: Ep_Return=1661.1104493319745, Ep_Len=1000
# 	  Episod-6: Ep_Return=1773.7061949174413, Ep_Len=1000
# 	  Episod-7: Ep_Return=1635.697624475642, Ep_Len=1000
# 	  Episod-8: Ep_Return=1748.3020882782291, Ep_Len=1000
# 	  Episod-9: Ep_Return=1771.255778261052, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1266.0534251540673, Ep_Len=1000
# 	  Episod-1: Ep_Return=763.9526608252573, Ep_Len=1000
# 	  Episod-2: Ep_Return=966.0922265937492, Ep_Len=1000
# 	  Episod-3: Ep_Return=778.7348573414478, Ep_Len=1000
# 	  Episod-4: Ep_Return=626.1284335512105, Ep_Len=1000
# 	  Episod-5: Ep_Return=1088.6508065651283, Ep_Len=1000
# 	  Episod-6: Ep_Return=1087.7070185803134, Ep_Len=1000
# 	  Episod-7: Ep_Return=698.5288068954833, Ep_Len=1000
# 	  Episod-8: Ep_Return=1005.5764194188929, Ep_Len=1000
# 	  Episod-9: Ep_Return=1259.9117903284275, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '3', '1']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_3_1_s3
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2701.3045097683653, Ep_Len=1000
# 	  Episod-1: Ep_Return=2684.673386940246, Ep_Len=1000
# 	  Episod-2: Ep_Return=2714.231999713802, Ep_Len=1000
# 	  Episod-3: Ep_Return=2721.134205130776, Ep_Len=1000
# 	  Episod-4: Ep_Return=2736.807004216679, Ep_Len=1000
# 	  Episod-5: Ep_Return=2659.8302097394176, Ep_Len=1000
# 	  Episod-6: Ep_Return=2726.1113553134132, Ep_Len=1000
# 	  Episod-7: Ep_Return=2727.75751962177, Ep_Len=1000
# 	  Episod-8: Ep_Return=2691.7800139624674, Ep_Len=1000
# 	  Episod-9: Ep_Return=2740.277094342513, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2332.804691485018, Ep_Len=1000
# 	  Episod-1: Ep_Return=2394.649036624209, Ep_Len=1000
# 	  Episod-2: Ep_Return=2427.21654646178, Ep_Len=1000
# 	  Episod-3: Ep_Return=2340.244248138781, Ep_Len=1000
# 	  Episod-4: Ep_Return=2378.2637334510055, Ep_Len=1000
# 	  Episod-5: Ep_Return=2502.440594853371, Ep_Len=1000
# 	  Episod-6: Ep_Return=2291.5771748671364, Ep_Len=1000
# 	  Episod-7: Ep_Return=2523.428403120296, Ep_Len=1000
# 	  Episod-8: Ep_Return=2310.954123151594, Ep_Len=1000
# 	  Episod-9: Ep_Return=2393.7585110074388, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2224.0388647808986, Ep_Len=1000
# 	  Episod-1: Ep_Return=2131.1786477862343, Ep_Len=1000
# 	  Episod-2: Ep_Return=2206.9131918568137, Ep_Len=1000
# 	  Episod-3: Ep_Return=2208.137318730836, Ep_Len=1000
# 	  Episod-4: Ep_Return=2198.214439854487, Ep_Len=1000
# 	  Episod-5: Ep_Return=2205.139581747507, Ep_Len=1000
# 	  Episod-6: Ep_Return=2199.6074921416116, Ep_Len=1000
# 	  Episod-7: Ep_Return=2157.857885185129, Ep_Len=1000
# 	  Episod-8: Ep_Return=2234.4547502693267, Ep_Len=1000
# 	  Episod-9: Ep_Return=2221.2505412879846, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2180.5522562012516, Ep_Len=1000
# 	  Episod-1: Ep_Return=2177.557787359255, Ep_Len=1000
# 	  Episod-2: Ep_Return=2164.930304785738, Ep_Len=1000
# 	  Episod-3: Ep_Return=2129.595951734315, Ep_Len=1000
# 	  Episod-4: Ep_Return=2208.715379514118, Ep_Len=1000
# 	  Episod-5: Ep_Return=2114.5675023346926, Ep_Len=1000
# 	  Episod-6: Ep_Return=2232.409874589122, Ep_Len=1000
# 	  Episod-7: Ep_Return=2276.1573601698115, Ep_Len=1000
# 	  Episod-8: Ep_Return=2223.896153967655, Ep_Len=1000
# 	  Episod-9: Ep_Return=2253.339945446119, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '3', '3']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_3_3_s3
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2999.5384624369126, Ep_Len=1000
# 	  Episod-1: Ep_Return=3046.7594895050947, Ep_Len=1000
# 	  Episod-2: Ep_Return=3031.8643361719073, Ep_Len=1000
# 	  Episod-3: Ep_Return=3069.3236877252893, Ep_Len=1000
# 	  Episod-4: Ep_Return=3033.5455310163616, Ep_Len=1000
# 	  Episod-5: Ep_Return=3039.4526140416056, Ep_Len=1000
# 	  Episod-6: Ep_Return=3073.5670125648458, Ep_Len=1000
# 	  Episod-7: Ep_Return=3047.1800661222264, Ep_Len=1000
# 	  Episod-8: Ep_Return=3004.309415818323, Ep_Len=1000
# 	  Episod-9: Ep_Return=3013.4987808998626, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2701.609412365345, Ep_Len=1000
# 	  Episod-1: Ep_Return=2739.193859381723, Ep_Len=1000
# 	  Episod-2: Ep_Return=2718.5951406559852, Ep_Len=1000
# 	  Episod-3: Ep_Return=2775.43692291091, Ep_Len=1000
# 	  Episod-4: Ep_Return=2783.88367816306, Ep_Len=1000
# 	  Episod-5: Ep_Return=2844.042146931702, Ep_Len=1000
# 	  Episod-6: Ep_Return=2678.0967944035688, Ep_Len=1000
# 	  Episod-7: Ep_Return=2758.27799068578, Ep_Len=1000
# 	  Episod-8: Ep_Return=2724.150917587649, Ep_Len=1000
# 	  Episod-9: Ep_Return=2717.265725077586, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2481.818920415896, Ep_Len=1000
# 	  Episod-1: Ep_Return=2528.5832052571936, Ep_Len=1000
# 	  Episod-2: Ep_Return=2551.3553067323055, Ep_Len=1000
# 	  Episod-3: Ep_Return=2487.4044301047575, Ep_Len=1000
# 	  Episod-4: Ep_Return=2456.5204570838146, Ep_Len=1000
# 	  Episod-5: Ep_Return=2431.419730066584, Ep_Len=1000
# 	  Episod-6: Ep_Return=2447.542356011535, Ep_Len=1000
# 	  Episod-7: Ep_Return=2432.427448653026, Ep_Len=1000
# 	  Episod-8: Ep_Return=2416.014342881575, Ep_Len=1000
# 	  Episod-9: Ep_Return=2414.2116147507113, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2402.552587739214, Ep_Len=1000
# 	  Episod-1: Ep_Return=2476.0544511810117, Ep_Len=1000
# 	  Episod-2: Ep_Return=2302.5901832363634, Ep_Len=1000
# 	  Episod-3: Ep_Return=2458.0771371915116, Ep_Len=1000
# 	  Episod-4: Ep_Return=2348.138425759221, Ep_Len=1000
# 	  Episod-5: Ep_Return=2353.134016167858, Ep_Len=1000
# 	  Episod-6: Ep_Return=2345.5694198018405, Ep_Len=1000
# 	  Episod-7: Ep_Return=2423.7594167064426, Ep_Len=1000
# 	  Episod-8: Ep_Return=2401.136351197816, Ep_Len=1000
# 	  Episod-9: Ep_Return=2433.1770336232953, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '3', '5']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_3_5_s3
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2595.736682434868, Ep_Len=1000
# 	  Episod-1: Ep_Return=2546.271610253168, Ep_Len=1000
# 	  Episod-2: Ep_Return=2569.2010430488, Ep_Len=1000
# 	  Episod-3: Ep_Return=2574.108775891268, Ep_Len=1000
# 	  Episod-4: Ep_Return=2630.373207572375, Ep_Len=1000
# 	  Episod-5: Ep_Return=2596.1310540358027, Ep_Len=1000
# 	  Episod-6: Ep_Return=2594.647264260589, Ep_Len=1000
# 	  Episod-7: Ep_Return=2593.7360251820905, Ep_Len=1000
# 	  Episod-8: Ep_Return=2614.2930538092933, Ep_Len=1000
# 	  Episod-9: Ep_Return=2527.321045705773, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2236.77660544725, Ep_Len=1000
# 	  Episod-1: Ep_Return=2195.2446924516075, Ep_Len=1000
# 	  Episod-2: Ep_Return=2277.9897001413597, Ep_Len=1000
# 	  Episod-3: Ep_Return=2267.8980042166127, Ep_Len=1000
# 	  Episod-4: Ep_Return=2206.4645525995543, Ep_Len=1000
# 	  Episod-5: Ep_Return=2234.841205624003, Ep_Len=1000
# 	  Episod-6: Ep_Return=2236.0460737242925, Ep_Len=1000
# 	  Episod-7: Ep_Return=2211.3095694508916, Ep_Len=1000
# 	  Episod-8: Ep_Return=2095.3552786563746, Ep_Len=1000
# 	  Episod-9: Ep_Return=2170.7322973749274, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2378.3106173329606, Ep_Len=1000
# 	  Episod-1: Ep_Return=2386.429042021869, Ep_Len=1000
# 	  Episod-2: Ep_Return=2372.663257528571, Ep_Len=1000
# 	  Episod-3: Ep_Return=2351.0605834550543, Ep_Len=1000
# 	  Episod-4: Ep_Return=2341.2070760795978, Ep_Len=1000
# 	  Episod-5: Ep_Return=2336.0068692571203, Ep_Len=1000
# 	  Episod-6: Ep_Return=2351.59437069948, Ep_Len=1000
# 	  Episod-7: Ep_Return=2275.0844366764063, Ep_Len=1000
# 	  Episod-8: Ep_Return=2327.6680918485504, Ep_Len=1000
# 	  Episod-9: Ep_Return=2350.463891421217, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2184.3656163766805, Ep_Len=1000
# 	  Episod-1: Ep_Return=2299.311655113688, Ep_Len=1000
# 	  Episod-2: Ep_Return=2194.190838502166, Ep_Len=1000
# 	  Episod-3: Ep_Return=2279.148704910618, Ep_Len=1000
# 	  Episod-4: Ep_Return=2237.397475612911, Ep_Len=1000
# 	  Episod-5: Ep_Return=2192.484187679061, Ep_Len=1000
# 	  Episod-6: Ep_Return=2259.401105386477, Ep_Len=1000
# 	  Episod-7: Ep_Return=2253.809699659737, Ep_Len=1000
# 	  Episod-8: Ep_Return=2202.992987678245, Ep_Len=1000
# 	  Episod-9: Ep_Return=2276.901432451205, Ep_Len=1000
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '3', '5']

# %%
import joblib
fname = 'D:\POMDP_Data\evaluation_on_different_environment.pkl'
joblib.dump({'baselines_MDP_to_POMDP': MDP_to_POMDP, 'lstm_td3_MDP_to_POMDP': lstm_td3_MDP_to_POMDP, 
             'baselines_POMDP_to_MDP': baselines_POMDP_to_MDP, 'lstm_td3_POMDP_to_MDP': lstm_td3_POMDP_to_MDP}, fname)
# reload_collected_environment_change_data = joblib.load(fname)
# Out:
# ['D:\\POMDP_Data\\evaluation_on_different_environment.pkl']

# %%
 MDP_to_POMDP['DDPG']['AntPyBulletEnv-v0']
# Out:
# {'s0': {'flickering': [985.1365913998804,
#    1015.8794903411405,
#    1168.837856609786,
#    1088.9633587455075,
#    1148.4388762292074,
#    1135.5874946723873,
#    1093.665924989961,
#    1187.5025505474753,
#    966.1897788216802,
#    1163.1665615004558],
#   'random_noise': [1551.824226094635,
#    1540.141159288047,
#    1488.2448922552337,
#    1454.520435841358,
#    1449.6158731906671,
#    1564.3954838246718,
#    1447.2731785110348,
#    1487.2630684072512,
#    1528.7492988991028,
#    1579.736988779131],
#   'random_sensor_missing': [1305.0928583037232,
#    1299.2943534629012,
#    1472.5287735044585,
#    1415.5257635654611,
#    1331.8546637064064,
#    1324.3114493302257,
#    1378.4442505004674,
#    1339.907648820905,
#    1325.3463540949685,
#    1368.616479554668],
#   'MDP': []},
#  's1': {'flickering': [-0.5757455207451139,
#    -0.9814749030512759,
#    -0.9481107618616083,
#    -1.1343098724566518,
#    -0.5878882226985302,
#    -0.8854635172159764,
#    -0.6238178358340525,
#    -0.6970159942458856,
#    -0.9736246592976392,
#    -0.8335090853724982],
#   'random_noise': [-0.659523821317999,
#    -1.0436221499810934,
#    -1.010330472872011,
#    -0.6190416433353683,
#    -0.9235313617944492,
#    -0.7870947129049464,
#    -1.5067051416684996,
#    -0.6538336100551541,
#    -0.5961484059691438,
#    -0.5667027075396622],
#   'random_sensor_missing': [-0.8338039798225518,
#    -0.28725402618874885,
#    -0.6104130342107972,
#    -0.6803477239722278,
#    -0.740104045467161,
#    -0.6526191137585564,
#    -1.342328266710684,
#    -1.249257772043348,
#    -0.6552197257857197,
#    -0.5716281224871644],
#   'MDP': [-1.3060677377899998,
#    -1.2377534957442555,
#    -0.47620800445729494,
#    -0.7272220545724859,
#    -0.40303395750670523,
#    -0.9842766120549649,
#    -1.4559587651296175,
#    -1.3228489581335459,
#    -0.5446988049530779,
#    -0.14399918234121412]}}

# %%
color = {'TD3':'b', 'TD3-OW':'m', 'TD3-OW-AddPastAct':'c', 'SAC':'g', 'DDPG':'k',
         'LSTM-TD3_HistLen0': 'k', 'LSTM-TD3_HistLen1': 'c', 'LSTM-TD3_HistLen3': 'b', 'LSTM-TD3_HistLen5': 'r'}
algs = ['DDPG', 'TD3', 'SAC', 'TD3-OW', 'TD3-OW-AddPastAct']
bar_width = 0.125
fig, axes = plt.subplots(1)
# Baselines
for alg_i, alg in enumerate(algs):
    # Calculate mean
    pomdp_evaluation = []
    pomdp_evaluation_mean = []
    pomdp_evaluation_std = []
    for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
        s_run_evals = []
        for s_run in MDP_to_POMDP[alg]['AntPyBulletEnv-v0'].keys():
            s_run_evals += MDP_to_POMDP[alg]['AntPyBulletEnv-v0'][s_run][pomdp_type]
        pomdp_evaluation.append(s_run_evals)
        pomdp_evaluation_mean.append(np.mean(s_run_evals))
        pomdp_evaluation_std.append(np.std(s_run_evals))
    
    # Plot
    axes.bar(np.arange(0,4) + alg_i*bar_width - 2.5*bar_width, pomdp_evaluation_mean, yerr = pomdp_evaluation_std,
             width = bar_width, label='{}'.format(alg), color=color[alg], alpha=0.8, edgecolor='w')
# LSTM-TD3
lstm_td3_pomdp_evaluation = []
lstm_td3_pomdp_evaluation_mean = []
lstm_td3_pomdp_evaluation_std = []
for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
    s_run_evals = []
    for s_run in lstm_td3_MDP_to_POMDP['LSTM-TD3']['AntPyBulletEnv-v0']['5'].keys():
        s_run_evals += lstm_td3_MDP_to_POMDP['LSTM-TD3']['AntPyBulletEnv-v0']['5'][s_run][pomdp_type]
    lstm_td3_pomdp_evaluation.append(s_run_evals)
    lstm_td3_pomdp_evaluation_mean.append(np.mean(s_run_evals))
    lstm_td3_pomdp_evaluation_std.append(np.std(s_run_evals))
    
# Plot
axes.bar(np.arange(0, 4) + 5*bar_width - 2.5*bar_width, lstm_td3_pomdp_evaluation_mean, yerr = lstm_td3_pomdp_evaluation_std,
         width = bar_width, label='{}'.format('LSTM-TD3'), color='r', alpha=0.8, edgecolor='w')

axes.set_xticks(np.arange(len(['MDP', 'flickering', 'random_noise', 'random_sensor_missing'])))
axes.set_xticklabels(['MDP', 'POMDP-FLK', 'POMDP-RN', 'POMDP-RSM'], fontsize=12)
axes.set_xlabel('Evaluation Environment', fontsize=16)
axes.set_ylabel('Average Return', fontsize=16)
axes.set_title('Trained on MDP and Evaluated on \n Both MDP and POMDPs', fontsize=16)
# axes.legend(ncol=3, bbox_to_anchor=(1.05, 1))
axes.grid(True, linestyle=':')
fig.savefig("D:\POMDP_Data\images\MDP_to_POMDP_evaluation.png", bbox_inches='tight')
plt.rc('font', size=12)

# %%
from matplotlib.patches import Patch, Rectangle
from matplotlib.lines import Line2D

lw_scale = 4

legend_elements= []
for alg in algs:
    legend_elements.append(Patch(facecolor=color[alg], edgecolor=color[alg], label=alg))
legend_elements.append(Patch(facecolor='r', edgecolor='r', label='LSTM-TD3(5)')) 
# Create the figure
fig, ax = plt.subplots()
ax.legend(handles=legend_elements, loc='center', ncol=6)
ax.axis(False)
plt.show()
plt.rc('font', size=30)
fig.savefig("D:\POMDP_Data\images\MDP_to_POMDP_legend.png", bbox_inches='tight')

# %%
plt.rc('font', size=14)

# %% [markdown]
# ## POMDP -> MDP
# ### Baselines

# %%
# root_dir = r"D:\POMDP_Data\clean_spinup_POMDP_Flickering_Baselines"
tasks = ['AntPyBulletEnv-v0']
baselines_POMDP_to_MDP = {}

root_dir_all_pomdp = ["D:\POMDP_Data\clean_spinup_POMDP_Flickering_Baselines", 
                      "D:\POMDP_Data\clean_spinup_POMDP_RandomNoise_Baselines",
                      "D:\POMDP_Data\clean_spinup_POMDP_RandomSensorMissing_Baselines",
                      "D:\POMDP_Data\clean_spinup_POMDP_RemoveVelocity_Baselines"]
for root_dir in root_dir_all_pomdp:
    for sub_dir in os.listdir(root_dir):
        print(sub_dir)
        print(sub_dir.split('_'))
        params = sub_dir.split('_')
        alg_name = params[1]
        task_name = params[2]
        pomdp_hyperparam = params[3]
        seed = params[4]
        if 'POMDP-RemoveVelocity' == pomdp_hyperparam:
            continue
        if task_name in tasks:
            if alg_name not in baselines_POMDP_to_MDP:
                baselines_POMDP_to_MDP[alg_name] = {}
            if task_name not in baselines_POMDP_to_MDP[alg_name]:
                baselines_POMDP_to_MDP[alg_name][task_name] = {}
            if pomdp_hyperparam not in baselines_POMDP_to_MDP[alg_name][task_name]:
                baselines_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam] = {}
            if seed not in baselines_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam]:
                baselines_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam][seed] = {}
            #
            print("********************************************************************")
            for exp_run in os.listdir(os.path.join(root_dir, sub_dir)):
                print(exp_run)
                # Load pre-trained model
                config_path = os.path.join(root_dir, sub_dir, exp_run, 'config.json')
                with open(config_path, 'r') as config_file:
                    config_json = json.load(config_file)
                model_path = os.path.join(root_dir, sub_dir, exp_run, 'pyt_save', 'model.pt')
                ac = torch.load(model_path)
                # print(ac)

                # Retrive hyper-parameters
                env_name = config_json['env_name']
                num_test_episodes = config_json['num_test_episodes']
                max_ep_len = config_json['max_ep_len']
                if alg_name == 'TD3-OW' or alg_name == 'TD3-OW-AddPastAct':
                    observation_window_size = config_json['observation_window_size']

                for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
                    print("\t{}".format(pomdp_type))
                    baselines_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam][seed][pomdp_type] = []
                    # Create environment
                    if pomdp_type == 'MDP':
                        test_env = gym.make(env_name)
                    else:
                        test_env = POMDPWrapper(env_name, pomdp_type, flicker_prob, random_noise_sigma, random_sensor_missing_prob)
                    obs_dim = test_env.observation_space.shape[0]
                    act_dim = test_env.action_space.shape[0]
                    act_limit = test_env.action_space.high[0]

                    # Evaluation
                    for j in range(num_test_episodes):
                        # Reset environment
                        o, d, ep_ret, ep_len = test_env.reset(), False, 0, 0
                        if alg_name == 'TD3-OW':
                            ow_o = np.zeros([int(observation_window_size * obs_dim)])
                            ow_o[-obs_dim:] = o
                        elif alg_name == 'TD3-OW-AddPastAct':
                            ow_o = np.zeros([int((observation_window_size - 1) * (obs_dim + act_dim) + obs_dim)])
                            ow_o[-obs_dim:] = o
                        elif alg_name == 'LSTM-TD3':
                            pass
                        else:
                            pass

                        # Interact
                        while not(d or (ep_len == max_ep_len)):
                            # Take deterministic actions at test time 
                            if alg_name == 'TD3-OW' or alg_name == 'TD3-OW-AddPastAct':
                                action = ac.act(torch.as_tensor(ow_o, dtype=torch.float32))
                            elif alg_name == 'SAC':
                                action = ac.act(torch.as_tensor(o, dtype=torch.float32), True)
                            else:
                                action = ac.act(torch.as_tensor(o, dtype=torch.float32))
                            o, r, d, _ = test_env.step(action)
                            ep_ret += r
                            ep_len += 1

                            # Construct Observation-Window-based observation for TD3-OW and TD3-OW-AddPastAct
                            if alg_name == 'TD3-OW':
                                ow_o[:-obs_dim] = ow_o[obs_dim:]
                                ow_o[-obs_dim:] = o
                            elif alg_name == 'TD3-OW-AddPastAct':
                                ow_o[:-(obs_dim + act_dim)] = ow_o[(obs_dim + act_dim):]
                                ow_o[-(obs_dim + act_dim):] = np.concatenate((action, o))

                        print('\t  Episod-{}: Ep_Return={}, Ep_Len={}'.format(j, ep_ret, ep_len))
                        baselines_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam][seed][pomdp_type].append(ep_ret)
# Out:
# 2020-11-17_DDPG_AntMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'DDPG', 'AntMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_DDPG_AntMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'DDPG', 'AntMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_DDPG_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'DDPG', 'AntPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# ********************************************************************
# 2020-11-17_00-01-23_DDPG_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=741.7631394082019, Ep_Len=1000
# 	  Episod-1: Ep_Return=397.34627567768575, Ep_Len=1000
# 	  Episod-2: Ep_Return=740.861651086443, Ep_Len=1000
# 	  Episod-3: Ep_Return=454.42986500873076, Ep_Len=1000
# 	  Episod-4: Ep_Return=542.9659805235221, Ep_Len=1000
# 	  Episod-5: Ep_Return=543.288051101932, Ep_Len=1000
# 	  Episod-6: Ep_Return=536.4946047808736, Ep_Len=1000
# 	  Episod-7: Ep_Return=488.81607307172396, Ep_Len=1000
# 	  Episod-8: Ep_Return=662.6559979859263, Ep_Len=1000
# 	  Episod-9: Ep_Return=629.9613436291966, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=367.32138682485817, Ep_Len=1000
# 	  Episod-1: Ep_Return=519.6482060635927, Ep_Len=1000
# 	  Episod-2: Ep_Return=484.27960462677845, Ep_Len=1000
# 	  Episod-3: Ep_Return=436.4870780516806, Ep_Len=1000
# 	  Episod-4: Ep_Return=461.78717950635775, Ep_Len=1000
# 	  Episod-5: Ep_Return=342.57571602284844, Ep_Len=1000
# 	  Episod-6: Ep_Return=337.3260393985561, Ep_Len=1000
# 	  Episod-7: Ep_Return=475.74242971049, Ep_Len=1000
# 	  Episod-8: Ep_Return=532.0766809123443, Ep_Len=1000
# 	  Episod-9: Ep_Return=357.40685853693685, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=557.1931550347281, Ep_Len=1000
# 	  Episod-1: Ep_Return=539.5159693744661, Ep_Len=1000
# 	  Episod-2: Ep_Return=594.5064609726052, Ep_Len=1000
# 	  Episod-3: Ep_Return=582.8336254781448, Ep_Len=1000
# 	  Episod-4: Ep_Return=576.387298914544, Ep_Len=1000
# 	  Episod-5: Ep_Return=558.4913882417284, Ep_Len=1000
# 	  Episod-6: Ep_Return=579.2613023051792, Ep_Len=1000
# 	  Episod-7: Ep_Return=604.2602640695246, Ep_Len=1000
# 	  Episod-8: Ep_Return=566.5658914262053, Ep_Len=1000
# 	  Episod-9: Ep_Return=618.0008307848881, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=608.7790348443818, Ep_Len=1000
# 	  Episod-1: Ep_Return=636.353740801428, Ep_Len=1000
# 	  Episod-2: Ep_Return=599.034613490172, Ep_Len=1000
# 	  Episod-3: Ep_Return=595.3373421757843, Ep_Len=1000
# 	  Episod-4: Ep_Return=612.2614699175986, Ep_Len=1000
# 	  Episod-5: Ep_Return=688.8959617603172, Ep_Len=1000
# 	  Episod-6: Ep_Return=689.121648193656, Ep_Len=1000
# 	  Episod-7: Ep_Return=613.0486907014188, Ep_Len=1000
# 	  Episod-8: Ep_Return=643.5414313938551, Ep_Len=1000
# 	  Episod-9: Ep_Return=613.3060094197393, Ep_Len=1000
# 2020-11-17_DDPG_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'DDPG', 'AntPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# ********************************************************************
# 2020-11-17_00-01-23_DDPG_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=428.60866740003996, Ep_Len=1000
# 	  Episod-1: Ep_Return=477.6007532926679, Ep_Len=1000
# 	  Episod-2: Ep_Return=456.85936334314766, Ep_Len=1000
# 	  Episod-3: Ep_Return=450.03991427211713, Ep_Len=1000
# 	  Episod-4: Ep_Return=469.2301011276388, Ep_Len=1000
# 	  Episod-5: Ep_Return=539.7995340667021, Ep_Len=1000
# 	  Episod-6: Ep_Return=433.34052464956164, Ep_Len=1000
# 	  Episod-7: Ep_Return=532.6516375233107, Ep_Len=1000
# 	  Episod-8: Ep_Return=498.93562844401185, Ep_Len=1000
# 	  Episod-9: Ep_Return=486.0085320216832, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=505.0256629908697, Ep_Len=1000
# 	  Episod-1: Ep_Return=486.65643130171077, Ep_Len=1000
# 	  Episod-2: Ep_Return=487.1311960448804, Ep_Len=1000
# 	  Episod-3: Ep_Return=495.0853392990973, Ep_Len=1000
# 	  Episod-4: Ep_Return=451.6731787886183, Ep_Len=1000
# 	  Episod-5: Ep_Return=476.62847997027086, Ep_Len=1000
# 	  Episod-6: Ep_Return=433.72437943653995, Ep_Len=1000
# 	  Episod-7: Ep_Return=430.02449948266076, Ep_Len=1000
# 	  Episod-8: Ep_Return=450.41714844819114, Ep_Len=1000
# 	  Episod-9: Ep_Return=506.0452399554443, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return
AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=787.1805387903036, Ep_Len=1000
# 	  Episod-1: Ep_Return=876.0094944692377, Ep_Len=1000
# 	  Episod-2: Ep_Return=795.2419893893857, Ep_Len=1000
# 	  Episod-3: Ep_Return=851.8060609736168, Ep_Len=1000
# 	  Episod-4: Ep_Return=859.2374803888999, Ep_Len=1000
# 	  Episod-5: Ep_Return=784.620794098495, Ep_Len=1000
# 	  Episod-6: Ep_Return=827.6540937435524, Ep_Len=1000
# 	  Episod-7: Ep_Return=837.727216948152, Ep_Len=1000
# 	  Episod-8: Ep_Return=723.142119335834, Ep_Len=1000
# 	  Episod-9: Ep_Return=875.3934608262269, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=612.2830002197551, Ep_Len=1000
# 	  Episod-1: Ep_Return=617.4520279410651, Ep_Len=1000
# 	  Episod-2: Ep_Return=621.0409121995608, Ep_Len=1000
# 	  Episod-3: Ep_Return=649.5268015229683, Ep_Len=1000
# 	  Episod-4: Ep_Return=639.2565200048313, Ep_Len=1000
# 	  Episod-5: Ep_Return=623.1299316507265, Ep_Len=1000
# 	  Episod-6: Ep_Return=660.9222775940426, Ep_Len=1000
# 	  Episod-7: Ep_Return=591.6713686552577, Ep_Len=1000
# 	  Episod-8: Ep_Return=536.5159717903348, Ep_Len=1000
# 	  Episod-9: Ep_Return=558.8791849044418, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=685.4002888436745, Ep_Len=1000
# 	  Episod-1: Ep_Return=715.6767297346876, Ep_Len=1000
# 	  Episod-2: Ep_Return=684.7290539149424, Ep_Len=1000
# 	  Episod-3: Ep_Return=702.0663183961127, Ep_Len=1000
# 	  Episod-4: Ep_Return=752.9864535165152, Ep_Len=1000
# 	  Episod-5: Ep_Return=408.4750397627103, Ep_Len=1000
# 	  Episod-6: Ep_Return=733.4109114709912, Ep_Len=1000
# 	  Episod-7: Ep_Return=640.4340256947185, Ep_Len=1000
# 	  Episod-8: Ep_Return=752.5674709890079, Ep_Len=1000
# 	  Episod-9: Ep_Return=711.7285729394022, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=835.8355241178133, Ep_Len=1000
# 	  Episod-1: Ep_Return=813.2292936825257, Ep_Len=1000
# 	  Episod-2: Ep_Return=726.6811312094073, Ep_Len=1000
# 	  Episod-3: Ep_Return=787.4754888687619, Ep_Len=1000
# 	  Episod-4: Ep_Return=852.3309432163574, Ep_Len=1000
# 	  Episod-5: Ep_Return=743.3565081950006, Ep_Len=1000
# 	  Episod-6: Ep_Return=798.8858662248509, Ep_Len=1000
# 	  Episod-7: Ep_Return=654.0230066801586, Ep_Len=1000
# 	  Episod-8: Ep_Return=835.5105700247736, Ep_Len=1000
# 	  Episod-9: Ep_Return=830.027521505094, Ep_Len=1000
# 2020-11-17_TD3_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'AntPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# ********************************************************************
# 2020-11-17_00-17-21_TD3_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=518.3263365814255, Ep_Len=1000
# 	  Episod-1: Ep_Return=503.76775745105823, Ep_Len=1000
# 	  Episod-2: Ep_Return=506.0559638157482, Ep_Len=1000
# 	  Episod-3: Ep_Return=563.7891395019145, Ep_Len=1000
# 	  Episod-4: Ep_Return=472.61345622472453, Ep_Len=1000
# 	  Episod-5: Ep_Return=495.51109119552564, Ep_Len=1000
# 	  Episod-6: Ep_Return=533.4917077319046, Ep_Len=1000
# 	  Episod-7: Ep_Return=198.52853537367923, Ep_Len=453
# 	  Episod-8: Ep_Return=709.029654627944, Ep_Len=1000
# 	  Episod-9: Ep_Return=592.3742720073789, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=636.3497024932611, Ep_Len=1000
# 	  Episod-1: Ep_Return=760.0461074008716, Ep_Len=1000
# 	  Episod-2: Ep_Return=575.8880935189133, Ep_Len=1000
# 	  Episod-3: Ep_Return=590.299834727533, Ep_Len=1000
# 	  Episod-4: Ep_Return=536.9239625512693, Ep_Len=1000
# 	  Episod-5: Ep_Return=669.2751786706178, Ep_Len=1000
# 	  Episod-6: Ep_Return=699.4004838988316, Ep_Len=1000
# 	  Episod-7: Ep_Return=721.842231883224, Ep_Len=1000
# 	  Episod-8: Ep_Return=741.5775634337829, Ep_Len=1000
# 	  Episod-9: Ep_Return=559.5385480582896, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=223.61487897394554, Ep_Len=388
# 	  Episod-1: Ep_Return=602.0520038378995, Ep_Len=1000
# 	  Episod-2: Ep_Return=674.691472155865, Ep_Len=1000
# 	  Episod-3: Ep_Return=701.7354936842878, Ep_Len=1000
# 	  Episod-4: Ep_Return=530.2593790954893, Ep_Len=1000
# 	  Episod-5: Ep_Return=680.8588788069139, Ep_Len=1000
# 	  Episod-6: Ep_Return=223.77847221903073, Ep_Len=426
# 	  Episod-7: Ep_Return=659.2471418695059, Ep_Len=1000
# 	  Episod-8: Ep_Return=627.7849860600192, Ep_Len=1000
# 	  Episod-9: Ep_Return=680.8683084664635, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=242.17179235653876, Ep_Len=437
# 	  Episod-1: Ep_Return=577.543037316529, Ep_Len=1000
# 	  Episod-2: Ep_Return=629.0749636234045, Ep_Len=1000
# 	  Episod-3: Ep_Return=630.4578678195076, Ep_Len=1000
# 	  Episod-4: Ep_Return=584.2342478472572, Ep_Len=1000
# 	  Episod-5: Ep_Return=515.8835108980289, Ep_Len=1000
# 	  Episod-6: Ep_Return=606.9537691172468, Ep_Len=1000
# 	  Episod-7: Ep_Return=544.3872224908484, Ep_Len=1000
# 	  Episod-8: Ep_Return=710.8408865540249, Ep_Len=1000
# 	  Episod-9: Ep_Return=642.506688435442, Ep_Len=1000
# 2020-11-17_TD3_HalfCheetahMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'HalfCheetahMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_HalfCheetahMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'HalfCheetahMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_HalfCheetahPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'HalfCheetahPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_HalfCheetahPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'HalfCheetahPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_HopperMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'HopperMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_HopperMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'HopperMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_HopperPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'HopperPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_HopperPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'HopperPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_InvertedDoublePendulumMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'InvertedDoublePendulumMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_InvertedDoublePendulumMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'InvertedDoublePendulumMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_InvertedDoublePendulumPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_InvertedDoublePendulumPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_InvertedPendulumMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'InvertedPendulumMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_InvertedPendulumMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'InvertedPendulumMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_InvertedPendulumPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'InvertedPendulumPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_InvertedPendulumPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'InvertedPendulumPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_ReacherPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'ReacherPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_ReacherPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'ReacherPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_Walker2DMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'Walker2DMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_Walker2DMuJoCoEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'Walker2DMuJoCoEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2020-11-17_TD3_Walker2DPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2020-11-17', 'TD3', 'Walker2DPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# 2020-11-17_TD3_Walker2DPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2020-11-17', 'TD3', 'Walker2DPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# 2021-01-29_TD3-OW-AddPastAct_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# ['2021-01-29', 'TD3-OW-AddPastAct', 'AntPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's0']
# ********************************************************************
# 2021-01-29_18-06-56_TD3-OW-AddPastAct_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s0
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1975.8152364127047, Ep_Len=1000
# 	  Episod-1: Ep_Return=1919.0468216977179, Ep_Len=1000
# 	  Episod-2: Ep_Return=1918.5911091595303, Ep_Len=1000
# 	  Episod-3: Ep_Return=1915.0783430873796, Ep_Len=1000
# 	  Episod-4: Ep_Return=1992.1716016284088, Ep_Len=1000
# 	  Episod-5: Ep_Return=1872.4577140490649, Ep_Len=1000
# 	  Episod-6: Ep_Return=1955.5546601780989, Ep_Len=1000
# 	  Episod-7: Ep_Return=1933.6043770680278, Ep_Len=1000
# 	  Episod-8: Ep_Return=1931.729425422842, Ep_Len=1000
# 	  Episod-9: Ep_Return=1941.3166720449192, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1864.0641050110885, Ep_Len=1000
# 	  Episod-1: Ep_Return=1885.606370548856, Ep_Len=1000
# 	  Episod-2: Ep_Return=1965.5385116757532, Ep_Len=1000
# 	  Episod-3: Ep_Return=1943.9264197548225, Ep_Len=1000
# 	  Episod-4: Ep_Return=1884.7794398112594, Ep_Len=1000
# 	  Episod-5: Ep_Return=1938.9638417680137, Ep_Len=1000
# 	  Episod-6: Ep_Return=1991.1309008072842, Ep_Len=1000
# 	  Episod-7: Ep_Return=1934.8632840757616, Ep_Len=1000
# 	  Episod-8: Ep_Return=2011.9063740854554, Ep_Len=1000
# 	  Episod-9: Ep_Return=1913.7796023389994, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1908.4387168978285, Ep_Len=1000
# 	  Episod-1: Ep_Return=1821.105855036283, Ep_Len=1000
# 	  Episod-2: Ep_Return=1863.1241964464682, Ep_Len=1000
# 	  Episod-3: Ep_Return=1836.7126407498945, Ep_Len=1000
# 	  Episod-4: Ep_Return=1823.5497278173473, Ep_Len=1000
# 	  Episod-5: Ep_Return=1985.7544738289703, Ep_Len=1000
# 	  Episod-6: Ep_Return=1866.701713327654, Ep_Len=1000
# 	  Episod-7: Ep_Return=1867.3497364564194, Ep_Len=1000
# 	  Episod-8: Ep_Return=1842.1120080387038, Ep_Len=1000
# 	  Episod-9: Ep_Return=1908.8337579518354, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1954.9461190177783, Ep_Len=1000
# 	  Episod-1: Ep_Return=1876.501310694293, Ep_Len=1000
# 	  Episod-2: Ep_Return=1853.8053778747492, Ep_Len=1000
# 	  Episod-3: Ep_Return=1893.9386686149562, Ep_Len=1000
# 	  Episod-4: Ep_Return=1899.4396311191833, Ep_Len=1000
# 	  Episod-5: Ep_Return=1917.261937360881, Ep_Len=1000
# 	  Episod-6: Ep_Return=1915.3814685923564, Ep_Len=1000
# 	  Episod-7: Ep_Return=1860.409086784044, Ep_Len=1000
# 	  Episod-8: Ep_Return=1878.8086835390197, Ep_Len=1000
# 	  Episod-9: Ep_Return=1918.698279881095, Ep_Len=1000
# 2021-01-29_TD3-OW-AddPastAct_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# ['2021-01-29', 'TD3-OW-AddPastAct', 'AntPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's1']
# ********************************************************************
# 2021-01-29_18-16-52_TD3-OW-AddPastAct_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s1
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2026.020864190608, Ep_Len=1000
# 	  Episod-1: Ep_Return=2013.7845296862472, Ep_Len=1000
# 	  Episod-2: Ep_Return=1985.8677329443562, Ep_Len=1000
# 	  Episod-3: Ep_Return=2044.6982899018917, Ep_Len=1000
# 	  Episod-4: Ep_Return=1992.556577767464, Ep_Len=1000
# 	  Episod-5: Ep_Return=2001.5642986276316, Ep_Len=1000
# 	  Episod-6: Ep_Return=2015.5117783786736, Ep_Len=1000
# 	  Episod-7: Ep_Return=2001.666380440501, Ep_Len=1000
# 	  Episod-8: Ep_Return=2004.2840189089964, Ep_Len=1000
# 	  Episod-9: Ep_Return=2005.6504184442829, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2006.2462945733946, Ep_Len=1000
# 	  Episod-1: Ep_Return=1943.3620205675654, Ep_Len=1000
# 	  Episod-2: Ep_Return=1986.4906009030908, Ep_Len=1000
# 	  Episod-3: Ep_Return=1994.326950078336, Ep_Len=1000
# 	  Episod-4: Ep_Return=1949.6557558772017, Ep_Len=1000
# 	  Episod-5: Ep_Return=1969.729492625247, Ep_Len=1000
# 	  Episod-6: Ep_Return=1930.3658899118777, Ep_Len=1000
# 	  Episod-7: Ep_Return=1958.583579651075, Ep_Len=1000
# 	  Episod-8: Ep_Return=2013.8274129510075, Ep_Len=1000
# 	  Episod-9: Ep_Return=1997.7433907318202, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1983.092584310786, Ep_Len=1000
# 	  Episod-1: Ep_Return=1912.6388683995597, Ep_Len=1000
# 	  Episod-2: Ep_Return=1950.447234028503, Ep_Len=1000
# 	  Episod-3: Ep_Return=1949.038586660562, Ep_Len=1000
# 	  Episod-4: Ep_Return=1942.2084993143615, Ep_Len=1000
# 	  Episod-5: Ep_Return=1958.5004831930848, Ep_Len=1000
# 	  Episod-6: Ep_Return=1982.116601715402, Ep_Len=1000
# 	  Episod-7: Ep_Return=1983.1453129493295, Ep_Len=1000
# 	  Episod-8: Ep_Return=1953.538934119, Ep_Len=1000
# 	  Episod-9: Ep_Return=1956.94238352467, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1920.4881305838173, Ep_Len=1000
# 	  Episod-1: Ep_Return=1997.5547479943355, Ep_Len=1000
# 	  Episod-2: Ep_Return=1857.1630775354008, Ep_Len=1000
# 	  Episod-3: Ep_Return=1943.7761599889961, Ep_Len=1000
# 	  Episod-4: Ep_Return=1963.2499476322423, Ep_Len=1000
# 	  Episod-5: Ep_Return=1926.3920615990971, Ep_Len=1000
# 	  Episod-6: Ep_Return=1875.3768279967678, Ep_Len=1000
# 	  Episod-7: Ep_Return=1904.5833916056265, Ep_Len=1000
# 	  Episod-8: Ep_Return=1949.5749862416392, Ep_Len=1000
# 	  Episod-9: Ep_Return=1946.1742597569848, Ep_Len=1000
# 2021-01-29_TD3-OW-AddPastAct_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s2
# ['2021-01-29', 'TD3-OW-AddPastAct', 'AntPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's2']
# ********************************************************************
# 2021-01-29_18-22-48_TD3-OW-AddPastAct_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s2
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=86.99770196865221, Ep_Len=1000
# 	  Episod-1: Ep_Return=89.07512265482576, Ep_Len=1000
# 	  Episod-2: Ep_Return=91.05452552239348, Ep_Len=1000
# 	  Episod-3: Ep_Return=88.70449658325731, Ep_Len=1000
# 	  Episod-4: Ep_Return=84.78195712706444, Ep_Len=1000
# 	  Episod-5: Ep_Return=89.3897308508086, Ep_Len=1000
# 	  Episod-6: Ep_Return=84.99954733303404, Ep_Len=1000
# 	  Episod-7: Ep_Return=174.53419993673896, Ep_Len=1000
# 	  Episod-8: Ep_Return=89.23933889310784, Ep_Len=1000
# 	  Episod-9: Ep_Return=89.07704663278776, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=93.25594816310225, Ep_Len=1000
# 	  Episod-1: Ep_Return=89.42962535135948, Ep_Len=1000
# 	  Episod-2: Ep_Return=88.97860967685176, Ep_Len=1000
# 	  Episod-3: Ep_Return=83.66538443087003, Ep_Len=1000
# 	  Episod-4: Ep_Return=92.60919983074754, Ep_Len=1000
# 	  Episod-5: Ep_Return=85.16692263352398, Ep_Len=1000
# 	  Episod-6: Ep_Return=91.52626018631904, Ep_Len=1000
# 	  Episod-7: Ep_Return=88.33875843876956, Ep_Len=1000
# 	  Episod-8: Ep_Return=94.92572711231362, Ep_Len=1000
# 	  Episod-9: Ep_Return=90.43916422366075, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=89.43827432153405, Ep_Len=1000
# 	  Episod-1: Ep_Return=85.17503147935442, Ep_Len=1000
# 	  Episod-2: Ep_Return=85.71272657847825, Ep_Len=1000
# 	  Episod-3: Ep_Return=89.73870493907503, Ep_Len=1000
# 	  Episod-4: Ep_Return=89.49412435443729, Ep_Len=1000
# 	  Episod-5: Ep_Return=94.56729125711894, Ep_Len=1000
# 	  Episod-6: Ep_Return=92.67044640696011, Ep_Len=1000
# 	  Episod-7: Ep_Return=171.12816606472654, Ep_Len=1000
# 	  Episod-8: Ep_Return=176.86144907553384, Ep_Len=1000
# 	  Episod-9: Ep_Return=93.33409139314647, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=88.70728480466565, Ep_Len=1000
# 	  Episod-1: Ep_Return=88.18603626212935, Ep_Len=1000
# 	  Episod-2: Ep_Return=89.80491745756215, Ep_Len=1000
# 	  Episod-3: Ep_Return=94.33328442131932, Ep_Len=1000
# 	  Episod-4: Ep_Return=86.53315163771269, Ep_Len=1000
# 	  Episod-5: Ep_Return=83.43823772246202, Ep_Len=1000
# 	  Episod-6: Ep_Return=90.38268537587047, Ep_Len=1000
# 	  Episod-7: Ep_Return=180.89402213857653, Ep_Len=1000
# 	  Episod-8: Ep_Return=89.72049913613506, Ep_Len=1000
# 	  Episod-9: Ep_Return=85.8353879244132, Ep_Len=1000
# 2021-01-29_TD3-OW-AddPastAct_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s3
# ['2021-01-29', 'TD3-OW-AddPastAct', 'AntPyBulletEnv-v0', 'POMDP-Flickering-FlickProb-0.2', 's3']
# ********************************************************************
# 2021-01-29_18-22-49_TD3-OW-AddPastAct_AntPyBulletEnv-v0_POMDP-Flickering-FlickProb-0.2_s3
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=175.9023797996676, Ep_Len=1000
# 	  Episod-1: Ep_Return=180.02473588019163, Ep_Len=1000
# 	  Episod-2: Ep_Return=61.275405738860535, Ep_Len=1000
# 	  Episod-3: Ep_Return=161.51592633322193, Ep_Len=1000
# 	  Episod-4: Ep_Return=69.6427109061571, Ep_Len=1000
# 	  Episod-5: Ep_Return=192.26857740115275, Ep_Len=1000
# 	  Episod-6: Ep_Return=193.8103478713853, Ep_Len=1000
# 	  Episod-7: Ep_Return=180.53690706570003, Ep_Len=1000
# 	  Episod-8: Ep_Return=188.0767220678863, Ep_Len=1000
# 	  Episod-9: Ep_Return=161.55992402764838, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=186.33092043212753, Ep_Len=1000
# 	  Episod-1: Ep_Return=185.5829776670254, Ep_Len=1000
# 	  Episod-2: Ep_Return=178.72298219438207, Ep_Len=1000
# 	  Episod-3: Ep_Return=187.8326892739897, Ep_Len=1000
# 	  Episod-4: Ep_Return=182.94265202421178, Ep_Len=1000
# 	  Episod-5: Ep_Return=185.1448904188548, Ep_Len=1000
# 	  Episod-6: Ep_Return=73.22448180936956, Ep_Len=1000
# 	  Episod-7: Ep_Return=189.69122938436405, Ep_Len=1000
# 	  Episod-8: Ep_Return=81.60097806612859, Ep_Len=1000
# 	  Episod-9: Ep_Return=182.79326411558085, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=179.0979926438592, Ep_Len=1000
# 	  Episod-1: Ep_Return=188.3981822644469, Ep_Len=1000
# 	  Episod-2: Ep_Return=179.49906662201505, Ep_Len=1000
# 	  Episod-3: Ep_Return=191.20116446568917, Ep_Len=1000
# 	  Episod-4: Ep_Return=185.5017172752684, Ep_Len=1000
# 	  Episod-5: Ep_Return=176.15869265066118, Ep_Len=1000
# 	  Episod-6: Ep_Return=69.48514624308801, Ep_Len=1000
# 	  Episod-7: Ep_Return=184.81946488122566, Ep_Len=1000
# 	  Episod-8: Ep_Return=69.84542333893825, Ep_Len=1000
# 	  Episod-9: Ep_Return=191.85151085157466, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=190.05873866454695, Ep_Len=1000
# 	  Episod-1: Ep_Return=193.52917368438835, Ep_Len=1000
# ...
# 	  Episod-2: Ep_Return=764.1314193994664, Ep_Len=1000
# 	  Episod-3: Ep_Return=773.378504315777, Ep_Len=1000
# 	  Episod-4: Ep_Return=771.9748907330218, Ep_Len=1000
# 	  Episod-5: Ep_Return=787.2861535788895, Ep_Len=1000
# 	  Episod-6: Ep_Return=856.0536823890769, Ep_Len=1000
# 	  Episod-7: Ep_Return=835.1375201950285, Ep_Len=1000
# 	  Episod-8: Ep_Return=837.035861365693, Ep_Len=1000
# 	  Episod-9: Ep_Return=793.4156974638964, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=738.9788587286789, Ep_Len=1000
# 	  Episod-1: Ep_Return=713.1964799377228, Ep_Len=1000
# 	  Episod-2: Ep_Return=723.7444209275666, Ep_Len=1000
# 	  Episod-3: Ep_Return=734.707385512607, Ep_Len=1000
# 	  Episod-4: Ep_Return=707.9919249533776, Ep_Len=1000
# 	  Episod-5: Ep_Return=708.7188034381167, Ep_Len=1000
# 	  Episod-6: Ep_Return=737.8141045423603, Ep_Len=1000
# 	  Episod-7: Ep_Return=702.8927828085342, Ep_Len=1000
# 	  Episod-8: Ep_Return=755.726920298778, Ep_Len=1000
# 	  Episod-9: Ep_Return=711.313300134016, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=756.2003589845397, Ep_Len=1000
# 	  Episod-1: Ep_Return=726.527345303522, Ep_Len=1000
# 	  Episod-2: Ep_Return=766.9296438020317, Ep_Len=1000
# 	  Episod-3: Ep_Return=718.5442025682718, Ep_Len=1000
# 	  Episod-4: Ep_Return=752.8161389426454, Ep_Len=1000
# 	  Episod-5: Ep_Return=708.2807098720236, Ep_Len=1000
# 	  Episod-6: Ep_Return=715.8614546207248, Ep_Len=1000
# 	  Episod-7: Ep_Return=695.2323805469747, Ep_Len=1000
# 	  Episod-8: Ep_Return=717.1183437596978, Ep_Len=1000
# 	  Episod-9: Ep_Return=794.1101611117235, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=749.4457897972429, Ep_Len=1000
# 	  Episod-1: Ep_Return=755.0192249740808, Ep_Len=1000
# 	  Episod-2: Ep_Return=753.6833078892982, Ep_Len=1000
# 	  Episod-3: Ep_Return=737.7195236262593, Ep_Len=1000
# 	  Episod-4: Ep_Return=771.8697656620695, Ep_Len=1000
# 	  Episod-5: Ep_Return=729.1034119954685, Ep_Len=1000
# 	  Episod-6: Ep_Return=772.6231959390559, Ep_Len=1000
# 	  Episod-7: Ep_Return=754.0530194568925, Ep_Len=1000
# 	  Episod-8: Ep_Return=780.1896463937712, Ep_Len=1000
# 	  Episod-9: Ep_Return=715.6059426201617, Ep_Len=1000
# 2021-01-29_TD3-OW_AntPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s2
# ['2021-01-29', 'TD3-OW', 'AntPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's2']
# ********************************************************************
# 2021-01-29_21-52-08_TD3-OW_AntPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s2
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1634.4343032272948, Ep_Len=1000
# 	  Episod-1: Ep_Return=1498.8464807938396, Ep_Len=1000
# 	  Episod-2: Ep_Return=1579.5157239216742, Ep_Len=1000
# 	  Episod-3: Ep_Return=1578.967132092842, Ep_Len=1000
# 	  Episod-4: Ep_Return=1577.2625878108997, Ep_Len=1000
# 	  Episod-5: Ep_Return=1469.1138219612012, Ep_Len=1000
# 	  Episod-6: Ep_Return=1605.2310966161986, Ep_Len=1000
# 	  Episod-7: Ep_Return=1559.7035779295124, Ep_Len=1000
# 	  Episod-8: Ep_Return=1543.0857436378376, Ep_Len=1000
# 	  Episod-9: Ep_Return=1616.297620465627, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1283.9943726886343, Ep_Len=1000
# 	  Episod-1: Ep_Return=1411.8347268009486, Ep_Len=1000
# 	  Episod-2: Ep_Return=1399.4046432024288, Ep_Len=1000
# 	  Episod-3: Ep_Return=1483.3220153608695, Ep_Len=1000
# 	  Episod-4: Ep_Return=1389.1254956816188, Ep_Len=1000
# 	  Episod-5: Ep_Return=1464.4838668506457, Ep_Len=1000
# 	  Episod-6: Ep_Return=1354.2396821577481, Ep_Len=1000
# 	  Episod-7: Ep_Return=1305.7574368832281, Ep_Len=1000
# 	  Episod-8: Ep_Return=1377.081881103119, Ep_Len=1000
# 	  Episod-9: Ep_Return=1397.232098464422, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1321.650879834355, Ep_Len=1000
# 	  Episod-1: Ep_Return=1297.7508680619223, Ep_Len=1000
# 	  Episod-2: Ep_Return=1314.493963131428, Ep_Len=1000
# 	  Episod-3: Ep_Return=1247.519245450921, Ep_Len=1000
# 	  Episod-4: Ep_Return=1314.78356523238, Ep_Len=1000
# 	  Episod-5: Ep_Return=1325.7737246056856, Ep_Len=1000
# 	  Episod-6: Ep_Return=1266.3804019799538, Ep_Len=1000
# 	  Episod-7: Ep_Return=1329.1691522771898, Ep_Len=1000
# 	  Episod-8: Ep_Return=1369.3847744755633, Ep_Len=1000
# 	  Episod-9: Ep_Return=1341.2257670719016, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1432.5409273311413, Ep_Len=1000
# 	  Episod-1: Ep_Return=1371.247525190117, Ep_Len=1000
# 	  Episod-2: Ep_Return=1353.7120647599422, Ep_Len=1000
# 	  Episod-3: Ep_Return=1399.0430790833555, Ep_Len=1000
# 	  Episod-4: Ep_Return=1382.5906518337895, Ep_Len=1000
# 	  Episod-5: Ep_Return=1438.1486346445581, Ep_Len=1000
# 	  Episod-6: Ep_Return=1446.2231172154368, Ep_Len=1000
# 	  Episod-7: Ep_Return=1403.1862765353019, Ep_Len=1000
# 	  Episod-8: Ep_Return=1393.1562778067525, Ep_Len=1000
# 	  Episod-9: Ep_Return=1483.2142024881443, Ep_Len=1000
# 2021-01-29_TD3-OW_AntPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s3
# ['2021-01-29', 'TD3-OW', 
yBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s3
# ['2021-01-29', 'TD3-OW', 'HalfCheetahPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's3']
# 2021-01-29_TD3-OW_HopperPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s0
# ['2021-01-29', 'TD3-OW', 'HopperPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's0']
# 2021-01-29_TD3-OW_HopperPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s1
# ['2021-01-29', 'TD3-OW', 'HopperPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's1']
# 2021-01-29_TD3-OW_HopperPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s2
# ['2021-01-29', 'TD3-OW', 'HopperPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's2']
# 2021-01-29_TD3-OW_HopperPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s3
# ['2021-01-29', 'TD3-OW', 'HopperPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's3']
# 2021-01-29_TD3-OW_InvertedDoublePendulumPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s0
# ['2021-01-29', 'TD3-OW', 'InvertedDoublePendulumPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's0']
# 2021-01-29_TD3-OW_InvertedDoublePendulumPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s1
# ['2021-01-29', 'TD3-OW', 'InvertedDoublePendulumPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's1']
# 2021-01-29_TD3-OW_InvertedDoublePendulumPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s2
# ['2021-01-29', 'TD3-OW', 'InvertedDoublePendulumPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's2']
# 2021-01-29_TD3-OW_InvertedDoublePendulumPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s3
# ['2021-01-29', 'TD3-OW', 'InvertedDoublePendulumPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's3']
# 2021-01-29_TD3-OW_InvertedPendulumPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s0
# ['2021-01-29', 'TD3-OW', 'InvertedPendulumPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's0']
# 2021-01-29_TD3-OW_InvertedPendulumPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s1
# ['2021-01-29', 'TD3-OW', 'InvertedPendulumPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's1']
# 2021-01-29_TD3-OW_InvertedPendulumPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s2
# ['2021-01-29', 'TD3-OW', 'InvertedPendulumPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's2']
# 2021-01-29_TD3-OW_InvertedPendulumPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s3
# ['2021-01-29', 'TD3-OW', 'InvertedPendulumPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's3']
# 2021-01-29_TD3-OW_ReacherPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s0
# ['2021-01-29', 'TD3-OW', 'ReacherPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's0']
# 2021-01-29_TD3-OW_ReacherPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s1
# ['2021-01-29', 'TD3-OW', 'ReacherPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's1']
# 2021-01-29_TD3-OW_ReacherPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s2
# ['2021-01-29', 'TD3-OW', 'ReacherPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's2']
# 2021-01-29_TD3-OW_ReacherPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s3
# ['2021-01-29', 'TD3-OW', 'ReacherPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's3']
# 2021-01-29_TD3-OW_Walker2DPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s0
# ['2021-01-29', 'TD3-OW', 'Walker2DPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's0']
# 2021-01-29_TD3-OW_Walker2DPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s1
# ['2021-01-29', 'TD3-OW', 'Walker2DPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's1']
# 2021-01-29_TD3-OW_Walker2DPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s2
# ['2021-01-29', 'TD3-OW', 'Walker2DPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's2']
# 2021-01-29_TD3-OW_Walker2DPyBulletEnv-v0_POMDP-RandomSensorMissing-MissProb-0.1_s3
# ['2021-01-29', 'TD3-OW', 'Walker2DPyBulletEnv-v0', 'POMDP-RandomSensorMissing-MissProb-0.1', 's3']
# 2020-10-27_DDPG_AntMuJoCoEnv-v0_POMDP-RemoveVelocity-Remove-All_s0
# ['2020-10-27', 'DDPG', 'AntMuJoCoEnv-v0', 'POMDP-RemoveVelocity-Remove-All', 's0']
# 2020-10-27_DDPG_AntMuJoCoEnv-v0_POMDP-RemoveVelocity-Remove-All_s1
# ['2020-10-27', 'DDPG', 'AntMuJoCoEnv-v0', 'POMDP-RemoveVelocity-Remove-All', 's1']
# 2020-10-27_DDPG_AntPyBulletEnv-v0_POMDP-RemoveVelocity-Remove-All_s0
# ['2020-10-27', 'DDPG', 'AntPyBulletEnv-v0', 'POMDP-RemoveVelocity-Remove-All', 's0']
# ********************************************************************
# 2020-10-27_19-12-58_DDPG_AntPyBulletEnv-v0_POMDP-RemoveVelocity-Remove-All_s0
# 	MDP
# WalkerBase::__init__
# options=
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-282-f270e8721433> in <module>
#      79                                 action = ac.act(torch.as_tensor(o, dtype=torch.float32), True)
#      80                             else:
# ---> 81                                 action = ac.act(torch.as_tensor(o, dtype=torch.float32))
#      82                             o, r, d, _ = test_env.step(action)
#      83                             ep_ret += r
#
# c:\users\lingheng\google drive\git_repos_2020\spinningup_new\spinup\algos\pytorch\ddpg\core.py in act(self, obs)
#      59     def act(self, obs):
#      60         with torch.no_grad():
# ---> 61             return self.pi(obs).numpy()
#
# C:\ProgramData\Anaconda3\envs\app_cloud\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# c:\users\lingheng\google drive\git_repos_2020\spinningup_new\spinup\algos\pytorch\ddpg\core.py in forward(self, obs)
#      31     def forward(self, obs):
#      32         # Return output from network scaled to action space limits.
# ---> 33         return self.act_limit * self.pi(obs)
#      34
#      35 class MLPQFunction(nn.Module):
#
# C:\ProgramData\Anaconda3\envs\app_cloud\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\envs\app_cloud\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# C:\ProgramData\Anaconda3\envs\app_cloud\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# C:\ProgramData\Anaconda3\envs\app_cloud\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# C:\ProgramData\Anaconda3\envs\app_cloud\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1610         ret = torch.addmm(bias, input, weight.t())
#    1611     else:
# -> 1612         output = input.matmul(weight.t())
#    1613         if bias is not None:
#    1614             output += bias
#
# RuntimeError: size mismatch, m1: [1 x 28], m2: [25 x 256] at C:\cb\pytorch_1000000000000\work\aten\src\TH/generic/THTensorMath.cpp:41

# %% [markdown]
# ### LSTM-TD3

# %%
root_dir = r"D:\POMDP_Data\new_spinup_resumable_POMDP_LSTM_TD3"
DEVICE = "cpu"  # "cuda"
lstm_td3_POMDP_to_MDP = {}
for sub_dir in os.listdir(root_dir):
    print(sub_dir)
    print(sub_dir.split('_'))
    params = sub_dir.split('_')
    alg_name = params[1]
    task_name = params[2]
    pomdp_hyperparam = '_'.join(params[4:-2])
    seed = params[-2]
    hist_len = params[-1]
    if 'remove_velocity' == pomdp_hyperparam:
        continue
    if task_name in tasks:
        if alg_name not in lstm_td3_POMDP_to_MDP:
            lstm_td3_POMDP_to_MDP[alg_name] = {}
        if task_name not in lstm_td3_POMDP_to_MDP[alg_name]:
            lstm_td3_POMDP_to_MDP[alg_name][task_name] = {}
        if pomdp_hyperparam not in lstm_td3_POMDP_to_MDP[alg_name][task_name]:
            lstm_td3_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam] = {}
        if hist_len not in lstm_td3_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam]:
            lstm_td3_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam][hist_len] = {}
        if seed not in lstm_td3_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam][hist_len]:
            lstm_td3_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam][hist_len][seed] = {}
        #
        print("********************************************************************")
        for exp_run in os.listdir(os.path.join(root_dir, sub_dir)):
            print(exp_run)
            # Load pre-trained model
            config_path = os.path.join(root_dir, sub_dir, exp_run, 'config.json')
            with open(config_path, 'r') as config_file:
                config_json = json.load(config_file)
            # Retrive hyper-parameters
            env_name = config_json['env_name']
            num_test_episodes = config_json['num_test_episodes']
            max_ep_len = config_json['max_ep_len']
            max_hist_len = config_json['max_hist_len']
            
            #
            if config_json['partially_observable']:
                env = POMDPWrapper(env_name, config_json['pomdp_type'], 
                                   config_json['flicker_prob'], config_json['random_noise_sigma'], 
                                   config_json['random_sensor_missing_prob'])
            else:
                env = gym.make(env_name)
            
            obs_dim = env.observation_space.shape[0]
            act_dim = env.action_space.shape[0]
            act_limit = env.action_space.high[0]
            
            critic_mem_pre_lstm_hid_sizes = config_json['critic_mem_pre_lstm_hid_sizes']
            critic_mem_lstm_hid_sizes = config_json['critic_mem_lstm_hid_sizes']
            critic_mem_after_lstm_hid_size = config_json['critic_mem_after_lstm_hid_size']
            critic_cur_feature_hid_sizes = config_json['critic_cur_feature_hid_sizes']
            critic_post_comb_hid_sizes = config_json['critic_post_comb_hid_sizes']
            critic_mem_gate = config_json['critic_mem_gate']
            critic_mem_gate_before_current_feature_extraction = config_json['critic_mem_gate_before_current_feature_extraction']
            critic_hist_with_past_act = config_json['critic_hist_with_past_act']
            critic_use_hist_mask = config_json['critic_use_hist_mask']
            actor_mem_pre_lstm_hid_sizes = config_json['actor_mem_pre_lstm_hid_sizes']
            actor_mem_lstm_hid_sizes = config_json['actor_mem_lstm_hid_sizes']
            actor_mem_after_lstm_hid_size = config_json['actor_mem_after_lstm_hid_size']
            actor_cur_feature_hid_sizes = config_json['actor_cur_feature_hid_sizes']
            actor_post_comb_hid_sizes = config_json['actor_post_comb_hid_sizes']
            actor_mem_gate = config_json['actor_mem_gate']
            actor_mem_gate_before_current_feature_extraction = config_json['actor_mem_gate_before_current_feature_extraction']
            actor_hist_with_past_act = config_json['actor_hist_with_past_act']
            actor_use_hist_mask = config_json['actor_use_hist_mask']    
            ac = MLPActorCritic(obs_dim, act_dim, act_limit,
                                critic_mem_pre_lstm_hid_sizes=critic_mem_pre_lstm_hid_sizes,
                                critic_mem_lstm_hid_sizes=critic_mem_lstm_hid_sizes,
                                critic_mem_after_lstm_hid_size=critic_mem_after_lstm_hid_size,
                                critic_cur_feature_hid_sizes=critic_cur_feature_hid_sizes,
                                critic_post_comb_hid_sizes=critic_post_comb_hid_sizes,
                                critic_mem_gate=critic_mem_gate,
                                critic_mem_gate_before_current_feature_extraction=critic_mem_gate_before_current_feature_extraction,
                                critic_hist_with_past_act=critic_hist_with_past_act,
                                critic_use_hist_mask=critic_use_hist_mask,
                                actor_mem_pre_lstm_hid_sizes=actor_mem_pre_lstm_hid_sizes,
                                actor_mem_lstm_hid_sizes=actor_mem_lstm_hid_sizes,
                                actor_mem_after_lstm_hid_size=actor_mem_after_lstm_hid_size,
                                actor_cur_feature_hid_sizes=actor_cur_feature_hid_sizes,
                                actor_post_comb_hid_sizes=actor_post_comb_hid_sizes,
                                actor_mem_gate=actor_mem_gate,
                                actor_mem_gate_before_current_feature_extraction=actor_mem_gate_before_current_feature_extraction,
                                actor_hist_with_past_act=actor_hist_with_past_act,
                                actor_use_hist_mask=actor_use_hist_mask)
            # Load model
            resume_checkpoint_path = os.path.join(root_dir, sub_dir, exp_run, "pyt_save")
            checkpoint_files = os.listdir(resume_checkpoint_path)
            latest_model_checkpoint_file_path = os.path.join(resume_checkpoint_path, checkpoint_files[-1])
            
            model_checkpoint = torch.load(latest_model_checkpoint_file_path)
            ac.load_state_dict(model_checkpoint['ac_state_dict'])
            
            # print(ac)

            # Not include POMDP-RV, because POMDP-RV changed the dimension of observation.
            for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
                print("\t{}".format(pomdp_type))
                lstm_td3_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam][hist_len][seed][pomdp_type] = []
                # Create environment
                if pomdp_type == 'MDP':
                    test_env = gym.make(env_name)
                else:
                    test_env = POMDPWrapper(env_name, pomdp_type, flicker_prob, random_noise_sigma, random_sensor_missing_prob)
                obs_dim = test_env.observation_space.shape[0]
                act_dim = test_env.action_space.shape[0]
                act_limit = test_env.action_space.high[0]
                
                # Evaluation
                for j in range(num_test_episodes):
                    # Reset environment
                    o, d, ep_ret, ep_len = test_env.reset(), False, 0, 0
                    if max_hist_len > 0:
                        o_buff = np.zeros([max_hist_len, obs_dim])
                        a_buff = np.zeros([max_hist_len, act_dim])
                        o_buff[0, :] = o
                        o_buff_len = 0
                    else:
                        o_buff = np.zeros([1, obs_dim])
                        a_buff = np.zeros([1, act_dim])
                        o_buff_len = 0

                    # Interact
                    while not(d or (ep_len == max_ep_len)):
                        # Take deterministic actions at test time 
                        h_o = torch.tensor(o_buff).view(1, o_buff.shape[0], o_buff.shape[1]).float().to(DEVICE)
                        h_a = torch.tensor(a_buff).view(1, a_buff.shape[0], a_buff.shape[1]).float().to(DEVICE)
                        h_l = torch.tensor([o_buff_len]).float().to(DEVICE)
                        a = ac.act(torch.as_tensor(o, dtype=torch.float32).view(1, -1).to(DEVICE),
                                   h_o, h_a, h_l).reshape(act_dim)
                        
                        o2, r, d, _ = test_env.step(a)
                        ep_ret += r
                        ep_len += 1

                        # Add short history
                        if max_hist_len != 0:
                            if o_buff_len == max_hist_len:
                                o_buff[:max_hist_len - 1] = o_buff[1:]
                                a_buff[:max_hist_len - 1] = a_buff[1:]
                                o_buff[max_hist_len - 1] = list(o)
                                a_buff[max_hist_len - 1] = list(a)
                            else:
                                o_buff[o_buff_len + 1 - 1] = list(o)
                                a_buff[o_buff_len + 1 - 1] = list(a)
                                o_buff_len += 1
                        o = o2
                    print('\t  Episod-{}: Ep_Return={}, Ep_Len={}'.format(j, ep_ret, ep_len))
                    lstm_td3_POMDP_to_MDP[alg_name][task_name][pomdp_hyperparam][hist_len][seed][pomdp_type].append(ep_ret)
# Out:
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0']
# ********************************************************************
# 2021-01-22_22-45-30-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=734.0480778839966, Ep_Len=1000
# 	  Episod-1: Ep_Return=785.4689725251291, Ep_Len=1000
# 	  Episod-2: Ep_Return=565.3787576323598, Ep_Len=1000
# 	  Episod-3: Ep_Return=541.4516366653294, Ep_Len=1000
# 	  Episod-4: Ep_Return=631.243874315578, Ep_Len=1000
# 	  Episod-5: Ep_Return=847.5266077504841, Ep_Len=1000
# 	  Episod-6: Ep_Return=543.9931968314575, Ep_Len=1000
# 	  Episod-7: Ep_Return=636.7949402673753, Ep_Len=1000
# 	  Episod-8: Ep_Return=769.202678427197, Ep_Len=1000
# 	  Episod-9: Ep_Return=758.0814000771852, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return
Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=778.2503922770068, Ep_Len=1000
# 	  Episod-1: Ep_Return=657.3190554140128, Ep_Len=1000
# 	  Episod-2: Ep_Return=650.3844489061387, Ep_Len=1000
# 	  Episod-3: Ep_Return=786.9742782456457, Ep_Len=1000
# 	  Episod-4: Ep_Return=805.0177275306079, Ep_Len=1000
# 	  Episod-5: Ep_Return=840.4109147361333, Ep_Len=1000
# 	  Episod-6: Ep_Return=619.769523617113, Ep_Len=1000
# 	  Episod-7: Ep_Return=718.5573340727676, Ep_Len=1000
# 	  Episod-8: Ep_Return=763.3817127121481, Ep_Len=1000
# 	  Episod-9: Ep_Return=765.5368301573084, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=663.5611490977428, Ep_Len=1000
# 	  Episod-1: Ep_Return=774.8226675813083, Ep_Len=1000
# 	  Episod-2: Ep_Return=702.3273594105468, Ep_Len=1000
# 	  Episod-3: Ep_Return=810.5180511807596, Ep_Len=1000
# 	  Episod-4: Ep_Return=672.269354130365, Ep_Len=1000
# 	  Episod-5: Ep_Return=761.1036159984451, Ep_Len=1000
# 	  Episod-6: Ep_Return=771.803394763783, Ep_Len=1000
# 	  Episod-7: Ep_Return=816.1627060018383, Ep_Len=1000
# 	  Episod-8: Ep_Return=669.1547491064423, Ep_Len=1000
# 	  Episod-9: Ep_Return=675.7552710363083, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '3']
# ********************************************************************
# 2021-01-22_22-45-32-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_3_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2308.205701109025, Ep_Len=1000
# 	  Episod-1: Ep_Return=2337.1811000377684, Ep_Len=1000
# 	  Episod-2: Ep_Return=2339.0269047773504, Ep_Len=1000
# 	  Episod-3: Ep_Return=2323.3425284975992, Ep_Len=1000
# 	  Episod-4: Ep_Return=2328.6831732123505, Ep_Len=1000
# 	  Episod-5: Ep_Return=2331.7557316140046, Ep_Len=1000
# 	  Episod-6: Ep_Return=2325.208168930053, Ep_Len=1000
# 	  Episod-7: Ep_Return=2327.891017730215, Ep_Len=1000
# 	  Episod-8: Ep_Return=2328.066424435346, Ep_Len=1000
# 	  Episod-9: Ep_Return=2336.035003621439, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2199.4151198926966, Ep_Len=1000
# 	  Episod-1: Ep_Return=2179.230213331636, Ep_Len=1000
# 	  Episod-2: Ep_Return=2093.588856693944, Ep_Len=1000
# 	  Episod-3: Ep_Return=2198.858335496601, Ep_Len=1000
# 	  Episod-4: Ep_Return=2185.865688995469, Ep_Len=1000
# 	  Episod-5: Ep_Return=2219.9389547050014, Ep_Len=1000
# 	  Episod-6: Ep_Return=2178.387977465202, Ep_Len=1000
# 	  Episod-7: Ep_Return=2155.9224998182567, Ep_Len=1000
# 	  Episod-8: Ep_Return=2162.7824462362937, Ep_Len=1000
# 	  Episod-9: Ep_Return=2155.681413976436, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2137.18910106167, Ep_Len=1000
# 	  Episod-1: Ep_Return=2099.016288188493, Ep_Len=1000
# 	  Episod-2: Ep_Return=2168.9226966898223, Ep_Len=1000
# 	  Episod-3: Ep_Return=2126.218719385869, Ep_Len=1000
# 	  Episod-4: Ep_Return=2129.348925920039, Ep_Len=1000
# 	  Episod-5: Ep_Return=2113.1923197337837, Ep_Len=1000
# 	  Episod-6: Ep_Return=2111.8882583485965, Ep_Len=1000
# 	  Episod-7: Ep_Return=2120.9976513180764, Ep_Len=1000
# 	  Episod-8: Ep_Return=2130.2498000244836, Ep_Len=1000
# 	  Episod-9: Ep_Return=2147.7649480850755, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2127.8114258538335, Ep_Len=1000
# 	  Episod-1: Ep_Return=2127.0050722339247, Ep_Len=1000
# 	  Episod-2: Ep_Return=2161.324450417392, Ep_Len=1000
# 	  Episod-3: Ep_Return=2124.9250924080743, Ep_Len=1000
# 	  Episod-4: Ep_Return=2131.205311867152, Ep_Len=1000
# 	  Episod-5: Ep_Return=2149.7221211297738, Ep_Len=1000
# 	  Episod-6: Ep_Return=2158.4795897128683, Ep_Len=1000
# 	  Episod-7: Ep_Return=2098.02635930838, Ep_Len=1000
# 	  Episod-8: Ep_Return=2127.12389004328, Ep_Len=1000
# 	  Episod-9: Ep_Return=2136.956641948759, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '5']
# ********************************************************************
# 2021-01-22_22-57-58-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_5_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2410.003047545354, Ep_Len=1000
# 	  Episod-1: Ep_Return=2355.4271057102915, Ep_Len=1000
# 	  Episod-2: Ep_Return=2420.1213969583155, Ep_Len=1000
# 	  Episod-3: Ep_Return=2450.169082542668, Ep_Len=1000
# 	  Episod-4: Ep_Return=2440.205933917315, Ep_Len=1000
# 	  Episod-5: Ep_Return=2421.1108558549445, Ep_Len=1000
# 	  Episod-6: Ep_Return=2449.2223812177676, Ep_Len=1000
# 	  Episod-7: Ep_Return=2424.9161656236506, Ep_Len=1000
# 	  Episod-8: Ep_Return=2407.9562093318973, Ep_Len=1000
# 	  Episod-9: Ep_Return=2440.243083952522, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2206.1617749963943, Ep_Len=1000
# 	  Episod-1: Ep_Return=2197.455824164263, Ep_Len=1000
# 	  Episod-2: Ep_Return=2196.4841395158983, Ep_Len=1000
# 	  Episod-3: Ep_Return=2007.9210429127868, Ep_Len=1000
# 	  Episod-4: Ep_Return=2016.7511643645937, Ep_Len=1000
# 	  Episod-5: Ep_Return=2199.3804561441034, Ep_Len=1000
# 	  Episod-6: Ep_Return=2005.5711010020113, Ep_Len=1000
# 	  Episod-7: Ep_Return=2139.000137579337, Ep_Len=1000
# 	  Episod-8: Ep_Return=2226.7326621029615, Ep_Len=1000
# 	  Episod-9: Ep_Return=2178.1910755864415, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1990.7905848947487, Ep_Len=1000
# 	  Episod-1: Ep_Return=2035.2198009341482, Ep_Len=1000
# 	  Episod-2: Ep_Return=2006.0999510205547, Ep_Len=1000
# 	  Episod-3: Ep_Return=1957.173552348615, Ep_Len=1000
# 	  Episod-4: Ep_Return=2002.366150449657, Ep_Len=1000
# 	  Episod-5: Ep_Return=1948.3169482883914, Ep_Len=1000
# 	  Episod-6: Ep_Return=1985.5580152576476, Ep_Len=1000
# 	  Episod-7: Ep_Return=2020.1907100935834, Ep_Len=1000
# 	  Episod-8: Ep_Return=2046.8465446263683, Ep_Len=1000
# 	  Episod-9: Ep_Return=1935.2016346692963, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_1_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '1', '1']
# ********************************************************************
# 2021-01-22_23-07-58-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_1_1_s1
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=959.2737261287969, Ep_Len=1000
# 	  Episod-1: Ep_Return=923.2736897823935, Ep_Len=1000
# 	  Episod-2: Ep_Return=982.7870222662166, Ep_Len=1000
# 	  Episod-3: Ep_Return=989.3161360334096, Ep_Len=1000
# 	  Episod-4: Ep_Return=893.2031287802339, Ep_Len=1000
# 	  Episod-5: Ep_Return=755.2602142218717, Ep_Len=1000
# 	  Episod-6: Ep_Return=701.071095732736, Ep_Len=1000
# 	  Episod-7: Ep_Return=902.3304892044322, Ep_Len=1000
# 	  Episod-8: Ep_Return=906.2196741323247, Ep_Len=1000
# 	  Episod-9: Ep_Return=893.21313480118, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=792.6899378307484, Ep_Len=1000
# 	  Episod-1: Ep_Return=794.5101331429653, Ep_Len=1000
# 	  Episod-2: Ep_Return=748.8666881088342, Ep_Len=1000
# 	  Episod-3: Ep_Return=952.8316129913072, Ep_Len=1000
# 	  Episod-4: Ep_Return=682.9354462629506, Ep_Len=1000
# 	  Episod-5: Ep_Return=692.0057022531336, Ep_Len=1000
# 	  Episod-6: Ep_Return=812.0707926806614, Ep_Len=1000
# 	  Episod-7: Ep_Return=915.0853504449659, Ep_Len=1000
# 	  Episod-8: Ep_Return=927.7553781049137, Ep_Len=1000
# 	  Episod-9: Ep_Return=761.565370376595, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=798.5009287618776, Ep_Len=1000
# 	  Episod-1: Ep_Return=755.7341879185121, Ep_Len=1000
# 	  Episod-2: Ep_Return=616.773000184684, Ep_Len=1000
# 	  Episod-3: Ep_Return=842.0867716149113, Ep_Len=1000
# 	  Episod-4: Ep_Return=684.7434941092278, Ep_Len=1000
# 	  Episod-5: Ep_Return=786.3202751691489, Ep_Len=1000
# 	  Episod-6: Ep_Return=780.1537608656836, Ep_Len=1000
# 	  Episod-7: Ep_Return=860.2243363759402, Ep_Len=1000
# 	  Episod-8: Ep_Return=894.2363842560072, Ep_Len=1000
# 	  Episod-9: Ep_Return=730.700065479862, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=824.5471256360796, Ep_Len=1000
# 	  Episod-1: Ep_Return=726.4220368867831, Ep_Len=1000
# 	  Episod-2: Ep_Return=858.3858187619786, Ep_Len=1000
# 	  Episod-3: Ep_Return=770.5130349903673, Ep_Len=1000
# 	  Episod-4: Ep_Return=858.3733941514773, Ep_Len=1000
# 	  Episod-5: Ep_Return=706.5184608236506, Ep_Len=1000
# 	  Episod-6: Ep_Return=687.2448596749193, Ep_Len=1000
# 	  Episod-7: Ep_Return=773.246271663457, Ep_Len=1000
# 	  Episod-8: Ep_Return=663.145743942994, Ep_Len=1000
# 	  Episod-9: Ep_Return=791.3830532412882, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_1_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '1', '3']
# ********************************************************************
# 2021-01-22_23-07-58-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_1_3_s1
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1933.7740788489484, Ep_Len=1000
# 	  Episod-1: Ep_Return=1971.0040155493432, Ep_Len=1000
# 	  Episod-2: Ep_Return=1956.6493800299236, Ep_Len=1000
# 	  Episod-3: Ep_Return=1982.6482394165068, Ep_Len=1000
# 	  Episod-4: Ep_Return=1954.8770110068897, Ep_Len=1000
# 	  Episod-5: Ep_Return=1952.0461143292985, Ep_Len=1000
# 	  Episod-6: Ep_Return=1967.3074804420655, Ep_Len=1000
# 	  Episod-7: Ep_Return=1942.2851167486094, Ep_Len=1000
# 	  Episod-8: Ep_Return=1969.805400251437, Ep_Len=1000
# 	  Episod-9: Ep_Return=1962.7713046615677, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1699.8564860144897, Ep_Len=1000
# 	  Episod-1: Ep_Return=1660.7635133141407, Ep_Len=1000
# 	  Episod-2: Ep_Return=1683.8437491431005, Ep_Len=1000
# 	  Episod-3: Ep_Return=1690.676022153382, Ep_Len=1000
# 	  Episod-4: Ep_Return=1661.932584552873, Ep_Len=1000
# 	  Episod-5: Ep_Return=1706.7690573108464, Ep_Len=1000
# 	  Episod-6: Ep_Return=1674.1867745689142, Ep_Len=1000
# 	  Episod-7: Ep_Return=1690.0653198864861, Ep_Len=1000
# 	  Episod-8: Ep_Return=1706.2925378184352, Ep_Len=1000
# 	  Episod-9: Ep_Return=1694.7508945139905, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1775.1986121597913, Ep_Len=1000
# 	  Episod-1: Ep_Return=1787.6588402245216, Ep_Len=1000
# 	  Episod-2: Ep_Return=1789.4763653450234, Ep_Len=1000
# 	  Episod-3: Ep_Return=1781.9972685669245, Ep_Len=1000
# 	  Episod-4: Ep_Return=1792.487674122961, Ep_Len=1000
# 	  Episod-5: Ep_Return=1783.614654856928, Ep_Len=1000
# 	  Episod-6: Ep_Return=1756.120246165795, Ep_Len=1000
# 	  Episod-7: Ep_Return=1784.4318545061672, Ep_Len=1000
# 	  Episod-8: Ep_Return=1803.4436670035516, Ep_Len=1000
# 	  Episod-9: Ep_Return=1786.3495626924118, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1705.0779693070556, Ep_Len=1000
# 	  Episod-1: Ep_Return=1719.5587481696102, Ep_Len=1000
# 	  Episod-2: Ep_Return=1723.9331381823042, Ep_Len=1000
# 	  Episod-3: Ep_Return=1712.6743558098265, Ep_Len=1000
# 	  Episod-4: Ep_Return=1734.649796609036, Ep_Len=1000
# 	  Episod-5: Ep_Return=1727.3553890406874, Ep_Len=1000
# 	  Episod-6: Ep_Return=1674.5246733774738, Ep_Len=1000
# 	  Episod-7: Ep_Return=1724.108981989738, Ep_Len=1000
# 	  Episod-8: Ep_Return=1699.355271035926, Ep_Len=1000
# 	  Episod-9: Ep_Return=1707.7718811668942, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_1_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '1', '5']
# ********************************************************************
# 2021-01-22_23-18-17-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_1_5_s1
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2210.0963614218717, Ep_Len=1000
# 	  Episod-1: Ep_Return=2185.37136135271, Ep_Len=1000
# 	  Episod-2: Ep_Return=2215.498050312027, Ep_Len=1000
# 	  Episod-3: Ep_Return=2214.2305388361456, Ep_Len=1000
# 	  Episod-4: Ep_Return=2176.0085187767677, Ep_Len=1000
# 	  Episod-5: Ep_Return=2211.325633737229, Ep_Len=1000
# 	  Episod-6: Ep_Return=2215.747651774281, Ep_Len=1000
# 	  Episod-7: Ep_Return=2214.4292444464913, Ep_Len=1000
# 	  Episod-8: Ep_Return=2203.014932726286, Ep_Len=1000
# 	  Episod-9: Ep_Return=2216.7973949901566, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=538.3081264519573, Ep_Len=1000
# 	  Episod-1: Ep_Return=527.8736219560112, Ep_Len=1000
# 	  Episod-2: Ep_Return=523.3691627097434, Ep_Len=1000
# 	  Episod-3: Ep_Return=679.9772584528417, Ep_Len=1000
# 	  Episod-4: Ep_Return=564.0010984792772, Ep_Len=1000
# 	  Episod-5: Ep_Return=501.3952269684166, Ep_Len=1000
# 	  Episod-6: Ep_Return=384.2804935993093, Ep_Len=1000
# 	  Episod-7: Ep_Return=389.0493394316891, Ep_Len=1000
# 	  Episod-8: Ep_Return=682.7794167524423, Ep_Len=1000
# 	  Episod-9: Ep_Return=400.13078258317455, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=401.3646755458819, Ep_Len=1000
# 	  Episod-1: Ep_Return=464.6634174781339, Ep_Len=1000
# 	  Episod-2: Ep_Return=593.3958049843192, Ep_Len=1000
# 	  Episod-3: Ep_Return=535.4748927650442, Ep_Len=1000
# 	  Episod-4: Ep_Return=446.6441566707975, Ep_Len=1000
# 	  Episod-5: Ep_Return=448.4349053758075, Ep_Len=1000
# 	  Episod-6: Ep_Return=499.6149930339677, Ep_Len=1000
# 	  Episod-7: Ep_Return=536.6264071071267, Ep_Len=1000
# 	  Episod-8: Ep_Return=518.8920946741483, Ep_Len=1000
# 	  Episod-9: Ep_Return=481.8999630372261, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=344.3600687037472, Ep_Len=1000
# 	  Episod-1: Ep_Return=455.1365577441726, Ep_Len=1000
# 	  Episod-2: Ep_Return=538.5356585405982, Ep_Len=1000
# 	  Episod-3: Ep_Return=413.521980494798, Ep_Len=1000
# 	  Episod-4: Ep_Return=538.5072317062445, Ep_Len=1000
# 	  Episod-5: Ep_Return=358.11404252604575, Ep_Len=1000
# 	  Episod-6: Ep_Return=545.044804501472, Ep_Len=1000
# 	  Episod-7: Ep_Return=549.0949728382902, Ep_Len=1000
# 	  Episod-8: Ep_Return=634.783770000591, Ep_Len=1000
# 	  Episod-9: Ep_Return=551.2154745988105, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '2', '1']
# ********************************************************************
# 2021-01-22_23-28-52-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_1_s2
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=880.1634208751116, Ep_Len=1000
# 	  Episod-1: Ep_Return=742.544832635279, Ep_Len=1000
# 	  Episod-2: Ep_Return=771.5765399688247, Ep_Len=1000
# 	  Episod-3: Ep_Return=792.8013049261174, Ep_Len=1000
# 	  Episod-4: Ep_Return=976.7764962977298, Ep_Len=1000
# 	  Episod-5: Ep_Return=753.2640497996547, Ep_Len=1000
# 	  Episod-6: Ep_Return=843.2483784270293, Ep_Len=1000
# 	  Episod-7: Ep_Return=565.9100515335837, Ep_Len=1000
# 	  Episod-8: Ep_Return=775.4721510448998, Ep_Len=1000
# 	  Episod-9: Ep_Return=891.8045868142848, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=851.351236116984, Ep_Len=1000
# 	  Episod-1: Ep_Return=722.2317953685841, Ep_Len=1000
# 	  Episod-2: Ep_Return=873.2378048219597, Ep_Len=1000
# 	  Episod-3: Ep_Return=870.7175368699371, Ep_Len=1000
# 	  Episod-4: Ep_Return=806.3498380007217, Ep_Len=1000
# 	  Episod-5: Ep_Return=811.175738472154, Ep_Len=1000
# 	  Episod-6: Ep_Return=751.0567366917949, Ep_Len=1000
# 	  Episod-7: Ep_Return=770.2171389939781, Ep_Len=1000
# 	  Episod-8: Ep_Return=754.1897990230067, Ep_Len=1000
# 	  Episod-9: Ep_Return=824.621711672154, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=869.6259640868751, Ep_Len=1000
# 	  Episod-1: Ep_Return=744.0354300267784, Ep_Len=1000
# 	  Episod-2: Ep_Return=793.4124693195073, Ep_Len=1000
# 	  Episod-3: Ep_Return=780.1465840286395, Ep_Len=1000
# 	  Episod-4: Ep_Return=643.1466502330892, Ep_Len=1000
# 	  Episod-5: Ep_Return=806.307813950431, Ep_Len=1000
# 	  Episod-6: Ep_Return=837.6597097642399, Ep_Len=1000
# 	  Episod-7: Ep_Return=749.9914664132345, Ep_Len=1000
# 	  Episod-8: Ep_Return=729.9645559451368, Ep_Len=1000
# 	  Episod-9: Ep_Return=729.4643200022996, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=750.5438046238538, Ep_Len=1000
# 	  Episod-1: Ep_Return=690.7724409244577, Ep_Len=1000
# 	  Episod-2: Ep_Return=659.7767232047796, Ep_Len=1000
# 	  Episod-3: Ep_Return=586.4047242432135, Ep_Len=1000
# 	  Episod-4: Ep_Return=658.2983580778774, Ep_Len=1000
# 	  Episod-5: Ep_Return=779.8747888848577, Ep_Len=1000
# 	  Episod-6: Ep_Return=601.5956877024552, Ep_Len=1000
# 	  Episod-7: Ep_Return=732.6795807381277, Ep_Len=1000
# 	  Episod-8: Ep_Return=640.5762454390035, Ep_Len=1000
# 	  Episod-9: Ep_Return=609.1808600260109, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '2', '3']
# ********************************************************************
# 2021-01-22_23-28-52-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_3_s2
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2465.7630187428545, Ep_Len=1000
# 	  Episod-1: Ep_Return=2489.3184233839497, Ep_Len=1000
# 	  Episod-2: Ep_Return=2507.0588975978817, Ep_Len=1000
# 	  Episod-3: Ep_Return=2541.208015086786, Ep_Len=1000
# 	  Episod-4: Ep_Return=2514.5642467067782, Ep_Len=1000
# 	  Episod-5: Ep_Return=2506.873945666539, Ep_Len=1000
# 	  Episod-6: Ep_Return=2549.6445901963325, Ep_Len=1000
# 	  Episod-7: Ep_Return=2424.802809131197, Ep_Len=1000
# 	  Episod-8: Ep_Return=2517.7569555852365, Ep_Len=1000
# 	  Episod-9: Ep_Return=2473.5118343794, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2262.7936112439165, Ep_Len=1000
# 	  Episod-1: Ep_Return=2341.3745320931744, Ep_Len=1000
# 	  Episod-2: Ep_Return=2282.9579234480248, Ep_Len=1000
# 	  Episod-3: Ep_Return=2243.6699953453985, Ep_Len=1000
# 	  Episod-4: Ep_Return=2168.4367162394888, Ep_Len=1000
# 	  Episod-5: Ep_Return=2075.2113520079506, Ep_Len=1000
# 	  Episod-6: Ep_Return=2298.279455512916, Ep_Len=1000
# 	  Episod-7: Ep_Return=2306.318563670611, Ep_Len=1000
# 	  Episod-8: Ep_Return=2125.010988119061, Ep_Len=1000
# 	  Episod-9: Ep_Return=2158.684595494902, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2270.5880966603595, Ep_Len=1000
# 	  Episod-1: Ep_Return=2228.2439196487408, Ep_Len=1000
# 	  Episod-2: Ep_Return=2280.7354396305086, Ep_Len=1000
# 	  Episod-3: Ep_Return=2241.3727017602073, Ep_Len=1000
# 	  Episod-4: Ep_Return=2266.5164573413294, Ep_Len=1000
# 	  Episod-5: Ep_Return=2312.89704443545, Ep_Len=1000
# 	  Episod-6: Ep_Return=2221.270463241441, Ep_Len=1000
# 	  Episod-7: Ep_Return=2197.47385651699, Ep_Len=1000
# 	  Episod-8: Ep_Return=2289.450052401567, Ep_Len=1000
# 	  Episod-9: Ep_Return=2274.9852387427395, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2239.8110437920914, Ep_Len=1000
# 	  Episod-1: Ep_Return=2127.3438410681983, Ep_Len=1000
# 	  Episod-2: Ep_Return=2148.49376521232, Ep_Len=1000
# 	  Episod-3: Ep_Return=2184.771754177148, Ep_Len=1000
# 	  Episod-4: Ep_Return=2172.7017074661826, Ep_Len=1000
# 	  Episod-5: Ep_Return=2213.2159815799287, Ep_Len=1000
# 	  Episod-6: Ep_Return=2250.602558836736, Ep_Len=1000
# 	  Episod-7: Ep_Return=2168.9938550674833, Ep_Len=1000
# 	  Episod-8: Ep_Return=2142.9942819056505, Ep_Len=1000
# 	  Episod-9: Ep_Return=2201.611433321882, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '2', '5']
# ********************************************************************
# 2021-01-22_23-28-52-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_5_s2
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2124.496451635149, Ep_Len=1000
# 	  Episod-1: Ep_Return=2114.2891126664094, Ep_Len=1000
# 	  Episod-2: Ep_Return=2143.6320771732076, Ep_Len=1000
# 	  Episod-3: Ep_Return=2138.898000420856, Ep_Len=1000
# 	  Episod-4: Ep_Return=2086.735818315866, Ep_Len=1000
# 	  Episod-5: Ep_Return=2113.207659373994, Ep_Len=1000
# 	  Episod-6: Ep_Return=2143.905248003713, Ep_Len=1000
# 	  Episod-7: Ep_Return=2080.5929179108493, Ep_Len=1000
# 	  Episod-8: Ep_Return=2097.068229529488, Ep_Len=1000
# 	  Episod-9: Ep_Return=2124.657531420696, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1936.4029034196553, Ep_Len=1000
# 	  Episod-1: Ep_Return=2011.1440655745819, Ep_Len=1000
# 	  Episod-2: Ep_Return=2059.535405358782, Ep_Len=1000
# 	  Episod-3: Ep_Return=1979.2608470968164, Ep_Len=1000
# 	  Episod-4: Ep_Return=2024.7807259219867, Ep_Len=1000
# 	  Episod-5: Ep_Return=1970.7907664674171, Ep_Len=1000
# 	  Episod-6: Ep_Return=1964.7468410935182, Ep_Len=1000
# 	  Episod-7: Ep_Return=2006.5322577201496, Ep_Len=1000
# 	  Episod-8: Ep_Return=2006.0757045632506, Ep_Len=1000
# 	  Episod-9: Ep_Return=2032.0118636306815, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1964.7411022226336, Ep_Len=1000
# 	  Episod-1: Ep_Return=2034.0401384389386, Ep_Len=1000
# 	  Episod-2: Ep_Return=2037.0359838914178, Ep_Len=1000
# 	  Episod-3: Ep_Return=1947.7375765590405, Ep_Len=1000
# 	  Episod-4: Ep_Return=1920.4700807520994, Ep_Len=1000
# 	  Episod-5: Ep_Return=1969.6287119355866, Ep_Len=1000
# 	  Episod-6: Ep_Return=1999.408827002479, Ep_Len=1000
# 	  Episod-7: Ep_Return=1981.0260210215451, Ep_Len=1000
# 	  Episod-8: Ep_Return=1945.2429280065512, Ep_Len=1000
# 	  Episod-9: Ep_Return=1917.3978312225604, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1958.4414632653989, Ep_Len=1000
# 	  Episod-1: Ep_Return=1908.625975407084, Ep_Len=1000
# 	  Episod-2: Ep_Return=1914.1040989910748, Ep_Len=1000
# 	  Episod-3: Ep_Return=1953.9870870313562, Ep_Len=1000
# 	  Episod-4: Ep_Return=1948.8779268775236, Ep_Len=1000
# 	  Episod-5: Ep_Return=1948.6784132808941, Ep_Len=1000
# 	  Episod-6: Ep_Return=1912.1631824880415, Ep_Len=1000
# 	  Episod-7: Ep_Return=1859.183173628099, Ep_Len=1000
# 	  Episod-8: Ep_Return=1947.3273006050297, Ep_Len=1000
# 	  Episod-9: Ep_Return=1963.9970728185283, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_3_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '3', '0']
# ********************************************************************
# 2021-01-22_23-33-52-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_3_0_s3
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=611.4277686463759, Ep_Len=1000
# 	  Episod-1: Ep_Return=616.9972219399061, Ep_Len=1000
# 	  Episod-2: Ep_Return=622.8198877292591, Ep_Len=1000
# 	  Episod-3: Ep_Return=621.6240910836838, Ep_Len=1000
# 	  Episod-4: Ep_Return=655.0165636268908, Ep_Len=1000
# 	  Episod-5: Ep_Return=620.4871263231994, Ep_Len=1000
# 	  Episod-6: Ep_Return=706.6584804478028, Ep_Len=1000
# 	  Episod-7: Ep_Return=648.5343502826194, Ep_Len=1000
# 	  Episod-8: Ep_Return=628.2397336831525, Ep_Len=1000
# 	  Episod-9: Ep_Return=621.7431531164941, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=722.1912412824079, Ep_Len=1000
# 	  Episod-1: Ep_Return=623.6235399596936, Ep_Len=1000
# 	  Episod-2: Ep_Return=646.7358964857035, Ep_Len=1000
# 	  Episod-3: Ep_Return=623.827813223642, Ep_Len=1000
# 	  Episod-4: Ep_Return=620.7760731603192, Ep_Len=1000
# 	  Episod-5: Ep_Return=843.0195326301746, Ep_Len=1000
# 	  Episod-6: Ep_Return=625.7367646415253, Ep_Len=1000
# 	  Episod-7: Ep_Return=629.1209024902065, Ep_Len=1000
# 	  Episod-8: Ep_Return=626.1508086135183, Ep_Len=1000
# 	  Episod-9: Ep_Return=661.7611005100505, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=742.7481188916956, Ep_Len=1000
# 	  Episod-1: Ep_Return=737.7905517171066, Ep_Len=1000
# 	  Episod-2: Ep_Return=752.7444032797954, Ep_Len=1000
# 	  Episod-3: Ep_Return=721.6875423832597, Ep_Len=1000
# 	  Episod-4: Ep_Return=739.2527997326691, Ep_Len=1000
# 	  Episod-5: Ep_Return=680.5267624319125, Ep_Len=1000
# 	  Episod-6: Ep_Return=553.6584332331253, Ep_Len=1000
# 	  Episod-7: Ep_Return=743.459684585565, Ep_Len=1000
# 	  Episod-8: Ep_Return=737.7240053659108, Ep_Len=1000
# 	  Episod-9: Ep_Return=712.5722223996288, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=609.2772758588497, Ep_Len=1000
# 	  Episod-1: Ep_Return=556.3375442624643, Ep_Len=1000
# 	  Episod-2: Ep_Return=723.2608498195264, Ep_Len=1000
# 	  Episod-3: Ep_Return=662.7186231686702, Ep_Len=1000
# 	  Episod-4: Ep_Return=490.0540568499087, Ep_Len=1000
# 	  Episod-5: Ep_Return=671.9476300783367, Ep_Len=1000
# 	  Episod-6: Ep_Return=621.6960428872459, Ep_Len=1000
# 	  Episod-7: Ep_Return=637.2678620480025, Ep_Len=1000
# 	  Episod-8: Ep_Return=633.3518280369894, Ep_Len=1000
# 	  Episod-9: Ep_Return=610.9994115707838, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_3_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '3', '1']
# ********************************************************************
# 2021-01-22_23-40-56-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_3_1_s3
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=850.8580187345526, Ep_Len=1000
# 	  Episod-1: Ep_Return=896.3243120414196, Ep_Len=1000
# 	  Episod-2: Ep_Return=604.268667234904, Ep_Len=1000
# 	  Episod-3: Ep_Return=983.702334601047, Ep_Len=1000
# 	  Episod-4: Ep_Return=848.172714603558, Ep_Len=1000
# 	  Episod-5: Ep_Return=901.8705585184997, Ep_Len=1000
# 	  Episod-6: Ep_Return=1124.6908287221079, Ep_Len=1000
# 	  Episod-7: Ep_Return=913.4375058025491, Ep_Len=1000
# 	  Episod-8: Ep_Return=721.7113054763885, Ep_Len=1000
# 	  Episod-9: Ep_Return=851.3242664968741, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1049.82531741069, Ep_Len=1000
# 	  Episod-1: Ep_Return=1185.1987437227797, Ep_Len=1000
# 	  Episod-2: Ep_Return=669.8518551117231, Ep_Len=1000
# 	  Episod-3: Ep_Return=1018.8300779954963, Ep_Len=1000
# 	  Episod-4: Ep_Return=1005.9984219066682, Ep_Len=1000
# 	  Episod-5: Ep_Return=1035.7092979638076, Ep_Len=1000
# 	  Episod-6: Ep_Return=1155.865312226584, Ep_Len=1000
# 	  Episod-7: Ep_Return=1144.5488167992128, Ep_Len=1000
# 	  Episod-8: Ep_Return=906.4001237507122, Ep_Len=1000
# 	  Episod-9: Ep_Return=1172.4531155268758, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=839.3821420677064, Ep_Len=1000
# 	  Episod-1: Ep_Return=697.1017429812583, Ep_Len=1000
# 	  Episod-2: Ep_Return=783.3072592720512, Ep_Len=1000
# 	  Episod-3: Ep_Return=753.5354557819728, Ep_Len=1000
# 	  Episod-4: Ep_Return=774.658021785393, Ep_Len=1000
# 	  Episod-5: Ep_Return=989.8067962554144, Ep_Len=1000
# 	  Episod-6: Ep_Return=794.7656441411482, Ep_Len=1000
# 	  Episod-7: Ep_Return=794.4411363935226, Ep_Len=1000
# 	  Episod-8: Ep_Return=865.9204406322436, Ep_Len=1000
# 	  Episod-9: Ep_Return=889.8208306383008, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=832.9733599950716, Ep_Len=1000
# 	  Episod-1: Ep_Return=822.2754546961697, Ep_Len=1000
# 	  Episod-2: Ep_Return=794.6282096729758, Ep_Len=1000
# 	  Episod-3: Ep_Return=726.515635847292, Ep_Len=1000
# 	  Episod-4: Ep_Return=763.0349035894537, Ep_Len=1000
# 	  Episod-5: Ep_Return=748.9064222331139, Ep_Len=1000
# 	  Episod-6: Ep_Return=767.4104697891961, Ep_Len=1000
# 	  Episod-7: Ep_Return=749.0260056472624, Ep_Len=1000
# 	  Episod-8: Ep_Return=759.0738080323356, Ep_Len=1000
# 	  Episod-9: Ep_Return=801.0992782975833, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_3_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '3', '3']
# ********************************************************************
# 2021-01-22_23-40-56-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_3_3_s3
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=2542.8635049130103, Ep_Len=1000
# 	  Episod-1: Ep_Return=2457.32329866858, Ep_Len=1000
# 	  Episod-2: Ep_Return=2485.79520732977, Ep_Len=1000
# 	  Episod-3: Ep_Return=2484.034914478677, Ep_Len=1000
# 	  Episod-4: Ep_Return=2467.5131555706153, Ep_Len=1000
# 	  Episod-5: Ep_Return=2523.824262680404, Ep_Len=1000
# 	  Episod-6: Ep_Return=2448.4881368141787, Ep_Len=1000
# 	  Episod-7: Ep_Return=2479.8179979348906, Ep_Len=1000
# 	  Episod-8: Ep_Return=2498.841920622621, Ep_Len=1000
# 	  Episod-9: Ep_Return=2537.9424071607114, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1875.552531641298, Ep_Len=1000
# 	  Episod-1: Ep_Return=1863.9614896980484, Ep_Len=1000
# 	  Episod-2: Ep_Return=1915.0678889084102, Ep_Len=1000
# 	  Episod-3: Ep_Return=1876.3633265851447, Ep_Len=1000
# 	  Episod-4: Ep_Return=1893.29230704161, Ep_Len=1000
# 	  Episod-5: Ep_Return=1873.2028538257193, Ep_Len=1000
# 	  Episod-6: Ep_Return=1868.220654138926, Ep_Len=1000
# 	  Episod-7: Ep_Return=1881.3916754596357, Ep_Len=1000
# 	  Episod-8: Ep_Return=1838.091835690307, Ep_Len=1000
# 	  Episod-9: Ep_Return=1866.676628979699, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1830.8993378166103, Ep_Len=1000
# 	  Episod-1: Ep_Return=1809.419306311915, Ep_Len=1000
# 	  Episod-2: Ep_Return=1858.7968912826861, Ep_Len=1000
# 	  Episod-3: Ep_Return=1831.9999972590642, Ep_Len=1000
# 	  Episod-4: Ep_Return=1840.8185499153099, Ep_Len=1000
# 	  Episod-5: Ep_Return=1846.5425370412943, Ep_Len=1000
# 	  Episod-6: Ep_Return=1860.8065079189046, Ep_Len=1000
# 	  Episod-7: Ep_Return=1850.1408135990823, Ep_Len=1000
# 	  Episod-8: Ep_Return=1839.4573395032867, Ep_Len=1000
# 	  Episod-9: Ep_Return=1833.072478201614, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=1757.2808550360958, Ep_Len=1000
# 	  Episod-1: Ep_Return=1768.4680201455524, Ep_Len=1000
# 	  Episod-2: Ep_Return=1734.541759915429, Ep_Len=1000
# 	  Episod-3: Ep_Return=1749.4481223438754, Ep_Len=1000
# 	  Episod-4: Ep_Return=1751.189296723612, Ep_Len=1000
# 	  Episod-5: Ep_Return=1701.1113383458307, Ep_Len=1000
# 	  Episod-6: Ep_Return=1739.0095853555708, Ep_Len=1000
# 	  Episod-7: Ep_Return=1737.3006820033484, Ep_Len=1000
# 	  Episod-8: Ep_Return=1744.6223683202406, Ep_Len=1000
# 	  Episod-9: Ep_Return=1721.099535043353, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_random_noise_0_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'random', 'noise', '0', '0']
# ********************************************************************
# 2021-01-22_22-57-58-LSTM-TD3_AntPyBulletEnv-v0_True_random_noise_0_0_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=751.7326551449394, Ep_Len=1000
# 	  Episod-1: Ep_Return=876.4781917630793, Ep_Len=1000
# 	  Episod-2: Ep_Return=897.8042957909691, Ep_Len=1000
# 	  Episod-3: Ep_Return=865.0991964952559, Ep_Len=1000
# 	  Episod-4: Ep_Return=871.284138030687, Ep_Len=1000
# 	  Episod-5: Ep_Return=730.4835828016121, Ep_Len=1000
# 	  Episod-6: Ep_Return=940.191726592808, Ep_Len=1000
# 	  Episod-7: Ep_Return=913.1950475699037, Ep_Len=1000
# 	  Episod-8: Ep_Return=918.2011747104817, Ep_Len=1000
# 	  Episod-9: Ep_Return=931.2840192491763, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=831.2799364435252, Ep_Len=1000
# 	  Episod-1: Ep_Return=757.1098661365329, Ep_Len=1000
# 	  Episod-2: Ep_Return=922.181448874483, Ep_Len=1000
# 	  Episod-3: Ep_Return=884.9035999013357, Ep_Len=1000
# 	  Episod-4: Ep_Return=833.314413676225, Ep_Len=1000
# 	  Episod-5: Ep_Return=892.5738045795786, Ep_Len=1000
# 	  Episod-6: Ep_Return=846.7084636642088, Ep_Len=1000
# 	  Episod-7: Ep_Return=801.9838256561512, Ep_Len=1000
# 	  Episod-8: Ep_Return=840.56961974134, Ep_Len=1000
# 	  Episod-9: Ep_Return=853.7010222745469, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=792.9804718941928, Ep_Len=1000
# 	  Episod-1: Ep_Return=802.291897396388, Ep_Len=1000
# 	  Episod-2: Ep_Return=844.2141837316001, Ep_Len=1000
# 	  Episod-3: Ep_Return=867.3351611158547, Ep_Len=1000
# 	  Episod-4: Ep_Return=825.7505748220958, Ep_Len=1000
# 	  Episod-5: Ep_Return=820.7766454924835, Ep_Len=1000
# 	  Episod-6: Ep_Return=845.5576315969405, Ep_Len=1000
# 	  Episod-7: Ep_Return=818.7671613267272, Ep_Len=1000
# 	  Episod-8: Ep_Return=771.2783707401061, Ep_Len=1000
# 	  Episod-9: Ep_Return=804.0116637612558, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=759.3390506492836, Ep_Len=1000
# 	  Episod-1: Ep_Return=750.1906545857308, Ep_Len=1000
# 	  Episod-2: Ep_Return=760.9504842380552, Ep_Len=1000
# 	  Episod-3: Ep_Return=737.3040691775401, Ep_Len=1000
# 	  Episod-4: Ep_Return=714.2478517348376, Ep_Len=1000
# 	  Episod-5: Ep_Return=741.7771882638867, Ep_Len=1000
# 	  Episod-6: Ep_Return=753.7292268738753, Ep_Len=1000
# 	  Episod-7: Ep_Return=757.5849215945085, Ep_Len=1000
# 	  Episod-8: Ep_Return=734.1718741168418, Ep_Len=1000
# 	  Episod-9: Ep_Return=764.3819050469842, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_random_noise_0_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'random', 'noise', '0', '1']
# ********************************************************************
# 2021-01-22_22-57-58-LSTM-TD3_AntPyBulletEnv-v0_True_random_noise_0_1_s0
# WalkerBase::__init__
# 	MDP
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=293.9614597256292, Ep_Len=1000
# 	  Episod-1: Ep_Return=198.31145330456508, Ep_Len=1000
# 	  Episod-2: Ep_Return=189.05060359215926, Ep_Len=1000
# 	  Episod-3: Ep_Return=294.8092613176701, Ep_Len=1000
# 	  Episod-4: Ep_Return=196.6182914458334, Ep_Len=1000
# 	  Episod-5: Ep_Return=297.794194008222, Ep_Len=1000
# 	  Episod-6: Ep_Return=279.2520259214467, Ep_Len=1000
# 	  Episod-7: Ep_Return=297.93553610378996, Ep_Len=1000
# 	  Episod-8: Ep_Return=198.11351724185533, Ep_Len=1000
# 	  Episod-9: Ep_Return=200.4905613348776, Ep_Len=1000
# 	flickering
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=297.18824597140747, Ep_Len=1000
# 	  Episod-1: Ep_Return=297.2571878348591, Ep_Len=1000
# 	  Episod-2: Ep_Return=197.07925766521097, Ep_Len=1000
# 	  Episod-3: Ep_Return=295.72736982071035, Ep_Len=1000
# 	  Episod-4: Ep_Return=299.07565072841805, Ep_Len=1000
# 	  Episod-5: Ep_Return=190.93993731296123, Ep_Len=1000
# 	  Episod-6: Ep_Return=188.7602133395492, Ep_Len=1000
# 	  Episod-7: Ep_Return=298.08844370231355, Ep_Len=1000
# 	  Episod-8: Ep_Return=213.08577461108123, Ep_Len=1000
# 	  Episod-9: Ep_Return=296.04913431730495, Ep_Len=1000
# 	random_noise
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=290.2934133482634, Ep_Len=1000
# 	  Episod-1: Ep_Return=197.62396833008265, Ep_Len=1000
# 	  Episod-2: Ep_Return=262.4700819947084, Ep_Len=1000
# 	  Episod-3: Ep_Return=295.7635974112808, Ep_Len=1000
# 	  Episod-4: Ep_Return=296.77269032576555, Ep_Len=1000
# 	  Episod-5: Ep_Return=296.82016037956026, Ep_Len=1000
# 	  Episod-6: Ep_Return=300.2371262864775, Ep_Len=1000
# 	  Episod-7: Ep_Return=195.8332588836539, Ep_Len=1000
# 	  Episod-8: Ep_Return=195.33810091532104, Ep_Len=1000
# 	  Episod-9: Ep_Return=203.66417535000647, Ep_Len=1000
# 	random_sensor_missing
# WalkerBase::__init__
# options=
# 	  Episod-0: Ep_Return=201.57125998856213, Ep_Len=1000
# 	  Episod-1: Ep_Return=298.4345069526445, Ep_Len=1000
# 	  Episod-2: Ep_Return=293.9733612837194, Ep_Len=1000
# 	  Episod-3: Ep_Return=294.4367651283679, Ep_Len=1000
# 	  Episod-4: Ep_Return=298.94052820040207, Ep_Len=1000
# 	  Episod-5: Ep_Return=198.30123694512892, Ep_Len=1000
# 	  Episod-6: Ep_Return=298.36997520662385, Ep_Len=1000
# 	  Episod-7: Ep_Return=291.9259887488305, Ep_Len=1000
# 	  Episod-8: Ep_Return=194.88010974656532, Ep_Len=1000
# 	  Episod-9: Ep_Return=297.5556070740114, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_random_noise_0_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'random', 'noise', '0', '3']
# ********************************************************************
# 2021-01-22_22-57-58-LSTM-TD3_AntPyBulletEnv-v0_True_random_noise_0_3_s0
# WalkerBase::__init__
# 	MDP
# ...
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'noise', '3', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_noise_3_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'noise', '3', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_noise_3_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'noise', '3', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_0_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_0_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_0_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_0_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_1_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_1_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_1_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_1_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_2_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_2_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_2_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_2_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_3_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_3_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_3_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_3_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_0_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_0_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_0_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_0_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_1_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_1_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_1_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_1_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_2_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_2_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_2_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_2_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_3_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_3_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_3_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_3_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_0_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '0', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_0_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '0', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_0_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '0', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_0_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '0', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_2_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '2', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_2_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '2', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_2_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '2', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_2_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '2', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_3_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '3', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_3_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '3', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_3_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '3', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_3_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '3', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_0_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '0', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_0_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '0', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_0_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '0', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_0_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '0', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_1_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '1', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_1_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '1', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_1_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '1', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_1_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '1', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_2_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '2', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_2_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '2', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_2_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '2', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_2_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '2', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_3_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '3', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_3_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '3', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_3_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '3', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_3_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '3', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_0_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_0_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_0_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_0_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_1_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_1_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_1_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_1_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_2_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_2_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_2_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_2_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_3_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_3_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_3_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_3_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_0_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_0_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_0_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_0_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_1_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_1_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_1_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_1_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_2_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_2_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_2_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_2_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_3_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_3_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_3_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_3_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '5']

# %%
lstm_td3_POMDP_to_MDP['LSTM-TD3']['AntPyBulletEnv-v0']
# Out:
# {'flickering': {'0': {'0': {'MDP': [734.0480778839966,
#      785.4689725251291,
#      565.3787576323598,
#      541.4516366653294,
#      631.243874315578,
#      847.5266077504841,
#      543.9931968314575,
#      636.7949402673753,
#      769.202678427197,
#      758.0814000771852],
#     'flickering': [666.9036675484365,
#      595.6950345466743,
#      641.680672595278,
#      786.7213711860179,
#      709.7431183615555,
#      730.1437664204904,
#      697.08781398553,
#      755.3478638198164,
#      643.1879936398823,
#      537.6656345401457],
#     'random_noise': [521.9623293219835,
#      560.5906680922568,
#      539.0545043597753,
#      545.9102817241568,
#      714.6784803299516,
#      557.2835913084701,
#      557.8136887161127,
#      597.1319816483533,
#      575.2421737352082,
#      808.2056108059649],
#     'random_sensor_missing': [606.466770355196,
#      581.6500939161183,
#      524.0315646880781,
#      551.2065355316237,
#      570.7817365044117,
#      555.8338752652446,
#      765.2689534415364,
#      538.4781263077615,
#      556.8294367869378,
#      539.6827167735838]},
#    '1': {'MDP': [535.5301604245224,
#      591.1515618348027,
#      606.0267833208768,
#      293.90589574432954,
#      211.00761598073407,
#      440.97206356310375,
#      617.6217114526887,
#      229.6073657514718,
#      304.52817275842443,
#      599.8258357299272],
#     'flickering': [419.9056003403938,
#      532.4525315216799,
#      117.00321308003038,
#      702.6538681296927,
#      56.244640956546945,
#      399.8182111962002,
#      620.5523155873766,
#      106.77910126831259,
#      393.6544710748305,
#      258.98562315832845],
#     'random_noise': [594.8165438369883,
#      181.58837279840228,
         'LSTM-TD3_HistLen0': 'k', 'LSTM-TD3_HistLen1': 'c', 'LSTM-TD3_HistLen3': 'b', 'LSTM-TD3_HistLen5': 'r'}
algs = ['DDPG', 'TD3', 'SAC', 'TD3-OW', 'TD3-OW-AddPastAct']
bar_width = 0.125
std_scale = 0.5
# Baselines
fig, axes = plt.subplots(1, 4, figsize = (25, 5), sharey=True)
for axes_i, original_pomdp_type in enumerate(['POMDP-Flickering-FlickProb-0.2', 'POMDP-RandomNoise-Sigma-0.1', 'POMDP-RandomSensorMissing-MissProb-0.1']):
    # Original MDP
    # Baselines
    for alg_i, alg in enumerate(algs):
        # Calculate mean
        pomdp_evaluation = []
        pomdp_evaluation_mean = []
        pomdp_evaluation_std = []
        for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
            s_run_evals = []
            for s_run in MDP_to_POMDP[alg]['AntPyBulletEnv-v0'].keys():
                s_run_evals += MDP_to_POMDP[alg]['AntPyBulletEnv-v0'][s_run][pomdp_type]
            pomdp_evaluation.append(s_run_evals)
            pomdp_evaluation_mean.append(np.mean(s_run_evals))
            pomdp_evaluation_std.append(np.std(s_run_evals))

        # Plot
        axes[0].bar(np.arange(0,4) + alg_i*bar_width - 2.5*bar_width, pomdp_evaluation_mean, 
                    yerr = pomdp_evaluation_std, error_kw=dict(lw=2, capsize=5, capthick=2),
                    width = bar_width, label='{}'.format(alg), color=color[alg], alpha=0.8, edgecolor='w')
    # LSTM-TD3
    lstm_td3_pomdp_evaluation = []
    lstm_td3_pomdp_evaluation_mean = []
    lstm_td3_pomdp_evaluation_std = []
    for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
        s_run_evals = []
        for s_run in lstm_td3_MDP_to_POMDP['LSTM-TD3']['AntPyBulletEnv-v0']['5'].keys():
            s_run_evals += lstm_td3_MDP_to_POMDP['LSTM-TD3']['AntPyBulletEnv-v0']['5'][s_run][pomdp_type]
        lstm_td3_pomdp_evaluation.append(s_run_evals)
        lstm_td3_pomdp_evaluation_mean.append(np.mean(s_run_evals))
        lstm_td3_pomdp_evaluation_std.append(np.std(s_run_evals))

    # Plot
    axes[0].bar(np.arange(0, 4) + 5*bar_width - 2.5*bar_width, lstm_td3_pomdp_evaluation_mean, 
                yerr = lstm_td3_pomdp_evaluation_std, error_kw=dict(lw=2, capsize=5, capthick=2),
             width = bar_width, label='{}'.format('LSTM-TD3'), color='r', alpha=0.8, edgecolor='w')
    axes[0].set_xticks(np.arange(len(['MDP', 'flickering', 'random_noise', 'random_sensor_missing'])))
    axes[0].set_xticklabels(['MDP', 'POMDP-FLK', 'POMDP-RN', 'POMDP-RSM'])
    axes[0].set_xlabel('Evaluation Environment', fontsize=20)
    axes[0].set_ylabel('Average Return', fontsize=20)
    axes[0].set_title('Trained on MDP', fontsize=22)
    axes[0].grid(True, linestyle=':')
    # Create a Rectangle patch
    rect = Rectangle((-0.45,0), 0.9, 2850, linewidth=3, linestyle = 'dashed', edgecolor='r', facecolor='none')
    # Add the patch to the Axes
    axes[0].add_patch(rect)
    
    # Original POMDP
    for alg_i, alg in enumerate(algs):
        # Calculate mean
        pomdp_evaluation = []
        pomdp_evaluation_mean = []
        pomdp_evaluation_std = []
        for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
            s_run_evals = []
            for s_run in baselines_POMDP_to_MDP[alg]['AntPyBulletEnv-v0'][original_pomdp_type].keys():
                s_run_evals += baselines_POMDP_to_MDP[alg]['AntPyBulletEnv-v0'][original_pomdp_type][s_run][pomdp_type]
            pomdp_evaluation.append(s_run_evals)
            pomdp_evaluation_mean.append(np.mean(s_run_evals))
            pomdp_evaluation_std.append(np.std(s_run_evals)*std_scale)
            
        # Plot
        axes[axes_i+1].bar(np.arange(0,4) + alg_i*bar_width - 2.5*bar_width, pomdp_evaluation_mean, 
                         yerr = pomdp_evaluation_std, error_kw=dict(lw=2, capsize=5, capthick=2),
                         width = bar_width,  label='{}'.format(alg), color=color[alg], alpha=0.8, edgecolor='w')

    # LSTM-TD3
    if 'Flickering' in original_pomdp_type:
        original_pomdp_type = 'flickering'
    if 'RandomNoise' in original_pomdp_type:
        original_pomdp_type = 'random_noise'
    if 'RandomSensorMissing' in original_pomdp_type:
        original_pomdp_type = 'random_sensor_missing'
    lstm_td3_pomdp_evaluation = []
    lstm_td3_pomdp_evaluation_mean = []
    lstm_td3_pomdp_evaluation_std = []
    for pomdp_type in ['MDP', 'flickering', 'random_noise', 'random_sensor_missing']:
        s_run_evals = []
        for s_run in lstm_td3_POMDP_to_MDP['LSTM-TD3']['AntPyBulletEnv-v0'][original_pomdp_type]['5'].keys():
            s_run_evals += lstm_td3_POMDP_to_MDP['LSTM-TD3']['AntPyBulletEnv-v0'][original_pomdp_type]['5'][s_run][pomdp_type]
        lstm_td3_pomdp_evaluation.append(s_run_evals)
        lstm_td3_pomdp_evaluation_mean.append(np.mean(s_run_evals))
        lstm_td3_pomdp_evaluation_std.append(np.std(s_run_evals)*std_scale)
    # Plot
    axes[axes_i+1].bar(np.arange(0, 4) + 5*bar_width - 2.5*bar_width, lstm_td3_pomdp_evaluation_mean, 
                     yerr = lstm_td3_pomdp_evaluation_std, error_kw=dict(lw=2, capsize=5, capthick=2),
                     width = bar_width, label='{}'.format('LSTM-TD3'), color='r', alpha=0.8, edgecolor='w')

    axes[axes_i+1].set_xticks(np.arange(len(['MDP', 'flickering', 'random_noise', 'random_sensor_missing'])))
    axes[axes_i+1].set_xticklabels(['MDP', 'POMDP-FLK', 'POMDP-RN', 'POMDP-RSM'])
    axes[axes_i+1].set_xlabel('Evaluation Environment', fontsize=20)
    if original_pomdp_type == 'flickering':
        original_pomdp_type_ = 'POMDP-FLK'
    if original_pomdp_type == 'random_noise':
        original_pomdp_type_ = 'POMDP-RN'
    if original_pomdp_type == 'random_sensor_missing':
        original_pomdp_type_ = 'POMDP-RSM'
    axes[axes_i+1].set_title('Trained on {}'.format(original_pomdp_type_), fontsize=22)
#     axes.legend(ncol=3, bbox_to_anchor=(1.05, 1))
    axes[axes_i+1].grid(True, linestyle=':')
    
    # Add rectangle
    rect = Rectangle((-0.45+(axes_i+1),0), 0.9, 2850, linewidth=3, linestyle = 'dashed', edgecolor='r', facecolor='none')
    axes[axes_i+1].add_patch(rect)
plt.tight_layout()
fig.suptitle('Cross Evaluation on AntPyBulletEnv-v0', fontsize=24)
fig.subplots_adjust(top=0.8)

fig.savefig("D:\POMDP_Data\images\MDP-to-POMDP_and_POMDP-to-MDP_evaluation.png", bbox_inches='tight')

# %% [markdown]
# ## LSTM-TD3 Train and Evaluate with Different History Length

# %% [markdown]
# ### MDP

# %%
root_dir = r"D:\POMDP_Data\new_spinup_resumable_MDP_LSTM_TD3"
DEVICE = "cpu"  # "cuda"

lstm_td3_trained_on_MDP_different_hist_len = {}
for sub_dir in os.listdir(root_dir):
    print(sub_dir)
    print(sub_dir.split('_'))
    params = sub_dir.split('_')
    alg_name = params[1]
    task_name = params[2]
    seed = params[4]
    hist_len = params[5]
    if task_name in tasks:
        if alg_name not in lstm_td3_trained_on_MDP_different_hist_len:
            lstm_td3_trained_on_MDP_different_hist_len[alg_name] = {}
        if task_name not in lstm_td3_trained_on_MDP_different_hist_len[alg_name]:
            lstm_td3_trained_on_MDP_different_hist_len[alg_name][task_name] = {}
        if hist_len not in lstm_td3_trained_on_MDP_different_hist_len[alg_name][task_name]:
            lstm_td3_trained_on_MDP_different_hist_len[alg_name][task_name][hist_len] = {}
        if seed not in lstm_td3_trained_on_MDP_different_hist_len[alg_name][task_name][hist_len]:
            lstm_td3_trained_on_MDP_different_hist_len[alg_name][task_name][hist_len][seed] = {}
        #
        print("********************************************************************")
        for exp_run in os.listdir(os.path.join(root_dir, sub_dir)):
            print(exp_run)
            # Load pre-trained model
            config_path = os.path.join(root_dir, sub_dir, exp_run, 'config.json')
            with open(config_path, 'r') as config_file:
                config_json = json.load(config_file)
            # Retrive hyper-parameters
            env_name = config_json['env_name']
            num_test_episodes = config_json['num_test_episodes']
            max_ep_len = config_json['max_ep_len']
            max_hist_len = config_json['max_hist_len']
            
            #
            env = gym.make(task_name)
            obs_dim = env.observation_space.shape[0]
            act_dim = env.action_space.shape[0]
            act_limit = env.action_space.high[0]
            critic_mem_pre_lstm_hid_sizes = config_json['critic_mem_pre_lstm_hid_sizes']
            critic_mem_lstm_hid_sizes = config_json['critic_mem_lstm_hid_sizes']
            critic_mem_after_lstm_hid_size = config_json['critic_mem_after_lstm_hid_size']
            critic_cur_feature_hid_sizes = config_json['critic_cur_feature_hid_sizes']
            critic_post_comb_hid_sizes = config_json['critic_post_comb_hid_sizes']
            critic_mem_gate = config_json['critic_mem_gate']
            critic_mem_gate_before_current_feature_extraction = config_json['critic_mem_gate_before_current_feature_extraction']
            critic_hist_with_past_act = config_json['critic_hist_with_past_act']
            critic_use_hist_mask = config_json['critic_use_hist_mask']
            actor_mem_pre_lstm_hid_sizes = config_json['actor_mem_pre_lstm_hid_sizes']
            actor_mem_lstm_hid_sizes = config_json['actor_mem_lstm_hid_sizes']
            actor_mem_after_lstm_hid_size = config_json['actor_mem_after_lstm_hid_size']
            actor_cur_feature_hid_sizes = config_json['actor_cur_feature_hid_sizes']
            actor_post_comb_hid_sizes = config_json['actor_post_comb_hid_sizes']
            actor_mem_gate = config_json['actor_mem_gate']
            actor_mem_gate_before_current_feature_extraction = config_json['actor_mem_gate_before_current_feature_extraction']
            actor_hist_with_past_act = config_json['actor_hist_with_past_act']
            actor_use_hist_mask = config_json['actor_use_hist_mask']    
            ac = MLPActorCritic(obs_dim, act_dim, act_limit,
                                critic_mem_pre_lstm_hid_sizes=critic_mem_pre_lstm_hid_sizes,
                                critic_mem_lstm_hid_sizes=critic_mem_lstm_hid_sizes,
                                critic_mem_after_lstm_hid_size=critic_mem_after_lstm_hid_size,
                                critic_cur_feature_hid_sizes=critic_cur_feature_hid_sizes,
                                critic_post_comb_hid_sizes=critic_post_comb_hid_sizes,
                                critic_mem_gate=critic_mem_gate,
                                critic_mem_gate_before_current_feature_extraction=critic_mem_gate_before_current_feature_extraction,
                                critic_hist_with_past_act=critic_hist_with_past_act,
                                critic_use_hist_mask=critic_use_hist_mask,
                                actor_mem_pre_lstm_hid_sizes=actor_mem_pre_lstm_hid_sizes,
                                actor_mem_lstm_hid_sizes=actor_mem_lstm_hid_sizes,
                                actor_mem_after_lstm_hid_size=actor_mem_after_lstm_hid_size,
                                actor_cur_feature_hid_sizes=actor_cur_feature_hid_sizes,
                                actor_post_comb_hid_sizes=actor_post_comb_hid_sizes,
                                actor_mem_gate=actor_mem_gate,
                                actor_mem_gate_before_current_feature_extraction=actor_mem_gate_before_current_feature_extraction,
                                actor_hist_with_past_act=actor_hist_with_past_act,
                                actor_use_hist_mask=actor_use_hist_mask)
            # Load model
            resume_checkpoint_path = os.path.join(root_dir, sub_dir, exp_run, "pyt_save")
            checkpoint_files = os.listdir(resume_checkpoint_path)
            latest_model_checkpoint_file_path = os.path.join(resume_checkpoint_path, checkpoint_files[-1])
            
            model_checkpoint = torch.load(latest_model_checkpoint_file_path)
            ac.load_state_dict(model_checkpoint['ac_state_dict'])
            
            # print(ac)

            
            # Not include POMDP-RV, because POMDP-RV changed the dimension of observation.
            for eval_hist_len in [0, 1, 3, 5, 8, 10, 15]:
                print("\t{}".format(eval_hist_len))
                lstm_td3_trained_on_MDP_different_hist_len[alg_name][task_name][hist_len][seed]['{}'.format(eval_hist_len)] = []
                
                
                # Evaluation
                for j in range(num_test_episodes):
                    # Reset environment
                    o, d, ep_ret, ep_len = test_env.reset(), False, 0, 0
                    if eval_hist_len > 0:
                        o_buff = np.zeros([eval_hist_len, obs_dim])
                        a_buff = np.zeros([eval_hist_len, act_dim])
                        o_buff[0, :] = o
                        o_buff_len = 0
                    else:
                        o_buff = np.zeros([1, obs_dim])
                        a_buff = np.zeros([1, act_dim])
                        o_buff_len = 0

                    # Interact
                    while not(d or (ep_len == max_ep_len)):
                        # Take deterministic actions at test time 
                        h_o = torch.tensor(o_buff).view(1, o_buff.shape[0], o_buff.shape[1]).float().to(DEVICE)
                        h_a = torch.tensor(a_buff).view(1, a_buff.shape[0], a_buff.shape[1]).float().to(DEVICE)
                        h_l = torch.tensor([o_buff_len]).float().to(DEVICE)
                        a = ac.act(torch.as_tensor(o, dtype=torch.float32).view(1, -1).to(DEVICE),
                                   h_o, h_a, h_l).reshape(act_dim)
                        
                        o2, r, d, _ = test_env.step(a)
                        ep_ret += r
                        ep_len += 1

                        # Add short history
                        if max_hist_len != 0:
                            if o_buff_len == eval_hist_len:
                                o_buff[:eval_hist_len - 1] = o_buff[1:]
                                a_buff[:eval_hist_len - 1] = a_buff[1:]
                                o_buff[eval_hist_len - 1] = list(o)
                                a_buff[eval_hist_len - 1] = list(a)
                            else:
                                o_buff[o_buff_len + 1 - 1] = list(o)
                                a_buff[o_buff_len + 1 - 1] = list(a)
                                o_buff_len += 1
                        o = o2
                    print('\t  Episod-{}: Ep_Return={}, Ep_Len={}'.format(j, ep_ret, ep_len))
                    lstm_td3_trained_on_MDP_different_hist_len[alg_name][task_name][hist_len][seed]['{}'.format(eval_hist_len)].append(ep_ret)
# Out:
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '0', '0']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_0_0_s0
# WalkerBase::__init__
# 	0
# 	  Episod-0: Ep_Return=2010.2205942756732, Ep_Len=1000
# 	  Episod-1: Ep_Return=1924.8957066658018, Ep_Len=1000
# 	  Episod-2: Ep_Return=2026.1937346826876, Ep_Len=1000
# 	  Episod-3: Ep_Return=2065.735767228102, Ep_Len=1000
# 	  Episod-4: Ep_Return=1945.350584631377, Ep_Len=1000
# 	  Episod-5: Ep_Return=2040.9784977124573, Ep_Len=1000
# 	  Episod-6: Ep_Return=2024.1605840980335, Ep_Len=1000
# 	  Episod-7: Ep_Return=1992.329139570821, Ep_Len=1000
# 	  Episod-8: Ep_Return=2055.4860585104593, Ep_Len=1000
# 	  Episod-9: Ep_Return=2033.2478088742228, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=1955.2780427704765, Ep_Len=1000
# 	  Episod-1: Ep_Return=2149.2910889066766, Ep_Len=1000
# 	  Episod-2: Ep_Return=2010.6195128319039, Ep_Len=1000
# 	  Episod-3: Ep_Return=1901.5399304925265, Ep_Len=1000
# 	  Episod-4: Ep_Return=2034.95985937059, Ep_Len=1000
# 	  Episod-5: Ep_Return=2092.9780311686163, Ep_Len=1000
# 	  Episod-6: Ep_Return=2030.594788119265, Ep_Len=1000
# 	  Episod-7: Ep_Return=2047.5281213005323, Ep_Len=1000
# 	  Episod-8: Ep_Return=1839.6151442921241, Ep_Len=1000
# 	  Episod-9: Ep_Return=1945.5306139902586, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=1964.7809312223271, Ep_Len=1000
# 	  Episod-1: Ep_Return=1963.8065377830906, Ep_Len=1000
# 	  Episod-2: Ep_Return=1989.4338035446738, Ep_Len=1000
# 	  Episod-3: Ep_Return=2041.0742953107992, Ep_Len=1000
# 	  Episod-4: Ep_Return=2018.8834490344957, Ep_Len=1000
# 	  Episod-5: Ep_Return=1970.349755082357, Ep_Len=1000
# 	  Episod-6: Ep_Return=1850.928785162135, Ep_Len=1000
# 	  Episod-7: Ep_Return=1969.3031253738418, Ep_Len=1000
# 	  Episod-8: Ep_Return=1927.4073362001448, Ep_Len=1000
# 	  Episod-9: Ep_Return=1731.695274224522, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '0', '1']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_0_1_s0
# WalkerBase::__init__
# 	0
# 	  Episod-0: Ep_Return=2254.342995177675, Ep_Len=1000
# 	  Episod-1: Ep_Return=2091.4517401939634, Ep_Len=1000
# 	  Episod-2: Ep_Return=2009.4615622977612, Ep_Len=1000
# 	  Episod-3: Ep_Return=625.0121779077724, Ep_Len=1000
# 	  Episod-4: Ep_Return=1592.1520229386551, Ep_Len=1000
# 	  Episod-5: Ep_Return=2290.582709800299, Ep_Len=1000
# 	  Episod-6: Ep_Return=2206.222536143647, Ep_Len=1000
# 	  Episod-7: Ep_Return=2146.8032000765456, Ep_Len=1000
# 	  Episod-8: Ep_Return=2355.73835584226, Ep_Len=1000
# 	  Episod-9: Ep_Return=2064.310902975067, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=2130.2075126919226, Ep_Len=1000
# 	  Episod-1: Ep_Return=2326.6072291475075, Ep_Len=1000
# 	  Episod-2: Ep_Return=1868.5756508722602, Ep_Len=1000
# 	  Episod-3: Ep_Return=2299.621447913175, Ep_Len=1000
# 	  Episod-4: Ep_Return=2177.968850684662, Ep_Len=1000
# 	  Episod-5: Ep_Return=2260.6294098990584, Ep_Len=1000
# 	  Episod-6: Ep_Return=1919.4494724368194, Ep_Len=1000
# 	  Episod-7: Ep_Return=2297.157592873097, Ep_Len=1000
# 	  Episod-8: Ep_Return=2056.6379631068185, Ep_Len=1000
# 	  Episod-9: Ep_Return=1952.649675817519, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2295.6780871676083, Ep_Len=1000
# 	  Episod-1: Ep_Return=2245.487780179029, Ep_Len=1000
# 	  Episod-2: Ep_Return=2188.3730059704503, Ep_Len=1000
# 	  Episod-3: Ep_Return=2308.8510764741036, Ep_Len=1000
# 	  Episod-4: Ep_Return=1732.1707636467188, Ep_Len=1000
# 	  Episod-5: Ep_Return=2230.603796708904, Ep_Len=1000
# 	  Episod-6: Ep_Return=2009.2497080717374, Ep_Len=1000
# 	  Episod-7: Ep_Return=1970.5469769280662, Ep_Len=1000
# 	  Episod-8: Ep_Return=2173.975450782819, Ep_Len=1000
# 	  Episod-9: Ep_Return=2070.6770280385003, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2197.2099181609606, Ep_Len=1000
# 	  Episod-1: Ep_Return=2302.5142441829694, Ep_Len=1000
# 	  Episod-2: Ep_Return=2221.619083296639, Ep_Len=1000
# 	  Episod-3: Ep_Return=1912.0365377208268, Ep_Len=1000
# 	  Episod-4: Ep_Return=2194.062043340414, Ep_Len=1000
# 	  Episod-5: Ep_Return=2311.5916132908264, Ep_Len=1000
# 	  Episod-6: Ep_Return=2000.649388640922, Ep_Len=1000
# 	  Episod-7: Ep_Return=2261.011854171785, Ep_Len=1000
# 	  Episod-8: Ep_Return=2089.2363176594977, Ep_Len=1000
# 	  Episod-9: Ep_Return=2133.1660383087433, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2342.73040703288, Ep_Len=1000
# 	  Episod-1: Ep_Return=2406.867256722501, Ep_Len=1000
# 	  Episod-2: Ep_Return=2420.2734817054024, Ep_Len=1000
# 	  Episod-3: Ep_Return=2354.211273345333, Ep_Len=1000
# 	  Episod-4: Ep_Return=2236.3347512597893, Ep_Len=1000
# 	  Episod-5: Ep_Return=2421.4543186751685, Ep_Len=1000
# 	  Episod-6: Ep_Return=2255.7740524066744, Ep_Len=1000
# 	  Episod-7: Ep_Return=2380.7739618065116, Ep_Len=1000
# 	  Episod-8: Ep_Return=2358.4697106211033, Ep_Len=1000
# 	  Episod-9: Ep_Return=2406.228532063293, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2300.0162823365126, Ep_Len=1000
# 	  Episod-1: Ep_Return=2395.7498721121597, Ep_Len=1000
# 	  Episod-2: Ep_Return=2324.9616268766754, Ep_Len=1000
# 	  Episod-3: Ep_Return=2270.2766122136018, Ep_Len=1000
# 	  Episod-4: Ep_Return=2328.8060162112483, Ep_Len=1000
# 	  Episod-5: Ep_Return=2244.5506497722763, Ep_Len=1000
# 	  Episod-6: Ep_Return=2258.5456451997807, Ep_Len=1000
# 	  Episod-7: Ep_Return=2363.8964135905985, Ep_Len=1000
# 	  Episod-8: Ep_Return=2202.1632126781774, Ep_Len=1000
# 	  Episod-9: Ep_Return=2408.9175607841253, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2255.2738866678756, Ep_Len=1000
# 	  Episod-1: Ep_Return=2211.028424782342, Ep_Len=1000
# 	  Episod-2: Ep_Return=2270.211510851898, Ep_Len=1000
# 	  Episod-3: Ep_Return=2285.0910633903, Ep_Len=1000
# 	  Episod-4: Ep_Return=2340.7553451060203, Ep_Len=1000
# 	  Episod-5: Ep_Return=2339.5471822068885, Ep_Len=1000
# 	  Episod-6: Ep_Return=2338.172150739286, Ep_Len=1000
# 	  Episod-7: Ep_Return=2274.6762657596455, Ep_Len=1000
# 	  Episod-8: Ep_Return=2290.826016592822, Ep_Len=1000
# 	  Episod-9: Ep_Return=2325.6848983978616, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2286.746738286027, Ep_Len=1000
# 	  Episod-1: Ep_Return=2404.7097226668707, Ep_Len=1000
# 	  Episod-2: Ep_Return=2201.7435896475026, Ep_Len=1000
# 	  Episod-3: Ep_Return=2356.4367060971936, Ep_Len=1000
# 	  Episod-4: Ep_Return=2305.3229184537713, Ep_Len=1000
# 	  Episod-5: Ep_Return=2278.423923473712, Ep_Len=1000
# 	  Episod-6: Ep_Return=2373.9617430583, Ep_Len=1000
# 	  Episod-7: Ep_Return=2311.0484052119323, Ep_Len=1000
# 	  Episod-8: Ep_Return=2302.1887767530757, Ep_Len=1000
# 	  Episod-9: Ep_Return=2358.9825207001363, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=2368.592205259182, Ep_Len=1000
# 	  Episod-1: Ep_Return=2192.5482867719675, Ep_Len=1000
# 	  Episod-2: Ep_Return=2319.208262901576, Ep_Len=1000
# 	  Episod-3: Ep_Return=2299.3178990169718, Ep_Len=1000
# 	  Episod-4: Ep_Return=2155.285215124341, Ep_Len=1000
# 	  Episod-5: Ep_Return=2383.0753579732063, Ep_Len=1000
# 	  Episod-6: Ep_Return=2347.6853783419133, Ep_Len=1000
# 	  Episod-7: Ep_Return=2319.359364140101, Ep_Len=1000
# 	  Episod-8: Ep_Return=2265.581444928016, Ep_Len=1000
# 	  Episod-9: Ep_Return=2287.775051310999, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '0', '5']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_0_5_s0
# WalkerBase::__init__
# 	0
# 	  Episod-0: Ep_Return=1957.7376512971596, Ep_Len=1000
# 	  Episod-1: Ep_Return=1943.4090741888886, Ep_Len=1000
# 	  Episod-2: Ep_Return=1954.3339757990284, Ep_Len=1000
# 	  Episod-3: Ep_Return=1995.5582970623232, Ep_Len=1000
# 	  Episod-4: Ep_Return=1942.5547415905794, Ep_Len=1000
# 	  Episod-5: Ep_Return=1916.511879304315, Ep_Len=1000
# 	  Episod-6: Ep_Return=1949.6747631362268, Ep_Len=1000
# 	  Episod-7: Ep_Return=2008.5624247231433, Ep_Len=1000
# 	  Episod-8: Ep_Return=2021.5519386952801, Ep_Len=1000
# 	  Episod-9: Ep_Return=1892.714160530013, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=1975.206606789466, Ep_Len=1000
# 	  Episod-1: Ep_Return=2005.2542396827664, Ep_Len=1000
# 	  Episod-2: Ep_Return=2015.0983070945188, Ep_Len=1000
# 	  Episod-3: Ep_Return=2010.9383548432256, Ep_Len=1000
# 	  Episod-4: Ep_Return=1999.0007166747987, Ep_Len=1000
# 	  Episod-5: Ep_Return=2031.5959513164435, Ep_Len=1000
# 	  Episod-6: Ep_Return=1946.1577701036401, Ep_Len=1000
# 	  Episod-7: Ep_Return=2055.6256821748093, Ep_Len=1000
# 	  Episod-8: Ep_Return=2000.5798401937768, Ep_Len=1000
# 	  Episod-9: Ep_Return=2021.3203993964564, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2125.280449251527, Ep_Len=1000
# 	  Episod-1: Ep_Return=2098.8867977688938, Ep_Len=1000
# 	  Episod-2: Ep_Return=2121.5903697738217, Ep_Len=1000
# 	  Episod-3: Ep_Return=2088.188353807229, Ep_Len=1000
# 	  Episod-4: Ep_Return=2126.3347827004363, Ep_Len=1000
# 	  Episod-5: Ep_Return=2088.8200778443525, Ep_Len=1000
# 	  Episod-6: Ep_Return=2120.7604014383865, Ep_Len=1000
# 	  Episod-7: Ep_Return=2068.482631535154, Ep_Len=1000
# 	  Episod-8: Ep_Return=2168.8529727381, Ep_Len=1000
# 	  Episod-9: Ep_Return=2117.543340538746, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2135.7405693997084, Ep_Len=1000
# 	  Episod-1: Ep_Return=2062.3297398969453, Ep_Len=1000
# 	  Episod-2: Ep_Return=2058.0244558002314, Ep_Len=1000
# 	  Episod-3: Ep_Return=2124.3135098802336, Ep_Len=1000
# 	  Episod-4: Ep_Return=2079.9874761146107, Ep_Len=1000
# 	  Episod-5: Ep_Return=2098.262424707037, Ep_Len=1000
# 	  Episod-6: Ep_Return=2055.5657832335037, Ep_Len=1000
# 	  Episod-7: Ep_Return=2113.410945842039, Ep_Len=1000
# 	  Episod-8: Ep_Return=2099.293033209179, Ep_Len=1000
# 	  Episod-9: Ep_Return=2059.628471012426, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2070.7082517805807, Ep_Len=1000
# 	  Episod-1: Ep_Return=2127.947818116041, Ep_Len=1000
# 	  Episod-2: Ep_Return=2067.780866618219, Ep_Len=1000
# 	  Episod-3: Ep_Return=2056.2165464760465, Ep_Len=1000
# 	  Episod-4: Ep_Return=2124.2939260599233, Ep_Len=1000
# 	  Episod-5: Ep_Return=2050.09986842436, Ep_Len=1000
# 	  Episod-6: Ep_Return=2050.299267672249, Ep_Len=1000
# 	  Episod-7: Ep_Return=1968.8611451056029, Ep_Len=1000
# 	  Episod-8: Ep_Return=2087.951312396797, Ep_Len=1000
# 	  Episod-9: Ep_Return=2085.16502701996, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2018.4514575257533, Ep_Len=1000
# 	  Episod-1: Ep_Return=1992.121950792106, Ep_Len=1000
# 	  Episod-2: Ep_Return=2071.088116794138, Ep_Len=1000
# 	  Episod-3: Ep_Return=2064.1938752015085, Ep_Len=1000
# 	  Episod-4: Ep_Return=1992.9281259814086, Ep_Len=1000
# 	  Episod-5: Ep_Return=2004.4852311077525, Ep_Len=1000
# 	  Episod-6: Ep_Return=2029.1952659771432, Ep_Len=1000
# 	  Episod-7: Ep_Return=2058.745557809627, Ep_Len=1000
# 	  Episod-8: Ep_Return=2044.2462170242284, Ep_Len=1000
# 	  Episod-9: Ep_Return=2006.789157290807, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=2024.9679606895393, Ep_Len=1000
# 	  Episod-1: Ep_Return=2006.5065876695264, Ep_Len=1000
# 	  Episod-2: Ep_Return=2057.245905556736, Ep_Len=1000
# 	  Episod-3: Ep_Return=2068.998647260208, Ep_Len=1000
# 	  Episod-4: Ep_Return=2042.9902907120854, Ep_Len=1000
# 	  Episod-5: Ep_Return=1954.5230084250454, Ep_Len=1000
# 	  Episod-6: Ep_Return=1912.8694401210232, Ep_Len=1000
# 	  Episod-7: Ep_Return=1935.522298218787, Ep_Len=1000
# 	  Episod-8: Ep_Return=2033.000781282178, Ep_Len=1000
# 	  Episod-9: Ep_Return=2081.2550133024756, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '1', '0']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_1_0_s1
# WalkerBase::__init__
# 	0
# 	  Episod-0: Ep_Return=1842.6358375220893, Ep_Len=1000
# 	  Episod-1: Ep_Return=1770.445405505251, Ep_Len=1000
# 	  Episod-2: Ep_Return=1821.1399302699351, Ep_Len=1000
# 	  Episod-3: Ep_Return=1907.2881051839204, Ep_Len=1000
# 	  Episod-4: Ep_Return=1947.1325725007025, Ep_Len=1000
# 	  Episod-5: Ep_Return=1950.686620444103, Ep_Len=1000
# 	  Episod-6: Ep_Return=1946.4050882069212, Ep_Len=1000
# 	  Episod-7: Ep_Return=1725.63884107597, Ep_Len=1000
# 	  Episod-8: Ep_Return=1891.8415794869502, Ep_Len=1000
# 	  Episod-9: Ep_Return=1833.2161040128778, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=1767.182050920756, Ep_Len=1000
# 	  Episod-1: Ep_Return=1860.7444495075508, Ep_Len=1000
# 	  Episod-2: Ep_Return=1885.5800981071066, Ep_Len=1000
# 	  Episod-3: Ep_Return=1755.19586370146, Ep_Len=1000
# 	  Episod-4: Ep_Return=1985.2219602878772, Ep_Len=1000
# 	  Episod-5: Ep_Return=1966.7239758820335, Ep_Len=1000
# 	  Episod-6: Ep_Return=2035.7899679781146, Ep_Len=1000
# 	  Episod-7: Ep_Return=1822.5525616993734, Ep_Len=1000
# 	  Episod-8: Ep_Return=1836.6139910823763, Ep_Len=1000
# 	  Episod-9: Ep_Return=1827.416391779985, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return
Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=1672.9597417131051, Ep_Len=1000
# 	  Episod-1: Ep_Return=918.043750002405, Ep_Len=1000
# 	  Episod-2: Ep_Return=1625.6296647650142, Ep_Len=1000
# 	  Episod-3: Ep_Return=1763.1114545061039, Ep_Len=1000
# 	  Episod-4: Ep_Return=890.3599997164845, Ep_Len=1000
# 	  Episod-5: Ep_Return=1712.049220308903, Ep_Len=1000
# 	  Episod-6: Ep_Return=1595.27005921611, Ep_Len=1000
# 	  Episod-7: Ep_Return=716.384770238625, Ep_Len=1000
# 	  Episod-8: Ep_Return=1621.4454392591317, Ep_Len=1000
# 	  Episod-9: Ep_Return=619.3200173867616, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2309.4459808430197, Ep_Len=1000
# 	  Episod-1: Ep_Return=2215.3933058856464, Ep_Len=1000
# 	  Episod-2: Ep_Return=2266.9139228152903, Ep_Len=1000
# 	  Episod-3: Ep_Return=2274.7690274538727, Ep_Len=1000
# 	  Episod-4: Ep_Return=2218.5134073191625, Ep_Len=1000
# 	  Episod-5: Ep_Return=2255.737631952413, Ep_Len=1000
# 	  Episod-6: Ep_Return=2271.044889185489, Ep_Len=1000
# 	  Episod-7: Ep_Return=2186.140028703974, Ep_Len=1000
# 	  Episod-8: Ep_Return=2297.329074948722, Ep_Len=1000
# 	  Episod-9: Ep_Return=2162.698384401762, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2166.6357469789987, Ep_Len=1000
# 	  Episod-1: Ep_Return=2183.4228584412385, Ep_Len=1000
# 	  Episod-2: Ep_Return=2165.3402292758215, Ep_Len=1000
# 	  Episod-3: Ep_Return=2167.335197180639, Ep_Len=1000
# 	  Episod-4: Ep_Return=1984.8248639080107, Ep_Len=1000
# 	  Episod-5: Ep_Return=2149.3031740360743, Ep_Len=1000
# 	  Episod-6: Ep_Return=2140.7285040822558, Ep_Len=1000
# 	  Episod-7: Ep_Return=2220.4294169678096, Ep_Len=1000
# 	  Episod-8: Ep_Return=2160.177187931643, Ep_Len=1000
# 	  Episod-9: Ep_Return=2150.5825000063505, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2078.9701015011674, Ep_Len=1000
# 	  Episod-1: Ep_Return=2266.4723347049294, Ep_Len=1000
# 	  Episod-2: Ep_Return=2167.848439176777, Ep_Len=1000
# 	  Episod-3: Ep_Return=2173.187116774181, Ep_Len=1000
# 	  Episod-4: Ep_Return=2098.144857471928, Ep_Len=1000
# 	  Episod-5: Ep_Return=2152.915796480671, Ep_Len=1000
# 	  Episod-6: Ep_Return=2143.15947399407, Ep_Len=1000
# 	  Episod-7: Ep_Return=2177.6781038279223, Ep_Len=1000
# 	  Episod-8: Ep_Return=2201.7370536745393, Ep_Len=1000
# 	  Episod-9: Ep_Return=2159.156725949733, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2132.9526790943546, Ep_Len=1000
# 	  Episod-1: Ep_Return=2201.1340422945063, Ep_Len=1000
# 	  Episod-2: Ep_Return=2114.0272043057307, Ep_Len=1000
# 	  Episod-3: Ep_Return=2005.899166342696, Ep_Len=1000
# 	  Episod-4: Ep_Return=2176.119091181235, Ep_Len=1000
# 	  Episod-5: Ep_Return=2183.0333699177077, Ep_Len=1000
# 	  Episod-6: Ep_Return=2089.574168941796, Ep_Len=1000
# 	  Episod-7: Ep_Return=2108.9988328853474, Ep_Len=1000
# 	  Episod-8: Ep_Return=2129.6425480852167, Ep_Len=1000
# 	  Episod-9: Ep_Return=2147.1700019690684, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=2104.4776206153306, Ep_Len=1000
# 	  Episod-1: Ep_Return=2060.4976845478527, Ep_Len=1000
# 	  Episod-2: Ep_Return=2213.5274055970926, Ep_Len=1000
# 	  Episod-3: Ep_Return=2121.5126319324345, Ep_Len=1000
# 	  Episod-4: Ep_Return=2135.9063175423635, Ep_Len=1000
# 	  Episod-5: Ep_Return=2088.1175703419317, Ep_Len=1000
# 	  Episod-6: Ep_Return=2097.661534585109, Ep_Len=1000
# 	  Episod-7: Ep_Return=2146.1461878894643, Ep_Len=1000
# 	  Episod-8: Ep_Return=2183.1011263656383, Ep_Len=1000
# 	  Episod-9: Ep_Return=2193.9248540725907, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '1', '5']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_1_5_s1
# WalkerBase::__init__
# 	0
# 	  Episod-0: Ep_Return=1305.7800048021024, Ep_Len=1000
# 	  Episod-1: Ep_Return=1305.755596386021, Ep_Len=1000
# 	  Episod-2: Ep_Return=1011.1913387713316, Ep_Len=1000
# 	  Episod-3: Ep_Return=1408.0943177207166, Ep_Len=1000
# 	  Episod-4: Ep_Return=1056.7773059303236, Ep_Len=1000
# 	  Episod-5: Ep_Return=1140.769263862696, Ep_Len=1000
# 	  Episod-6: Ep_Return=1082.768475495241, Ep_Len=1000
# 	  Episod-7: Ep_Return=1165.8735644708456, Ep_Len=1000
# 	  Episod-8: Ep_Return=1145.3045137449817, Ep_Len=1000
# 	  Episod-9: Ep_Return=1063.7446204810667, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=1008.2952791170871, Ep_Len=1000
# 	  Episod-1: Ep_Return=1076.9141427332563, Ep_Len=1000
# 	  Episod-2: Ep_Return=995.4888072447344, Ep_Len=1000
# 	  Episod-3: Ep_Return=1000.2866826186977, Ep_Len=1000
# 	  Episod-4: Ep_Return=1291.9621234467277, Ep_Len=1000
# 	  Episod-5: Ep_Return=1396.3895585337614, Ep_Len=1000
# 	  Episod-6: Ep_Return=1206.3026716592085, Ep_Len=1000
# 	  Episod-7: Ep_Return=1202.654492555213, Ep_Len=1000
# 	  Episod-8: Ep_Return=1263.0481839034028, Ep_Len=1000
# 	  Episod-9: Ep_Return=1093.5950087131448, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2226.491845683581, Ep_Len=1000
# 	  Episod-1: Ep_Return=2209.937075889273, Ep_Len=1000
# 	  Episod-2: Ep_Return=2079.018227485819, Ep_Len=1000
# 	  Episod-3: Ep_Return=2162.2309103154776, Ep_Len=1000
# 	  Episod-4: Ep_Return=2264.8675453144338, Ep_Len=1000
# 	  Episod-5: Ep_Return=2216.939343014355, Ep_Len=1000
# 	  Episod-6: Ep_Return=2171.377545465362, Ep_Len=1000
# 	  Episod-7: Ep_Return=2177.707814016896, Ep_Len=1000
# 	  Episod-8: Ep_Return=2180.2578785548467, Ep_Len=1000
# 	  Episod-9: Ep_Return=2090.9629440612443, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2270.6358762887967, Ep_Len=1000
# 	  Episod-1: Ep_Return=2154.5358008253884, Ep_Len=1000
# 	  Episod-2: Ep_Return=2241.5973408610876, Ep_Len=1000
# 	  Episod-3: Ep_Return=2122.2102838954856, Ep_Len=1000
# 	  Episod-4: Ep_Return=2212.627832248929, Ep_Len=1000
# 	  Episod-5: Ep_Return=2255.800907555994, Ep_Len=1000
# 	  Episod-6: Ep_Return=2254.103199062714, Ep_Len=1000
# 	  Episod-7: Ep_Return=2199.6190246976134, Ep_Len=1000
# 	  Episod-8: Ep_Return=2173.284850816365, Ep_Len=1000
# 	  Episod-9: Ep_Return=2229.836096191494, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2127.5783402385555, Ep_Len=1000
# 	  Episod-1: Ep_Return=2193.174327992437, Ep_Len=1000
# 	  Episod-2: Ep_Return=2202.556665980947, Ep_Len=1000
# 	  Episod-3: Ep_Return=2276.209788961781, Ep_Len=1000
# 	  Episod-4: Ep_Return=2200.7794472008222, Ep_Len=1000
# 	  Episod-5: Ep_Return=2158.502018153986, Ep_Len=1000
# 	  Episod-6: Ep_Return=2217.3914400608737, Ep_Len=1000
# 	  Episod-7: Ep_Return=2133.4456217971174, Ep_Len=1000
# 	  Episod-8: Ep_Return=2206.2527350031887, Ep_Len=1000
# 	  Episod-9: Ep_Return=2216.278472439918, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2126.048687633269, Ep_Len=1000
# 	  Episod-1: Ep_Return=2261.369866190976, Ep_Len=1000
# 	  Episod-2: Ep_Return=2204.2420776165022, Ep_Len=1000
# 	  Episod-3: Ep_Return=2218.864202013166, Ep_Len=1000
# 	  Episod-4: Ep_Return=2160.4049643112508, Ep_Len=1000
# 	  Episod-5: Ep_Return=2256.5221272279573, Ep_Len=1000
# 	  Episod-6: Ep_Return=2267.6187681036376, Ep_Len=1000
# 	  Episod-7: Ep_Return=2156.6497286346535, Ep_Len=1000
# 	  Episod-8: Ep_Return=2221.8682575088874, Ep_Len=1000
# 	  Episod-9: Ep_Return=2180.5765285311722, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=2146.1664939471993, Ep_Len=1000
# 	  Episod-1: Ep_Return=2317.092637353416, Ep_Len=1000
# 	  Episod-2: Ep_Return=2183.2259432529154, Ep_Len=1000
# 	  Episod-3: Ep_Return=2250.8106976450485, Ep_Len=1000
# 	  Episod-4: Ep_Return=2216.6635071787214, Ep_Len=1000
# 	  Episod-5: Ep_Return=2181.6132937653642, Ep_Len=1000
# 	  Episod-6: Ep_Return=2275.684117359196, Ep_Len=1000
# 	  Episod-7: Ep_Return=2236.983460270019, Ep_Len=1000
# 	  Episod-8: Ep_Return=2208.109555160989, Ep_Len=1000
# 	  Episod-9: Ep_Return=2196.4572425321894, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '2', '0']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_2_0_s2
# WalkerBase::__init__
# 	0
# 	  Episod-0: Ep_Return=1388.9039103878, Ep_Len=1000
# 	  Episod-1: Ep_Return=1476.504656916449, Ep_Len=1000
# 	  Episod-2: Ep_Return=1498.1841153267603, Ep_Len=1000
# 	  Episod-3: Ep_Return=1448.2604669536308, Ep_Len=1000
# 	  Episod-4: Ep_Return=1387.3434226536076, Ep_Len=1000
# 	  Episod-5: Ep_Return=1501.5012130551352, Ep_Len=1000
# 	  Episod-6: Ep_Return=1540.4170627578849, Ep_Len=1000
# 	  Episod-7: Ep_Return=1346.4577649313128, Ep_Len=1000
# 	  Episod-8: Ep_Return=1420.5002767693618, Ep_Len=1000
# 	  Episod-9: Ep_Return=1447.3148268443515, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=1293.3618745217254, Ep_Len=1000
# 	  Episod-1: Ep_Return=1270.5784830484904, Ep_Len=1000
# 	  Episod-2: Ep_Return=1412.0813271326538, Ep_Len=1000
# 	  Episod-3: Ep_Return=1380.8137080714196, Ep_Len=1000
# 	  Episod-4: Ep_Return=1487.0882516669844, Ep_Len=1000
# 	  Episod-5: Ep_Return=1293.2805820307635, Ep_Len=1000
# 	  Episod-6: Ep_Return=1433.9722164290324, Ep_Len=1000
# 	  Episod-7: Ep_Return=1451.0710076056637, Ep_Len=1000
# 	  Episod-8: Ep_Return=1393.9793874721329, Ep_Len=1000
# 	  Episod-9: Ep_Return=1328.9426704041516, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'False', '2', '1']
# ********************************************************************
# 2021-01-22_21-34-24-LSTM-TD3_AntPyBulletEnv-v0_False_2_1_s2
# WalkerBase::__init__
# 	0
# 	  Episod-0: Ep_Return=2149.836827040275, Ep_Len=1000
# 	  Episod-1: Ep_Return=2176.7371321876317, Ep_Len=1000
# 	  Episod-2: Ep_Return=1924.4813359966536, Ep_Len=1000
# 	  Episod-3: Ep_Return=283.97499127140736, Ep_Len=1000
# 	  Episod-4: Ep_Return=2074.0455396239045, Ep_Len=1000
# 	  Episod-5: Ep_Return=2061.831206864418, Ep_Len=1000
# 	  Episod-6: Ep_Return=2117.620634074062, Ep_Len=1000
# 	  Episod-7: Ep_Return=2108.4628975743044, Ep_Len=1000
# 	  Episod-8: Ep_Return=2077.565657396869, Ep_Len=1000
# 	  Episod-9: Ep_Return=2120.271750350882, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=2044.5097669151369, Ep_Len=1000
# 	  Episod-1: Ep_Return=2060.6451305764153, Ep_Len=1000
# 	  Episod-2: Ep_Return=1918.9888805162007, Ep_Len=1000
# 	  Episod-3: Ep_Return=2023.5452176557094, Ep_Len=1000
# 	  Episod-4: Ep_Return=2046.8288975109215, Ep_Len=1000
# 	  Episod-5: Ep_Return=2100.102392388863, Ep_Len=1000
# 	  Episod-6: Ep_Return=1913.5702569822622, Ep_Len=1000
# 	  Episod-7: Ep_Return=2017.2889396404466, Ep_Len=1000
# 	  Episod-8: Ep_Return=1844.1031964933218, Ep_Len=1000
# 	  Episod-9: Ep_Return=2163.2083187644585, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=906.1126966338461, Ep_Len=1000
# 	  Episod-1: Ep_Return=2032.138699026337, Ep_Len=1000
# 	  Episod-2: Ep_Return=1950.8775045896111, Ep_Len=1000
# 	  Episod-3: Ep_Return=2078.1258464133134, Ep_Len=1000
# 	  Episod-4: Ep_Return=1965.3001459688064, Ep_Len=1000
# 	  Episod-5: Ep_Return=2085.5512596752974, Ep_Len=1000
# 	  Episod-6: Ep_Return=2036.5689398327925, Ep_Len=1000
# 	  Episod-7: Ep_Return=2106.2028100612815, Ep_Len=1000
# 	  Episod-8: Ep_Return=2032.40944401488, Ep_Len=1000
# 	  Episod-9: Ep_Return=2062.9490759398054, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2082.1605390937243, Ep_Len=1000
# 	  Episod-1: Ep_Return=2042.3325451228043, Ep_Len=1000
# 	  Episod-2: Ep_Return=1988.537670100794, Ep_Len=1000
# 	  Episod-3: Ep_Return=2157.798384661224, Ep_Len=1000
# 	  Episod-4: Ep_Return=1934.3078967626998, Ep_Len=1000
# 	  Episod-5: Ep_Return=2022.962626891241, Ep_Len=1000
# 	  Episod-6: Ep_Return=2015.228899530809, Ep_Len=1000
# 	  Episod-7: Ep_Return=2039.137750727367, Ep_Len=1000
# 	  Episod-8: Ep_Return=1828.4433551427176, Ep_Len=1000
# 	  Episod-9: Ep_Return=1963.2825661323245, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=279.652366290656, Ep_Len=1000
# 	  Episod-1: Ep_Return=363.5529483212044, Ep_Len=1000
# 	  Episod-2: Ep_Return=464.70656646264024, Ep_Len=1000
# 	  Episod-3: Ep_Return=368.94400574874174, Ep_Len=1000
# 	  Episod-4: Ep_Return=323.50822316980697, Ep_Len=1000
# 	  Episod-5: Ep_Return=363.444273864641, Ep_Len=1000
# 	  Episod-6: Ep_Return=415.0122293051713, Ep_Len=1000
# 	  Episod-7: Ep_Return=404.2729800336717, Ep_Len=1000
# 	  Episod-8: Ep_Return=366.44355691750053, Ep_Len=1000
# 	  Episod-9: Ep_Return=557.9474215620942, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2176.8480567727484, Ep_Len=1000
# 	  Episod-1: Ep_Return=2186.5203134858284, Ep_Len=1000
# 	  Episod-2: Ep_Return=2141.6934893155667, Ep_Len=1000
# 	  Episod-3: Ep_Return=2222.0815652423753, Ep_Len=1000
# 	  Episod-4: Ep_Return=2186.7667971364845, Ep_Len=1000
# 	  Episod-5: Ep_Return=2172.679326353026, Ep_Len=1000
# 	  Episod-6: Ep_Return=2162.369375937031, Ep_Len=1000
# 	  Episod-7: Ep_Return=2230.6642531771754, Ep_Len=1000
# 	  Episod-8: Ep_Return=2228.304594103539, Ep_Len=1000
# 	  Episod-9: Ep_Return=2190.3113557995266, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=1991.8950423641131, Ep_Len=1000
# 	  Episod-1: Ep_Return=1935.0675875019267, Ep_Len=1000
# 	  Episod-2: Ep_Return=1973.1774557858648, Ep_Len=1000
# 	  Episod-3: Ep_Return=1992.9100032373449, Ep_Len=1000
# 	  Episod-4: Ep_Return=2043.5266404025335, Ep_Len=1000
# 	  Episod-5: Ep_Return=1981.139629538085, Ep_Len=1000
# 	  Episod-6: Ep_Return=1995.5722696634384, Ep_Len=1000
# 	  Episod-7: Ep_Return=1981.470255609852, Ep_Len=1000
# 	  Episod-8: Ep_Return=2038.52707719543, Ep_Len=1000
# 	  Episod-9: Ep_Return=2016.6692176820775, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2025.1239345686042, Ep_Len=1000
# 	  Episod-1: Ep_Return=1969.417415390919, Ep_Len=1000
# 	  Episod-2: Ep_Return=1999.448868327161, Ep_Len=1000
# 	  Episod-3: Ep_Return=1957.3866622215212, Ep_Len=1000
# 	  Episod-4: Ep_Return=1947.606338634078, Ep_Len=1000
# 	  Episod-5: Ep_Return=1963.308781984832, Ep_Len=1000
# 	  Episod-6: Ep_Return=2011.2561090418615, Ep_Len=1000
# 	  Episod-7: Ep_Return=1985.8146806445986, Ep_Len=1000
# 	  Episod-8: Ep_Return=1938.8562788533675, Ep_Len=1000
# 	  Episod-9: Ep_Return=2035.5473715035798, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=1986.8174159676735, Ep_Len=1000
# 	  Episod-1: Ep_Return=1944.4366366074794, Ep_Len=1000
# 	  Episod-2: Ep_Return=1986.1729297444556, Ep_Len=1000
# 	  Episod-3: Ep_Return=1966.4032387954778, Ep_Len=1000
# 	  Episod-4: Ep_Return=2064.515420956635, Ep_Len=1000
# 	  Episod-5: Ep_Return=1968.9909347318212, Ep_Len=1000
# 	  Episod-6: Ep_Return=1979.9708691354394, Ep_Len=1000
# 	  Episod-7: Ep_Return=1875.4384316775936, Ep_Len=1000
# 	  Episod-8: Ep_Return=2020.9625416604913, Ep_Len=1000
# 	  Episod-9: Ep_Return=1992.7281914668483, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2082.1006971670545, Ep_Len=1000
# 	  Episod-1: Ep_Return=2119.2844823224777, Ep_Len=1000
# 	  Episod-2: Ep_Return=2049.8548382503636, Ep_Len=1000
# 	  Episod-3: Ep_Return=2045.6240973959264, Ep_Len=1000
# 	  Episod-4: Ep_Return=2126.0830498918644, Ep_Len=1000
# 	  Episod-5: Ep_Return=1974.1624970671708, Ep_Len=1000
# 	  Episod-6: Ep_Return=2086.1232461129885, Ep_Len=1000
# 	  Episod-7: Ep_Return=2110.115897020428, Ep_Len=1000
# 	  Episod-8: Ep_Return=2115.594703019607, Ep_Len=1000
# 	  Episod-9: Ep_Return=2081.0869776779173, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2103.145367894973, Ep_Len=1000
# 	  Episod-1: Ep_Return=2034.9432128578062, Ep_Len=1000
# 	  Episod-2: Ep_Return=2182.3702195598507, Ep_Len=1000
# 	  Episod-3: Ep_Return=2142.241262163885, Ep_Len=1000
# 	  Episod-4: Ep_Return=2004.9019140042476, Ep_Len=1000
# ...
# 	  Episod-0: Ep_Return=1712.8010021513933, Ep_Len=1000
# 	  Episod-1: Ep_Return=1766.3308964816642, Ep_Len=1000
# 	  Episod-2: Ep_Return=1246.4019649675154, Ep_Len=1000
# 	  Episod-3: Ep_Return=1745.536690567381, Ep_Len=1000
# 	  Episod-4: Ep_Return=1762.0478587263037, Ep_Len=1000
# 	  Episod-5: Ep_Return=1708.6087869687399, Ep_Len=1000
# 	  Episod-6: Ep_Return=1641.4483108277047, Ep_Len=1000
# 	  Episod-7: Ep_Return=1645.7564921382746, Ep_Len=1000
# 	  Episod-8: Ep_Return=1555.8639054827156, Ep_Len=1000
# 	  Episod-9: Ep_Return=1535.3652396986427, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2243.624111081281, Ep_Len=1000
# 	  Episod-1: Ep_Return=2285.6719480487413, Ep_Len=1000
# 	  Episod-2: Ep_Return=2278.7566000768875, Ep_Len=1000
# 	  Episod-3: Ep_Return=2267.185939186831, Ep_Len=1000
# 	  Episod-4: Ep_Return=2188.326160849138, Ep_Len=1000
# 	  Episod-5: Ep_Return=2254.4152091022747, Ep_Len=1000
# 	  Episod-6: Ep_Return=2238.4745191879238, Ep_Len=1000
# 	  Episod-7: Ep_Return=2218.7059033421733, Ep_Len=1000
# 	  Episod-8: Ep_Return=2152.1200098058903, Ep_Len=1000
# 	  Episod-9: Ep_Return=2251.789701674787, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2233.2348342836854, Ep_Len=1000
# 	  Episod-1: Ep_Return=2250.8806912713644, Ep_Len=1000
# 	  Episod-2: Ep_Return=2184.0899685960126, Ep_Len=1000
# 	  Episod-3: Ep_Return=2281.095911989605, Ep_Len=1000
# 	  Episod-4: Ep_Return=2197.6324206833415, Ep_Len=1000
# 	  Episod-5: Ep_Return=2217.9264756437224, Ep_Len=1000
# 	  Episod-6: Ep_Return=2264.8803290962624, Ep_Len=1000
# 	  Episod-7: Ep_Return=2176.72589649091, Ep_Len=1000
# 	  Episod-8: Ep_Return=2278.0517469290658, Ep_Len=1000
# 	  Episod-9: Ep_Return=2205.880690087043, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2195.5797445945796, Ep_Len=1000
# 	  Episod-1: Ep_Return=2186.317575552537, Ep_Len=1000
# 	  Episod-2: Ep_Return=2215.007917344874, Ep_Len=1000
# 	  Episod-3: Ep_Return=2246.7511707261365, Ep_Len=1000
# 	  Episod-4: Ep_Return=2311.424133149637, Ep_Len=1000
# 	  Episod-5: Ep_Return=2167.102782745728, Ep_Len=1000
# 	  Episod-6: Ep_Return=2294.329106051465, Ep_Len=1000
# 	  Episod-7: Ep_Return=2234.453993113484, Ep_Len=1000
# 	  Episod-8: Ep_Return=2261.0468225735667, Ep_Len=1000
# 	  Episod-9: Ep_Return=2291.8779081291846, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2138.0843683651246, Ep_Len=1000
# 	  Episod-1: Ep_Return=2132.6015591704413, Ep_Len=1000
# 	  Episod-2: Ep_Return=2211.4211800104986, Ep_Len=1000
# 	  Episod-3: Ep_Return=2231.683838023554, Ep_Len=1000
# 	  Episod-4: Ep_Return=2195.0994933211805, Ep_Len=1000
# 	  Episod-5: Ep_Return=2229.3467717528583, Ep_Len=1000
# 	  Episod-6: Ep_Return=2243.292812503598, Ep_Len=1000
# 	  Episod-7: Ep_Return=2212.5944336260977, Ep_Len=1000
# 	  Episod-8: Ep_Return=2034.9850099125783, Ep_Len=1000
# 	  Episod-9: Ep_Return=2305.234806393351, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=2196.1751895503703, Ep_Len=1000
# 	  Episod-1: Ep_Return=2022.8040747812136, Ep_Len=1000
# 	  Episod-2: Ep_Return=2201.9354050817496, Ep_Len=1000
# 	  Episod-3: Ep_Return=2110.684824525352, Ep_Len=1000
# 	  Episod-4: Ep_Return=2278.639756368062, Ep_Len=1000
# 	  Episod-5: Ep_Return=2206.0589805252125, Ep_Len=1000
# 	  Episod-6: Ep_Return=2145.749864065205, Ep_Len=1000
# 	  Episod-7: Ep_Return=2258.892017232839, Ep_Len=1000
# 	  Episod-8: Ep_Return=2224.9666211093136, Ep_Len=1000
# 	  Episod-9: Ep_Return=2287.713676469115, Ep_Len=1000
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_HalfCheetahPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'HalfCheetahPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_HopperPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'HopperPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_InvertedDoublePendulumPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedDoublePendulumPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_InvertedPendulumPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'InvertedPendulumPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_ReacherPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'False', '3', '5']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_0_0
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '0', '0']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_0_1
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '0', '1']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_0_3
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '0', '3']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_0_5
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '0', '5']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_1_0
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '1', '0']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_1_1
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '1', '1']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_1_3
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '1', '3']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_1_5
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '1', '5']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_2_0
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '2', '0']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_2_1
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '2', '1']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_2_3
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '2', '3']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_2_5
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '2', '5']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_3_0
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '3', '0']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_3_1
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '3', '1']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_3_3
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '3', '3']
# 2021-01-22_LSTM-TD3_Walker2DPyBulletEnv-v0_False_3_5
# ['2021-01-22', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'False', '3', '5']

# %% [markdown]
# ### POMDP

# %%
root_dir = r"D:\POMDP_Data\new_spinup_resumable_POMDP_LSTM_TD3"
DEVICE = "cpu"  # "cuda"

lstm_td3_different_hist_len = {}
for sub_dir in os.listdir(root_dir):
    print(sub_dir)
    print(sub_dir.split('_'))
    params = sub_dir.split('_')
    alg_name = params[1]
    task_name = params[2]
    pomdp_hyperparam = '_'.join(params[4:-2])
    seed = params[-2]
    hist_len = params[-1]
    
    if task_name in tasks:
        if alg_name not in lstm_td3_different_hist_len:
            lstm_td3_different_hist_len[alg_name] = {}
        if task_name not in lstm_td3_different_hist_len[alg_name]:
            lstm_td3_different_hist_len[alg_name][task_name] = {}
        if pomdp_hyperparam not in lstm_td3_different_hist_len[alg_name][task_name]:
            lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam] = {}
        if hist_len not in lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam]:
            lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len] = {}
        if seed not in lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len]:
            lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len][seed] = {}
        #
        print("********************************************************************")
        for exp_run in os.listdir(os.path.join(root_dir, sub_dir)):
            print(exp_run)
            # Load pre-trained model
            config_path = os.path.join(root_dir, sub_dir, exp_run, 'config.json')
            with open(config_path, 'r') as config_file:
                config_json = json.load(config_file)
            # Retrive hyper-parameters
            env_name = config_json['env_name']
            num_test_episodes = config_json['num_test_episodes']
            max_ep_len = config_json['max_ep_len']
            max_hist_len = config_json['max_hist_len']
            
            # Create environment
            if config_json['partially_observable']:
                env = POMDPWrapper(env_name, config_json['pomdp_type'], 
                                   config_json['flicker_prob'], config_json['random_noise_sigma'], 
                                   config_json['random_sensor_missing_prob'])
            else:
                env = gym.make(env_name)
            
            obs_dim = env.observation_space.shape[0]
            act_dim = env.action_space.shape[0]
            act_limit = env.action_space.high[0]
            
            critic_mem_pre_lstm_hid_sizes = config_json['critic_mem_pre_lstm_hid_sizes']
            critic_mem_lstm_hid_sizes = config_json['critic_mem_lstm_hid_sizes']
            critic_mem_after_lstm_hid_size = config_json['critic_mem_after_lstm_hid_size']
            critic_cur_feature_hid_sizes = config_json['critic_cur_feature_hid_sizes']
            critic_post_comb_hid_sizes = config_json['critic_post_comb_hid_sizes']
            critic_mem_gate = config_json['critic_mem_gate']
            critic_mem_gate_before_current_feature_extraction = config_json['critic_mem_gate_before_current_feature_extraction']
            critic_hist_with_past_act = config_json['critic_hist_with_past_act']
            critic_use_hist_mask = config_json['critic_use_hist_mask']
            actor_mem_pre_lstm_hid_sizes = config_json['actor_mem_pre_lstm_hid_sizes']
            actor_mem_lstm_hid_sizes = config_json['actor_mem_lstm_hid_sizes']
            actor_mem_after_lstm_hid_size = config_json['actor_mem_after_lstm_hid_size']
            actor_cur_feature_hid_sizes = config_json['actor_cur_feature_hid_sizes']
            actor_post_comb_hid_sizes = config_json['actor_post_comb_hid_sizes']
            actor_mem_gate = config_json['actor_mem_gate']
            actor_mem_gate_before_current_feature_extraction = config_json['actor_mem_gate_before_current_feature_extraction']
            actor_hist_with_past_act = config_json['actor_hist_with_past_act']
            actor_use_hist_mask = config_json['actor_use_hist_mask']    
            ac = MLPActorCritic(obs_dim, act_dim, act_limit,
                                critic_mem_pre_lstm_hid_sizes=critic_mem_pre_lstm_hid_sizes,
                                critic_mem_lstm_hid_sizes=critic_mem_lstm_hid_sizes,
                                critic_mem_after_lstm_hid_size=critic_mem_after_lstm_hid_size,
                                critic_cur_feature_hid_sizes=critic_cur_feature_hid_sizes,
                                critic_post_comb_hid_sizes=critic_post_comb_hid_sizes,
                                critic_mem_gate=critic_mem_gate,
                                critic_mem_gate_before_current_feature_extraction=critic_mem_gate_before_current_feature_extraction,
                                critic_hist_with_past_act=critic_hist_with_past_act,
                                critic_use_hist_mask=critic_use_hist_mask,
                                actor_mem_pre_lstm_hid_sizes=actor_mem_pre_lstm_hid_sizes,
                                actor_mem_lstm_hid_sizes=actor_mem_lstm_hid_sizes,
                                actor_mem_after_lstm_hid_size=actor_mem_after_lstm_hid_size,
                                actor_cur_feature_hid_sizes=actor_cur_feature_hid_sizes,
                                actor_post_comb_hid_sizes=actor_post_comb_hid_sizes,
                                actor_mem_gate=actor_mem_gate,
                                actor_mem_gate_before_current_feature_extraction=actor_mem_gate_before_current_feature_extraction,
                                actor_hist_with_past_act=actor_hist_with_past_act,
                                actor_use_hist_mask=actor_use_hist_mask)
            # Load model
            resume_checkpoint_path = os.path.join(root_dir, sub_dir, exp_run, "pyt_save")
            checkpoint_files = os.listdir(resume_checkpoint_path)
            latest_model_checkpoint_file_path = os.path.join(resume_checkpoint_path, checkpoint_files[-1])
            
            model_checkpoint = torch.load(latest_model_checkpoint_file_path)
            ac.load_state_dict(model_checkpoint['ac_state_dict'])
            
            # print(ac)
            
            # Evaluate on the same environment, but with different history length.
            for eval_hist_len in [0, 1, 3, 5, 8, 10, 15]:
                print("\t{}".format(eval_hist_len))
                lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len][seed]['{}'.format(eval_hist_len)] = []
                
                # Evaluation
                for j in range(num_test_episodes):
                    # Reset environment
                    o, d, ep_ret, ep_len = env.reset(), False, 0, 0
                    if eval_hist_len > 0:
                        o_buff = np.zeros([eval_hist_len, obs_dim])
                        a_buff = np.zeros([eval_hist_len, act_dim])
                        o_buff[0, :] = o
                        o_buff_len = 0
                    else:
                        o_buff = np.zeros([1, obs_dim])
                        a_buff = np.zeros([1, act_dim])
                        o_buff_len = 0

                    # Interact
                    while not(d or (ep_len == max_ep_len)):
                        # Take deterministic actions at test time 
                        h_o = torch.tensor(o_buff).view(1, o_buff.shape[0], o_buff.shape[1]).float().to(DEVICE)
                        h_a = torch.tensor(a_buff).view(1, a_buff.shape[0], a_buff.shape[1]).float().to(DEVICE)
                        h_l = torch.tensor([o_buff_len]).float().to(DEVICE)
                        a = ac.act(torch.as_tensor(o, dtype=torch.float32).view(1, -1).to(DEVICE),
                                   h_o, h_a, h_l).reshape(act_dim)
                        
                        o2, r, d, _ = env.step(a)
                        ep_ret += r
                        ep_len += 1

                        # Add short history
                        if eval_hist_len != 0:
                            if o_buff_len == eval_hist_len:
                                o_buff[:eval_hist_len - 1] = o_buff[1:]
                                a_buff[:eval_hist_len - 1] = a_buff[1:]
                                o_buff[eval_hist_len - 1] = list(o)
                                a_buff[eval_hist_len - 1] = list(a)
                            else:
                                o_buff[o_buff_len + 1 - 1] = list(o)
                                a_buff[o_buff_len + 1 - 1] = list(a)
                                o_buff_len += 1
                        o = o2
                    print('\t  Episod-{}: Ep_Return={}, Ep_Len={}'.format(j, ep_ret, ep_len))
                    lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len][seed]['{}'.format(eval_hist_len)].append(ep_ret)
# Out:
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0']
# ********************************************************************
# 2021-01-22_22-45-30-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=683.3195551060422, Ep_Len=1000
# 	  Episod-1: Ep_Return=658.343928481871, Ep_Len=1000
# 	  Episod-2: Ep_Return=562.1863115855616, Ep_Len=1000
# 	  Episod-3: Ep_Return=730.1319758924069, Ep_Len=1000
# 	  Episod-4: Ep_Return=567.6036346683248, Ep_Len=1000
# 	  Episod-5: Ep_Return=635.3525965094702, Ep_Len=1000
# 	  Episod-6: Ep_Return=600.6378107450779, Ep_Len=1000
# 	  Episod-7: Ep_Return=572.0976491683874, Ep_Len=1000
# 	  Episod-8: Ep_Return=656.8467463905081, Ep_Len=1000
# 	  Episod-9: Ep_Return=755.724065436991, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=665.369653829179, Ep_Len=1000
# 	  Episod-1: Ep_Return=577.0146326335704, Ep_Len=1000
# 	  Episod-2: Ep_Return=683.0624537840849, Ep_Len=1000
# 	  Episod-3: Ep_Return=557.1416728425022, Ep_Len=1000
# 	  Episod-4: Ep_Return=544.6574225656924, Ep_Len=1000
# 	  Episod-5: Ep_Return=672.2881615245028, Ep_Len=1000
# 	  Episod-6: Ep_Return=505.64660039296064, Ep_Len=1000
# 	  Episod-7: Ep_Return=594.5262155878082, Ep_Len=1000
# 	  Episod-8: Ep_Return=772.69476048355, Ep_Len=1000
# 	  Episod-9: Ep_Return=569.7691775357118, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=725.0846381450716, Ep_Len=1000
# 	  Episod-1: Ep_Return=662.1016448309798, Ep_Len=1000
# 	  Episod-2: Ep_Return=585.3829610636772, Ep_Len=1000
# 	  Episod-3: Ep_Return=750.0589540828971, Ep_Len=1000
# 	  Episod-4: Ep_Return=654.5160210969586, Ep_Len=1000
# 	  Episod-5: Ep_Return=583.1855919228391, Ep_Len=1000
# 	  Episod-6: Ep_Return=532.2555247326454, Ep_Len=1000
# 	  Episod-7: Ep_Return=707.4940881141779, Ep_Len=1000
# 	  Episod-8: Ep_Return=698.7862879457555, Ep_Len=1000
# 	  Episod-9: Ep_Return=775.0669396535984, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=828.4743728735874, Ep_Len=1000
# 	  Episod-1: Ep_Return=538.7953919958178, Ep_Len=1000
# 	  Episod-2: Ep_Return=664.5727599932069, Ep_Len=1000
# 	  Episod-3: Ep_Return=627.4958248602484, Ep_Len=1000
# 	  Episod-4: Ep_Return=713.4895012230234, Ep_Len=1000
# 	  Episod-5: Ep_Return=718.0455829157899, Ep_Len=1000
# 	  Episod-6: Ep_Return=761.6327045715384, Ep_Len=1000
# 	  Episod-7: Ep_Return=632.6460305278544, Ep_Len=1000
# 	  Episod-8: Ep_Return=685.0605194639912, Ep_Len=1000
# 	  Episod-9: Ep_Return=543.0278401997626, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=551.779109115241, Ep_Len=1000
# 	  Episod-1: Ep_Return=706.8003063160018, Ep_Len=1000
# 	  Episod-2: Ep_Return=584.8180968727579, Ep_Len=1000
# 	  Episod-3: Ep_Return=690.4898052926463, Ep_Len=1000
# 	  Episod-4: Ep_Return=685.9770060004325, Ep_Len=1000
# 	  Episod-5: Ep_Return=765.7033843558871, Ep_Len=1000
# 	  Episod-6: Ep_Return=635.4057093691615, Ep_Len=1000
# 	  Episod-7: Ep_Return=569.7721536176837, Ep_Len=1000
# 	  Episod-8: Ep_Return=676.9839048535964, Ep_Len=1000
# 	  Episod-9: Ep_Return=583.8145989097003, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=559.865610297503, Ep_Len=1000
# 	  Episod-1: Ep_Return=693.05029655748, Ep_Len=1000
# 	  Episod-2: Ep_Return=738.7586347825741, Ep_Len=1000
# 	  Episod-3: Ep_Return=516.6308849553919, Ep_Len=1000
# 	  Episod-4: Ep_Return=676.7677965011333, Ep_Len=1000
# 	  Episod-5: Ep_Return=714.1450741643503, Ep_Len=1000
# 	  Episod-6: Ep_Return=624.6270515659929, Ep_Len=1000
# 	  Episod-7: Ep_Return=688.8460444622689, Ep_Len=1000
# 	  Episod-8: Ep_Return=584.7115511804041, Ep_Len=1000
# 	  Episod-9: Ep_Return=533.4428715445764, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=669.7555858757036, Ep_Len=1000
# 	  Episod-1: Ep_Return=563.6699063151432, Ep_Len=1000
# 	  Episod-2: Ep_Return=754.0604992183061, Ep_Len=1000
# 	  Episod-3: Ep_Return=684.6459267710652, Ep_Len=1000
# 	  Episod-4: Ep_Return=499.42481904988546, Ep_Len=1000
# 	  Episod-5: Ep_Return=675.8530931926365, Ep_Len=1000
# 	  Episod-6: Ep_Return=751.9161304588295, Ep_Len=1000
# 	  Episod-7: Ep_Return=594.2555401576287, Ep_Len=1000
# 	  Episod-8: Ep_Return=730.062952907062, Ep_Len=1000
# 	  Episod-9: Ep_Return=544.2785924416668, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '1']
# ********************************************************************
# 2021-01-22_22-45-30-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_1_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=645.8488070751011, Ep_Len=1000
# 	  Episod-1: Ep_Return=798.1624965040872, Ep_Len=1000
# 	  Episod-2: Ep_Return=691.6856906319251, Ep_Len=1000
# 	  Episod-3: Ep_Return=531.4273387364235, Ep_Len=1000
# 	  Episod-4: Ep_Return=795.4692781481909, Ep_Len=1000
# 	  Episod-5: Ep_Return=865.7031983547787, Ep_Len=1000
# 	  Episod-6: Ep_Return=790.2350947682827, Ep_Len=1000
# 	  Episod-7: Ep_Return=756.1756365835805, Ep_Len=1000
# 	  Episod-8: Ep_Return=746.544517085508, Ep_Len=1000
# 	  Episod-9: Ep_Return=759.374015129252, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=807.1559552475851, Ep_Len=1000
# 	  Episod-1: Ep_Return=887.6369096305652, Ep_Len=1000
# 	  Episod-2: Ep_Return=851.1506022844891, Ep_Len=1000
# 	  Episod-3: Ep_Return=573.337419394352, Ep_Len=1000
# 	  Episod-4: Ep_Return=840.7426493068542, Ep_Len=1000
# 	  Episod-5: Ep_Return=546.390720095823, Ep_Len=1000
# 	  Episod-6: Ep_Return=862.6034579277904, Ep_Len=1000
# 	  Episod-7: Ep_Return=874.2475708826506, Ep_Len=1000
# 	  Episod-8: Ep_Return=801.1554468765875, Ep_Len=1000
# 	  Episod-9: Ep_Return=807.1901494233728, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=712.7023715176475, Ep_Len=1000
# 	  Episod-1: Ep_Return=819.2996834283191, Ep_Len=1000
# 	  Episod-2: Ep_Return=844.5051557331338, Ep_Len=1000
# 	  Episod-3: Ep_Return=779.3081936179124, Ep_Len=1000
# 	  Episod-4: Ep_Return=760.8575037074222, Ep_Len=1000
# 	  Episod-5: Ep_Return=808.0050256751726, Ep_Len=1000
# 	  Episod-6: Ep_Return=799.3424443042978, Ep_Len=1000
# 	  Episod-7: Ep_Return=697.5624246266901, Ep_Len=1000
# 	  Episod-8: Ep_Return=793.7740173321076, Ep_Len=1000
# 	  Episod-9: Ep_Return=833.1238987642579, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=817.2844589505818, Ep_Len=1000
# 	  Episod-1: Ep_Return=652.7842164144869, Ep_Len=1000
# 	  Episod-2: Ep_Return=861.7982211744356, Ep_Len=1000
# 	  Episod-3: Ep_Return=651.9849799852188, Ep_Len=1000
# 	  Episod-4: Ep_Return=803.9128549752186, Ep_Len=1000
# 	  Episod-5: Ep_Return=838.3925063133571, Ep_Len=1000
# 	  Episod-6: Ep_Return=771.8788490815011, Ep_Len=1000
# 	  Episod-7: Ep_Return=798.447216695759, Ep_Len=1000
# 	  Episod-8: Ep_Return=841.8151596861886, Ep_Len=1000
# 	  Episod-9: Ep_Return=744.1511370994892, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=797.5628818309391, Ep_Len=1000
# 	  Episod-1: Ep_Return=727.7191395679733, Ep_Len=1000
# 	  Episod-2: Ep_Return=749.1588704761484, Ep_Len=1000
# 	  Episod-3: Ep_Return=829.2982549769084, Ep_Len=1000
# 	  Episod-4: Ep_Return=867.6916944810424, Ep_Len=1000
# 	  Episod-5: Ep_Return=834.0408117130705, Ep_Len=1000
# 	  Episod-6: Ep_Return=550.9602228844128, Ep_Len=1000
# 	  Episod-7: Ep_Return=729.9860690281722, Ep_Len=1000
# 	  Episod-8: Ep_Return=798.7899615081194, Ep_Len=1000
# 	  Episod-9: Ep_Return=766.3321981735402, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=814.828474766245, Ep_Len=1000
# 	  Episod-1: Ep_Return=821.2268390761468, Ep_Len=1000
# 	  Episod-2: Ep_Return=589.2826586983161, Ep_Len=1000
# 	  Episod-3: Ep_Return=518.9196689603574, Ep_Len=1000
# 	  Episod-4: Ep_Return=847.3194131770418, Ep_Len=1000
# 	  Episod-5: Ep_Return=771.1754471359196, Ep_Len=1000
# 	  Episod-6: Ep_Return=818.7538600291144, Ep_Len=1000
# 	  Episod-7: Ep_Return=841.3472149488828, Ep_Len=1000
# 	  Episod-8: Ep_Return=775.831626759556, Ep_Len=1000
# 	  Episod-9: Ep_Return=799.0096498658113, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return
Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2141.376701771394, Ep_Len=1000
# 	  Episod-1: Ep_Return=2130.9924401612016, Ep_Len=1000
# 	  Episod-2: Ep_Return=2198.945005084357, Ep_Len=1000
# 	  Episod-3: Ep_Return=2208.284042468892, Ep_Len=1000
# 	  Episod-4: Ep_Return=2151.041055264519, Ep_Len=1000
# 	  Episod-5: Ep_Return=2152.9775853903175, Ep_Len=1000
# 	  Episod-6: Ep_Return=2183.081048689759, Ep_Len=1000
# 	  Episod-7: Ep_Return=2176.624095347319, Ep_Len=1000
# 	  Episod-8: Ep_Return=2185.530958932174, Ep_Len=1000
# 	  Episod-9: Ep_Return=2185.953131707097, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2182.5109531056846, Ep_Len=1000
# 	  Episod-1: Ep_Return=2218.7372832391507, Ep_Len=1000
# 	  Episod-2: Ep_Return=2213.506786160084, Ep_Len=1000
# 	  Episod-3: Ep_Return=2167.2004022042765, Ep_Len=1000
# 	  Episod-4: Ep_Return=2192.7090031445405, Ep_Len=1000
# 	  Episod-5: Ep_Return=2191.0437577304556, Ep_Len=1000
# 	  Episod-6: Ep_Return=2213.648636766309, Ep_Len=1000
# 	  Episod-7: Ep_Return=2155.4903383283727, Ep_Len=1000
# 	  Episod-8: Ep_Return=2192.8757980016535, Ep_Len=1000
# 	  Episod-9: Ep_Return=2210.604236439047, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2196.0329999528885, Ep_Len=1000
# 	  Episod-1: Ep_Return=2173.574557709382, Ep_Len=1000
# 	  Episod-2: Ep_Return=2145.743487617116, Ep_Len=1000
# 	  Episod-3: Ep_Return=2115.7197510052843, Ep_Len=1000
# 	  Episod-4: Ep_Return=2173.394336008518, Ep_Len=1000
# 	  Episod-5: Ep_Return=2134.433014244864, Ep_Len=1000
# 	  Episod-6: Ep_Return=2194.7563549114966, Ep_Len=1000
# 	  Episod-7: Ep_Return=2106.87175194164, Ep_Len=1000
# 	  Episod-8: Ep_Return=2219.1000054227475, Ep_Len=1000
# 	  Episod-9: Ep_Return=2183.7833523434847, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=2221.0949628597627, Ep_Len=1000
# 	  Episod-1: Ep_Return=2209.943010999042, Ep_Len=1000
# 	  Episod-2: Ep_Return=2115.0863780122013, Ep_Len=1000
# 	  Episod-3: Ep_Return=2151.6724952796794, Ep_Len=1000
# 	  Episod-4: Ep_Return=2203.5637855607442, Ep_Len=1000
# 	  Episod-5: Ep_Return=2221.303445241433, Ep_Len=1000
# 	  Episod-6: Ep_Return=2230.3053065030053, Ep_Len=1000
# 	  Episod-7: Ep_Return=2117.8453859209008, Ep_Len=1000
# 	  Episod-8: Ep_Return=2234.0174979833064, Ep_Len=1000
# 	  Episod-9: Ep_Return=2182.0585043653628, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '5']
# ********************************************************************
# 2021-01-22_22-57-58-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_5_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=737.6146475214871, Ep_Len=1000
# 	  Episod-1: Ep_Return=909.6566069364237, Ep_Len=1000
# 	  Episod-2: Ep_Return=1050.4784030053331, Ep_Len=1000
# 	  Episod-3: Ep_Return=1118.5827422966004, Ep_Len=1000
# 	  Episod-4: Ep_Return=885.2587571601464, Ep_Len=1000
# 	  Episod-5: Ep_Return=672.8472770065327, Ep_Len=1000
# 	  Episod-6: Ep_Return=1093.2043012273941, Ep_Len=1000
# 	  Episod-7: Ep_Return=830.801235539605, Ep_Len=1000
# 	  Episod-8: Ep_Return=1074.8946548276535, Ep_Len=1000
# 	  Episod-9: Ep_Return=664.9889355997603, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=2060.5108759041523, Ep_Len=1000
# 	  Episod-1: Ep_Return=2060.770299752934, Ep_Len=1000
# 	  Episod-2: Ep_Return=2021.373214674663, Ep_Len=1000
# 	  Episod-3: Ep_Return=2098.1881747889424, Ep_Len=1000
# 	  Episod-4: Ep_Return=2092.3022277677974, Ep_Len=1000
# 	  Episod-5: Ep_Return=2031.4807044630463, Ep_Len=1000
# 	  Episod-6: Ep_Return=2103.8180638756967, Ep_Len=1000
# 	  Episod-7: Ep_Return=2040.2149086761876, Ep_Len=1000
# 	  Episod-8: Ep_Return=2101.447390640427, Ep_Len=1000
# 	  Episod-9: Ep_Return=2098.113924567899, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2108.146191558199, Ep_Len=1000
# 	  Episod-1: Ep_Return=2198.8211185361133, Ep_Len=1000
# 	  Episod-2: Ep_Return=2111.664007989221, Ep_Len=1000
# 	  Episod-3: Ep_Return=2178.877537546527, Ep_Len=1000
# 	  Episod-4: Ep_Return=2098.176941532279, Ep_Len=1000
# 	  Episod-5: Ep_Return=2093.9951507565943, Ep_Len=1000
# 	  Episod-6: Ep_Return=2205.2855436657687, Ep_Len=1000
# 	  Episod-7: Ep_Return=2258.666100959863, Ep_Len=1000
# 	  Episod-8: Ep_Return=2152.154746609943, Ep_Len=1000
# 	  Episod-9: Ep_Return=2146.1424146142, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2179.664994137048, Ep_Len=1000
# 	  Episod-1: Ep_Return=2114.4463735977342, Ep_Len=1000
# 	  Episod-2: Ep_Return=2116.3157484473477, Ep_Len=1000
# 	  Episod-3: Ep_Return=2142.602708605699, Ep_Len=1000
# 	  Episod-4: Ep_Return=2172.7827282722196, Ep_Len=1000
# 	  Episod-5: Ep_Return=2139.5033274745056, Ep_Len=1000
# 	  Episod-6: Ep_Return=2151.8920690531218, Ep_Len=1000
# 	  Episod-7: Ep_Return=2189.532189585918, Ep_Len=1000
# 	  Episod-8: Ep_Return=2130.069398041663, Ep_Len=1000
# 	  Episod-9: Ep_Return=2153.317940435652, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2130.621973604259, Ep_Len=1000
# 	  Episod-1: Ep_Return=2185.4843900376513, Ep_Len=1000
# 	  Episod-2: Ep_Return=2137.208592643496, Ep_Len=1000
# 	  Episod-3: Ep_Return=2125.9421615428914, Ep_Len=1000
# 	  Episod-4: Ep_Return=2135.701043061316, Ep_Len=1000
# 	  Episod-5: Ep_Return=2253.723538047079, Ep_Len=1000
# 	  Episod-6: Ep_Return=2234.777784270045, Ep_Len=1000
# 	  Episod-7: Ep_Return=2253.2184714459827, Ep_Len=1000
# 	  Episod-8: Ep_Return=2195.4797745739115, Ep_Len=1000
# 	  Episod-9: Ep_Return=2164.684509241081, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2114.8373911700237, Ep_Len=1000
# 	  Episod-1: Ep_Return=2207.6666235378166, Ep_Len=1000
# 	  Episod-2: Ep_Return=2187.76031277618, Ep_Len=1000
# 	  Episod-3: Ep_Return=2184.068965609622, Ep_Len=1000
# 	  Episod-4: Ep_Return=2133.7554145237323, Ep_Len=1000
# 	  Episod-5: Ep_Return=2045.0347249759363, Ep_Len=1000
# 	  Episod-6: Ep_Return=2177.440940461114, Ep_Len=1000
# 	  Episod-7: Ep_Return=2162.2159154261676, Ep_Len=1000
# 	  Episod-8: Ep_Return=2197.6223586536817, Ep_Len=1000
# 	  Episod-9: Ep_Return=2124.2478951798093, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=
Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=854.7312452224943, Ep_Len=1000
# 	  Episod-1: Ep_Return=824.2419533283098, Ep_Len=1000
# 	  Episod-2: Ep_Return=710.9087928289512, Ep_Len=1000
# 	  Episod-3: Ep_Return=659.8032161301709, Ep_Len=1000
# 	  Episod-4: Ep_Return=662.7832813843617, Ep_Len=1000
# 	  Episod-5: Ep_Return=699.3129049873382, Ep_Len=1000
# 	  Episod-6: Ep_Return=708.4821774343808, Ep_Len=1000
# 	  Episod-7: Ep_Return=694.1281351221669, Ep_Len=1000
# 	  Episod-8: Ep_Return=676.898314888003, Ep_Len=1000
# 	  Episod-9: Ep_Return=707.1122535961485, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=832.9385190906706, Ep_Len=1000
# 	  Episod-1: Ep_Return=648.1904301932949, Ep_Len=1000
# 	  Episod-2: Ep_Return=689.4743601832515, Ep_Len=1000
# 	  Episod-3: Ep_Return=694.2986235196347, Ep_Len=1000
# 	  Episod-4: Ep_Return=823.3114791867046, Ep_Len=1000
# 	  Episod-5: Ep_Return=854.7677636242681, Ep_Len=1000
# 	  Episod-6: Ep_Return=702.6479190902207, Ep_Len=1000
# 	  Episod-7: Ep_Return=736.3036506398696, Ep_Len=1000
# 	  Episod-8: Ep_Return=658.6988955101582, Ep_Len=1000
# 	  Episod-9: Ep_Return=802.434647175526, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=875.6448250903444, Ep_Len=1000
# 	  Episod-1: Ep_Return=659.1201132442806, Ep_Len=1000
# 	  Episod-2: Ep_Return=730.6069169470812, Ep_Len=1000
# 	  Episod-3: Ep_Return=789.5964308990174, Ep_Len=1000
# 	  Episod-4: Ep_Return=757.2986471504279, Ep_Len=1000
# 	  Episod-5: Ep_Return=756.5820866976422, Ep_Len=1000
# 	  Episod-6: Ep_Return=654.2652489064476, Ep_Len=1000
# 	  Episod-7: Ep_Return=845.2620334237981, Ep_Len=1000
# 	  Episod-8: Ep_Return=834.2060659834438, Ep_Len=1000
# 	  Episod-9: Ep_Return=743.1100721577882, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=778.5446710162271, Ep_Len=1000
# 	  Episod-1: Ep_Return=697.6643830164246, Ep_Len=1000
# 	  Episod-2: Ep_Return=763.9392593829798, Ep_Len=1000
# 	  Episod-3: Ep_Return=830.8180264199507, Ep_Len=1000
# 	  Episod-4: Ep_Return=759.3023145928238, Ep_Len=1000
# 	  Episod-5: Ep_Return=765.4700353371661, Ep_Len=1000
# 	  Episod-6: Ep_Return=785.8220251714569, Ep_Len=1000
# 	  Episod-7: Ep_Return=817.3911597533836, Ep_Len=1000
# 	  Episod-8: Ep_Return=805.5830887762678, Ep_Len=1000
# 	  Episod-9: Ep_Return=933.4919500951274, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=802.5642144077088, Ep_Len=1000
# 	  Episod-1: Ep_Return=892.5014886793441, Ep_Len=1000
# 	  Episod-2: Ep_Return=834.6068340599568, Ep_Len=1000
# 	  Episod-3: Ep_Return=743.2426043032962, Ep_Len=1000
# 	  Episod-4: Ep_Return=788.8548469662726, Ep_Len=1000
# 	  Episod-5: Ep_Return=827.5286661891126, Ep_Len=1000
# 	  Episod-6: Ep_Return=784.0101631473046, Ep_Len=1000
# 	  Episod-7: Ep_Return=793.1374659725706, Ep_Len=1000
# 	  Episod-8: Ep_Return=775.4229661251708, Ep_Len=1000
# 	  Episod-9: Ep_Return=764.463905946137, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return
Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=490.78059742908295, Ep_Len=1000
# 	  Episod-1: Ep_Return=454.5036142901348, Ep_Len=1000
# 	  Episod-2: Ep_Return=455.91317421643237, Ep_Len=1000
# 	  Episod-3: Ep_Return=548.9510082993338, Ep_Len=1000
# 	  Episod-4: Ep_Return=376.1505818064428, Ep_Len=1000
# 	  Episod-5: Ep_Return=396.5052623608947, Ep_Len=1000
# 	  Episod-6: Ep_Return=454.2957699685162, Ep_Len=1000
# 	  Episod-7: Ep_Return=525.5307474932338, Ep_Len=1000
# 	  Episod-8: Ep_Return=434.51420668330223, Ep_Len=1000
# 	  Episod-9: Ep_Return=549.7072410470981, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=483.10862657768797, Ep_Len=1000
# 	  Episod-1: Ep_Return=620.5476821052481, Ep_Len=1000
# 	  Episod-2: Ep_Return=488.9081982291928, Ep_Len=1000
# 	  Episod-3: Ep_Return=499.63530587070863, Ep_Len=1000
# 	  Episod-4: Ep_Return=425.2046119717434, Ep_Len=1000
# 	  Episod-5: Ep_Return=512.4960633977935, Ep_Len=1000
# 	  Episod-6: Ep_Return=579.9293430999602, Ep_Len=1000
# 	  Episod-7: Ep_Return=492.8752943076862, Ep_Len=1000
# 	  Episod-8: Ep_Return=497.73682975807884, Ep_Len=1000
# 	  Episod-9: Ep_Return=591.1294014868724, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=518.2454359839275, Ep_Len=1000
# 	  Episod-1: Ep_Return=458.479187668992, Ep_Len=1000
# 	  Episod-2: Ep_Return=625.2158017054137, Ep_Len=1000
# 	  Episod-3: Ep_Return=527.0742835730937, Ep_Len=1000
# 	  Episod-4: Ep_Return=452.4058070032959, Ep_Len=1000
# 	  Episod-5: Ep_Return=365.875824519554, Ep_Len=1000
# 	  Episod-6: Ep_Return=407.37294042396985, Ep_Len=1000
# 	  Episod-7: Ep_Return=522.507134605486, Ep_Len=1000
# 	  Episod-8: Ep_Return=512.9335940563031, Ep_Len=1000
# 	  Episod-9: Ep_Return=453.69227008833843, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=604.8681245473175, Ep_Len=1000
# 	  Episod-1: Ep_Return=362.6223493202448, Ep_Len=1000
# 	  Episod-2: Ep_Return=591.497147698187, Ep_Len=1000
# 	  Episod-3: Ep_Return=456.6784714751918, Ep_Len=1000
# 	  Episod-4: Ep_Return=467.0918989031659, Ep_Len=1000
# 	  Episod-5: Ep_Return=428.7599040514894, Ep_Len=1000
# 	  Episod-6: Ep_Return=481.18535567786915, Ep_Len=1000
# 	  Episod-7: Ep_Return=496.21282341148907, Ep_Len=1000
# 	  Episod-8: Ep_Return=563.6301380709863, Ep_Len=1000
# 	  Episod-9: Ep_Return=385.41084921405314, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_1
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '2', '1']
# ********************************************************************
# 2021-01-22_23-28-52-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_1_s2
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=832.8845902283783, Ep_Len=1000
# 	  Episod-1: Ep_Return=742.3805546867192, Ep_Len=1000
# 	  Episod-2: Ep_Return=777.1617881011595, Ep_Len=1000
# 	  Episod-3: Ep_Return=810.2007661713332, Ep_Len=1000
# 	  Episod-4: Ep_Return=787.8962900397532, Ep_Len=1000
# 	  Episod-5: Ep_Return=754.2831313734689, Ep_Len=1000
# 	  Episod-6: Ep_Return=752.7773718379614, Ep_Len=1000
# 	  Episod-7: Ep_Return=777.3058295123046, Ep_Len=1000
# 	  Episod-8: Ep_Return=768.8060291215479, Ep_Len=1000
# 	  Episod-9: Ep_Return=784.307157660184, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=847.6281869469352, Ep_Len=1000
# 	  Episod-1: Ep_Return=722.7130120829552, Ep_Len=1000
# 	  Episod-2: Ep_Return=842.4370676851669, Ep_Len=1000
# 	  Episod-3: Ep_Return=757.1699575637117, Ep_Len=1000
# 	  Episod-4: Ep_Return=857.1685600009038, Ep_Len=1000
# 	  Episod-5: Ep_Return=800.0519042862419, Ep_Len=1000
# 	  Episod-6: Ep_Return=853.6145193569826, Ep_Len=1000
# 	  Episod-7: Ep_Return=778.8525017667499, Ep_Len=1000
# 	  Episod-8: Ep_Return=800.6084870217368, Ep_Len=1000
# 	  Episod-9: Ep_Return=636.7366504233268, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=607.4240931891883, Ep_Len=1000
# 	  Episod-1: Ep_Return=735.3833722087602, Ep_Len=1000
# 	  Episod-2: Ep_Return=838.0035953492194, Ep_Len=1000
# 	  Episod-3: Ep_Return=725.0821220793988, Ep_Len=1000
# 	  Episod-4: Ep_Return=837.1426556102696, Ep_Len=1000
# 	  Episod-5: Ep_Return=754.6632847206029, Ep_Len=1000
# 	  Episod-6: Ep_Return=815.3316705916467, Ep_Len=1000
# 	  Episod-7: Ep_Return=893.3300706223067, Ep_Len=1000
# 	  Episod-8: Ep_Return=812.7064913682146, Ep_Len=1000
# 	  Episod-9: Ep_Return=928.1757966546784, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=736.7088301787203, Ep_Len=1000
# 	  Episod-1: Ep_Return=810.0464177223306, Ep_Len=1000
# 	  Episod-2: Ep_Return=808.1744126030077, Ep_Len=1000
# 	  Episod-3: Ep_Return=828.0277643214287, Ep_Len=1000
# 	  Episod-4: Ep_Return=788.7797585292515, Ep_Len=1000
# 	  Episod-5: Ep_Return=690.6516331833237, Ep_Len=1000
# 	  Episod-6: Ep_Return=811.3307264809484, Ep_Len=1000
# 	  Episod-7: Ep_Return=784.0830968056978, Ep_Len=1000
# 	  Episod-8: Ep_Return=829.6333566055778, Ep_Len=1000
# 	  Episod-9: Ep_Return=749.4413578356432, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=736.770957476703, Ep_Len=1000
# 	  Episod-1: Ep_Return=863.2486341888224, Ep_Len=1000
# 	  Episod-2: Ep_Return=736.1033842806021, Ep_Len=1000
# 	  Episod-3: Ep_Return=809.6090685916981, Ep_Len=1000
# 	  Episod-4: Ep_Return=771.7210615396323, Ep_Len=1000
# 	  Episod-5: Ep_Return=915.2815538477031, Ep_Len=1000
# 	  Episod-6: Ep_Return=798.942324104241, Ep_Len=1000
# 	  Episod-7: Ep_Return=781.1375526005197, Ep_Len=1000
# 	  Episod-8: Ep_Return=818.8784481445483, Ep_Len=1000
# 	  Episod-9: Ep_Return=778.896153028123, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=739.0922319036531, Ep_Len=1000
# 	  Episod-1: Ep_Return=830.2692322174245, Ep_Len=1000
# 	  Episod-2: Ep_Return=715.7864352542928, Ep_Len=1000
# 	  Episod-3: Ep_Return=807.4088724413075, Ep_Len=1000
# 	  Episod-4: Ep_Return=807.1109565739197, Ep_Len=1000
# 	  Episod-5: Ep_Return=748.4008577121509, Ep_Len=1000
# 	  Episod-6: Ep_Return=740.5980260751539, Ep_Len=1000
# 	  Episod-7: Ep_Return=741.2713219547943, Ep_Len=1000
# 	  Episod-8: Ep_Return=772.6404662845431, Ep_Len=1000
# 	  Episod-9: Ep_Return=838.9453856796587, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=791.5881149231768, Ep_Len=1000
# 	  Episod-1: Ep_Return=777.3590318834961, Ep_Len=1000
# 	  Episod-2: Ep_Return=763.3538576042779, Ep_Len=1000
# 	  Episod-3: Ep_Return=897.4147107116374, Ep_Len=1000
# 	  Episod-4: Ep_Return=842.554614392366, Ep_Len=1000
# 	  Episod-5: Ep_Return=810.9532642202383, Ep_Len=1000
# 	  Episod-6: Ep_Return=812.4553495939664, Ep_Len=1000
# 	  Episod-7: Ep_Return=770.2170246072274, Ep_Len=1000
# 	  Episod-8: Ep_Return=826.4627267092928, Ep_Len=1000
# 	  Episod-9: Ep_Return=755.2610777109538, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_3
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '2', '3']
# ********************************************************************
# 2021-01-22_23-28-52-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_3_s2
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=1100.3466558807459, Ep_Len=1000
# 	  Episod-1: Ep_Return=890.5184662311567, Ep_Len=1000
# 	  Episod-2: Ep_Return=1070.9906647978344, Ep_Len=1000
# 	  Episod-3: Ep_Return=1019.1128709506663, Ep_Len=1000
# 	  Episod-4: Ep_Return=995.463963020789, Ep_Len=1000
# 	  Episod-5: Ep_Return=958.916150051001, Ep_Len=1000
# 	  Episod-6: Ep_Return=587.0252870252485, Ep_Len=1000
# 	  Episod-7: Ep_Return=972.2508487284316, Ep_Len=1000
# 	  Episod-8: Ep_Return=848.7708343726006, Ep_Len=1000
# 	  Episod-9: Ep_Return=1005.4825588342827, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=2205.247911214438, Ep_Len=1000
# 	  Episod-1: Ep_Return=2238.0685459826673, Ep_Len=1000
# 	  Episod-2: Ep_Return=2103.5256591834764, Ep_Len=1000
# 	  Episod-3: Ep_Return=1899.6498337661603, Ep_Len=1000
# 	  Episod-4: Ep_Return=1997.320339244523, Ep_Len=1000
# 	  Episod-5: Ep_Return=1953.7684838616156, Ep_Len=1000
# 	  Episod-6: Ep_Return=2030.4274192683768, Ep_Len=1000
# 	  Episod-7: Ep_Return=1937.3538067202448, Ep_Len=1000
# 	  Episod-8: Ep_Return=2037.9709424311816, Ep_Len=1000
# 	  Episod-9: Ep_Return=1860.7014286640576, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2311.7686590564617, Ep_Len=1000
# 	  Episod-1: Ep_Return=2231.0185774750994, Ep_Len=1000
# 	  Episod-2: Ep_Return=2190.9436123536398, Ep_Len=1000
# 	  Episod-3: Ep_Return=2176.4517380832103, Ep_Len=1000
# 	  Episod-4: Ep_Return=2224.472768211619, Ep_Len=1000
# 	  Episod-5: Ep_Return=2247.1436799501175, Ep_Len=1000
# 	  Episod-6: Ep_Return=2263.3156949595286, Ep_Len=1000
# 	  Episod-7: Ep_Return=2195.795734646382, Ep_Len=1000
# 	  Episod-8: Ep_Return=2281.745883821809, Ep_Len=1000
# 	  Episod-9: Ep_Return=2225.081149800794, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2209.9815563486136, Ep_Len=1000
# 	  Episod-1: Ep_Return=2278.025942371722, Ep_Len=1000
# 	  Episod-2: Ep_Return=2267.4892393166006, Ep_Len=1000
# 	  Episod-3: Ep_Return=2226.242398133338, Ep_Len=1000
# 	  Episod-4: Ep_Return=2233.2151432550727, Ep_Len=1000
# 	  Episod-5: Ep_Return=2240.3162781519227, Ep_Len=1000
# 	  Episod-6: Ep_Return=2217.1268454863953, Ep_Len=1000
# 	  Episod-7: Ep_Return=2225.1243145538847, Ep_Len=1000
# 	  Episod-8: Ep_Return=2235.750125743472, Ep_Len=1000
# 	  Episod-9: Ep_Return=2183.843810433832, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2231.5760899836373, Ep_Len=1000
# 	  Episod-1: Ep_Return=2063.6802865921554, Ep_Len=1000
# 	  Episod-2: Ep_Return=2235.2497787391358, Ep_Len=1000
# 	  Episod-3: Ep_Return=2161.2377660848965, Ep_Len=1000
# 	  Episod-4: Ep_Return=2278.816209840033, Ep_Len=1000
# 	  Episod-5: Ep_Return=2243.919654538576, Ep_Len=1000
# 	  Episod-6: Ep_Return=2219.9593115708153, Ep_Len=1000
# 	  Episod-7: Ep_Return=2241.3355863706975, Ep_Len=1000
# 	  Episod-8: Ep_Return=2201.8690950761006, Ep_Len=1000
# 	  Episod-9: Ep_Return=2279.2014019418534, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2189.29035891502, Ep_Len=1000
# 	  Episod-1: Ep_Return=2182.167056832346, Ep_Len=1000
# 	  Episod-2: Ep_Return=2186.2237933438682, Ep_Len=1000
# 	  Episod-3: Ep_Return=2199.5320552172843, Ep_Len=1000
# 	  Episod-4: Ep_Return=2309.138625461694, Ep_Len=1000
# 	  Episod-5: Ep_Return=2196.349606981209, Ep_Len=1000
# 	  Episod-6: Ep_Return=2247.6712901723595, Ep_Len=1000
# 	  Episod-7: Ep_Return=2257.1932504905394, Ep_Len=1000
# 	  Episod-8: Ep_Return=2275.0753840186403, Ep_Len=1000
# 	  Episod-9: Ep_Return=2078.3510850724037, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=2280.063968135337, Ep_Len=1000
# 	  Episod-1: Ep_Return=2142.7492393106945, Ep_Len=1000
# 	  Episod-2: Ep_Return=2155.8269460572747, Ep_Len=1000
# 	  Episod-3: Ep_Return=2230.8528273991865, Ep_Len=1000
# 	  Episod-4: Ep_Return=2092.129225117205, Ep_Len=1000
# 	  Episod-5: Ep_Return=2258.6046853409184, Ep_Len=1000
# 	  Episod-6: Ep_Return=2157.6551784842113, Ep_Len=1000
# 	  Episod-7: Ep_Return=2141.401773742743, Ep_Len=1000
# 	  Episod-8: Ep_Return=2159.3900645643507, Ep_Len=1000
# 	  Episod-9: Ep_Return=2131.7247085439103, Ep_Len=1000
# 2021-01-22_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_5
# ['2021-01-22', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '2', '5']
# ********************************************************************
# 2021-01-22_23-28-52-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_2_5_s2
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=1766.2993398646615, Ep_Len=1000
# 	  Episod-1: Ep_Return=1829.5722069328313, Ep_Len=1000
# 	  Episod-2: Ep_Return=1729.2586830154237, Ep_Len=1000
# 	  Episod-3: Ep_Return=1682.4131536985124, Ep_Len=1000
# 	  Episod-4: Ep_Return=1797.00687489879, Ep_Len=1000
# 	  Episod-5: Ep_Return=1816.095305775425, Ep_Len=1000
# 	  Episod-6: Ep_Return=1760.5617592861813, Ep_Len=1000
# 	  Episod-7: Ep_Return=1749.4374374495856, Ep_Len=1000
# 	  Episod-8: Ep_Return=1677.945362243079, Ep_Len=1000
# 	  Episod-9: Ep_Return=1833.7556473796544, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=1872.4118912493927, Ep_Len=1000
# 	  Episod-1: Ep_Return=1895.3838674483984, Ep_Len=1000
# 	  Episod-2: Ep_Return=1905.8404681815769, Ep_Len=1000
# 	  Episod-3: Ep_Return=1913.0972875709133, Ep_Len=1000
# 	  Episod-4: Ep_Return=1854.1768370693683, Ep_Len=1000
# 	  Episod-5: Ep_Return=1821.46613672377, Ep_Len=1000
# 	  Episod-6: Ep_Return=1891.8893427274452, Ep_Len=1000
# 	  Episod-7: Ep_Return=1977.8847583603388, Ep_Len=1000
# 	  Episod-8: Ep_Return=1928.0878200351501, Ep_Len=1000
# 	  Episod-9: Ep_Return=1891.7535378000885, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2011.1906801291793, Ep_Len=1000
# 	  Episod-1: Ep_Return=1908.021942697106, Ep_Len=1000
# 	  Episod-2: Ep_Return=2014.6478336498435, Ep_Len=1000
# 	  Episod-3: Ep_Return=1889.231011463513, Ep_Len=1000
# 	  Episod-4: Ep_Return=1947.4554735339022, Ep_Len=1000
# 	  Episod-5: Ep_Return=2003.4917485157498, Ep_Len=1000
# 	  Episod-6: Ep_Return=1987.1845329199639, Ep_Len=1000
# 	  Episod-7: Ep_Return=2038.9926526142553, Ep_Len=1000
# 	  Episod-8: Ep_Return=2034.8795738630838, Ep_Len=1000
# 	  Episod-9: Ep_Return=1969.2795192736162, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2037.282902582053, Ep_Len=1000
# 	  Episod-1: Ep_Return=1949.3307709709077, Ep_Len=1000
# 	  Episod-2: Ep_Return=1923.6452708980823, Ep_Len=1000
# 	  Episod-3: Ep_Return=2046.989060162338, Ep_Len=1000
# 	  Episod-4: Ep_Return=1978.0616337016363, Ep_Len=1000
# 	  Episod-5: Ep_Return=1963.8342603850656, Ep_Len=1000
# 	  Episod-6: Ep_Return=1999.2827912045614, Ep_Len=1000
# 	  Episod-7: Ep_Return=1988.7032560087887, Ep_Len=1000
# 	  Episod-8: Ep_Return=1965.7976478233936, Ep_Len=1000
# 	  Episod-9: Ep_Return=2014.551518037241, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=1957.8961463022265, Ep_Len=1000
# ...
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'noise', '3', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_noise_3_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'noise', '3', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_noise_3_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'noise', '3', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_0_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_0_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_0_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_0_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_1_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_1_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_1_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_1_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_2_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_2_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_2_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_2_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_3_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_3_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_3_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_random_sensor_missing_3_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_0_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_0_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_0_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_0_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_1_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_1_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_1_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_1_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_2_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_2_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_2_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_2_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '5']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_3_0
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '0']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_3_1
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '1']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_3_3
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '3']
# 2021-01-23_LSTM-TD3_ReacherPyBulletEnv-v0_True_remove_velocity_3_5
# ['2021-01-23', 'LSTM-TD3', 'ReacherPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_0_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '0', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_0_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '0', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_0_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '0', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_0_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '0', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_2_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '2', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_2_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '2', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_2_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '2', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_2_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '2', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_3_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '3', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_3_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '3', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_3_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '3', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_3_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '3', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_0_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '0', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_0_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '0', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_0_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '0', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_0_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '0', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_1_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '1', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_1_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '1', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_1_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '1', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_1_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '1', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_2_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '2', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_2_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '2', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_2_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '2', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_2_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '2', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_3_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '3', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_3_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '3', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_3_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '3', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_noise_3_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'noise', '3', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_0_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_0_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_0_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_0_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '0', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_1_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_1_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_1_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_1_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '1', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_2_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_2_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_2_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_2_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '2', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_3_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_3_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_3_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_random_sensor_missing_3_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'random', 'sensor', 'missing', '3', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_0_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_0_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_0_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_0_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '0', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_1_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_1_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_1_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_1_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '1', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_2_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_2_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_2_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_2_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '2', '5']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_3_0
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '0']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_3_1
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '1']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_3_3
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '3']
# 2021-01-23_LSTM-TD3_Walker2DPyBulletEnv-v0_True_remove_velocity_3_5
# ['2021-01-23', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'remove', 'velocity', '3', '5']

# %%
import joblib
fname = 'D:\POMDP_Data\evaluation_on_different_environment.pkl'
# joblib.dump({'baselines_MDP_to_POMDP': MDP_to_POMDP, 'lstm_td3_MDP_to_POMDP': lstm_td3_MDP_to_POMDP, 
#              'baselines_POMDP_to_MDP': baselines_POMDP_to_MDP, 'lstm_td3_POMDP_to_MDP': lstm_td3_POMDP_to_MDP,
#              'lstm_td3_different_hist_len': lstm_td3_different_hist_len,
#              'lstm_td3_trained_on_MDP_different_hist_len': lstm_td3_trained_on_MDP_different_hist_len}, fname)
reload_collected_environment_change_data = joblib.load(fname)

# %%
lstm_td3_trained_on_MDP_different_hist_len = reload_collected_environment_change_data['lstm_td3_trained_on_MDP_different_hist_len']

# %%
lstm_td3_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0'].keys()
# Out:
# dict_keys(['flickering-0.05', 'flickering-0.1', 'flickering-0.15', 'flickering-0.2', 'flickering-0.25', 'flickering-0.3', 'flickering-0.35', 'flickering-0.4', 'flickering-0.45', 'flickering-0.5'])

# %%
original_hist_len = ['0', '1', '3', '5']
eval_results_on_diff_hist_len = {}
eval_results_on_diff_hist_len_mean = {}
eval_results_on_diff_hist_len_std = {}
for pomdp_type in ['flickering', 'random_noise', 'random_sensor_missing', 'remove_velocity']:
    eval_results_on_diff_hist_len[pomdp_type] = {}
    eval_results_on_diff_hist_len_mean[pomdp_type] = {}
    eval_results_on_diff_hist_len_std[pomdp_type] = {}
    for orig_hist_len in ['0', '1', '3', '5']:
        eval_results_on_diff_hist_len[pomdp_type][orig_hist_len] = {}
        eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len] = []
        eval_results_on_diff_hist_len_std[pomdp_type][orig_hist_len] = []
        for eval_hist_len in ['0', '1', '3', '5', '8', '10', '15']:
            eval_results = []
            for run_seed in ['0', '1', '2', '3']:
                eval_results += lstm_td3_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0'][pomdp_type][orig_hist_len][run_seed][eval_hist_len]
            eval_results_on_diff_hist_len[pomdp_type][orig_hist_len][eval_hist_len] = eval_results
            eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len].append(np.mean(eval_results))
            eval_results_on_diff_hist_len_std[pomdp_type][orig_hist_len].append(np.std(eval_results))

# %%
# lstm_td3_trained_on_MDP_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0']['0']['0']

# %%
lstm_td3_trained_on_MDP_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0'].keys()


lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len = {}
lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean = {}
lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_std = {}
    
for orig_hist_len in ['0', '1', '3', '5']:
    lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len[orig_hist_len] = {}
    lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean[orig_hist_len] = []
    lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_std[orig_hist_len] = []
    
    for eval_hist_len in ['0', '1', '3', '5', '8', '10', '15']:
        eval_results = []
        for run_seed in ['0', '1', '2', '3']:
            eval_results += lstm_td3_trained_on_MDP_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0'][orig_hist_len][run_seed][eval_hist_len]
        lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len[orig_hist_len][eval_hist_len] = eval_results
        lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean[orig_hist_len].append(np.mean(eval_results))
        lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_std[orig_hist_len].append(np.std(eval_results))

# %%
color = {'0':'c', '1':'m', '3':'b', '5':'r', 'DDPG':'k'}

fig, axes = plt.subplots(1, 5, figsize=(20, 4), sharey=True)
for axes_i, pomdp_type in enumerate(['MDP', 'remove_velocity', 'flickering', 'random_noise', 'random_sensor_missing']):
    if pomdp_type == 'MDP':
        # Trained on MDP
        for orig_hist_len in lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean.keys():
            axes[axes_i].plot(np.arange(7), lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean[orig_hist_len], 
                              label='Training Hist Len: {}'.format(orig_hist_len), color=color[orig_hist_len])
            if orig_hist_len == '0':
                index = 0
            if orig_hist_len == '1':
                index = 1
            if orig_hist_len == '3':
                index = 2
            if orig_hist_len == '5':
                index = 3
            axes[axes_i].scatter(index, lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean[orig_hist_len][index],
                                 color=color[orig_hist_len], s=100)
        axes[axes_i].set_xticks(np.arange(7))
        axes[axes_i].set_xticklabels(['0', '1', '3', '5', '8', '10', '15'])
        axes[axes_i].set_xlabel('Evaluation History Length')
        axes[axes_i].set_ylabel('Average Return')
        axes[axes_i].set_title('{}'.format(pomdp_type))
        axes[axes_i].grid(linestyle=':')
    else:
        # Trained on POMDP
        for orig_hist_len in eval_results_on_diff_hist_len_mean[pomdp_type].keys():
            axes[axes_i].plot(np.arange(7), eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len], 
                              label='Training Hist Len: {}'.format(orig_hist_len), color=color[orig_hist_len])
#             axes[axes_i].errorbar(np.arange(7), eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len], 
#                                   yerr=eval_results_on_diff_hist_len_std[pomdp_type][orig_hist_len], label='Training Hist Len: {}'.format(orig_hist_len))
            if orig_hist_len == '0':
                index = 0
            if orig_hist_len == '1':
                index = 1
            if orig_hist_len == '3':
                index = 2
            if orig_hist_len == '5':
                index = 3
            axes[axes_i].scatter(index, eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len][index],
                                 color=color[orig_hist_len], s=100)
        axes[axes_i].set_xticks(np.arange(7))
        axes[axes_i].set_xticklabels(['0', '1', '3', '5', '8', '10', '15'])
        axes[axes_i].set_xlabel('Evaluation History Length')
        axes[axes_i].set_ylabel('Average Return')
        if pomdp_type == 'remove_velocity':
            pomdp_type = 'POMDP-RV'
        if pomdp_type == 'flickering':
            pomdp_type = 'POMDP-FLK'
        if pomdp_type == 'random_noise':
            pomdp_type = 'POMDP-RN'
        if pomdp_type == 'random_sensor_missing':
            pomdp_type = 'POMDP-RSM'
        axes[axes_i].set_title('{}'.format(pomdp_type))
        axes[axes_i].grid(linestyle=':')
plt.tight_layout()
fig.suptitle("{}".format('AntPyBulletEnv-v0'), fontsize=24)
fig.subplots_adjust(top=0.8)
fig.savefig("D:\POMDP_Data\images\evaluation_on_different_history_length.png", bbox_inches='tight')

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

color = {'0':'c', '1':'m', '3':'b', '5':'r'}

lw_scale = 4

legend_elements= []
for train_hist_len in color.keys():
    label='LSTM-TD3({})'.format(train_hist_len)
    legend_elements.append(Line2D([0], [0], color=color[train_hist_len], lw=lw_scale*1, label=label))

# Create the figure
fig, ax = plt.subplots()
ax.legend(handles=legend_elements, loc='center', ncol=4)
ax.axis(False)
plt.show()
plt.rc('font', size=30)
fig.savefig("D:\POMDP_Data\images\evaluation_on_different_history_length_legend.png", bbox_inches='tight')

# %%
plt.rc('font', size=16)

# %% [markdown]
# ### POMDP-FLK

# %%
import torch.nn as nn

# %%
root_dir = r"D:\new_spinup_resumable_POMDP_LSTM_TD3_POMDP-FLK"
DEVICE = "cpu"  # "cuda"

lstm_td3_different_hist_len_POMDP_FLK = {}
for sub_dir in os.listdir(root_dir):
    if 'lstm_td3' in sub_dir:
        print(sub_dir)
        print(sub_dir.split('_'))
        params = sub_dir.split('_')
        alg_name = '-'.format(params[1].upper(), params[2].upper)
        task_name = params[3]
        seed = params[4]
        hist_len = params[6]
        
        pomdp_hyperparam = 'POMDP-{}'.format('-'.join(params[-2:]))
        
        if task_name in tasks:
            if alg_name not in lstm_td3_different_hist_len_POMDP_FLK:
                lstm_td3_different_hist_len_POMDP_FLK[alg_name] = {}
            if task_name not in lstm_td3_different_hist_len_POMDP_FLK[alg_name]:
                lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name] = {}
            if pomdp_hyperparam not in lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name]:
                lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name][pomdp_hyperparam] = {}
            if hist_len not in lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name][pomdp_hyperparam]:
                lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name][pomdp_hyperparam][hist_len] = {}
            if seed not in lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name][pomdp_hyperparam][hist_len]:
                lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name][pomdp_hyperparam][hist_len][seed] = {}
            #
            print("********************************************************************")
            for exp_run in os.listdir(os.path.join(root_dir, sub_dir)):
                print(exp_run)
                # Load pre-trained model
                config_path = os.path.join(root_dir, sub_dir, exp_run, 'config.json')
                with open(config_path, 'r') as config_file:
                    config_json = json.load(config_file)
                model_path = os.path.join(root_dir, sub_dir, exp_run, 'pyt_save', 'model.pt')
                ac = torch.load(model_path)
                ac.pi.mem_after_lstm_layers = nn.ModuleList()
                # print(ac)
                
                # Evaluate on the same environment, but with different history length.
                for eval_hist_len in [0, 1, 3, 5, 8, 10, 15]:
                    print("\t{}".format(eval_hist_len))
                    lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name][pomdp_hyperparam][hist_len][seed]['{}'.format(eval_hist_len)] = []

                    # Evaluation
                    for j in range(num_test_episodes):
                        # Reset environment
                        o, d, ep_ret, ep_len = env.reset(), False, 0, 0
                        if eval_hist_len > 0:
                            o_buff = np.zeros([eval_hist_len, obs_dim])
                            a_buff = np.zeros([eval_hist_len, act_dim])
                            o_buff[0, :] = o
                            o_buff_len = 0
                        else:
                            o_buff = np.zeros([1, obs_dim])
                            a_buff = np.zeros([1, act_dim])
                            o_buff_len = 0

                        # Interact
                        while not(d or (ep_len == max_ep_len)):
                            # Take deterministic actions at test time 
                            h_o = torch.tensor(o_buff).view(1, o_buff.shape[0], o_buff.shape[1]).float().to(DEVICE)
                            h_a = torch.tensor(a_buff).view(1, a_buff.shape[0], a_buff.shape[1]).float().to(DEVICE)
                            h_l = torch.tensor([o_buff_len]).float().to(DEVICE)
                            a = ac.act(torch.as_tensor(o, dtype=torch.float32).view(1, -1).to(DEVICE),
                                       h_o, h_a, h_l).reshape(act_dim)

                            o2, r, d, _ = env.step(a)
                            ep_ret += r
                            ep_len += 1

                            # Add short history
                            if eval_hist_len != 0:
                                if o_buff_len == eval_hist_len:
                                    o_buff[:eval_hist_len - 1] = o_buff[1:]
                                    a_buff[:eval_hist_len - 1] = a_buff[1:]
                                    o_buff[eval_hist_len - 1] = list(o)
                                    a_buff[eval_hist_len - 1] = list(a)
                                else:
                                    o_buff[o_buff_len + 1 - 1] = list(o)
                                    a_buff[o_buff_len + 1 - 1] = list(a)
                                    o_buff_len += 1
                            o = o2
                        print('\t  Episod-{}: Ep_Return={}, Ep_Len={}'.format(j, ep_ret, ep_len))
                        lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name][pomdp_hyperparam][hist_len][seed]['{}'.format(eval_hist_len)].append(ep_ret)

# %%
lstm_td3_different_hist_len_POMDP_FLK[alg_name][task_name][pomdp_hyperparam]
# Out:
# {'0': {}}

# %%
tasks = ['AntPyBulletEnv-v0']

root_dir = r"D:\new_spinup_resumable_POMDP_LSTM_TD3_POMDP-FLK"
DEVICE = "cpu"  # "cuda"

# lstm_td3_different_hist_len = {}
for sub_dir in os.listdir(root_dir):
    print(sub_dir)
    print(sub_dir.split('_'))
    params = sub_dir.split('_')
    alg_name = params[1]
    task_name = params[2]
    pomdp_hyperparam = '{}-{}'.format(params[4], params[-1])
    seed = params[-3]
    hist_len = params[-2]
    
    if task_name in tasks:
        if alg_name not in lstm_td3_different_hist_len:
            lstm_td3_different_hist_len[alg_name] = {}
        if task_name not in lstm_td3_different_hist_len[alg_name]:
            lstm_td3_different_hist_len[alg_name][task_name] = {}
        if pomdp_hyperparam not in lstm_td3_different_hist_len[alg_name][task_name]:
            lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam] = {}
        if hist_len not in lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam]:
            lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len] = {}
        if seed not in lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len]:
            lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len][seed] = {}
        #
        print("********************************************************************")
        for exp_run in os.listdir(os.path.join(root_dir, sub_dir)):
            print(exp_run)
            # Load pre-trained model
            config_path = os.path.join(root_dir, sub_dir, exp_run, 'config.json')
            with open(config_path, 'r') as config_file:
                config_json = json.load(config_file)
            # Retrive hyper-parameters
            env_name = config_json['env_name']
            num_test_episodes = config_json['num_test_episodes']
            max_ep_len = config_json['max_ep_len']
            max_hist_len = config_json['max_hist_len']
            
            # Create environment
            if config_json['partially_observable']:
                env = POMDPWrapper(env_name, config_json['pomdp_type'], 
                                   config_json['flicker_prob'], config_json['random_noise_sigma'], 
                                   config_json['random_sensor_missing_prob'])
            else:
                env = gym.make(env_name)
            
            obs_dim = env.observation_space.shape[0]
            act_dim = env.action_space.shape[0]
            act_limit = env.action_space.high[0]
            
            critic_mem_pre_lstm_hid_sizes = config_json['critic_mem_pre_lstm_hid_sizes']
            critic_mem_lstm_hid_sizes = config_json['critic_mem_lstm_hid_sizes']
            critic_mem_after_lstm_hid_size = config_json['critic_mem_after_lstm_hid_size']
            critic_cur_feature_hid_sizes = config_json['critic_cur_feature_hid_sizes']
            critic_post_comb_hid_sizes = config_json['critic_post_comb_hid_sizes']
            critic_mem_gate = config_json['critic_mem_gate']
            critic_mem_gate_before_current_feature_extraction = config_json['critic_mem_gate_before_current_feature_extraction']
            critic_hist_with_past_act = config_json['critic_hist_with_past_act']
            critic_use_hist_mask = config_json['critic_use_hist_mask']
            actor_mem_pre_lstm_hid_sizes = config_json['actor_mem_pre_lstm_hid_sizes']
            actor_mem_lstm_hid_sizes = config_json['actor_mem_lstm_hid_sizes']
            actor_mem_after_lstm_hid_size = config_json['actor_mem_after_lstm_hid_size']
            actor_cur_feature_hid_sizes = config_json['actor_cur_feature_hid_sizes']
            actor_post_comb_hid_sizes = config_json['actor_post_comb_hid_sizes']
            actor_mem_gate = config_json['actor_mem_gate']
            actor_mem_gate_before_current_feature_extraction = config_json['actor_mem_gate_before_current_feature_extraction']
            actor_hist_with_past_act = config_json['actor_hist_with_past_act']
            actor_use_hist_mask = config_json['actor_use_hist_mask']    
            ac = MLPActorCritic(obs_dim, act_dim, act_limit,
                                critic_mem_pre_lstm_hid_sizes=critic_mem_pre_lstm_hid_sizes,
                                critic_mem_lstm_hid_sizes=critic_mem_lstm_hid_sizes,
                                critic_mem_after_lstm_hid_size=critic_mem_after_lstm_hid_size,
                                critic_cur_feature_hid_sizes=critic_cur_feature_hid_sizes,
                                critic_post_comb_hid_sizes=critic_post_comb_hid_sizes,
                                critic_mem_gate=critic_mem_gate,
                                critic_mem_gate_before_current_feature_extraction=critic_mem_gate_before_current_feature_extraction,
                                critic_hist_with_past_act=critic_hist_with_past_act,
                                critic_use_hist_mask=critic_use_hist_mask,
                                actor_mem_pre_lstm_hid_sizes=actor_mem_pre_lstm_hid_sizes,
                                actor_mem_lstm_hid_sizes=actor_mem_lstm_hid_sizes,
                                actor_mem_after_lstm_hid_size=actor_mem_after_lstm_hid_size,
                                actor_cur_feature_hid_sizes=actor_cur_feature_hid_sizes,
                                actor_post_comb_hid_sizes=actor_post_comb_hid_sizes,
                                actor_mem_gate=actor_mem_gate,
                                actor_mem_gate_before_current_feature_extraction=actor_mem_gate_before_current_feature_extraction,
                                actor_hist_with_past_act=actor_hist_with_past_act,
                                actor_use_hist_mask=actor_use_hist_mask)
            # Load model
            resume_checkpoint_path = os.path.join(root_dir, sub_dir, exp_run, "pyt_save")
            checkpoint_files = os.listdir(resume_checkpoint_path)
            latest_model_checkpoint_file_path = os.path.join(resume_checkpoint_path, checkpoint_files[-1])
            
            model_checkpoint = torch.load(latest_model_checkpoint_file_path)
            ac.load_state_dict(model_checkpoint['ac_state_dict'])
            
            # print(ac)
            
            # Evaluate on the same environment, but with different history length.
#             for eval_hist_len in [0, 1, 3, 5, 8, 10, 15]:
            for eval_hist_len in [12, 18, 20]:
                print("\t{}".format(eval_hist_len))
                lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len][seed]['{}'.format(eval_hist_len)] = []
                
                # Evaluation
                for j in range(num_test_episodes):
                    # Reset environment
                    o, d, ep_ret, ep_len = env.reset(), False, 0, 0
                    if eval_hist_len > 0:
                        o_buff = np.zeros([eval_hist_len, obs_dim])
                        a_buff = np.zeros([eval_hist_len, act_dim])
                        o_buff[0, :] = o
                        o_buff_len = 0
                    else:
                        o_buff = np.zeros([1, obs_dim])
                        a_buff = np.zeros([1, act_dim])
                        o_buff_len = 0

                    # Interact
                    while not(d or (ep_len == max_ep_len)):
                        # Take deterministic actions at test time 
                        h_o = torch.tensor(o_buff).view(1, o_buff.shape[0], o_buff.shape[1]).float().to(DEVICE)
                        h_a = torch.tensor(a_buff).view(1, a_buff.shape[0], a_buff.shape[1]).float().to(DEVICE)
                        h_l = torch.tensor([o_buff_len]).float().to(DEVICE)
                        a = ac.act(torch.as_tensor(o, dtype=torch.float32).view(1, -1).to(DEVICE),
                                   h_o, h_a, h_l).reshape(act_dim)
                        
                        o2, r, d, _ = env.step(a)
                        ep_ret += r
                        ep_len += 1

                        # Add short history
                        if eval_hist_len != 0:
                            if o_buff_len == eval_hist_len:
                                o_buff[:eval_hist_len - 1] = o_buff[1:]
                                a_buff[:eval_hist_len - 1] = a_buff[1:]
                                o_buff[eval_hist_len - 1] = list(o)
                                a_buff[eval_hist_len - 1] = list(a)
                            else:
                                o_buff[o_buff_len + 1 - 1] = list(o)
                                a_buff[o_buff_len + 1 - 1] = list(a)
                                o_buff_len += 1
                        o = o2
                    print('\t  Episod-{}: Ep_Return={}, Ep_Len={}'.format(j, ep_ret, ep_len))
                    lstm_td3_different_hist_len[alg_name][task_name][pomdp_hyperparam][hist_len][seed]['{}'.format(eval_hist_len)].append(ep_ret)
# Out:
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.05
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.05']
# ********************************************************************
# 2021-02-02_20-45-28-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.05_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=777.846722124906, Ep_Len=1000
# 	  Episod-1: Ep_Return=742.8917986446975, Ep_Len=1000
# 	  Episod-2: Ep_Return=794.316487063712, Ep_Len=1000
# 	  Episod-3: Ep_Return=724.6441623059943, Ep_Len=1000
# 	  Episod-4: Ep_Return=754.2815077314445, Ep_Len=1000
# 	  Episod-5: Ep_Return=823.9801654668262, Ep_Len=1000
# 	  Episod-6: Ep_Return=752.8474273819745, Ep_Len=1000
# 	  Episod-7: Ep_Return=843.4290870686118, Ep_Len=1000
# 	  Episod-8: Ep_Return=739.9188876452969, Ep_Len=1000
# 	  Episod-9: Ep_Return=691.410359454558, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=756.5279043146342, Ep_Len=1000
# 	  Episod-1: Ep_Return=832.665843683525, Ep_Len=1000
# 	  Episod-2: Ep_Return=766.4005982102763, Ep_Len=1000
# 	  Episod-3: Ep_Return=841.2109946037779, Ep_Len=1000
# 	  Episod-4: Ep_Return=739.4154207187916, Ep_Len=1000
# 	  Episod-5: Ep_Return=763.5302473915705, Ep_Len=1000
# 	  Episod-6: Ep_Return=800.3588600511713, Ep_Len=1000
# 	  Episod-7: Ep_Return=815.2898997106171, Ep_Len=1000
# 	  Episod-8: Ep_Return=771.6743517382281, Ep_Len=1000
# 	  Episod-9: Ep_Return=777.8594145187977, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=830.4415579166598, Ep_Len=1000
# 	  Episod-1: Ep_Return=800.2075752933873, Ep_Len=1000
# 	  Episod-2: Ep_Return=718.3616240244, Ep_Len=1000
# 	  Episod-3: Ep_Return=714.4623760977167, Ep_Len=1000
# 	  Episod-4: Ep_Return=752.9286984870336, Ep_Len=1000
# 	  Episod-5: Ep_Return=839.133196792581, Ep_Len=1000
# 	  Episod-6: Ep_Return=778.8207910225022, Ep_Len=1000
# 	  Episod-7: Ep_Return=827.3420209271061, Ep_Len=1000
# 	  Episod-8: Ep_Return=839.0105445622875, Ep_Len=1000
# 	  Episod-9: Ep_Return=795.333617704551, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=888.3433087316761, Ep_Len=1000
# 	  Episod-1: Ep_Return=774.1301214518804, Ep_Len=1000
# 	  Episod-2: Ep_Return=742.9079124833208, Ep_Len=1000
# 	  Episod-3: Ep_Return=706.9477649423872, Ep_Len=1000
# 	  Episod-4: Ep_Return=786.9972276818112, Ep_Len=1000
# 	  Episod-5: Ep_Return=776.0357009028262, Ep_Len=1000
# 	  Episod-6: Ep_Return=666.0854503343286, Ep_Len=1000
# 	  Episod-7: Ep_Return=749.4256809730566, Ep_Len=1000
# 	  Episod-8: Ep_Return=790.3973448274933, Ep_Len=1000
# 	  Episod-9: Ep_Return=753.8900972111142, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=733.3448400630717, Ep_Len=1000
# 	  Episod-1: Ep_Return=738.0496160019948, Ep_Len=1000
# 	  Episod-2: Ep_Return=701.0200079103013, Ep_Len=1000
# 	  Episod-3: Ep_Return=739.1772788374703, Ep_Len=1000
# 	  Episod-4: Ep_Return=724.5840124614355, Ep_Len=1000
# 	  Episod-5: Ep_Return=749.9597311248779, Ep_Len=1000
# 	  Episod-6: Ep_Return=822.53949974568, Ep_Len=1000
# 	  Episod-7: Ep_Return=708.766843417441, Ep_Len=1000
# 	  Episod-8: Ep_Return=765.7587002305576, Ep_Len=1000
# 	  Episod-9: Ep_Return=800.9833438324509, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=805.3807220638603, Ep_Len=1000
# 	  Episod-1: Ep_Return=786.4870470664005, Ep_Len=1000
# 	  Episod-2: Ep_Return=774.844587876869, Ep_Len=1000
# 	  Episod-3: Ep_Return=736.439902509511, Ep_Len=1000
# 	  Episod-4: Ep_Return=701.3608333056698, Ep_Len=1000
# 	  Episod-5: Ep_Return=681.5028866748578, Ep_Len=1000
# 	  Episod-6: Ep_Return=786.267272569245, Ep_Len=1000
# 	  Episod-7: Ep_Return=678.9760356928908, Ep_Len=1000
# 	  Episod-8: Ep_Return=812.5051782793108, Ep_Len=1000
# 	  Episod-9: Ep_Return=813.032034719657, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=754.4299536775729, Ep_Len=1000
# 	  Episod-1: Ep_Return=748.7823458770192, Ep_Len=1000
# 	  Episod-2: Ep_Return=730.6491772289979, Ep_Len=1000
# 	  Episod-3: Ep_Return=767.5850224920077, Ep_Len=1000
# 	  Episod-4: Ep_Return=835.3758059140314, Ep_Len=1000
# 	  Episod-5: Ep_Return=736.2460567906203, Ep_Len=1000
# 	  Episod-6: Ep_Return=791.4467784818947, Ep_Len=1000
# 	  Episod-7: Ep_Return=836.7274549118733, Ep_Len=1000
# 	  Episod-8: Ep_Return=759.2840114518776, Ep_Len=1000
# 	  Episod-9: Ep_Return=684.1077413983598, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.1
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.1']
# ********************************************************************
# 2021-02-02_20-50-14-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.1_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=683.9922232205049, Ep_Len=1000
# 	  Episod-1: Ep_Return=671.8581887433065, Ep_Len=1000
# 	  Episod-2: Ep_Return=665.1431588524948, Ep_Len=1000
# 	  Episod-3: Ep_Return=568.8984310518615, Ep_Len=1000
# 	  Episod-4: Ep_Return=660.5955670105091, Ep_Len=1000
# 	  Episod-5: Ep_Return=475.9272059909706, Ep_Len=1000
# 	  Episod-6: Ep_Return=571.509864389296, Ep_Len=1000
# 	  Episod-7: Ep_Return=675.3108409125967, Ep_Len=1000
# 	  Episod-8: Ep_Return=505.023737461519, Ep_Len=1000
# 	  Episod-9: Ep_Return=686.3197353823722, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=511.15358357653804, Ep_Len=1000
# 	  Episod-1: Ep_Return=558.1558585497002, Ep_Len=1000
# 	  Episod-2: Ep_Return=559.7398281648185, Ep_Len=1000
# 	  Episod-3: Ep_Return=690.9470826528234, Ep_Len=1000
# 	  Episod-4: Ep_Return=625.499736781466, Ep_Len=1000
# 	  Episod-5: Ep_Return=569.6501803057077, Ep_Len=1000
# 	  Episod-6: Ep_Return=571.5454354888207, Ep_Len=1000
# 	  Episod-7: Ep_Return=640.22202398119, Ep_Len=1000
# 	  Episod-8: Ep_Return=602.2000270010548, Ep_Len=1000
# 	  Episod-9: Ep_Return=457.1063137148579, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=744.4243827462508, Ep_Len=1000
# 	  Episod-1: Ep_Return=407.7952425071781, Ep_Len=1000
# 	  Episod-2: Ep_Return=567.9253465362086, Ep_Len=1000
# 	  Episod-3: Ep_Return=588.9016297682466, Ep_Len=1000
# 	  Episod-4: Ep_Return=466.4530405524151, Ep_Len=1000
# 	  Episod-5: Ep_Return=668.5727283811692, Ep_Len=1000
# 	  Episod-6: Ep_Return=504.3154827427684, Ep_Len=1000
# 	  Episod-7: Ep_Return=429.9532689746828, Ep_Len=1000
# 	  Episod-8: Ep_Return=482.47775525659836, Ep_Len=1000
# 	  Episod-9: Ep_Return=423.7715288856493, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=632.8236882965881, Ep_Len=1000
# 	  Episod-1: Ep_Return=775.9128346072865, Ep_Len=1000
# 	  Episod-2: Ep_Return=489.71713402792517, Ep_Len=1000
# 	  Episod-3: Ep_Return=406.5471468371812, Ep_Len=1000
# 	  Episod-4: Ep_Return=482.5500370006467, Ep_Len=1000
# 	  Episod-5: Ep_Return=671.3746159683565, Ep_Len=1000
# 	  Episod-6: Ep_Return=457.9614248889686, Ep_Len=1000
# 	  Episod-7: Ep_Return=567.4443653299319, Ep_Len=1000
# 	  Episod-8: Ep_Return=418.86562513717774, Ep_Len=1000
# 	  Episod-9: Ep_Return=398.25707281434455, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=680.4034957153933, Ep_Len=1000
# 	  Episod-1: Ep_Return=548.9478795523717, Ep_Len=1000
# 	  Episod-2: Ep_Return=585.7063193670328, Ep_Len=1000
# 	  Episod-3: Ep_Return=558.1481605674729, Ep_Len=1000
# 	  Episod-4: Ep_Return=602.8281746629123, Ep_Len=1000
# 	  Episod-5: Ep_Return=671.4112435704076, Ep_Len=1000
# 	  Episod-6: Ep_Return=616.2799700862046, Ep_Len=1000
# 	  Episod-7: Ep_Return=469.3481630039873, Ep_Len=1000
# 	  Episod-8: Ep_Return=659.7607852184827, Ep_Len=1000
# 	  Episod-9: Ep_Return=482.06826835754913, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=591.1047125607818, Ep_Len=1000
# 	  Episod-1: Ep_Return=681.0192293851119, Ep_Len=1000
# 	  Episod-2: Ep_Return=383.1777126723243, Ep_Len=1000
# 	  Episod-3: Ep_Return=672.4311141463584, Ep_Len=1000
# 	  Episod-4: Ep_Return=643.2984771963502, Ep_Len=1000
# 	  Episod-5: Ep_Return=662.9441058868867, Ep_Len=1000
# 	  Episod-6: Ep_Return=584.6576214255828, Ep_Len=1000
# 	  Episod-7: Ep_Return=479.7391279906586, Ep_Len=1000
# 	  Episod-8: Ep_Return=677.2477034330043, Ep_Len=1000
# 	  Episod-9: Ep_Return=632.1020681641997, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=385.127617819444, Ep_Len=1000
# 	  Episod-1: Ep_Return=422.9551096951786, Ep_Len=1000
# 	  Episod-2: Ep_Return=618.0437618908514, Ep_Len=1000
# 	  Episod-3: Ep_Return=775.0426305423508, Ep_Len=1000
# 	  Episod-4: Ep_Return=658.2343835475622, Ep_Len=1000
# 	  Episod-5: Ep_Return=585.7026098411081, Ep_Len=1000
# 	  Episod-6: Ep_Return=366.87829275648403, Ep_Len=1000
# 	  Episod-7: Ep_Return=482.06243040638464, Ep_Len=1000
# 	  Episod-8: Ep_Return=479.8457990744421, Ep_Len=1000
# 	  Episod-9: Ep_Return=429.8348822076373, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.15
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.15']
# ********************************************************************
# 2021-02-02_20-50-14-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.15_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=596.8193819581172, Ep_Len=1000
# 	  Episod-1: Ep_Return=318.9172271596549, Ep_Len=1000
# 	  Episod-2: Ep_Return=545.2306622014426, Ep_Len=1000
# 	  Episod-3: Ep_Return=418.42852170890404, Ep_Len=1000
# 	  Episod-4: Ep_Return=459.129164865438, Ep_Len=1000
# 	  Episod-5: Ep_Return=423.2217057936482, Ep_Len=1000
# 	  Episod-6: Ep_Return=492.19505709977597, Ep_Len=1000
# 	  Episod-7: Ep_Return=520.6361592382672, Ep_Len=1000
# 	  Episod-8: Ep_Return=409.1233568255265, Ep_Len=1000
# 	  Episod-9: Ep_Return=475.5539502622281, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=436.69742476613845, Ep_Len=1000
# 	  Episod-1: Ep_Return=392.99504796176086, Ep_Len=1000
# 	  Episod-2: Ep_Return=479.2482017589732, Ep_Len=1000
# 	  Episod-3: Ep_Return=406.384697929634, Ep_Len=1000
# 	  Episod-4: Ep_Return=462.3157674833827, Ep_Len=1000
# 	  Episod-5: Ep_Return=366.5694111081175, Ep_Len=1000
# 	  Episod-6: Ep_Return=407.42443876481457, Ep_Len=1000
# 	  Episod-7: Ep_Return=411.99438856147594, Ep_Len=1000
# 	  Episod-8: Ep_Return=461.5816983087852, Ep_Len=1000
# 	  Episod-9: Ep_Return=385.7807248815209, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=402.5851970510411, Ep_Len=1000
# 	  Episod-1: Ep_Return=423.9429642197334, Ep_Len=1000
# 	  Episod-2: Ep_Return=468.46777407648176, Ep_Len=1000
# 	  Episod-3: Ep_Return=494.3348576200718, Ep_Len=1000
# 	  Episod-4: Ep_Return=462.94401437466416, Ep_Len=1000
# 	  Episod-5: Ep_Return=487.5243288956366, Ep_Len=1000
# 	  Episod-6: Ep_Return=348.9070353852706, Ep_Len=1000
# 	  Episod-7: Ep_Return=412.9396697052576, Ep_Len=1000
# 	  Episod-8: Ep_Return=415.4506115440855, Ep_Len=1000
# 	  Episod-9: Ep_Return=575.9846845563837, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=360.19566364526446, Ep_Len=1000
# 	  Episod-1: Ep_Return=386.59949183397976, Ep_Len=1000
# 	  Episod-2: Ep_Return=412.8693101920799, Ep_Len=1000
# 	  Episod-3: Ep_Return=396.662409485398, Ep_Len=1000
# 	  Episod-4: Ep_Return=455.0507028896377, Ep_Len=1000
# 	  Episod-5: Ep_Return=447.631530766139, Ep_Len=1000
# 	  Episod-6: Ep_Return=591.2945809834109, Ep_Len=1000
# 	  Episod-7: Ep_Return=384.7778110821104, Ep_Len=1000
# 	  Episod-8: Ep_Return=382.79587237346885, Ep_Len=1000
# 	  Episod-9: Ep_Return=527.2010271035774, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=582.2068858171701, Ep_Len=1000
# 	  Episod-1: Ep_Return=343.6463559997619, Ep_Len=1000
# 	  Episod-2: Ep_Return=429.61268147411573, Ep_Len=1000
# 	  Episod-3: Ep_Return=396.38685230007235, Ep_Len=1000
# 	  Episod-4: Ep_Return=379.794977314436, Ep_Len=1000
# 	  Episod-5: Ep_Return=450.8709150416831, Ep_Len=1000
# 	  Episod-6: Ep_Return=410.33019793929714, Ep_Len=1000
# 	  Episod-7: Ep_Return=396.70869929097745, Ep_Len=1000
# 	  Episod-8: Ep_Return=353.3911184813021, Ep_Len=1000
# 	  Episod-9: Ep_Return=609.3252583656903, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=409.7848626351399, Ep_Len=1000
# 	  Episod-1: Ep_Return=439.80486375953393, Ep_Len=1000
# 	  Episod-2: Ep_Return=429.1960325863498, Ep_Len=1000
# 	  Episod-3: Ep_Return=370.0477689128033, Ep_Len=1000
# 	  Episod-4: Ep_Return=394.35098149453995, Ep_Len=1000
# 	  Episod-5: Ep_Return=440.2053703257458, Ep_Len=1000
# 	  Episod-6: Ep_Return=474.39014105270167, Ep_Len=1000
# 	  Episod-7: Ep_Return=604.6571331945056, Ep_Len=1000
# 	  Episod-8: Ep_Return=312.1943177158443, Ep_Len=1000
# 	  Episod-9: Ep_Return=509.336745263019, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=477.2389292531544, Ep_Len=1000
# 	  Episod-1: Ep_Return=397.93020597911914, Ep_Len=1000
# 	  Episod-2: Ep_Return=445.11378671741704, Ep_Len=1000
# 	  Episod-3: Ep_Return=415.88583472527955, Ep_Len=1000
# 	  Episod-4: Ep_Return=440.6929435630664, Ep_Len=1000
# 	  Episod-5: Ep_Return=536.4873880204805, Ep_Len=1000
# 	  Episod-6: Ep_Return=356.1965607811626, Ep_Len=1000
# 	  Episod-7: Ep_Return=624.934165510492, Ep_Len=1000
# 	  Episod-8: Ep_Return=413.8612735224205, Ep_Len=1000
# 	  Episod-9: Ep_Return=649.7286132004061, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.2
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.2']
# ********************************************************************
# 2021-02-02_20-55-58-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.2_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=629.3756328638425, Ep_Len=1000
# 	  Episod-1: Ep_Return=640.9452155505694, Ep_Len=1000
# 	  Episod-2: Ep_Return=711.5267230685967, Ep_Len=1000
# 	  Episod-3: Ep_Return=590.1545927190742, Ep_Len=1000
# 	  Episod-4: Ep_Return=656.0845722302145, Ep_Len=1000
# 	  Episod-5: Ep_Return=587.3215010510055, Ep_Len=1000
# 	  Episod-6: Ep_Return=650.992782774077, Ep_Len=1000
# 	  Episod-7: Ep_Return=740.0125560683593, Ep_Len=1000
# 	  Episod-8: Ep_Return=650.3870307989438, Ep_Len=1000
# 	  Episod-9: Ep_Return=707.3067487817605, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=549.650773434649, Ep_Len=1000
# 	  Episod-1: Ep_Return=693.5769068348619, Ep_Len=1000
# 	  Episod-2: Ep_Return=742.1940202882205, Ep_Len=1000
# 	  Episod-3: Ep_Return=-26.179470342240524, Ep_Len=111
# 	  Episod-4: Ep_Return=695.5971356459542, Ep_Len=1000
# 	  Episod-5: Ep_Return=666.654294109996, Ep_Len=1000
# 	  Episod-6: Ep_Return=648.5354402654041, Ep_Len=1000
# 	  Episod-7: Ep_Return=735.769832560825, Ep_Len=1000
# 	  Episod-8: Ep_Return=514.9356413041535, Ep_Len=1000
# 	  Episod-9: Ep_Return=572.4824976099609, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=592.8254780095315, Ep_Len=1000
# 	  Episod-1: Ep_Return=-28.574426027301527, Ep_Len=102
# 	  Episod-2: Ep_Return=700.1321375900562, Ep_Len=1000
# 	  Episod-3: Ep_Return=731.6617310380145, Ep_Len=1000
# 	  Episod-4: Ep_Return=453.5408809603614, Ep_Len=1000
# 	  Episod-5: Ep_Return=519.6894709262748, Ep_Len=1000
# 	  Episod-6: Ep_Return=642.8152938863818, Ep_Len=1000
# 	  Episod-7: Ep_Return=621.9798656561725, Ep_Len=1000
# 	  Episod-8: Ep_Return=627.4433421146559, Ep_Len=1000
# 	  Episod-9: Ep_Return=664.2078203105712, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=682.4111204768755, Ep_Len=1000
# 	  Episod-1: Ep_Return=571.7923789316887, Ep_Len=1000
# 	  Episod-2: Ep_Return=-35.811834832660686, Ep_Len=94
# 	  Episod-3: Ep_Return=711.9784545772767, Ep_Len=1000
# 	  Episod-4: Ep_Return=571.9860840884234, Ep_Len=1000
# 	  Episod-5: Ep_Return=547.5545807140924, Ep_Len=1000
# 	  Episod-6: Ep_Return=657.0868533170875, Ep_Len=1000
# 	  Episod-7: Ep_Return=705.7653145015339, Ep_Len=1000
# 	  Episod-8: Ep_Return=675.0658388908797, Ep_Len=1000
# 	  Episod-9: Ep_Return=718.452082878335, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return
Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=671.5453638641924, Ep_Len=1000
# 	  Episod-1: Ep_Return=671.174738162286, Ep_Len=1000
# 	  Episod-2: Ep_Return=709.3329025459165, Ep_Len=1000
# 	  Episod-3: Ep_Return=646.185511437268, Ep_Len=1000
# 	  Episod-4: Ep_Return=638.7940517183956, Ep_Len=1000
# 	  Episod-5: Ep_Return=655.2372866506603, Ep_Len=1000
# 	  Episod-6: Ep_Return=579.8559446052018, Ep_Len=1000
# 	  Episod-7: Ep_Return=355.5096895923865, Ep_Len=1000
# 	  Episod-8: Ep_Return=628.9936846809859, Ep_Len=1000
# 	  Episod-9: Ep_Return=757.9736983612819, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=732.2567568665229, Ep_Len=1000
# 	  Episod-1: Ep_Return=717.4159737083759, Ep_Len=1000
# 	  Episod-2: Ep_Return=701.0782778217906, Ep_Len=1000
# 	  Episod-3: Ep_Return=698.3296436646757, Ep_Len=1000
# 	  Episod-4: Ep_Return=388.7210878921338, Ep_Len=1000
# 	  Episod-5: Ep_Return=279.78759315086654, Ep_Len=1000
# 	  Episod-6: Ep_Return=704.6090620543007, Ep_Len=1000
# 	  Episod-7: Ep_Return=701.2030757539511, Ep_Len=1000
# 	  Episod-8: Ep_Return=704.9418953706117, Ep_Len=1000
# 	  Episod-9: Ep_Return=707.1597743205105, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=654.7328137502981, Ep_Len=1000
# 	  Episod-1: Ep_Return=637.1146415637473, Ep_Len=1000
# 	  Episod-2: Ep_Return=680.1781849982422, Ep_Len=1000
# 	  Episod-3: Ep_Return=712.9375090460219, Ep_Len=1000
# 	  Episod-4: Ep_Return=697.3867481319326, Ep_Len=1000
# 	  Episod-5: Ep_Return=508.3314275257739, Ep_Len=1000
# 	  Episod-6: Ep_Return=766.480611121146, Ep_Len=1000
# 	  Episod-7: Ep_Return=593.9095342416721, Ep_Len=1000
# 	  Episod-8: Ep_Return=704.951811849601, Ep_Len=1000
# 	  Episod-9: Ep_Return=537.6810918550582, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=532.7382750078312, Ep_Len=1000
# 	  Episod-1: Ep_Return=682.0738252569853, Ep_Len=1000
# 	  Episod-2: Ep_Return=700.9058492919152, Ep_Len=1000
# 	  Episod-3: Ep_Return=654.2210097951291, Ep_Len=1000
# 	  Episod-4: Ep_Return=652.79644668765, Ep_Len=1000
# 	  Episod-5: Ep_Return=650.0956700809558, Ep_Len=1000
# 	  Episod-6: Ep_Return=523.517852884517, Ep_Len=1000
# 	  Episod-7: Ep_Return=720.51281909411, Ep_Len=1000
# 	  Episod-8: Ep_Return=763.8535243494316, Ep_Len=1000
# 	  Episod-9: Ep_Return=709.3712945615614, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=620.6703906658043, Ep_Len=1000
# 	  Episod-1: Ep_Return=653.5167006653712, Ep_Len=1000
# 	  Episod-2: Ep_Return=488.600968219511, Ep_Len=1000
# 	  Episod-3: Ep_Return=611.5630407337758, Ep_Len=1000
# 	  Episod-4: Ep_Return=694.2025839807461, Ep_Len=1000
# 	  Episod-5: Ep_Return=784.7714680919959, Ep_Len=1000
# 	  Episod-6: Ep_Return=728.9630962936687, Ep_Len=1000
# 	  Episod-7: Ep_Return=712.365164301409, Ep_Len=1000
# 	  Episod-8: Ep_Return=662.7534526157049, Ep_Len=1000
# 	  Episod-9: Ep_Return=752.9681286538516, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=752.104366967688, Ep_Len=1000
# 	  Episod-1: Ep_Return=657.9952824977885, Ep_Len=1000
# 	  Episod-2: Ep_Return=673.7097341621352, Ep_Len=1000
# 	  Episod-3: Ep_Return=777.2944137044245, Ep_Len=1000
# 	  Episod-4: Ep_Return=704.8165230070825, Ep_Len=1000
# 	  Episod-5: Ep_Return=673.9738222455195, Ep_Len=1000
# 	  Episod-6: Ep_Return=604.5856151667493, Ep_Len=1000
# 	  Episod-7: Ep_Return=703.0306089858497, Ep_Len=1000
# 	  Episod-8: Ep_Return=519.3430069744676, Ep_Len=1000
# 	  Episod-9: Ep_Return=615.0875380018558, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.3
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.3']
# ********************************************************************
# 2021-02-02_20-55-58-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.3_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=582.0217188905965, Ep_Len=1000
# 	  Episod-1: Ep_Return=562.5226752448247, Ep_Len=1000
# 	  Episod-2: Ep_Return=543.2719360787995, Ep_Len=1000
# 	  Episod-3: Ep_Return=102.25258600127708, Ep_Len=202
# 	  Episod-4: Ep_Return=554.3699675548297, Ep_Len=1000
# 	  Episod-5: Ep_Return=561.8093247597158, Ep_Len=1000
# 	  Episod-6: Ep_Return=531.0314223705839, Ep_Len=1000
# 	  Episod-7: Ep_Return=420.128056064249, Ep_Len=1000
# 	  Episod-8: Ep_Return=584.1202305589342, Ep_Len=1000
# 	  Episod-9: Ep_Return=560.2234360669032, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=601.8275300179033, Ep_Len=1000
# 	  Episod-1: Ep_Return=460.79709678912747, Ep_Len=872
# 	  Episod-2: Ep_Return=566.0359427645835, Ep_Len=1000
# 	  Episod-3: Ep_Return=544.8046094690983, Ep_Len=1000
# 	  Episod-4: Ep_Return=602.5807574847163, Ep_Len=1000
# 	  Episod-5: Ep_Return=553.4366224913866, Ep_Len=1000
# 	  Episod-6: Ep_Return=607.1230633633171, Ep_Len=1000
# 	  Episod-7: Ep_Return=429.7330649069171, Ep_Len=1000
# 	  Episod-8: Ep_Return=636.6192352171074, Ep_Len=1000
# 	  Episod-9: Ep_Return=193.0370421169708, Ep_Len=404
# 	3
# 	  Episod-0: Ep_Return=564.2502235850502, Ep_Len=1000
# 	  Episod-1: Ep_Return=61.10226408335145, Ep_Len=119
# 	  Episod-2: Ep_Return=543.9412473227497, Ep_Len=1000
# 	  Episod-3: Ep_Return=567.7367893182628, Ep_Len=1000
# 	  Episod-4: Ep_Return=443.3874242730438, Ep_Len=1000
# 	  Episod-5: Ep_Return=54.71421899150878, Ep_Len=118
# 	  Episod-6: Ep_Return=557.577806182758, Ep_Len=1000
# 	  Episod-7: Ep_Return=582.3266130772257, Ep_Len=1000
# 	  Episod-8: Ep_Return=545.1440918602191, Ep_Len=1000
# 	  Episod-9: Ep_Return=539.1729748893712, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=609.4870284632699, Ep_Len=1000
# 	  Episod-1: Ep_Return=184.77271207817992, Ep_Len=297
# 	  Episod-2: Ep_Return=503.64414805618, Ep_Len=1000
# 	  Episod-3: Ep_Return=611.7669570255802, Ep_Len=1000
# 	  Episod-4: Ep_Return=490.72377058757024, Ep_Len=1000
# 	  Episod-5: Ep_Return=397.9255660454291, Ep_Len=1000
# 	  Episod-6: Ep_Return=542.9888960404609, Ep_Len=1000
# 	  Episod-7: Ep_Return=521.6934685082623, Ep_Len=1000
# 	  Episod-8: Ep_Return=525.0723613660851, Ep_Len=1000
# 	  Episod-9: Ep_Return=476.47828767272733, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=634.0145156294485, Ep_Len=1000
# 	  Episod-1: Ep_Return=549.1888185004398, Ep_Len=1000
# 	  Episod-2: Ep_Return=556.7338964621684, Ep_Len=1000
# 	  Episod-3: Ep_Return=564.9158335533432, Ep_Len=1000
# 	  Episod-4: Ep_Return=502.77177566079905, Ep_Len=1000
# 	  Episod-5: Ep_Return=592.1942012947641, Ep_Len=1000
# 	  Episod-6: Ep_Return=497.32830337194207, Ep_Len=1000
# 	  Episod-7: Ep_Return=515.4107318489546, Ep_Len=1000
# 	  Episod-8: Ep_Return=564.3811864545231, Ep_Len=1000
# 	  Episod-9: Ep_Return=506.00599680679045, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=649.4431402254165, Ep_Len=1000
# 	  Episod-1: Ep_Return=541.7711095789713, Ep_Len=1000
# 	  Episod-2: Ep_Return=606.3658437429679, Ep_Len=1000
# 	  Episod-3: Ep_Return=632.1938802033465, Ep_Len=1000
# 	  Episod-4: Ep_Return=555.5093981265313, Ep_Len=1000
# 	  Episod-5: Ep_Return=563.2691300059079, Ep_Len=1000
# 	  Episod-6: Ep_Return=466.3498814143786, Ep_Len=1000
# 	  Episod-7: Ep_Return=586.6045594319982, Ep_Len=1000
# 	  Episod-8: Ep_Return=400.56232848976845, Ep_Len=787
# 	  Episod-9: Ep_Return=500.2176276144101, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=572.9039769787468, Ep_Len=1000
# 	  Episod-1: Ep_Return=402.61598407539196, Ep_Len=1000
# 	  Episod-2: Ep_Return=565.120440414569, Ep_Len=1000
# 	  Episod-3: Ep_Return=519.7190757755263, Ep_Len=1000
# 	  Episod-4: Ep_Return=496.6399227629917, Ep_Len=1000
# 	  Episod-5: Ep_Return=562.6414039425639, Ep_Len=1000
# 	  Episod-6: Ep_Return=489.54640592733386, Ep_Len=1000
# 	  Episod-7: Ep_Return=497.06963287337726, Ep_Len=1000
# 	  Episod-8: Ep_Return=529.4321574974558, Ep_Len=1000
# 	  Episod-9: Ep_Return=43.47018477209494, Ep_Len=92
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.35
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.35']
# ********************************************************************
# 2021-02-02_21-25-08-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.35_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=161.558542230648, Ep_Len=1000
# 	  Episod-1: Ep_Return=159.3034188783956, Ep_Len=1000
# 	  Episod-2: Ep_Return=149.35867641233432, Ep_Len=1000
# 	  Episod-3: Ep_Return=31.899127367793742, Ep_Len=272
# 	  Episod-4: Ep_Return=151.21880248121875, Ep_Len=1000
# 	  Episod-5: Ep_Return=3.9030649442080154, Ep_Len=56
# 	  Episod-6: Ep_Return=-0.12445119367621782, Ep_Len=52
# 	  Episod-7: Ep_Return=155.55703549140873, Ep_Len=1000
# 	  Episod-8: Ep_Return=154.13468559720232, Ep_Len=1000
# 	  Episod-9: Ep_Return=143.4353115500052, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return
Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=152.36937032323135, Ep_Len=1000
# 	  Episod-1: Ep_Return=0.10942879774956626, Ep_Len=47
# 	  Episod-2: Ep_Return=151.2900464393926, Ep_Len=1000
# 	  Episod-3: Ep_Return=25.75847592214995, Ep_Len=116
# 	  Episod-4: Ep_Return=159.28286895299863, Ep_Len=1000
# 	  Episod-5: Ep_Return=26.360091462082345, Ep_Len=151
# 	  Episod-6: Ep_Return=153.00822075857678, Ep_Len=1000
# 	  Episod-7: Ep_Return=154.66860384201462, Ep_Len=1000
# 	  Episod-8: Ep_Return=0.11675259143521188, Ep_Len=53
# 	  Episod-9: Ep_Return=162.40252956442367, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.4
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.4']
# ********************************************************************
# 2021-02-02_21-25-08-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.4_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=401.6250963135765, Ep_Len=1000
# 	  Episod-1: Ep_Return=707.2886841644184, Ep_Len=1000
# 	  Episod-2: Ep_Return=542.0981190827463, Ep_Len=1000
# 	  Episod-3: Ep_Return=665.5378646151706, Ep_Len=1000
# 	  Episod-4: Ep_Return=363.90734305886764, Ep_Len=1000
# 	  Episod-5: Ep_Return=578.3224770533918, Ep_Len=1000
# 	  Episod-6: Ep_Return=538.8849752239435, Ep_Len=1000
# 	  Episod-7: Ep_Return=468.9021021637428, Ep_Len=1000
# 	  Episod-8: Ep_Return=563.3043379819923, Ep_Len=1000
# 	  Episod-9: Ep_Return=583.0439617920662, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=568.8567888716019, Ep_Len=1000
# 	  Episod-1: Ep_Return=565.3919260491662, Ep_Len=1000
# 	  Episod-2: Ep_Return=606.1816943343858, Ep_Len=1000
# 	  Episod-3: Ep_Return=711.3653762078716, Ep_Len=1000
# 	  Episod-4: Ep_Return=743.3496369220744, Ep_Len=1000
# 	  Episod-5: Ep_Return=563.4141180104798, Ep_Len=1000
# 	  Episod-6: Ep_Return=827.7942653690197, Ep_Len=1000
# 	  Episod-7: Ep_Return=696.7605153750238, Ep_Len=1000
# 	  Episod-8: Ep_Return=607.6555669259583, Ep_Len=1000
# 	  Episod-9: Ep_Return=408.586916037691, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=356.57338846896704, Ep_Len=1000
# 	  Episod-1: Ep_Return=439.556801090623, Ep_Len=1000
# 	  Episod-2: Ep_Return=745.7533667784966, Ep_Len=1000
# 	  Episod-3: Ep_Return=529.452853977984, Ep_Len=1000
# 	  Episod-4: Ep_Return=680.4436866068096, Ep_Len=1000
# 	  Episod-5: Ep_Return=601.6044822599499, Ep_Len=1000
# 	  Episod-6: Ep_Return=712.7681363379472, Ep_Len=1000
# 	  Episod-7: Ep_Return=724.686748130859, Ep_Len=1000
# 	  Episod-8: Ep_Return=648.9978632599515, Ep_Len=1000
# 	  Episod-9: Ep_Return=686.9923691888313, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=752.5019815467597, Ep_Len=1000
# 	  Episod-1: Ep_Return=500.76574964434286, Ep_Len=1000
# 	  Episod-2: Ep_Return=672.1946097210102, Ep_Len=1000
# 	  Episod-3: Ep_Return=464.1873624164859, Ep_Len=1000
# 	  Episod-4: Ep_Return=682.5391313158376, Ep_Len=1000
# 	  Episod-5: Ep_Return=512.8584976137907, Ep_Len=1000
# 	  Episod-6: Ep_Return=442.82573086736124, Ep_Len=1000
# 	  Episod-7: Ep_Return=549.4515530605455, Ep_Len=1000
# 	  Episod-8: Ep_Return=729.331122286571, Ep_Len=1000
# 	  Episod-9: Ep_Return=701.85457435969, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=377.332292050312, Ep_Len=1000
# 	  Episod-1: Ep_Return=510.57287167229816, Ep_Len=1000
# 	  Episod-2: Ep_Return=595.9345684405339, Ep_Len=1000
# 	  Episod-3: Ep_Return=471.0505545807289, Ep_Len=1000
# 	  Episod-4: Ep_Return=519.8903432745609, Ep_Len=1000
# 	  Episod-5: Ep_Return=745.7148017707494, Ep_Len=1000
# 	  Episod-6: Ep_Return=544.3086956276036, Ep_Len=1000
# 	  Episod-7: Ep_Return=629.1613568254661, Ep_Len=1000
# 	  Episod-8: Ep_Return=529.7278266424037, Ep_Len=1000
# 	  Episod-9: Ep_Return=408.34065170567743, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=519.8914639041673, Ep_Len=1000
# 	  Episod-1: Ep_Return=155.85869706130168, Ep_Len=361
# 	  Episod-2: Ep_Return=361.16478634757596, Ep_Len=1000
# 	  Episod-3: Ep_Return=606.0799377944799, Ep_Len=1000
# 	  Episod-4: Ep_Return=544.3394528595555, Ep_Len=1000
# 	  Episod-5: Ep_Return=577.7433100697267, Ep_Len=1000
# 	  Episod-6: Ep_Return=581.7564193803021, Ep_Len=1000
# 	  Episod-7: Ep_Return=622.7059721708574, Ep_Len=1000
# 	  Episod-8: Ep_Return=581.5082227031849, Ep_Len=1000
# 	  Episod-9: Ep_Return=684.1172006684636, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=156.74698312119145, Ep_Len=364
# 	  Episod-1: Ep_Return=597.7055037761659, Ep_Len=1000
# 	  Episod-2: Ep_Return=727.0337279450505, Ep_Len=1000
# 	  Episod-3: Ep_Return=416.8073084527565, Ep_Len=1000
# 	  Episod-4: Ep_Return=714.7119314247325, Ep_Len=1000
# 	  Episod-5: Ep_Return=583.7910104087298, Ep_Len=1000
# 	  Episod-6: Ep_Return=749.2969699359252, Ep_Len=1000
# 	  Episod-7: Ep_Return=611.986004778166, Ep_Len=1000
# 	  Episod-8: Ep_Return=681.4886371296622, Ep_Len=1000
# 	  Episod-9: Ep_Return=612.7469601610381, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.45
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.45']
# ********************************************************************
# 2021-02-02_21-25-08-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.45_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=511.9994824555745, Ep_Len=881
# 	  Episod-1: Ep_Return=552.1852688320852, Ep_Len=1000
# 	  Episod-2: Ep_Return=192.15537226676014, Ep_Len=389
# 	  Episod-3: Ep_Return=524.2341925077186, Ep_Len=1000
# 	  Episod-4: Ep_Return=584.1754966731593, Ep_Len=1000
# 	  Episod-5: Ep_Return=62.749611538994984, Ep_Len=137
# 	  Episod-6: Ep_Return=463.6044118510671, Ep_Len=1000
# 	  Episod-7: Ep_Return=629.0747531356728, Ep_Len=1000
# 	  Episod-8: Ep_Return=691.2190529688197, Ep_Len=1000
# 	  Episod-9: Ep_Return=668.6116108996341, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=601.7152414256065, Ep_Len=1000
# 	  Episod-1: Ep_Return=489.4026690136655, Ep_Len=1000
# 	  Episod-2: Ep_Return=489.1036351793133, Ep_Len=1000
# 	  Episod-3: Ep_Return=510.89551724787486, Ep_Len=1000
# 	  Episod-4: Ep_Return=688.6795622486806, Ep_Len=1000
# 	  Episod-5: Ep_Return=80.65213234226243, Ep_Len=178
# 	  Episod-6: Ep_Return=725.5582180515058, Ep_Len=1000
# 	  Episod-7: Ep_Return=623.6918376300292, Ep_Len=1000
# 	  Episod-8: Ep_Return=555.8876021238698, Ep_Len=1000
# 	  Episod-9: Ep_Return=594.7798545241714, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=564.1792806131979, Ep_Len=1000
# 	  Episod-1: Ep_Return=729.7162244288993, Ep_Len=1000
# 	  Episod-2: Ep_Return=525.2170448019494, Ep_Len=1000
# 	  Episod-3: Ep_Return=786.3617807820245, Ep_Len=1000
# 	  Episod-4: Ep_Return=516.789160644497, Ep_Len=1000
# 	  Episod-5: Ep_Return=646.9506849645874, Ep_Len=1000
# 	  Episod-6: Ep_Return=476.72777508279097, Ep_Len=1000
# 	  Episod-7: Ep_Return=569.3576701183065, Ep_Len=955
# 	  Episod-8: Ep_Return=832.7870026105293, Ep_Len=1000
# 	  Episod-9: Ep_Return=636.126885262326, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=421.3353233192097, Ep_Len=708
# 	  Episod-1: Ep_Return=525.3393245138825, Ep_Len=1000
# 	  Episod-2: Ep_Return=539.8995466770813, Ep_Len=1000
# 	  Episod-3: Ep_Return=808.2628057529964, Ep_Len=1000
# 	  Episod-4: Ep_Return=232.77684362364243, Ep_Len=389
# 	  Episod-5: Ep_Return=503.816577438042, Ep_Len=1000
# 	  Episod-6: Ep_Return=656.3083340680222, Ep_Len=1000
# 	  Episod-7: Ep_Return=499.7980322089276, Ep_Len=1000
# 	  Episod-8: Ep_Return=585.7936015953985, Ep_Len=1000
# 	  Episod-9: Ep_Return=579.5102543694687, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=587.4480065408746, Ep_Len=1000
# 	  Episod-1: Ep_Return=659.1467808116489, Ep_Len=1000
# 	  Episod-2: Ep_Return=709.9316171602505, Ep_Len=1000
# 	  Episod-3: Ep_Return=832.5037448377772, Ep_Len=1000
# 	  Episod-4: Ep_Return=675.6471674385017, Ep_Len=1000
# 	  Episod-5: Ep_Return=514.6736139527088, Ep_Len=1000
# 	  Episod-6: Ep_Return=700.5776670321284, Ep_Len=1000
# 	  Episod-7: Ep_Return=500.5710245049076, Ep_Len=1000
# 	  Episod-8: Ep_Return=554.3399201924856, Ep_Len=1000
# 	  Episod-9: Ep_Return=629.0810431137522, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=677.6091742700147, Ep_Len=1000
# 	  Episod-1: Ep_Return=572.3437036430923, Ep_Len=1000
# 	  Episod-2: Ep_Return=295.2988953329519, Ep_Len=497
# 	  Episod-3: Ep_Return=567.0930992549248, Ep_Len=1000
# 	  Episod-4: Ep_Return=582.9499375457854, Ep_Len=1000
# 	  Episod-5: Ep_Return=536.502698887109, Ep_Len=1000
# 	  Episod-6: Ep_Return=619.9002548448697, Ep_Len=1000
# 	  Episod-7: Ep_Return=505.2398492653587, Ep_Len=1000
# 	  Episod-8: Ep_Return=414.3789332786968, Ep_Len=857
# 	  Episod-9: Ep_Return=508.04023747720197, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=554.7356952770542, Ep_Len=1000
# 	  Episod-1: Ep_Return=588.1890402103598, Ep_Len=1000
# 	  Episod-2: Ep_Return=522.3945638822698, Ep_Len=969
# 	  Episod-3: Ep_Return=696.8754857533072, Ep_Len=1000
# 	  Episod-4: Ep_Return=613.5477611998361, Ep_Len=1000
# 	  Episod-5: Ep_Return=729.154233696441, Ep_Len=1000
# 	  Episod-6: Ep_Return=560.5603822520534, Ep_Len=1000
# 	  Episod-7: Ep_Return=576.2564768526454, Ep_Len=965
# 	  Episod-8: Ep_Return=518.156111785028, Ep_Len=1000
# 	  Episod-9: Ep_Return=690.3775641021888, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.5
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '0', '0.5']
# ********************************************************************
# 2021-02-02_21-25-08-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_0_0.5_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=650.1679353178581, Ep_Len=1000
# 	  Episod-1: Ep_Return=727.2580841949617, Ep_Len=1000
# 	  Episod-2: Ep_Return=656.4552231329025, Ep_Len=1000
# 	  Episod-3: Ep_Return=316.4005218926193, Ep_Len=513
# 	  Episod-4: Ep_Return=872.70870216193, Ep_Len=1000
# 	  Episod-5: Ep_Return=638.5733764157517, Ep_Len=1000
# 	  Episod-6: Ep_Return=663.6272538885805, Ep_Len=1000
# 	  Episod-7: Ep_Return=619.7730843816272, Ep_Len=1000
# 	  Episod-8: Ep_Return=703.856693051667, Ep_Len=1000
# 	  Episod-9: Ep_Return=704.4824548006492, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=638.309624253183, Ep_Len=1000
# 	  Episod-1: Ep_Return=519.4929731479536, Ep_Len=1000
# 	  Episod-2: Ep_Return=529.6587352382973, Ep_Len=1000
# 	  Episod-3: Ep_Return=572.7770060334265, Ep_Len=1000
# 	  Episod-4: Ep_Return=600.3791908345383, Ep_Len=1000
# 	  Episod-5: Ep_Return=736.7535830984327, Ep_Len=1000
# 	  Episod-6: Ep_Return=623.7580105450767, Ep_Len=1000
# 	  Episod-7: Ep_Return=617.5172760179232, Ep_Len=1000
# 	  Episod-8: Ep_Return=625.0206564481438, Ep_Len=1000
# 	  Episod-9: Ep_Return=638.3754369000126, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=495.41137713636, Ep_Len=1000
# 	  Episod-1: Ep_Return=687.708033289281, Ep_Len=1000
# 	  Episod-2: Ep_Return=611.6777987323617, Ep_Len=1000
# 	  Episod-3: Ep_Return=649.1139104442823, Ep_Len=1000
# 	  Episod-4: Ep_Return=643.7874341919554, Ep_Len=1000
# 	  Episod-5: Ep_Return=677.7231009171304, Ep_Len=1000
# 	  Episod-6: Ep_Return=238.55782784440035, Ep_Len=609
# 	  Episod-7: Ep_Return=703.3360865824562, Ep_Len=1000
# 	  Episod-8: Ep_Return=664.9930133960622, Ep_Len=1000
# 	  Episod-9: Ep_Return=622.5309070369782, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=539.0364705749306, Ep_Len=1000
# 	  Episod-1: Ep_Return=683.6529923427595, Ep_Len=1000
# 	  Episod-2: Ep_Return=606.3956331511966, Ep_Len=1000
# 	  Episod-3: Ep_Return=438.8948523179895, Ep_Len=831
# 	  Episod-4: Ep_Return=475.261302909443, Ep_Len=1000
# 	  Episod-5: Ep_Return=553.4449458200867, Ep_Len=1000
# 	  Episod-6: Ep_Return=344.6970865694255, Ep_Len=647
# 	  Episod-7: Ep_Return=572.679145256475, Ep_Len=1000
# 	  Episod-8: Ep_Return=593.9526096987138, Ep_Len=1000
# 	  Episod-9: Ep_Return=597.333718823267, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=632.1394772312591, Ep_Len=1000
# 	  Episod-1: Ep_Return=515.9705000973024, Ep_Len=1000
# 	  Episod-2: Ep_Return=610.3337148438732, Ep_Len=1000
# 	  Episod-3: Ep_Return=765.1456391307419, Ep_Len=1000
# 	  Episod-4: Ep_Return=520.397983735167, Ep_Len=1000
# 	  Episod-5: Ep_Return=603.4003045181436, Ep_Len=1000
# 	  Episod-6: Ep_Return=622.0607371105201, Ep_Len=1000
# 	  Episod-7: Ep_Return=471.79455595124574, Ep_Len=796
# 	  Episod-8: Ep_Return=604.3568807574691, Ep_Len=1000
# 	  Episod-9: Ep_Return=742.8783483245611, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=623.9838496379692, Ep_Len=1000
# 	  Episod-1: Ep_Return=693.9001949825098, Ep_Len=1000
# 	  Episod-2: Ep_Return=629.5553753971022, Ep_Len=1000
# 	  Episod-3: Ep_Return=700.9462108441807, Ep_Len=1000
# 	  Episod-4: Ep_Return=676.1324662918857, Ep_Len=1000
# 	  Episod-5: Ep_Return=661.602719026252, Ep_Len=1000
# 	  Episod-6: Ep_Return=761.2637031434421, Ep_Len=1000
# 	  Episod-7: Ep_Return=527.7225820535028, Ep_Len=1000
# 	  Episod-8: Ep_Return=524.2292205139842, Ep_Len=1000
# 	  Episod-9: Ep_Return=410.91471128808234, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=705.0409467131643, Ep_Len=1000
# 	  Episod-1: Ep_Return=676.8791233613638, Ep_Len=1000
# 	  Episod-2: Ep_Return=529.3966679629415, Ep_Len=1000
# 	  Episod-3: Ep_Return=665.9374724011764, Ep_Len=1000
# 	  Episod-4: Ep_Return=629.1254264868851, Ep_Len=1000
# 	  Episod-5: Ep_Return=837.7299607803894, Ep_Len=1000
# 	  Episod-6: Ep_Return=615.9831889549388, Ep_Len=1000
# 	  Episod-7: Ep_Return=592.8237117399256, Ep_Len=1000
# 	  Episod-8: Ep_Return=648.3846976441249, Ep_Len=1000
# 	  Episod-9: Ep_Return=580.2010574456051, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_10_0.05
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '10', '0.05']
# ********************************************************************
# 2021-02-02_21-34-57-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_10_0.05_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=891.9376512877112, Ep_Len=1000
# 	  Episod-1: Ep_Return=1022.2418498699858, Ep_Len=1000
# 	  Episod-2: Ep_Return=854.175705744485, Ep_Len=1000
# 	  Episod-3: Ep_Return=752.2703938289823, Ep_Len=1000
# 	  Episod-4: Ep_Return=986.8721022161723, Ep_Len=1000
# 	  Episod-5: Ep_Return=800.7449093522504, Ep_Len=1000
# 	  Episod-6: Ep_Return=772.4064928635659, Ep_Len=1000
# 	  Episod-7: Ep_Return=1058.0814062902148, Ep_Len=1000
# 	  Episod-8: Ep_Return=1185.775589404804, Ep_Len=1000
# 	  Episod-9: Ep_Return=930.6874605586571, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=2402.3877540493772, Ep_Len=1000
# 	  Episod-1: Ep_Return=2313.0835683128134, Ep_Len=1000
# 	  Episod-2: Ep_Return=2421.3398759253914, Ep_Len=1000
# 	  Episod-3: Ep_Return=2430.490879149364, Ep_Len=1000
# 	  Episod-4: Ep_Return=2412.401505127935, Ep_Len=1000
# 	  Episod-5: Ep_Return=2328.5498033525205, Ep_Len=1000
# 	  Episod-6: Ep_Return=2412.7439418314066, Ep_Len=1000
# 	  Episod-7: Ep_Return=2442.2272292970456, Ep_Len=1000
# 	  Episod-8: Ep_Return=2458.04401182757, Ep_Len=1000
# 	  Episod-9: Ep_Return=2338.4150669550622, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=2439.671559151358, Ep_Len=1000
# 	  Episod-1: Ep_Return=2488.7802856866642, Ep_Len=1000
# 	  Episod-2: Ep_Return=2455.5285793887483, Ep_Len=1000
# 	  Episod-3: Ep_Return=2455.8570509510655, Ep_Len=1000
# 	  Episod-4: Ep_Return=2508.5377597145225, Ep_Len=1000
# 	  Episod-5: Ep_Return=2480.4066525678595, Ep_Len=1000
# 	  Episod-6: Ep_Return=2524.3318078080356, Ep_Len=1000
# 	  Episod-7: Ep_Return=2496.234034267262, Ep_Len=1000
# 	  Episod-8: Ep_Return=2509.993764440379, Ep_Len=1000
# 	  Episod-9: Ep_Return=2523.653179526802, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2418.984404135903, Ep_Len=1000
# 	  Episod-1: Ep_Return=2424.128367685145, Ep_Len=1000
# 	  Episod-2: Ep_Return=2486.3973072717845, Ep_Len=1000
# 	  Episod-3: Ep_Return=2474.560619760639, Ep_Len=1000
# 	  Episod-4: Ep_Return=2458.7538273463224, Ep_Len=1000
# 	  Episod-5: Ep_Return=2512.0505736240866, Ep_Len=1000
# 	  Episod-6: Ep_Return=2459.7079866573845, Ep_Len=1000
# 	  Episod-7: Ep_Return=2520.641647677331, Ep_Len=1000
# 	  Episod-8: Ep_Return=2509.5341118686792, Ep_Len=1000
# 	  Episod-9: Ep_Return=2519.722265555394, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2466.490449134758, Ep_Len=1000
# 	  Episod-1: Ep_Return=2489.973697167809, Ep_Len=1000
# 	  Episod-2: Ep_Return=2524.9020717730546, Ep_Len=1000
# 	  Episod-3: Ep_Return=2557.823190556941, Ep_Len=1000
# 	  Episod-4: Ep_Return=2525.200665157791, Ep_Len=1000
# 	  Episod-5: Ep_Return=2474.7580472353, Ep_Len=1000
# 	  Episod-6: Ep_Return=2485.4154004575216, Ep_Len=1000
# 	  Episod-7: Ep_Return=2483.4940023703725, Ep_Len=1000
# 	  Episod-8: Ep_Return=2463.137598617499, Ep_Len=1000
# 	  Episod-9: Ep_Return=2551.7019299814033, Ep_Len=1000
# 	10
# 	  Episod-0: Ep_Return=2513.856245724048, Ep_Len=1000
# 	  Episod-1: Ep_Return=2525.7092691853986, Ep_Len=1000
# 	  Episod-2: Ep_Return=2490.215194732023, Ep_Len=1000
# 	  Episod-3: Ep_Return=2494.9209999830205, Ep_Len=1000
# 	  Episod-4: Ep_Return=2501.18879788447, Ep_Len=1000
# 	  Episod-5: Ep_Return=2467.7700573777297, Ep_Len=1000
# 	  Episod-6: Ep_Return=2531.58111657794, Ep_Len=1000
# 	  Episod-7: Ep_Return=2477.3705432305005, Ep_Len=1000
# 	  Episod-8: Ep_Return=2513.521860662913, Ep_Len=1000
# 	  Episod-9: Ep_Return=2489.548841781866, Ep_Len=1000
# 	15
# 	  Episod-0: Ep_Return=2568.46516299114, Ep_Len=1000
# 	  Episod-1: Ep_Return=2472.29751629376, Ep_Len=1000
# 	  Episod-2: Ep_Return=2527.7633349031776, Ep_Len=1000
# 	  Episod-3: Ep_Return=2484.081480232339, Ep_Len=1000
# 	  Episod-4: Ep_Return=2553.222848484433, Ep_Len=1000
# 	  Episod-5: Ep_Return=2475.0854167446223, Ep_Len=1000
# 	  Episod-6: Ep_Return=2513.361816885484, Ep_Len=1000
# 	  Episod-7: Ep_Return=2560.4491319323984, Ep_Len=1000
# 	  Episod-8: Ep_Return=2481.3591116868024, Ep_Len=1000
# 	  Episod-9: Ep_Return=2460.27578826318, Ep_Len=1000
# 2021-02-02_LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_10_0.1
# ['2021-02-02', 'LSTM-TD3', 'AntPyBulletEnv-v0', 'True', 'flickering', '0', '10', '0.1']
# ********************************************************************
# 2021-02-02_21-48-47-LSTM-TD3_AntPyBulletEnv-v0_True_flickering_0_10_0.1_s0
# WalkerBase::__init__
# 	0
# options=
# 	  Episod-0: Ep_Return=706.067324732376, Ep_Len=1000
# 	  Episod-1: Ep_Return=681.1401799857045, Ep_Len=1000
# 	  Episod-2: Ep_Return=695.8212695927177, Ep_Len=1000
# 	  Episod-3: Ep_Return=714.2724517260075, Ep_Len=1000
# 	  Episod-4: Ep_Return=695.8160957771785, Ep_Len=1000
# 	  Episod-5: Ep_Return=776.2886652377524, Ep_Len=1000
# 	  Episod-6: Ep_Return=659.9307104420006, Ep_Len=1000
# 	  Episod-7: Ep_Return=679.6592961538221, Ep_Len=1000
# 	  Episod-8: Ep_Return=781.4155023946294, Ep_Len=1000
# 	  Episod-9: Ep_Return=669.2665849151437, Ep_Len=1000
# 	1
# 	  Episod-0: Ep_Return=1706.3587303638703, Ep_Len=1000
# 	  Episod-1: Ep_Return=1568.2136229112884, Ep_Len=1000
# 	  Episod-2: Ep_Return=1600.3950203204113, Ep_Len=1000
# 	  Episod-3: Ep_Return=1925.6563993131278, Ep_Len=1000
# 	  Episod-4: Ep_Return=1709.5669153451486, Ep_Len=1000
# 	  Episod-5: Ep_Return=1849.6190461876536, Ep_Len=1000
# 	  Episod-6: Ep_Return=1889.9332055677537, Ep_Len=1000
# 	  Episod-7: Ep_Return=1620.5385766228476, Ep_Len=1000
# 	  Episod-8: Ep_Return=1820.4518935950468, Ep_Len=1000
# 	  Episod-9: Ep_Return=1850.1463001416046, Ep_Len=1000
# 	3
# 	  Episod-0: Ep_Return=243.1115408076529, Ep_Len=1000
# 	  Episod-1: Ep_Return=2180.5408880805967, Ep_Len=1000
# 	  Episod-2: Ep_Return=2035.7943083460596, Ep_Len=1000
# 	  Episod-3: Ep_Return=-38.409148751791506, Ep_Len=125
# 	  Episod-4: Ep_Return=2120.6585777331284, Ep_Len=1000
# 	  Episod-5: Ep_Return=2119.2321664244787, Ep_Len=1000
# 	  Episod-6: Ep_Return=2193.1888262717553, Ep_Len=1000
# 	  Episod-7: Ep_Return=1959.6704122114722, Ep_Len=1000
# 	  Episod-8: Ep_Return=299.63393241781165, Ep_Len=1000
# 	  Episod-9: Ep_Return=1793.1573038872043, Ep_Len=1000
# 	5
# 	  Episod-0: Ep_Return=2183.3547209001304, Ep_Len=1000
# 	  Episod-1: Ep_Return=275.84381315395564, Ep_Len=1000
# 	  Episod-2: Ep_Return=263.31638096117234, Ep_Len=1000
# 	  Episod-3: Ep_Return=2257.0105167866022, Ep_Len=1000
# 	  Episod-4: Ep_Return=2159.3722158166697, Ep_Len=1000
# 	  Episod-5: Ep_Return=2148.048909421253, Ep_Len=1000
# 	  Episod-6: Ep_Return=351.73464887453474, Ep_Len=1000
# 	  Episod-7: Ep_Return=251.97824608743377, Ep_Len=1000
# 	  Episod-8: Ep_Return=2233.3199997395236, Ep_Len=1000
# 	  Episod-9: Ep_Return=2180.6410453833014, Ep_Len=1000
# 	8
# 	  Episod-0: Ep_Return=2102.506152547161, Ep_Len=1000
# ...
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_0_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '0', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_10_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '10', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_12_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '12', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_15_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '15', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_18_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '18', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_1_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '1', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_20_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '20', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_3_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '3', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_5_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '5', '0.5']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.05
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.05']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.1
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.1']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.15
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.15']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.2
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.2']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.25
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.25']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.3
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.3']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.35
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.35']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.4
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.4']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.45
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.45']
# 2021-02-05_LSTM-TD3_Walker2DPyBulletEnv-v0_True_flickering_1_8_0.5
# ['2021-02-05', 'LSTM-TD3', 'Walker2DPyBulletEnv-v0', 'True', 'flickering', '1', '8', '0.5']

# %%
import joblib
fname = 'D:\POMDP_Data\evaluation_on_different_environment_POMDP_LSTM_TD3_POMDP-FLK.pkl'
joblib.dump({'lstm_td3_different_hist_len': lstm_td3_different_hist_len}, fname)
# reload_collected_environment_change_data = joblib.load(fname)
# Out:
# ['D:\\POMDP_Data\\evaluation_on_different_environment_POMDP_LSTM_TD3_POMDP-FLK.pkl']

# %%
lstm_td3_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0']['flickering-0.05'][orig_hist_len][run_seed].keys()
# Out:
# dict_keys(['0', '1', '3', '5', '8', '10', '15'])

# %%
lstm_td3_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0'].keys()
# Out:
# dict_keys(['flickering-0.05', 'flickering-0.1', 'flickering-0.15', 'flickering-0.2', 'flickering-0.25', 'flickering-0.3', 'flickering-0.35', 'flickering-0.4', 'flickering-0.45', 'flickering-0.5'])

# %%
original_hist_len = ['0', '1', '3', '5', '8', '10', '12', '15', '18', '20']
eval_results_on_diff_hist_len = {}
eval_results_on_diff_hist_len_mean = {}
eval_results_on_diff_hist_len_std = {}
for pomdp_type in lstm_td3_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0'].keys():
    eval_results_on_diff_hist_len[pomdp_type] = {}
    eval_results_on_diff_hist_len_mean[pomdp_type] = {}
    eval_results_on_diff_hist_len_std[pomdp_type] = {}
    for orig_hist_len in original_hist_len:
        eval_results_on_diff_hist_len[pomdp_type][orig_hist_len] = {}
        eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len] = []
        eval_results_on_diff_hist_len_std[pomdp_type][orig_hist_len] = []
        for eval_hist_len in ['0', '1', '3', '5', '8', '10', '15']:
            eval_results = []
            for run_seed in ['0', '1']:
                eval_results += lstm_td3_different_hist_len['LSTM-TD3']['AntPyBulletEnv-v0'][pomdp_type][orig_hist_len][run_seed][eval_hist_len]
            eval_results_on_diff_hist_len[pomdp_type][orig_hist_len][eval_hist_len] = eval_results
            eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len].append(np.mean(eval_results))
            eval_results_on_diff_hist_len_std[pomdp_type][orig_hist_len].append(np.std(eval_results))

# %%
original_hist_len.index(orig_hist_len)
# Out:
# 9

# %%
color = {'0':'c', '1':'m', '3':'b', '5':'r', 'DDPG':'k'}

fig, axes = plt.subplots(1, len(original_hist_len)+1, figsize=(4*(len(original_hist_len)+1), 4), sharey=True)
for axes_i, pomdp_type in enumerate(['MDP', 'flickering-0.05', 'flickering-0.1', 'flickering-0.15', 'flickering-0.2', 'flickering-0.25', 'flickering-0.3', 'flickering-0.35', 'flickering-0.4', 'flickering-0.45', 'flickering-0.5']):
    if pomdp_type == 'MDP':
        # Trained on MDP
        for orig_hist_len in lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean.keys():
            axes[axes_i].plot(np.arange(7), lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean[orig_hist_len], 
                              label='Training Hist Len: {}'.format(orig_hist_len), color=color[orig_hist_len])
            if orig_hist_len == '0':
                index = 0
            if orig_hist_len == '1':
                index = 1
            if orig_hist_len == '3':
                index = 2
            if orig_hist_len == '5':
                index = 3
            axes[axes_i].scatter(index, lstm_td3_trained_on_MDP_eval_results_on_diff_hist_len_mean[orig_hist_len][index],
                                 color=color[orig_hist_len], s=100)
        axes[axes_i].set_xticks(np.arange(7))
        axes[axes_i].set_xticklabels(['0', '1', '3', '5', '8', '10', '15'])
        axes[axes_i].set_xlabel('Evaluation History Length')
        axes[axes_i].set_ylabel('Average Return')
        axes[axes_i].set_title('{}'.format(pomdp_type))
        axes[axes_i].grid(linestyle=':')
    else:
        # Trained on POMDP
        for orig_hist_len in eval_results_on_diff_hist_len_mean[pomdp_type].keys():
            axes[axes_i].plot(np.arange(7), eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len], 
                              label='Training Hist Len: {}'.format(orig_hist_len))
            if orig_hist_len == '0':
                index = 0
            if orig_hist_len == '1':
                index = 1
            if orig_hist_len == '3':
                index = 2
            if orig_hist_len == '5':
                index = 3
            axes[axes_i].scatter(original_hist_len.index(orig_hist_len), eval_results_on_diff_hist_len_mean[pomdp_type][orig_hist_len][index],
                                 s=100)
        axes[axes_i].set_xticks(np.arange(len(original_hist_len)))
        axes[axes_i].set_xticklabels(original_hist_len)
        axes[axes_i].set_xlabel('Evaluation History Length')
        axes[axes_i].set_ylabel('Average Return')
        if pomdp_type == 'remove_velocity':
            pomdp_type = 'POMDP-RV'
        if pomdp_type == 'flickering':
            pomdp_type = 'POMDP-FLK'
        if pomdp_type == 'random_noise':
            pomdp_type = 'POMDP-RN'
        if pomdp_type == 'random_sensor_missing':
            pomdp_type = 'POMDP-RSM'
        axes[axes_i].set_title('{}'.format(pomdp_type))
        axes[axes_i].grid(linestyle=':')
        axes[axes_i].legend()
plt.tight_layout()
fig.suptitle("{}".format('AntPyBulletEnv-v0'), fontsize=24)
fig.subplots_adjust(top=0.8)
fig.savefig("D:\POMDP_Data\images\evaluation_on_different_history_length.png", bbox_inches='tight')
