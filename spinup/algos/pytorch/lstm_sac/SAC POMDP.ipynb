# %%
from copy import deepcopy
import itertools
import numpy as np
import torch
from torch.optim import Adam
import pybulletgym
import gym
import time
import spinup.algos.pytorch.lstm_sac.core as core
from spinup.utils.logx import EpochLogger

# %%
class POMDPWrapper(gym.ObservationWrapper):
    def __init__(self, env_name):
        super().__init__(gym.make(env_name))
        
        # Remove velocity info
        # OpenAIGym
        #  1. MuJoCo
        if env_name == "HalfCheetah-v3" or env_name == "HalfCheetah-v2":
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == "Ant-v3" or env_name == "Ant-v2":
            self.remain_obs_idx = list(np.arange(0, 13)) + list(np.arange(27, 111))
        elif env_name == 'Walker2d-v3' or env_name == "Walker2d-v2":
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'Hopper-v3' or env_name == "Hopper-v2":
            self.remain_obs_idx = np.arange(0, 5)
        elif env_name == "InvertedPendulum-v2":
            self.remain_obs_idx = np.arange(0, 2)
        elif env_name == "InvertedDoublePendulum-v2":
            self.remain_obs_idx = list(np.arange(0, 5)) + list(np.arange(8, 11))
        elif env_name == "Swimmer-v3" or env_name == "Swimmer-v2":
            self.remain_obs_idx = np.arange(0, 3)
        elif env_name == "Thrower-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Striker-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Pusher-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Reacher-v2":
            self.remain_obs_idx = list(np.arange(0, 6)) + list(np.arange(8, 11))
        elif env_name == 'Humanoid-v3' or env_name == "Humanoid-v2":
            self.remain_obs_idx = list(np.arange(0, 22)) + list(np.arange(45, 185)) + list(np.arange(269, 376))
        elif env_name == 'HumanoidStandup-v2':
            self.remain_obs_idx = list(np.arange(0, 22)) + list(np.arange(45, 185)) + list(np.arange(269, 376))
        # PyBulletGym
        #  1. MuJoCo
        elif env_name == 'HalfCheetahMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'AntMuJoCoEnv-v0':
            self.remain_obs_idx = list(np.arange(0, 13)) + list(np.arange(27, 111))
        elif env_name == 'Walker2DMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'HopperMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 7)
        elif env_name == 'InvertedPendulumMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 3)
        elif env_name == 'InvertedDoublePendulumMuJoCoEnv-v0':
            self.remain_obs_idx = list(np.arange(0, 5)) + list(np.arange(8, 11))
        #  2. Roboschool
        elif env_name == 'HalfCheetahPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,26)) - set(np.arange(3,6)))
        elif env_name ==  'AntPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,28)) - set(np.arange(3,6)))
        elif env_name == 'Walker2DPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,22)) - set(np.arange(3,6)))
        elif env_name == 'HopperPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,15)) - set(np.arange(3,6)))
        elif env_name == 'InvertedPendulumPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,5)) - set([1,4]))
        elif env_name == 'InvertedDoublePendulumPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,9)) - set([1,5,8]))
        elif env_name == 'ReacherPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,9)) - set([6,8]))
        else:
            raise ValueError('POMDP for {} is not defined!'.format(env_name))
            
        # Redefine observation_space
        obs_low = np.array([-np.inf for i in range(len(self.remain_obs_idx))], dtype="float32")
        obs_high = np.array([np.inf for i in range(len(self.remain_obs_idx))], dtype="float32")
        self.observation_space = gym.spaces.Box(obs_low, obs_high)
        
    def observation(self, obs):
        return obs.flatten()[self.remain_obs_idx]

# %%
class ReplayBuffer:
    """
    A simple FIFO experience replay buffer for SAC agents.
    """

    def __init__(self, obs_dim, act_dim, size):
        self.obs_buf = np.zeros(core.combined_shape(size, obs_dim), dtype=np.float32)
        self.obs2_buf = np.zeros(core.combined_shape(size, obs_dim), dtype=np.float32)
        self.act_buf = np.zeros(core.combined_shape(size, act_dim), dtype=np.float32)
        self.rew_buf = np.zeros(size, dtype=np.float32)
        self.done_buf = np.zeros(size, dtype=np.float32)
        self.ptr, self.size, self.max_size = 0, 0, size

    def store(self, obs, act, rew, next_obs, done):
        self.obs_buf[self.ptr] = obs
        self.obs2_buf[self.ptr] = next_obs
        self.act_buf[self.ptr] = act
        self.rew_buf[self.ptr] = rew
        self.done_buf[self.ptr] = done
        self.ptr = (self.ptr+1) % self.max_size
        self.size = min(self.size+1, self.max_size)

    def sample_batch(self, batch_size=32):
        idxs = np.random.randint(0, self.size, size=batch_size)
        batch = dict(obs=self.obs_buf[idxs],
                     obs2=self.obs2_buf[idxs],
                     act=self.act_buf[idxs],
                     rew=self.rew_buf[idxs],
                     done=self.done_buf[idxs])
        return {k: torch.as_tensor(v, dtype=torch.float32) for k,v in batch.items()}

# %%
def sac(env_name, actor_critic=core.MLPActorCritic, ac_kwargs=dict(), seed=0, 
        steps_per_epoch=4000, epochs=100, replay_size=int(1e6), gamma=0.99, 
        polyak=0.995, lr=1e-3, alpha=0.2, batch_size=100, start_steps=10000, 
        update_after=1000, update_every=50, num_test_episodes=10, max_ep_len=1000, 
        partially_observable=False,
        logger_kwargs=dict(), save_freq=1):
    """
    Soft Actor-Critic (SAC)


    Args:
        env_fn : A function which creates a copy of the environment.
            The environment must satisfy the OpenAI Gym API.

        actor_critic: The constructor method for a PyTorch Module with an ``act`` 
            method, a ``pi`` module, a ``q1`` module, and a ``q2`` module.
            The ``act`` method and ``pi`` module should accept batches of 
            observations as inputs, and ``q1`` and ``q2`` should accept a batch 
            of observations and a batch of actions as inputs. When called, 
            ``act``, ``q1``, and ``q2`` should return:

            ===========  ================  ======================================
            Call         Output Shape      Description
            ===========  ================  ======================================
            ``act``      (batch, act_dim)  | Numpy array of actions for each 
                                           | observation.
            ``q1``       (batch,)          | Tensor containing one current estimate
                                           | of Q* for the provided observations
                                           | and actions. (Critical: make sure to
                                           | flatten this!)
            ``q2``       (batch,)          | Tensor containing the other current 
                                           | estimate of Q* for the provided observations
                                           | and actions. (Critical: make sure to
                                           | flatten this!)
            ===========  ================  ======================================

            Calling ``pi`` should return:

            ===========  ================  ======================================
            Symbol       Shape             Description
            ===========  ================  ======================================
            ``a``        (batch, act_dim)  | Tensor containing actions from policy
                                           | given observations.
            ``logp_pi``  (batch,)          | Tensor containing log probabilities of
                                           | actions in ``a``. Importantly: gradients
                                           | should be able to flow back into ``a``.
            ===========  ================  ======================================

        ac_kwargs (dict): Any kwargs appropriate for the ActorCritic object 
            you provided to SAC.

        seed (int): Seed for random number generators.

        steps_per_epoch (int): Number of steps of interaction (state-action pairs) 
            for the agent and the environment in each epoch.

        epochs (int): Number of epochs to run and train agent.

        replay_size (int): Maximum length of replay buffer.

        gamma (float): Discount factor. (Always between 0 and 1.)

        polyak (float): Interpolation factor in polyak averaging for target 
            networks. Target networks are updated towards main networks 
            according to:

            .. math:: \\theta_{\\text{targ}} \\leftarrow 
                \\rho \\theta_{\\text{targ}} + (1-\\rho) \\theta

            where :math:`\\rho` is polyak. (Always between 0 and 1, usually 
            close to 1.)

        lr (float): Learning rate (used for both policy and value learning).

        alpha (float): Entropy regularization coefficient. (Equivalent to 
            inverse of reward scale in the original SAC paper.)

        batch_size (int): Minibatch size for SGD.

        start_steps (int): Number of steps for uniform-random action selection,
            before running real policy. Helps exploration.

        update_after (int): Number of env interactions to collect before
            starting to do gradient descent updates. Ensures replay buffer
            is full enough for useful updates.

        update_every (int): Number of env interactions that should elapse
            between gradient descent updates. Note: Regardless of how long 
            you wait between updates, the ratio of env steps to gradient steps 
            is locked to 1.

        num_test_episodes (int): Number of episodes to test the deterministic
            policy at the end of each epoch.

        max_ep_len (int): Maximum length of trajectory / episode / rollout.

        logger_kwargs (dict): Keyword args for EpochLogger.

        save_freq (int): How often (in terms of gap between epochs) to save
            the current policy and value function.

    """

    logger = EpochLogger(**logger_kwargs)
    logger.save_config(locals())

    torch.manual_seed(seed)
    np.random.seed(seed)

    # Wrapper environment if using POMDP
    if partially_observable == True:
        env, test_env = POMDPWrapper(env_name), POMDPWrapper(env_name)
    else:
        env, test_env = gym.make(env_name), gym.make(env_name)
    obs_dim = env.observation_space.shape[0]   
    act_dim = env.action_space.shape[0]

    # Action limit for clamping: critically, assumes all dimensions share the same bound!
    act_limit = env.action_space.high[0]

    # Create actor-critic module and target networks
    ac = actor_critic(env.observation_space, env.action_space, **ac_kwargs)
    ac_targ = deepcopy(ac)

    # Freeze target networks with respect to optimizers (only update via polyak averaging)
    for p in ac_targ.parameters():
        p.requires_grad = False
        
    # List of parameters for both Q-networks (save this for convenience)
    q_params = itertools.chain(ac.q1.parameters(), ac.q2.parameters())

    # Experience buffer
    replay_buffer = ReplayBuffer(obs_dim=obs_dim, act_dim=act_dim, size=replay_size)

    # Count variables (protip: try to get a feel for how different size networks behave!)
    var_counts = tuple(core.count_vars(module) for module in [ac.pi, ac.q1, ac.q2])
    logger.log('\nNumber of parameters: \t pi: %d, \t q1: %d, \t q2: %d\n'%var_counts)

    # Set up function for computing SAC Q-losses
    def compute_loss_q(data):
        o, a, r, o2, d = data['obs'], data['act'], data['rew'], data['obs2'], data['done']

        q1 = ac.q1(o,a)
        q2 = ac.q2(o,a)

        # Bellman backup for Q functions
        with torch.no_grad():
            # Target actions come from *current* policy
            a2, logp_a2 = ac.pi(o2)

            # Target Q-values
            q1_pi_targ = ac_targ.q1(o2, a2)
            q2_pi_targ = ac_targ.q2(o2, a2)
            q_pi_targ = torch.min(q1_pi_targ, q2_pi_targ)
            backup = r + gamma * (1 - d) * (q_pi_targ - alpha * logp_a2)

        # MSE loss against Bellman backup
        loss_q1 = ((q1 - backup)**2).mean()
        loss_q2 = ((q2 - backup)**2).mean()
        loss_q = loss_q1 + loss_q2

        # Useful info for logging
        q_info = dict(Q1Vals=q1.detach().numpy(),
                      Q2Vals=q2.detach().numpy())

        return loss_q, q_info

    # Set up function for computing SAC pi loss
    def compute_loss_pi(data):
        o = data['obs']
        pi, logp_pi = ac.pi(o)
        q1_pi = ac.q1(o, pi)
        q2_pi = ac.q2(o, pi)
        q_pi = torch.min(q1_pi, q2_pi)

        # Entropy-regularized policy loss
        loss_pi = (alpha * logp_pi - q_pi).mean()

        # Useful info for logging
        pi_info = dict(LogPi=logp_pi.detach().numpy())

        return loss_pi, pi_info

    # Set up optimizers for policy and q-function
    pi_optimizer = Adam(ac.pi.parameters(), lr=lr)
    q_optimizer = Adam(q_params, lr=lr)

    # Set up model saving
    logger.setup_pytorch_saver(ac)

    def update(data):
        # First run one gradient descent step for Q1 and Q2
        q_optimizer.zero_grad()
        loss_q, q_info = compute_loss_q(data)
        loss_q.backward()
        q_optimizer.step()

        # Record things
        logger.store(LossQ=loss_q.item(), **q_info)

        # Freeze Q-networks so you don't waste computational effort 
        # computing gradients for them during the policy learning step.
        for p in q_params:
            p.requires_grad = False

        # Next run one gradient descent step for pi.
        pi_optimizer.zero_grad()
        loss_pi, pi_info = compute_loss_pi(data)
        loss_pi.backward()
        pi_optimizer.step()

        # Unfreeze Q-networks so you can optimize it at next DDPG step.
        for p in q_params:
            p.requires_grad = True

        # Record things
        logger.store(LossPi=loss_pi.item(), **pi_info)

        # Finally, update target networks by polyak averaging.
        with torch.no_grad():
            for p, p_targ in zip(ac.parameters(), ac_targ.parameters()):
                # NB: We use an in-place operations "mul_", "add_" to update target
                # params, as opposed to "mul" and "add", which would make new tensors.
                p_targ.data.mul_(polyak)
                p_targ.data.add_((1 - polyak) * p.data)

    def get_action(o, deterministic=False):
        return ac.act(torch.as_tensor(o, dtype=torch.float32), 
                      deterministic)

    def test_agent():
        for j in range(num_test_episodes):
            o, d, ep_ret, ep_len = test_env.reset(), False, 0, 0
            while not(d or (ep_len == max_ep_len)):
                # Take deterministic actions at test time 
                o, r, d, _ = test_env.step(get_action(o, True))
                ep_ret += r
                ep_len += 1
            logger.store(TestEpRet=ep_ret, TestEpLen=ep_len)

    # Prepare for interaction with environment
    total_steps = steps_per_epoch * epochs
    start_time = time.time()
    o, ep_ret, ep_len = env.reset(), 0, 0

    # Main loop: collect experience in env and update/log each epoch
    for t in range(total_steps):
        
        # Until start_steps have elapsed, randomly sample actions
        # from a uniform distribution for better exploration. Afterwards, 
        # use the learned policy. 
        if t > start_steps:
            a = get_action(o)
        else:
            a = env.action_space.sample()

        # Step the env
        o2, r, d, _ = env.step(a)
        ep_ret += r
        ep_len += 1

        # Ignore the "done" signal if it comes from hitting the time
        # horizon (that is, when it's an artificial terminal signal
        # that isn't based on the agent's state)
        d = False if ep_len==max_ep_len else d

        # Store experience to replay buffer
        replay_buffer.store(o, a, r, o2, d)

        # Super critical, easy to overlook step: make sure to update 
        # most recent observation!
        o = o2

        # End of trajectory handling
        if d or (ep_len == max_ep_len):
            logger.store(EpRet=ep_ret, EpLen=ep_len)
            o, ep_ret, ep_len = env.reset(), 0, 0

        # Update handling
        if t >= update_after and t % update_every == 0:
            for j in range(update_every):
                batch = replay_buffer.sample_batch(batch_size)
                update(data=batch)

        # End of epoch handling
        if (t+1) % steps_per_epoch == 0:
            epoch = (t+1) // steps_per_epoch

            # Save model
            if (epoch % save_freq == 0) or (epoch == epochs):
                logger.save_state({'env': env}, None)

            # Test the performance of the deterministic version of the agent.
            test_agent()

            # Log info about epoch
            logger.log_tabular('Epoch', epoch)
            logger.log_tabular('EpRet', with_min_and_max=True)
            logger.log_tabular('TestEpRet', with_min_and_max=True)
            logger.log_tabular('EpLen', average_only=True)
            logger.log_tabular('TestEpLen', average_only=True)
            logger.log_tabular('TotalEnvInteracts', t)
            logger.log_tabular('Q1Vals', with_min_and_max=True)
            logger.log_tabular('Q2Vals', with_min_and_max=True)
            logger.log_tabular('LogPi', with_min_and_max=True)
            logger.log_tabular('LossPi', average_only=True)
            logger.log_tabular('LossQ', average_only=True)
            logger.log_tabular('Time', time.time()-start_time)
            logger.dump_tabular()

# %%
args = {'env': 'Ant-v2', 'hid': 256, 'l': 2, 
        'max_hist_len': 5,
        'gamma': 0.99, 'seed': 0, 'epochs': 50, 
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'freeze_hist_coding': False,
        'exp_name': 'test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     max_hist_len=args['max_hist_len'],
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
    freeze_hist_coding=args['freeze_hist_coding'],
     logger_kwargs=logger_kwargs)

# %%
args = {'env': 'Ant-v2', 'hid': 256, 'l': 2, 
        'gamma': 0.99, 'seed':5, 'epochs':50, 
        'partially_observable': True,
        'exp_name': 'sac_POMDP'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

torch.set_num_threads(torch.get_num_threads())

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
    gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    partially_observable=args['partially_observable'],
    logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_POMDP\sac_POMDP_s5 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_POMDP\sac_POMDP_s5\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"Ant-v2",
#     "epochs":	50,
#     "exp_name":	"sac_POMDP",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001D4E01E31C8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_POMDP",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP\\sac_POMDP_s5",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\sac_POMDP\\\\sac_POMDP_s5\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_POMDP",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP\\sac_POMDP_s5"
#     },
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	5,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Number of parameters: 	 pi: 94992, 	 q1: 93185, 	 q2: 93185
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |           -52.9 |
# |          StdEpRet |            98.1 |
# |          MaxEpRet |            42.4 |
# |          MinEpRet |            -373 |
# |  AverageTestEpRet |             686 |
# |      StdTestEpRet |             119 |
# |      MaxTestEpRet |             922 |
# |      MinTestEpRet |             581 |
# |             EpLen |             156 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            6.45 |
# |         StdQ1Vals |            3.93 |
# |         MaxQ1Vals |              19 |
# |         MinQ1Vals |           -2.48 |
# |     AverageQ2Vals |            6.45 |
# |         StdQ2Vals |            3.93 |
# |         MaxQ2Vals |            18.8 |
# |         MinQ2Vals |           -2.43 |
# |      AverageLogPi |           -3.49 |
# |          StdLogPi |            1.55 |
# |          MaxLogPi |            5.07 |
# |          MinLogPi |           -17.4 |
# |            LossPi |           -7.81 |
# |             LossQ |            0.56 |
# |              Time |             154 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -66.6 |
# |          StdEpRet |             106 |
# |          MaxEpRet |            30.3 |
# |          MinEpRet |            -318 |
# |  AverageTestEpRet |             857 |
# |      StdTestEpRet |            44.9 |
# |      MaxTestEpRet |             900 |
# |      MinTestEpRet |             763 |
# |             EpLen |             222 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            20.8 |
# |         StdQ1Vals |            5.12 |
# |         MaxQ1Vals |            39.6 |
# |         MinQ1Vals |           -12.2 |
# |     AverageQ2Vals |            20.8 |
# |         StdQ2Vals |            5.11 |
# |         MaxQ2Vals |            39.4 |
# |         MinQ2Vals |           -10.5 |
# |      AverageLogPi |           -3.07 |
# |          StdLogPi |            1.74 |
# |          MaxLogPi |            10.4 |
# |          MinLogPi |           -15.8 |
# |            LossPi |           -22.2 |
# |             LossQ |            1.36 |
# |              Time |             344 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            6.28 |
# |          StdEpRet |             151 |
# |          MaxEpRet |             404 |
# |          MinEpRet |            -307 |
# |  AverageTestEpRet |             837 |
# |      StdTestEpRet |            15.3 |
# |      MaxTestEpRet |             868 |
# |      MinTestEpRet |             818 |
# |             EpLen |             250 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            34.4 |
# |         StdQ1Vals |            5.88 |
# |         MaxQ1Vals |            54.7 |
# |         MinQ1Vals |           -24.9 |
# |     AverageQ2Vals |            34.4 |
# |         StdQ2Vals |            5.88 |
# |         MaxQ2Vals |              55 |
# |         MinQ2Vals |           -22.7 |
# |      AverageLogPi |           -3.14 |
# |          StdLogPi |            1.68 |
# |          MaxLogPi |            12.2 |
# |          MinLogPi |           -15.2 |
# |            LossPi |           -35.8 |
# |             LossQ |            2.65 |
# |              Time |             526 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             220 |
# |          StdEpRet |             167 |
# |          MaxEpRet |             487 |
# |          MinEpRet |           -1.73 |
# |  AverageTestEpRet |             925 |
# |      StdTestEpRet |            63.1 |
# |      MaxTestEpRet |        1.01e+03 |
# |      MinTestEpRet |             835 |
# |             EpLen |             548 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            45.3 |
# |         StdQ1Vals |            6.46 |
# |         MaxQ1Vals |            66.8 |
# |         MinQ1Vals |             -36 |
# |     AverageQ2Vals |            45.3 |
# |         StdQ2Vals |            6.46 |
# |         MaxQ2Vals |            66.8 |
# |         MinQ2Vals |           -26.5 |
# |      AverageLogPi |           -3.28 |
# |          StdLogPi |            1.62 |
# |          MaxLogPi |              14 |
# |          MinLogPi |             -15 |
# |            LossPi |           -46.4 |
# |             LossQ |            2.76 |
# |              Time |             709 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             175 |
# |          StdEpRet |             112 |
# |          MaxEpRet |             376 |
# |          MinEpRet |            11.3 |
# |  AverageTestEpRet |             947 |
# |      StdTestEpRet |            17.2 |
# |      MaxTestEpRet |             979 |
# |      MinTestEpRet |             924 |
# |             EpLen |             501 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            54.3 |
# |         StdQ1Vals |            6.83 |
# |         MaxQ1Vals |            72.9 |
# |         MinQ1Vals |             -35 |
# |     AverageQ2Vals |            54.3 |
# |         StdQ2Vals |            6.83 |
# |         MaxQ2Vals |            73.4 |
# |         MinQ2Vals |           -37.7 |
# |      AverageLogPi |           -3.29 |
# |          StdLogPi |            1.59 |
# |          MaxLogPi |            15.8 |
# |          MinLogPi |           -16.2 |
# |            LossPi |           -55.3 |
# |             LossQ |             3.3 |
# |              Time |             894 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             201 |
# |          StdEpRet |            83.9 |
# |          MaxEpRet |             354 |
# |          MinEpRet |            60.5 |
# |  AverageTestEpRet |             904 |
# |      StdTestEpRet |            6.78 |
# |      MaxTestEpRet |             915 |
# |      MinTestEpRet |             889 |
# |             EpLen |             565 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            60.9 |
# |         StdQ1Vals |            6.58 |
# |         MaxQ1Vals |            78.3 |
# |         MinQ1Vals |           -38.1 |
# |     AverageQ2Vals |            60.9 |
# |         StdQ2Vals |            6.58 |
# |         MaxQ2Vals |            78.7 |
# |         MinQ2Vals |           -37.8 |
# |      AverageLogPi |           -3.27 |
# |          StdLogPi |            1.62 |
# |          MaxLogPi |            19.9 |
# |          MinLogPi |             -15 |
# |            LossPi |           -61.8 |
# |             LossQ |            3.96 |
# |              Time |        1.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             326 |
# |          StdEpRet |            60.3 |
# |          MaxEpRet |             425 |
# |          MinEpRet |             268 |
# |  AverageTestEpRet |             933 |
# |      StdTestEpRet |            34.2 |
# |      MaxTestEpRet |             971 |
# |      MinTestEpRet |             862 |
# |             EpLen |             906 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            65.8 |
# |         StdQ1Vals |            6.54 |
# |         MaxQ1Vals |              82 |
# |         MinQ1Vals |           -49.3 |
# |     AverageQ2Vals |            65.8 |
# |         StdQ2Vals |            6.54 |
# |         MaxQ2Vals |            82.6 |
# |         MinQ2Vals |           -35.9 |
# |      AverageLogPi |           -3.25 |
# |          StdLogPi |            1.65 |
# |          MaxLogPi |            23.2 |
# |          MinLogPi |           -16.1 |
# |            LossPi |           -66.7 |
# |             LossQ |            3.58 |
# |              Time |        1.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             227 |
# |          StdEpRet |             153 |
# |          MaxEpRet |             401 |
# |          MinEpRet |            33.4 |
# |  AverageTestEpRet |             941 |
# |      StdTestEpRet |            32.1 |
# |      MaxTestEpRet |             964 |
# |      MinTestEpRet |             850 |
# |             EpLen |             623 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            70.1 |
# |         StdQ1Vals |            6.41 |
# |         MaxQ1Vals |            86.2 |
# |         MinQ1Vals |           -49.7 |
# |     AverageQ2Vals |            70.1 |
# |         StdQ2Vals |            6.41 |
# |         MaxQ2Vals |              86 |
# |         MinQ2Vals |           -37.3 |
# |      AverageLogPi |           -3.28 |
# |          StdLogPi |            1.64 |
# |          MaxLogPi |            21.6 |
# |          MinLogPi |           -15.6 |
# |            LossPi |             -71 |
# |             LossQ |            3.82 |
# |              Time |        1.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             151 |
# |          StdEpRet |             141 |
# |          MaxEpRet |             413 |
# |          MinEpRet |           -1.22 |
# |  AverageTestEpRet |             928 |
# |      StdTestEpRet |            22.1 |
# |      MaxTestEpRet |             950 |
# |      MinTestEpRet |             874 |
# |             EpLen |             437 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            73.7 |
# |         StdQ1Vals |            6.38 |
# |         MaxQ1Vals |            88.5 |
# |         MinQ1Vals |           -36.7 |
# |     AverageQ2Vals |            73.7 |
# |         StdQ2Vals |            6.37 |
# |         MaxQ2Vals |            88.5 |
# |         MinQ2Vals |           -42.5 |
# |      AverageLogPi |           -3.28 |
# |          StdLogPi |            1.66 |
# |          MaxLogPi |            20.4 |
# |          MinLogPi |           -15.7 |
# |            LossPi |           -74.5 |
# |             LossQ |            4.77 |
# |              Time |        1.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             195 |
# |          StdEpRet |             143 |
# |          MaxEpRet |             421 |
# |          MinEpRet |           0.853 |
# |  AverageTestEpRet |             959 |
# |      StdTestEpRet |            5.98 |
# |      MaxTestEpRet |             975 |
# |      MinTestEpRet |             953 |
# |             EpLen |             563 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            76.3 |
# |         StdQ1Vals |             6.3 |
# |         MaxQ1Vals |              91 |
# |         MinQ1Vals |           -54.7 |
# |     AverageQ2Vals |            76.3 |
# |         StdQ2Vals |             6.3 |
# |         MaxQ2Vals |            90.6 |
# |         MinQ2Vals |           -48.2 |
# |      AverageLogPi |           -3.27 |
# |          StdLogPi |            1.68 |
# |          MaxLogPi |            25.7 |
# |          MinLogPi |             -18 |
# |            LossPi |           -77.1 |
# |             LossQ |            4.65 |
# |              Time |        1.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             195 |
# |          StdEpRet |             117 |
# |          MaxEpRet |             338 |
# |          MinEpRet |            52.2 |
# |  AverageTestEpRet |             919 |
# |      StdTestEpRet |             4.2 |
# |      MaxTestEpRet |             926 |
# |      MinTestEpRet |             911 |
# |             EpLen |             537 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            78.6 |
# |         StdQ1Vals |            6.22 |
# |         MaxQ1Vals |            92.8 |
# |         MinQ1Vals |           -37.2 |
# |     AverageQ2Vals |            78.6 |
# |         StdQ2Vals |            6.22 |
# |         MaxQ2Vals |            93.1 |
# |         MinQ2Vals |           -47.5 |
# |      AverageLogPi |           -3.24 |
# |          StdLogPi |            1.67 |
# |          MaxLogPi |            21.7 |
# |          MinLogPi |           -13.8 |
# |            LossPi |           -79.3 |
# |             LossQ |            4.78 |
# |              Time |        2.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             271 |
# |          StdEpRet |             132 |
# |          MaxEpRet |             351 |
# |          MinEpRet |            43.1 |
# |  AverageTestEpRet |             890 |
# |      StdTestEpRet |            32.1 |
# |      MaxTestEpRet |             923 |
# |      MinTestEpRet |             835 |
# |             EpLen |             785 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            80.5 |
# |         StdQ1Vals |            6.17 |
# |         MaxQ1Vals |            94.6 |
# |         MinQ1Vals |           -47.4 |
# |     AverageQ2Vals |            80.5 |
# |         StdQ2Vals |            6.18 |
# |         MaxQ2Vals |            94.3 |
# |         MinQ2Vals |           -43.1 |
# |      AverageLogPi |           -3.26 |
# |          StdLogPi |            1.69 |
# |          MaxLogPi |            20.7 |
# |          MinLogPi |           -14.3 |
# |            LossPi |           -81.3 |
# |             LossQ |            4.71 |
# |              Time |        2.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             169 |
# |          StdEpRet |             146 |
# |          MaxEpRet |             465 |
# |          MinEpRet |            2.82 |
# |  AverageTestEpRet |             824 |
# |      StdTestEpRet |            22.2 |
# |      MaxTestEpRet |             859 |
# |      MinTestEpRet |             786 |
# |             EpLen |             433 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |              82 |
# |         StdQ1Vals |            6.12 |
# |         MaxQ1Vals |            96.6 |
# |         MinQ1Vals |           -45.5 |
# |     AverageQ2Vals |              82 |
# |         StdQ2Vals |            6.14 |
# |         MaxQ2Vals |            95.8 |
# |         MinQ2Vals |           -51.9 |
# |      AverageLogPi |            -3.3 |
# |          StdLogPi |             1.7 |
# |          MaxLogPi |            25.3 |
# |          MinLogPi |           -15.7 |
# |            LossPi |           -82.8 |
# |             LossQ |            4.91 |
# |              Time |        2.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             309 |
# |          StdEpRet |              49 |
# |          MaxEpRet |             361 |
# |          MinEpRet |             238 |
# |  AverageTestEpRet |             791 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |             809 |
# |      MinTestEpRet |             778 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            83.2 |
# |         StdQ1Vals |            6.07 |
# |         MaxQ1Vals |            97.6 |
# |         MinQ1Vals |           -55.4 |
# |     AverageQ2Vals |            83.2 |
# |         StdQ2Vals |            6.06 |
# |         MaxQ2Vals |            97.2 |
# |         MinQ2Vals |           -58.3 |
# |      AverageLogPi |           -3.33 |
# |          StdLogPi |            1.64 |
# |          MaxLogPi |              24 |
# |          MinLogPi |           -13.7 |
# |            LossPi |             -84 |
# |             LossQ |            4.94 |
# |              Time |        2.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             163 |
# |          StdEpRet |             128 |
# |          MaxEpRet |             380 |
# |          MinEpRet |            4.96 |
# |  AverageTestEpRet |             767 |
# |      StdTestEpRet |            24.8 |
# |      MaxTestEpRet |             831 |
# |      MinTestEpRet |             741 |
# |             EpLen |             475 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            84.2 |
# |         StdQ1Vals |            6.23 |
# |         MaxQ1Vals |            98.3 |
# |         MinQ1Vals |           -45.8 |
# |     AverageQ2Vals |            84.2 |
# |         StdQ2Vals |            6.23 |
# |         MaxQ2Vals |            97.7 |
# |         MinQ2Vals |           -50.3 |
# |      AverageLogPi |           -3.35 |
# |          StdLogPi |            1.64 |
# |          MaxLogPi |              23 |
# |          MinLogPi |           -16.4 |
# |            LossPi |           -84.9 |
# |             LossQ |             5.2 |
# |              Time |        2.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             221 |
# |          StdEpRet |             149 |
# |          MaxEpRet |             466 |
# |          MinEpRet |              15 |
# |  AverageTestEpRet |             834 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |             853 |
# |      MinTestEpRet |             818 |
# |             EpLen |             601 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |              85 |
# |         StdQ1Vals |            6.46 |
# |         MaxQ1Vals |            99.4 |
# |         MinQ1Vals |           -51.9 |
# |     AverageQ2Vals |              85 |
# |         StdQ2Vals |            6.44 |
# |         MaxQ2Vals |            98.8 |
# |         MinQ2Vals |           -44.2 |
# |      AverageLogPi |           -3.37 |
# |          StdLogPi |            1.62 |
# |          MaxLogPi |            22.1 |
# |          MinLogPi |           -14.4 |
# |            LossPi |           -85.7 |
# |             LossQ |            4.57 |
# |              Time |        3.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             217 |
# |          StdEpRet |             161 |
# |          MaxEpRet |             492 |
# |          MinEpRet |            18.1 |
# |  AverageTestEpRet |             925 |
# |      StdTestEpRet |            4.45 |
# |      MaxTestEpRet |             932 |
# |      MinTestEpRet |             919 |
# |             EpLen |             488 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            85.7 |
# |         StdQ1Vals |            6.75 |
# |         MaxQ1Vals |            99.4 |
# |         MinQ1Vals |           -47.1 |
# |     AverageQ2Vals |            85.7 |
# |         StdQ2Vals |            6.74 |
# |         MaxQ2Vals |            99.5 |
# |         MinQ2Vals |           -51.4 |
# |      AverageLogPi |           -3.35 |
# |          StdLogPi |            1.61 |
# |          MaxLogPi |            25.9 |
# |          MinLogPi |           -17.9 |
# |            LossPi |           -86.4 |
# |             LossQ |            4.66 |
# |              Time |        3.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             153 |
# |          StdEpRet |             145 |
# |          MaxEpRet |             429 |
# |          MinEpRet |            1.35 |
# |  AverageTestEpRet |             891 |
# |      StdTestEpRet |            44.3 |
# |      MaxTestEpRet |             916 |
# |      MinTestEpRet |             785 |
# |             EpLen |             382 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            86.4 |
# |         StdQ1Vals |            6.99 |
# |         MaxQ1Vals |             100 |
# |         MinQ1Vals |           -46.7 |
# |     AverageQ2Vals |            86.4 |
# |         StdQ2Vals |            6.99 |
# |         MaxQ2Vals |            99.5 |
# |         MinQ2Vals |           -51.5 |
# |      AverageLogPi |           -3.31 |
# |          StdLogPi |            1.66 |
# |          MaxLogPi |            30.4 |
# |          MinLogPi |           -16.3 |
# |            LossPi |           -87.1 |
# |             LossQ |            5.51 |
# |              Time |        3.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             272 |
# |          StdEpRet |             105 |
# |          MaxEpRet |             410 |
# |          MinEpRet |             102 |
# |  AverageTestEpRet |             737 |
# |      StdTestEpRet |            7.23 |
# |      MaxTestEpRet |             755 |
# |      MinTestEpRet |             729 |
# |             EpLen |             680 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            86.8 |
# |         StdQ1Vals |            7.01 |
# |         MaxQ1Vals |            99.7 |
# |         MinQ1Vals |           -49.5 |
# |     AverageQ2Vals |            86.8 |
# |         StdQ2Vals |               7 |
# |         MaxQ2Vals |            99.6 |
# |         MinQ2Vals |           -45.6 |
# |      AverageLogPi |           -3.27 |
# |          StdLogPi |            1.68 |
# |          MaxLogPi |              36 |
# |          MinLogPi |           -15.4 |
# |            LossPi |           -87.5 |
# |             LossQ |            5.34 |
# |              Time |        3.77e+03 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6a0744134518> in <module>
#      13     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
#      14     partially_observable=args['partially_observable'],
# ---> 15     logger_kwargs=logger_kwargs)
#
# <ipython-input-7-207d40c8f2da> in sac(env_name, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, lr, alpha, batch_size, start_steps, update_after, update_every, num_test_episodes, max_ep_len, partially_observable, logger_kwargs, save_freq)
#     281             for j in range(update_every):
#     282                 batch = replay_buffer.sample_batch(batch_size)
# --> 283                 update(data=batch)
#     284
#     285         # End of epoch handling
#
# <ipython-input-7-207d40c8f2da> in update(data)
#     208         loss_pi, pi_info = compute_loss_pi(data)
#     209         loss_pi.backward()
# --> 210         pi_optimizer.step()
#     211
#     212         # Unfreeze Q-networks so you can optimize it at next DDPG step.
#
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     109                 step_size = group['lr'] / bias_correction1
#     110
# --> 111                 p.addcdiv_(exp_avg, denom, value=-step_size)
#     112
#     113         return loss
#
# KeyboardInterrupt:

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 
        'gamma': 0.99, 'seed':5, 'epochs':50, 
        'partially_observable': True,
        'exp_name': 'sac_POMDP_HalfCheetah'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

torch.set_num_threads(torch.get_num_threads())

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
    gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    partially_observable=args['partially_observable'],
    logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_POMDP_HalfCheetah\sac_POMDP_HalfCheetah_s5\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"sac_POMDP_HalfCheetah",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001D4DE3A2108>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_POMDP_HalfCheetah",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_HalfCheetah\\sac_POMDP_HalfCheetah_s5",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\sac_POMDP_HalfCheetah\\\\sac_POMDP_HalfCheetah_s5\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_POMDP_HalfCheetah",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_HalfCheetah\\sac_POMDP_HalfCheetah_s5"
#     },
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	5,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 71180, 	 q1: 69889, 	 q2: 69889
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -271 |
# |          StdEpRet |              78 |
# |          MaxEpRet |            -191 |
# |          MinEpRet |            -383 |
# |  AverageTestEpRet |           -7.04 |
# |      StdTestEpRet |            1.09 |
# |      MaxTestEpRet |           -5.71 |
# |      MinTestEpRet |            -9.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            4.64 |
# |         StdQ1Vals |            2.54 |
# |         MaxQ1Vals |            15.3 |
# |         MinQ1Vals |          -0.911 |
# |     AverageQ2Vals |            4.64 |
# |         StdQ2Vals |            2.54 |
# |         MaxQ2Vals |            15.4 |
# |         MinQ2Vals |          -0.853 |
# |      AverageLogPi |            -3.5 |
# |          StdLogPi |            1.18 |
# |          MaxLogPi |            7.23 |
# |          MinLogPi |           -11.5 |
# |            LossPi |            -5.5 |
# |             LossQ |           0.269 |
# |              Time |             123 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -315 |
# |          StdEpRet |             100 |
# |          MaxEpRet |            -192 |
# |          MinEpRet |            -418 |
# |  AverageTestEpRet |            -106 |
# |      StdTestEpRet |           0.868 |
# |      MaxTestEpRet |            -105 |
# |      MinTestEpRet |            -108 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            13.3 |
# |         StdQ1Vals |            3.44 |
# |         MaxQ1Vals |            27.5 |
# |         MinQ1Vals |            5.23 |
# |     AverageQ2Vals |            13.3 |
# |         StdQ2Vals |            3.44 |
# |         MaxQ2Vals |            27.1 |
# |         MinQ2Vals |            5.23 |
# |      AverageLogPi |            -2.9 |
# |          StdLogPi |            1.56 |
# |          MaxLogPi |            7.25 |
# |          MinLogPi |           -12.5 |
# |            LossPi |           -14.3 |
# |             LossQ |             0.5 |
# |              Time |             288 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -257 |
# |          StdEpRet |             106 |
# |          MaxEpRet |            -128 |
# |          MinEpRet |            -394 |
# |  AverageTestEpRet |           -49.9 |
# |      StdTestEpRet |            1.18 |
# |      MaxTestEpRet |           -48.1 |
# |      MinTestEpRet |           -51.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            25.1 |
# |         StdQ1Vals |            4.03 |
# |         MaxQ1Vals |            35.9 |
# |         MinQ1Vals |            14.5 |
# |     AverageQ2Vals |            25.1 |
# |         StdQ2Vals |            4.03 |
# |         MaxQ2Vals |            35.5 |
# |         MinQ2Vals |            14.3 |
# |      AverageLogPi |           -2.04 |
# |          StdLogPi |            2.09 |
# |          MaxLogPi |            11.7 |
# |          MinLogPi |           -14.2 |
# |            LossPi |           -26.2 |
# |             LossQ |           0.686 |
# |              Time |             457 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -152 |
# |          StdEpRet |            57.9 |
# |          MaxEpRet |           -94.2 |
# |          MinEpRet |            -233 |
# |  AverageTestEpRet |           -5.91 |
# |      StdTestEpRet |            1.89 |
# |      MaxTestEpRet |            -3.6 |
# |      MinTestEpRet |           -9.86 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            31.3 |
# |         StdQ1Vals |            2.29 |
# |         MaxQ1Vals |            38.3 |
# |         MinQ1Vals |            21.4 |
# |     AverageQ2Vals |            31.3 |
# |         StdQ2Vals |            2.29 |
# |         MaxQ2Vals |            37.7 |
# |         MinQ2Vals |            21.6 |
# |      AverageLogPi |           -3.43 |
# |          StdLogPi |            1.13 |
# |          MaxLogPi |            5.84 |
# |          MinLogPi |           -11.9 |
# |            LossPi |             -32 |
# |             LossQ |           0.463 |
# |              Time |             621 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -176 |
# |          StdEpRet |            34.2 |
# |          MaxEpRet |            -118 |
# |          MinEpRet |            -202 |
# |  AverageTestEpRet |           -6.71 |
# |      StdTestEpRet |             1.8 |
# |      MaxTestEpRet |           -3.44 |
# |      MinTestEpRet |           -9.77 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            34.4 |
# |         StdQ1Vals |            2.66 |
# |         MaxQ1Vals |            41.9 |
# |         MinQ1Vals |            25.8 |
# |     AverageQ2Vals |            34.4 |
# |         StdQ2Vals |            2.66 |
# |         MaxQ2Vals |            41.9 |
# |         MinQ2Vals |            25.8 |
# |      AverageLogPi |           -3.39 |
# |          StdLogPi |            1.18 |
# |          MaxLogPi |            10.5 |
# |          MinLogPi |             -11 |
# |            LossPi |           -35.2 |
# |             LossQ |           0.434 |
# |              Time |             784 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -181 |
# |          StdEpRet |            25.9 |
# |          MaxEpRet |            -138 |
# |          MinEpRet |            -204 |
# |  AverageTestEpRet |           -6.78 |
# |      StdTestEpRet |            1.54 |
# |      MaxTestEpRet |           -3.55 |
# |      MinTestEpRet |           -8.82 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            37.6 |
# |         StdQ1Vals |            2.92 |
# |         MaxQ1Vals |            45.1 |
# |         MinQ1Vals |            29.2 |
# |     AverageQ2Vals |            37.6 |
# |         StdQ2Vals |            2.92 |
# |         MaxQ2Vals |            45.1 |
# |         MinQ2Vals |            29.3 |
# |      AverageLogPi |           -3.41 |
# |          StdLogPi |            1.19 |
# |          MaxLogPi |            8.85 |
# |          MinLogPi |           -11.8 |
# |            LossPi |           -38.3 |
# |             LossQ |           0.404 |
# |              Time |             954 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |           -95.9 |
# |          StdEpRet |            43.3 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |            -136 |
# |  AverageTestEpRet |           -7.53 |
# |      StdTestEpRet |            1.61 |
# |      MaxTestEpRet |           -5.32 |
# |      MinTestEpRet |           -10.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            40.5 |
# |         StdQ1Vals |            3.35 |
# |         MaxQ1Vals |            48.1 |
# |         MinQ1Vals |            32.1 |
# |     AverageQ2Vals |            40.5 |
# |         StdQ2Vals |            3.35 |
# |         MaxQ2Vals |            48.2 |
# |         MinQ2Vals |            32.3 |
# |      AverageLogPi |           -3.43 |
# |          StdLogPi |            1.19 |
# |          MaxLogPi |            9.77 |
# |          MinLogPi |             -12 |
# |            LossPi |           -41.3 |
# |             LossQ |           0.396 |
# |              Time |        1.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -156 |
# |          StdEpRet |            56.1 |
# |          MaxEpRet |           -83.9 |
# |          MinEpRet |            -241 |
# |  AverageTestEpRet |           -10.1 |
# |      StdTestEpRet |            1.27 |
# |      MaxTestEpRet |           -8.28 |
# |      MinTestEpRet |           -12.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            43.1 |
# |         StdQ1Vals |            3.63 |
# |         MaxQ1Vals |            50.9 |
# |         MinQ1Vals |            34.2 |
# |     AverageQ2Vals |            43.1 |
# |         StdQ2Vals |            3.63 |
# |         MaxQ2Vals |            51.1 |
# |         MinQ2Vals |            34.5 |
# |      AverageLogPi |            -3.5 |
# |          StdLogPi |            1.12 |
# |          MaxLogPi |            11.5 |
# |          MinLogPi |           -11.5 |
# |            LossPi |           -43.8 |
# |             LossQ |           0.379 |
# |              Time |         1.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -162 |
# |          StdEpRet |            61.3 |
# |          MaxEpRet |           -61.3 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |           -13.3 |
# |      StdTestEpRet |            1.27 |
# |      MaxTestEpRet |           -10.4 |
# |      MinTestEpRet |           -14.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |              45 |
# |         StdQ1Vals |            3.96 |
# |         MaxQ1Vals |              53 |
# |         MinQ1Vals |            36.1 |
# |     AverageQ2Vals |              45 |
# |         StdQ2Vals |            3.96 |
# |         MaxQ2Vals |              53 |
# |         MinQ2Vals |            36.1 |
# |      AverageLogPi |           -3.51 |
# |          StdLogPi |            1.12 |
# |          MaxLogPi |            10.9 |
# |          MinLogPi |           -12.4 |
# |            LossPi |           -45.7 |
# |             LossQ |           0.374 |
# |              Time |        1.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -199 |
# |          StdEpRet |            29.4 |
# |          MaxEpRet |            -158 |
# |          MinEpRet |            -239 |
# |  AverageTestEpRet |           -8.47 |
# |      StdTestEpRet |           0.835 |
# |      MaxTestEpRet |           -7.34 |
# |      MinTestEpRet |           -10.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            46.5 |
# |         StdQ1Vals |            4.22 |
# |         MaxQ1Vals |            55.1 |
# |         MinQ1Vals |            38.2 |
# |     AverageQ2Vals |            46.5 |
# |         StdQ2Vals |            4.22 |
# |         MaxQ2Vals |              55 |
# |         MinQ2Vals |            37.8 |
# |      AverageLogPi |           -3.54 |
# |          StdLogPi |            1.07 |
# |          MaxLogPi |            8.61 |
# |          MinLogPi |           -14.6 |
# |            LossPi |           -47.3 |
# |             LossQ |           0.354 |
# |              Time |        1.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -153 |
# |          StdEpRet |            65.6 |
# |          MaxEpRet |           -40.4 |
# |          MinEpRet |            -199 |
# |  AverageTestEpRet |           -6.86 |
# |      StdTestEpRet |           0.704 |
# |      MaxTestEpRet |           -5.97 |
# |      MinTestEpRet |           -8.28 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            47.8 |
# |         StdQ1Vals |            4.45 |
# |         MaxQ1Vals |            56.7 |
# |         MinQ1Vals |            39.3 |
# |     AverageQ2Vals |            47.8 |
# |         StdQ2Vals |            4.45 |
# |         MaxQ2Vals |            56.7 |
# |         MinQ2Vals |            39.3 |
# |      AverageLogPi |           -3.55 |
# |          StdLogPi |            1.06 |
# |          MaxLogPi |            8.35 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -48.5 |
# |             LossQ |            0.34 |
# |              Time |        1.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -177 |
# |          StdEpRet |            27.3 |
# |          MaxEpRet |            -133 |
# |          MinEpRet |            -202 |
# |  AverageTestEpRet |           -1.39 |
# |      StdTestEpRet |           0.843 |
# |      MaxTestEpRet |           0.489 |
# |      MinTestEpRet |           -2.44 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |              49 |
# |         StdQ1Vals |            4.67 |
# |         MaxQ1Vals |            58.1 |
# |         MinQ1Vals |            40.3 |
# |     AverageQ2Vals |              49 |
# |         StdQ2Vals |            4.67 |
# |         MaxQ2Vals |            58.3 |
# |         MinQ2Vals |            40.7 |
# |      AverageLogPi |           -3.58 |
# |          StdLogPi |            1.03 |
# |          MaxLogPi |            6.18 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -49.7 |
# |             LossQ |           0.341 |
# |              Time |           2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           -88.7 |
# |          StdEpRet |            71.1 |
# |          MaxEpRet |           -23.1 |
# |          MinEpRet |            -204 |
# |  AverageTestEpRet |            -8.8 |
# |      StdTestEpRet |           0.875 |
# |      MaxTestEpRet |           -7.51 |
# |      MinTestEpRet |           -9.97 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |              50 |
# |         StdQ1Vals |            4.88 |
# |         MaxQ1Vals |            59.3 |
# |         MinQ1Vals |            41.1 |
# |     AverageQ2Vals |              50 |
# |         StdQ2Vals |            4.88 |
# |         MaxQ2Vals |            59.3 |
# |         MinQ2Vals |            41.3 |
# |      AverageLogPi |           -3.58 |
# |          StdLogPi |            1.03 |
# |          MaxLogPi |            8.26 |
# |          MinLogPi |           -12.4 |
# |            LossPi |           -50.7 |
# |             LossQ |           0.331 |
# |              Time |        2.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -134 |
# |          StdEpRet |            59.3 |
# |          MaxEpRet |             -43 |
# |          MinEpRet |            -204 |
# |  AverageTestEpRet |           -6.85 |
# |      StdTestEpRet |            1.09 |
# |      MaxTestEpRet |           -5.04 |
# |      MinTestEpRet |           -8.75 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |              51 |
# |         StdQ1Vals |             5.1 |
# |         MaxQ1Vals |            60.8 |
# |         MinQ1Vals |            41.9 |
# |     AverageQ2Vals |              51 |
# |         StdQ2Vals |             5.1 |
# |         MaxQ2Vals |            60.5 |
# |         MinQ2Vals |            41.8 |
# |      AverageLogPi |           -3.59 |
# |          StdLogPi |            1.04 |
# |          MaxLogPi |            7.74 |
# |          MinLogPi |             -13 |
# |            LossPi |           -51.7 |
# |             LossQ |            0.33 |
# |              Time |        2.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -127 |
# |          StdEpRet |            40.6 |
# |          MaxEpRet |           -78.6 |
# |          MinEpRet |            -178 |
# |  AverageTestEpRet |           -4.41 |
# |      StdTestEpRet |            0.99 |
# |      MaxTestEpRet |           -2.24 |
# |      MinTestEpRet |           -6.24 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            51.9 |
# |         StdQ1Vals |            5.29 |
# |         MaxQ1Vals |            61.6 |
# |         MinQ1Vals |            42.8 |
# |     AverageQ2Vals |            51.9 |
# |         StdQ2Vals |            5.29 |
# |         MaxQ2Vals |            61.6 |
# |         MinQ2Vals |              43 |
# |      AverageLogPi |           -3.63 |
# |          StdLogPi |           0.979 |
# |          MaxLogPi |            6.76 |
# |          MinLogPi |           -11.1 |
# |            LossPi |           -52.6 |
# |             LossQ |           0.334 |
# |              Time |        2.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -181 |
# |          StdEpRet |            34.2 |
# |          MaxEpRet |            -138 |
# |          MinEpRet |            -233 |
# |  AverageTestEpRet |           -14.2 |
# |      StdTestEpRet |            1.19 |
# |      MaxTestEpRet |           -11.7 |
# |      MinTestEpRet |             -16 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            52.3 |
# |         StdQ1Vals |            5.41 |
# |         MaxQ1Vals |            62.4 |
# |         MinQ1Vals |            42.9 |
# |     AverageQ2Vals |            52.3 |
# |         StdQ2Vals |            5.41 |
# |         MaxQ2Vals |              62 |
# |         MinQ2Vals |            43.1 |
# |      AverageLogPi |           -3.63 |
# |          StdLogPi |            0.99 |
# |          MaxLogPi |            6.53 |
# |          MinLogPi |             -12 |
# |            LossPi |           -53.1 |
# |             LossQ |           0.329 |
# |              Time |        2.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -179 |
# |          StdEpRet |            36.1 |
# |          MaxEpRet |            -146 |
# |          MinEpRet |            -238 |
# |  AverageTestEpRet |           -8.79 |
# |      StdTestEpRet |            1.24 |
# |      MaxTestEpRet |           -6.92 |
# |      MinTestEpRet |           -10.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            52.8 |
# |         StdQ1Vals |            5.57 |
# |         MaxQ1Vals |            63.1 |
# |         MinQ1Vals |            43.8 |
# |     AverageQ2Vals |            52.8 |
# |         StdQ2Vals |            5.57 |
# |         MaxQ2Vals |            62.9 |
# |         MinQ2Vals |            43.9 |
# |      AverageLogPi |           -3.63 |
# |          StdLogPi |               1 |
# |          MaxLogPi |            6.47 |
# |          MinLogPi |           -13.5 |
# |            LossPi |           -53.5 |
# |             LossQ |           0.328 |
# |              Time |        2.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -185 |
# |          StdEpRet |            55.9 |
# |          MaxEpRet |            -113 |
# |          MinEpRet |            -254 |
# |  AverageTestEpRet |            -9.4 |
# |      StdTestEpRet |            1.34 |
# |      MaxTestEpRet |           -7.24 |
# |      MinTestEpRet |           -11.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            53.1 |
# |         StdQ1Vals |            5.75 |
# |         MaxQ1Vals |            63.5 |
# |         MinQ1Vals |            44.3 |
# |     AverageQ2Vals |            53.1 |
# |         StdQ2Vals |            5.75 |
# |         MaxQ2Vals |            63.4 |
# |         MinQ2Vals |            44.4 |
# |      AverageLogPi |           -3.63 |
# |          StdLogPi |            1.02 |
# |          MaxLogPi |            6.64 |
# |          MinLogPi |           -12.3 |
# |            LossPi |           -53.9 |
# |             LossQ |           0.322 |
# |              Time |        3.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -142 |
# |          StdEpRet |            69.1 |
# |          MaxEpRet |           -24.5 |
# |          MinEpRet |            -201 |
# |  AverageTestEpRet |           -2.78 |
# |      StdTestEpRet |            0.98 |
# |      MaxTestEpRet |            -1.4 |
# |      MinTestEpRet |           -4.87 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            53.5 |
# |         StdQ1Vals |            5.94 |
# |         MaxQ1Vals |            64.2 |
# |         MinQ1Vals |            44.4 |
# |     AverageQ2Vals |            53.5 |
# |         StdQ2Vals |            5.94 |
# |         MaxQ2Vals |              64 |
# |         MinQ2Vals |            44.4 |
# |      AverageLogPi |           -3.64 |
# |          StdLogPi |            0.99 |
# |          MaxLogPi |             7.8 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -54.2 |
# |             LossQ |           0.322 |
# |              Time |         3.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -178 |
# |          StdEpRet |            33.7 |
# |          MaxEpRet |            -124 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |           -9.33 |
# |      StdTestEpRet |            1.21 |
# |      MaxTestEpRet |           -7.96 |
# |      MinTestEpRet |           -12.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            53.7 |
# |         StdQ1Vals |             6.1 |
# |         MaxQ1Vals |            64.9 |
# |         MinQ1Vals |            44.7 |
# |     AverageQ2Vals |            53.7 |
# |         StdQ2Vals |             6.1 |
# |         MaxQ2Vals |            64.7 |
# |         MinQ2Vals |            44.5 |
# |      AverageLogPi |           -3.63 |
# |          StdLogPi |            1.01 |
# |          MaxLogPi |            6.09 |
# |          MinLogPi |             -12 |
# |            LossPi |           -54.5 |
# |             LossQ |           0.318 |
# |              Time |        3.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -216 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |            -186 |
# |          MinEpRet |            -254 |
# |  AverageTestEpRet |           -9.88 |
# |      StdTestEpRet |           0.884 |
# |      MaxTestEpRet |           -8.02 |
# |      MinTestEpRet |           -10.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            53.9 |
# |         StdQ1Vals |            6.23 |
# |         MaxQ1Vals |            65.2 |
# |         MinQ1Vals |            44.6 |
# |     AverageQ2Vals |            53.9 |
# |         StdQ2Vals |            6.23 |
# |         MaxQ2Vals |            65.2 |
# |         MinQ2Vals |            44.9 |
# |      AverageLogPi |           -3.64 |
# |          StdLogPi |           0.999 |
# |          MaxLogPi |            6.67 |
# |          MinLogPi |           -12.7 |
# |            LossPi |           -54.6 |
# |             LossQ |           0.316 |
# |              Time |        3.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -152 |
# |          StdEpRet |            58.8 |
# |          MaxEpRet |           -62.6 |
# |          MinEpRet |            -205 |
# |  AverageTestEpRet |           -9.25 |
# |      StdTestEpRet |               1 |
# |      MaxTestEpRet |           -7.22 |
# |      MinTestEpRet |           -10.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |              54 |
# |         StdQ1Vals |            6.33 |
# |         MaxQ1Vals |            65.6 |
# |         MinQ1Vals |              45 |
# |     AverageQ2Vals |              54 |
# |         StdQ2Vals |            6.33 |
# |         MaxQ2Vals |            65.5 |
# |         MinQ2Vals |            44.9 |
# |      AverageLogPi |           -3.65 |
# |          StdLogPi |           0.982 |
# |          MaxLogPi |            8.82 |
# |          MinLogPi |           -12.3 |
# |            LossPi |           -54.7 |
# |             LossQ |           0.304 |
# |              Time |        3.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -169 |
# |          StdEpRet |            72.9 |
# |          MaxEpRet |           -43.2 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |             -14 |
# |      StdTestEpRet |           0.901 |
# |      MaxTestEpRet |           -12.6 |
# |      MinTestEpRet |           -15.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            54.1 |
# |         StdQ1Vals |            6.47 |
# |         MaxQ1Vals |            66.4 |
# |         MinQ1Vals |            44.9 |
# |     AverageQ2Vals |            54.1 |
# |         StdQ2Vals |            6.47 |
# |         MaxQ2Vals |              66 |
# |         MinQ2Vals |            44.8 |
# |      AverageLogPi |           -3.67 |
# |          StdLogPi |           0.952 |
# |          MaxLogPi |            7.31 |
# |          MinLogPi |           -12.6 |
# |            LossPi |           -54.8 |
# |             LossQ |           0.302 |
# |              Time |        3.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -196 |
# |          StdEpRet |            41.4 |
# |          MaxEpRet |            -127 |
# |          MinEpRet |            -237 |
# |  AverageTestEpRet |           -12.7 |
# |      StdTestEpRet |           0.664 |
# |      MaxTestEpRet |           -11.8 |
# |      MinTestEpRet |           -13.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            54.2 |
# |         StdQ1Vals |            6.58 |
# |         MaxQ1Vals |            66.3 |
# |         MinQ1Vals |            44.9 |
# |     AverageQ2Vals |            54.2 |
# |         StdQ2Vals |            6.58 |
# |         MaxQ2Vals |            66.2 |
# |         MinQ2Vals |              45 |
# |      AverageLogPi |           -3.66 |
# |          StdLogPi |           0.965 |
# |          MaxLogPi |            8.81 |
# |          MinLogPi |           -11.2 |
# |            LossPi |             -55 |
# |             LossQ |           0.303 |
# |              Time |        4.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -157 |
# |          StdEpRet |            79.8 |
# |          MaxEpRet |           -21.2 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |             -14 |
# |      StdTestEpRet |           0.941 |
# |      MaxTestEpRet |           -12.9 |
# |      MinTestEpRet |           -16.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            54.4 |
# |         StdQ1Vals |            6.73 |
# |         MaxQ1Vals |            66.6 |
# |         MinQ1Vals |            45.3 |
# |     AverageQ2Vals |            54.4 |
# |         StdQ2Vals |            6.73 |
# |         MaxQ2Vals |            66.7 |
# |         MinQ2Vals |              45 |
# |      AverageLogPi |           -3.67 |
# |          StdLogPi |           0.954 |
# |          MaxLogPi |            6.59 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -55.1 |
# |             LossQ |           0.298 |
# |              Time |        4.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -181 |
# |          StdEpRet |            40.4 |
# |          MaxEpRet |            -115 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |           -18.7 |
# |      StdTestEpRet |            1.24 |
# |      MaxTestEpRet |           -16.8 |
# |      MinTestEpRet |           -20.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            54.4 |
# |         StdQ1Vals |            6.82 |
# |         MaxQ1Vals |            66.9 |
# |         MinQ1Vals |            45.4 |
# |     AverageQ2Vals |            54.4 |
# |         StdQ2Vals |            6.82 |
# |         MaxQ2Vals |            66.8 |
# |         MinQ2Vals |            45.3 |
# |      AverageLogPi |           -3.67 |
# |          StdLogPi |           0.959 |
# |          MaxLogPi |            5.13 |
# |          MinLogPi |             -11 |
# |            LossPi |           -55.1 |
# |             LossQ |           0.296 |
# |              Time |        4.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -165 |
# |          StdEpRet |            59.8 |
# |          MaxEpRet |           -63.4 |
# |          MinEpRet |            -213 |
# |  AverageTestEpRet |           -13.1 |
# |      StdTestEpRet |            0.74 |
# |      MaxTestEpRet |           -12.1 |
# |      MinTestEpRet |           -14.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            54.5 |
# |         StdQ1Vals |            6.91 |
# |         MaxQ1Vals |            67.2 |
# |         MinQ1Vals |            45.3 |
# |     AverageQ2Vals |            54.5 |
# |         StdQ2Vals |            6.91 |
# |         MaxQ2Vals |            67.4 |
# |         MinQ2Vals |            45.2 |
# |      AverageLogPi |           -3.67 |
# |          StdLogPi |           0.956 |
# |          MaxLogPi |            7.84 |
# |          MinLogPi |           -11.9 |
# |            LossPi |           -55.2 |
# |             LossQ |           0.292 |
# |              Time |        4.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -150 |
# |          StdEpRet |              82 |
# |          MaxEpRet |           -45.8 |
# |          MinEpRet |            -232 |
# |  AverageTestEpRet |           -16.8 |
# |      StdTestEpRet |           0.721 |
# |      MaxTestEpRet |           -15.6 |
# |      MinTestEpRet |           -17.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            54.5 |
# |         StdQ1Vals |            6.98 |
# |         MaxQ1Vals |            67.3 |
# |         MinQ1Vals |            45.4 |
# |     AverageQ2Vals |            54.5 |
# |         StdQ2Vals |            6.98 |
# |         MaxQ2Vals |            67.3 |
# |         MinQ2Vals |            45.4 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |           0.924 |
# |          MaxLogPi |            7.26 |
# |          MinLogPi |           -12.7 |
# |            LossPi |           -55.3 |
# |             LossQ |           0.289 |
# |              Time |        4.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -139 |
# |          StdEpRet |            58.5 |
# |          MaxEpRet |           -69.5 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |           -21.3 |
# |      StdTestEpRet |            1.03 |
# |      MaxTestEpRet |           -19.9 |
# |      MinTestEpRet |           -22.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            54.7 |
# |         StdQ1Vals |            7.09 |
# |         MaxQ1Vals |            67.5 |
# |         MinQ1Vals |            45.5 |
# |     AverageQ2Vals |            54.7 |
# |         StdQ2Vals |            7.09 |
# |         MaxQ2Vals |            67.3 |
# |         MinQ2Vals |            45.6 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |           0.921 |
# |          MaxLogPi |            7.71 |
# |          MinLogPi |           -12.7 |
# |            LossPi |           -55.5 |
# |             LossQ |           0.293 |
# |              Time |        4.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            23.3 |
# |          MaxEpRet |            -173 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |           -13.4 |
# |      StdTestEpRet |            1.05 |
# |      MaxTestEpRet |             -12 |
# |      MinTestEpRet |           -15.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            54.8 |
# |         StdQ1Vals |            7.13 |
# |         MaxQ1Vals |            67.6 |
# |         MinQ1Vals |            45.5 |
# |     AverageQ2Vals |            54.8 |
# |         StdQ2Vals |            7.13 |
# |         MaxQ2Vals |            67.5 |
# |         MinQ2Vals |            45.6 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |           0.915 |
# |          MaxLogPi |               9 |
# |          MinLogPi |           -13.7 |
# |            LossPi |           -55.5 |
# |             LossQ |           0.293 |
# |              Time |         5.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -173 |
# |          StdEpRet |            56.7 |
# |          MaxEpRet |           -75.1 |
# |          MinEpRet |            -210 |
# |  AverageTestEpRet |             -19 |
# |      StdTestEpRet |            1.28 |
# |      MaxTestEpRet |           -17.1 |
# |      MinTestEpRet |           -20.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            54.8 |
# |         StdQ1Vals |            7.19 |
# |         MaxQ1Vals |            68.1 |
# |         MinQ1Vals |            45.6 |
# |     AverageQ2Vals |            54.8 |
# |         StdQ2Vals |            7.19 |
# |         MaxQ2Vals |            68.1 |
# |         MinQ2Vals |            45.6 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |           0.929 |
# |          MaxLogPi |            5.99 |
# |          MinLogPi |           -11.4 |
# |            LossPi |           -55.5 |
# |             LossQ |            0.29 |
# |              Time |        5.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -175 |
# |          StdEpRet |            42.4 |
# |          MaxEpRet |            -112 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |           -14.5 |
# |      StdTestEpRet |           0.955 |
# |      MaxTestEpRet |           -12.6 |
# |      MinTestEpRet |           -15.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            54.8 |
# |         StdQ1Vals |            7.24 |
# |         MaxQ1Vals |            68.2 |
# |         MinQ1Vals |            45.5 |
# |     AverageQ2Vals |            54.8 |
# |         StdQ2Vals |            7.24 |
# |         MaxQ2Vals |            68.2 |
# |         MinQ2Vals |            45.7 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |           0.906 |
# |          MaxLogPi |            6.34 |
# |          MinLogPi |             -12 |
# |            LossPi |           -55.5 |
# |             LossQ |           0.292 |
# |              Time |        5.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -156 |
# |          StdEpRet |            69.3 |
# |          MaxEpRet |           -44.2 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |           -24.9 |
# |      StdTestEpRet |            1.32 |
# |      MaxTestEpRet |           -22.8 |
# |      MinTestEpRet |           -26.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            54.8 |
# |         StdQ1Vals |            7.25 |
# |         MaxQ1Vals |            68.1 |
# |         MinQ1Vals |            45.2 |
# |     AverageQ2Vals |            54.8 |
# |         StdQ2Vals |            7.25 |
# |         MaxQ2Vals |            68.3 |
# |         MinQ2Vals |            45.4 |
# |      AverageLogPi |           -3.68 |
# |          StdLogPi |           0.947 |
# |          MaxLogPi |             5.8 |
# |          MinLogPi |           -11.6 |
# |            LossPi |           -55.5 |
# |             LossQ |           0.296 |
# |              Time |        5.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -164 |
# |          StdEpRet |            48.5 |
# |          MaxEpRet |            -111 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |           -22.9 |
# |      StdTestEpRet |            1.19 |
# |      MaxTestEpRet |             -21 |
# |      MinTestEpRet |           -24.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |            54.8 |
# |         StdQ1Vals |            7.29 |
# |         MaxQ1Vals |            68.2 |
# |         MinQ1Vals |            45.4 |
# |     AverageQ2Vals |            54.8 |
# |         StdQ2Vals |            7.29 |
# |         MaxQ2Vals |              68 |
# |         MinQ2Vals |            45.4 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |           0.923 |
# |          MaxLogPi |            9.65 |
# |          MinLogPi |           -13.4 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.292 |
# |              Time |        5.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -165 |
# |          StdEpRet |            54.4 |
# |          MaxEpRet |            -124 |
# |          MinEpRet |            -257 |
# |  AverageTestEpRet |           -20.1 |
# |      StdTestEpRet |           0.792 |
# |      MaxTestEpRet |           -18.8 |
# |      MinTestEpRet |           -21.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            54.8 |
# |         StdQ1Vals |            7.31 |
# |         MaxQ1Vals |            68.1 |
# |         MinQ1Vals |            45.3 |
# |     AverageQ2Vals |            54.8 |
# |         StdQ2Vals |            7.31 |
# |         MaxQ2Vals |            68.1 |
# |         MinQ2Vals |            45.4 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |           0.929 |
# |          MaxLogPi |            5.55 |
# |          MinLogPi |             -12 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.297 |
# |              Time |        5.99e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -169 |
# |          StdEpRet |            42.4 |
# |          MaxEpRet |           -96.3 |
# |          MinEpRet |            -199 |
# |  AverageTestEpRet |           -20.5 |
# |      StdTestEpRet |            0.84 |
# |      MaxTestEpRet |           -19.2 |
# |      MinTestEpRet |           -22.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.32 |
# |         MaxQ1Vals |            68.2 |
# |         MinQ1Vals |            45.6 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.32 |
# |         MaxQ2Vals |            68.4 |
# |         MinQ2Vals |            45.5 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |           0.925 |
# |          MaxLogPi |            7.38 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.296 |
# |              Time |        6.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -167 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |            -141 |
# |          MinEpRet |            -212 |
# |  AverageTestEpRet |           -15.6 |
# |      StdTestEpRet |           0.946 |
# |      MaxTestEpRet |           -14.2 |
# |      MinTestEpRet |           -17.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.32 |
# |         MaxQ1Vals |            68.1 |
# |         MinQ1Vals |            45.6 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.32 |
# |         MaxQ2Vals |            68.2 |
# |         MinQ2Vals |            45.8 |
# |      AverageLogPi |            -3.7 |
# |          StdLogPi |           0.906 |
# |          MaxLogPi |            7.33 |
# |          MinLogPi |           -11.4 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.301 |
# |              Time |        6.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -140 |
# |          StdEpRet |            47.3 |
# |          MaxEpRet |           -84.4 |
# |          MinEpRet |            -202 |
# |  AverageTestEpRet |           -17.2 |
# |      StdTestEpRet |           0.883 |
# |      MaxTestEpRet |           -15.8 |
# |      MinTestEpRet |           -18.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.33 |
# |         MaxQ1Vals |            68.2 |
# |         MinQ1Vals |            45.6 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.33 |
# |         MaxQ2Vals |            68.3 |
# |         MinQ2Vals |            45.9 |
# |      AverageLogPi |            -3.7 |
# |          StdLogPi |            0.91 |
# |          MaxLogPi |            6.87 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.299 |
# |              Time |        6.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -134 |
# |          StdEpRet |              44 |
# |          MaxEpRet |           -80.1 |
# |          MinEpRet |            -202 |
# |  AverageTestEpRet |           -15.1 |
# |      StdTestEpRet |           0.971 |
# |      MaxTestEpRet |             -14 |
# |      MinTestEpRet |           -17.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |              55 |
# |         StdQ1Vals |            7.35 |
# |         MaxQ1Vals |            68.3 |
# |         MinQ1Vals |            45.5 |
# |     AverageQ2Vals |              55 |
# |         StdQ2Vals |            7.35 |
# |         MaxQ2Vals |            68.5 |
# |         MinQ2Vals |            45.7 |
# |      AverageLogPi |            -3.7 |
# |          StdLogPi |           0.905 |
# |          MaxLogPi |            7.23 |
# |          MinLogPi |           -11.4 |
# |            LossPi |           -55.7 |
# |             LossQ |           0.302 |
# |              Time |         6.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            37.4 |
# |          MaxEpRet |            -150 |
# |          MinEpRet |            -255 |
# |  AverageTestEpRet |             -18 |
# |      StdTestEpRet |            1.31 |
# |      MaxTestEpRet |           -15.8 |
# |      MinTestEpRet |           -21.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |              55 |
# |         StdQ1Vals |            7.37 |
# |         MaxQ1Vals |            68.2 |
# |         MinQ1Vals |            45.6 |
# |     AverageQ2Vals |              55 |
# |         StdQ2Vals |            7.37 |
# |         MaxQ2Vals |            68.3 |
# |         MinQ2Vals |            45.6 |
# |      AverageLogPi |            -3.7 |
# |          StdLogPi |           0.911 |
# |          MaxLogPi |            5.89 |
# |          MinLogPi |           -11.2 |
# |            LossPi |           -55.8 |
# |             LossQ |           0.305 |
# |              Time |        6.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -145 |
# |          StdEpRet |            37.2 |
# |          MaxEpRet |            -100 |
# |          MinEpRet |            -200 |
# |  AverageTestEpRet |           -7.59 |
# |      StdTestEpRet |           0.862 |
# |      MaxTestEpRet |            -6.1 |
# |      MinTestEpRet |           -8.97 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |              55 |
# |         StdQ1Vals |            7.37 |
# |         MaxQ1Vals |            68.2 |
# |         MinQ1Vals |            45.6 |
# |     AverageQ2Vals |              55 |
# |         StdQ2Vals |            7.37 |
# |         MaxQ2Vals |            68.2 |
# |         MinQ2Vals |            45.6 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.899 |
# |          MaxLogPi |            5.82 |
# |          MinLogPi |           -11.4 |
# |            LossPi |           -55.7 |
# |             LossQ |           0.299 |
# |              Time |        7.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -192 |
# |          StdEpRet |            31.7 |
# |          MaxEpRet |            -143 |
# |          MinEpRet |            -229 |
# |  AverageTestEpRet |           -18.3 |
# |      StdTestEpRet |           0.545 |
# |      MaxTestEpRet |           -17.3 |
# |      MinTestEpRet |           -19.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |              55 |
# |         StdQ1Vals |            7.37 |
# |         MaxQ1Vals |            68.4 |
# |         MinQ1Vals |            45.8 |
# |     AverageQ2Vals |              55 |
# |         StdQ2Vals |            7.37 |
# |         MaxQ2Vals |            68.5 |
# |         MinQ2Vals |            45.8 |
# |      AverageLogPi |            -3.7 |
# |          StdLogPi |           0.902 |
# |          MaxLogPi |            6.26 |
# |          MinLogPi |           -11.1 |
# |            LossPi |           -55.7 |
# |             LossQ |           0.296 |
# |              Time |         7.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -218 |
# |          StdEpRet |            25.7 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |            -246 |
# |  AverageTestEpRet |           -11.6 |
# |      StdTestEpRet |            15.5 |
# |      MaxTestEpRet |            4.94 |
# |      MinTestEpRet |           -28.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.35 |
# |         MaxQ1Vals |            68.6 |
# |         MinQ1Vals |            45.8 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.35 |
# |         MaxQ2Vals |            68.5 |
# |         MinQ2Vals |            45.8 |
# |      AverageLogPi |            -3.7 |
# |          StdLogPi |           0.901 |
# |          MaxLogPi |            7.07 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -55.7 |
# |             LossQ |           0.296 |
# |              Time |        7.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -175 |
# |          StdEpRet |            89.5 |
# |          MaxEpRet |           -22.8 |
# |          MinEpRet |            -249 |
# |  AverageTestEpRet |           -15.9 |
# |      StdTestEpRet |           0.403 |
# |      MaxTestEpRet |           -15.1 |
# |      MinTestEpRet |           -16.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.34 |
# |         MaxQ1Vals |            68.6 |
# |         MinQ1Vals |            45.7 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.34 |
# |         MaxQ2Vals |            68.4 |
# |         MinQ2Vals |            45.8 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.888 |
# |          MaxLogPi |             6.4 |
# |          MinLogPi |           -11.5 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.294 |
# |              Time |        7.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -211 |
# |          StdEpRet |            63.3 |
# |          MaxEpRet |            -103 |
# |          MinEpRet |            -264 |
# |  AverageTestEpRet |             -24 |
# |      StdTestEpRet |            1.17 |
# |      MaxTestEpRet |           -22.3 |
# |      MinTestEpRet |           -26.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.36 |
# |         MaxQ1Vals |            68.7 |
# |         MinQ1Vals |            45.9 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.36 |
# |         MaxQ2Vals |            68.7 |
# |         MinQ2Vals |            45.9 |
# |      AverageLogPi |           -3.72 |
# |          StdLogPi |           0.876 |
# |          MaxLogPi |            5.03 |
# |          MinLogPi |           -13.1 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.293 |
# |              Time |        7.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -156 |
# |          StdEpRet |            79.7 |
# |          MaxEpRet |           -18.4 |
# |          MinEpRet |            -210 |
# |  AverageTestEpRet |           -13.2 |
# |      StdTestEpRet |           0.958 |
# |      MaxTestEpRet |           -11.3 |
# |      MinTestEpRet |           -14.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |             7.4 |
# |         MaxQ1Vals |            68.7 |
# |         MinQ1Vals |            45.8 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |             7.4 |
# |         MaxQ2Vals |            68.7 |
# |         MinQ2Vals |            45.9 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.882 |
# |          MaxLogPi |            4.31 |
# |          MinLogPi |           -11.8 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.293 |
# |              Time |        7.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            48.8 |
# |          MaxEpRet |            -136 |
# |          MinEpRet |            -255 |
# |  AverageTestEpRet |           -21.5 |
# |      StdTestEpRet |            1.14 |
# |      MaxTestEpRet |           -18.9 |
# |      MinTestEpRet |           -23.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |            54.8 |
# |         StdQ1Vals |            7.42 |
# |         MaxQ1Vals |            69.1 |
# |         MinQ1Vals |            45.7 |
# |     AverageQ2Vals |            54.8 |
# |         StdQ2Vals |            7.42 |
# |         MaxQ2Vals |            68.9 |
# |         MinQ2Vals |            45.9 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.896 |
# |          MaxLogPi |            5.44 |
# |          MinLogPi |           -13.8 |
# |            LossPi |           -55.6 |
# |             LossQ |            0.29 |
# |              Time |        8.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -137 |
# |          StdEpRet |            77.6 |
# |          MaxEpRet |           -35.1 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |           -21.3 |
# |      StdTestEpRet |            1.16 |
# |      MaxTestEpRet |           -19.7 |
# |      MinTestEpRet |           -23.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.45 |
# |         MaxQ1Vals |              69 |
# |         MinQ1Vals |            45.8 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.45 |
# |         MaxQ2Vals |            68.7 |
# |         MinQ2Vals |            45.9 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.893 |
# |          MaxLogPi |            8.56 |
# |          MinLogPi |           -13.2 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.285 |
# |              Time |        8.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -163 |
# |          StdEpRet |            44.8 |
# |          MaxEpRet |            -100 |
# |          MinEpRet |            -210 |
# |  AverageTestEpRet |           -14.3 |
# |      StdTestEpRet |            0.82 |
# |      MaxTestEpRet |           -13.1 |
# |      MinTestEpRet |           -15.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.45 |
# |         MaxQ1Vals |            69.5 |
# |         MinQ1Vals |            46.1 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.45 |
# |         MaxQ2Vals |            69.1 |
# |         MinQ2Vals |            45.9 |
# |      AverageLogPi |           -3.72 |
# |          StdLogPi |           0.886 |
# |          MaxLogPi |            6.77 |
# |          MinLogPi |             -12 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.286 |
# |              Time |        8.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -121 |
# |          StdEpRet |            82.6 |
# |          MaxEpRet |           -22.4 |
# |          MinEpRet |            -208 |
# |  AverageTestEpRet |           -12.6 |
# |      StdTestEpRet |           0.602 |
# |      MaxTestEpRet |           -11.2 |
# |      MinTestEpRet |           -13.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |            54.9 |
# |         StdQ1Vals |            7.49 |
# |         MaxQ1Vals |              69 |
# |         MinQ1Vals |            45.9 |
# |     AverageQ2Vals |            54.9 |
# |         StdQ2Vals |            7.49 |
# |         MaxQ2Vals |            68.8 |
# |         MinQ2Vals |            45.9 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.885 |
# |          MaxLogPi |            8.26 |
# |          MinLogPi |           -13.1 |
# |            LossPi |           -55.6 |
# |             LossQ |           0.285 |
# |              Time |        8.52e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 128, 'l': 2, 
        'gamma': 0.99, 'seed':5, 'epochs':50, 
        'partially_observable': True,
        'exp_name': 'sac_POMDP_HalfCheetah_2L128'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

torch.set_num_threads(torch.get_num_threads())

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
    gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    partially_observable=args['partially_observable'],
    logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_POMDP_HalfCheetah_2L128\sac_POMDP_HalfCheetah_2L128_s5\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             128,
#             128
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"sac_POMDP_HalfCheetah_2L128",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001D4DE361F08>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_POMDP_HalfCheetah_2L128",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_HalfCheetah_2L128\\sac_POMDP_HalfCheetah_2L128_s5",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\sac_POMDP_HalfCheetah_2L128\\\\sac_POMDP_HalfCheetah_2L128_s5\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_POMDP_HalfCheetah_2L128",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_HalfCheetah_2L128\\sac_POMDP_HalfCheetah_2L128_s5"
#     },
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	5,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 19212, 	 q1: 18561, 	 q2: 18561
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -278 |
# |          StdEpRet |            43.9 |
# |          MaxEpRet |            -219 |
# |          MinEpRet |            -342 |
# |  AverageTestEpRet |           -53.6 |
# |      StdTestEpRet |           0.743 |
# |      MaxTestEpRet |           -52.3 |
# |      MinTestEpRet |           -54.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |             4.5 |
# |         StdQ1Vals |            2.35 |
# |         MaxQ1Vals |            14.3 |
# |         MinQ1Vals |          -0.688 |
# |     AverageQ2Vals |             4.5 |
# |         StdQ2Vals |            2.35 |
# |         MaxQ2Vals |            14.3 |
# |         MinQ2Vals |          -0.505 |
# |      AverageLogPi |           -3.59 |
# |          StdLogPi |           0.975 |
# |          MaxLogPi |            1.86 |
# |          MinLogPi |           -11.5 |
# |            LossPi |           -5.35 |
# |             LossQ |           0.306 |
# |              Time |            87.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -192 |
# |          StdEpRet |            45.2 |
# |          MaxEpRet |            -120 |
# |          MinEpRet |            -245 |
# |  AverageTestEpRet |             -68 |
# |      StdTestEpRet |            3.33 |
# |      MaxTestEpRet |           -62.9 |
# |      MinTestEpRet |           -72.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            12.6 |
# |         StdQ1Vals |             3.3 |
# |         MaxQ1Vals |            32.3 |
# |         MinQ1Vals |            5.47 |
# |     AverageQ2Vals |            12.6 |
# |         StdQ2Vals |             3.3 |
# |         MaxQ2Vals |            32.2 |
# |         MinQ2Vals |            5.58 |
# |      AverageLogPi |           -3.44 |
# |          StdLogPi |            1.12 |
# |          MaxLogPi |            7.39 |
# |          MinLogPi |           -12.3 |
# |            LossPi |           -13.4 |
# |             LossQ |           0.485 |
# |              Time |             203 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -268 |
# |          StdEpRet |             113 |
# |          MaxEpRet |            -112 |
# |          MinEpRet |            -404 |
# |  AverageTestEpRet |            20.2 |
# |      StdTestEpRet |           0.889 |
# |      MaxTestEpRet |            21.2 |
# |      MinTestEpRet |            18.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            21.3 |
# |         StdQ1Vals |            4.32 |
# |         MaxQ1Vals |              43 |
# |         MinQ1Vals |            12.9 |
# |     AverageQ2Vals |            21.3 |
# |         StdQ2Vals |            4.32 |
# |         MaxQ2Vals |            42.2 |
# |         MinQ2Vals |            13.2 |
# |      AverageLogPi |           -2.95 |
# |          StdLogPi |            1.49 |
# |          MaxLogPi |            7.26 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -22.2 |
# |             LossQ |           0.727 |
# |              Time |             319 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -162 |
# |          StdEpRet |            90.1 |
# |          MaxEpRet |           -5.93 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |           -8.75 |
# |      StdTestEpRet |            1.08 |
# |      MaxTestEpRet |           -7.28 |
# |      MinTestEpRet |           -11.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            28.9 |
# |         StdQ1Vals |            4.59 |
# |         MaxQ1Vals |            43.3 |
# |         MinQ1Vals |            19.1 |
# |     AverageQ2Vals |            28.9 |
# |         StdQ2Vals |            4.59 |
# |         MaxQ2Vals |            42.5 |
# |         MinQ2Vals |            18.9 |
# |      AverageLogPi |           -3.15 |
# |          StdLogPi |            1.37 |
# |          MaxLogPi |            7.99 |
# |          MinLogPi |           -14.5 |
# |            LossPi |           -29.7 |
# |             LossQ |           0.638 |
# |              Time |             440 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            24.2 |
# |          MaxEpRet |            -151 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            5.75 |
# |      StdTestEpRet |            1.19 |
# |      MaxTestEpRet |            7.51 |
# |      MinTestEpRet |            3.09 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            33.9 |
# |         StdQ1Vals |            4.77 |
# |         MaxQ1Vals |            44.2 |
# |         MinQ1Vals |            23.7 |
# |     AverageQ2Vals |            33.9 |
# |         StdQ2Vals |            4.77 |
# |         MaxQ2Vals |            44.1 |
# |         MinQ2Vals |            23.5 |
# |      AverageLogPi |           -3.43 |
# |          StdLogPi |            1.15 |
# |          MaxLogPi |            5.54 |
# |          MinLogPi |           -13.2 |
# |            LossPi |           -34.7 |
# |             LossQ |           0.489 |
# |              Time |             557 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -129 |
# |          StdEpRet |            54.3 |
# |          MaxEpRet |           -50.6 |
# |          MinEpRet |            -189 |
# |  AverageTestEpRet |            4.54 |
# |      StdTestEpRet |            1.44 |
# |      MaxTestEpRet |            6.84 |
# |      MinTestEpRet |            1.71 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            37.4 |
# |         StdQ1Vals |            4.98 |
# |         MaxQ1Vals |            48.2 |
# |         MinQ1Vals |            27.5 |
# |     AverageQ2Vals |            37.4 |
# |         StdQ2Vals |            4.98 |
# |         MaxQ2Vals |              48 |
# |         MinQ2Vals |            27.6 |
# |      AverageLogPi |           -3.52 |
# |          StdLogPi |            1.06 |
# |          MaxLogPi |            5.31 |
# |          MinLogPi |           -12.6 |
# |            LossPi |           -38.1 |
# |             LossQ |           0.417 |
# |              Time |             673 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -157 |
# |          StdEpRet |            64.3 |
# |          MaxEpRet |           -51.2 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |           -1.73 |
# |      StdTestEpRet |            1.09 |
# |      MaxTestEpRet |           0.376 |
# |      MinTestEpRet |           -3.54 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            40.6 |
# |         StdQ1Vals |            5.26 |
# |         MaxQ1Vals |              52 |
# |         MinQ1Vals |            30.9 |
# |     AverageQ2Vals |            40.6 |
# |         StdQ2Vals |            5.26 |
# |         MaxQ2Vals |            52.2 |
# |         MinQ2Vals |              31 |
# |      AverageLogPi |           -3.52 |
# |          StdLogPi |            1.09 |
# |          MaxLogPi |            4.73 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -41.3 |
# |             LossQ |           0.395 |
# |              Time |             789 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -194 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |            -171 |
# |          MinEpRet |            -237 |
# |  AverageTestEpRet |           -8.56 |
# |      StdTestEpRet |            1.07 |
# |      MaxTestEpRet |           -6.85 |
# |      MinTestEpRet |           -10.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            43.4 |
# |         StdQ1Vals |            5.67 |
# |         MaxQ1Vals |            54.8 |
# |         MinQ1Vals |            33.9 |
# |     AverageQ2Vals |            43.4 |
# |         StdQ2Vals |            5.67 |
# |         MaxQ2Vals |            54.6 |
# |         MinQ2Vals |            33.8 |
# |      AverageLogPi |           -3.56 |
# |          StdLogPi |            1.04 |
# |          MaxLogPi |            3.96 |
# |          MinLogPi |           -13.1 |
# |            LossPi |           -44.2 |
# |             LossQ |           0.372 |
# |              Time |             905 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -136 |
# |          StdEpRet |            71.1 |
# |          MaxEpRet |           -14.4 |
# |          MinEpRet |            -194 |
# |  AverageTestEpRet |           -7.98 |
# |      StdTestEpRet |           0.945 |
# |      MaxTestEpRet |            -6.4 |
# |      MinTestEpRet |           -9.97 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            45.5 |
# |         StdQ1Vals |            6.03 |
# |         MaxQ1Vals |            57.6 |
# |         MinQ1Vals |              36 |
# |     AverageQ2Vals |            45.5 |
# |         StdQ2Vals |            6.03 |
# |         MaxQ2Vals |            57.4 |
# |         MinQ2Vals |            36.1 |
# |      AverageLogPi |           -3.57 |
# |          StdLogPi |            1.04 |
# |          MaxLogPi |            3.45 |
# |          MinLogPi |             -12 |
# |            LossPi |           -46.3 |
# |             LossQ |           0.351 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -144 |
# |          StdEpRet |            22.5 |
# |          MaxEpRet |            -123 |
# |          MinEpRet |            -179 |
# |  AverageTestEpRet |           -9.84 |
# |      StdTestEpRet |             1.3 |
# |      MaxTestEpRet |           -7.77 |
# |      MinTestEpRet |           -12.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            47.4 |
# |         StdQ1Vals |            6.38 |
# |         MaxQ1Vals |            60.3 |
# |         MinQ1Vals |            37.8 |
# |     AverageQ2Vals |            47.4 |
# |         StdQ2Vals |            6.38 |
# |         MaxQ2Vals |            60.3 |
# |         MinQ2Vals |            37.8 |
# |      AverageLogPi |            -3.6 |
# |          StdLogPi |            1.01 |
# |          MaxLogPi |            3.99 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -48.2 |
# |             LossQ |           0.337 |
# |              Time |        1.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -139 |
# |          StdEpRet |              95 |
# |          MaxEpRet |           -6.39 |
# |          MinEpRet |            -232 |
# |  AverageTestEpRet |           -2.34 |
# |      StdTestEpRet |            1.33 |
# |      MaxTestEpRet |            0.34 |
# |      MinTestEpRet |           -4.14 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            49.2 |
# |         StdQ1Vals |            6.72 |
# |         MaxQ1Vals |              62 |
# |         MinQ1Vals |            39.6 |
# |     AverageQ2Vals |            49.2 |
# |         StdQ2Vals |            6.72 |
# |         MaxQ2Vals |            62.3 |
# |         MinQ2Vals |            39.5 |
# |      AverageLogPi |           -3.61 |
# |          StdLogPi |               1 |
# |          MaxLogPi |            4.29 |
# |          MinLogPi |           -11.2 |
# |            LossPi |           -49.9 |
# |             LossQ |           0.331 |
# |              Time |        1.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -214 |
# |          StdEpRet |            19.4 |
# |          MaxEpRet |            -189 |
# |          MinEpRet |            -234 |
# |  AverageTestEpRet |           -14.2 |
# |      StdTestEpRet |            1.44 |
# |      MaxTestEpRet |           -11.3 |
# |      MinTestEpRet |           -16.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            50.4 |
# |         StdQ1Vals |             6.9 |
# |         MaxQ1Vals |            63.7 |
# |         MinQ1Vals |              41 |
# |     AverageQ2Vals |            50.4 |
# |         StdQ2Vals |             6.9 |
# |         MaxQ2Vals |            63.7 |
# |         MinQ2Vals |            40.9 |
# |      AverageLogPi |           -3.63 |
# |          StdLogPi |           0.977 |
# |          MaxLogPi |            3.44 |
# |          MinLogPi |           -12.3 |
# |            LossPi |           -51.1 |
# |             LossQ |           0.322 |
# |              Time |        1.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -146 |
# |          StdEpRet |            79.5 |
# |          MaxEpRet |           -12.2 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -7.4 |
# |      StdTestEpRet |             1.2 |
# |      MaxTestEpRet |           -5.13 |
# |      MinTestEpRet |           -9.11 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            51.3 |
# |         StdQ1Vals |            7.14 |
# |         MaxQ1Vals |            65.2 |
# |         MinQ1Vals |            41.9 |
# |     AverageQ2Vals |            51.3 |
# |         StdQ2Vals |            7.14 |
# |         MaxQ2Vals |            64.9 |
# |         MinQ2Vals |              42 |
# |      AverageLogPi |           -3.65 |
# |          StdLogPi |           0.957 |
# |          MaxLogPi |            3.48 |
# |          MinLogPi |           -11.9 |
# |            LossPi |           -52.1 |
# |             LossQ |           0.315 |
# |              Time |        1.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -114 |
# |          StdEpRet |            48.3 |
# |          MaxEpRet |           -75.8 |
# |          MinEpRet |            -196 |
# |  AverageTestEpRet |           -5.69 |
# |      StdTestEpRet |           0.965 |
# |      MaxTestEpRet |           -4.22 |
# |      MinTestEpRet |            -7.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            52.5 |
# |         StdQ1Vals |            7.39 |
# |         MaxQ1Vals |            66.1 |
# |         MinQ1Vals |              43 |
# |     AverageQ2Vals |            52.5 |
# |         StdQ2Vals |            7.39 |
# |         MaxQ2Vals |              66 |
# |         MinQ2Vals |            42.8 |
# |      AverageLogPi |           -3.67 |
# |          StdLogPi |           0.922 |
# |          MaxLogPi |            8.26 |
# |          MinLogPi |           -13.8 |
# |            LossPi |           -53.2 |
# |             LossQ |           0.318 |
# |              Time |         1.6e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -162 |
# |          StdEpRet |            67.6 |
# |          MaxEpRet |           -91.6 |
# |          MinEpRet |            -273 |
# |  AverageTestEpRet |           -6.85 |
# |      StdTestEpRet |            0.92 |
# |      MaxTestEpRet |           -5.41 |
# |      MinTestEpRet |           -8.17 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            53.3 |
# |         StdQ1Vals |            7.52 |
# |         MaxQ1Vals |              67 |
# |         MinQ1Vals |            43.7 |
# |     AverageQ2Vals |            53.3 |
# |         StdQ2Vals |            7.52 |
# |         MaxQ2Vals |            66.9 |
# |         MinQ2Vals |            43.5 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |            0.91 |
# |          MaxLogPi |            3.63 |
# |          MinLogPi |           -12.1 |
# |            LossPi |             -54 |
# |             LossQ |           0.313 |
# |              Time |        1.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -141 |
# |          StdEpRet |            71.9 |
# |          MaxEpRet |           -63.6 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |           -2.74 |
# |      StdTestEpRet |            1.16 |
# |      MaxTestEpRet |           -0.56 |
# |      MinTestEpRet |           -4.67 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            53.9 |
# |         StdQ1Vals |            7.67 |
# |         MaxQ1Vals |            67.5 |
# |         MinQ1Vals |            44.2 |
# |     AverageQ2Vals |            53.9 |
# |         StdQ2Vals |            7.67 |
# |         MaxQ2Vals |            67.6 |
# |         MinQ2Vals |            44.1 |
# |      AverageLogPi |           -3.69 |
# |          StdLogPi |            0.91 |
# |          MaxLogPi |            3.34 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -54.7 |
# |             LossQ |           0.311 |
# |              Time |        1.83e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           -94.4 |
# |          StdEpRet |            72.3 |
# |          MaxEpRet |           -16.7 |
# |          MinEpRet |            -180 |
# |  AverageTestEpRet |           -6.61 |
# |      StdTestEpRet |           0.749 |
# |      MaxTestEpRet |           -5.45 |
# |      MinTestEpRet |           -7.51 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            54.7 |
# |         StdQ1Vals |             7.8 |
# |         MaxQ1Vals |            68.2 |
# |         MinQ1Vals |            44.7 |
# |     AverageQ2Vals |            54.7 |
# |         StdQ2Vals |             7.8 |
# |         MaxQ2Vals |              68 |
# |         MinQ2Vals |            44.7 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.871 |
# |          MaxLogPi |            4.99 |
# |          MinLogPi |           -10.8 |
# |            LossPi |           -55.4 |
# |             LossQ |           0.318 |
# |              Time |        1.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |           -95.4 |
# |          StdEpRet |            46.1 |
# |          MaxEpRet |           -27.7 |
# |          MinEpRet |            -153 |
# |  AverageTestEpRet |           -9.06 |
# |      StdTestEpRet |            1.64 |
# |      MaxTestEpRet |           -6.61 |
# |      MinTestEpRet |           -11.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            55.4 |
# |         StdQ1Vals |            7.93 |
# |         MaxQ1Vals |            68.7 |
# |         MinQ1Vals |            45.1 |
# |     AverageQ2Vals |            55.4 |
# |         StdQ2Vals |            7.93 |
# |         MaxQ2Vals |            68.7 |
# |         MinQ2Vals |            45.1 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.876 |
# |          MaxLogPi |            2.85 |
# |          MinLogPi |           -12.3 |
# |            LossPi |           -56.1 |
# |             LossQ |           0.322 |
# |              Time |        2.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -233 |
# |          StdEpRet |            16.9 |
# |          MaxEpRet |            -217 |
# |          MinEpRet |            -261 |
# |  AverageTestEpRet |           -13.2 |
# |      StdTestEpRet |            1.13 |
# |      MaxTestEpRet |           -11.6 |
# |      MinTestEpRet |             -15 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            55.7 |
# |         StdQ1Vals |               8 |
# |         MaxQ1Vals |            68.8 |
# |         MinQ1Vals |            45.5 |
# |     AverageQ2Vals |            55.7 |
# |         StdQ2Vals |               8 |
# |         MaxQ2Vals |            68.6 |
# |         MinQ2Vals |            45.4 |
# |      AverageLogPi |           -3.72 |
# |          StdLogPi |           0.867 |
# |          MaxLogPi |            3.15 |
# |          MinLogPi |           -12.3 |
# |            LossPi |           -56.4 |
# |             LossQ |           0.322 |
# |              Time |        2.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -169 |
# |          StdEpRet |            54.1 |
# |          MaxEpRet |             -79 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |           -9.11 |
# |      StdTestEpRet |           0.904 |
# |      MaxTestEpRet |           -7.09 |
# |      MinTestEpRet |           -10.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            55.8 |
# |         StdQ1Vals |            8.05 |
# |         MaxQ1Vals |            69.2 |
# |         MinQ1Vals |            45.7 |
# |     AverageQ2Vals |            55.8 |
# |         StdQ2Vals |            8.05 |
# |         MaxQ2Vals |            69.2 |
# |         MinQ2Vals |            45.6 |
# |      AverageLogPi |           -3.72 |
# |          StdLogPi |           0.867 |
# |          MaxLogPi |             5.9 |
# |          MinLogPi |           -11.6 |
# |            LossPi |           -56.5 |
# |             LossQ |            0.32 |
# |              Time |        2.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            79.6 |
# |          MaxEpRet |           -68.6 |
# |          MinEpRet |            -273 |
# |  AverageTestEpRet |           -18.7 |
# |      StdTestEpRet |           0.727 |
# |      MaxTestEpRet |           -17.5 |
# |      MinTestEpRet |           -20.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            55.9 |
# |         StdQ1Vals |             8.1 |
# |         MaxQ1Vals |            69.7 |
# |         MinQ1Vals |            45.7 |
# |     AverageQ2Vals |            55.9 |
# |         StdQ2Vals |             8.1 |
# |         MaxQ2Vals |            69.5 |
# |         MinQ2Vals |            45.5 |
# |      AverageLogPi |           -3.71 |
# |          StdLogPi |           0.866 |
# |          MaxLogPi |            3.97 |
# |          MinLogPi |           -11.4 |
# |            LossPi |           -56.6 |
# |             LossQ |           0.319 |
# |              Time |         2.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -174 |
# |          StdEpRet |            74.3 |
# |          MaxEpRet |           -45.6 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |           -6.93 |
# |      StdTestEpRet |           0.522 |
# |      MaxTestEpRet |           -6.16 |
# |      MinTestEpRet |           -8.05 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            55.9 |
# |         StdQ1Vals |            8.14 |
# |         MaxQ1Vals |            69.8 |
# |         MinQ1Vals |              46 |
# |     AverageQ2Vals |            55.9 |
# |         StdQ2Vals |            8.14 |
# |         MaxQ2Vals |            69.8 |
# |         MinQ2Vals |              46 |
# |      AverageLogPi |           -3.72 |
# |          StdLogPi |           0.852 |
# |          MaxLogPi |             3.8 |
# |          MinLogPi |           -12.4 |
# |            LossPi |           -56.6 |
# |             LossQ |           0.318 |
# |              Time |        2.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |            78.1 |
# |          MaxEpRet |            2.11 |
# |          MinEpRet |            -199 |
# |  AverageTestEpRet |           -11.1 |
# |      StdTestEpRet |            1.16 |
# |      MaxTestEpRet |           -9.08 |
# |      MinTestEpRet |           -12.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            55.9 |
# |         StdQ1Vals |             8.2 |
# |         MaxQ1Vals |              70 |
# |         MinQ1Vals |            46.1 |
# |     AverageQ2Vals |            55.9 |
# |         StdQ2Vals |             8.2 |
# |         MaxQ2Vals |            69.7 |
# |         MinQ2Vals |            46.1 |
# |      AverageLogPi |           -3.73 |
# |          StdLogPi |           0.851 |
# |          MaxLogPi |             5.4 |
# |          MinLogPi |           -11.5 |
# |            LossPi |           -56.7 |
# |             LossQ |           0.319 |
# |              Time |        2.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -158 |
# |          StdEpRet |            74.5 |
# |          MaxEpRet |           -60.6 |
# |          MinEpRet |            -245 |
# |  AverageTestEpRet |           -8.97 |
# |      StdTestEpRet |            1.13 |
# |      MaxTestEpRet |           -7.33 |
# |      MinTestEpRet |           -10.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            56.2 |
# |         StdQ1Vals |            8.33 |
# |         MaxQ1Vals |            70.5 |
# |         MinQ1Vals |            46.2 |
# |     AverageQ2Vals |            56.2 |
# |         StdQ2Vals |            8.33 |
# |         MaxQ2Vals |            69.9 |
# |         MinQ2Vals |            46.3 |
# |      AverageLogPi |           -3.72 |
# |          StdLogPi |           0.859 |
# |          MaxLogPi |             4.2 |
# |          MinLogPi |           -12.6 |
# |            LossPi |             -57 |
# |             LossQ |            0.32 |
# |              Time |        2.75e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -114 |
# |          StdEpRet |            51.4 |
# |          MaxEpRet |           -58.3 |
# |          MinEpRet |            -194 |
# |  AverageTestEpRet |           -10.3 |
# |      StdTestEpRet |            1.21 |
# |      MaxTestEpRet |           -7.73 |
# |      MinTestEpRet |           -12.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            56.4 |
# |         StdQ1Vals |            8.44 |
# |         MaxQ1Vals |            70.4 |
# |         MinQ1Vals |            46.3 |
# |     AverageQ2Vals |            56.4 |
# |         StdQ2Vals |            8.44 |
# |         MaxQ2Vals |            70.1 |
# |         MinQ2Vals |            46.2 |
# |      AverageLogPi |           -3.72 |
# |          StdLogPi |           0.856 |
# |          MaxLogPi |            5.93 |
# |          MinLogPi |           -11.9 |
# |            LossPi |           -57.1 |
# |             LossQ |            0.32 |
# |              Time |        2.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -143 |
# |          StdEpRet |            68.7 |
# |          MaxEpRet |           -56.9 |
# |          MinEpRet |            -229 |
# |  AverageTestEpRet |             -15 |
# |      StdTestEpRet |           0.534 |
# |      MaxTestEpRet |           -14.3 |
# |      MinTestEpRet |           -15.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            56.6 |
# |         StdQ1Vals |             8.5 |
# |         MaxQ1Vals |            70.5 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.6 |
# |         StdQ2Vals |             8.5 |
# |         MaxQ2Vals |            70.6 |
# |         MinQ2Vals |            46.4 |
# |      AverageLogPi |           -3.73 |
# |          StdLogPi |            0.84 |
# |          MaxLogPi |            3.79 |
# |          MinLogPi |           -12.8 |
# |            LossPi |           -57.3 |
# |             LossQ |            0.32 |
# |              Time |        2.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -222 |
# |          StdEpRet |            31.3 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -261 |
# |  AverageTestEpRet |           -9.15 |
# |      StdTestEpRet |           0.695 |
# |      MaxTestEpRet |           -7.73 |
# |      MinTestEpRet |           -10.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            56.6 |
# |         StdQ1Vals |            8.52 |
# |         MaxQ1Vals |            70.7 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.6 |
# |         StdQ2Vals |            8.52 |
# |         MaxQ2Vals |            70.5 |
# |         MinQ2Vals |            46.1 |
# |      AverageLogPi |           -3.74 |
# |          StdLogPi |           0.831 |
# |          MaxLogPi |            4.74 |
# |          MinLogPi |           -10.9 |
# |            LossPi |           -57.3 |
# |             LossQ |           0.318 |
# |              Time |         3.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -175 |
# |          StdEpRet |            45.1 |
# |          MaxEpRet |            -136 |
# |          MinEpRet |            -251 |
# |  AverageTestEpRet |           -10.2 |
# |      StdTestEpRet |            1.09 |
# |      MaxTestEpRet |           -7.86 |
# |      MinTestEpRet |           -11.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            56.5 |
# |         StdQ1Vals |            8.53 |
# |         MaxQ1Vals |            70.9 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |            56.5 |
# |         StdQ2Vals |            8.53 |
# |         MaxQ2Vals |            70.4 |
# |         MinQ2Vals |            46.4 |
# |      AverageLogPi |           -3.74 |
# |          StdLogPi |           0.842 |
# |          MaxLogPi |              12 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -57.3 |
# |             LossQ |           0.318 |
# |              Time |        3.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |            49.5 |
# |          MaxEpRet |             -70 |
# |          MinEpRet |            -202 |
# |  AverageTestEpRet |           -7.18 |
# |      StdTestEpRet |            0.91 |
# |      MaxTestEpRet |            -5.4 |
# |      MinTestEpRet |           -8.81 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            56.7 |
# |         StdQ1Vals |            8.59 |
# |         MaxQ1Vals |            71.3 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |            56.7 |
# |         StdQ2Vals |            8.59 |
# |         MaxQ2Vals |            70.6 |
# |         MinQ2Vals |            46.4 |
# |      AverageLogPi |           -3.74 |
# |          StdLogPi |            0.83 |
# |          MaxLogPi |            7.05 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -57.4 |
# |             LossQ |           0.322 |
# |              Time |        3.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            24.7 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -232 |
# |  AverageTestEpRet |            -6.1 |
# |      StdTestEpRet |           0.912 |
# |      MaxTestEpRet |           -4.14 |
# |      MinTestEpRet |           -7.33 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            56.6 |
# |         StdQ1Vals |             8.6 |
# |         MaxQ1Vals |            70.8 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.6 |
# |         StdQ2Vals |             8.6 |
# |         MaxQ2Vals |            70.7 |
# |         MinQ2Vals |            46.3 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.825 |
# |          MaxLogPi |            2.92 |
# |          MinLogPi |           -12.5 |
# |            LossPi |           -57.3 |
# |             LossQ |            0.32 |
# |              Time |        3.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -101 |
# |          StdEpRet |            43.9 |
# |          MaxEpRet |           -30.4 |
# |          MinEpRet |            -150 |
# |  AverageTestEpRet |           -6.79 |
# |      StdTestEpRet |           0.685 |
# |      MaxTestEpRet |           -5.68 |
# |      MinTestEpRet |           -7.86 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            56.6 |
# |         StdQ1Vals |            8.61 |
# |         MaxQ1Vals |              71 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |            56.6 |
# |         StdQ2Vals |            8.61 |
# |         MaxQ2Vals |            70.6 |
# |         MinQ2Vals |            46.5 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.831 |
# |          MaxLogPi |            3.78 |
# |          MinLogPi |           -16.4 |
# |            LossPi |           -57.4 |
# |             LossQ |           0.318 |
# |              Time |        3.57e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -150 |
# |          StdEpRet |            89.8 |
# |          MaxEpRet |            4.07 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |           -14.2 |
# |      StdTestEpRet |           0.861 |
# |      MaxTestEpRet |           -12.1 |
# |      MinTestEpRet |           -15.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            56.8 |
# |         StdQ1Vals |            8.64 |
# |         MaxQ1Vals |              71 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |            56.8 |
# |         StdQ2Vals |            8.64 |
# |         MaxQ2Vals |            70.5 |
# |         MinQ2Vals |            46.4 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.819 |
# |          MaxLogPi |            4.79 |
# |          MinLogPi |           -13.5 |
# |            LossPi |           -57.5 |
# |             LossQ |            0.32 |
# |              Time |         3.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -194 |
# |          StdEpRet |              44 |
# |          MaxEpRet |            -120 |
# |          MinEpRet |            -235 |
# |  AverageTestEpRet |           -12.4 |
# |      StdTestEpRet |            1.24 |
# |      MaxTestEpRet |           -9.89 |
# |      MinTestEpRet |             -14 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            56.6 |
# |         StdQ1Vals |            8.64 |
# |         MaxQ1Vals |            71.1 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.6 |
# |         StdQ2Vals |            8.64 |
# |         MaxQ2Vals |            70.8 |
# |         MinQ2Vals |            46.5 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.826 |
# |          MaxLogPi |            4.05 |
# |          MinLogPi |           -10.1 |
# |            LossPi |           -57.4 |
# |             LossQ |           0.318 |
# |              Time |        3.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -161 |
# |          StdEpRet |              57 |
# |          MaxEpRet |           -70.8 |
# |          MinEpRet |            -211 |
# |  AverageTestEpRet |           -7.08 |
# |      StdTestEpRet |               1 |
# |      MaxTestEpRet |           -5.29 |
# |      MinTestEpRet |           -8.69 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |            56.6 |
# |         StdQ1Vals |            8.66 |
# |         MaxQ1Vals |            71.1 |
# |         MinQ1Vals |            46.3 |
# |     AverageQ2Vals |            56.6 |
# |         StdQ2Vals |            8.67 |
# |         MaxQ2Vals |            70.9 |
# |         MinQ2Vals |            46.4 |
# |      AverageLogPi |           -3.74 |
# |          StdLogPi |           0.832 |
# |          MaxLogPi |            4.19 |
# |          MinLogPi |           -12.4 |
# |            LossPi |           -57.3 |
# |             LossQ |           0.321 |
# |              Time |        3.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |            73.7 |
# |          MaxEpRet |           -8.41 |
# |          MinEpRet |            -213 |
# |  AverageTestEpRet |           -8.08 |
# |      StdTestEpRet |           0.855 |
# |      MaxTestEpRet |           -5.82 |
# |      MinTestEpRet |           -8.88 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            56.6 |
# |         StdQ1Vals |            8.71 |
# |         MaxQ1Vals |            71.3 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.6 |
# |         StdQ2Vals |            8.71 |
# |         MaxQ2Vals |            70.8 |
# |         MinQ2Vals |            46.4 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.814 |
# |          MaxLogPi |            3.82 |
# |          MinLogPi |             -15 |
# |            LossPi |           -57.4 |
# |             LossQ |           0.322 |
# |              Time |        4.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -164 |
# |          StdEpRet |            96.7 |
# |          MaxEpRet |           -15.1 |
# |          MinEpRet |            -270 |
# |  AverageTestEpRet |           -10.5 |
# |      StdTestEpRet |           0.753 |
# |      MaxTestEpRet |           -9.42 |
# |      MinTestEpRet |             -12 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |            56.7 |
# |         StdQ1Vals |            8.75 |
# |         MaxQ1Vals |            71.2 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.7 |
# |         StdQ2Vals |            8.75 |
# |         MaxQ2Vals |              71 |
# |         MinQ2Vals |            46.4 |
# |      AverageLogPi |           -3.76 |
# |          StdLogPi |           0.817 |
# |          MaxLogPi |            3.35 |
# |          MinLogPi |           -11.5 |
# |            LossPi |           -57.4 |
# |             LossQ |           0.318 |
# |              Time |        4.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -147 |
# |          StdEpRet |            94.4 |
# |          MaxEpRet |            16.8 |
# |          MinEpRet |            -206 |
# |  AverageTestEpRet |           -15.3 |
# |      StdTestEpRet |           0.453 |
# |      MaxTestEpRet |           -14.7 |
# |      MinTestEpRet |           -16.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            56.6 |
# |         StdQ1Vals |            8.75 |
# |         MaxQ1Vals |            71.1 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.6 |
# |         StdQ2Vals |            8.75 |
# |         MaxQ2Vals |            70.9 |
# |         MinQ2Vals |            46.6 |
# |      AverageLogPi |           -3.76 |
# |          StdLogPi |           0.804 |
# |          MaxLogPi |            4.18 |
# |          MinLogPi |           -11.9 |
# |            LossPi |           -57.3 |
# |             LossQ |           0.318 |
# |              Time |         4.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -148 |
# |          StdEpRet |            79.7 |
# |          MaxEpRet |           -65.3 |
# |          MinEpRet |            -245 |
# |  AverageTestEpRet |           -15.1 |
# |      StdTestEpRet |           0.756 |
# |      MaxTestEpRet |           -13.7 |
# |      MinTestEpRet |           -16.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |            56.7 |
# |         StdQ1Vals |            8.81 |
# |         MaxQ1Vals |            71.1 |
# |         MinQ1Vals |            46.3 |
# |     AverageQ2Vals |            56.7 |
# |         StdQ2Vals |            8.81 |
# |         MaxQ2Vals |            71.3 |
# |         MinQ2Vals |            46.5 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.829 |
# |          MaxLogPi |            3.86 |
# |          MinLogPi |           -12.9 |
# |            LossPi |           -57.4 |
# |             LossQ |           0.321 |
# |              Time |        4.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -138 |
# |          StdEpRet |            70.7 |
# |          MaxEpRet |           -57.1 |
# |          MinEpRet |            -236 |
# |  AverageTestEpRet |           -4.23 |
# |      StdTestEpRet |           0.996 |
# |      MaxTestEpRet |           -2.82 |
# |      MinTestEpRet |           -5.55 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |            56.7 |
# |         StdQ1Vals |            8.83 |
# |         MaxQ1Vals |            71.3 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |            56.7 |
# |         StdQ2Vals |            8.83 |
# |         MaxQ2Vals |            71.1 |
# |         MinQ2Vals |            46.5 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.814 |
# |          MaxLogPi |            3.12 |
# |          MinLogPi |           -10.8 |
# |            LossPi |           -57.4 |
# |             LossQ |           0.318 |
# |              Time |        4.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |           -92.3 |
# |          StdEpRet |            50.3 |
# |          MaxEpRet |           -43.7 |
# |          MinEpRet |            -176 |
# |  AverageTestEpRet |           -10.7 |
# |      StdTestEpRet |               1 |
# |      MaxTestEpRet |           -9.14 |
# |      MinTestEpRet |             -13 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |            56.8 |
# |         StdQ1Vals |            8.85 |
# |         MaxQ1Vals |            71.4 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.8 |
# |         StdQ2Vals |            8.85 |
# |         MaxQ2Vals |            71.2 |
# |         MinQ2Vals |            46.3 |
# |      AverageLogPi |           -3.76 |
# |          StdLogPi |           0.815 |
# |          MaxLogPi |            3.58 |
# |          MinLogPi |           -10.7 |
# |            LossPi |           -57.5 |
# |             LossQ |           0.321 |
# |              Time |        4.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            56.8 |
# |          MaxEpRet |           -59.1 |
# |          MinEpRet |            -201 |
# |  AverageTestEpRet |           -12.1 |
# |      StdTestEpRet |             1.2 |
# |      MaxTestEpRet |           -9.95 |
# |      MinTestEpRet |           -13.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |              57 |
# |         StdQ1Vals |             8.9 |
# |         MaxQ1Vals |            71.1 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |              57 |
# |         StdQ2Vals |             8.9 |
# |         MaxQ2Vals |            71.1 |
# |         MinQ2Vals |            46.5 |
# |      AverageLogPi |           -3.76 |
# |          StdLogPi |           0.804 |
# |          MaxLogPi |            3.26 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -57.7 |
# |             LossQ |           0.317 |
# |              Time |        4.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -191 |
# |          StdEpRet |            39.7 |
# |          MaxEpRet |            -127 |
# |          MinEpRet |            -237 |
# |  AverageTestEpRet |           -11.4 |
# |      StdTestEpRet |           0.716 |
# |      MaxTestEpRet |           -9.79 |
# |      MinTestEpRet |           -12.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |              57 |
# |         StdQ1Vals |            8.91 |
# |         MaxQ1Vals |            71.2 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |              57 |
# |         StdQ2Vals |            8.91 |
# |         MaxQ2Vals |            71.1 |
# |         MinQ2Vals |            46.2 |
# |      AverageLogPi |           -3.76 |
# |          StdLogPi |           0.813 |
# |          MaxLogPi |            3.45 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -57.7 |
# |             LossQ |           0.321 |
# |              Time |        4.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -128 |
# |          StdEpRet |            69.8 |
# |          MaxEpRet |             -55 |
# |          MinEpRet |            -205 |
# |  AverageTestEpRet |           -9.22 |
# |      StdTestEpRet |           0.888 |
# |      MaxTestEpRet |           -7.87 |
# |      MinTestEpRet |           -10.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |              57 |
# |         StdQ1Vals |             8.9 |
# |         MaxQ1Vals |            71.5 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |              57 |
# |         StdQ2Vals |             8.9 |
# |         MaxQ2Vals |            71.2 |
# |         MinQ2Vals |            46.6 |
# |      AverageLogPi |           -3.76 |
# |          StdLogPi |            0.81 |
# |          MaxLogPi |            3.14 |
# |          MinLogPi |           -10.9 |
# |            LossPi |           -57.7 |
# |             LossQ |           0.318 |
# |              Time |        5.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -166 |
# |          StdEpRet |            58.4 |
# |          MaxEpRet |           -66.6 |
# |          MinEpRet |            -212 |
# |  AverageTestEpRet |            -7.8 |
# |      StdTestEpRet |           0.394 |
# |      MaxTestEpRet |           -7.01 |
# |      MinTestEpRet |           -8.41 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |            56.9 |
# |         StdQ1Vals |            8.89 |
# |         MaxQ1Vals |            71.2 |
# |         MinQ1Vals |            46.6 |
# |     AverageQ2Vals |            56.9 |
# |         StdQ2Vals |            8.89 |
# |         MaxQ2Vals |            71.3 |
# |         MinQ2Vals |            46.6 |
# |      AverageLogPi |           -3.76 |
# |          StdLogPi |           0.808 |
# |          MaxLogPi |            3.36 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -57.7 |
# |             LossQ |           0.318 |
# |              Time |        5.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -183 |
# |          StdEpRet |            41.4 |
# |          MaxEpRet |            -134 |
# |          MinEpRet |            -248 |
# |  AverageTestEpRet |           -8.85 |
# |      StdTestEpRet |           0.724 |
# |      MaxTestEpRet |           -7.91 |
# |      MinTestEpRet |           -10.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |              57 |
# |         StdQ1Vals |            8.89 |
# |         MaxQ1Vals |            71.2 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |              57 |
# |         StdQ2Vals |            8.89 |
# |         MaxQ2Vals |            71.2 |
# |         MinQ2Vals |            46.3 |
# |      AverageLogPi |           -3.77 |
# |          StdLogPi |           0.794 |
# |          MaxLogPi |            3.19 |
# |          MinLogPi |           -11.6 |
# |            LossPi |           -57.7 |
# |             LossQ |           0.312 |
# |              Time |        5.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -188 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |            -154 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |           -9.04 |
# |      StdTestEpRet |            1.12 |
# |      MaxTestEpRet |           -6.79 |
# |      MinTestEpRet |           -10.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |              57 |
# |         StdQ1Vals |             8.9 |
# |         MaxQ1Vals |            71.2 |
# |         MinQ1Vals |            46.7 |
# |     AverageQ2Vals |              57 |
# |         StdQ2Vals |             8.9 |
# |         MaxQ2Vals |              71 |
# |         MinQ2Vals |            46.6 |
# |      AverageLogPi |           -3.77 |
# |          StdLogPi |           0.794 |
# |          MaxLogPi |            2.81 |
# |          MinLogPi |           -12.8 |
# |            LossPi |           -57.7 |
# |             LossQ |           0.308 |
# |              Time |        5.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -191 |
# |          StdEpRet |            79.3 |
# |          MaxEpRet |           -53.8 |
# |          MinEpRet |            -246 |
# |  AverageTestEpRet |             -11 |
# |      StdTestEpRet |            1.07 |
# |      MaxTestEpRet |           -8.84 |
# |      MinTestEpRet |           -12.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |            56.9 |
# |         StdQ1Vals |             8.9 |
# |         MaxQ1Vals |            71.2 |
# |         MinQ1Vals |            46.4 |
# |     AverageQ2Vals |            56.9 |
# |         StdQ2Vals |             8.9 |
# |         MaxQ2Vals |            71.3 |
# |         MinQ2Vals |            46.6 |
# |      AverageLogPi |           -3.77 |
# |          StdLogPi |           0.789 |
# |          MaxLogPi |            3.16 |
# |          MinLogPi |           -12.7 |
# |            LossPi |           -57.7 |
# |             LossQ |            0.31 |
# |              Time |        5.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -173 |
# |          StdEpRet |            51.8 |
# |          MaxEpRet |           -84.7 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |           -11.2 |
# |      StdTestEpRet |           0.782 |
# |      MaxTestEpRet |           -9.97 |
# |      MinTestEpRet |           -12.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |            56.9 |
# |         StdQ1Vals |            8.89 |
# |         MaxQ1Vals |            71.2 |
# |         MinQ1Vals |            46.6 |
# |     AverageQ2Vals |            56.9 |
# |         StdQ2Vals |            8.89 |
# |         MaxQ2Vals |            71.2 |
# |         MinQ2Vals |            46.5 |
# |      AverageLogPi |           -3.77 |
# |          StdLogPi |           0.796 |
# |          MaxLogPi |             3.3 |
# |          MinLogPi |           -12.4 |
# |            LossPi |           -57.6 |
# |             LossQ |            0.31 |
# |              Time |        5.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -138 |
# |          StdEpRet |            94.6 |
# |          MaxEpRet |           -40.6 |
# |          MinEpRet |            -234 |
# |  AverageTestEpRet |             -10 |
# |      StdTestEpRet |           0.775 |
# |      MaxTestEpRet |           -8.58 |
# |      MinTestEpRet |           -10.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |            56.9 |
# |         StdQ1Vals |             8.9 |
# |         MaxQ1Vals |            71.7 |
# |         MinQ1Vals |            46.7 |
# |     AverageQ2Vals |            56.9 |
# |         StdQ2Vals |             8.9 |
# |         MaxQ2Vals |            71.2 |
# |         MinQ2Vals |            46.5 |
# |      AverageLogPi |           -3.77 |
# |          StdLogPi |           0.788 |
# |          MaxLogPi |            5.39 |
# |          MinLogPi |           -10.4 |
# |            LossPi |           -57.6 |
# |             LossQ |            0.31 |
# |              Time |        5.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -122 |
# |          StdEpRet |              67 |
# |          MaxEpRet |           -6.85 |
# |          MinEpRet |            -170 |
# |  AverageTestEpRet |           -8.93 |
# |      StdTestEpRet |               1 |
# |      MaxTestEpRet |           -7.62 |
# |      MinTestEpRet |           -10.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |            56.9 |
# |         StdQ1Vals |             8.9 |
# |         MaxQ1Vals |            71.2 |
# |         MinQ1Vals |            46.5 |
# |     AverageQ2Vals |            56.9 |
# |         StdQ2Vals |             8.9 |
# |         MaxQ2Vals |            71.3 |
# |         MinQ2Vals |            46.4 |
# |      AverageLogPi |           -3.77 |
# |          StdLogPi |           0.794 |
# |          MaxLogPi |            3.23 |
# |          MinLogPi |           -10.9 |
# |            LossPi |           -57.6 |
# |             LossQ |           0.305 |
# |              Time |        5.82e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 128, 'l': 2, 
        'gamma': 0.99, 'seed':5, 'epochs':50, 
        'partially_observable': False,
        'exp_name': 'sac_MDP_HalfCheetah_2L128'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

torch.set_num_threads(torch.get_num_threads())

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
    gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    partially_observable=args['partially_observable'],
    logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_MDP_HalfCheetah_2L128\sac_MDP_HalfCheetah_2L128_s5\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             128,
#             128
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"sac_MDP_HalfCheetah_2L128",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001D4E0436948>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_MDP_HalfCheetah_2L128",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_MDP_HalfCheetah_2L128\\sac_MDP_HalfCheetah_2L128_s5",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\sac_MDP_HalfCheetah_2L128\\\\sac_MDP_HalfCheetah_2L128_s5\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_MDP_HalfCheetah_2L128",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_MDP_HalfCheetah_2L128\\sac_MDP_HalfCheetah_2L128_s5"
#     },
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "partially_observable":	false,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	5,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 20364, 	 q1: 19713, 	 q2: 19713
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -302 |
# |          StdEpRet |            25.4 |
# |          MaxEpRet |            -265 |
# |          MinEpRet |            -335 |
# |  AverageTestEpRet |          -0.608 |
# |      StdTestEpRet |            2.71 |
# |      MaxTestEpRet |            6.02 |
# |      MinTestEpRet |           -5.09 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            4.47 |
# |         StdQ1Vals |            2.99 |
# |         MaxQ1Vals |              18 |
# |         MinQ1Vals |           -3.23 |
# |     AverageQ2Vals |            4.47 |
# |         StdQ2Vals |            2.98 |
# |         MaxQ2Vals |            18.5 |
# |         MinQ2Vals |           -3.92 |
# |      AverageLogPi |            -3.1 |
# |          StdLogPi |            1.47 |
# |          MaxLogPi |            7.71 |
# |          MinLogPi |           -11.6 |
# |            LossPi |           -5.37 |
# |             LossQ |           0.841 |
# |              Time |            79.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -342 |
# |          StdEpRet |            65.2 |
# |          MaxEpRet |            -281 |
# |          MinEpRet |            -449 |
# |  AverageTestEpRet |            -120 |
# |      StdTestEpRet |            38.9 |
# |      MaxTestEpRet |           -80.4 |
# |      MinTestEpRet |            -201 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            14.3 |
# |         StdQ1Vals |            5.28 |
# |         MaxQ1Vals |            41.1 |
# |         MinQ1Vals |           -3.27 |
# |     AverageQ2Vals |            14.3 |
# |         StdQ2Vals |            5.28 |
# |         MaxQ2Vals |            40.5 |
# |         MinQ2Vals |           -3.28 |
# |      AverageLogPi |           -1.75 |
# |          StdLogPi |             2.3 |
# |          MaxLogPi |              11 |
# |          MinLogPi |           -15.4 |
# |            LossPi |           -15.5 |
# |             LossQ |            2.22 |
# |              Time |             187 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -294 |
# |          StdEpRet |              81 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -222 |
# |      StdTestEpRet |            33.1 |
# |      MaxTestEpRet |            -150 |
# |      MinTestEpRet |            -280 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            28.7 |
# |         StdQ1Vals |             6.9 |
# |         MaxQ1Vals |            58.6 |
# |         MinQ1Vals |            6.95 |
# |     AverageQ2Vals |            28.7 |
# |         StdQ2Vals |             6.9 |
# |         MaxQ2Vals |            58.4 |
# |         MinQ2Vals |            7.39 |
# |      AverageLogPi |          -0.953 |
# |          StdLogPi |            2.58 |
# |          MaxLogPi |            12.7 |
# |          MinLogPi |           -14.9 |
# |            LossPi |             -30 |
# |             LossQ |            3.47 |
# |              Time |             294 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             163 |
# |          StdEpRet |             358 |
# |          MaxEpRet |             710 |
# |          MinEpRet |            -250 |
# |  AverageTestEpRet |        1.21e+03 |
# |      StdTestEpRet |            44.1 |
# |      MaxTestEpRet |        1.26e+03 |
# |      MinTestEpRet |        1.12e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            35.2 |
# |         StdQ1Vals |            10.5 |
# |         MaxQ1Vals |            65.9 |
# |         MinQ1Vals |            10.3 |
# |     AverageQ2Vals |            35.2 |
# |         StdQ2Vals |            10.5 |
# |         MaxQ2Vals |            66.3 |
# |         MinQ2Vals |            11.6 |
# |      AverageLogPi |           -2.23 |
# |          StdLogPi |            2.03 |
# |          MaxLogPi |            11.4 |
# |          MinLogPi |           -12.6 |
# |            LossPi |           -35.9 |
# |             LossQ |            3.85 |
# |              Time |             404 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |        1.09e+03 |
# |          StdEpRet |             240 |
# |          MaxEpRet |        1.49e+03 |
# |          MinEpRet |             873 |
# |  AverageTestEpRet |        1.97e+03 |
# |      StdTestEpRet |            97.3 |
# |      MaxTestEpRet |        2.17e+03 |
# |      MinTestEpRet |        1.79e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            40.5 |
# |         StdQ1Vals |            13.9 |
# |         MaxQ1Vals |            84.8 |
# |         MinQ1Vals |            11.7 |
# |     AverageQ2Vals |            40.5 |
# |         StdQ2Vals |            13.9 |
# |         MaxQ2Vals |            83.7 |
# |         MinQ2Vals |            11.6 |
# |      AverageLogPi |           -2.34 |
# |          StdLogPi |            1.92 |
# |          MaxLogPi |            15.8 |
# |          MinLogPi |           -13.1 |
# |            LossPi |           -41.2 |
# |             LossQ |            4.06 |
# |              Time |             512 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |        1.72e+03 |
# |          StdEpRet |             255 |
# |          MaxEpRet |        2.15e+03 |
# |          MinEpRet |         1.5e+03 |
# |  AverageTestEpRet |        2.39e+03 |
# |      StdTestEpRet |            86.8 |
# |      MaxTestEpRet |        2.49e+03 |
# |      MinTestEpRet |        2.18e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            51.2 |
# |         StdQ1Vals |            18.9 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |            11.8 |
# |     AverageQ2Vals |            51.2 |
# |         StdQ2Vals |            18.9 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |            10.9 |
# |      AverageLogPi |           -1.69 |
# |          StdLogPi |            2.33 |
# |          MaxLogPi |            18.8 |
# |          MinLogPi |           -13.7 |
# |            LossPi |           -51.9 |
# |             LossQ |            5.64 |
# |              Time |             620 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |        2.37e+03 |
# |          StdEpRet |             186 |
# |          MaxEpRet |        2.65e+03 |
# |          MinEpRet |        2.17e+03 |
# |  AverageTestEpRet |        3.15e+03 |
# |      StdTestEpRet |            78.3 |
# |      MaxTestEpRet |        3.31e+03 |
# |      MinTestEpRet |        3.05e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            67.1 |
# |         StdQ1Vals |            25.8 |
# |         MaxQ1Vals |             137 |
# |         MinQ1Vals |              12 |
# |     AverageQ2Vals |            67.1 |
# |         StdQ2Vals |            25.8 |
# |         MaxQ2Vals |             134 |
# |         MinQ2Vals |            11.7 |
# |      AverageLogPi |           -1.03 |
# |          StdLogPi |            2.64 |
# |          MaxLogPi |            21.1 |
# |          MinLogPi |           -13.5 |
# |            LossPi |           -67.9 |
# |             LossQ |            7.57 |
# |              Time |             727 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |        2.67e+03 |
# |          StdEpRet |             265 |
# |          MaxEpRet |        2.84e+03 |
# |          MinEpRet |        2.21e+03 |
# |  AverageTestEpRet |        3.56e+03 |
# |      StdTestEpRet |            33.6 |
# |      MaxTestEpRet |        3.61e+03 |
# |      MinTestEpRet |         3.5e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            86.7 |
# |         StdQ1Vals |            32.7 |
# |         MaxQ1Vals |             162 |
# |         MinQ1Vals |            11.2 |
# |     AverageQ2Vals |            86.7 |
# |         StdQ2Vals |            32.7 |
# |         MaxQ2Vals |             163 |
# |         MinQ2Vals |            11.9 |
# |      AverageLogPi |          -0.423 |
# |          StdLogPi |            2.88 |
# |          MaxLogPi |            20.9 |
# |          MinLogPi |           -15.5 |
# |            LossPi |           -87.5 |
# |             LossQ |            9.35 |
# |              Time |             834 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |        3.22e+03 |
# |          StdEpRet |             136 |
# |          MaxEpRet |        3.43e+03 |
# |          MinEpRet |        3.07e+03 |
# |  AverageTestEpRet |        3.68e+03 |
# |      StdTestEpRet |            76.1 |
# |      MaxTestEpRet |        3.81e+03 |
# |      MinTestEpRet |        3.56e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |             108 |
# |         StdQ1Vals |            39.7 |
# |         MaxQ1Vals |             194 |
# |         MinQ1Vals |            10.2 |
# |     AverageQ2Vals |             108 |
# |         StdQ2Vals |            39.7 |
# |         MaxQ2Vals |             192 |
# |         MinQ2Vals |            12.8 |
# |      AverageLogPi |          0.0453 |
# |          StdLogPi |            3.12 |
# |          MaxLogPi |            24.8 |
# |          MinLogPi |           -14.9 |
# |            LossPi |            -108 |
# |             LossQ |            11.4 |
# |              Time |             944 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |         3.4e+03 |
# |          StdEpRet |            55.5 |
# |          MaxEpRet |        3.45e+03 |
# |          MinEpRet |        3.31e+03 |
# |  AverageTestEpRet |        3.88e+03 |
# |      StdTestEpRet |              95 |
# |      MaxTestEpRet |        4.01e+03 |
# |      MinTestEpRet |        3.72e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |             130 |
# |         StdQ1Vals |            45.8 |
# |         MaxQ1Vals |             213 |
# |         MinQ1Vals |            9.35 |
# |     AverageQ2Vals |             130 |
# |         StdQ2Vals |            45.8 |
# |         MaxQ2Vals |             216 |
# |         MinQ2Vals |            11.2 |
# |      AverageLogPi |           0.329 |
# |          StdLogPi |            3.23 |
# |          MaxLogPi |            26.8 |
# |          MinLogPi |           -13.8 |
# |            LossPi |            -131 |
# |             LossQ |            12.4 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |        3.74e+03 |
# |          StdEpRet |            57.6 |
# |          MaxEpRet |         3.8e+03 |
# |          MinEpRet |        3.65e+03 |
# |  AverageTestEpRet |         4.3e+03 |
# |      StdTestEpRet |            57.4 |
# |      MaxTestEpRet |        4.37e+03 |
# |      MinTestEpRet |        4.21e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |             151 |
# |         StdQ1Vals |              51 |
# |         MaxQ1Vals |             242 |
# |         MinQ1Vals |            9.07 |
# |     AverageQ2Vals |             151 |
# |         StdQ2Vals |              51 |
# |         MaxQ2Vals |             242 |
# |         MinQ2Vals |            10.2 |
# |      AverageLogPi |            0.57 |
# |          StdLogPi |            3.32 |
# |          MaxLogPi |            21.7 |
# |          MinLogPi |           -13.6 |
# |            LossPi |            -152 |
# |             LossQ |            13.6 |
# |              Time |        1.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |        3.96e+03 |
# |          StdEpRet |            77.8 |
# |          MaxEpRet |        4.06e+03 |
# |          MinEpRet |        3.86e+03 |
# |  AverageTestEpRet |         4.5e+03 |
# |      StdTestEpRet |            61.4 |
# |      MaxTestEpRet |        4.61e+03 |
# |      MinTestEpRet |        4.41e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |             172 |
# |         StdQ1Vals |            55.5 |
# |         MaxQ1Vals |             263 |
# |         MinQ1Vals |            4.75 |
# |     AverageQ2Vals |             172 |
# |         StdQ2Vals |            55.5 |
# |         MaxQ2Vals |             263 |
# |         MinQ2Vals |            7.92 |
# |      AverageLogPi |           0.752 |
# |          StdLogPi |             3.4 |
# |          MaxLogPi |              27 |
# |          MinLogPi |           -13.4 |
# |            LossPi |            -172 |
# |             LossQ |            14.6 |
# |              Time |        1.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |        4.16e+03 |
# |          StdEpRet |             142 |
# |          MaxEpRet |        4.35e+03 |
# |          MinEpRet |        4.02e+03 |
# |  AverageTestEpRet |        4.68e+03 |
# |      StdTestEpRet |            94.7 |
# |      MaxTestEpRet |        4.82e+03 |
# |      MinTestEpRet |        4.53e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |             191 |
# |         StdQ1Vals |            59.5 |
# |         MaxQ1Vals |             285 |
# |         MinQ1Vals |            2.12 |
# |     AverageQ2Vals |             191 |
# |         StdQ2Vals |            59.5 |
# |         MaxQ2Vals |             284 |
# |         MinQ2Vals |            3.19 |
# |      AverageLogPi |           0.974 |
# |          StdLogPi |            3.48 |
# |          MaxLogPi |            26.2 |
# |          MinLogPi |           -13.9 |
# |            LossPi |            -192 |
# |             LossQ |            15.4 |
# |              Time |        1.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        4.22e+03 |
# |          StdEpRet |            95.5 |
# |          MaxEpRet |        4.37e+03 |
# |          MinEpRet |        4.13e+03 |
# |  AverageTestEpRet |        4.07e+03 |
# |      StdTestEpRet |        1.04e+03 |
# |      MaxTestEpRet |        4.72e+03 |
# |      MinTestEpRet |         1.5e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |             209 |
# |         StdQ1Vals |            62.9 |
# |         MaxQ1Vals |             298 |
# |         MinQ1Vals |           -2.66 |
# |     AverageQ2Vals |             209 |
# |         StdQ2Vals |            62.9 |
# |         MaxQ2Vals |             300 |
# |         MinQ2Vals |           -3.89 |
# |      AverageLogPi |            1.15 |
# |          StdLogPi |            3.51 |
# |          MaxLogPi |              24 |
# |          MinLogPi |           -14.1 |
# |            LossPi |            -210 |
# |             LossQ |            15.6 |
# |              Time |        1.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        4.29e+03 |
# |          StdEpRet |            95.8 |
# |          MaxEpRet |        4.39e+03 |
# |          MinEpRet |        4.18e+03 |
# |  AverageTestEpRet |        4.09e+03 |
# |      StdTestEpRet |        1.54e+03 |
# |      MaxTestEpRet |        4.96e+03 |
# |      MinTestEpRet |             644 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             226 |
# |         StdQ1Vals |            65.9 |
# |         MaxQ1Vals |             317 |
# |         MinQ1Vals |           -7.78 |
# |     AverageQ2Vals |             226 |
# |         StdQ2Vals |            65.9 |
# |         MaxQ2Vals |             316 |
# |         MinQ2Vals |           -11.8 |
# |      AverageLogPi |             1.3 |
# |          StdLogPi |            3.58 |
# |          MaxLogPi |            28.6 |
# |          MinLogPi |           -14.5 |
# |            LossPi |            -226 |
# |             LossQ |            16.1 |
# |              Time |        1.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |        3.98e+03 |
# |          StdEpRet |             916 |
# |          MaxEpRet |         4.6e+03 |
# |          MinEpRet |         2.4e+03 |
# |  AverageTestEpRet |        3.82e+03 |
# |      StdTestEpRet |        1.09e+03 |
# |      MaxTestEpRet |        4.99e+03 |
# |      MinTestEpRet |        2.32e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             241 |
# |         StdQ1Vals |            68.1 |
# |         MaxQ1Vals |             332 |
# |         MinQ1Vals |           -17.1 |
# |     AverageQ2Vals |             241 |
# |         StdQ2Vals |            68.1 |
# |         MaxQ2Vals |             333 |
# |         MinQ2Vals |             -12 |
# |      AverageLogPi |            1.45 |
# |          StdLogPi |            3.63 |
# |          MaxLogPi |            25.2 |
# |          MinLogPi |           -14.7 |
# |            LossPi |            -242 |
# |             LossQ |              17 |
# |              Time |        1.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        4.55e+03 |
# |          StdEpRet |            39.3 |
# |          MaxEpRet |        4.61e+03 |
# |          MinEpRet |        4.51e+03 |
# |  AverageTestEpRet |        4.08e+03 |
# |      StdTestEpRet |        1.51e+03 |
# |      MaxTestEpRet |         5.2e+03 |
# |      MinTestEpRet |        1.38e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             254 |
# |         StdQ1Vals |            72.7 |
# |         MaxQ1Vals |             351 |
# |         MinQ1Vals |           -10.7 |
# |     AverageQ2Vals |             254 |
# |         StdQ2Vals |            72.7 |
# |         MaxQ2Vals |             350 |
# |         MinQ2Vals |           -14.4 |
# |      AverageLogPi |            1.57 |
# |          StdLogPi |            3.71 |
# |          MaxLogPi |            22.9 |
# |          MinLogPi |           -13.7 |
# |            LossPi |            -254 |
# |             LossQ |            18.7 |
# |              Time |        1.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        4.68e+03 |
# |          StdEpRet |            73.5 |
# |          MaxEpRet |        4.77e+03 |
# |          MinEpRet |         4.6e+03 |
# |  AverageTestEpRet |        5.05e+03 |
# |      StdTestEpRet |            75.8 |
# |      MaxTestEpRet |        5.26e+03 |
# |      MinTestEpRet |        4.96e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             267 |
# |         StdQ1Vals |              74 |
# |         MaxQ1Vals |             359 |
# |         MinQ1Vals |           -10.3 |
# |     AverageQ2Vals |             267 |
# |         StdQ2Vals |              74 |
# |         MaxQ2Vals |             360 |
# |         MinQ2Vals |           -12.4 |
# |      AverageLogPi |            1.63 |
# |          StdLogPi |            3.71 |
# |          MaxLogPi |            24.5 |
# |          MinLogPi |           -12.8 |
# |            LossPi |            -267 |
# |             LossQ |            18.7 |
# |              Time |        1.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |        4.67e+03 |
# |          StdEpRet |             154 |
# |          MaxEpRet |        4.85e+03 |
# |          MinEpRet |        4.45e+03 |
# |  AverageTestEpRet |        4.94e+03 |
# |      StdTestEpRet |             410 |
# |      MaxTestEpRet |         5.3e+03 |
# |      MinTestEpRet |        3.92e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             279 |
# |         StdQ1Vals |            75.2 |
# |         MaxQ1Vals |             366 |
# |         MinQ1Vals |             -29 |
# |     AverageQ2Vals |             279 |
# |         StdQ2Vals |            75.2 |
# |         MaxQ2Vals |             365 |
# |         MinQ2Vals |           -20.7 |
# |      AverageLogPi |            1.72 |
# |          StdLogPi |            3.73 |
# |          MaxLogPi |            28.8 |
# |          MinLogPi |           -13.6 |
# |            LossPi |            -279 |
# |             LossQ |            18.2 |
# |              Time |        2.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |         4.7e+03 |
# |          StdEpRet |            76.3 |
# |          MaxEpRet |        4.83e+03 |
# |          MinEpRet |        4.62e+03 |
# |  AverageTestEpRet |        5.23e+03 |
# |      StdTestEpRet |            88.2 |
# |      MaxTestEpRet |        5.43e+03 |
# |      MinTestEpRet |        5.12e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             290 |
# |         StdQ1Vals |            76.2 |
# |         MaxQ1Vals |             381 |
# |         MinQ1Vals |           -19.1 |
# |     AverageQ2Vals |             290 |
# |         StdQ2Vals |            76.2 |
# |         MaxQ2Vals |             382 |
# |         MinQ2Vals |           -14.9 |
# |      AverageLogPi |            1.73 |
# |          StdLogPi |            3.74 |
# |          MaxLogPi |              32 |
# |          MinLogPi |           -13.8 |
# |            LossPi |            -290 |
# |             LossQ |            18.6 |
# |              Time |        2.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        4.85e+03 |
# |          StdEpRet |            80.7 |
# |          MaxEpRet |        4.96e+03 |
# |          MinEpRet |        4.74e+03 |
# |  AverageTestEpRet |           5e+03 |
# |      StdTestEpRet |             796 |
# |      MaxTestEpRet |         5.5e+03 |
# |      MinTestEpRet |        2.64e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             300 |
# |         StdQ1Vals |            76.7 |
# |         MaxQ1Vals |             392 |
# |         MinQ1Vals |           -14.3 |
# |     AverageQ2Vals |             300 |
# |         StdQ2Vals |            76.7 |
# |         MaxQ2Vals |             393 |
# |         MinQ2Vals |           -11.6 |
# |      AverageLogPi |             1.9 |
# |          StdLogPi |             3.8 |
# |          MaxLogPi |            35.7 |
# |          MinLogPi |           -16.7 |
# |            LossPi |            -300 |
# |             LossQ |            19.7 |
# |              Time |        2.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |         4.9e+03 |
# |          StdEpRet |            85.9 |
# |          MaxEpRet |        5.04e+03 |
# |          MinEpRet |        4.81e+03 |
# |  AverageTestEpRet |        4.61e+03 |
# |      StdTestEpRet |             999 |
# |      MaxTestEpRet |         5.4e+03 |
# |      MinTestEpRet |        2.66e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             309 |
# |         StdQ1Vals |            77.5 |
# |         MaxQ1Vals |             400 |
# |         MinQ1Vals |           -5.79 |
# |     AverageQ2Vals |             309 |
# |         StdQ2Vals |            77.5 |
# |         MaxQ2Vals |             400 |
# |         MinQ2Vals |           -7.63 |
# |      AverageLogPi |            1.91 |
# |          StdLogPi |            3.81 |
# |          MaxLogPi |            28.2 |
# |          MinLogPi |             -13 |
# |            LossPi |            -309 |
# |             LossQ |            19.9 |
# |              Time |        2.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        4.95e+03 |
# |          StdEpRet |            97.7 |
# |          MaxEpRet |        5.01e+03 |
# |          MinEpRet |        4.78e+03 |
# |  AverageTestEpRet |        5.47e+03 |
# |      StdTestEpRet |            62.2 |
# |      MaxTestEpRet |        5.56e+03 |
# |      MinTestEpRet |        5.38e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             317 |
# |         StdQ1Vals |            77.7 |
# |         MaxQ1Vals |             409 |
# |         MinQ1Vals |           -2.48 |
# |     AverageQ2Vals |             317 |
# |         StdQ2Vals |            77.7 |
# |         MaxQ2Vals |             409 |
# |         MinQ2Vals |           -4.62 |
# |      AverageLogPi |            1.98 |
# |          StdLogPi |            3.86 |
# |          MaxLogPi |            42.9 |
# |          MinLogPi |           -13.7 |
# |            LossPi |            -318 |
# |             LossQ |            20.6 |
# |              Time |        2.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        5.04e+03 |
# |          StdEpRet |             123 |
# |          MaxEpRet |        5.25e+03 |
# |          MinEpRet |        4.94e+03 |
# |  AverageTestEpRet |        5.51e+03 |
# |      StdTestEpRet |             124 |
# |      MaxTestEpRet |        5.68e+03 |
# |      MinTestEpRet |        5.32e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             326 |
# |         StdQ1Vals |            77.7 |
# |         MaxQ1Vals |             415 |
# |         MinQ1Vals |           -8.56 |
# |     AverageQ2Vals |             326 |
# |         StdQ2Vals |            77.7 |
# |         MaxQ2Vals |             416 |
# |         MinQ2Vals |          -0.583 |
# |      AverageLogPi |             2.1 |
# |          StdLogPi |            3.87 |
# |          MaxLogPi |              31 |
# |          MinLogPi |           -16.6 |
# |            LossPi |            -326 |
# |             LossQ |            20.5 |
# |              Time |        2.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        5.03e+03 |
# |          StdEpRet |            87.8 |
# |          MaxEpRet |        5.14e+03 |
# |          MinEpRet |         4.9e+03 |
# |  AverageTestEpRet |        5.25e+03 |
# |      StdTestEpRet |             758 |
# |      MaxTestEpRet |        5.63e+03 |
# |      MinTestEpRet |        2.99e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             333 |
# |         StdQ1Vals |            77.8 |
# |         MaxQ1Vals |             424 |
# |         MinQ1Vals |            6.37 |
# |     AverageQ2Vals |             333 |
# |         StdQ2Vals |            77.8 |
# |         MaxQ2Vals |             427 |
# |         MinQ2Vals |           -25.4 |
# |      AverageLogPi |            2.21 |
# |          StdLogPi |            3.94 |
# |          MaxLogPi |            42.6 |
# |          MinLogPi |             -15 |
# |            LossPi |            -333 |
# |             LossQ |            20.9 |
# |              Time |        2.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        4.83e+03 |
# |          StdEpRet |             640 |
# |          MaxEpRet |        5.33e+03 |
# |          MinEpRet |        3.73e+03 |
# |  AverageTestEpRet |        4.68e+03 |
# |      StdTestEpRet |        1.59e+03 |
# |      MaxTestEpRet |        5.84e+03 |
# |      MinTestEpRet |             978 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             340 |
# |         StdQ1Vals |            78.9 |
# |         MaxQ1Vals |             432 |
# |         MinQ1Vals |           -8.18 |
# |     AverageQ2Vals |             340 |
# |         StdQ2Vals |            78.9 |
# |         MaxQ2Vals |             430 |
# |         MinQ2Vals |           -8.02 |
# |      AverageLogPi |            2.18 |
# |          StdLogPi |            3.92 |
# |          MaxLogPi |            38.5 |
# |          MinLogPi |           -13.1 |
# |            LossPi |            -340 |
# |             LossQ |            21.4 |
# |              Time |         2.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |        5.23e+03 |
# |          StdEpRet |             203 |
# |          MaxEpRet |        5.54e+03 |
# |          MinEpRet |        4.99e+03 |
# |  AverageTestEpRet |        5.68e+03 |
# |      StdTestEpRet |            56.8 |
# |      MaxTestEpRet |        5.78e+03 |
# |      MinTestEpRet |         5.6e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             346 |
# |         StdQ1Vals |            80.1 |
# |         MaxQ1Vals |             442 |
# |         MinQ1Vals |           -24.5 |
# |     AverageQ2Vals |             346 |
# |         StdQ2Vals |            80.1 |
# |         MaxQ2Vals |             439 |
# |         MinQ2Vals |           -35.7 |
# |      AverageLogPi |            2.28 |
# |          StdLogPi |            3.96 |
# |          MaxLogPi |            38.1 |
# |          MinLogPi |           -13.1 |
# |            LossPi |            -346 |
# |             LossQ |            22.6 |
# |              Time |        2.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        4.89e+03 |
# |          StdEpRet |             668 |
# |          MaxEpRet |        5.44e+03 |
# |          MinEpRet |        3.75e+03 |
# |  AverageTestEpRet |        4.92e+03 |
# |      StdTestEpRet |         1.3e+03 |
# |      MaxTestEpRet |        5.91e+03 |
# |      MinTestEpRet |         2.5e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             352 |
# |         StdQ1Vals |            80.7 |
# |         MaxQ1Vals |             446 |
# |         MinQ1Vals |           -51.6 |
# |     AverageQ2Vals |             352 |
# |         StdQ2Vals |            80.7 |
# |         MaxQ2Vals |             446 |
# |         MinQ2Vals |           -56.6 |
# |      AverageLogPi |            2.32 |
# |          StdLogPi |            3.98 |
# |          MaxLogPi |            32.1 |
# |          MinLogPi |           -12.9 |
# |            LossPi |            -352 |
# |             LossQ |            23.2 |
# |              Time |        3.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        5.32e+03 |
# |          StdEpRet |            70.6 |
# |          MaxEpRet |         5.4e+03 |
# |          MinEpRet |        5.21e+03 |
# |  AverageTestEpRet |        5.85e+03 |
# |      StdTestEpRet |             147 |
# |      MaxTestEpRet |        6.04e+03 |
# |      MinTestEpRet |        5.51e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |             357 |
# |         StdQ1Vals |            82.1 |
# |         MaxQ1Vals |             454 |
# |         MinQ1Vals |           -87.3 |
# |     AverageQ2Vals |             357 |
# |         StdQ2Vals |            82.1 |
# |         MaxQ2Vals |             451 |
# |         MinQ2Vals |           -78.7 |
# |      AverageLogPi |            2.42 |
# |          StdLogPi |               4 |
# |          MaxLogPi |            33.8 |
# |          MinLogPi |           -13.3 |
# |            LossPi |            -357 |
# |             LossQ |            26.1 |
# |              Time |        3.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        4.32e+03 |
# |          StdEpRet |        1.96e+03 |
# |          MaxEpRet |        5.58e+03 |
# |          MinEpRet |             924 |
# |  AverageTestEpRet |        5.56e+03 |
# |      StdTestEpRet |             879 |
# |      MaxTestEpRet |        6.08e+03 |
# |      MinTestEpRet |        2.94e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |             360 |
# |         StdQ1Vals |            85.7 |
# |         MaxQ1Vals |             459 |
# |         MinQ1Vals |           -84.1 |
# |     AverageQ2Vals |             360 |
# |         StdQ2Vals |            85.7 |
# |         MaxQ2Vals |             457 |
# |         MinQ2Vals |           -82.2 |
# |      AverageLogPi |            2.42 |
# |          StdLogPi |            4.04 |
# |          MaxLogPi |            41.6 |
# |          MinLogPi |             -12 |
# |            LossPi |            -360 |
# |             LossQ |            27.4 |
# |              Time |        3.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |         5.2e+03 |
# |          StdEpRet |             322 |
# |          MaxEpRet |         5.6e+03 |
# |          MinEpRet |        4.74e+03 |
# |  AverageTestEpRet |        5.86e+03 |
# |      StdTestEpRet |             197 |
# |      MaxTestEpRet |        6.09e+03 |
# |      MinTestEpRet |        5.53e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             364 |
# |         StdQ1Vals |            86.6 |
# |         MaxQ1Vals |             462 |
# |         MinQ1Vals |           -57.6 |
# |     AverageQ2Vals |             364 |
# |         StdQ2Vals |            86.6 |
# |         MaxQ2Vals |             460 |
# |         MinQ2Vals |           -62.4 |
# |      AverageLogPi |            2.46 |
# |          StdLogPi |            4.02 |
# |          MaxLogPi |            37.3 |
# |          MinLogPi |           -16.4 |
# |            LossPi |            -364 |
# |             LossQ |            27.1 |
# |              Time |        3.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        5.46e+03 |
# |          StdEpRet |             157 |
# |          MaxEpRet |        5.61e+03 |
# |          MinEpRet |        5.25e+03 |
# |  AverageTestEpRet |        5.51e+03 |
# |      StdTestEpRet |        1.47e+03 |
# |      MaxTestEpRet |        6.19e+03 |
# |      MinTestEpRet |        1.14e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             369 |
# |         StdQ1Vals |            87.3 |
# |         MaxQ1Vals |             469 |
# |         MinQ1Vals |           -69.7 |
# |     AverageQ2Vals |             369 |
# |         StdQ2Vals |            87.3 |
# |         MaxQ2Vals |             464 |
# |         MinQ2Vals |           -71.6 |
# |      AverageLogPi |            2.66 |
# |          StdLogPi |            4.09 |
# |          MaxLogPi |            34.4 |
# |          MinLogPi |           -15.9 |
# |            LossPi |            -369 |
# |             LossQ |              31 |
# |              Time |        3.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |        5.49e+03 |
# |          StdEpRet |            85.2 |
# |          MaxEpRet |        5.63e+03 |
# |          MinEpRet |         5.4e+03 |
# |  AverageTestEpRet |        6.27e+03 |
# |      StdTestEpRet |             104 |
# |      MaxTestEpRet |        6.44e+03 |
# |      MinTestEpRet |        6.11e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             374 |
# |         StdQ1Vals |            87.5 |
# |         MaxQ1Vals |             473 |
# |         MinQ1Vals |             -67 |
# |     AverageQ2Vals |             374 |
# |         StdQ2Vals |            87.5 |
# |         MaxQ2Vals |             472 |
# |         MinQ2Vals |           -77.9 |
# |      AverageLogPi |            2.69 |
# |          StdLogPi |            4.08 |
# |          MaxLogPi |            41.4 |
# |          MinLogPi |           -13.2 |
# |            LossPi |            -374 |
# |             LossQ |            30.4 |
# |              Time |        3.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |        4.93e+03 |
# |          StdEpRet |        1.43e+03 |
# |          MaxEpRet |        5.88e+03 |
# |          MinEpRet |        2.45e+03 |
# |  AverageTestEpRet |        6.45e+03 |
# |      StdTestEpRet |             116 |
# |      MaxTestEpRet |        6.65e+03 |
# |      MinTestEpRet |        6.24e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             378 |
# |         StdQ1Vals |            89.4 |
# |         MaxQ1Vals |             480 |
# |         MinQ1Vals |           -76.9 |
# |     AverageQ2Vals |             378 |
# |         StdQ2Vals |            89.4 |
# |         MaxQ2Vals |             477 |
# |         MinQ2Vals |            -101 |
# |      AverageLogPi |            2.72 |
# |          StdLogPi |            4.11 |
# |          MaxLogPi |              47 |
# |          MinLogPi |           -14.1 |
# |            LossPi |            -378 |
# |             LossQ |            30.6 |
# |              Time |         3.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |        4.69e+03 |
# |          StdEpRet |        1.37e+03 |
# |          MaxEpRet |        5.75e+03 |
# |          MinEpRet |        2.38e+03 |
# |  AverageTestEpRet |        5.07e+03 |
# |      StdTestEpRet |        1.74e+03 |
# |      MaxTestEpRet |        6.42e+03 |
# |      MinTestEpRet |        1.45e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             382 |
# |         StdQ1Vals |            90.9 |
# |         MaxQ1Vals |             484 |
# |         MinQ1Vals |           -75.9 |
# |     AverageQ2Vals |             382 |
# |         StdQ2Vals |            90.9 |
# |         MaxQ2Vals |             485 |
# |         MinQ2Vals |           -60.5 |
# |      AverageLogPi |            2.77 |
# |          StdLogPi |            4.12 |
# |          MaxLogPi |            37.7 |
# |          MinLogPi |           -17.2 |
# |            LossPi |            -382 |
# |             LossQ |            31.5 |
# |              Time |        3.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |        5.85e+03 |
# |          StdEpRet |            84.5 |
# |          MaxEpRet |        5.97e+03 |
# |          MinEpRet |        5.74e+03 |
# |  AverageTestEpRet |        6.36e+03 |
# |      StdTestEpRet |             169 |
# |      MaxTestEpRet |        6.52e+03 |
# |      MinTestEpRet |        5.92e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             384 |
# |         StdQ1Vals |            93.7 |
# |         MaxQ1Vals |             489 |
# |         MinQ1Vals |             -56 |
# |     AverageQ2Vals |             384 |
# |         StdQ2Vals |            93.7 |
# |         MaxQ2Vals |             487 |
# |         MinQ2Vals |            -106 |
# |      AverageLogPi |            2.83 |
# |          StdLogPi |            4.17 |
# |          MaxLogPi |            46.5 |
# |          MinLogPi |           -12.1 |
# |            LossPi |            -384 |
# |             LossQ |              34 |
# |              Time |        3.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |        5.76e+03 |
# |          StdEpRet |            95.2 |
# |          MaxEpRet |        5.89e+03 |
# |          MinEpRet |        5.62e+03 |
# |  AverageTestEpRet |        6.18e+03 |
# |      StdTestEpRet |              89 |
# |      MaxTestEpRet |        6.32e+03 |
# |      MinTestEpRet |        6.02e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             389 |
# |         StdQ1Vals |            93.2 |
# |         MaxQ1Vals |             493 |
# |         MinQ1Vals |           -47.4 |
# |     AverageQ2Vals |             389 |
# |         StdQ2Vals |            93.2 |
# |         MaxQ2Vals |             491 |
# |         MinQ2Vals |           -50.3 |
# |      AverageLogPi |            2.87 |
# |          StdLogPi |            4.17 |
# |          MaxLogPi |            46.1 |
# |          MinLogPi |           -13.6 |
# |            LossPi |            -389 |
# |             LossQ |            34.3 |
# |              Time |        4.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        5.97e+03 |
# |          StdEpRet |             100 |
# |          MaxEpRet |        6.11e+03 |
# |          MinEpRet |        5.85e+03 |
# |  AverageTestEpRet |        6.39e+03 |
# |      StdTestEpRet |              78 |
# |      MaxTestEpRet |        6.52e+03 |
# |      MinTestEpRet |         6.3e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             393 |
# |         StdQ1Vals |            93.6 |
# |         MaxQ1Vals |             497 |
# |         MinQ1Vals |           -34.9 |
# |     AverageQ2Vals |             393 |
# |         StdQ2Vals |            93.6 |
# |         MaxQ2Vals |             498 |
# |         MinQ2Vals |           -29.8 |
# |      AverageLogPi |            2.93 |
# |          StdLogPi |            4.18 |
# |          MaxLogPi |            57.2 |
# |          MinLogPi |           -14.8 |
# |            LossPi |            -393 |
# |             LossQ |            32.8 |
# |              Time |        4.11e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        6.13e+03 |
# |          StdEpRet |            53.3 |
# |          MaxEpRet |        6.22e+03 |
# |          MinEpRet |        6.07e+03 |
# |  AverageTestEpRet |        6.44e+03 |
# |      StdTestEpRet |            80.2 |
# |      MaxTestEpRet |        6.56e+03 |
# |      MinTestEpRet |         6.3e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             398 |
# |         StdQ1Vals |              93 |
# |         MaxQ1Vals |             509 |
# |         MinQ1Vals |           -61.7 |
# |     AverageQ2Vals |             398 |
# |         StdQ2Vals |              93 |
# |         MaxQ2Vals |             510 |
# |         MinQ2Vals |           -28.9 |
# |      AverageLogPi |            3.04 |
# |          StdLogPi |            4.16 |
# |          MaxLogPi |            51.3 |
# |          MinLogPi |           -12.1 |
# |            LossPi |            -398 |
# |             LossQ |            33.1 |
# |              Time |        4.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        6.07e+03 |
# |          StdEpRet |            80.5 |
# |          MaxEpRet |        6.18e+03 |
# |          MinEpRet |        5.99e+03 |
# |  AverageTestEpRet |        6.49e+03 |
# |      StdTestEpRet |            54.5 |
# |      MaxTestEpRet |        6.59e+03 |
# |      MinTestEpRet |        6.38e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             403 |
# |         StdQ1Vals |            93.3 |
# |         MaxQ1Vals |             512 |
# |         MinQ1Vals |           -29.1 |
# |     AverageQ2Vals |             403 |
# |         StdQ2Vals |            93.3 |
# |         MaxQ2Vals |             512 |
# |         MinQ2Vals |             -20 |
# |      AverageLogPi |            3.11 |
# |          StdLogPi |            4.19 |
# |          MaxLogPi |            47.9 |
# |          MinLogPi |           -13.3 |
# |            LossPi |            -403 |
# |             LossQ |            33.2 |
# |              Time |         4.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        6.18e+03 |
# |          StdEpRet |             138 |
# |          MaxEpRet |         6.3e+03 |
# |          MinEpRet |        5.95e+03 |
# |  AverageTestEpRet |        6.91e+03 |
# |      StdTestEpRet |             105 |
# |      MaxTestEpRet |        7.04e+03 |
# |      MinTestEpRet |        6.71e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             408 |
# |         StdQ1Vals |            93.5 |
# |         MaxQ1Vals |             518 |
# |         MinQ1Vals |           -13.5 |
# |     AverageQ2Vals |             408 |
# |         StdQ2Vals |            93.5 |
# |         MaxQ2Vals |             520 |
# |         MinQ2Vals |           -22.6 |
# |      AverageLogPi |            3.21 |
# |          StdLogPi |            4.25 |
# |          MaxLogPi |            60.4 |
# |          MinLogPi |           -14.2 |
# |            LossPi |            -408 |
# |             LossQ |            34.5 |
# |              Time |         4.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        6.32e+03 |
# |          StdEpRet |             137 |
# |          MaxEpRet |        6.49e+03 |
# |          MinEpRet |        6.12e+03 |
# |  AverageTestEpRet |        6.68e+03 |
# |      StdTestEpRet |            95.1 |
# |      MaxTestEpRet |        6.88e+03 |
# |      MinTestEpRet |        6.58e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             413 |
# |         StdQ1Vals |            94.2 |
# |         MaxQ1Vals |             519 |
# |         MinQ1Vals |           -12.4 |
# |     AverageQ2Vals |             413 |
# |         StdQ2Vals |            94.2 |
# |         MaxQ2Vals |             519 |
# |         MinQ2Vals |           -13.1 |
# |      AverageLogPi |            3.24 |
# |          StdLogPi |             4.2 |
# |          MaxLogPi |            40.6 |
# |          MinLogPi |           -15.1 |
# |            LossPi |            -413 |
# |             LossQ |            33.3 |
# |              Time |         4.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        6.48e+03 |
# |          StdEpRet |             114 |
# |          MaxEpRet |        6.62e+03 |
# |          MinEpRet |        6.31e+03 |
# |  AverageTestEpRet |         7.1e+03 |
# |      StdTestEpRet |             146 |
# |      MaxTestEpRet |        7.33e+03 |
# |      MinTestEpRet |        6.84e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             419 |
# |         StdQ1Vals |            94.3 |
# |         MaxQ1Vals |             532 |
# |         MinQ1Vals |           -16.7 |
# |     AverageQ2Vals |             419 |
# |         StdQ2Vals |            94.3 |
# |         MaxQ2Vals |             533 |
# |         MinQ2Vals |           -25.8 |
# |      AverageLogPi |            3.28 |
# |          StdLogPi |             4.2 |
# |          MaxLogPi |            42.3 |
# |          MinLogPi |           -12.3 |
# |            LossPi |            -419 |
# |             LossQ |            34.9 |
# |              Time |        4.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        6.46e+03 |
# |          StdEpRet |             106 |
# |          MaxEpRet |        6.64e+03 |
# |          MinEpRet |        6.38e+03 |
# |  AverageTestEpRet |        6.69e+03 |
# |      StdTestEpRet |            64.2 |
# |      MaxTestEpRet |        6.83e+03 |
# |      MinTestEpRet |        6.61e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             424 |
# |         StdQ1Vals |            94.9 |
# |         MaxQ1Vals |             540 |
# |         MinQ1Vals |           -19.6 |
# |     AverageQ2Vals |             424 |
# |         StdQ2Vals |            94.9 |
# |         MaxQ2Vals |             540 |
# |         MinQ2Vals |             -11 |
# |      AverageLogPi |             3.4 |
# |          StdLogPi |            4.22 |
# |          MaxLogPi |            45.8 |
# |          MinLogPi |           -12.3 |
# |            LossPi |            -424 |
# |             LossQ |            37.1 |
# |              Time |        4.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        6.61e+03 |
# |          StdEpRet |            62.8 |
# |          MaxEpRet |        6.67e+03 |
# |          MinEpRet |        6.51e+03 |
# |  AverageTestEpRet |        6.98e+03 |
# |      StdTestEpRet |              87 |
# |      MaxTestEpRet |        7.12e+03 |
# |      MinTestEpRet |        6.82e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             430 |
# |         StdQ1Vals |            95.2 |
# |         MaxQ1Vals |             554 |
# |         MinQ1Vals |           -16.9 |
# |     AverageQ2Vals |             430 |
# |         StdQ2Vals |            95.2 |
# |         MaxQ2Vals |             554 |
# |         MinQ2Vals |           -31.6 |
# |      AverageLogPi |            3.47 |
# |          StdLogPi |            4.22 |
# |          MaxLogPi |            55.4 |
# |          MinLogPi |           -15.4 |
# |            LossPi |            -430 |
# |             LossQ |            38.2 |
# |              Time |        4.78e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        6.73e+03 |
# |          StdEpRet |             207 |
# |          MaxEpRet |        7.01e+03 |
# |          MinEpRet |        6.45e+03 |
# |  AverageTestEpRet |        7.08e+03 |
# |      StdTestEpRet |             105 |
# |      MaxTestEpRet |        7.24e+03 |
# |      MinTestEpRet |        6.94e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             436 |
# |         StdQ1Vals |            95.6 |
# |         MaxQ1Vals |             561 |
# |         MinQ1Vals |            -146 |
# |     AverageQ2Vals |             436 |
# |         StdQ2Vals |            95.6 |
# |         MaxQ2Vals |             561 |
# |         MinQ2Vals |             -65 |
# |      AverageLogPi |            3.46 |
# |          StdLogPi |            4.16 |
# |          MaxLogPi |            41.4 |
# |          MinLogPi |           -13.7 |
# |            LossPi |            -436 |
# |             LossQ |            36.9 |
# |              Time |        4.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        6.59e+03 |
# |          StdEpRet |            40.3 |
# |          MaxEpRet |        6.64e+03 |
# |          MinEpRet |        6.54e+03 |
# |  AverageTestEpRet |        7.71e+03 |
# |      StdTestEpRet |             146 |
# |      MaxTestEpRet |         7.9e+03 |
# |      MinTestEpRet |        7.48e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             441 |
# |         StdQ1Vals |            96.8 |
# |         MaxQ1Vals |             565 |
# |         MinQ1Vals |           -17.7 |
# |     AverageQ2Vals |             441 |
# |         StdQ2Vals |            96.8 |
# |         MaxQ2Vals |             563 |
# |         MinQ2Vals |           -25.4 |
# |      AverageLogPi |            3.52 |
# |          StdLogPi |            4.19 |
# |          MaxLogPi |            55.6 |
# |          MinLogPi |           -12.2 |
# |            LossPi |            -441 |
# |             LossQ |            36.6 |
# |              Time |        4.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        6.68e+03 |
# |          StdEpRet |             166 |
# |          MaxEpRet |        6.88e+03 |
# |          MinEpRet |        6.46e+03 |
# |  AverageTestEpRet |        6.91e+03 |
# |      StdTestEpRet |            75.2 |
# |      MaxTestEpRet |        7.06e+03 |
# |      MinTestEpRet |         6.8e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             446 |
# |         StdQ1Vals |            97.8 |
# |         MaxQ1Vals |             570 |
# |         MinQ1Vals |           -17.8 |
# |     AverageQ2Vals |             446 |
# |         StdQ2Vals |            97.8 |
# |         MaxQ2Vals |             570 |
# |         MinQ2Vals |           -19.4 |
# |      AverageLogPi |             3.6 |
# |          StdLogPi |            4.19 |
# |          MaxLogPi |            51.1 |
# |          MinLogPi |           -14.1 |
# |            LossPi |            -446 |
# |             LossQ |            38.9 |
# |              Time |        5.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        6.28e+03 |
# |          StdEpRet |        1.05e+03 |
# |          MaxEpRet |        7.01e+03 |
# |          MinEpRet |        4.46e+03 |
# |  AverageTestEpRet |        7.31e+03 |
# |      StdTestEpRet |            75.8 |
# |      MaxTestEpRet |        7.43e+03 |
# |      MinTestEpRet |        7.19e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             452 |
# |         StdQ1Vals |            98.2 |
# |         MaxQ1Vals |             579 |
# |         MinQ1Vals |           -20.5 |
# |     AverageQ2Vals |             452 |
# |         StdQ2Vals |            98.2 |
# |         MaxQ2Vals |             579 |
# |         MinQ2Vals |           -30.6 |
# |      AverageLogPi |            3.64 |
# |          StdLogPi |             4.2 |
# |          MaxLogPi |              51 |
# |          MinLogPi |             -12 |
# |            LossPi |            -452 |
# |             LossQ |            40.7 |
# |              Time |        5.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        6.82e+03 |
# |          StdEpRet |             147 |
# |          MaxEpRet |        6.95e+03 |
# |          MinEpRet |        6.59e+03 |
# |  AverageTestEpRet |         7.4e+03 |
# |      StdTestEpRet |            96.9 |
# |      MaxTestEpRet |        7.51e+03 |
# |      MinTestEpRet |        7.24e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             456 |
# |         StdQ1Vals |            99.8 |
# |         MaxQ1Vals |             583 |
# |         MinQ1Vals |           -42.4 |
# |     AverageQ2Vals |             456 |
# |         StdQ2Vals |            99.8 |
# |         MaxQ2Vals |             584 |
# |         MinQ2Vals |           -53.9 |
# |      AverageLogPi |            3.71 |
# |          StdLogPi |             4.2 |
# |          MaxLogPi |            49.1 |
# |          MinLogPi |           -13.7 |
# |            LossPi |            -456 |
# |             LossQ |            44.1 |
# |              Time |        5.26e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetahMuJoCoEnv-v0', 'hid': 128, 'l': 2, 
        'gamma': 0.99, 'seed':5, 'epochs':50, 
        'partially_observable': True,
        'exp_name': 'sac_POMDP_HalfCheetahMuJoCoEnv_2L128'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

torch.set_num_threads(torch.get_num_threads())

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
    gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    partially_observable=args['partially_observable'],
    logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             128,
#             128
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"HalfCheetahMuJoCoEnv-v0",
#     "epochs":	50,
#     "exp_name":	"sac_POMDP_HalfCheetahMuJoCoEnv_2L128",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001D4DE364E88>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_POMDP_HalfCheetahMuJoCoEnv_2L128",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\\\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_POMDP_HalfCheetahMuJoCoEnv_2L128",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5"
#     },
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	5,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
# current_dir=c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\pybullet_envs\bullet
# WalkerBase::__init__
# WalkerBase::__init__
#
# Number of parameters: 	 pi: 19212, 	 q1: 18561, 	 q2: 18561
#
# options=
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -223 |
# |          StdEpRet |            51.8 |
# |          MaxEpRet |            -159 |
# |          MinEpRet |            -303 |
# |  AverageTestEpRet |           -33.1 |
# |      StdTestEpRet |              31 |
# |      MaxTestEpRet |           -2.44 |
# |      MinTestEpRet |           -88.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |             4.5 |
# |         StdQ1Vals |             2.7 |
# |         MaxQ1Vals |            21.1 |
# |         MinQ1Vals |          -0.415 |
# |     AverageQ2Vals |             4.5 |
# |         StdQ2Vals |             2.7 |
# |         MaxQ2Vals |            20.6 |
# |         MinQ2Vals |          -0.162 |
# |      AverageLogPi |           -3.39 |
# |          StdLogPi |            1.34 |
# |          MaxLogPi |            7.92 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -5.32 |
# |             LossQ |           0.582 |
# |              Time |            84.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -246 |
# |          StdEpRet |            29.3 |
# |          MaxEpRet |            -203 |
# |          MinEpRet |            -285 |
# |  AverageTestEpRet |            -177 |
# |      StdTestEpRet |             124 |
# |      MaxTestEpRet |              11 |
# |      MinTestEpRet |            -420 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            15.3 |
# |         StdQ1Vals |            6.07 |
# |         MaxQ1Vals |            47.4 |
# |         MinQ1Vals |            1.74 |
# |     AverageQ2Vals |            15.3 |
# |         StdQ2Vals |            6.07 |
# |         MaxQ2Vals |              46 |
# |         MinQ2Vals |            1.53 |
# |      AverageLogPi |           -2.29 |
# |          StdLogPi |            1.95 |
# |          MaxLogPi |            9.26 |
# |          MinLogPi |           -14.6 |
# |            LossPi |           -16.2 |
# |             LossQ |            1.56 |
# |              Time |             198 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -215 |
# |          StdEpRet |            31.5 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -257 |
# |  AverageTestEpRet |            -114 |
# |      StdTestEpRet |            46.6 |
# |      MaxTestEpRet |           -46.5 |
# |      MinTestEpRet |            -232 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            28.3 |
# |         StdQ1Vals |            8.57 |
# |         MaxQ1Vals |            91.9 |
# |         MinQ1Vals |            8.89 |
# |     AverageQ2Vals |            28.3 |
# |         StdQ2Vals |            8.58 |
# |         MaxQ2Vals |            89.5 |
# |         MinQ2Vals |            8.34 |
# |      AverageLogPi |           -1.57 |
# |          StdLogPi |            2.34 |
# |          MaxLogPi |            15.1 |
# |          MinLogPi |           -13.7 |
# |            LossPi |           -29.3 |
# |             LossQ |            2.69 |
# |              Time |             317 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -183 |
# |          StdEpRet |            32.5 |
# |          MaxEpRet |            -162 |
# |          MinEpRet |            -239 |
# |  AverageTestEpRet |           -27.3 |
# |      StdTestEpRet |            2.44 |
# |      MaxTestEpRet |           -24.4 |
# |      MinTestEpRet |           -33.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            39.7 |
# |         StdQ1Vals |            11.4 |
# |         MaxQ1Vals |            84.3 |
# |         MinQ1Vals |            19.3 |
# |     AverageQ2Vals |            39.7 |
# |         StdQ2Vals |            11.4 |
# |         MaxQ2Vals |            85.6 |
# |         MinQ2Vals |              19 |
# |      AverageLogPi |           -2.43 |
# |          StdLogPi |               2 |
# |          MaxLogPi |            13.5 |
# |          MinLogPi |           -11.8 |
# |            LossPi |           -40.5 |
# |             LossQ |            2.06 |
# |              Time |             439 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -170 |
# |          StdEpRet |            18.8 |
# |          MaxEpRet |            -145 |
# |          MinEpRet |            -191 |
# |  AverageTestEpRet |           -30.7 |
# |      StdTestEpRet |            21.8 |
# |      MaxTestEpRet |           -1.35 |
# |      MinTestEpRet |           -73.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            44.6 |
# |         StdQ1Vals |            9.44 |
# |         MaxQ1Vals |            75.7 |
# |         MinQ1Vals |            15.8 |
# |     AverageQ2Vals |            44.6 |
# |         StdQ2Vals |            9.44 |
# |         MaxQ2Vals |            75.1 |
# |         MinQ2Vals |            15.1 |
# |      AverageLogPi |           -3.13 |
# |          StdLogPi |            1.45 |
# |          MaxLogPi |            10.7 |
# |          MinLogPi |           -14.8 |
# |            LossPi |           -45.3 |
# |             LossQ |            1.22 |
# |              Time |             554 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -142 |
# |          StdEpRet |            30.6 |
# |          MaxEpRet |            -117 |
# |          MinEpRet |            -193 |
# |  AverageTestEpRet |            4.93 |
# |      StdTestEpRet |            7.69 |
# |      MaxTestEpRet |            15.8 |
# |      MinTestEpRet |           -8.49 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            46.4 |
# |         StdQ1Vals |             7.4 |
# |         MaxQ1Vals |            68.4 |
# |         MinQ1Vals |            18.1 |
# |     AverageQ2Vals |            46.4 |
# |         StdQ2Vals |             7.4 |
# |         MaxQ2Vals |            68.6 |
# |         MinQ2Vals |            18.3 |
# |      AverageLogPi |           -3.52 |
# |          StdLogPi |            1.07 |
# |          MaxLogPi |            9.68 |
# |          MinLogPi |           -12.1 |
# |            LossPi |             -47 |
# |             LossQ |           0.848 |
# |              Time |             680 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -148 |
# |          StdEpRet |            82.8 |
# |          MaxEpRet |           -76.5 |
# |          MinEpRet |            -289 |
# |  AverageTestEpRet |           -2.72 |
# |      StdTestEpRet |            10.7 |
# |      MaxTestEpRet |            9.25 |
# |      MinTestEpRet |           -25.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            45.8 |
# |         StdQ1Vals |            7.35 |
# |         MaxQ1Vals |            63.2 |
# |         MinQ1Vals |            6.79 |
# |     AverageQ2Vals |            45.8 |
# |         StdQ2Vals |            7.35 |
# |         MaxQ2Vals |            63.7 |
# |         MinQ2Vals |               7 |
# |      AverageLogPi |           -3.65 |
# |          StdLogPi |            0.94 |
# |          MaxLogPi |            8.71 |
# |          MinLogPi |           -11.5 |
# |            LossPi |           -46.5 |
# |             LossQ |           0.743 |
# |              Time |             805 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |            27.3 |
# |          MaxEpRet |           -91.9 |
# |          MinEpRet |            -163 |
# |  AverageTestEpRet |             3.9 |
# |      StdTestEpRet |            5.11 |
# |      MaxTestEpRet |              12 |
# |      MinTestEpRet |           -7.05 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            46.1 |
# |         StdQ1Vals |            7.02 |
# |         MaxQ1Vals |            61.8 |
# |         MinQ1Vals |            9.97 |
# |     AverageQ2Vals |            46.1 |
# |         StdQ2Vals |            7.02 |
# |         MaxQ2Vals |            61.1 |
# |         MinQ2Vals |            10.4 |
# |      AverageLogPi |           -3.73 |
# |          StdLogPi |           0.862 |
# |          MaxLogPi |            4.15 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -46.8 |
# |             LossQ |           0.658 |
# |              Time |             931 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |           -83.1 |
# |          StdEpRet |            33.5 |
# |          MaxEpRet |           -47.8 |
# |          MinEpRet |            -122 |
# |  AverageTestEpRet |            7.74 |
# |      StdTestEpRet |             7.1 |
# |      MaxTestEpRet |            25.1 |
# |      MinTestEpRet |           -3.07 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            47.4 |
# |         StdQ1Vals |            6.02 |
# |         MaxQ1Vals |            63.5 |
# |         MinQ1Vals |            10.9 |
# |     AverageQ2Vals |            47.4 |
# |         StdQ2Vals |            6.02 |
# |         MaxQ2Vals |            62.4 |
# |         MinQ2Vals |            12.1 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.851 |
# |          MaxLogPi |            5.43 |
# |          MinLogPi |           -11.8 |
# |            LossPi |           -48.1 |
# |             LossQ |           0.641 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |            32.3 |
# |          MaxEpRet |           -68.9 |
# |          MinEpRet |            -158 |
# |  AverageTestEpRet |           -1.18 |
# |      StdTestEpRet |            41.2 |
# |      MaxTestEpRet |              25 |
# |      MinTestEpRet |            -121 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |              49 |
# |         StdQ1Vals |            5.38 |
# |         MaxQ1Vals |            63.8 |
# |         MinQ1Vals |              15 |
# |     AverageQ2Vals |              49 |
# |         StdQ2Vals |            5.39 |
# |         MaxQ2Vals |            62.8 |
# |         MinQ2Vals |            14.5 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.866 |
# |          MaxLogPi |            4.93 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -49.7 |
# |             LossQ |           0.656 |
# |              Time |        1.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -118 |
# |          StdEpRet |            20.2 |
# |          MaxEpRet |           -97.1 |
# |          MinEpRet |            -149 |
# |  AverageTestEpRet |           -3.96 |
# |      StdTestEpRet |            17.6 |
# |      MaxTestEpRet |            8.99 |
# |      MinTestEpRet |           -38.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            50.5 |
# |         StdQ1Vals |            4.89 |
# |         MaxQ1Vals |            64.6 |
# |         MinQ1Vals |            16.2 |
# |     AverageQ2Vals |            50.5 |
# |         StdQ2Vals |            4.89 |
# |         MaxQ2Vals |            64.1 |
# |         MinQ2Vals |              16 |
# |      AverageLogPi |           -3.74 |
# |          StdLogPi |           0.895 |
# |          MaxLogPi |            5.07 |
# |          MinLogPi |           -12.4 |
# |            LossPi |           -51.2 |
# |             LossQ |           0.684 |
# |              Time |         1.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -122 |
# |          StdEpRet |            13.1 |
# |          MaxEpRet |            -103 |
# |          MinEpRet |            -139 |
# |  AverageTestEpRet |            4.72 |
# |      StdTestEpRet |             7.6 |
# |      MaxTestEpRet |            15.1 |
# |      MinTestEpRet |           -11.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |              52 |
# |         StdQ1Vals |            4.66 |
# |         MaxQ1Vals |            69.6 |
# |         MinQ1Vals |            18.8 |
# |     AverageQ2Vals |              52 |
# |         StdQ2Vals |            4.66 |
# |         MaxQ2Vals |            66.2 |
# |         MinQ2Vals |            18.4 |
# |      AverageLogPi |           -3.74 |
# |          StdLogPi |           0.899 |
# |          MaxLogPi |            5.38 |
# |          MinLogPi |           -11.8 |
# |            LossPi |           -52.7 |
# |             LossQ |           0.678 |
# |              Time |        1.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -108 |
# |          StdEpRet |              25 |
# |          MaxEpRet |           -82.1 |
# |          MinEpRet |            -136 |
# |  AverageTestEpRet |            10.1 |
# |      StdTestEpRet |            3.37 |
# |      MaxTestEpRet |            15.9 |
# |      MinTestEpRet |            5.61 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            53.3 |
# |         StdQ1Vals |            4.48 |
# |         MaxQ1Vals |            66.6 |
# |         MinQ1Vals |            19.6 |
# |     AverageQ2Vals |            53.3 |
# |         StdQ2Vals |            4.48 |
# |         MaxQ2Vals |            65.5 |
# |         MinQ2Vals |            19.4 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.891 |
# |          MaxLogPi |            4.45 |
# |          MinLogPi |           -11.6 |
# |            LossPi |           -54.1 |
# |             LossQ |           0.677 |
# |              Time |        1.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           -99.3 |
# |          StdEpRet |            7.05 |
# |          MaxEpRet |           -90.3 |
# |          MinEpRet |            -108 |
# |  AverageTestEpRet |            5.34 |
# |      StdTestEpRet |            12.1 |
# |      MaxTestEpRet |              40 |
# |      MinTestEpRet |           -4.48 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            54.6 |
# |         StdQ1Vals |            4.44 |
# |         MaxQ1Vals |            73.1 |
# |         MinQ1Vals |            21.6 |
# |     AverageQ2Vals |            54.6 |
# |         StdQ2Vals |            4.44 |
# |         MaxQ2Vals |            72.3 |
# |         MinQ2Vals |            21.3 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |           0.908 |
# |          MaxLogPi |            10.3 |
# |          MinLogPi |           -11.8 |
# |            LossPi |           -55.3 |
# |             LossQ |           0.678 |
# |              Time |        1.67e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -106 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |             -68 |
# |          MinEpRet |            -141 |
# |  AverageTestEpRet |           -6.58 |
# |      StdTestEpRet |            42.2 |
# |      MaxTestEpRet |            9.88 |
# |      MinTestEpRet |            -133 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            55.7 |
# |         StdQ1Vals |            4.43 |
# |         MaxQ1Vals |            68.4 |
# |         MinQ1Vals |            22.6 |
# |     AverageQ2Vals |            55.7 |
# |         StdQ2Vals |            4.43 |
# |         MaxQ2Vals |            67.8 |
# |         MinQ2Vals |            22.2 |
# |      AverageLogPi |           -3.75 |
# |          StdLogPi |            0.91 |
# |          MaxLogPi |            4.94 |
# |          MinLogPi |           -11.1 |
# |            LossPi |           -56.4 |
# |             LossQ |           0.684 |
# |              Time |        1.79e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            10.1 |
# |          MaxEpRet |           -88.6 |
# |          MinEpRet |            -116 |
# |  AverageTestEpRet |            17.5 |
# |      StdTestEpRet |            4.99 |
# |      MaxTestEpRet |            24.2 |
# |      MinTestEpRet |            8.93 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            56.7 |
# |         StdQ1Vals |            4.42 |
# |         MaxQ1Vals |            71.5 |
# |         MinQ1Vals |            21.9 |
# |     AverageQ2Vals |            56.7 |
# |         StdQ2Vals |            4.42 |
# |         MaxQ2Vals |            70.8 |
# |         MinQ2Vals |            22.1 |
# |      AverageLogPi |           -3.76 |
# |          StdLogPi |           0.909 |
# |          MaxLogPi |             4.4 |
# |          MinLogPi |           -13.5 |
# |            LossPi |           -57.4 |
# |             LossQ |           0.671 |
# |              Time |        1.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -100 |
# |          StdEpRet |            27.1 |
# |          MaxEpRet |           -64.5 |
# |          MinEpRet |            -132 |
# |  AverageTestEpRet |            11.1 |
# |      StdTestEpRet |            4.31 |
# |      MaxTestEpRet |            18.1 |
# |      MinTestEpRet |            2.66 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            57.5 |
# |         StdQ1Vals |            4.39 |
# |         MaxQ1Vals |            81.7 |
# |         MinQ1Vals |            22.6 |
# |     AverageQ2Vals |            57.5 |
# |         StdQ2Vals |            4.39 |
# |         MaxQ2Vals |              82 |
# |         MinQ2Vals |              22 |
# |      AverageLogPi |           -3.79 |
# |          StdLogPi |           0.873 |
# |          MaxLogPi |            6.87 |
# |          MinLogPi |             -12 |
# |            LossPi |           -58.2 |
# |             LossQ |           0.634 |
# |              Time |        2.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |           -80.7 |
# |          MinEpRet |            -148 |
# |  AverageTestEpRet |            9.76 |
# |      StdTestEpRet |            2.12 |
# |      MaxTestEpRet |            12.3 |
# |      MinTestEpRet |            5.14 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            58.3 |
# |         StdQ1Vals |            4.34 |
# |         MaxQ1Vals |            88.1 |
# |         MinQ1Vals |            23.5 |
# |     AverageQ2Vals |            58.3 |
# |         StdQ2Vals |            4.34 |
# |         MaxQ2Vals |            87.3 |
# |         MinQ2Vals |            22.9 |
# |      AverageLogPi |           -3.79 |
# |          StdLogPi |           0.874 |
# |          MaxLogPi |            5.25 |
# |          MinLogPi |           -12.7 |
# |            LossPi |             -59 |
# |             LossQ |           0.603 |
# |              Time |        2.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |           -75.8 |
# |          StdEpRet |            9.54 |
# |          MaxEpRet |           -61.2 |
# |          MinEpRet |             -86 |
# |  AverageTestEpRet |            21.3 |
# |      StdTestEpRet |            3.23 |
# |      MaxTestEpRet |            26.7 |
# |      MinTestEpRet |            14.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            58.9 |
# |         StdQ1Vals |            4.33 |
# |         MaxQ1Vals |            87.5 |
# |         MinQ1Vals |            24.4 |
# |     AverageQ2Vals |            58.9 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |            91.5 |
# |         MinQ2Vals |            24.3 |
# |      AverageLogPi |            -3.8 |
# |          StdLogPi |            0.86 |
# |          MaxLogPi |            4.25 |
# |          MinLogPi |           -11.8 |
# |            LossPi |           -59.6 |
# |             LossQ |           0.582 |
# |              Time |        2.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |           -72.8 |
# |          StdEpRet |            16.9 |
# |          MaxEpRet |             -52 |
# |          MinEpRet |             -98 |
# |  AverageTestEpRet |             9.5 |
# |      StdTestEpRet |            2.98 |
# |      MaxTestEpRet |            14.2 |
# |      MinTestEpRet |            5.49 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            59.5 |
# |         StdQ1Vals |            4.33 |
# |         MaxQ1Vals |            89.7 |
# |         MinQ1Vals |            25.1 |
# |     AverageQ2Vals |            59.5 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |            86.5 |
# |         MinQ2Vals |            24.6 |
# |      AverageLogPi |           -3.81 |
# |          StdLogPi |           0.843 |
# |          MaxLogPi |            5.78 |
# |          MinLogPi |           -10.9 |
# |            LossPi |           -60.2 |
# |             LossQ |           0.556 |
# |              Time |        2.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |           -83.7 |
# |          StdEpRet |            22.8 |
# |          MaxEpRet |           -51.7 |
# |          MinEpRet |            -114 |
# |  AverageTestEpRet |            20.7 |
# |      StdTestEpRet |            6.43 |
# |      MaxTestEpRet |            35.2 |
# |      MinTestEpRet |            10.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |              60 |
# |         StdQ1Vals |            4.31 |
# |         MaxQ1Vals |            91.4 |
# |         MinQ1Vals |            24.7 |
# |     AverageQ2Vals |              60 |
# |         StdQ2Vals |            4.31 |
# |         MaxQ2Vals |            93.9 |
# |         MinQ2Vals |              25 |
# |      AverageLogPi |           -3.81 |
# |          StdLogPi |           0.847 |
# |          MaxLogPi |            6.35 |
# |          MinLogPi |             -11 |
# |            LossPi |           -60.7 |
# |             LossQ |           0.565 |
# |              Time |         2.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           -91.4 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |           -78.8 |
# |          MinEpRet |            -118 |
# |  AverageTestEpRet |            9.08 |
# |      StdTestEpRet |            7.44 |
# |      MaxTestEpRet |            15.8 |
# |      MinTestEpRet |           -12.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            60.4 |
# |         StdQ1Vals |            4.29 |
# |         MaxQ1Vals |            86.5 |
# |         MinQ1Vals |            24.7 |
# |     AverageQ2Vals |            60.4 |
# |         StdQ2Vals |            4.29 |
# |         MaxQ2Vals |            86.1 |
# |         MinQ2Vals |            25.2 |
# |      AverageLogPi |           -3.82 |
# |          StdLogPi |            0.84 |
# |          MaxLogPi |             7.1 |
# |          MinLogPi |           -11.9 |
# |            LossPi |           -61.2 |
# |             LossQ |            0.56 |
# |              Time |        2.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |           -66.1 |
# |          StdEpRet |            19.3 |
# |          MaxEpRet |           -45.3 |
# |          MinEpRet |           -93.4 |
# |  AverageTestEpRet |            10.3 |
# |      StdTestEpRet |            3.39 |
# |      MaxTestEpRet |            15.4 |
# |      MinTestEpRet |            5.17 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            60.9 |
# |         StdQ1Vals |            4.33 |
# |         MaxQ1Vals |            87.5 |
# |         MinQ1Vals |              25 |
# |     AverageQ2Vals |            60.9 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |            91.9 |
# |         MinQ2Vals |              25 |
# |      AverageLogPi |           -3.82 |
# |          StdLogPi |           0.848 |
# |          MaxLogPi |            5.86 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -61.6 |
# |             LossQ |           0.557 |
# |              Time |        2.72e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |           -84.3 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |           -71.1 |
# |          MinEpRet |           -96.9 |
# |  AverageTestEpRet |             -26 |
# |      StdTestEpRet |             112 |
# |      MaxTestEpRet |            14.4 |
# |      MinTestEpRet |            -362 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            61.3 |
# |         StdQ1Vals |            4.36 |
# |         MaxQ1Vals |            98.7 |
# |         MinQ1Vals |            25.8 |
# |     AverageQ2Vals |            61.3 |
# |         StdQ2Vals |            4.36 |
# |         MaxQ2Vals |            96.9 |
# |         MinQ2Vals |            25.7 |
# |      AverageLogPi |           -3.82 |
# |          StdLogPi |            0.85 |
# |          MaxLogPi |            6.89 |
# |          MinLogPi |           -10.4 |
# |            LossPi |             -62 |
# |             LossQ |           0.551 |
# |              Time |        2.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |           -51.5 |
# |          StdEpRet |            22.4 |
# |          MaxEpRet |           -20.2 |
# |          MinEpRet |           -82.4 |
# |  AverageTestEpRet |           -7.13 |
# |      StdTestEpRet |            41.7 |
# |      MaxTestEpRet |            18.4 |
# |      MinTestEpRet |            -132 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            61.7 |
# |         StdQ1Vals |            4.37 |
# |         MaxQ1Vals |            90.9 |
# |         MinQ1Vals |            26.2 |
# |     AverageQ2Vals |            61.7 |
# |         StdQ2Vals |            4.37 |
# |         MaxQ2Vals |            93.2 |
# |         MinQ2Vals |            25.4 |
# |      AverageLogPi |           -3.83 |
# |          StdLogPi |           0.833 |
# |          MaxLogPi |            6.01 |
# |          MinLogPi |             -11 |
# |            LossPi |           -62.4 |
# |             LossQ |           0.541 |
# |              Time |        2.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |           -96.8 |
# |          StdEpRet |            30.5 |
# |          MaxEpRet |           -57.8 |
# |          MinEpRet |            -143 |
# |  AverageTestEpRet |            11.4 |
# |      StdTestEpRet |            5.51 |
# |      MaxTestEpRet |            16.1 |
# |      MinTestEpRet |          0.0464 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |              62 |
# |         StdQ1Vals |            4.36 |
# |         MaxQ1Vals |            93.7 |
# |         MinQ1Vals |            26.2 |
# |     AverageQ2Vals |              62 |
# |         StdQ2Vals |            4.36 |
# |         MaxQ2Vals |            94.6 |
# |         MinQ2Vals |            25.4 |
# |      AverageLogPi |           -3.82 |
# |          StdLogPi |           0.856 |
# |          MaxLogPi |            6.99 |
# |          MinLogPi |           -11.2 |
# |            LossPi |           -62.7 |
# |             LossQ |           0.545 |
# |              Time |        3.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |            76.1 |
# |          MaxEpRet |           -44.7 |
# |          MinEpRet |            -238 |
# |  AverageTestEpRet |           -5.18 |
# |      StdTestEpRet |            38.9 |
# |      MaxTestEpRet |            11.9 |
# |      MinTestEpRet |            -122 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            62.2 |
# |         StdQ1Vals |            4.63 |
# |         MaxQ1Vals |            98.9 |
# |         MinQ1Vals |            21.6 |
# |     AverageQ2Vals |            62.2 |
# |         StdQ2Vals |            4.63 |
# |         MaxQ2Vals |             101 |
# |         MinQ2Vals |              22 |
# |      AverageLogPi |           -3.83 |
# |          StdLogPi |           0.837 |
# |          MaxLogPi |            5.35 |
# |          MinLogPi |           -13.2 |
# |            LossPi |             -63 |
# |             LossQ |           0.544 |
# |              Time |        3.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |           -91.3 |
# |          StdEpRet |            71.2 |
# |          MaxEpRet |           -25.7 |
# |          MinEpRet |            -206 |
# |  AverageTestEpRet |            10.1 |
# |      StdTestEpRet |            3.94 |
# |      MaxTestEpRet |            15.5 |
# |      MinTestEpRet |            4.33 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            62.2 |
# |         StdQ1Vals |            5.44 |
# |         MaxQ1Vals |            96.9 |
# |         MinQ1Vals |            21.7 |
# |     AverageQ2Vals |            62.2 |
# |         StdQ2Vals |            5.44 |
# |         MaxQ2Vals |            97.7 |
# |         MinQ2Vals |            22.6 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |           0.808 |
# |          MaxLogPi |            4.96 |
# |          MinLogPi |             -11 |
# |            LossPi |           -62.9 |
# |             LossQ |            0.55 |
# |              Time |        3.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |           -69.4 |
# |          StdEpRet |            18.4 |
# |          MaxEpRet |           -50.9 |
# |          MinEpRet |           -94.9 |
# |  AverageTestEpRet |            13.5 |
# |      StdTestEpRet |             5.3 |
# |      MaxTestEpRet |            22.6 |
# |      MinTestEpRet |            5.58 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            62.3 |
# |         StdQ1Vals |            5.65 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |            18.7 |
# |     AverageQ2Vals |            62.3 |
# |         StdQ2Vals |            5.65 |
# |         MaxQ2Vals |            96.2 |
# |         MinQ2Vals |            18.9 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |            0.82 |
# |          MaxLogPi |            4.86 |
# |          MinLogPi |           -11.1 |
# |            LossPi |           -63.1 |
# |             LossQ |           0.551 |
# |              Time |         3.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -119 |
# |          StdEpRet |            53.5 |
# |          MaxEpRet |           -66.7 |
# |          MinEpRet |            -208 |
# |  AverageTestEpRet |            15.7 |
# |      StdTestEpRet |            2.98 |
# |      MaxTestEpRet |            20.4 |
# |      MinTestEpRet |            10.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            62.5 |
# |         StdQ1Vals |            5.75 |
# |         MaxQ1Vals |            95.6 |
# |         MinQ1Vals |            17.7 |
# |     AverageQ2Vals |            62.5 |
# |         StdQ2Vals |            5.75 |
# |         MaxQ2Vals |            97.8 |
# |         MinQ2Vals |            16.7 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |            0.82 |
# |          MaxLogPi |            4.93 |
# |          MinLogPi |           -11.1 |
# |            LossPi |           -63.2 |
# |             LossQ |           0.567 |
# |              Time |        3.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             -45 |
# |          StdEpRet |            31.7 |
# |          MaxEpRet |           -12.6 |
# |          MinEpRet |           -95.6 |
# |  AverageTestEpRet |            15.4 |
# |      StdTestEpRet |            5.05 |
# |      MaxTestEpRet |            24.7 |
# |      MinTestEpRet |            7.58 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            62.6 |
# |         StdQ1Vals |            5.96 |
# |         MaxQ1Vals |            94.1 |
# |         MinQ1Vals |            16.5 |
# |     AverageQ2Vals |            62.6 |
# |         StdQ2Vals |            5.96 |
# |         MaxQ2Vals |            88.7 |
# |         MinQ2Vals |            15.9 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |           0.821 |
# |          MaxLogPi |             6.3 |
# |          MinLogPi |           -11.9 |
# |            LossPi |           -63.3 |
# |             LossQ |           0.574 |
# |              Time |        3.62e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |           -88.6 |
# |          StdEpRet |            13.6 |
# |          MaxEpRet |           -65.6 |
# |          MinEpRet |            -101 |
# |  AverageTestEpRet |            8.73 |
# |      StdTestEpRet |            3.16 |
# |      MaxTestEpRet |            14.7 |
# |      MinTestEpRet |            2.94 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            62.8 |
# |         StdQ1Vals |            5.85 |
# |         MaxQ1Vals |            89.5 |
# |         MinQ1Vals |            15.5 |
# |     AverageQ2Vals |            62.8 |
# |         StdQ2Vals |            5.85 |
# |         MaxQ2Vals |            92.5 |
# |         MinQ2Vals |            14.7 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.817 |
# |          MaxLogPi |            6.23 |
# |          MinLogPi |           -12.3 |
# |            LossPi |           -63.6 |
# |             LossQ |           0.581 |
# |              Time |        3.73e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |           -85.3 |
# |          StdEpRet |            7.12 |
# |          MaxEpRet |           -79.2 |
# |          MinEpRet |           -96.6 |
# |  AverageTestEpRet |            10.5 |
# |      StdTestEpRet |            3.92 |
# |      MaxTestEpRet |            15.2 |
# |      MinTestEpRet |            1.84 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            63.1 |
# |         StdQ1Vals |            5.75 |
# |         MaxQ1Vals |            91.5 |
# |         MinQ1Vals |            14.1 |
# |     AverageQ2Vals |            63.1 |
# |         StdQ2Vals |            5.75 |
# |         MaxQ2Vals |            90.3 |
# |         MinQ2Vals |            15.4 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |           0.823 |
# |          MaxLogPi |            7.46 |
# |          MinLogPi |           -10.1 |
# |            LossPi |           -63.8 |
# |             LossQ |           0.583 |
# |              Time |        3.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -103 |
# |          StdEpRet |            57.7 |
# |          MaxEpRet |           -42.7 |
# |          MinEpRet |            -197 |
# |  AverageTestEpRet |           -35.7 |
# |      StdTestEpRet |             143 |
# |      MaxTestEpRet |            15.8 |
# |      MinTestEpRet |            -465 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |            63.1 |
# |         StdQ1Vals |            5.83 |
# |         MaxQ1Vals |            94.2 |
# |         MinQ1Vals |              14 |
# |     AverageQ2Vals |            63.1 |
# |         StdQ2Vals |            5.83 |
# |         MaxQ2Vals |            91.7 |
# |         MinQ2Vals |            17.6 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |            0.83 |
# |          MaxLogPi |            5.97 |
# |          MinLogPi |             -12 |
# |            LossPi |           -63.8 |
# |             LossQ |           0.594 |
# |              Time |        3.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |           -63.5 |
# |          StdEpRet |            10.5 |
# |          MaxEpRet |           -50.1 |
# |          MinEpRet |           -76.4 |
# |  AverageTestEpRet |            8.86 |
# |      StdTestEpRet |            2.91 |
# |      MaxTestEpRet |            14.3 |
# |      MinTestEpRet |            4.95 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            63.2 |
# |         StdQ1Vals |            5.87 |
# |         MaxQ1Vals |            89.6 |
# |         MinQ1Vals |              15 |
# |     AverageQ2Vals |            63.2 |
# |         StdQ2Vals |            5.87 |
# |         MaxQ2Vals |            94.5 |
# |         MinQ2Vals |            18.3 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.817 |
# |          MaxLogPi |            6.76 |
# |          MinLogPi |           -11.5 |
# |            LossPi |           -63.9 |
# |             LossQ |           0.598 |
# |              Time |        4.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |           -60.4 |
# |          StdEpRet |            21.9 |
# |          MaxEpRet |           -23.3 |
# |          MinEpRet |           -80.2 |
# |  AverageTestEpRet |            12.6 |
# |      StdTestEpRet |            3.39 |
# |      MaxTestEpRet |            19.1 |
# |      MinTestEpRet |            6.79 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |            63.3 |
# |         StdQ1Vals |            5.74 |
# |         MaxQ1Vals |            93.5 |
# |         MinQ1Vals |            19.2 |
# |     AverageQ2Vals |            63.3 |
# |         StdQ2Vals |            5.74 |
# |         MaxQ2Vals |            96.2 |
# |         MinQ2Vals |            19.5 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |           0.824 |
# |          MaxLogPi |            6.76 |
# |          MinLogPi |           -10.3 |
# |            LossPi |             -64 |
# |             LossQ |           0.583 |
# |              Time |        4.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |           -75.4 |
# |          StdEpRet |            17.6 |
# |          MaxEpRet |           -45.5 |
# |          MinEpRet |           -89.9 |
# |  AverageTestEpRet |           -14.7 |
# |      StdTestEpRet |            88.8 |
# |      MaxTestEpRet |            26.6 |
# |      MinTestEpRet |            -279 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            63.5 |
# |         StdQ1Vals |            5.62 |
# |         MaxQ1Vals |            90.1 |
# |         MinQ1Vals |            20.9 |
# |     AverageQ2Vals |            63.5 |
# |         StdQ2Vals |            5.62 |
# |         MaxQ2Vals |            90.6 |
# |         MinQ2Vals |            23.7 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |           0.819 |
# |          MaxLogPi |              10 |
# |          MinLogPi |           -11.6 |
# |            LossPi |           -64.2 |
# |             LossQ |           0.589 |
# |              Time |        4.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |           -70.6 |
# |          StdEpRet |            37.3 |
# |          MaxEpRet |           -11.1 |
# |          MinEpRet |            -113 |
# |  AverageTestEpRet |            9.51 |
# |      StdTestEpRet |            3.86 |
# |      MaxTestEpRet |            15.5 |
# |      MinTestEpRet |            2.22 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |            63.6 |
# |         StdQ1Vals |            5.52 |
# |         MaxQ1Vals |            99.5 |
# |         MinQ1Vals |            23.1 |
# |     AverageQ2Vals |            63.6 |
# |         StdQ2Vals |            5.52 |
# |         MaxQ2Vals |             100 |
# |         MinQ2Vals |            24.6 |
# |      AverageLogPi |           -3.84 |
# |          StdLogPi |           0.824 |
# |          MaxLogPi |            7.12 |
# |          MinLogPi |           -11.2 |
# |            LossPi |           -64.3 |
# |             LossQ |           0.586 |
# |              Time |        4.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |           -46.7 |
# |          StdEpRet |            5.46 |
# |          MaxEpRet |             -38 |
# |          MinEpRet |             -53 |
# |  AverageTestEpRet |           -1.76 |
# |      StdTestEpRet |            39.2 |
# |      MaxTestEpRet |            14.1 |
# |      MinTestEpRet |            -119 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |            63.7 |
# |         StdQ1Vals |            5.43 |
# |         MaxQ1Vals |            98.7 |
# |         MinQ1Vals |            24.7 |
# |     AverageQ2Vals |            63.7 |
# |         StdQ2Vals |            5.43 |
# |         MaxQ2Vals |             100 |
# |         MinQ2Vals |            24.8 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.814 |
# |          MaxLogPi |            7.99 |
# |          MinLogPi |           -12.2 |
# |            LossPi |           -64.5 |
# |             LossQ |           0.586 |
# |              Time |        4.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |           -51.6 |
# |          StdEpRet |            18.7 |
# |          MaxEpRet |           -20.9 |
# |          MinEpRet |             -68 |
# |  AverageTestEpRet |            15.4 |
# |      StdTestEpRet |            2.12 |
# |      MaxTestEpRet |            20.2 |
# |      MinTestEpRet |            12.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |            63.9 |
# |         StdQ1Vals |            5.33 |
# |         MaxQ1Vals |            98.5 |
# |         MinQ1Vals |            21.1 |
# |     AverageQ2Vals |            63.9 |
# |         StdQ2Vals |            5.33 |
# |         MaxQ2Vals |            98.2 |
# |         MinQ2Vals |            20.6 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.807 |
# |          MaxLogPi |            6.27 |
# |          MinLogPi |           -10.6 |
# |            LossPi |           -64.6 |
# |             LossQ |           0.582 |
# |              Time |         4.6e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -131 |
# |          StdEpRet |             124 |
# |          MaxEpRet |             -42 |
# |          MinEpRet |            -345 |
# |  AverageTestEpRet |           -1.46 |
# |      StdTestEpRet |            35.6 |
# |      MaxTestEpRet |            17.4 |
# |      MinTestEpRet |            -100 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |            63.8 |
# |         StdQ1Vals |             5.6 |
# |         MaxQ1Vals |             102 |
# |         MinQ1Vals |            4.75 |
# |     AverageQ2Vals |            63.8 |
# |         StdQ2Vals |             5.6 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |            7.83 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.811 |
# |          MaxLogPi |            7.39 |
# |          MinLogPi |           -13.5 |
# |            LossPi |           -64.5 |
# |             LossQ |           0.625 |
# |              Time |        4.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |           -78.8 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |           -49.3 |
# |          MinEpRet |           -93.9 |
# |  AverageTestEpRet |            10.7 |
# |      StdTestEpRet |            4.63 |
# |      MaxTestEpRet |            16.4 |
# |      MinTestEpRet |           -1.29 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |            63.9 |
# |         StdQ1Vals |            5.77 |
# |         MaxQ1Vals |             109 |
# |         MinQ1Vals |            3.68 |
# |     AverageQ2Vals |            63.9 |
# |         StdQ2Vals |            5.77 |
# |         MaxQ2Vals |             106 |
# |         MinQ2Vals |           0.798 |
# |      AverageLogPi |           -3.86 |
# |          StdLogPi |           0.802 |
# |          MaxLogPi |            8.86 |
# |          MinLogPi |           -11.4 |
# |            LossPi |           -64.6 |
# |             LossQ |           0.613 |
# |              Time |        4.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |           -42.9 |
# |          StdEpRet |            38.6 |
# |          MaxEpRet |            12.6 |
# |          MinEpRet |           -85.4 |
# |  AverageTestEpRet |            8.46 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            17.4 |
# |      MinTestEpRet |           -44.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |              64 |
# |         StdQ1Vals |            5.84 |
# |         MaxQ1Vals |             103 |
# |         MinQ1Vals |           -4.18 |
# |     AverageQ2Vals |              64 |
# |         StdQ2Vals |            5.84 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |           -6.78 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.803 |
# |          MaxLogPi |             7.8 |
# |          MinLogPi |             -12 |
# |            LossPi |           -64.7 |
# |             LossQ |             0.6 |
# |              Time |        4.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |           -68.6 |
# |          StdEpRet |            7.36 |
# |          MaxEpRet |           -57.8 |
# |          MinEpRet |           -78.3 |
# |  AverageTestEpRet |            12.2 |
# |      StdTestEpRet |            3.09 |
# |      MaxTestEpRet |            16.1 |
# |      MinTestEpRet |            7.55 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |            64.1 |
# |         StdQ1Vals |            5.86 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |           -3.97 |
# |     AverageQ2Vals |            64.1 |
# |         StdQ2Vals |            5.86 |
# |         MaxQ2Vals |             104 |
# |         MinQ2Vals |           -6.15 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |            0.81 |
# |          MaxLogPi |             6.3 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -64.8 |
# |             LossQ |           0.608 |
# |              Time |        5.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             -61 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |           -43.6 |
# |          MinEpRet |           -76.7 |
# |  AverageTestEpRet |            1.44 |
# |      StdTestEpRet |            28.6 |
# |      MaxTestEpRet |            22.8 |
# |      MinTestEpRet |           -57.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |            64.2 |
# |         StdQ1Vals |            5.84 |
# |         MaxQ1Vals |             101 |
# |         MinQ1Vals |             1.5 |
# |     AverageQ2Vals |            64.2 |
# |         StdQ2Vals |            5.84 |
# |         MaxQ2Vals |             106 |
# |         MinQ2Vals |           0.805 |
# |      AverageLogPi |           -3.86 |
# |          StdLogPi |             0.8 |
# |          MaxLogPi |            8.06 |
# |          MinLogPi |           -10.9 |
# |            LossPi |           -64.9 |
# |             LossQ |           0.596 |
# |              Time |        5.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |           -57.9 |
# |          StdEpRet |            18.3 |
# |          MaxEpRet |             -29 |
# |          MinEpRet |           -79.6 |
# |  AverageTestEpRet |            7.44 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            14.5 |
# |      MinTestEpRet |             -25 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |            64.3 |
# |         StdQ1Vals |            5.85 |
# |         MaxQ1Vals |             106 |
# |         MinQ1Vals |           0.763 |
# |     AverageQ2Vals |            64.3 |
# |         StdQ2Vals |            5.85 |
# |         MaxQ2Vals |             105 |
# |         MinQ2Vals |          -0.513 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.806 |
# |          MaxLogPi |            7.98 |
# |          MinLogPi |             -12 |
# |            LossPi |             -65 |
# |             LossQ |           0.614 |
# |              Time |        5.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |           -74.6 |
# |          StdEpRet |            15.2 |
# |          MaxEpRet |           -49.5 |
# |          MinEpRet |           -90.4 |
# |  AverageTestEpRet |             6.4 |
# |      StdTestEpRet |            16.6 |
# |      MaxTestEpRet |            17.4 |
# |      MinTestEpRet |           -42.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |            64.4 |
# |         StdQ1Vals |            5.84 |
# |         MaxQ1Vals |             105 |
# |         MinQ1Vals |             2.8 |
# |     AverageQ2Vals |            64.4 |
# |         StdQ2Vals |            5.84 |
# |         MaxQ2Vals |             104 |
# |         MinQ2Vals |             2.7 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.811 |
# |          MaxLogPi |            9.19 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -65.1 |
# |             LossQ |           0.604 |
# |              Time |        5.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |           -60.9 |
# |          StdEpRet |            6.48 |
# |          MaxEpRet |           -51.6 |
# |          MinEpRet |           -68.8 |
# |  AverageTestEpRet |            14.7 |
# |      StdTestEpRet |            3.23 |
# |      MaxTestEpRet |            19.3 |
# |      MinTestEpRet |            9.43 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |            64.5 |
# |         StdQ1Vals |             5.8 |
# |         MaxQ1Vals |             105 |
# |         MinQ1Vals |            0.69 |
# |     AverageQ2Vals |            64.5 |
# |         StdQ2Vals |             5.8 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |            2.73 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |            0.81 |
# |          MaxLogPi |            9.59 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -65.2 |
# |             LossQ |           0.604 |
# |              Time |         5.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |           -42.1 |
# |          StdEpRet |            13.9 |
# |          MaxEpRet |             -21 |
# |          MinEpRet |           -59.8 |
# |  AverageTestEpRet |           -4.84 |
# |      StdTestEpRet |            29.5 |
# |      MaxTestEpRet |            19.9 |
# |      MinTestEpRet |           -60.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |            64.6 |
# |         StdQ1Vals |            5.72 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |            4.35 |
# |     AverageQ2Vals |            64.6 |
# |         StdQ2Vals |            5.72 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |            4.11 |
# |      AverageLogPi |           -3.86 |
# |          StdLogPi |           0.809 |
# |          MaxLogPi |            8.43 |
# |          MinLogPi |           -12.3 |
# |            LossPi |           -65.3 |
# |             LossQ |           0.596 |
# |              Time |        5.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |           -68.9 |
# |          StdEpRet |              26 |
# |          MaxEpRet |             -32 |
# |          MinEpRet |           -98.5 |
# |  AverageTestEpRet |            12.3 |
# |      StdTestEpRet |            5.75 |
# |      MaxTestEpRet |            19.5 |
# |      MinTestEpRet |           -1.93 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |            64.6 |
# |         StdQ1Vals |            5.68 |
# |         MaxQ1Vals |            97.6 |
# |         MinQ1Vals |          -0.163 |
# |     AverageQ2Vals |            64.6 |
# |         StdQ2Vals |            5.68 |
# |         MaxQ2Vals |            94.2 |
# |         MinQ2Vals |            2.33 |
# |      AverageLogPi |           -3.85 |
# |          StdLogPi |           0.816 |
# |          MaxLogPi |            9.04 |
# |          MinLogPi |           -10.9 |
# |            LossPi |           -65.4 |
# |             LossQ |           0.601 |
# |              Time |        5.72e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetahMuJoCoEnv-v0', 'hid': 128, 'l': 2, 
        'gamma': 0.99, 'seed':5, 'epochs':50, 
        'partially_observable': False,
        'exp_name': 'sac_POMDP_HalfCheetahMuJoCoEnv_2L128'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

torch.set_num_threads(torch.get_num_threads())

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
    gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    partially_observable=args['partially_observable'],
    logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             128,
#             128
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"HalfCheetahMuJoCoEnv-v0",
#     "epochs":	50,
#     "exp_name":	"sac_POMDP_HalfCheetahMuJoCoEnv_2L128",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001D4A81462C8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_POMDP_HalfCheetahMuJoCoEnv_2L128",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\\\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_POMDP_HalfCheetahMuJoCoEnv_2L128",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128\\sac_POMDP_HalfCheetahMuJoCoEnv_2L128_s5"
#     },
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "partially_observable":	false,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	5,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
#
# Number of parameters: 	 pi: 20364, 	 q1: 19713, 	 q2: 19713
#
# options=
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -227 |
# |          StdEpRet |            29.4 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -259 |
# |  AverageTestEpRet |            -397 |
# |      StdTestEpRet |               6 |
# |      MaxTestEpRet |            -387 |
# |      MinTestEpRet |            -406 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            11.8 |
# |         StdQ1Vals |             9.4 |
# |         MaxQ1Vals |            45.1 |
# |         MinQ1Vals |           -4.03 |
# |     AverageQ2Vals |            11.8 |
# |         StdQ2Vals |             9.4 |
# |         MaxQ2Vals |            47.4 |
# |         MinQ2Vals |            -4.4 |
# |      AverageLogPi |          0.0972 |
# |          StdLogPi |            2.82 |
# |          MaxLogPi |            13.3 |
# |          MinLogPi |           -13.3 |
# |            LossPi |           -14.1 |
# |             LossQ |            1.14 |
# |              Time |            86.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -236 |
# |          StdEpRet |            16.9 |
# |          MaxEpRet |            -217 |
# |          MinEpRet |            -257 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |            44.5 |
# |      MaxTestEpRet |            -176 |
# |      MinTestEpRet |            -341 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            41.7 |
# |         StdQ1Vals |            9.37 |
# |         MaxQ1Vals |            78.2 |
# |         MinQ1Vals |            8.63 |
# |     AverageQ2Vals |            41.7 |
# |         StdQ2Vals |            9.37 |
# |         MaxQ2Vals |            77.6 |
# |         MinQ2Vals |            8.84 |
# |      AverageLogPi |           0.379 |
# |          StdLogPi |            2.64 |
# |          MaxLogPi |            15.3 |
# |          MinLogPi |           -16.6 |
# |            LossPi |           -43.8 |
# |             LossQ |            2.81 |
# |              Time |             195 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            35.4 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |            -253 |
# |  AverageTestEpRet |            -429 |
# |      StdTestEpRet |            24.3 |
# |      MaxTestEpRet |            -395 |
# |      MinTestEpRet |            -487 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            70.1 |
# |         StdQ1Vals |            9.49 |
# |         MaxQ1Vals |             107 |
# |         MinQ1Vals |            28.3 |
# |     AverageQ2Vals |            70.1 |
# |         StdQ2Vals |            9.48 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |            28.4 |
# |      AverageLogPi |           0.186 |
# |          StdLogPi |            2.78 |
# |          MaxLogPi |            20.3 |
# |          MinLogPi |           -12.6 |
# |            LossPi |           -72.1 |
# |             LossQ |            4.34 |
# |              Time |             305 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            39.5 |
# |          MaxEpRet |            -163 |
# |          MinEpRet |            -254 |
# |  AverageTestEpRet |             -90 |
# |      StdTestEpRet |            68.1 |
# |      MaxTestEpRet |           -1.43 |
# |      MinTestEpRet |            -223 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            81.5 |
# |         StdQ1Vals |            7.79 |
# |         MaxQ1Vals |             120 |
# |         MinQ1Vals |            48.3 |
# |     AverageQ2Vals |            81.5 |
# |         StdQ2Vals |            7.79 |
# |         MaxQ2Vals |             121 |
# |         MinQ2Vals |            50.3 |
# |      AverageLogPi |           -1.46 |
# |          StdLogPi |            2.33 |
# |          MaxLogPi |            18.8 |
# |          MinLogPi |           -12.4 |
# |            LossPi |           -82.7 |
# |             LossQ |            3.43 |
# |              Time |             419 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -140 |
# |          StdEpRet |            8.11 |
# |          MaxEpRet |            -130 |
# |          MinEpRet |            -153 |
# |  AverageTestEpRet |           -50.3 |
# |      StdTestEpRet |             108 |
# |      MaxTestEpRet |            3.59 |
# |      MinTestEpRet |            -371 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            80.6 |
# |         StdQ1Vals |            9.42 |
# |         MaxQ1Vals |             110 |
# |         MinQ1Vals |            46.6 |
# |     AverageQ2Vals |            80.6 |
# |         StdQ2Vals |            9.41 |
# |         MaxQ2Vals |             112 |
# |         MinQ2Vals |            47.7 |
# |      AverageLogPi |           -2.67 |
# |          StdLogPi |            1.74 |
# |          MaxLogPi |            13.2 |
# |          MinLogPi |           -14.3 |
# |            LossPi |           -81.4 |
# |             LossQ |            1.82 |
# |              Time |             528 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             -76 |
# |          StdEpRet |            21.3 |
# |          MaxEpRet |           -47.4 |
# |          MinEpRet |           -97.6 |
# |  AverageTestEpRet |           -21.5 |
# |      StdTestEpRet |            80.5 |
# |      MaxTestEpRet |            15.7 |
# |      MinTestEpRet |            -257 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |              75 |
# |         StdQ1Vals |            9.25 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |            40.2 |
# |     AverageQ2Vals |              75 |
# |         StdQ2Vals |            9.25 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |            43.3 |
# |      AverageLogPi |           -3.38 |
# |          StdLogPi |             1.2 |
# |          MaxLogPi |            17.8 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -75.7 |
# |             LossQ |            1.04 |
# |              Time |             636 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            30.8 |
# |          StdEpRet |            72.6 |
# |          MaxEpRet |             145 |
# |          MinEpRet |           -49.4 |
# |  AverageTestEpRet |             282 |
# |      StdTestEpRet |             141 |
# |      MaxTestEpRet |             371 |
# |      MinTestEpRet |           0.282 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            70.7 |
# |         StdQ1Vals |            8.31 |
# |         MaxQ1Vals |             100 |
# |         MinQ1Vals |            42.1 |
# |     AverageQ2Vals |            70.7 |
# |         StdQ2Vals |            8.31 |
# |         MaxQ2Vals |             100 |
# |         MinQ2Vals |            42.4 |
# |      AverageLogPi |           -3.41 |
# |          StdLogPi |            1.16 |
# |          MaxLogPi |            10.8 |
# |          MinLogPi |           -12.1 |
# |            LossPi |           -71.5 |
# |             LossQ |           0.829 |
# |              Time |             744 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             299 |
# |          StdEpRet |            82.9 |
# |          MaxEpRet |             395 |
# |          MinEpRet |             184 |
# |  AverageTestEpRet |             365 |
# |      StdTestEpRet |            15.6 |
# |      MaxTestEpRet |             383 |
# |      MinTestEpRet |             321 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            69.1 |
# |         StdQ1Vals |             7.4 |
# |         MaxQ1Vals |              97 |
# |         MinQ1Vals |            40.5 |
# |     AverageQ2Vals |            69.1 |
# |         StdQ2Vals |             7.4 |
# |         MaxQ2Vals |            99.2 |
# |         MinQ2Vals |            42.2 |
# |      AverageLogPi |            -3.2 |
# |          StdLogPi |            1.29 |
# |          MaxLogPi |            7.41 |
# |          MinLogPi |           -13.5 |
# |            LossPi |           -69.9 |
# |             LossQ |           0.852 |
# |              Time |             863 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             512 |
# |          StdEpRet |            28.5 |
# |          MaxEpRet |             553 |
# |          MinEpRet |             473 |
# |  AverageTestEpRet |             858 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |             880 |
# |      MinTestEpRet |             843 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            70.3 |
# |         StdQ1Vals |            6.48 |
# |         MaxQ1Vals |            95.8 |
# |         MinQ1Vals |            40.8 |
# |     AverageQ2Vals |            70.3 |
# |         StdQ2Vals |            6.48 |
# |         MaxQ2Vals |            95.4 |
# |         MinQ2Vals |            42.5 |
# |      AverageLogPi |           -2.85 |
# |          StdLogPi |            1.45 |
# |          MaxLogPi |            6.86 |
# |          MinLogPi |           -14.5 |
# |            LossPi |           -71.1 |
# |             LossQ |           0.992 |
# |              Time |             972 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             698 |
# |          StdEpRet |            63.9 |
# |          MaxEpRet |             775 |
# |          MinEpRet |             607 |
# |  AverageTestEpRet |        1.36e+03 |
# |      StdTestEpRet |            50.8 |
# |      MaxTestEpRet |        1.41e+03 |
# |      MinTestEpRet |        1.25e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            73.4 |
# |         StdQ1Vals |            6.32 |
# |         MaxQ1Vals |             101 |
# |         MinQ1Vals |            41.2 |
# |     AverageQ2Vals |            73.4 |
# |         StdQ2Vals |            6.32 |
# |         MaxQ2Vals |            96.2 |
# |         MinQ2Vals |            41.3 |
# |      AverageLogPi |           -2.57 |
# |          StdLogPi |            1.55 |
# |          MaxLogPi |            8.75 |
# |          MinLogPi |           -13.3 |
# |            LossPi |           -74.3 |
# |             LossQ |            1.24 |
# |              Time |        1.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             644 |
# |          StdEpRet |             570 |
# |          MaxEpRet |        1.03e+03 |
# |          MinEpRet |            -340 |
# |  AverageTestEpRet |         1.3e+03 |
# |      StdTestEpRet |            24.4 |
# |      MaxTestEpRet |        1.34e+03 |
# |      MinTestEpRet |        1.27e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            78.2 |
# |         StdQ1Vals |            8.53 |
# |         MaxQ1Vals |             156 |
# |         MinQ1Vals |            40.9 |
# |     AverageQ2Vals |            78.2 |
# |         StdQ2Vals |            8.53 |
# |         MaxQ2Vals |             157 |
# |         MinQ2Vals |            40.7 |
# |      AverageLogPi |           -2.29 |
# |          StdLogPi |            1.68 |
# |          MaxLogPi |            8.88 |
# |          MinLogPi |           -13.9 |
# |            LossPi |           -79.1 |
# |             LossQ |             1.6 |
# |              Time |        1.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |        1.06e+03 |
# |          StdEpRet |            23.9 |
# |          MaxEpRet |        1.09e+03 |
# |          MinEpRet |        1.03e+03 |
# |  AverageTestEpRet |        1.38e+03 |
# |      StdTestEpRet |            25.7 |
# |      MaxTestEpRet |        1.41e+03 |
# |      MinTestEpRet |        1.33e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            84.1 |
# |         StdQ1Vals |            9.73 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |            40.2 |
# |     AverageQ2Vals |            84.1 |
# |         StdQ2Vals |            9.74 |
# |         MaxQ2Vals |             146 |
# |         MinQ2Vals |            39.5 |
# |      AverageLogPi |           -2.06 |
# |          StdLogPi |            1.78 |
# |          MaxLogPi |            7.42 |
# |          MinLogPi |           -14.1 |
# |            LossPi |           -84.9 |
# |             LossQ |            1.78 |
# |              Time |         1.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |        1.17e+03 |
# |          StdEpRet |            49.1 |
# |          MaxEpRet |        1.25e+03 |
# |          MinEpRet |        1.11e+03 |
# |  AverageTestEpRet |        1.29e+03 |
# |      StdTestEpRet |            51.5 |
# |      MaxTestEpRet |        1.34e+03 |
# |      MinTestEpRet |        1.18e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            89.8 |
# |         StdQ1Vals |            9.06 |
# |         MaxQ1Vals |             126 |
# |         MinQ1Vals |            41.6 |
# |     AverageQ2Vals |            89.8 |
# |         StdQ2Vals |            9.06 |
# |         MaxQ2Vals |             127 |
# |         MinQ2Vals |            39.5 |
# |      AverageLogPi |           -1.82 |
# |          StdLogPi |            1.87 |
# |          MaxLogPi |              13 |
# |          MinLogPi |           -13.8 |
# |            LossPi |           -90.7 |
# |             LossQ |            1.97 |
# |              Time |        1.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        1.25e+03 |
# |          StdEpRet |              18 |
# |          MaxEpRet |        1.27e+03 |
# |          MinEpRet |        1.22e+03 |
# |  AverageTestEpRet |         1.1e+03 |
# |      StdTestEpRet |             711 |
# |      MaxTestEpRet |         1.5e+03 |
# |      MinTestEpRet |            -324 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            95.8 |
# |         StdQ1Vals |            9.53 |
# |         MaxQ1Vals |             128 |
# |         MinQ1Vals |            36.9 |
# |     AverageQ2Vals |            95.8 |
# |         StdQ2Vals |            9.53 |
# |         MaxQ2Vals |             127 |
# |         MinQ2Vals |            37.3 |
# |      AverageLogPi |           -1.66 |
# |          StdLogPi |            1.93 |
# |          MaxLogPi |            10.8 |
# |          MinLogPi |           -14.3 |
# |            LossPi |           -96.6 |
# |             LossQ |             2.2 |
# |              Time |        1.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        1.28e+03 |
# |          StdEpRet |            38.1 |
# |          MaxEpRet |        1.33e+03 |
# |          MinEpRet |        1.23e+03 |
# |  AverageTestEpRet |        1.66e+03 |
# |      StdTestEpRet |            14.7 |
# |      MaxTestEpRet |        1.69e+03 |
# |      MinTestEpRet |        1.64e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             101 |
# |         StdQ1Vals |            10.4 |
# |         MaxQ1Vals |             130 |
# |         MinQ1Vals |            36.8 |
# |     AverageQ2Vals |             101 |
# |         StdQ2Vals |            10.4 |
# |         MaxQ2Vals |             130 |
# |         MinQ2Vals |            37.3 |
# |      AverageLogPi |           -1.54 |
# |          StdLogPi |            1.98 |
# |          MaxLogPi |            8.18 |
# |          MinLogPi |           -13.4 |
# |            LossPi |            -102 |
# |             LossQ |            2.32 |
# |              Time |        1.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             906 |
# |          StdEpRet |             704 |
# |          MaxEpRet |        1.34e+03 |
# |          MinEpRet |            -313 |
# |  AverageTestEpRet |        1.63e+03 |
# |      StdTestEpRet |            28.6 |
# |      MaxTestEpRet |        1.68e+03 |
# |      MinTestEpRet |        1.58e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             107 |
# |         StdQ1Vals |            11.5 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |            43.3 |
# |     AverageQ2Vals |             107 |
# |         StdQ2Vals |            11.5 |
# |         MaxQ2Vals |             136 |
# |         MinQ2Vals |            41.7 |
# |      AverageLogPi |           -1.42 |
# |          StdLogPi |            2.01 |
# |          MaxLogPi |            8.86 |
# |          MinLogPi |           -15.6 |
# |            LossPi |            -107 |
# |             LossQ |             2.5 |
# |              Time |        1.75e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        1.37e+03 |
# |          StdEpRet |            40.2 |
# |          MaxEpRet |        1.42e+03 |
# |          MinEpRet |        1.33e+03 |
# |  AverageTestEpRet |        1.46e+03 |
# |      StdTestEpRet |             506 |
# |      MaxTestEpRet |        1.66e+03 |
# |      MinTestEpRet |           -53.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            13.1 |
# |         MaxQ1Vals |             141 |
# |         MinQ1Vals |              43 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            13.1 |
# |         MaxQ2Vals |             140 |
# |         MinQ2Vals |            43.6 |
# |      AverageLogPi |           -1.37 |
# |          StdLogPi |            2.05 |
# |          MaxLogPi |            12.8 |
# |          MinLogPi |           -14.3 |
# |            LossPi |            -112 |
# |             LossQ |            2.59 |
# |              Time |        1.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        1.39e+03 |
# |          StdEpRet |            37.5 |
# |          MaxEpRet |        1.45e+03 |
# |          MinEpRet |        1.36e+03 |
# |  AverageTestEpRet |        1.69e+03 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |        1.73e+03 |
# |      MinTestEpRet |        1.66e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             115 |
# |         StdQ1Vals |            14.8 |
# |         MaxQ1Vals |             145 |
# |         MinQ1Vals |            31.8 |
# |     AverageQ2Vals |             115 |
# |         StdQ2Vals |            14.8 |
# |         MaxQ2Vals |             145 |
# |         MinQ2Vals |            30.7 |
# |      AverageLogPi |           -1.37 |
# |          StdLogPi |            2.04 |
# |          MaxLogPi |            10.7 |
# |          MinLogPi |           -15.6 |
# |            LossPi |            -116 |
# |             LossQ |            2.51 |
# |              Time |        1.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             994 |
# |          StdEpRet |             723 |
# |          MaxEpRet |        1.43e+03 |
# |          MinEpRet |            -257 |
# |  AverageTestEpRet |         1.7e+03 |
# |      StdTestEpRet |            59.1 |
# |      MaxTestEpRet |        1.75e+03 |
# |      MinTestEpRet |        1.54e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             119 |
# |         StdQ1Vals |            16.2 |
# |         MaxQ1Vals |             148 |
# |         MinQ1Vals |              27 |
# |     AverageQ2Vals |             119 |
# |         StdQ2Vals |            16.2 |
# |         MaxQ2Vals |             149 |
# |         MinQ2Vals |            29.4 |
# |      AverageLogPi |           -1.29 |
# |          StdLogPi |            2.06 |
# |          MaxLogPi |            16.3 |
# |          MinLogPi |           -13.2 |
# |            LossPi |            -119 |
# |             LossQ |             2.6 |
# |              Time |        2.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |         1.4e+03 |
# |          StdEpRet |            58.2 |
# |          MaxEpRet |        1.46e+03 |
# |          MinEpRet |        1.33e+03 |
# |  AverageTestEpRet |        1.58e+03 |
# |      StdTestEpRet |             612 |
# |      MaxTestEpRet |         1.8e+03 |
# |      MinTestEpRet |            -255 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            18.7 |
# |         MaxQ1Vals |             152 |
# |         MinQ1Vals |            10.5 |
# |     AverageQ2Vals |             121 |
# |         StdQ2Vals |            18.7 |
# |         MaxQ2Vals |             152 |
# |         MinQ2Vals |            11.4 |
# |      AverageLogPi |           -1.29 |
# |          StdLogPi |            2.07 |
# |          MaxLogPi |            11.6 |
# |          MinLogPi |           -14.2 |
# |            LossPi |            -122 |
# |             LossQ |            2.77 |
# |              Time |        2.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             979 |
# |          StdEpRet |             738 |
# |          MaxEpRet |        1.42e+03 |
# |          MinEpRet |            -300 |
# |  AverageTestEpRet |        1.72e+03 |
# |      StdTestEpRet |             299 |
# |      MaxTestEpRet |        1.84e+03 |
# |      MinTestEpRet |             828 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             124 |
# |         StdQ1Vals |            20.5 |
# |         MaxQ1Vals |             155 |
# |         MinQ1Vals |            11.9 |
# |     AverageQ2Vals |             124 |
# |         StdQ2Vals |            20.5 |
# |         MaxQ2Vals |             155 |
# |         MinQ2Vals |            12.9 |
# |      AverageLogPi |           -1.24 |
# |          StdLogPi |            2.08 |
# |          MaxLogPi |            12.7 |
# |          MinLogPi |           -14.5 |
# |            LossPi |            -125 |
# |             LossQ |            3.09 |
# |              Time |        2.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        1.43e+03 |
# |          StdEpRet |            30.4 |
# |          MaxEpRet |        1.45e+03 |
# |          MinEpRet |        1.38e+03 |
# |  AverageTestEpRet |        1.76e+03 |
# |      StdTestEpRet |            21.1 |
# |      MaxTestEpRet |         1.8e+03 |
# |      MinTestEpRet |        1.73e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             126 |
# |         StdQ1Vals |            22.5 |
# |         MaxQ1Vals |             156 |
# |         MinQ1Vals |            12.5 |
# |     AverageQ2Vals |             126 |
# |         StdQ2Vals |            22.5 |
# |         MaxQ2Vals |             156 |
# |         MinQ2Vals |            10.4 |
# |      AverageLogPi |           -1.22 |
# |          StdLogPi |            2.09 |
# |          MaxLogPi |            15.4 |
# |          MinLogPi |           -13.1 |
# |            LossPi |            -127 |
# |             LossQ |            3.12 |
# |              Time |        2.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        1.44e+03 |
# |          StdEpRet |            16.5 |
# |          MaxEpRet |        1.46e+03 |
# |          MinEpRet |        1.42e+03 |
# |  AverageTestEpRet |        1.78e+03 |
# |      StdTestEpRet |            19.9 |
# |      MaxTestEpRet |        1.81e+03 |
# |      MinTestEpRet |        1.75e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             128 |
# |         StdQ1Vals |              23 |
# |         MaxQ1Vals |             159 |
# |         MinQ1Vals |            7.99 |
# |     AverageQ2Vals |             128 |
# |         StdQ2Vals |              23 |
# |         MaxQ2Vals |             158 |
# |         MinQ2Vals |            9.73 |
# |      AverageLogPi |           -1.18 |
# |          StdLogPi |             2.1 |
# |          MaxLogPi |            15.4 |
# |          MinLogPi |           -13.6 |
# |            LossPi |            -129 |
# |             LossQ |            3.06 |
# |              Time |        2.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        1.44e+03 |
# |          StdEpRet |            22.3 |
# |          MaxEpRet |        1.48e+03 |
# |          MinEpRet |        1.43e+03 |
# |  AverageTestEpRet |        1.62e+03 |
# |      StdTestEpRet |             583 |
# |      MaxTestEpRet |        1.87e+03 |
# |      MinTestEpRet |            -125 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             131 |
# |         StdQ1Vals |            23.5 |
# |         MaxQ1Vals |             162 |
# |         MinQ1Vals |            7.83 |
# |     AverageQ2Vals |             131 |
# |         StdQ2Vals |            23.5 |
# |         MaxQ2Vals |             161 |
# |         MinQ2Vals |            8.44 |
# |      AverageLogPi |           -1.16 |
# |          StdLogPi |            2.09 |
# |          MaxLogPi |            15.7 |
# |          MinLogPi |           -15.2 |
# |            LossPi |            -131 |
# |             LossQ |            3.01 |
# |              Time |        2.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        1.41e+03 |
# |          StdEpRet |            13.8 |
# |          MaxEpRet |        1.43e+03 |
# |          MinEpRet |        1.39e+03 |
# |  AverageTestEpRet |        1.74e+03 |
# |      StdTestEpRet |            68.6 |
# |      MaxTestEpRet |        1.79e+03 |
# |      MinTestEpRet |        1.54e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             133 |
# |         StdQ1Vals |            23.8 |
# |         MaxQ1Vals |             163 |
# |         MinQ1Vals |            5.89 |
# |     AverageQ2Vals |             133 |
# |         StdQ2Vals |            23.8 |
# |         MaxQ2Vals |             163 |
# |         MinQ2Vals |            5.66 |
# |      AverageLogPi |           -1.15 |
# |          StdLogPi |            2.09 |
# |          MaxLogPi |            15.1 |
# |          MinLogPi |             -14 |
# |            LossPi |            -134 |
# |             LossQ |            2.96 |
# |              Time |        2.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        1.46e+03 |
# |          StdEpRet |            30.4 |
# |          MaxEpRet |        1.51e+03 |
# |          MinEpRet |        1.43e+03 |
# |  AverageTestEpRet |        1.82e+03 |
# |      StdTestEpRet |            12.9 |
# |      MaxTestEpRet |        1.84e+03 |
# |      MinTestEpRet |         1.8e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             135 |
# |         StdQ1Vals |            24.4 |
# |         MaxQ1Vals |             165 |
# |         MinQ1Vals |           -10.3 |
# |     AverageQ2Vals |             135 |
# |         StdQ2Vals |            24.4 |
# |         MaxQ2Vals |             165 |
# |         MinQ2Vals |           -17.8 |
# |      AverageLogPi |           -1.13 |
# |          StdLogPi |            2.08 |
# |          MaxLogPi |            18.4 |
# |          MinLogPi |           -14.2 |
# |            LossPi |            -136 |
# |             LossQ |            3.03 |
# |              Time |        2.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |        1.06e+03 |
# |          StdEpRet |             717 |
# |          MaxEpRet |        1.52e+03 |
# |          MinEpRet |            -178 |
# |  AverageTestEpRet |         1.7e+03 |
# |      StdTestEpRet |            30.4 |
# |      MaxTestEpRet |        1.74e+03 |
# |      MinTestEpRet |        1.62e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             137 |
# |         StdQ1Vals |            25.2 |
# |         MaxQ1Vals |             166 |
# |         MinQ1Vals |           -18.2 |
# |     AverageQ2Vals |             137 |
# |         StdQ2Vals |            25.2 |
# |         MaxQ2Vals |             166 |
# |         MinQ2Vals |             -17 |
# |      AverageLogPi |            -1.1 |
# |          StdLogPi |            2.11 |
# |          MaxLogPi |            25.4 |
# |          MinLogPi |           -14.3 |
# |            LossPi |            -137 |
# |             LossQ |            3.09 |
# |              Time |        2.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        1.02e+03 |
# |          StdEpRet |             771 |
# |          MaxEpRet |        1.48e+03 |
# |          MinEpRet |            -311 |
# |  AverageTestEpRet |        1.83e+03 |
# |      StdTestEpRet |            24.2 |
# |      MaxTestEpRet |        1.86e+03 |
# |      MinTestEpRet |        1.77e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             137 |
# |         StdQ1Vals |            27.9 |
# |         MaxQ1Vals |             168 |
# |         MinQ1Vals |           -12.9 |
# |     AverageQ2Vals |             137 |
# |         StdQ2Vals |            27.9 |
# |         MaxQ2Vals |             168 |
# |         MinQ2Vals |           -15.6 |
# |      AverageLogPi |           -1.13 |
# |          StdLogPi |            2.09 |
# |          MaxLogPi |              22 |
# |          MinLogPi |           -12.5 |
# |            LossPi |            -137 |
# |             LossQ |            3.15 |
# |              Time |        3.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        1.47e+03 |
# |          StdEpRet |            53.4 |
# |          MaxEpRet |        1.53e+03 |
# |          MinEpRet |        1.38e+03 |
# |  AverageTestEpRet |        1.82e+03 |
# |      StdTestEpRet |              16 |
# |      MaxTestEpRet |        1.83e+03 |
# |      MinTestEpRet |        1.78e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |             138 |
# |         StdQ1Vals |            28.8 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |           -3.72 |
# |     AverageQ2Vals |             138 |
# |         StdQ2Vals |            28.8 |
# |         MaxQ2Vals |             169 |
# |         MinQ2Vals |           -2.05 |
# |      AverageLogPi |            -1.1 |
# |          StdLogPi |            2.11 |
# |          MaxLogPi |            21.7 |
# |          MinLogPi |             -13 |
# |            LossPi |            -138 |
# |             LossQ |            3.26 |
# |              Time |        3.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        1.49e+03 |
# |          StdEpRet |            11.3 |
# |          MaxEpRet |        1.51e+03 |
# |          MinEpRet |        1.48e+03 |
# |  AverageTestEpRet |        1.86e+03 |
# |      StdTestEpRet |            9.51 |
# |      MaxTestEpRet |        1.87e+03 |
# |      MinTestEpRet |        1.84e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |             139 |
# |         StdQ1Vals |              29 |
# |         MaxQ1Vals |             171 |
# |         MinQ1Vals |           -12.7 |
# |     AverageQ2Vals |             139 |
# |         StdQ2Vals |              29 |
# |         MaxQ2Vals |             170 |
# |         MinQ2Vals |           -20.5 |
# |      AverageLogPi |           -1.15 |
# |          StdLogPi |            2.09 |
# |          MaxLogPi |            13.9 |
# |          MinLogPi |           -18.5 |
# |            LossPi |            -140 |
# |             LossQ |            3.75 |
# |              Time |         3.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |        1.53e+03 |
# |          StdEpRet |            15.1 |
# |          MaxEpRet |        1.55e+03 |
# |          MinEpRet |        1.51e+03 |
# |  AverageTestEpRet |        1.87e+03 |
# |      StdTestEpRet |            18.7 |
# |      MaxTestEpRet |        1.89e+03 |
# |      MinTestEpRet |        1.83e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             141 |
# |         StdQ1Vals |            29.2 |
# |         MaxQ1Vals |             171 |
# |         MinQ1Vals |           -11.4 |
# |     AverageQ2Vals |             141 |
# |         StdQ2Vals |            29.2 |
# |         MaxQ2Vals |             172 |
# |         MinQ2Vals |           -9.18 |
# |      AverageLogPi |           -1.12 |
# |          StdLogPi |            2.09 |
# |          MaxLogPi |            18.5 |
# |          MinLogPi |           -15.7 |
# |            LossPi |            -141 |
# |             LossQ |            3.37 |
# |              Time |        3.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |         1.5e+03 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |        1.55e+03 |
# |          MinEpRet |        1.47e+03 |
# |  AverageTestEpRet |        1.82e+03 |
# |      StdTestEpRet |            25.5 |
# |      MaxTestEpRet |        1.87e+03 |
# |      MinTestEpRet |        1.78e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             142 |
# |         StdQ1Vals |            29.2 |
# |         MaxQ1Vals |             172 |
# |         MinQ1Vals |           -10.8 |
# |     AverageQ2Vals |             142 |
# |         StdQ2Vals |            29.2 |
# |         MaxQ2Vals |             171 |
# |         MinQ2Vals |           -10.4 |
# |      AverageLogPi |           -1.09 |
# |          StdLogPi |            2.11 |
# |          MaxLogPi |              22 |
# |          MinLogPi |           -14.1 |
# |            LossPi |            -143 |
# |             LossQ |            3.19 |
# |              Time |        3.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |        1.54e+03 |
# |          StdEpRet |            15.1 |
# |          MaxEpRet |        1.56e+03 |
# |          MinEpRet |        1.52e+03 |
# |  AverageTestEpRet |        1.87e+03 |
# |      StdTestEpRet |            10.4 |
# |      MaxTestEpRet |        1.89e+03 |
# |      MinTestEpRet |        1.85e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             143 |
# |         StdQ1Vals |            29.2 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |           -4.47 |
# |     AverageQ2Vals |             143 |
# |         StdQ2Vals |            29.2 |
# |         MaxQ2Vals |             172 |
# |         MinQ2Vals |           -6.05 |
# |      AverageLogPi |           -1.06 |
# |          StdLogPi |            2.12 |
# |          MaxLogPi |            15.2 |
# |          MinLogPi |           -14.1 |
# |            LossPi |            -144 |
# |             LossQ |            3.24 |
# |              Time |        3.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |        1.51e+03 |
# |          StdEpRet |            24.1 |
# |          MaxEpRet |        1.55e+03 |
# |          MinEpRet |        1.49e+03 |
# |  AverageTestEpRet |        1.88e+03 |
# |      StdTestEpRet |            38.1 |
# |      MaxTestEpRet |        1.91e+03 |
# |      MinTestEpRet |        1.77e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             145 |
# |         StdQ1Vals |            29.1 |
# |         MaxQ1Vals |             174 |
# |         MinQ1Vals |           -9.94 |
# |     AverageQ2Vals |             145 |
# |         StdQ2Vals |            29.1 |
# |         MaxQ2Vals |             174 |
# |         MinQ2Vals |           -5.41 |
# |      AverageLogPi |           -1.07 |
# |          StdLogPi |            2.11 |
# |          MaxLogPi |            17.8 |
# |          MinLogPi |           -16.1 |
# |            LossPi |            -145 |
# |             LossQ |            3.04 |
# |              Time |        3.73e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |        1.54e+03 |
# |          StdEpRet |            28.8 |
# |          MaxEpRet |        1.59e+03 |
# |          MinEpRet |        1.52e+03 |
# |  AverageTestEpRet |        1.93e+03 |
# |      StdTestEpRet |               6 |
# |      MaxTestEpRet |        1.93e+03 |
# |      MinTestEpRet |        1.92e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             146 |
# |         StdQ1Vals |            29.1 |
# |         MaxQ1Vals |             174 |
# |         MinQ1Vals |          -0.113 |
# |     AverageQ2Vals |             146 |
# |         StdQ2Vals |            29.1 |
# |         MaxQ2Vals |             177 |
# |         MinQ2Vals |           -4.24 |
# |      AverageLogPi |           -1.02 |
# |          StdLogPi |            2.12 |
# |          MaxLogPi |            20.7 |
# |          MinLogPi |           -13.9 |
# |            LossPi |            -146 |
# |             LossQ |            3.17 |
# |              Time |        3.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |        1.53e+03 |
# |          StdEpRet |            16.4 |
# |          MaxEpRet |        1.55e+03 |
# |          MinEpRet |        1.51e+03 |
# |  AverageTestEpRet |         1.9e+03 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |        1.92e+03 |
# |      MinTestEpRet |        1.88e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             147 |
# |         StdQ1Vals |              29 |
# |         MaxQ1Vals |             176 |
# |         MinQ1Vals |           -7.07 |
# |     AverageQ2Vals |             147 |
# |         StdQ2Vals |              29 |
# |         MaxQ2Vals |             176 |
# |         MinQ2Vals |           -6.46 |
# |      AverageLogPi |           -1.06 |
# |          StdLogPi |             2.1 |
# |          MaxLogPi |              21 |
# |          MinLogPi |           -15.5 |
# |            LossPi |            -147 |
# |             LossQ |            3.04 |
# |              Time |        3.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |        1.56e+03 |
# |          StdEpRet |            11.5 |
# |          MaxEpRet |        1.58e+03 |
# |          MinEpRet |        1.55e+03 |
# |  AverageTestEpRet |         1.9e+03 |
# |      StdTestEpRet |            29.9 |
# |      MaxTestEpRet |        1.93e+03 |
# |      MinTestEpRet |        1.82e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             148 |
# |         StdQ1Vals |            28.8 |
# |         MaxQ1Vals |             176 |
# |         MinQ1Vals |           -5.48 |
# |     AverageQ2Vals |             148 |
# |         StdQ2Vals |            28.8 |
# |         MaxQ2Vals |             177 |
# |         MinQ2Vals |           -8.75 |
# |      AverageLogPi |          -0.997 |
# |          StdLogPi |            2.12 |
# |          MaxLogPi |            17.4 |
# |          MinLogPi |           -16.1 |
# |            LossPi |            -148 |
# |             LossQ |            3.17 |
# |              Time |        4.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        1.56e+03 |
# |          StdEpRet |             4.3 |
# |          MaxEpRet |        1.57e+03 |
# |          MinEpRet |        1.55e+03 |
# |  AverageTestEpRet |        1.92e+03 |
# |      StdTestEpRet |            26.5 |
# |      MaxTestEpRet |        1.95e+03 |
# |      MinTestEpRet |        1.85e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             149 |
# |         StdQ1Vals |            28.5 |
# |         MaxQ1Vals |             176 |
# |         MinQ1Vals |           -8.37 |
# |     AverageQ2Vals |             149 |
# |         StdQ2Vals |            28.5 |
# |         MaxQ2Vals |             177 |
# |         MinQ2Vals |           -10.4 |
# |      AverageLogPi |           -1.02 |
# |          StdLogPi |            2.12 |
# |          MaxLogPi |            14.7 |
# |          MinLogPi |           -15.6 |
# |            LossPi |            -149 |
# |             LossQ |            3.19 |
# |              Time |        4.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        1.58e+03 |
# |          StdEpRet |            8.25 |
# |          MaxEpRet |        1.59e+03 |
# |          MinEpRet |        1.57e+03 |
# |  AverageTestEpRet |        1.98e+03 |
# |      StdTestEpRet |              16 |
# |      MaxTestEpRet |           2e+03 |
# |      MinTestEpRet |        1.95e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             150 |
# |         StdQ1Vals |            28.5 |
# |         MaxQ1Vals |             177 |
# |         MinQ1Vals |           -5.69 |
# |     AverageQ2Vals |             150 |
# |         StdQ2Vals |            28.5 |
# |         MaxQ2Vals |             179 |
# |         MinQ2Vals |           -3.25 |
# |      AverageLogPi |           -0.98 |
# |          StdLogPi |            2.12 |
# |          MaxLogPi |            16.2 |
# |          MinLogPi |           -15.5 |
# |            LossPi |            -150 |
# |             LossQ |            2.89 |
# |              Time |        4.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        1.58e+03 |
# |          StdEpRet |              26 |
# |          MaxEpRet |        1.61e+03 |
# |          MinEpRet |        1.54e+03 |
# |  AverageTestEpRet |        1.94e+03 |
# |      StdTestEpRet |            27.3 |
# |      MaxTestEpRet |        1.97e+03 |
# |      MinTestEpRet |        1.87e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             151 |
# |         StdQ1Vals |            28.1 |
# |         MaxQ1Vals |             180 |
# |         MinQ1Vals |           -3.77 |
# |     AverageQ2Vals |             151 |
# |         StdQ2Vals |            28.1 |
# |         MaxQ2Vals |             179 |
# |         MinQ2Vals |           -5.27 |
# |      AverageLogPi |          -0.955 |
# |          StdLogPi |            2.13 |
# |          MaxLogPi |            28.6 |
# |          MinLogPi |           -13.3 |
# |            LossPi |            -151 |
# |             LossQ |            2.82 |
# |              Time |        4.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        1.61e+03 |
# |          StdEpRet |            10.1 |
# |          MaxEpRet |        1.62e+03 |
# |          MinEpRet |         1.6e+03 |
# |  AverageTestEpRet |        1.69e+03 |
# |      StdTestEpRet |             589 |
# |      MaxTestEpRet |        1.91e+03 |
# |      MinTestEpRet |           -76.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             152 |
# |         StdQ1Vals |            27.9 |
# |         MaxQ1Vals |             179 |
# |         MinQ1Vals |          -0.816 |
# |     AverageQ2Vals |             152 |
# |         StdQ2Vals |            27.9 |
# |         MaxQ2Vals |             178 |
# |         MinQ2Vals |           -3.86 |
# |      AverageLogPi |           -0.95 |
# |          StdLogPi |            2.12 |
# |          MaxLogPi |            12.4 |
# |          MinLogPi |           -13.3 |
# |            LossPi |            -152 |
# |             LossQ |            2.72 |
# |              Time |        4.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        1.62e+03 |
# |          StdEpRet |            25.6 |
# |          MaxEpRet |        1.65e+03 |
# |          MinEpRet |        1.58e+03 |
# |  AverageTestEpRet |        1.91e+03 |
# |      StdTestEpRet |            8.34 |
# |      MaxTestEpRet |        1.92e+03 |
# |      MinTestEpRet |         1.9e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             153 |
# |         StdQ1Vals |            27.9 |
# |         MaxQ1Vals |             180 |
# |         MinQ1Vals |           -8.06 |
# |     AverageQ2Vals |             153 |
# |         StdQ2Vals |            27.9 |
# |         MaxQ2Vals |             181 |
# |         MinQ2Vals |           -8.83 |
# |      AverageLogPi |          -0.932 |
# |          StdLogPi |            2.14 |
# |          MaxLogPi |            16.1 |
# |          MinLogPi |           -13.9 |
# |            LossPi |            -153 |
# |             LossQ |            2.72 |
# |              Time |         4.6e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        1.62e+03 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |        1.65e+03 |
# |          MinEpRet |        1.61e+03 |
# |  AverageTestEpRet |        1.97e+03 |
# |      StdTestEpRet |            5.77 |
# |      MaxTestEpRet |        1.98e+03 |
# |      MinTestEpRet |        1.96e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             154 |
# |         StdQ1Vals |            27.9 |
# |         MaxQ1Vals |             180 |
# |         MinQ1Vals |            -2.1 |
# |     AverageQ2Vals |             154 |
# |         StdQ2Vals |            27.9 |
# |         MaxQ2Vals |             180 |
# |         MinQ2Vals |           -1.51 |
# |      AverageLogPi |          -0.915 |
# |          StdLogPi |            2.15 |
# |          MaxLogPi |            18.7 |
# |          MinLogPi |           -15.7 |
# |            LossPi |            -154 |
# |             LossQ |            2.77 |
# |              Time |        4.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        1.63e+03 |
# |          StdEpRet |            20.1 |
# |          MaxEpRet |        1.65e+03 |
# |          MinEpRet |         1.6e+03 |
# |  AverageTestEpRet |        1.94e+03 |
# |      StdTestEpRet |            56.4 |
# |      MaxTestEpRet |        1.98e+03 |
# |      MinTestEpRet |        1.79e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             155 |
# |         StdQ1Vals |            27.6 |
# |         MaxQ1Vals |             181 |
# |         MinQ1Vals |           0.158 |
# |     AverageQ2Vals |             155 |
# |         StdQ2Vals |            27.6 |
# |         MaxQ2Vals |             181 |
# |         MinQ2Vals |           -1.05 |
# |      AverageLogPi |          -0.881 |
# |          StdLogPi |            2.16 |
# |          MaxLogPi |            14.8 |
# |          MinLogPi |           -15.8 |
# |            LossPi |            -155 |
# |             LossQ |             2.8 |
# |              Time |        4.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        1.64e+03 |
# |          StdEpRet |            10.9 |
# |          MaxEpRet |        1.65e+03 |
# |          MinEpRet |        1.63e+03 |
# |  AverageTestEpRet |        1.78e+03 |
# |      StdTestEpRet |             610 |
# |      MaxTestEpRet |           2e+03 |
# |      MinTestEpRet |           -48.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             155 |
# |         StdQ1Vals |            27.5 |
# |         MaxQ1Vals |             182 |
# |         MinQ1Vals |          -0.548 |
# |     AverageQ2Vals |             155 |
# |         StdQ2Vals |            27.5 |
# |         MaxQ2Vals |             182 |
# |         MinQ2Vals |          -0.609 |
# |      AverageLogPi |          -0.862 |
# |          StdLogPi |            2.16 |
# |          MaxLogPi |            18.2 |
# |          MinLogPi |           -13.3 |
# |            LossPi |            -156 |
# |             LossQ |            2.64 |
# |              Time |        4.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        1.63e+03 |
# |          StdEpRet |            27.3 |
# |          MaxEpRet |        1.66e+03 |
# |          MinEpRet |        1.59e+03 |
# |  AverageTestEpRet |        1.96e+03 |
# |      StdTestEpRet |            5.85 |
# |      MaxTestEpRet |        1.96e+03 |
# |      MinTestEpRet |        1.94e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             156 |
# |         StdQ1Vals |            27.6 |
# |         MaxQ1Vals |             183 |
# |         MinQ1Vals |           -1.18 |
# |     AverageQ2Vals |             156 |
# |         StdQ2Vals |            27.6 |
# |         MaxQ2Vals |             182 |
# |         MinQ2Vals |           -2.24 |
# |      AverageLogPi |          -0.866 |
# |          StdLogPi |            2.15 |
# |          MaxLogPi |            17.8 |
# |          MinLogPi |           -13.9 |
# |            LossPi |            -156 |
# |             LossQ |             2.8 |
# |              Time |        5.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        1.65e+03 |
# |          StdEpRet |            24.7 |
# |          MaxEpRet |        1.67e+03 |
# |          MinEpRet |         1.6e+03 |
# |  AverageTestEpRet |        1.95e+03 |
# |      StdTestEpRet |            47.3 |
# |      MaxTestEpRet |        1.98e+03 |
# |      MinTestEpRet |        1.84e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             157 |
# |         StdQ1Vals |            27.4 |
# |         MaxQ1Vals |             183 |
# |         MinQ1Vals |            0.64 |
# |     AverageQ2Vals |             157 |
# |         StdQ2Vals |            27.4 |
# |         MaxQ2Vals |             182 |
# |         MinQ2Vals |           0.768 |
# |      AverageLogPi |          -0.842 |
# |          StdLogPi |            2.15 |
# |          MaxLogPi |            17.6 |
# |          MinLogPi |           -17.8 |
# |            LossPi |            -157 |
# |             LossQ |            2.66 |
# |              Time |        5.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        1.66e+03 |
# |          StdEpRet |               7 |
# |          MaxEpRet |        1.66e+03 |
# |          MinEpRet |        1.64e+03 |
# |  AverageTestEpRet |        2.01e+03 |
# |      StdTestEpRet |            7.15 |
# |      MaxTestEpRet |        2.02e+03 |
# |      MinTestEpRet |           2e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             158 |
# |         StdQ1Vals |            27.3 |
# |         MaxQ1Vals |             183 |
# |         MinQ1Vals |           -3.19 |
# |     AverageQ2Vals |             158 |
# |         StdQ2Vals |            27.3 |
# |         MaxQ2Vals |             184 |
# |         MinQ2Vals |           -3.36 |
# |      AverageLogPi |          -0.829 |
# |          StdLogPi |            2.15 |
# |          MaxLogPi |            15.4 |
# |          MinLogPi |           -13.8 |
# |            LossPi |            -158 |
# |             LossQ |            2.65 |
# |              Time |        5.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        1.67e+03 |
# |          StdEpRet |            28.1 |
# |          MaxEpRet |         1.7e+03 |
# |          MinEpRet |        1.64e+03 |
# |  AverageTestEpRet |        2.03e+03 |
# |      StdTestEpRet |              37 |
# |      MaxTestEpRet |        2.06e+03 |
# |      MinTestEpRet |        1.93e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             158 |
# |         StdQ1Vals |            27.2 |
# |         MaxQ1Vals |             184 |
# |         MinQ1Vals |           -6.82 |
# |     AverageQ2Vals |             158 |
# |         StdQ2Vals |            27.2 |
# |         MaxQ2Vals |             184 |
# |         MinQ2Vals |           -7.22 |
# |      AverageLogPi |          -0.806 |
# |          StdLogPi |            2.17 |
# |          MaxLogPi |            17.3 |
# |          MinLogPi |           -13.8 |
# |            LossPi |            -159 |
# |             LossQ |            2.64 |
# |              Time |        5.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |         1.2e+03 |
# |          StdEpRet |             819 |
# |          MaxEpRet |        1.68e+03 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |        1.98e+03 |
# |      StdTestEpRet |            59.1 |
# |      MaxTestEpRet |        2.02e+03 |
# |      MinTestEpRet |        1.81e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             159 |
# |         StdQ1Vals |            27.5 |
# |         MaxQ1Vals |             184 |
# |         MinQ1Vals |            -7.1 |
# |     AverageQ2Vals |             159 |
# |         StdQ2Vals |            27.5 |
# |         MaxQ2Vals |             185 |
# |         MinQ2Vals |           -11.7 |
# |      AverageLogPi |          -0.805 |
# |          StdLogPi |            2.15 |
# |          MaxLogPi |            21.2 |
# |          MinLogPi |           -14.3 |
# |            LossPi |            -159 |
# |             LossQ |            2.69 |
# |              Time |        5.48e+03 |
# ---------------------------------------

# %%
args = {'env': 'AntMuJoCoEnv-v0', 'hid': 128, 'l': 2, 
        'gamma': 0.99, 'seed':5, 'epochs':50, 
        'partially_observable': False,
        'exp_name': 'sac_MDP_AntMuJoCoEnv_2L128'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

torch.set_num_threads(torch.get_num_threads())

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
    gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    partially_observable=args['partially_observable'],
    logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_MDP_AntMuJoCoEnv_2L128\sac_MDP_AntMuJoCoEnv_2L128_s5\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             128,
#             128
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"AntMuJoCoEnv-v0",
#     "epochs":	50,
#     "exp_name":	"sac_MDP_AntMuJoCoEnv_2L128",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001D4DE34AB88>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_MDP_AntMuJoCoEnv_2L128",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_MDP_AntMuJoCoEnv_2L128\\sac_MDP_AntMuJoCoEnv_2L128_s5",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\sac_MDP_AntMuJoCoEnv_2L128\\\\sac_MDP_AntMuJoCoEnv_2L128_s5\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_MDP_AntMuJoCoEnv_2L128",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_MDP_AntMuJoCoEnv_2L128\\sac_MDP_AntMuJoCoEnv_2L128_s5"
#     },
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "partially_observable":	false,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	5,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
#
# Number of parameters: 	 pi: 32912, 	 q1: 32001, 	 q2: 32001
#
# options=
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |             571 |
# |          StdEpRet |            64.1 |
# |          MaxEpRet |             638 |
# |          MinEpRet |             465 |
# |  AverageTestEpRet |             655 |
# |      StdTestEpRet |            61.8 |
# |      MaxTestEpRet |             718 |
# |      MinTestEpRet |             525 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            11.7 |
# |         StdQ1Vals |            6.33 |
# |         MaxQ1Vals |            29.9 |
# |         MinQ1Vals |           0.088 |
# |     AverageQ2Vals |            11.7 |
# |         StdQ2Vals |            6.33 |
# |         MaxQ2Vals |            29.6 |
# |         MinQ2Vals |         -0.0494 |
# |      AverageLogPi |           -5.03 |
# |          StdLogPi |             1.2 |
# |          MaxLogPi |            10.3 |
# |          MinLogPi |           -12.6 |
# |            LossPi |           -12.8 |
# |             LossQ |          0.0971 |
# |              Time |             100 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |             614 |
# |          StdEpRet |            26.3 |
# |          MaxEpRet |             642 |
# |          MinEpRet |             573 |
# |  AverageTestEpRet |             505 |
# |      StdTestEpRet |            90.7 |
# |      MaxTestEpRet |             658 |
# |      MinTestEpRet |             360 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |              37 |
# |         StdQ1Vals |            8.46 |
# |         MaxQ1Vals |            78.7 |
# |         MinQ1Vals |            19.3 |
# |     AverageQ2Vals |              37 |
# |         StdQ2Vals |            8.46 |
# |         MaxQ2Vals |            79.1 |
# |         MinQ2Vals |            19.3 |
# |      AverageLogPi |           -4.48 |
# |          StdLogPi |            1.84 |
# |          MaxLogPi |            12.2 |
# |          MinLogPi |           -15.2 |
# |            LossPi |           -38.2 |
# |             LossQ |           0.229 |
# |              Time |             241 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |             611 |
# |          StdEpRet |              63 |
# |          MaxEpRet |             690 |
# |          MinEpRet |             515 |
# |  AverageTestEpRet |             375 |
# |      StdTestEpRet |            64.4 |
# |      MaxTestEpRet |             501 |
# |      MinTestEpRet |             305 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            64.7 |
# |         StdQ1Vals |            10.7 |
# |         MaxQ1Vals |             135 |
# |         MinQ1Vals |            39.4 |
# |     AverageQ2Vals |            64.7 |
# |         StdQ2Vals |            10.7 |
# |         MaxQ2Vals |             141 |
# |         MinQ2Vals |            39.5 |
# |      AverageLogPi |           -3.57 |
# |          StdLogPi |            2.46 |
# |          MaxLogPi |            23.8 |
# |          MinLogPi |           -14.9 |
# |            LossPi |           -66.1 |
# |             LossQ |            1.19 |
# |              Time |             383 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             591 |
# |          StdEpRet |             129 |
# |          MaxEpRet |             814 |
# |          MinEpRet |             508 |
# |  AverageTestEpRet |             618 |
# |      StdTestEpRet |            71.3 |
# |      MaxTestEpRet |             699 |
# |      MinTestEpRet |             487 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            86.1 |
# |         StdQ1Vals |            9.07 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |            56.4 |
# |     AverageQ2Vals |            86.1 |
# |         StdQ2Vals |            9.07 |
# |         MaxQ2Vals |             122 |
# |         MinQ2Vals |            56.3 |
# |      AverageLogPi |           -4.75 |
# |          StdLogPi |            1.41 |
# |          MaxLogPi |            19.6 |
# |          MinLogPi |           -12.8 |
# |            LossPi |           -87.2 |
# |             LossQ |           0.694 |
# |              Time |             527 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             625 |
# |          StdEpRet |            62.2 |
# |          MaxEpRet |             717 |
# |          MinEpRet |             550 |
# |  AverageTestEpRet |             465 |
# |      StdTestEpRet |             139 |
# |      MaxTestEpRet |             716 |
# |      MinTestEpRet |             328 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |             103 |
# |         StdQ1Vals |            9.27 |
# |         MaxQ1Vals |             138 |
# |         MinQ1Vals |            71.1 |
# |     AverageQ2Vals |             103 |
# |         StdQ2Vals |            9.27 |
# |         MaxQ2Vals |             137 |
# |         MinQ2Vals |            70.9 |
# |      AverageLogPi |           -5.07 |
# |          StdLogPi |            1.03 |
# |          MaxLogPi |              10 |
# |          MinLogPi |           -13.5 |
# |            LossPi |            -104 |
# |             LossQ |           0.546 |
# |              Time |             667 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             657 |
# |          StdEpRet |             128 |
# |          MaxEpRet |             819 |
# |          MinEpRet |             521 |
# |  AverageTestEpRet |             545 |
# |      StdTestEpRet |            40.9 |
# |      MaxTestEpRet |             598 |
# |      MinTestEpRet |             473 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |             116 |
# |         StdQ1Vals |             8.9 |
# |         MaxQ1Vals |             148 |
# |         MinQ1Vals |            82.3 |
# |     AverageQ2Vals |             116 |
# |         StdQ2Vals |             8.9 |
# |         MaxQ2Vals |             148 |
# |         MinQ2Vals |            82.5 |
# |      AverageLogPi |           -5.14 |
# |          StdLogPi |           0.921 |
# |          MaxLogPi |             6.2 |
# |          MinLogPi |           -11.5 |
# |            LossPi |            -117 |
# |             LossQ |           0.549 |
# |              Time |             806 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             699 |
# |          StdEpRet |            53.2 |
# |          MaxEpRet |             781 |
# |          MinEpRet |             634 |
# |  AverageTestEpRet |             557 |
# |      StdTestEpRet |            42.4 |
# |      MaxTestEpRet |             677 |
# |      MinTestEpRet |             512 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |             125 |
# |         StdQ1Vals |            8.35 |
# |         MaxQ1Vals |             152 |
# |         MinQ1Vals |            92.3 |
# |     AverageQ2Vals |             125 |
# |         StdQ2Vals |            8.35 |
# |         MaxQ2Vals |             151 |
# |         MinQ2Vals |            92.2 |
# |      AverageLogPi |           -5.19 |
# |          StdLogPi |           0.851 |
# |          MaxLogPi |            4.52 |
# |          MinLogPi |           -11.9 |
# |            LossPi |            -126 |
# |             LossQ |           0.466 |
# |              Time |             946 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             699 |
# |          StdEpRet |            26.9 |
# |          MaxEpRet |             720 |
# |          MinEpRet |             654 |
# |  AverageTestEpRet |             686 |
# |      StdTestEpRet |            59.7 |
# |      MaxTestEpRet |             811 |
# |      MinTestEpRet |             614 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |             133 |
# |         StdQ1Vals |            8.08 |
# |         MaxQ1Vals |             157 |
# |         MinQ1Vals |            99.8 |
# |     AverageQ2Vals |             133 |
# |         StdQ2Vals |            8.08 |
# |         MaxQ2Vals |             156 |
# |         MinQ2Vals |            99.8 |
# |      AverageLogPi |           -5.19 |
# |          StdLogPi |           0.854 |
# |          MaxLogPi |            10.7 |
# |          MinLogPi |           -12.1 |
# |            LossPi |            -134 |
# |             LossQ |           0.463 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             694 |
# |          StdEpRet |            43.4 |
# |          MaxEpRet |             761 |
# |          MinEpRet |             645 |
# |  AverageTestEpRet |             639 |
# |      StdTestEpRet |            95.4 |
# |      MaxTestEpRet |             722 |
# |      MinTestEpRet |             449 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |             140 |
# |         StdQ1Vals |            7.97 |
# |         MaxQ1Vals |             163 |
# |         MinQ1Vals |             105 |
# |     AverageQ2Vals |             140 |
# |         StdQ2Vals |            7.97 |
# |         MaxQ2Vals |             163 |
# |         MinQ2Vals |             105 |
# |      AverageLogPi |           -5.22 |
# |          StdLogPi |           0.812 |
# |          MaxLogPi |            3.49 |
# |          MinLogPi |           -12.9 |
# |            LossPi |            -141 |
# |             LossQ |           0.477 |
# |              Time |        1.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             814 |
# |          StdEpRet |            47.2 |
# |          MaxEpRet |             890 |
# |          MinEpRet |             766 |
# |  AverageTestEpRet |             654 |
# |      StdTestEpRet |            91.5 |
# |      MaxTestEpRet |             758 |
# |      MinTestEpRet |             519 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |             145 |
# |         StdQ1Vals |            8.02 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |             110 |
# |     AverageQ2Vals |             145 |
# |         StdQ2Vals |            8.02 |
# |         MaxQ2Vals |             169 |
# |         MinQ2Vals |             110 |
# |      AverageLogPi |           -5.23 |
# |          StdLogPi |           0.798 |
# |          MaxLogPi |            6.24 |
# |          MinLogPi |           -11.1 |
# |            LossPi |            -146 |
# |             LossQ |           0.512 |
# |              Time |        1.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             734 |
# |          StdEpRet |            56.4 |
# |          MaxEpRet |             812 |
# |          MinEpRet |             671 |
# |  AverageTestEpRet |             724 |
# |      StdTestEpRet |            69.7 |
# |      MaxTestEpRet |             808 |
# |      MinTestEpRet |             556 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |             149 |
# |         StdQ1Vals |            8.01 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |             114 |
# |     AverageQ2Vals |             149 |
# |         StdQ2Vals |            8.01 |
# |         MaxQ2Vals |             172 |
# |         MinQ2Vals |             114 |
# |      AverageLogPi |           -5.24 |
# |          StdLogPi |           0.773 |
# |          MaxLogPi |            4.39 |
# |          MinLogPi |           -13.8 |
# |            LossPi |            -150 |
# |             LossQ |           0.565 |
# |              Time |        1.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             813 |
# |          StdEpRet |            50.1 |
# |          MaxEpRet |             851 |
# |          MinEpRet |             728 |
# |  AverageTestEpRet |             836 |
# |      StdTestEpRet |            69.2 |
# |      MaxTestEpRet |             897 |
# |      MinTestEpRet |             708 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |             153 |
# |         StdQ1Vals |            7.95 |
# |         MaxQ1Vals |             175 |
# |         MinQ1Vals |             117 |
# |     AverageQ2Vals |             153 |
# |         StdQ2Vals |            7.95 |
# |         MaxQ2Vals |             174 |
# |         MinQ2Vals |             117 |
# |      AverageLogPi |           -5.21 |
# |          StdLogPi |           0.819 |
# |          MaxLogPi |            5.55 |
# |          MinLogPi |           -11.6 |
# |            LossPi |            -154 |
# |             LossQ |           0.569 |
# |              Time |        1.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             760 |
# |          StdEpRet |            52.7 |
# |          MaxEpRet |             837 |
# |          MinEpRet |             691 |
# |  AverageTestEpRet |             793 |
# |      StdTestEpRet |            80.4 |
# |      MaxTestEpRet |             901 |
# |      MinTestEpRet |             680 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |             156 |
# |         StdQ1Vals |            7.96 |
# |         MaxQ1Vals |             178 |
# |         MinQ1Vals |             120 |
# |     AverageQ2Vals |             156 |
# |         StdQ2Vals |            7.96 |
# |         MaxQ2Vals |             178 |
# |         MinQ2Vals |             120 |
# |      AverageLogPi |           -5.19 |
# |          StdLogPi |           0.832 |
# |          MaxLogPi |            4.48 |
# |          MinLogPi |           -12.4 |
# |            LossPi |            -157 |
# |             LossQ |           0.584 |
# |              Time |        1.79e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             889 |
# |          StdEpRet |            59.8 |
# |          MaxEpRet |             964 |
# |          MinEpRet |             801 |
# |  AverageTestEpRet |             698 |
# |      StdTestEpRet |            96.1 |
# |      MaxTestEpRet |             827 |
# |      MinTestEpRet |             466 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |             158 |
# |         StdQ1Vals |            8.09 |
# |         MaxQ1Vals |             184 |
# |         MinQ1Vals |             122 |
# |     AverageQ2Vals |             158 |
# |         StdQ2Vals |            8.09 |
# |         MaxQ2Vals |             182 |
# |         MinQ2Vals |             122 |
# |      AverageLogPi |           -5.18 |
# |          StdLogPi |           0.859 |
# |          MaxLogPi |            4.91 |
# |          MinLogPi |           -14.2 |
# |            LossPi |            -159 |
# |             LossQ |           0.595 |
# |              Time |        1.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             808 |
# |          StdEpRet |            24.2 |
# |          MaxEpRet |             841 |
# |          MinEpRet |             774 |
# |  AverageTestEpRet |             811 |
# |      StdTestEpRet |            65.4 |
# |      MaxTestEpRet |             933 |
# |      MinTestEpRet |             690 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             161 |
# |         StdQ1Vals |            8.26 |
# |         MaxQ1Vals |             183 |
# |         MinQ1Vals |             124 |
# |     AverageQ2Vals |             161 |
# |         StdQ2Vals |            8.26 |
# |         MaxQ2Vals |             183 |
# |         MinQ2Vals |             124 |
# |      AverageLogPi |           -5.15 |
# |          StdLogPi |           0.894 |
# |          MaxLogPi |            6.09 |
# |          MinLogPi |           -12.4 |
# |            LossPi |            -162 |
# |             LossQ |            0.64 |
# |              Time |        2.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             936 |
# |          StdEpRet |            42.8 |
# |          MaxEpRet |             974 |
# |          MinEpRet |             863 |
# |  AverageTestEpRet |             739 |
# |      StdTestEpRet |            71.2 |
# |      MaxTestEpRet |             852 |
# |      MinTestEpRet |             583 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             163 |
# |         StdQ1Vals |            8.47 |
# |         MaxQ1Vals |             185 |
# |         MinQ1Vals |             125 |
# |     AverageQ2Vals |             163 |
# |         StdQ2Vals |            8.47 |
# |         MaxQ2Vals |             186 |
# |         MinQ2Vals |             125 |
# |      AverageLogPi |           -5.12 |
# |          StdLogPi |           0.921 |
# |          MaxLogPi |            5.17 |
# |          MinLogPi |           -12.2 |
# |            LossPi |            -164 |
# |             LossQ |           0.665 |
# |              Time |         2.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             881 |
# |          StdEpRet |             127 |
# |          MaxEpRet |             994 |
# |          MinEpRet |             668 |
# |  AverageTestEpRet |             800 |
# |      StdTestEpRet |            99.2 |
# |      MaxTestEpRet |             939 |
# |      MinTestEpRet |             629 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             165 |
# |         StdQ1Vals |            8.87 |
# |         MaxQ1Vals |             188 |
# |         MinQ1Vals |             126 |
# |     AverageQ2Vals |             165 |
# |         StdQ2Vals |            8.87 |
# |         MaxQ2Vals |             189 |
# |         MinQ2Vals |             126 |
# |      AverageLogPi |           -5.09 |
# |          StdLogPi |           0.958 |
# |          MaxLogPi |            4.24 |
# |          MinLogPi |           -12.2 |
# |            LossPi |            -166 |
# |             LossQ |           0.683 |
# |              Time |        2.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             965 |
# |          StdEpRet |            32.6 |
# |          MaxEpRet |             990 |
# |          MinEpRet |             909 |
# |  AverageTestEpRet |             782 |
# |      StdTestEpRet |              65 |
# |      MaxTestEpRet |             926 |
# |      MinTestEpRet |             691 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |            9.14 |
# |         MaxQ1Vals |             190 |
# |         MinQ1Vals |             128 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |            9.14 |
# |         MaxQ2Vals |             190 |
# |         MinQ2Vals |             127 |
# |      AverageLogPi |           -5.07 |
# |          StdLogPi |            0.97 |
# |          MaxLogPi |            2.86 |
# |          MinLogPi |           -11.3 |
# |            LossPi |            -168 |
# |             LossQ |           0.702 |
# |              Time |        2.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             857 |
# |          StdEpRet |             105 |
# |          MaxEpRet |        1.02e+03 |
# |          MinEpRet |             734 |
# |  AverageTestEpRet |             908 |
# |      StdTestEpRet |            85.8 |
# |      MaxTestEpRet |             978 |
# |      MinTestEpRet |             719 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             168 |
# |         StdQ1Vals |            9.44 |
# |         MaxQ1Vals |             194 |
# |         MinQ1Vals |             128 |
# |     AverageQ2Vals |             168 |
# |         StdQ2Vals |            9.44 |
# |         MaxQ2Vals |             194 |
# |         MinQ2Vals |             128 |
# |      AverageLogPi |           -5.04 |
# |          StdLogPi |           0.994 |
# |          MaxLogPi |            4.19 |
# |          MinLogPi |           -12.4 |
# |            LossPi |            -169 |
# |             LossQ |           0.721 |
# |              Time |        2.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             978 |
# |          StdEpRet |            46.1 |
# |          MaxEpRet |        1.01e+03 |
# |          MinEpRet |             899 |
# |  AverageTestEpRet |        1.06e+03 |
# |      StdTestEpRet |            67.9 |
# |      MaxTestEpRet |        1.18e+03 |
# |      MinTestEpRet |             926 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             170 |
# |         StdQ1Vals |            9.76 |
# |         MaxQ1Vals |             195 |
# |         MinQ1Vals |             129 |
# |     AverageQ2Vals |             170 |
# |         StdQ2Vals |            9.76 |
# |         MaxQ2Vals |             195 |
# |         MinQ2Vals |             129 |
# |      AverageLogPi |           -5.01 |
# |          StdLogPi |            1.03 |
# |          MaxLogPi |            2.57 |
# |          MinLogPi |           -11.8 |
# |            LossPi |            -171 |
# |             LossQ |           0.747 |
# |              Time |        2.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             967 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |        1.02e+03 |
# |          MinEpRet |             945 |
# |  AverageTestEpRet |             782 |
# |      StdTestEpRet |            58.1 |
# |      MaxTestEpRet |             836 |
# |      MinTestEpRet |             632 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             171 |
# |         StdQ1Vals |            10.1 |
# |         MaxQ1Vals |             195 |
# |         MinQ1Vals |             129 |
# |     AverageQ2Vals |             171 |
# |         StdQ2Vals |            10.1 |
# |         MaxQ2Vals |             195 |
# |         MinQ2Vals |             129 |
# |      AverageLogPi |           -4.98 |
# |          StdLogPi |            1.06 |
# |          MaxLogPi |            3.63 |
# |          MinLogPi |           -12.4 |
# |            LossPi |            -172 |
# |             LossQ |           0.755 |
# |              Time |        2.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           1e+03 |
# |          StdEpRet |            32.7 |
# |          MaxEpRet |        1.03e+03 |
# |          MinEpRet |             948 |
# |  AverageTestEpRet |             874 |
# |      StdTestEpRet |            86.5 |
# |      MaxTestEpRet |         1.1e+03 |
# |      MinTestEpRet |             802 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             172 |
# |         StdQ1Vals |            10.4 |
# |         MaxQ1Vals |             197 |
# |         MinQ1Vals |             129 |
# |     AverageQ2Vals |             172 |
# |         StdQ2Vals |            10.4 |
# |         MaxQ2Vals |             197 |
# |         MinQ2Vals |             129 |
# |      AverageLogPi |           -4.98 |
# |          StdLogPi |            1.07 |
# |          MaxLogPi |            3.68 |
# |          MinLogPi |           -13.7 |
# |            LossPi |            -173 |
# |             LossQ |           0.794 |
# |              Time |        3.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             880 |
# |          StdEpRet |             116 |
# |          MaxEpRet |        1.04e+03 |
# |          MinEpRet |             750 |
# |  AverageTestEpRet |             911 |
# |      StdTestEpRet |             115 |
# |      MaxTestEpRet |         1.1e+03 |
# |      MinTestEpRet |             678 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             173 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |             198 |
# |         MinQ1Vals |             129 |
# |     AverageQ2Vals |             173 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |             198 |
# |         MinQ2Vals |             129 |
# |      AverageLogPi |           -4.97 |
# |          StdLogPi |            1.07 |
# |          MaxLogPi |            3.76 |
# |          MinLogPi |           -11.7 |
# |            LossPi |            -174 |
# |             LossQ |           0.808 |
# |              Time |        3.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        1.07e+03 |
# |          StdEpRet |            17.8 |
# |          MaxEpRet |        1.09e+03 |
# |          MinEpRet |        1.04e+03 |
# |  AverageTestEpRet |             844 |
# |      StdTestEpRet |            49.5 |
# |      MaxTestEpRet |             925 |
# |      MinTestEpRet |             787 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             174 |
# |         StdQ1Vals |            10.9 |
# |         MaxQ1Vals |             201 |
# |         MinQ1Vals |             130 |
# |     AverageQ2Vals |             174 |
# |         StdQ2Vals |            10.9 |
# |         MaxQ2Vals |             199 |
# |         MinQ2Vals |             130 |
# |      AverageLogPi |           -4.95 |
# |          StdLogPi |            1.09 |
# |          MaxLogPi |            3.93 |
# |          MinLogPi |           -12.7 |
# |            LossPi |            -175 |
# |             LossQ |           0.806 |
# |              Time |        3.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        1.04e+03 |
# |          StdEpRet |            75.4 |
# |          MaxEpRet |         1.1e+03 |
# |          MinEpRet |             914 |
# |  AverageTestEpRet |             980 |
# |      StdTestEpRet |             113 |
# |      MaxTestEpRet |        1.16e+03 |
# |      MinTestEpRet |             763 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             175 |
# |         StdQ1Vals |            11.3 |
# |         MaxQ1Vals |             202 |
# |         MinQ1Vals |             130 |
# |     AverageQ2Vals |             175 |
# |         StdQ2Vals |            11.3 |
# |         MaxQ2Vals |             200 |
# |         MinQ2Vals |             130 |
# |      AverageLogPi |           -4.94 |
# |          StdLogPi |             1.1 |
# |          MaxLogPi |            5.71 |
# |          MinLogPi |           -12.4 |
# |            LossPi |            -176 |
# |             LossQ |           0.854 |
# |              Time |        3.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             998 |
# |          StdEpRet |             133 |
# |          MaxEpRet |         1.1e+03 |
# |          MinEpRet |             769 |
# |  AverageTestEpRet |             979 |
# |      StdTestEpRet |            98.7 |
# |      MaxTestEpRet |        1.15e+03 |
# |      MinTestEpRet |             882 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             176 |
# |         StdQ1Vals |            11.6 |
# |         MaxQ1Vals |             202 |
# |         MinQ1Vals |             131 |
# |     AverageQ2Vals |             176 |
# |         StdQ2Vals |            11.6 |
# |         MaxQ2Vals |             201 |
# |         MinQ2Vals |             130 |
# |      AverageLogPi |            -4.9 |
# |          StdLogPi |            1.14 |
# |          MaxLogPi |            5.66 |
# |          MinLogPi |           -11.8 |
# |            LossPi |            -177 |
# |             LossQ |           0.871 |
# |              Time |        3.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |        1.11e+03 |
# |          StdEpRet |            52.4 |
# |          MaxEpRet |        1.17e+03 |
# |          MinEpRet |        1.04e+03 |
# |  AverageTestEpRet |             785 |
# |      StdTestEpRet |            70.6 |
# |      MaxTestEpRet |             894 |
# |      MinTestEpRet |             683 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             177 |
# |         StdQ1Vals |            11.9 |
# |         MaxQ1Vals |             203 |
# |         MinQ1Vals |             131 |
# |     AverageQ2Vals |             177 |
# |         StdQ2Vals |            11.9 |
# |         MaxQ2Vals |             202 |
# |         MinQ2Vals |             131 |
# |      AverageLogPi |           -4.87 |
# |          StdLogPi |            1.17 |
# |          MaxLogPi |            6.32 |
# |          MinLogPi |           -15.1 |
# |            LossPi |            -178 |
# |             LossQ |           0.875 |
# |              Time |        3.74e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |         1.1e+03 |
# |          StdEpRet |            36.9 |
# |          MaxEpRet |        1.15e+03 |
# |          MinEpRet |        1.05e+03 |
# |  AverageTestEpRet |        1.04e+03 |
# |      StdTestEpRet |             175 |
# |      MaxTestEpRet |        1.27e+03 |
# |      MinTestEpRet |             845 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             178 |
# |         StdQ1Vals |            12.2 |
# |         MaxQ1Vals |             204 |
# |         MinQ1Vals |             131 |
# |     AverageQ2Vals |             178 |
# |         StdQ2Vals |            12.2 |
# |         MaxQ2Vals |             203 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.83 |
# |          StdLogPi |             1.2 |
# |          MaxLogPi |            4.56 |
# |          MinLogPi |           -12.5 |
# |            LossPi |            -179 |
# |             LossQ |           0.893 |
# |              Time |        3.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        1.11e+03 |
# |          StdEpRet |            14.7 |
# |          MaxEpRet |        1.14e+03 |
# |          MinEpRet |         1.1e+03 |
# |  AverageTestEpRet |             932 |
# |      StdTestEpRet |             206 |
# |      MaxTestEpRet |        1.21e+03 |
# |      MinTestEpRet |             674 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |             179 |
# |         StdQ1Vals |            12.5 |
# |         MaxQ1Vals |             204 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             179 |
# |         StdQ2Vals |            12.5 |
# |         MaxQ2Vals |             203 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.83 |
# |          StdLogPi |             1.2 |
# |          MaxLogPi |            9.84 |
# |          MinLogPi |           -12.6 |
# |            LossPi |            -180 |
# |             LossQ |           0.923 |
# |              Time |        4.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        1.12e+03 |
# |          StdEpRet |            23.4 |
# |          MaxEpRet |        1.15e+03 |
# |          MinEpRet |         1.1e+03 |
# |  AverageTestEpRet |        1.16e+03 |
# |      StdTestEpRet |             115 |
# |      MaxTestEpRet |        1.27e+03 |
# |      MinTestEpRet |             903 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |             179 |
# |         StdQ1Vals |            12.7 |
# |         MaxQ1Vals |             204 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             179 |
# |         StdQ2Vals |            12.7 |
# |         MaxQ2Vals |             203 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.79 |
# |          StdLogPi |            1.23 |
# |          MaxLogPi |               5 |
# |          MinLogPi |           -12.6 |
# |            LossPi |            -180 |
# |             LossQ |           0.949 |
# |              Time |        4.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |        1.15e+03 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |        1.16e+03 |
# |          MinEpRet |        1.13e+03 |
# |  AverageTestEpRet |         1.2e+03 |
# |      StdTestEpRet |             107 |
# |      MaxTestEpRet |        1.27e+03 |
# |      MinTestEpRet |             901 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             180 |
# |         StdQ1Vals |            12.9 |
# |         MaxQ1Vals |             205 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             180 |
# |         StdQ2Vals |            12.9 |
# |         MaxQ2Vals |             205 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.77 |
# |          StdLogPi |            1.25 |
# |          MaxLogPi |            3.28 |
# |          MinLogPi |           -13.1 |
# |            LossPi |            -181 |
# |             LossQ |           0.969 |
# |              Time |        4.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        1.13e+03 |
# |          StdEpRet |              48 |
# |          MaxEpRet |        1.18e+03 |
# |          MinEpRet |        1.05e+03 |
# |  AverageTestEpRet |         1.2e+03 |
# |      StdTestEpRet |              81 |
# |      MaxTestEpRet |        1.25e+03 |
# |      MinTestEpRet |             958 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             181 |
# |         StdQ1Vals |            13.2 |
# |         MaxQ1Vals |             204 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             181 |
# |         StdQ2Vals |            13.2 |
# |         MaxQ2Vals |             205 |
# |         MinQ2Vals |             131 |
# |      AverageLogPi |           -4.74 |
# |          StdLogPi |            1.28 |
# |          MaxLogPi |            5.01 |
# |          MinLogPi |           -14.4 |
# |            LossPi |            -182 |
# |             LossQ |               1 |
# |              Time |        4.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |        1.19e+03 |
# |          StdEpRet |            21.1 |
# |          MaxEpRet |        1.21e+03 |
# |          MinEpRet |        1.16e+03 |
# |  AverageTestEpRet |        1.13e+03 |
# |      StdTestEpRet |             113 |
# |      MaxTestEpRet |        1.26e+03 |
# |      MinTestEpRet |             915 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             182 |
# |         StdQ1Vals |            13.4 |
# |         MaxQ1Vals |             205 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             182 |
# |         StdQ2Vals |            13.4 |
# |         MaxQ2Vals |             205 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.73 |
# |          StdLogPi |            1.28 |
# |          MaxLogPi |            4.37 |
# |          MinLogPi |           -12.4 |
# |            LossPi |            -183 |
# |             LossQ |               1 |
# |              Time |        4.57e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |        1.19e+03 |
# |          StdEpRet |            56.6 |
# |          MaxEpRet |        1.25e+03 |
# |          MinEpRet |        1.09e+03 |
# |  AverageTestEpRet |        1.32e+03 |
# |      StdTestEpRet |             110 |
# |      MaxTestEpRet |        1.39e+03 |
# |      MinTestEpRet |             997 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             183 |
# |         StdQ1Vals |            13.6 |
# |         MaxQ1Vals |             206 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             183 |
# |         StdQ2Vals |            13.6 |
# |         MaxQ2Vals |             207 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |            -4.7 |
# |          StdLogPi |             1.3 |
# |          MaxLogPi |            4.49 |
# |          MinLogPi |           -14.9 |
# |            LossPi |            -184 |
# |             LossQ |            1.04 |
# |              Time |         4.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |         1.2e+03 |
# |          StdEpRet |            18.8 |
# |          MaxEpRet |        1.23e+03 |
# |          MinEpRet |        1.18e+03 |
# |  AverageTestEpRet |        1.38e+03 |
# |      StdTestEpRet |            31.9 |
# |      MaxTestEpRet |        1.43e+03 |
# |      MinTestEpRet |         1.3e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             183 |
# |         StdQ1Vals |            13.7 |
# |         MaxQ1Vals |             207 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             183 |
# |         StdQ2Vals |            13.7 |
# |         MaxQ2Vals |             208 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.64 |
# |          StdLogPi |            1.34 |
# |          MaxLogPi |            4.98 |
# |          MinLogPi |           -13.4 |
# |            LossPi |            -184 |
# |             LossQ |            1.08 |
# |              Time |        4.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |        1.19e+03 |
# |          StdEpRet |            23.8 |
# |          MaxEpRet |        1.23e+03 |
# |          MinEpRet |        1.17e+03 |
# |  AverageTestEpRet |        1.01e+03 |
# |      StdTestEpRet |             109 |
# |      MaxTestEpRet |        1.23e+03 |
# |      MinTestEpRet |             852 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             184 |
# |         StdQ1Vals |            13.9 |
# |         MaxQ1Vals |             208 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             184 |
# |         StdQ2Vals |            13.9 |
# |         MaxQ2Vals |             208 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.62 |
# |          StdLogPi |            1.35 |
# |          MaxLogPi |            4.58 |
# |          MinLogPi |           -13.3 |
# |            LossPi |            -185 |
# |             LossQ |            1.09 |
# |              Time |        4.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |        1.19e+03 |
# |          StdEpRet |            38.6 |
# |          MaxEpRet |        1.23e+03 |
# |          MinEpRet |        1.13e+03 |
# |  AverageTestEpRet |        1.29e+03 |
# |      StdTestEpRet |            29.9 |
# |      MaxTestEpRet |        1.34e+03 |
# |      MinTestEpRet |        1.23e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             185 |
# |         StdQ1Vals |              14 |
# |         MaxQ1Vals |             211 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             185 |
# |         StdQ2Vals |              14 |
# |         MaxQ2Vals |             211 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |            -4.6 |
# |          StdLogPi |            1.37 |
# |          MaxLogPi |            6.58 |
# |          MinLogPi |           -12.5 |
# |            LossPi |            -186 |
# |             LossQ |            1.13 |
# |              Time |        5.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        1.21e+03 |
# |          StdEpRet |            13.6 |
# |          MaxEpRet |        1.24e+03 |
# |          MinEpRet |         1.2e+03 |
# |  AverageTestEpRet |         1.2e+03 |
# |      StdTestEpRet |             128 |
# |      MaxTestEpRet |        1.38e+03 |
# |      MinTestEpRet |             983 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             186 |
# |         StdQ1Vals |            14.1 |
# |         MaxQ1Vals |             210 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             186 |
# |         StdQ2Vals |            14.1 |
# |         MaxQ2Vals |             210 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -4.57 |
# |          StdLogPi |            1.39 |
# |          MaxLogPi |            5.62 |
# |          MinLogPi |           -14.6 |
# |            LossPi |            -187 |
# |             LossQ |            1.14 |
# |              Time |        5.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        1.23e+03 |
# |          StdEpRet |            17.3 |
# |          MaxEpRet |        1.25e+03 |
# |          MinEpRet |        1.21e+03 |
# |  AverageTestEpRet |        1.39e+03 |
# |      StdTestEpRet |             113 |
# |      MaxTestEpRet |        1.46e+03 |
# |      MinTestEpRet |        1.06e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             186 |
# |         StdQ1Vals |            14.2 |
# |         MaxQ1Vals |             211 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             186 |
# |         StdQ2Vals |            14.2 |
# |         MaxQ2Vals |             211 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.56 |
# |          StdLogPi |            1.39 |
# |          MaxLogPi |            5.88 |
# |          MinLogPi |           -13.4 |
# |            LossPi |            -187 |
# |             LossQ |            1.14 |
# |              Time |        5.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        1.17e+03 |
# |          StdEpRet |            46.9 |
# |          MaxEpRet |        1.24e+03 |
# |          MinEpRet |        1.12e+03 |
# |  AverageTestEpRet |        1.15e+03 |
# |      StdTestEpRet |             135 |
# |      MaxTestEpRet |        1.32e+03 |
# |      MinTestEpRet |             889 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             187 |
# |         StdQ1Vals |            14.3 |
# |         MaxQ1Vals |             211 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             187 |
# |         StdQ2Vals |            14.3 |
# |         MaxQ2Vals |             212 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.52 |
# |          StdLogPi |            1.42 |
# |          MaxLogPi |            4.61 |
# |          MinLogPi |           -12.9 |
# |            LossPi |            -188 |
# |             LossQ |            1.14 |
# |              Time |        5.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |         1.2e+03 |
# |          StdEpRet |            60.8 |
# |          MaxEpRet |        1.24e+03 |
# |          MinEpRet |         1.1e+03 |
# |  AverageTestEpRet |        1.15e+03 |
# |      StdTestEpRet |             152 |
# |      MaxTestEpRet |        1.47e+03 |
# |      MinTestEpRet |             939 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             187 |
# |         StdQ1Vals |            14.4 |
# |         MaxQ1Vals |             212 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             187 |
# |         StdQ2Vals |            14.4 |
# |         MaxQ2Vals |             212 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -4.52 |
# |          StdLogPi |            1.41 |
# |          MaxLogPi |            6.32 |
# |          MinLogPi |           -12.5 |
# |            LossPi |            -188 |
# |             LossQ |            1.15 |
# |              Time |        5.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        1.26e+03 |
# |          StdEpRet |            21.6 |
# |          MaxEpRet |        1.28e+03 |
# |          MinEpRet |        1.23e+03 |
# |  AverageTestEpRet |        1.27e+03 |
# |      StdTestEpRet |             223 |
# |      MaxTestEpRet |        1.47e+03 |
# |      MinTestEpRet |             963 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             188 |
# |         StdQ1Vals |            14.4 |
# |         MaxQ1Vals |             212 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             188 |
# |         StdQ2Vals |            14.4 |
# |         MaxQ2Vals |             213 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -4.49 |
# |          StdLogPi |            1.44 |
# |          MaxLogPi |            6.16 |
# |          MinLogPi |           -13.6 |
# |            LossPi |            -189 |
# |             LossQ |             1.2 |
# |              Time |         5.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        1.24e+03 |
# |          StdEpRet |            52.6 |
# |          MaxEpRet |        1.29e+03 |
# |          MinEpRet |        1.16e+03 |
# |  AverageTestEpRet |        1.18e+03 |
# |      StdTestEpRet |             151 |
# |      MaxTestEpRet |        1.44e+03 |
# |      MinTestEpRet |             976 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             189 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |             212 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             189 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |             213 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -4.47 |
# |          StdLogPi |            1.44 |
# |          MaxLogPi |             5.4 |
# |          MinLogPi |             -14 |
# |            LossPi |            -190 |
# |             LossQ |            1.21 |
# |              Time |        5.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        1.27e+03 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |        1.28e+03 |
# |          MinEpRet |        1.26e+03 |
# |  AverageTestEpRet |        1.24e+03 |
# |      StdTestEpRet |             205 |
# |      MaxTestEpRet |        1.44e+03 |
# |      MinTestEpRet |             966 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             189 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |             214 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             189 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |             214 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -4.41 |
# |          StdLogPi |            1.48 |
# |          MaxLogPi |            4.98 |
# |          MinLogPi |             -14 |
# |            LossPi |            -190 |
# |             LossQ |            1.23 |
# |              Time |        6.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |         1.3e+03 |
# |          StdEpRet |            28.3 |
# |          MaxEpRet |        1.35e+03 |
# |          MinEpRet |        1.27e+03 |
# |  AverageTestEpRet |        1.53e+03 |
# |      StdTestEpRet |            32.8 |
# |      MaxTestEpRet |        1.57e+03 |
# |      MinTestEpRet |        1.45e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             190 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |             214 |
# |         MinQ1Vals |             134 |
# |     AverageQ2Vals |             190 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |             215 |
# |         MinQ2Vals |             134 |
# |      AverageLogPi |           -4.42 |
# |          StdLogPi |            1.47 |
# |          MaxLogPi |            6.88 |
# |          MinLogPi |           -13.3 |
# |            LossPi |            -191 |
# |             LossQ |            1.24 |
# |              Time |        6.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |         1.3e+03 |
# |          StdEpRet |            35.9 |
# |          MaxEpRet |        1.35e+03 |
# |          MinEpRet |        1.26e+03 |
# |  AverageTestEpRet |        1.56e+03 |
# |      StdTestEpRet |              29 |
# |      MaxTestEpRet |         1.6e+03 |
# |      MinTestEpRet |        1.51e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             190 |
# |         StdQ1Vals |            14.6 |
# |         MaxQ1Vals |             214 |
# |         MinQ1Vals |             136 |
# |     AverageQ2Vals |             190 |
# |         StdQ2Vals |            14.6 |
# |         MaxQ2Vals |             214 |
# |         MinQ2Vals |             136 |
# |      AverageLogPi |            -4.4 |
# |          StdLogPi |            1.48 |
# |          MaxLogPi |            6.97 |
# |          MinLogPi |           -12.9 |
# |            LossPi |            -191 |
# |             LossQ |            1.24 |
# |              Time |        6.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        1.22e+03 |
# |          StdEpRet |             157 |
# |          MaxEpRet |        1.38e+03 |
# |          MinEpRet |             963 |
# |  AverageTestEpRet |         1.3e+03 |
# |      StdTestEpRet |             135 |
# |      MaxTestEpRet |        1.45e+03 |
# |      MinTestEpRet |             983 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             191 |
# |         StdQ1Vals |            14.7 |
# |         MaxQ1Vals |             215 |
# |         MinQ1Vals |             136 |
# |     AverageQ2Vals |             191 |
# |         StdQ2Vals |            14.7 |
# |         MaxQ2Vals |             215 |
# |         MinQ2Vals |             136 |
# |      AverageLogPi |           -4.41 |
# |          StdLogPi |            1.48 |
# |          MaxLogPi |            5.96 |
# |          MinLogPi |           -14.3 |
# |            LossPi |            -192 |
# |             LossQ |            1.26 |
# |              Time |        6.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        1.32e+03 |
# |          StdEpRet |            28.8 |
# |          MaxEpRet |        1.37e+03 |
# |          MinEpRet |         1.3e+03 |
# |  AverageTestEpRet |        1.52e+03 |
# |      StdTestEpRet |            24.2 |
# |      MaxTestEpRet |        1.54e+03 |
# |      MinTestEpRet |        1.47e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             191 |
# |         StdQ1Vals |            14.8 |
# |         MaxQ1Vals |             216 |
# |         MinQ1Vals |             137 |
# |     AverageQ2Vals |             191 |
# |         StdQ2Vals |            14.8 |
# |         MaxQ2Vals |             216 |
# |         MinQ2Vals |             136 |
# |      AverageLogPi |           -4.39 |
# |          StdLogPi |            1.49 |
# |          MaxLogPi |            5.88 |
# |          MinLogPi |           -15.5 |
# |            LossPi |            -192 |
# |             LossQ |            1.29 |
# |              Time |        6.62e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        1.34e+03 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |        1.36e+03 |
# |          MinEpRet |        1.32e+03 |
# |  AverageTestEpRet |        1.49e+03 |
# |      StdTestEpRet |            61.9 |
# |      MaxTestEpRet |        1.55e+03 |
# |      MinTestEpRet |        1.32e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             192 |
# |         StdQ1Vals |            14.9 |
# |         MaxQ1Vals |             216 |
# |         MinQ1Vals |             138 |
# |     AverageQ2Vals |             192 |
# |         StdQ2Vals |            14.9 |
# |         MaxQ2Vals |             216 |
# |         MinQ2Vals |             139 |
# |      AverageLogPi |           -4.36 |
# |          StdLogPi |            1.51 |
# |          MaxLogPi |            6.62 |
# |          MinLogPi |           -13.4 |
# |            LossPi |            -193 |
# |             LossQ |            1.31 |
# |              Time |        6.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        1.34e+03 |
# |          StdEpRet |            23.9 |
# |          MaxEpRet |        1.37e+03 |
# |          MinEpRet |         1.3e+03 |
# |  AverageTestEpRet |        1.39e+03 |
# |      StdTestEpRet |            32.6 |
# |      MaxTestEpRet |        1.44e+03 |
# |      MinTestEpRet |        1.35e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             192 |
# |         StdQ1Vals |            14.9 |
# |         MaxQ1Vals |             216 |
# |         MinQ1Vals |             139 |
# |     AverageQ2Vals |             192 |
# |         StdQ2Vals |            14.9 |
# |         MaxQ2Vals |             216 |
# |         MinQ2Vals |             139 |
# |      AverageLogPi |           -4.37 |
# |          StdLogPi |             1.5 |
# |          MaxLogPi |            8.44 |
# |          MinLogPi |           -12.7 |
# |            LossPi |            -193 |
# |             LossQ |            1.33 |
# |              Time |        6.89e+03 |
# ---------------------------------------

# %%
args = {'env': 'AntMuJoCoEnv-v0', 'hid': 128, 'l': 2, 
        'gamma': 0.99, 'seed':5, 'epochs':50, 
        'partially_observable': True,
        'exp_name': 'sac_POMDP_AntMuJoCoEnv_2L128'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

torch.set_num_threads(torch.get_num_threads())

sac(env_name=args['env'], actor_critic=core.MLPActorCritic,
    ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
    gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    partially_observable=args['partially_observable'],
    logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\sac_POMDP_AntMuJoCoEnv_2L128\sac_POMDP_AntMuJoCoEnv_2L128_s5\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             128,
#             128
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.2,
#     "batch_size":	100,
#     "env_name":	"AntMuJoCoEnv-v0",
#     "epochs":	50,
#     "exp_name":	"sac_POMDP_AntMuJoCoEnv_2L128",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001D4A08EA7C8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"sac_POMDP_AntMuJoCoEnv_2L128",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_AntMuJoCoEnv_2L128\\sac_POMDP_AntMuJoCoEnv_2L128_s5",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\sac_POMDP_AntMuJoCoEnv_2L128\\\\sac_POMDP_AntMuJoCoEnv_2L128_s5\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"sac_POMDP_AntMuJoCoEnv_2L128",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\sac_POMDP_AntMuJoCoEnv_2L128\\sac_POMDP_AntMuJoCoEnv_2L128_s5"
#     },
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	5,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
#
# Number of parameters: 	 pi: 31120, 	 q1: 30209, 	 q2: 30209
#
# options=
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |             589 |
# |          StdEpRet |            17.7 |
# |          MaxEpRet |             607 |
# |          MinEpRet |             568 |
# |  AverageTestEpRet |             600 |
# |      StdTestEpRet |          0.0893 |
# |      MaxTestEpRet |             600 |
# |      MinTestEpRet |             600 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            11.7 |
# |         StdQ1Vals |            6.25 |
# |         MaxQ1Vals |              26 |
# |         MinQ1Vals |          0.0347 |
# |     AverageQ2Vals |            11.7 |
# |         StdQ2Vals |            6.24 |
# |         MaxQ2Vals |              26 |
# |         MinQ2Vals |         -0.0249 |
# |      AverageLogPi |           -5.45 |
# |          StdLogPi |             0.4 |
# |          MaxLogPi |           -2.87 |
# |          MinLogPi |           -10.8 |
# |            LossPi |           -12.7 |
# |             LossQ |          0.0658 |
# |              Time |             105 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |             600 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |             613 |
# |          MinEpRet |             588 |
# |  AverageTestEpRet |             796 |
# |      StdTestEpRet |             9.3 |
# |      MaxTestEpRet |             802 |
# |      MinTestEpRet |             770 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            35.5 |
# |         StdQ1Vals |            7.43 |
# |         MaxQ1Vals |            55.6 |
# |         MinQ1Vals |            21.2 |
# |     AverageQ2Vals |            35.5 |
# |         StdQ2Vals |            7.43 |
# |         MaxQ2Vals |            55.4 |
# |         MinQ2Vals |            21.4 |
# |      AverageLogPi |           -5.43 |
# |          StdLogPi |           0.445 |
# |          MaxLogPi |           -3.16 |
# |          MinLogPi |           -11.3 |
# |            LossPi |           -36.6 |
# |             LossQ |          0.0704 |
# |              Time |             245 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |             568 |
# |          StdEpRet |             109 |
# |          MaxEpRet |             698 |
# |          MinEpRet |             396 |
# |  AverageTestEpRet |             753 |
# |      StdTestEpRet |            39.2 |
# |      MaxTestEpRet |             814 |
# |      MinTestEpRet |             717 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            58.8 |
# |         StdQ1Vals |            6.28 |
# |         MaxQ1Vals |            82.3 |
# |         MinQ1Vals |            45.3 |
# |     AverageQ2Vals |            58.8 |
# |         StdQ2Vals |            6.28 |
# |         MaxQ2Vals |              82 |
# |         MinQ2Vals |            45.3 |
# |      AverageLogPi |           -5.39 |
# |          StdLogPi |            0.52 |
# |          MaxLogPi |           -1.76 |
# |          MinLogPi |           -11.1 |
# |            LossPi |           -59.9 |
# |             LossQ |           0.106 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             574 |
# |          StdEpRet |            78.9 |
# |          MaxEpRet |             642 |
# |          MinEpRet |             441 |
# |  AverageTestEpRet |             682 |
# |      StdTestEpRet |            30.2 |
# |      MaxTestEpRet |             719 |
# |      MinTestEpRet |             640 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            78.5 |
# |         StdQ1Vals |            5.85 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |            65.3 |
# |     AverageQ2Vals |            78.5 |
# |         StdQ2Vals |            5.85 |
# |         MaxQ2Vals |             104 |
# |         MinQ2Vals |            65.4 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.562 |
# |          MaxLogPi |           -2.15 |
# |          MinLogPi |           -11.6 |
# |            LossPi |           -79.5 |
# |             LossQ |           0.134 |
# |              Time |             528 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             619 |
# |          StdEpRet |            23.5 |
# |          MaxEpRet |             649 |
# |          MinEpRet |             584 |
# |  AverageTestEpRet |             704 |
# |      StdTestEpRet |            4.82 |
# |      MaxTestEpRet |             715 |
# |      MinTestEpRet |             700 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            94.4 |
# |         StdQ1Vals |            5.51 |
# |         MaxQ1Vals |             119 |
# |         MinQ1Vals |            78.1 |
# |     AverageQ2Vals |            94.4 |
# |         StdQ2Vals |            5.51 |
# |         MaxQ2Vals |             119 |
# |         MinQ2Vals |            78.1 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.561 |
# |          MaxLogPi |            -1.7 |
# |          MinLogPi |           -10.9 |
# |            LossPi |           -95.5 |
# |             LossQ |           0.152 |
# |              Time |             666 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             642 |
# |          StdEpRet |            41.6 |
# |          MaxEpRet |             711 |
# |          MinEpRet |             608 |
# |  AverageTestEpRet |             613 |
# |      StdTestEpRet |            31.2 |
# |      MaxTestEpRet |             653 |
# |      MinTestEpRet |             532 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |             108 |
# |         StdQ1Vals |            5.54 |
# |         MaxQ1Vals |             134 |
# |         MinQ1Vals |            88.1 |
# |     AverageQ2Vals |             108 |
# |         StdQ2Vals |            5.54 |
# |         MaxQ2Vals |             133 |
# |         MinQ2Vals |            88.2 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.554 |
# |          MaxLogPi |           -1.36 |
# |          MinLogPi |           -11.9 |
# |            LossPi |            -109 |
# |             LossQ |           0.166 |
# |              Time |             804 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             657 |
# |          StdEpRet |            25.3 |
# |          MaxEpRet |             689 |
# |          MinEpRet |             630 |
# |  AverageTestEpRet |             633 |
# |      StdTestEpRet |            26.2 |
# |      MaxTestEpRet |             702 |
# |      MinTestEpRet |             611 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |             118 |
# |         StdQ1Vals |            5.69 |
# |         MaxQ1Vals |             144 |
# |         MinQ1Vals |            96.1 |
# |     AverageQ2Vals |             118 |
# |         StdQ2Vals |            5.69 |
# |         MaxQ2Vals |             144 |
# |         MinQ2Vals |            96.2 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |            0.55 |
# |          MaxLogPi |           -1.15 |
# |          MinLogPi |           -11.8 |
# |            LossPi |            -119 |
# |             LossQ |           0.172 |
# |              Time |             945 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             634 |
# |          StdEpRet |            33.6 |
# |          MaxEpRet |             679 |
# |          MinEpRet |             597 |
# |  AverageTestEpRet |             569 |
# |      StdTestEpRet |            38.9 |
# |      MaxTestEpRet |             638 |
# |      MinTestEpRet |             514 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |             127 |
# |         StdQ1Vals |            6.08 |
# |         MaxQ1Vals |             154 |
# |         MinQ1Vals |             103 |
# |     AverageQ2Vals |             127 |
# |         StdQ2Vals |            6.08 |
# |         MaxQ2Vals |             154 |
# |         MinQ2Vals |             103 |
# |      AverageLogPi |           -5.39 |
# |          StdLogPi |           0.536 |
# |          MaxLogPi |           -0.97 |
# |          MinLogPi |           -11.6 |
# |            LossPi |            -128 |
# |             LossQ |           0.194 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             684 |
# |          StdEpRet |            72.5 |
# |          MaxEpRet |             793 |
# |          MinEpRet |             601 |
# |  AverageTestEpRet |             621 |
# |      StdTestEpRet |              53 |
# |      MaxTestEpRet |             739 |
# |      MinTestEpRet |             568 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |             134 |
# |         StdQ1Vals |             6.4 |
# |         MaxQ1Vals |             160 |
# |         MinQ1Vals |             108 |
# |     AverageQ2Vals |             134 |
# |         StdQ2Vals |             6.4 |
# |         MaxQ2Vals |             160 |
# |         MinQ2Vals |             108 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.552 |
# |          MaxLogPi |           0.263 |
# |          MinLogPi |           -11.2 |
# |            LossPi |            -135 |
# |             LossQ |           0.202 |
# |              Time |        1.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             642 |
# |          StdEpRet |            31.3 |
# |          MaxEpRet |             695 |
# |          MinEpRet |             616 |
# |  AverageTestEpRet |             653 |
# |      StdTestEpRet |            43.5 |
# |      MaxTestEpRet |             704 |
# |      MinTestEpRet |             595 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |             140 |
# |         StdQ1Vals |            6.57 |
# |         MaxQ1Vals |             167 |
# |         MinQ1Vals |             112 |
# |     AverageQ2Vals |             140 |
# |         StdQ2Vals |            6.57 |
# |         MaxQ2Vals |             166 |
# |         MinQ2Vals |             112 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.547 |
# |          MaxLogPi |          -0.152 |
# |          MinLogPi |           -11.3 |
# |            LossPi |            -141 |
# |             LossQ |           0.215 |
# |              Time |        1.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             666 |
# |          StdEpRet |            14.7 |
# |          MaxEpRet |             680 |
# |          MinEpRet |             642 |
# |  AverageTestEpRet |             725 |
# |      StdTestEpRet |            32.2 |
# |      MaxTestEpRet |             786 |
# |      MinTestEpRet |             678 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |             145 |
# |         StdQ1Vals |            6.71 |
# |         MaxQ1Vals |             171 |
# |         MinQ1Vals |             116 |
# |     AverageQ2Vals |             145 |
# |         StdQ2Vals |            6.71 |
# |         MaxQ2Vals |             171 |
# |         MinQ2Vals |             116 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.559 |
# |          MaxLogPi |           -1.42 |
# |          MinLogPi |           -10.8 |
# |            LossPi |            -146 |
# |             LossQ |           0.228 |
# |              Time |        1.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             628 |
# |          StdEpRet |            28.9 |
# |          MaxEpRet |             656 |
# |          MinEpRet |             581 |
# |  AverageTestEpRet |             640 |
# |      StdTestEpRet |            73.1 |
# |      MaxTestEpRet |             763 |
# |      MinTestEpRet |             531 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |             149 |
# |         StdQ1Vals |            6.73 |
# |         MaxQ1Vals |             174 |
# |         MinQ1Vals |             119 |
# |     AverageQ2Vals |             149 |
# |         StdQ2Vals |            6.73 |
# |         MaxQ2Vals |             174 |
# |         MinQ2Vals |             118 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.563 |
# |          MaxLogPi |          -0.677 |
# |          MinLogPi |           -11.7 |
# |            LossPi |            -150 |
# |             LossQ |           0.235 |
# |              Time |        1.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             630 |
# |          StdEpRet |            62.4 |
# |          MaxEpRet |             681 |
# |          MinEpRet |             526 |
# |  AverageTestEpRet |             689 |
# |      StdTestEpRet |            29.6 |
# |      MaxTestEpRet |             705 |
# |      MinTestEpRet |             601 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |             152 |
# |         StdQ1Vals |            7.02 |
# |         MaxQ1Vals |             177 |
# |         MinQ1Vals |             121 |
# |     AverageQ2Vals |             152 |
# |         StdQ2Vals |            7.02 |
# |         MaxQ2Vals |             177 |
# |         MinQ2Vals |             121 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.558 |
# |          MaxLogPi |          -0.568 |
# |          MinLogPi |           -10.6 |
# |            LossPi |            -153 |
# |             LossQ |            0.24 |
# |              Time |        1.79e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             638 |
# |          StdEpRet |            16.6 |
# |          MaxEpRet |             661 |
# |          MinEpRet |             615 |
# |  AverageTestEpRet |             685 |
# |      StdTestEpRet |            49.6 |
# |      MaxTestEpRet |             710 |
# |      MinTestEpRet |             537 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |             154 |
# |         StdQ1Vals |            7.14 |
# |         MaxQ1Vals |             180 |
# |         MinQ1Vals |             123 |
# |     AverageQ2Vals |             154 |
# |         StdQ2Vals |            7.14 |
# |         MaxQ2Vals |             180 |
# |         MinQ2Vals |             123 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.562 |
# |          MaxLogPi |            2.84 |
# |          MinLogPi |             -12 |
# |            LossPi |            -155 |
# |             LossQ |           0.242 |
# |              Time |        1.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             657 |
# |          StdEpRet |              11 |
# |          MaxEpRet |             672 |
# |          MinEpRet |             641 |
# |  AverageTestEpRet |             719 |
# |      StdTestEpRet |            83.8 |
# |      MaxTestEpRet |             828 |
# |      MinTestEpRet |             593 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             156 |
# |         StdQ1Vals |            7.22 |
# |         MaxQ1Vals |             183 |
# |         MinQ1Vals |             125 |
# |     AverageQ2Vals |             156 |
# |         StdQ2Vals |            7.22 |
# |         MaxQ2Vals |             183 |
# |         MinQ2Vals |             125 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.556 |
# |          MaxLogPi |           0.494 |
# |          MinLogPi |           -11.4 |
# |            LossPi |            -157 |
# |             LossQ |           0.242 |
# |              Time |        2.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             678 |
# |          StdEpRet |            45.4 |
# |          MaxEpRet |             738 |
# |          MinEpRet |             615 |
# |  AverageTestEpRet |             721 |
# |      StdTestEpRet |            96.2 |
# |      MaxTestEpRet |             894 |
# |      MinTestEpRet |             591 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             158 |
# |         StdQ1Vals |            7.26 |
# |         MaxQ1Vals |             185 |
# |         MinQ1Vals |             126 |
# |     AverageQ2Vals |             158 |
# |         StdQ2Vals |            7.26 |
# |         MaxQ2Vals |             185 |
# |         MinQ2Vals |             126 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.562 |
# |          MaxLogPi |            2.01 |
# |          MinLogPi |             -11 |
# |            LossPi |            -159 |
# |             LossQ |           0.237 |
# |              Time |         2.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             634 |
# |          StdEpRet |            75.4 |
# |          MaxEpRet |             700 |
# |          MinEpRet |             511 |
# |  AverageTestEpRet |             676 |
# |      StdTestEpRet |            99.8 |
# |      MaxTestEpRet |             908 |
# |      MinTestEpRet |             602 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             160 |
# |         StdQ1Vals |            7.41 |
# |         MaxQ1Vals |             187 |
# |         MinQ1Vals |             128 |
# |     AverageQ2Vals |             160 |
# |         StdQ2Vals |            7.41 |
# |         MaxQ2Vals |             187 |
# |         MinQ2Vals |             128 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |            0.56 |
# |          MaxLogPi |            2.38 |
# |          MinLogPi |           -11.2 |
# |            LossPi |            -161 |
# |             LossQ |           0.242 |
# |              Time |        2.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             666 |
# |          StdEpRet |              28 |
# |          MaxEpRet |             693 |
# |          MinEpRet |             620 |
# |  AverageTestEpRet |             582 |
# |      StdTestEpRet |            87.6 |
# |      MaxTestEpRet |             802 |
# |      MinTestEpRet |             504 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             161 |
# |         StdQ1Vals |            7.55 |
# |         MaxQ1Vals |             189 |
# |         MinQ1Vals |             129 |
# |     AverageQ2Vals |             161 |
# |         StdQ2Vals |            7.55 |
# |         MaxQ2Vals |             189 |
# |         MinQ2Vals |             129 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.557 |
# |          MaxLogPi |            3.08 |
# |          MinLogPi |           -11.2 |
# |            LossPi |            -162 |
# |             LossQ |           0.249 |
# |              Time |        2.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             643 |
# |          StdEpRet |            80.3 |
# |          MaxEpRet |             756 |
# |          MinEpRet |             567 |
# |  AverageTestEpRet |             617 |
# |      StdTestEpRet |            95.9 |
# |      MaxTestEpRet |             809 |
# |      MinTestEpRet |             470 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             162 |
# |         StdQ1Vals |            7.77 |
# |         MaxQ1Vals |             190 |
# |         MinQ1Vals |             129 |
# |     AverageQ2Vals |             162 |
# |         StdQ2Vals |            7.77 |
# |         MaxQ2Vals |             190 |
# |         MinQ2Vals |             129 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |            0.55 |
# |          MaxLogPi |            3.58 |
# |          MinLogPi |           -11.2 |
# |            LossPi |            -163 |
# |             LossQ |           0.242 |
# |              Time |        2.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             593 |
# |          StdEpRet |            32.6 |
# |          MaxEpRet |             636 |
# |          MinEpRet |             548 |
# |  AverageTestEpRet |             666 |
# |      StdTestEpRet |            61.1 |
# |      MaxTestEpRet |             734 |
# |      MinTestEpRet |             506 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             163 |
# |         StdQ1Vals |            8.58 |
# |         MaxQ1Vals |             204 |
# |         MinQ1Vals |             130 |
# |     AverageQ2Vals |             163 |
# |         StdQ2Vals |            8.58 |
# |         MaxQ2Vals |             204 |
# |         MinQ2Vals |             130 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.542 |
# |          MaxLogPi |           0.227 |
# |          MinLogPi |           -11.9 |
# |            LossPi |            -164 |
# |             LossQ |           0.246 |
# |              Time |        2.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             625 |
# |          StdEpRet |            32.1 |
# |          MaxEpRet |             677 |
# |          MinEpRet |             597 |
# |  AverageTestEpRet |             654 |
# |      StdTestEpRet |            51.5 |
# |      MaxTestEpRet |             763 |
# |      MinTestEpRet |             594 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             163 |
# |         StdQ1Vals |            8.19 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             130 |
# |     AverageQ2Vals |             163 |
# |         StdQ2Vals |            8.19 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             130 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.539 |
# |          MaxLogPi |           -1.38 |
# |          MinLogPi |           -11.5 |
# |            LossPi |            -164 |
# |             LossQ |           0.239 |
# |              Time |         2.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             660 |
# |          StdEpRet |              21 |
# |          MaxEpRet |             683 |
# |          MinEpRet |             627 |
# |  AverageTestEpRet |             810 |
# |      StdTestEpRet |             115 |
# |      MaxTestEpRet |             943 |
# |      MinTestEpRet |             620 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             164 |
# |         StdQ1Vals |            8.06 |
# |         MaxQ1Vals |             191 |
# |         MinQ1Vals |             131 |
# |     AverageQ2Vals |             164 |
# |         StdQ2Vals |            8.06 |
# |         MaxQ2Vals |             192 |
# |         MinQ2Vals |             131 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |            0.54 |
# |          MaxLogPi |           -1.15 |
# |          MinLogPi |           -13.9 |
# |            LossPi |            -165 |
# |             LossQ |           0.245 |
# |              Time |        3.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             668 |
# |          StdEpRet |            33.6 |
# |          MaxEpRet |             711 |
# |          MinEpRet |             617 |
# |  AverageTestEpRet |             681 |
# |      StdTestEpRet |              52 |
# |      MaxTestEpRet |             769 |
# |      MinTestEpRet |             611 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             164 |
# |         StdQ1Vals |            7.98 |
# |         MaxQ1Vals |             192 |
# |         MinQ1Vals |             131 |
# |     AverageQ2Vals |             164 |
# |         StdQ2Vals |            7.98 |
# |         MaxQ2Vals |             192 |
# |         MinQ2Vals |             131 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |            0.54 |
# |          MaxLogPi |          -0.892 |
# |          MinLogPi |           -11.2 |
# |            LossPi |            -165 |
# |             LossQ |           0.246 |
# |              Time |        3.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             649 |
# |          StdEpRet |            30.4 |
# |          MaxEpRet |             698 |
# |          MinEpRet |             620 |
# |  AverageTestEpRet |             709 |
# |      StdTestEpRet |            49.3 |
# |      MaxTestEpRet |             840 |
# |      MinTestEpRet |             662 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             164 |
# |         StdQ1Vals |            7.97 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             131 |
# |     AverageQ2Vals |             164 |
# |         StdQ2Vals |            7.97 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             131 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.548 |
# |          MaxLogPi |           -1.39 |
# |          MinLogPi |           -13.1 |
# |            LossPi |            -165 |
# |             LossQ |           0.244 |
# |              Time |        3.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             629 |
# |          StdEpRet |            42.8 |
# |          MaxEpRet |             698 |
# |          MinEpRet |             582 |
# |  AverageTestEpRet |             688 |
# |      StdTestEpRet |            56.5 |
# |      MaxTestEpRet |             792 |
# |      MinTestEpRet |             611 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             165 |
# |         StdQ1Vals |            7.99 |
# |         MaxQ1Vals |             192 |
# |         MinQ1Vals |             131 |
# |     AverageQ2Vals |             165 |
# |         StdQ2Vals |            7.99 |
# |         MaxQ2Vals |             192 |
# |         MinQ2Vals |             131 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |            0.55 |
# |          MaxLogPi |           -1.19 |
# |          MinLogPi |           -12.6 |
# |            LossPi |            -166 |
# |             LossQ |           0.247 |
# |              Time |        3.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             621 |
# |          StdEpRet |            40.8 |
# |          MaxEpRet |             667 |
# |          MinEpRet |             560 |
# |  AverageTestEpRet |             756 |
# |      StdTestEpRet |            43.5 |
# |      MaxTestEpRet |             846 |
# |      MinTestEpRet |             715 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             165 |
# |         StdQ1Vals |            8.01 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             131 |
# |     AverageQ2Vals |             165 |
# |         StdQ2Vals |            8.01 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.544 |
# |          MaxLogPi |           -1.87 |
# |          MinLogPi |             -11 |
# |            LossPi |            -166 |
# |             LossQ |           0.247 |
# |              Time |        3.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             649 |
# |          StdEpRet |            29.6 |
# |          MaxEpRet |             686 |
# |          MinEpRet |             608 |
# |  AverageTestEpRet |             794 |
# |      StdTestEpRet |             103 |
# |      MaxTestEpRet |             968 |
# |      MinTestEpRet |             669 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             165 |
# |         StdQ1Vals |            7.89 |
# |         MaxQ1Vals |             192 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             165 |
# |         StdQ2Vals |            7.89 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.546 |
# |          MaxLogPi |           -1.68 |
# |          MinLogPi |           -11.9 |
# |            LossPi |            -166 |
# |             LossQ |           0.248 |
# |              Time |        3.73e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             684 |
# |          StdEpRet |            73.4 |
# |          MaxEpRet |             809 |
# |          MinEpRet |             621 |
# |  AverageTestEpRet |             746 |
# |      StdTestEpRet |            61.7 |
# |      MaxTestEpRet |             910 |
# |      MinTestEpRet |             705 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             165 |
# |         StdQ1Vals |            7.84 |
# |         MaxQ1Vals |             197 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             165 |
# |         StdQ2Vals |            7.84 |
# |         MaxQ2Vals |             197 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.544 |
# |          MaxLogPi |           -1.96 |
# |          MinLogPi |           -12.5 |
# |            LossPi |            -166 |
# |             LossQ |           0.253 |
# |              Time |        3.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             654 |
# |          StdEpRet |            51.9 |
# |          MaxEpRet |             717 |
# |          MinEpRet |             586 |
# |  AverageTestEpRet |             892 |
# |      StdTestEpRet |            47.1 |
# |      MaxTestEpRet |             975 |
# |      MinTestEpRet |             802 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            7.95 |
# |         MaxQ1Vals |             196 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            7.95 |
# |         MaxQ2Vals |             196 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.553 |
# |          MaxLogPi |           -1.51 |
# |          MinLogPi |             -11 |
# |            LossPi |            -167 |
# |             LossQ |            0.26 |
# |              Time |        4.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             663 |
# |          StdEpRet |            23.8 |
# |          MaxEpRet |             685 |
# |          MinEpRet |             624 |
# |  AverageTestEpRet |             792 |
# |      StdTestEpRet |              92 |
# |      MaxTestEpRet |             897 |
# |      MinTestEpRet |             650 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            7.95 |
# |         MaxQ1Vals |             195 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            7.95 |
# |         MaxQ2Vals |             195 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.555 |
# |          MaxLogPi |           -1.36 |
# |          MinLogPi |           -11.5 |
# |            LossPi |            -167 |
# |             LossQ |           0.257 |
# |              Time |        4.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             637 |
# |          StdEpRet |            18.3 |
# |          MaxEpRet |             662 |
# |          MinEpRet |             614 |
# |  AverageTestEpRet |             802 |
# |      StdTestEpRet |            65.5 |
# |      MaxTestEpRet |             954 |
# |      MinTestEpRet |             713 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            7.89 |
# |         MaxQ1Vals |             194 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            7.89 |
# |         MaxQ2Vals |             194 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.555 |
# |          MaxLogPi |          -0.622 |
# |          MinLogPi |           -11.3 |
# |            LossPi |            -167 |
# |             LossQ |           0.261 |
# |              Time |        4.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             673 |
# |          StdEpRet |            7.62 |
# |          MaxEpRet |             684 |
# |          MinEpRet |             666 |
# |  AverageTestEpRet |             759 |
# |      StdTestEpRet |            74.7 |
# |      MaxTestEpRet |             925 |
# |      MinTestEpRet |             658 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            7.95 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            7.95 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.38 |
# |          StdLogPi |           0.549 |
# |          MaxLogPi |           -1.34 |
# |          MinLogPi |           -10.9 |
# |            LossPi |            -167 |
# |             LossQ |           0.259 |
# |              Time |        4.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             658 |
# |          StdEpRet |            36.6 |
# |          MaxEpRet |             717 |
# |          MinEpRet |             616 |
# |  AverageTestEpRet |             784 |
# |      StdTestEpRet |            75.7 |
# |      MaxTestEpRet |             981 |
# |      MinTestEpRet |             715 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            7.94 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            7.94 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.556 |
# |          MaxLogPi |           -1.65 |
# |          MinLogPi |           -11.1 |
# |            LossPi |            -167 |
# |             LossQ |           0.261 |
# |              Time |        4.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             663 |
# |          StdEpRet |            50.8 |
# |          MaxEpRet |             737 |
# |          MinEpRet |             612 |
# |  AverageTestEpRet |             732 |
# |      StdTestEpRet |              25 |
# |      MaxTestEpRet |             801 |
# |      MinTestEpRet |             702 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            7.97 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            7.97 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             132 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |            0.56 |
# |          MaxLogPi |           -1.77 |
# |          MinLogPi |           -11.6 |
# |            LossPi |            -167 |
# |             LossQ |           0.269 |
# |              Time |        4.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             650 |
# |          StdEpRet |            11.5 |
# |          MaxEpRet |             665 |
# |          MinEpRet |             633 |
# |  AverageTestEpRet |             782 |
# |      StdTestEpRet |            56.9 |
# |      MaxTestEpRet |             868 |
# |      MinTestEpRet |             689 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            8.05 |
# |         MaxQ1Vals |             194 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            8.05 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.562 |
# |          MaxLogPi |           -1.67 |
# |          MinLogPi |           -11.3 |
# |            LossPi |            -167 |
# |             LossQ |           0.265 |
# |              Time |        4.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             635 |
# |          StdEpRet |            61.6 |
# |          MaxEpRet |             711 |
# |          MinEpRet |             542 |
# |  AverageTestEpRet |             752 |
# |      StdTestEpRet |            60.4 |
# |      MaxTestEpRet |             915 |
# |      MinTestEpRet |             705 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |             8.1 |
# |         MaxQ1Vals |             194 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |             8.1 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -5.37 |
# |          StdLogPi |           0.568 |
# |          MaxLogPi |           -1.77 |
# |          MinLogPi |           -11.5 |
# |            LossPi |            -167 |
# |             LossQ |           0.269 |
# |              Time |        4.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             656 |
# |          StdEpRet |            9.96 |
# |          MaxEpRet |             671 |
# |          MinEpRet |             644 |
# |  AverageTestEpRet |             758 |
# |      StdTestEpRet |            50.6 |
# |      MaxTestEpRet |             839 |
# |      MinTestEpRet |             690 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            8.12 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             132 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            8.12 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.574 |
# |          MaxLogPi |           -1.19 |
# |          MinLogPi |           -11.7 |
# |            LossPi |            -167 |
# |             LossQ |           0.273 |
# |              Time |        5.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             643 |
# |          StdEpRet |            36.5 |
# |          MaxEpRet |             672 |
# |          MinEpRet |             582 |
# |  AverageTestEpRet |             736 |
# |      StdTestEpRet |            50.8 |
# |      MaxTestEpRet |             793 |
# |      MinTestEpRet |             610 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            8.15 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            8.15 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.578 |
# |          MaxLogPi |           0.204 |
# |          MinLogPi |           -12.5 |
# |            LossPi |            -167 |
# |             LossQ |           0.275 |
# |              Time |         5.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |             655 |
# |          StdEpRet |            21.4 |
# |          MaxEpRet |             682 |
# |          MinEpRet |             623 |
# |  AverageTestEpRet |             707 |
# |      StdTestEpRet |            5.48 |
# |      MaxTestEpRet |             716 |
# |      MinTestEpRet |             697 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |             8.2 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |             8.2 |
# |         MaxQ2Vals |             194 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |            0.58 |
# |          MaxLogPi |          -0.715 |
# |          MinLogPi |           -11.6 |
# |            LossPi |            -167 |
# |             LossQ |           0.275 |
# |              Time |        5.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |             643 |
# |          StdEpRet |            44.6 |
# |          MaxEpRet |             703 |
# |          MinEpRet |             577 |
# |  AverageTestEpRet |             623 |
# |      StdTestEpRet |            19.5 |
# |      MaxTestEpRet |             668 |
# |      MinTestEpRet |             605 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            8.29 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            8.29 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.585 |
# |          MaxLogPi |          -0.801 |
# |          MinLogPi |           -11.9 |
# |            LossPi |            -167 |
# |             LossQ |           0.285 |
# |              Time |        5.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             673 |
# |          StdEpRet |            20.8 |
# |          MaxEpRet |             695 |
# |          MinEpRet |             639 |
# |  AverageTestEpRet |             610 |
# |      StdTestEpRet |              47 |
# |      MaxTestEpRet |             686 |
# |      MinTestEpRet |             499 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |             8.3 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             133 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |             8.3 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             133 |
# |      AverageLogPi |           -5.35 |
# |          StdLogPi |           0.588 |
# |          MaxLogPi |          -0.339 |
# |          MinLogPi |           -11.8 |
# |            LossPi |            -167 |
# |             LossQ |           0.282 |
# |              Time |        5.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             683 |
# |          StdEpRet |            23.9 |
# |          MaxEpRet |             723 |
# |          MinEpRet |             662 |
# |  AverageTestEpRet |             650 |
# |      StdTestEpRet |              49 |
# |      MaxTestEpRet |             712 |
# |      MinTestEpRet |             586 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |             8.3 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             134 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |             8.3 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             134 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.583 |
# |          MaxLogPi |           0.826 |
# |          MinLogPi |           -11.6 |
# |            LossPi |            -167 |
# |             LossQ |           0.281 |
# |              Time |        5.73e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             648 |
# |          StdEpRet |            56.9 |
# |          MaxEpRet |             747 |
# |          MinEpRet |             612 |
# |  AverageTestEpRet |             796 |
# |      StdTestEpRet |            90.2 |
# |      MaxTestEpRet |             899 |
# |      MinTestEpRet |             617 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            8.32 |
# |         MaxQ1Vals |             192 |
# |         MinQ1Vals |             134 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            8.32 |
# |         MaxQ2Vals |             192 |
# |         MinQ2Vals |             134 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.581 |
# |          MaxLogPi |          -0.058 |
# |          MinLogPi |           -12.2 |
# |            LossPi |            -167 |
# |             LossQ |           0.282 |
# |              Time |        5.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             688 |
# |          StdEpRet |            88.3 |
# |          MaxEpRet |             839 |
# |          MinEpRet |             612 |
# |  AverageTestEpRet |             787 |
# |      StdTestEpRet |            56.9 |
# |      MaxTestEpRet |             847 |
# |      MinTestEpRet |             652 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             166 |
# |         StdQ1Vals |            8.31 |
# |         MaxQ1Vals |             195 |
# |         MinQ1Vals |             134 |
# |     AverageQ2Vals |             166 |
# |         StdQ2Vals |            8.31 |
# |         MaxQ2Vals |             195 |
# |         MinQ2Vals |             135 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.584 |
# |          MaxLogPi |          0.0907 |
# |          MinLogPi |             -12 |
# |            LossPi |            -167 |
# |             LossQ |           0.279 |
# |              Time |        5.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             663 |
# |          StdEpRet |            11.6 |
# |          MaxEpRet |             682 |
# |          MinEpRet |             652 |
# |  AverageTestEpRet |             799 |
# |      StdTestEpRet |            64.3 |
# |      MaxTestEpRet |             906 |
# |      MinTestEpRet |             703 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |            8.32 |
# |         MaxQ1Vals |             195 |
# |         MinQ1Vals |             135 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |            8.32 |
# |         MaxQ2Vals |             195 |
# |         MinQ2Vals |             135 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.576 |
# |          MaxLogPi |           0.205 |
# |          MinLogPi |           -12.1 |
# |            LossPi |            -168 |
# |             LossQ |           0.283 |
# |              Time |        6.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |             619 |
# |          StdEpRet |            65.9 |
# |          MaxEpRet |             679 |
# |          MinEpRet |             508 |
# |  AverageTestEpRet |             604 |
# |      StdTestEpRet |            92.3 |
# |      MaxTestEpRet |             804 |
# |      MinTestEpRet |             492 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |            8.37 |
# |         MaxQ1Vals |             195 |
# |         MinQ1Vals |             135 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |            8.37 |
# |         MaxQ2Vals |             194 |
# |         MinQ2Vals |             135 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.574 |
# |          MaxLogPi |           0.182 |
# |          MinLogPi |           -11.5 |
# |            LossPi |            -168 |
# |             LossQ |           0.284 |
# |              Time |        6.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |             647 |
# |          StdEpRet |              22 |
# |          MaxEpRet |             670 |
# |          MinEpRet |             611 |
# |  AverageTestEpRet |             719 |
# |      StdTestEpRet |            30.1 |
# |      MaxTestEpRet |             789 |
# |      MinTestEpRet |             686 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |            8.34 |
# |         MaxQ1Vals |             195 |
# |         MinQ1Vals |             135 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |            8.34 |
# |         MaxQ2Vals |             194 |
# |         MinQ2Vals |             135 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.578 |
# |          MaxLogPi |           -1.18 |
# |          MinLogPi |             -11 |
# |            LossPi |            -168 |
# |             LossQ |           0.281 |
# |              Time |        6.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             669 |
# |          StdEpRet |            49.9 |
# |          MaxEpRet |             744 |
# |          MinEpRet |             604 |
# |  AverageTestEpRet |             787 |
# |      StdTestEpRet |            22.4 |
# |      MaxTestEpRet |             805 |
# |      MinTestEpRet |             732 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |            8.35 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             136 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |            8.35 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             136 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.569 |
# |          MaxLogPi |           -1.19 |
# |          MinLogPi |           -12.6 |
# |            LossPi |            -168 |
# |             LossQ |           0.281 |
# |              Time |        6.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             650 |
# |          StdEpRet |            12.2 |
# |          MaxEpRet |             667 |
# |          MinEpRet |             634 |
# |  AverageTestEpRet |             729 |
# |      StdTestEpRet |            72.8 |
# |      MaxTestEpRet |             853 |
# |      MinTestEpRet |             617 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |            8.34 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             136 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |            8.34 |
# |         MaxQ2Vals |             193 |
# |         MinQ2Vals |             136 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.574 |
# |          MaxLogPi |          -0.673 |
# |          MinLogPi |           -11.9 |
# |            LossPi |            -168 |
# |             LossQ |           0.288 |
# |              Time |        6.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |             649 |
# |          StdEpRet |            41.6 |
# |          MaxEpRet |             707 |
# |          MinEpRet |             595 |
# |  AverageTestEpRet |             751 |
# |      StdTestEpRet |            63.4 |
# |      MaxTestEpRet |             890 |
# |      MinTestEpRet |             685 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |             8.3 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             136 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |             8.3 |
# |         MaxQ2Vals |             192 |
# |         MinQ2Vals |             136 |
# |      AverageLogPi |           -5.36 |
# |          StdLogPi |           0.576 |
# |          MaxLogPi |           0.295 |
# |          MinLogPi |           -10.9 |
# |            LossPi |            -168 |
# |             LossQ |           0.284 |
# |              Time |        6.85e+03 |
# ---------------------------------------
