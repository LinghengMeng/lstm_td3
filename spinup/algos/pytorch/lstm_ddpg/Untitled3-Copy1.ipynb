# %%
from copy import deepcopy
import numpy as np
import torch
from torch.optim import Adam
import pybulletgym
import gym
import time
import spinup.algos.pytorch.lstm_ddpg.core as core
from spinup.utils.logx import EpochLogger
import itertools

# %%
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %%
class POMDPWrapper(gym.ObservationWrapper):
    def __init__(self, env_name):
        super().__init__(gym.make(env_name))
        
        # Remove velocity info
        # OpenAIGym
        #  1. MuJoCo
        if env_name == "HalfCheetah-v3" or env_name == "HalfCheetah-v2":
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == "Ant-v3" or env_name == "Ant-v2":
            self.remain_obs_idx = list(np.arange(0, 13)) + list(np.arange(27, 111))
        elif env_name == 'Walker2d-v3' or env_name == "Walker2d-v2":
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'Hopper-v3' or env_name == "Hopper-v2":
            self.remain_obs_idx = np.arange(0, 5)
        elif env_name == "InvertedPendulum-v2":
            self.remain_obs_idx = np.arange(0, 2)
        elif env_name == "InvertedDoublePendulum-v2":
            self.remain_obs_idx = list(np.arange(0, 5)) + list(np.arange(8, 11))
        elif env_name == "Swimmer-v3" or env_name == "Swimmer-v2":
            self.remain_obs_idx = np.arange(0, 3)
        elif env_name == "Thrower-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Striker-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Pusher-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Reacher-v2":
            self.remain_obs_idx = list(np.arange(0, 6)) + list(np.arange(8, 11))
        elif env_name == 'Humanoid-v3' or env_name == "Humanoid-v2":
            self.remain_obs_idx = list(np.arange(0, 22)) + list(np.arange(45, 185)) + list(np.arange(269, 376))
        elif env_name == 'HumanoidStandup-v2':
            self.remain_obs_idx = list(np.arange(0, 22)) + list(np.arange(45, 185)) + list(np.arange(269, 376))
        # PyBulletGym
        #  1. MuJoCo
        elif env_name == 'HalfCheetahMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'AntMuJoCoEnv-v0':
            self.remain_obs_idx = list(np.arange(0, 13)) + list(np.arange(27, 111))
        elif env_name == 'Walker2DMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'HopperMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 7)
        elif env_name == 'InvertedPendulumMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 3)
        elif env_name == 'InvertedDoublePendulumMuJoCoEnv-v0':
            self.remain_obs_idx = list(np.arange(0, 5)) + list(np.arange(8, 11))
        #  2. Roboschool
        elif env_name == 'HalfCheetahPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,26)) - set(np.arange(3,6)))
        elif env_name ==  'AntPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,28)) - set(np.arange(3,6)))
        elif env_name == 'Walker2DPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,22)) - set(np.arange(3,6)))
        elif env_name == 'HopperPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,15)) - set(np.arange(3,6)))
        elif env_name == 'InvertedPendulumPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,5)) - set([1,4]))
        elif env_name == 'InvertedDoublePendulumPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,9)) - set([1,5,8]))
        elif env_name == 'ReacherPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,9)) - set([6,8]))
        else:
            raise ValueError('POMDP for {} is not defined!'.format(env_name))
            
        # Redefine observation_space
        obs_low = np.array([-np.inf for i in range(len(self.remain_obs_idx))], dtype="float32")
        obs_high = np.array([np.inf for i in range(len(self.remain_obs_idx))], dtype="float32")
        self.observation_space = gym.spaces.Box(obs_low, obs_high)
        
    def observation(self, obs):
        return obs.flatten()[self.remain_obs_idx]

# %%
class ReplayBuffer:
    """
    A simple FIFO experience replay buffer for agents.
    """

    def __init__(self, obs_dim, act_dim, max_size):
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.max_size = max_size
        self.obs_buf = np.zeros(core.combined_shape(max_size, obs_dim), dtype=np.float32)
        self.obs2_buf = np.zeros(core.combined_shape(max_size, obs_dim), dtype=np.float32)
        self.act_buf = np.zeros(core.combined_shape(max_size, act_dim), dtype=np.float32)
        self.rew_buf = np.zeros(max_size, dtype=np.float32)
        self.done_buf = np.zeros(max_size, dtype=np.float32)
        self.ptr, self.size = 0, 0

    def store(self, obs, act, rew, next_obs, done):
        self.obs_buf[self.ptr] = obs
        self.act_buf[self.ptr] = act
        self.rew_buf[self.ptr] = rew
        self.obs2_buf[self.ptr] = list(next_obs)
        self.done_buf[self.ptr] = done
        self.ptr = (self.ptr+1) % self.max_size
        self.size = min(self.size+1, self.max_size)

    def sample_batch(self, batch_size=32):
        idxs = np.random.randint(0, self.size, size=batch_size)
        batch = dict(obs=self.obs_buf[idxs],
                     obs2=self.obs2_buf[idxs],
                     act=self.act_buf[idxs],
                     rew=self.rew_buf[idxs],
                     done=self.done_buf[idxs])
        return {k: torch.as_tensor(v, dtype=torch.float32) for k,v in batch.items()}
    
    def sample_batch_with_history(self, batch_size=32, max_hist_len=100):
        idxs = np.random.randint(max_hist_len, self.size, size=batch_size)
        # History 
        if max_hist_len == 0:
            hist_obs = np.zeros([batch_size, 1, self.obs_dim])
            hist_act = np.zeros([batch_size, 1, self.act_dim])
            hist_obs2 = np.zeros([batch_size, 1, self.obs_dim])
            hist_act2 = np.zeros([batch_size, 1, self.act_dim])
            hist_rew = np.zeros([batch_size, 1])
            hist_done = np.zeros([batch_size, 1])
            hist_len = np.zeros(batch_size)
#             hist_msk = np.tile((hist_len!=0).astype(float).reshape([-1,1]), [1, 12]).shape
        else:
            hist_obs = np.zeros([batch_size, max_hist_len, self.obs_dim])
            hist_act = np.zeros([batch_size, max_hist_len, self.act_dim])
            hist_obs2 = np.zeros([batch_size, max_hist_len, self.obs_dim])
            hist_act2 = np.zeros([batch_size, max_hist_len, self.act_dim])
            hist_rew = np.zeros([batch_size, max_hist_len])
            hist_done = np.zeros([batch_size, max_hist_len])
            hist_len = max_hist_len * np.ones(batch_size)
            for hist_i in range(max_hist_len):
                hist_obs[:, -1-hist_i, :] = self.obs_buf[idxs-hist_i-1, :]
                hist_act[:, -1-hist_i, :] = self.act_buf[idxs-hist_i-1, :]
                hist_obs2[:, -1-hist_i, :] = self.obs2_buf[idxs-hist_i-1, :]
                hist_act2[:, -1-hist_i, :] = self.act_buf[idxs-hist_i, :]  # include a_t
                hist_rew[:, -1-hist_i] = self.rew_buf[idxs-hist_i-1]
                hist_done[:, -1-hist_i] = self.done_buf[idxs-hist_i-1]
            # If there is done in the backward experiences, only consider the experiences after the last done.
            for batch_i in range(batch_size):
                done_idxs_exclude_last_exp = np.where(hist_done[batch_i][:-1] == 1)  # Exclude last experience
                # If exist done
                if done_idxs_exclude_last_exp[0].size != 0:
                    largest_done_id = done_idxs_exclude_last_exp[0][-1]
                    hist_len[batch_i] = max_hist_len - (largest_done_id+1)

                    # Only keep experiences after the last done
                    obs_keep_part = np.copy(hist_obs[batch_i, largest_done_id+1:, :])
                    act_keep_part = np.copy(hist_act[batch_i, largest_done_id+1:, :])
                    obs2_keep_part = np.copy(hist_obs2[batch_i, largest_done_id+1:, :])
                    act2_keep_part = np.copy(hist_act2[batch_i, largest_done_id+1:, :])
                    rew_keep_part = np.copy(hist_rew[batch_i, largest_done_id+1:])
                    done_keep_part = np.copy(hist_done[batch_i, largest_done_id+1:])

                    # Set to 0 to make sure all experiences are at the beginning
                    hist_obs[batch_i] = np.zeros([max_hist_len, self.obs_dim])
                    hist_act[batch_i] = np.zeros([max_hist_len, self.act_dim])
                    hist_obs2[batch_i] = np.zeros([max_hist_len, self.obs_dim])
                    hist_act2[batch_i] = np.zeros([max_hist_len, self.act_dim])
                    hist_rew[batch_i] = np.zeros([max_hist_len])
                    hist_done[batch_i] = np.zeros([max_hist_len])

                    # Move kept experiences to the start of the segment
                    hist_obs[batch_i, :max_hist_len-(largest_done_id+1), :] = obs_keep_part
                    hist_act[batch_i, :max_hist_len-(largest_done_id+1), :] = act_keep_part
                    hist_obs2[batch_i, :max_hist_len-(largest_done_id+1), :] = obs2_keep_part
                    hist_act2[batch_i, :max_hist_len-(largest_done_id+1), :] = act2_keep_part
                    hist_rew[batch_i, :max_hist_len-(largest_done_id+1)] = rew_keep_part
                    hist_done[batch_i, :max_hist_len-(largest_done_id+1)] = done_keep_part
        # 
        batch = dict(obs=self.obs_buf[idxs],
                     obs2=self.obs2_buf[idxs],
                     act=self.act_buf[idxs],
                     rew=self.rew_buf[idxs],
                     done=self.done_buf[idxs],
                     hist_obs=hist_obs,
                     hist_act=hist_act,
                     hist_obs2=hist_obs2,
                     hist_act2=hist_act2,
                     hist_rew=hist_rew,
                     hist_done=hist_done,
                     hist_len=hist_len)
        return {k: torch.as_tensor(v, dtype=torch.float32) for k,v in batch.items()}

# %%
class MLPCritic(nn.Module):
    def __init__(self, obs_dim, act_dim, 
                 mem_pre_lstm_hid_sizes=(128,),
                 mem_lstm_hid_sizes=(128,),
                 cur_feature_hid_sizes=(128,),
                 post_comb_hid_sizes=(128,), mem_gate=True):
        super(MLPCritic, self).__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.mem_gate = mem_gate
        #
        self.mem_pre_lstm_layers = nn.ModuleList()
        self.mem_lstm_layers = nn.ModuleList()
        
        self.mem_gate_layer = nn.ModuleList()
        
        self.cur_feature_layers = nn.ModuleList()
        self.post_combined_layers = nn.ModuleList()
        # Memory
        #    Pre-LSTM
        mem_pre_lstm_layer_size = [obs_dim+act_dim] + list(mem_pre_lstm_hid_sizes)
        for h in range(len(mem_pre_lstm_layer_size)-1):
            self.mem_pre_lstm_layers += [nn.Linear(mem_pre_lstm_layer_size[h], 
                                                   mem_pre_lstm_layer_size[h+1]),
                                         nn.ReLU()]
        #    LSTM
        self.mem_lstm_layer_sizes = [mem_pre_lstm_layer_size[-1]] + list(mem_lstm_hid_sizes)
        for h in range(len(self.mem_lstm_layer_sizes)-1):
            self.mem_lstm_layers += [nn.LSTM(self.mem_lstm_layer_sizes[h], self.mem_lstm_layer_sizes[h+1], batch_first=True)]
        
        #    Memeory Gate
        if self.mem_gate:
            self.mem_gate_layer += [nn.Linear(self.mem_lstm_layer_sizes[-1]+obs_dim+act_dim, self.mem_lstm_layer_sizes[-1]),
                                    nn.Sigmoid()]
        
        # Current Feature Extraction
        cur_feature_layer_size = [obs_dim+act_dim]+list(cur_feature_hid_sizes) 
        for h in range(len(cur_feature_layer_size)-1):
            self.cur_feature_layers += [nn.Linear(cur_feature_layer_size[h], cur_feature_layer_size[h+1]),
                                        nn.ReLU()]
        
        # Post-Combination 
        post_combined_layer_size = [self.mem_lstm_layer_sizes[-1]+cur_feature_layer_size[-1]]+list(post_comb_hid_sizes) + [1]
        for h in range(len(post_combined_layer_size)-2):
            self.post_combined_layers += [nn.Linear(post_combined_layer_size[h], post_combined_layer_size[h+1]), nn.ReLU()]
        self.post_combined_layers += [nn.Linear(post_combined_layer_size[-2], post_combined_layer_size[-1]), nn.Identity()]
    
    def forward(self, obs, act, hist_obs, hist_act, hist_seg_len):
        #
        tmp_hist_seg_len = deepcopy(hist_seg_len)
        tmp_hist_seg_len[hist_seg_len == 0] = 1
        
        x = torch.cat([hist_obs, hist_act], dim=-1)
        
        # Memory
        #    Pre-LSTM
        for layer in self.mem_pre_lstm_layers:
            x = layer(x)
        #    LSTM
        for layer in self.mem_lstm_layers:
             x, (lstm_hidden_state, lstm_cell_state) = layer(x)
        hist_out = torch.gather(x, 1, (tmp_hist_seg_len-1).view(-1,1).repeat(1, self.mem_lstm_layer_sizes[-1]).unsqueeze(1).long()).squeeze(1)
        hist_msk = (hist_seg_len != 0).float().view(-1,1).repeat(1, self.mem_lstm_layer_sizes[-1]).cuda()
        #   Memory Gate
        if self.mem_gate:
            memory_gate = torch.cat([hist_out*hist_msk, obs, act], dim=-1)
            for layer in self.mem_gate_layer:
                memory_gate = layer(memory_gate)
            
        # Current Feature Extraction
        x = torch.cat([obs, act], dim=-1)
        for layer in self.cur_feature_layers:
            x = layer(x)
        # Post-Combination
        if self.mem_gate:
            x = torch.cat([memory_gate*hist_out*hist_msk, x], dim=-1)
        else:
            x = torch.cat([hist_out*hist_msk, x], dim=-1)
        
        for layer in self.post_combined_layers:
            x = layer(x)
        return torch.squeeze(x, -1) # Critical to ensure q has right shape.

class MLPActor(nn.Module):
    def __init__(self, obs_dim, act_dim, act_limit, 
                 mem_pre_lstm_hid_sizes=(128,),
                 mem_lstm_hid_sizes=(128,),
                 cur_feature_hid_sizes=(128,),
                 post_comb_hid_sizes=(128,), mem_gate=True):
        super(MLPActor, self).__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.act_limit = act_limit
        self.mem_gate = mem_gate
        #
        self.mem_pre_lstm_layers = nn.ModuleList()
        self.mem_lstm_layers = nn.ModuleList()
        
        self.mem_gate_layer = nn.ModuleList()
        
        self.cur_feature_layers = nn.ModuleList()
        self.post_combined_layers = nn.ModuleList()
        
        # Memory
        #    Pre-LSTM
        mem_pre_lstm_layer_size = [obs_dim+act_dim] + list(mem_pre_lstm_hid_sizes)
        for h in range(len(mem_pre_lstm_layer_size)-1):
            self.mem_pre_lstm_layers += [nn.Linear(mem_pre_lstm_layer_size[h], 
                                                   mem_pre_lstm_layer_size[h+1]),
                                         nn.ReLU()]
        #    LSTM
        self.mem_lstm_layer_sizes = [mem_pre_lstm_layer_size[-1]] + list(mem_lstm_hid_sizes)
        for h in range(len(self.mem_lstm_layer_sizes)-1):
            self.mem_lstm_layers += [nn.LSTM(self.mem_lstm_layer_sizes[h], self.mem_lstm_layer_sizes[h+1], batch_first=True)]
        
        #    Memeory Gate
        if self.mem_gate:
            self.mem_gate_layer += [nn.Linear(self.mem_lstm_layer_sizes[-1]+obs_dim, self.mem_lstm_layer_sizes[-1]),
                                    nn.Sigmoid()]
        
        # Current Feature Extraction
        cur_feature_layer_size = [obs_dim]+list(cur_feature_hid_sizes) 
        for h in range(len(cur_feature_layer_size)-1):
            self.cur_feature_layers += [nn.Linear(cur_feature_layer_size[h], cur_feature_layer_size[h+1]),
                                        nn.ReLU()]
        
        # Post-Combination 
        post_combined_layer_size = [self.mem_lstm_layer_sizes[-1]+cur_feature_layer_size[-1]]+list(post_comb_hid_sizes) + [act_dim]
        for h in range(len(post_combined_layer_size)-2):
            self.post_combined_layers += [nn.Linear(post_combined_layer_size[h], post_combined_layer_size[h+1]), nn.ReLU()]
        self.post_combined_layers += [nn.Linear(post_combined_layer_size[-2], post_combined_layer_size[-1]), nn.Tanh()]
    
    def forward(self, obs, hist_obs, hist_act, hist_seg_len):
        #
        tmp_hist_seg_len = deepcopy(hist_seg_len)
        tmp_hist_seg_len[hist_seg_len == 0] = 1
        
        x = torch.cat([hist_obs, hist_act], dim=-1)
        
        # Memory
        #    Pre-LSTM
        for layer in self.mem_pre_lstm_layers:
            x = layer(x)
        #    LSTM
        for layer in self.mem_lstm_layers:
             x, (lstm_hidden_state, lstm_cell_state) = layer(x)
        hist_out = torch.gather(x, 1, (tmp_hist_seg_len-1).view(-1,1).repeat(1, self.mem_lstm_layer_sizes[-1]).unsqueeze(1).long()).squeeze(1)
        hist_msk = (hist_seg_len != 0).float().view(-1,1).repeat(1, self.mem_lstm_layer_sizes[-1]).cuda()
        #   Memory Gate
        if self.mem_gate:
            memory_gate = torch.cat([hist_out*hist_msk, obs], dim=-1)
            for layer in self.mem_gate_layer:
                memory_gate = layer(memory_gate)
            
        # Current Feature Extraction
        x = obs
        for layer in self.cur_feature_layers:
            x = layer(x)
        # Post-Combination
        if self.mem_gate:
            x = torch.cat([memory_gate*hist_out*hist_msk, x], dim=-1)
        else:
            x = torch.cat([hist_out*hist_msk, x], dim=-1)
        
        for layer in self.post_combined_layers:
            x = layer(x)
        return self.act_limit * x

class MLPActorCritic(nn.Module):
    def __init__(self, obs_dim, act_dim, act_limit=1, 
                 critic_mem_pre_lstm_hid_sizes=(128,),
                 critic_mem_lstm_hid_sizes=(128,),
                 critic_cur_feature_hid_sizes=(128,),
                 critic_post_comb_hid_sizes=(128,), critic_mem_gate=True,
                 actor_mem_pre_lstm_hid_sizes=(128,),
                 actor_mem_lstm_hid_sizes=(128,),
                 actor_cur_feature_hid_sizes=(128,),
                 actor_post_comb_hid_sizes=(128,), actor_mem_gate=True):
        super(MLPActorCritic, self).__init__()
        self.q1 = MLPCritic(obs_dim, act_dim, 
                            mem_pre_lstm_hid_sizes=critic_mem_pre_lstm_hid_sizes,
                            mem_lstm_hid_sizes=critic_mem_lstm_hid_sizes,
                            cur_feature_hid_sizes=critic_cur_feature_hid_sizes,
                            post_comb_hid_sizes=critic_post_comb_hid_sizes, mem_gate=critic_mem_gate)
        self.q2 = MLPCritic(obs_dim, act_dim, 
                            mem_pre_lstm_hid_sizes=critic_mem_pre_lstm_hid_sizes,
                            mem_lstm_hid_sizes=critic_mem_lstm_hid_sizes,
                            cur_feature_hid_sizes=critic_cur_feature_hid_sizes,
                            post_comb_hid_sizes=critic_post_comb_hid_sizes, mem_gate=critic_mem_gate)
        self.pi = MLPActor(obs_dim, act_dim, act_limit,
                           mem_pre_lstm_hid_sizes=actor_mem_pre_lstm_hid_sizes,
                           mem_lstm_hid_sizes=actor_mem_lstm_hid_sizes,
                           cur_feature_hid_sizes=actor_cur_feature_hid_sizes,
                           post_comb_hid_sizes=actor_post_comb_hid_sizes, mem_gate=actor_mem_gate)
    
    def act(self, obs, hist_obs=None, hist_act=None, hist_seg_len=None):
        if (hist_obs is None) or (hist_act is None) or (hist_seg_len is None):
            hist_obs = torch.zeros(1, 1, self.obs_dim).cuda()
            hist_act = torch.zeros(1, 1, self.act_dim).cuda()
            hist_seg_len = torch.zeros(1).cuda()
        with torch.no_grad():
            return self.pi(obs, hist_obs, hist_act, hist_seg_len).cpu().numpy()

# %%
device = torch.device("cuda")
device
# Out:
# device(type='cuda')

# %%
device = "cuda"
torch.device(device)
# Out:
# device(type='cuda')

# %%
torch.rand([2,3]).to(device)
# Out:
# tensor([[0.2285, 0.5924, 0.4242],
#         [0.5068, 0.9532, 0.4619]], device='cuda:0')

# %%
def td3(env_name, actor_critic=core.MLPActorCritic, ac_kwargs=dict(), seed=0, 
        steps_per_epoch=4000, epochs=100, replay_size=int(1e6), gamma=0.99, 
        polyak=0.995, pi_lr=1e-3, q_lr=1e-3, 
        batch_size=100, max_hist_len=100,
        start_steps=10000, 
        update_after=1000, update_every=50, act_noise=0.1, target_noise=0.2, 
        noise_clip=0.5, policy_delay=2, num_test_episodes=10, max_ep_len=1000, 
        nonstationary_env = True,
        gravity_change_pattern = 'gravity_averagely_equal',
        partially_observable = False,
        freeze_hist_coding = False,
        logger_kwargs=dict(), save_freq=1):
    """
    Twin Delayed Deep Deterministic Policy Gradient (TD3)


    Args:
        env_fn : A function which creates a copy of the environment.
            The environment must satisfy the OpenAI Gym API.

        actor_critic: The constructor method for a PyTorch Module with an ``act`` 
            method, a ``pi`` module, a ``q1`` module, and a ``q2`` module.
            The ``act`` method and ``pi`` module should accept batches of 
            observations as inputs, and ``q1`` and ``q2`` should accept a batch 
            of observations and a batch of actions as inputs. When called, 
            these should return:

            ===========  ================  ======================================
            Call         Output Shape      Description
            ===========  ================  ======================================
            ``act``      (batch, act_dim)  | Numpy array of actions for each 
                                           | observation.
            ``pi``       (batch, act_dim)  | Tensor containing actions from policy
                                           | given observations.
            ``q1``       (batch,)          | Tensor containing one current estimate
                                           | of Q* for the provided observations
                                           | and actions. (Critical: make sure to
                                           | flatten this!)
            ``q2``       (batch,)          | Tensor containing the other current 
                                           | estimate of Q* for the provided observations
                                           | and actions. (Critical: make sure to
                                           | flatten this!)
            ===========  ================  ======================================

        ac_kwargs (dict): Any kwargs appropriate for the ActorCritic object 
            you provided to TD3.

        seed (int): Seed for random number generators.

        steps_per_epoch (int): Number of steps of interaction (state-action pairs) 
            for the agent and the environment in each epoch.

        epochs (int): Number of epochs to run and train agent.

        replay_size (int): Maximum length of replay buffer.

        gamma (float): Discount factor. (Always between 0 and 1.)

        polyak (float): Interpolation factor in polyak averaging for target 
            networks. Target networks are updated towards main networks 
            according to:

            .. math:: \\theta_{\\text{targ}} \\leftarrow 
                \\rho \\theta_{\\text{targ}} + (1-\\rho) \\theta

            where :math:`\\rho` is polyak. (Always between 0 and 1, usually 
            close to 1.)

        pi_lr (float): Learning rate for policy.

        q_lr (float): Learning rate for Q-networks.

        batch_size (int): Minibatch size for SGD.

        start_steps (int): Number of steps for uniform-random action selection,
            before running real policy. Helps exploration.

        update_after (int): Number of env interactions to collect before
            starting to do gradient descent updates. Ensures replay buffer
            is full enough for useful updates.

        update_every (int): Number of env interactions that should elapse
            between gradient descent updates. Note: Regardless of how long 
            you wait between updates, the ratio of env steps to gradient steps 
            is locked to 1.

        act_noise (float): Stddev for Gaussian exploration noise added to 
            policy at training time. (At test time, no noise is added.)

        target_noise (float): Stddev for smoothing noise added to target 
            policy.

        noise_clip (float): Limit for absolute value of target policy 
            smoothing noise.

        policy_delay (int): Policy will only be updated once every 
            policy_delay times for each update of the Q-networks.

        num_test_episodes (int): Number of episodes to test the deterministic
            policy at the end of each epoch.

        max_ep_len (int): Maximum length of trajectory / episode / rollout.

        logger_kwargs (dict): Keyword args for EpochLogger.

        save_freq (int): How often (in terms of gap between epochs) to save
            the current policy and value function.

    """

    logger = EpochLogger(**logger_kwargs)
    logger.save_config(locals())

    torch.manual_seed(seed)
    np.random.seed(seed)

    # Wrapper environment if using POMDP
    if partially_observable == True:
        env, test_env = POMDPWrapper(env_name), POMDPWrapper(env_name)
    else:
        env, test_env = gym.make(env_name), gym.make(env_name)
    obs_dim = env.observation_space.shape[0]   
    act_dim = env.action_space.shape[0]

    # Action limit for clamping: critically, assumes all dimensions share the same bound!
    act_limit = env.action_space.high[0]

    # Create actor-critic module and target networks
    critic_mem_gate = False
    actor_mem_gate = False
    ac = MLPActorCritic( obs_dim, act_dim, act_limit, 
                         critic_mem_pre_lstm_hid_sizes=(128,),
                         critic_mem_lstm_hid_sizes=(128,),
                         critic_cur_feature_hid_sizes=(128,),
                         critic_post_comb_hid_sizes=(128,), critic_mem_gate=critic_mem_gate,
                         actor_mem_pre_lstm_hid_sizes=(128,),
                         actor_mem_lstm_hid_sizes=(128,),
                         actor_cur_feature_hid_sizes=(128,),
                         actor_post_comb_hid_sizes=(128,), actor_mem_gate=actor_mem_gate)
    ac_targ = deepcopy(ac)
    ac.cuda()
    ac_targ.cuda()
    
#     # Freeze hist coding
#     if freeze_hist_coding:
#         ac.q1.layers[0].requires_grad=False
#         ac.q2.layers[0].requires_grad=False
#         ac.pi.layers[0].requires_grad=False

    # Freeze target networks with respect to optimizers (only update via polyak averaging)
    for p in ac_targ.parameters():
        p.requires_grad = False
        
    # List of parameters for both Q-networks (save this for convenience)
    q_params = itertools.chain(ac.q1.parameters(), ac.q2.parameters())
    
    # Experience buffer
    replay_buffer = ReplayBuffer(obs_dim=obs_dim, act_dim=act_dim, max_size=replay_size)

    # Count variables (protip: try to get a feel for how different size networks behave!)
    var_counts = tuple(core.count_vars(module) for module in [ac.pi, ac.q1, ac.q2])
    logger.log('\nNumber of parameters: \t pi: %d, \t q1: %d, \t q2: %d\n'%var_counts)

    # Set up function for computing TD3 Q-losses
    def compute_loss_q(data):
        o, a, r, o2, d = data['obs'], data['act'], data['rew'], data['obs2'], data['done']
        h_o, h_a, h_o2, h_a2, h_len = data['hist_obs'], data['hist_act'], data['hist_obs2'], data['hist_act2'], data['hist_len']

        q1 = ac.q1(o, a, h_o, h_a, h_len)
        q2 = ac.q2(o, a, h_o, h_a, h_len)

        # Bellman backup for Q functions
        with torch.no_grad():
            pi_targ = ac_targ.pi(o2, h_o2, h_a2, h_len)
            
            # Target policy smoothing
            epsilon = torch.randn_like(pi_targ) * target_noise
            epsilon = torch.clamp(epsilon, -noise_clip, noise_clip)
            a2 = pi_targ + epsilon
            a2 = torch.clamp(a2, -act_limit, act_limit)

            # Target Q-values
            q1_pi_targ = ac_targ.q1(o2, a2, h_o2, h_a2, h_len)
            q2_pi_targ = ac_targ.q2(o2, a2, h_o2, h_a2, h_len)
            q_pi_targ = torch.min(q1_pi_targ, q2_pi_targ)
            q_pi_targ = q1_pi_targ
            backup = r + gamma * (1 - d) * q_pi_targ

        # MSE loss against Bellman backup
        loss_q1 = ((q1 - backup)**2).mean()
        loss_q2 = ((q2 - backup)**2).mean()
        loss_q = loss_q1 + loss_q2
        loss_q = loss_q1

        # Useful info for logging
        loss_info = dict(Q1Vals=q1.detach().cpu().numpy(),
                         Q2Vals=q2.detach().cpu().numpy())

        return loss_q, loss_info

    # Set up function for computing TD3 pi loss
    def compute_loss_pi(data):
        o, h_o, h_a, h_len = data['obs'], data['hist_obs'], data['hist_act'], data['hist_len']
        q1_pi = ac.q1(o, ac.pi(o, h_o, h_a, h_len), h_o, h_a, h_len)
        return -q1_pi.mean()

    # Set up optimizers for policy and q-function
    pi_optimizer = Adam(ac.pi.parameters(), lr=pi_lr)
    q_optimizer = Adam(q_params, lr=q_lr)

    # Set up model saving
    logger.setup_pytorch_saver(ac)

    def update(data, timer):
        # First run one gradient descent step for Q1 and Q2
        q_optimizer.zero_grad()
        loss_q, loss_info = compute_loss_q(data)
        loss_q.backward()
        q_optimizer.step()

        # Record things
        logger.store(LossQ=loss_q.item(), **loss_info)

        # Possibly update pi and target networks
        if timer % policy_delay == 0:

#             # Freeze Q-networks so you don't waste computational effort 
#             # computing gradients for them during the policy learning step.
#             for p in q_params:
#                 p.requires_grad = False

            # Next run one gradient descent step for pi.
            pi_optimizer.zero_grad()
            loss_pi = compute_loss_pi(data)
            loss_pi.backward()
            pi_optimizer.step()

#             # Unfreeze Q-networks so you can optimize it at next DDPG step.
#             for p in q_params:
#                 p.requires_grad = True

            # Record things
            logger.store(LossPi=loss_pi.item())

            # Finally, update target networks by polyak averaging.
            with torch.no_grad():
                for p, p_targ in zip(ac.parameters(), ac_targ.parameters()):
                    # NB: We use an in-place operations "mul_", "add_" to update target
                    # params, as opposed to "mul" and "add", which would make new tensors.
                    p_targ.data.mul_(polyak)
                    p_targ.data.add_((1 - polyak) * p.data)

    def get_action(o, o_buff, a_buff, o_buff_len, noise_scale):
        h_o = torch.tensor(o_buff).view(1, o_buff.shape[0], o_buff.shape[1]).float().cuda()
        h_a = torch.tensor(a_buff).view(1, a_buff.shape[0], a_buff.shape[1]).float().cuda()
        h_l = torch.tensor([o_buff_len]).float().cuda()
        with torch.no_grad(): 
            a = ac.act(torch.as_tensor(o, dtype=torch.float32).view(1,-1).cuda(),
                       h_o, h_a, h_l).reshape(act_dim)
        a += noise_scale * np.random.randn(act_dim)
        if a.shape[0]!=act_dim:
            import pdb
            pdb.set_trace()
        return np.clip(a, -act_limit, act_limit)

    def test_agent():
        for j in range(num_test_episodes):
            o, d, ep_ret, ep_len = test_env.reset(), False, 0, 0
                
            if max_hist_len>0:
                o_buff = np.zeros([max_hist_len, obs_dim])
                a_buff = np.zeros([max_hist_len, act_dim])
                o_buff[0,:] = o
                o_buff_len = 0
            else:
                o_buff = np.zeros([1, obs_dim])
                a_buff = np.zeros([1, act_dim])
                o_buff_len = 0
                
            while not(d or (ep_len == max_ep_len)):
                # Take deterministic actions at test time (noise_scale=0)
                a = get_action(o, o_buff, a_buff, o_buff_len, 0)
                o2, r, d, _ = test_env.step(a)
                
                ep_ret += r
                ep_len += 1
                # Add short history
                if max_hist_len != 0:
                    if o_buff_len == max_hist_len:
                        o_buff[:max_hist_len-1] = o_buff[1:]
                        a_buff[:max_hist_len-1] = a_buff[1:]
                        o_buff[max_hist_len-1] = list(o)
                        a_buff[max_hist_len-1] = list(a)
                    else:
                        if a.shape[0]!=act_dim:
                            import pdb
                            pdb.set_trace()
                        o_buff[o_buff_len+1-1] = list(o)
                        a_buff[o_buff_len+1-1] = list(a)
                        o_buff_len += 1
                o = o2
                
            logger.store(TestEpRet=ep_ret, TestEpLen=ep_len)

    # Prepare for interaction with environment
    total_steps = steps_per_epoch * epochs
    start_time = time.time()
    o, ep_ret, ep_len = env.reset(), 0, 0
        
    if max_hist_len>0:
        o_buff = np.zeros([max_hist_len, obs_dim])
        a_buff = np.zeros([max_hist_len, act_dim])
        o_buff[0,:] = o
        o_buff_len = 0
    else:
        o_buff = np.zeros([1, obs_dim])
        a_buff = np.zeros([1, act_dim])
        o_buff_len = 0

    # Main loop: collect experience in env and update/log each epoch
    start_time = time.time()
    for t in range(total_steps):
        if t%200 == 0:
            end_time = time.time()
            print("t={}, {}s".format(t, end_time-start_time))
            start_time = end_time
        # Until start_steps have elapsed, randomly sample actions
        # from a uniform distribution for better exploration. Afterwards, 
        # use the learned policy (with some noise, via act_noise). 
        if t > start_steps:
            a = get_action(o, o_buff, a_buff, o_buff_len, act_noise)
        else:
            a = env.action_space.sample()
        
        if nonstationary_env == True:
            gravity_cycle = 1000
            gravity_base = -9.81
            if gravity_change_pattern == 'gravity_averagely_equal':
                gravity = gravity_base * 1 / 2 * (np.cos(2 * np.pi / gravity_cycle * t) + 1) + gravity_base / 2
            elif gravity_change_pattern == 'gravity_averagely_easier':
                gravity = gravity_base * 1 / 2 * (np.cos(2 * np.pi / gravity_cycle * t) + 1)
            elif gravity_change_pattern == 'gravity_averagely_harder':
                gravity = gravity_base * 1 / 2 * (-np.cos(2 * np.pi / gravity_cycle * t) + 1) + gravity_base
            else:
                pass

            if 'PyBulletEnv' in env_name:
                env.env._p.setGravity(0, 0, gravity)
            elif 'Roboschool' in env_name:
                pass
            else:
                env.model.opt.gravity[2] = gravity
        
        # Step the env
        o2, r, d, _ = env.step(a)
            
        ep_ret += r
        ep_len += 1

        # Ignore the "done" signal if it comes from hitting the time
        # horizon (that is, when it's an artificial terminal signal
        # that isn't based on the agent's state)
        d = False if ep_len==max_ep_len else d

        # Store experience to replay buffer
        replay_buffer.store(o, a, r, o2, d)
        
        # Add short history
        if max_hist_len != 0:
            if o_buff_len == max_hist_len:
                o_buff[:max_hist_len-1] = o_buff[1:]
                a_buff[:max_hist_len-1] = a_buff[1:]
                o_buff[max_hist_len-1] = list(o)
                a_buff[max_hist_len-1] = list(a)
            else:
                if a.shape[0]!=act_dim:
                    import pdb
                    pdb.set_trace()
                o_buff[o_buff_len+1-1] = list(o)
                a_buff[o_buff_len+1-1] = list(a)
                o_buff_len += 1
        
        # Super critical, easy to overlook step: make sure to update 
        # most recent observation!
        o = o2
        
        # End of trajectory handling
        if d or (ep_len == max_ep_len):
            logger.store(EpRet=ep_ret, EpLen=ep_len)
            o, ep_ret, ep_len = env.reset(), 0, 0
                
            if max_hist_len>0:
                o_buff = np.zeros([max_hist_len, obs_dim])
                a_buff = np.zeros([max_hist_len, act_dim])
                o_buff[0,:] = o
                o_buff_len = 0
            else:
                o_buff = np.zeros([1, obs_dim])
                a_buff = np.zeros([1, act_dim])
                o_buff_len = 0
        
        # Update handling
        if t >= update_after and t % update_every == 0:
            for j in range(update_every):
                batch = replay_buffer.sample_batch_with_history(batch_size, max_hist_len)
                batch = {k: v.cuda() for k,v in batch.items()}
                update(data=batch, timer=j)

        # End of epoch handling
        if (t+1) % steps_per_epoch == 0:
            epoch = (t+1) // steps_per_epoch

            # Save model
            if (epoch % save_freq == 0) or (epoch == epochs):
                logger.save_state({'env': env}, None)

            # Test the performance of the deterministic version of the agent.
            test_agent()

            # Log info about epoch
            logger.log_tabular('Epoch', epoch)
            logger.log_tabular('EpRet', with_min_and_max=True)
            logger.log_tabular('TestEpRet', with_min_and_max=True)
            logger.log_tabular('EpLen', average_only=True)
            logger.log_tabular('TestEpLen', average_only=True)
            logger.log_tabular('TotalEnvInteracts', t)
            logger.log_tabular('Q1Vals', with_min_and_max=True)
            logger.log_tabular('Q2Vals', with_min_and_max=True)
            logger.log_tabular('LossPi', average_only=True)
            logger.log_tabular('LossQ', average_only=True)
            logger.log_tabular('Time', time.time()-start_time)
            logger.dump_tabular()

# %%
args = {'env': 'Ant-v2', 'hid': 256, 'l': 2, 
        'max_hist_len': 5,
        'gamma': 0.99, 'seed': 0, 'epochs': 50, 
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'freeze_hist_coding': False,
        'exp_name': 'RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     max_hist_len=args['max_hist_len'],
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
    freeze_hist_coding=args['freeze_hist_coding'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"Ant-v2",
#     "epochs":	50,
#     "exp_name":	"RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#     "freeze_hist_coding":	false,
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x00000209EA135D88>":	{
#             "epoch_dict":	{},
#             "exp_name":	"RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\\\RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_MemGate_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0"
#     },
#     "max_ep_len":	1000,
#     "max_hist_len":	5,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	1000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 221064, 	 q1: 222209, 	 q2: 222209
#
# t=0, 0.0s
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# t=200, 0.12566375732421875s
# t=400, 0.10871148109436035s
# t=600, 0.10671401023864746s
# t=800, 0.09773731231689453s
# t=1000, 0.0967411994934082s
# t=1200, 13.122312545776367s
# t=1400, 13.113930702209473s
# t=1600, 15.874975204467773s
# t=1800, 15.427724838256836s
# t=2000, 15.180763244628906s
# t=2200, 15.567386150360107s
# t=2400, 15.473840475082397s
# t=2600, 16.079743146896362s
# t=2800, 15.218315362930298s
# t=3000, 15.481597661972046s
# t=3200, 14.773526668548584s
# t=3400, 14.510177373886108s
# t=3600, 16.87888479232788s
# t=3800, 15.759825468063354s
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |             365 |
# |          StdEpRet |             507 |
# |          MaxEpRet |             900 |
# |          MinEpRet |            -194 |
# |  AverageTestEpRet |             864 |
# |      StdTestEpRet |            17.2 |
# |      MaxTestEpRet |             887 |
# |      MinTestEpRet |             839 |
# |             EpLen |             797 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            1.65 |
# |         StdQ1Vals |            1.95 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -8.46 |
# |     AverageQ2Vals |         0.00644 |
# |         StdQ2Vals |         0.00972 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -2.25 |
# |             LossQ |          0.0437 |
# |              Time |            71.1 |
# ---------------------------------------
# t=4000, 71.13123488426208s
# t=4200, 17.439623594284058s
# t=4400, 16.151047706604004s
# t=4600, 16.802236795425415s
# t=4800, 15.207363843917847s
# t=5000, 17.237435817718506s
# t=5200, 15.582743167877197s
# t=5400, 18.056994915008545s
# t=5600, 17.76561403274536s
# t=5800, 16.007125854492188s
# t=6000, 15.576097011566162s
# t=6200, 15.356962203979492s
# t=6400, 16.748072147369385s
# t=6600, 15.843018054962158s
# t=6800, 17.90907907485962s
# t=7000, 15.515527486801147s
# t=7200, 16.648491621017456s
# t=7400, 15.861552953720093s
# t=7600, 15.064748764038086s
# t=7800, 16.206626892089844s
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |             645 |
# |          StdEpRet |             233 |
# |          MaxEpRet |             829 |
# |          MinEpRet |             258 |
# |  AverageTestEpRet |             936 |
# |      StdTestEpRet |            57.7 |
# |      MaxTestEpRet |             972 |
# |      MinTestEpRet |             820 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            8.73 |
# |         StdQ1Vals |            3.01 |
# |         MaxQ1Vals |            21.9 |
# |         MinQ1Vals |           -8.52 |
# |     AverageQ2Vals |         0.00919 |
# |         StdQ2Vals |         0.00721 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -9.24 |
# |             LossQ |          0.0487 |
# |              Time |            67.9 |
# ---------------------------------------
# t=8000, 67.90949964523315s
# t=8200, 14.917580127716064s
# t=8400, 14.943052291870117s
# t=8600, 16.759368419647217s
# t=8800, 18.263734817504883s
# t=9000, 16.12454652786255s
# t=9200, 14.929049253463745s
# t=9400, 15.651172399520874s
# t=9600, 15.936900615692139s
# t=9800, 17.279067516326904s
# t=10000, 17.253854274749756s
# t=10200, 18.41273522377014s
# t=10400, 16.6275634765625s
# t=10600, 16.87085747718811s
# t=10800, 17.662794589996338s
# t=11000, 17.900104999542236s
# t=11200, 18.16445565223694s
# t=11400, 18.37383723258972s
# t=11600, 16.5567569732666s
# t=11800, 16.411396026611328s
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |             693 |
# |          StdEpRet |             107 |
# |          MaxEpRet |             827 |
# |          MinEpRet |             528 |
# |  AverageTestEpRet |             871 |
# |      StdTestEpRet |            33.3 |
# |      MaxTestEpRet |             893 |
# |      MinTestEpRet |             802 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |              17 |
# |         StdQ1Vals |            3.39 |
# |         MaxQ1Vals |            33.6 |
# |         MinQ1Vals |           -4.41 |
# |     AverageQ2Vals |         0.00956 |
# |         StdQ2Vals |         0.00643 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -17.5 |
# |             LossQ |          0.0786 |
# |              Time |            72.4 |
# ---------------------------------------
# t=12000, 72.38636898994446s
# t=12200, 17.419907331466675s
# t=12400, 18.034772396087646s
# t=12600, 16.723295211791992s
# t=12800, 18.915118932724s
# t=13000, 17.09686589241028s
# t=13200, 17.850276470184326s
# t=13400, 16.232561826705933s
# t=13600, 15.906466007232666s
# t=13800, 17.039464473724365s
# t=14000, 16.126872539520264s
# t=14200, 16.10490584373474s
# t=14400, 15.869421243667603s
# t=14600, 18.291075706481934s
# t=14800, 19.369927406311035s
# t=15000, 17.850061416625977s
# t=15200, 17.661921977996826s
# t=15400, 20.634004592895508s
# t=15600, 17.31157159805298s
# t=15800, 18.62220811843872s
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             681 |
# |          StdEpRet |            81.4 |
# |          MaxEpRet |             747 |
# |          MinEpRet |             541 |
# |  AverageTestEpRet |             609 |
# |      StdTestEpRet |             283 |
# |      MaxTestEpRet |             860 |
# |      MinTestEpRet |            59.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             723 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            26.5 |
# |         StdQ1Vals |            3.67 |
# |         MaxQ1Vals |              45 |
# |         MinQ1Vals |           -2.48 |
# |     AverageQ2Vals |         0.00877 |
# |         StdQ2Vals |         0.00626 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -27.2 |
# |             LossQ |             0.1 |
# |              Time |            63.8 |
# ---------------------------------------
# t=16000, 63.812830686569214s
# t=16200, 17.60939598083496s
# t=16400, 18.038832426071167s
# t=16600, 18.903124809265137s
# t=16800, 19.526382446289062s
# t=17000, 16.485023498535156s
# t=17200, 19.04219937324524s
# t=17400, 17.98063588142395s
# t=17600, 19.565022468566895s
# t=17800, 17.642081022262573s
# t=18000, 19.006139516830444s
# t=18200, 20.069640159606934s
# t=18400, 19.828697443008423s
# t=18600, 19.762868881225586s
# t=18800, 18.47179865837097s
# t=19000, 18.92264437675476s
# t=19200, 16.95480442047119s
# t=19400, 16.54913640022278s
# t=19600, 18.21571183204651s
# t=19800, 17.073726177215576s
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             326 |
# |          StdEpRet |             151 |
# |          MaxEpRet |             496 |
# |          MinEpRet |            81.1 |
# |  AverageTestEpRet |             867 |
# |      StdTestEpRet |            35.7 |
# |      MaxTestEpRet |             921 |
# |      MinTestEpRet |             807 |
# |             EpLen |             636 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            34.8 |
# |         StdQ1Vals |            3.78 |
# |         MaxQ1Vals |            53.3 |
# |         MinQ1Vals |           -7.22 |
# |     AverageQ2Vals |         0.00781 |
# |         StdQ2Vals |         0.00703 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -35.4 |
# |             LossQ |           0.223 |
# |              Time |            86.2 |
# ---------------------------------------
# t=20000, 86.15728378295898s
# t=20200, 21.419906616210938s
# t=20400, 17.031635284423828s
# t=20600, 17.851491689682007s
# t=20800, 17.2122163772583s
# t=21000, 18.6408531665802s
# t=21200, 18.648325443267822s
# t=21400, 17.558836698532104s
# t=21600, 18.405521631240845s
# t=21800, 17.96192216873169s
# t=22000, 17.36951470375061s
# t=22200, 17.468302011489868s
# t=22400, 17.51312780380249s
# t=22600, 19.191730260849s
# t=22800, 17.491174697875977s
# t=23000, 18.558531284332275s
# t=23200, 17.959048748016357s
# t=23400, 17.484734058380127s
# t=23600, 17.420769453048706s
# t=23800, 17.301848888397217s
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             637 |
# |          StdEpRet |             150 |
# |          MaxEpRet |             809 |
# |          MinEpRet |             370 |
# |  AverageTestEpRet |             810 |
# |      StdTestEpRet |            45.4 |
# |      MaxTestEpRet |             890 |
# |      MinTestEpRet |             723 |
# |             EpLen |             945 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            41.2 |
# |         StdQ1Vals |            3.96 |
# |         MaxQ1Vals |            62.6 |
# |         MinQ1Vals |           -5.74 |
# |     AverageQ2Vals |         0.00669 |
# |         StdQ2Vals |         0.00792 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -41.9 |
# |             LossQ |           0.243 |
# |              Time |              77 |
# ---------------------------------------
# t=24000, 77.00192618370056s
# t=24200, 16.898985624313354s
# t=24400, 17.376201629638672s
# t=24600, 18.140621662139893s
# t=24800, 17.265233516693115s
# t=25000, 17.106788396835327s
# t=25200, 18.186319828033447s
# t=25400, 17.488903999328613s
# t=25600, 18.14281177520752s
# t=25800, 17.04593825340271s
# t=26000, 18.02803683280945s
# t=26200, 17.135233879089355s
# t=26400, 17.264034509658813s
# t=26600, 17.380339860916138s
# t=26800, 17.619755029678345s
# t=27000, 17.33184814453125s
# t=27200, 17.270721912384033s
# t=27400, 17.504100561141968s
# t=27600, 17.106959581375122s
# t=27800, 18.413007020950317s
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             485 |
# |          StdEpRet |             321 |
# |          MaxEpRet |             803 |
# |          MinEpRet |            33.9 |
# |  AverageTestEpRet |             300 |
# |      StdTestEpRet |             303 |
# |      MaxTestEpRet |             870 |
# |      MinTestEpRet |           -6.88 |
# |             EpLen |             664 |
# |         TestEpLen |             536 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            47.4 |
# |         StdQ1Vals |            4.18 |
# |         MaxQ1Vals |            67.9 |
# |         MinQ1Vals |           -11.4 |
# |     AverageQ2Vals |         0.00635 |
# |         StdQ2Vals |         0.00814 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -48.2 |
# |             LossQ |           0.434 |
# |              Time |            48.1 |
# ---------------------------------------
# t=28000, 48.06280589103699s
# t=28200, 16.987093925476074s
# t=28400, 18.713269472122192s
# t=28600, 18.85479426383972s
# t=28800, 17.545974016189575s
# t=29000, 17.798027992248535s
# t=29200, 16.95802927017212s
# t=29400, 17.178448915481567s
# t=29600, 17.49940276145935s
# t=29800, 17.41576600074768s
# t=30000, 17.33159852027893s
# t=30200, 17.91295099258423s
# t=30400, 17.705520391464233s
# t=30600, 17.411929845809937s
# t=30800, 17.317298889160156s
# t=31000, 17.48733115196228s
# t=31200, 18.120963096618652s
# t=31400, 17.323912143707275s
# t=31600, 17.22563147544861s
# t=31800, 17.30525541305542s
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             385 |
# |          StdEpRet |             290 |
# |          MaxEpRet |             763 |
# |          MinEpRet |            21.1 |
# |  AverageTestEpRet |             542 |
# |      StdTestEpRet |             197 |
# |      MaxTestEpRet |             783 |
# |      MinTestEpRet |           -3.93 |
# |             EpLen |             588 |
# |         TestEpLen |             901 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            53.7 |
# |         StdQ1Vals |            4.27 |
# |         MaxQ1Vals |            78.1 |
# |         MinQ1Vals |           -4.73 |
# |     AverageQ2Vals |         0.00606 |
# |         StdQ2Vals |          0.0081 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -54.5 |
# |             LossQ |           0.638 |
# |              Time |            71.1 |
# ---------------------------------------
# t=32000, 71.10723114013672s
# t=32200, 17.403992891311646s
# t=32400, 20.067805528640747s
# t=32600, 17.361140251159668s
# t=32800, 17.18247365951538s
# t=33000, 17.235636234283447s
# t=33200, 17.725070238113403s
# t=33400, 18.062308073043823s
# t=33600, 17.476099014282227s
# t=33800, 17.674196004867554s
# t=34000, 17.30156421661377s
# t=34200, 17.10480308532715s
# t=34400, 18.340418338775635s
# t=34600, 18.09484624862671s
# t=34800, 17.12614393234253s
# t=35000, 17.293607711791992s
# t=35200, 17.121626377105713s
# t=35400, 17.684804916381836s
# t=35600, 18.489694833755493s
# t=35800, 17.386717796325684s
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             466 |
# |          StdEpRet |             274 |
# |          MaxEpRet |             926 |
# |          MinEpRet |            31.8 |
# |  AverageTestEpRet |             234 |
# |      StdTestEpRet |             209 |
# |      MaxTestEpRet |             744 |
# |      MinTestEpRet |            12.5 |
# |             EpLen |             593 |
# |         TestEpLen |             181 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            60.2 |
# |         StdQ1Vals |            4.44 |
# |         MaxQ1Vals |            89.6 |
# |         MinQ1Vals |           -11.2 |
# |     AverageQ2Vals |         0.00564 |
# |         StdQ2Vals |         0.00806 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -61.1 |
# |             LossQ |            1.01 |
# |              Time |            28.3 |
# ---------------------------------------
# t=36000, 28.252636909484863s
# t=36200, 17.24264144897461s
# t=36400, 19.22675132751465s
# t=36600, 17.428678512573242s
# t=36800, 17.609073877334595s
# t=37000, 17.767475128173828s
# t=37200, 18.132702112197876s
# t=37400, 17.40121340751648s
# t=37600, 17.431686401367188s
# t=37800, 17.83454132080078s
# t=38000, 19.93097496032715s
# t=38200, 18.30316710472107s
# t=38400, 19.32062530517578s
# t=38600, 17.40631937980652s
# t=38800, 17.21545958518982s
# t=39000, 17.19402289390564s
# t=39200, 17.33443808555603s
# t=39400, 17.677673816680908s
# t=39600, 17.69467782974243s
# t=39800, 17.659810781478882s
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             478 |
# |          StdEpRet |             432 |
# |          MaxEpRet |        1.11e+03 |
# |          MinEpRet |             -12 |
# |  AverageTestEpRet |             634 |
# |      StdTestEpRet |            66.7 |
# |      MaxTestEpRet |             762 |
# |      MinTestEpRet |             553 |
# |             EpLen |             538 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            66.6 |
# |         StdQ1Vals |             5.1 |
# |         MaxQ1Vals |             103 |
# |         MinQ1Vals |           -6.35 |
# |     AverageQ2Vals |         0.00525 |
# |         StdQ2Vals |         0.00806 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -67.6 |
# |             LossQ |           0.979 |
# |              Time |            77.1 |
# ---------------------------------------
# t=40000, 77.10605597496033s
# t=40200, 17.02781081199646s
# t=40400, 17.456807613372803s
# t=40600, 17.899096965789795s
# t=40800, 17.63094997406006s
# t=41000, 17.053998708724976s
# t=41200, 17.125906944274902s
# t=41400, 17.079192638397217s
# t=41600, 17.157684326171875s
# t=41800, 17.388185262680054s
# t=42000, 18.239485025405884s
# t=42200, 17.368285417556763s
# t=42400, 17.42227530479431s
# t=42600, 17.365821599960327s
# t=42800, 17.261291980743408s
# t=43000, 17.18540930747986s
# t=43200, 18.058629989624023s
# t=43400, 17.489468097686768s
# t=43600, 17.197115659713745s
# t=43800, 17.48134708404541s
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             219 |
# |          StdEpRet |             226 |
# |          MaxEpRet |             667 |
# |          MinEpRet |           -24.9 |
# |  AverageTestEpRet |             281 |
# |      StdTestEpRet |             238 |
# |      MaxTestEpRet |             745 |
# |      MinTestEpRet |            12.8 |
# |             EpLen |             579 |
# |         TestEpLen |             636 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            72.6 |
# |         StdQ1Vals |            5.86 |
# |         MaxQ1Vals |             117 |
# |         MinQ1Vals |           -11.8 |
# |     AverageQ2Vals |         0.00481 |
# |         StdQ2Vals |          0.0081 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -73.6 |
# |             LossQ |            1.03 |
# |              Time |            56.6 |
# ---------------------------------------
# t=44000, 56.6350634098053s
# t=44200, 18.572829246520996s
# t=44400, 17.159806728363037s
# t=44600, 17.621918201446533s
# t=44800, 17.2769877910614s
# t=45000, 17.416014194488525s
# t=45200, 17.847285270690918s
# t=45400, 17.16264247894287s
# t=45600, 17.676741361618042s
# t=45800, 17.226842641830444s
# t=46000, 17.47813320159912s
# t=46200, 17.750183582305908s
# t=46400, 17.518057584762573s
# t=46600, 17.20569682121277s
# t=46800, 17.165364503860474s
# t=47000, 17.787649631500244s
# t=47200, 20.01668620109558s
# t=47400, 17.40515446662903s
# t=47600, 17.270671129226685s
# t=47800, 17.14431118965149s
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             255 |
# |          StdEpRet |             542 |
# |          MaxEpRet |             802 |
# |          MinEpRet |            -641 |
# |  AverageTestEpRet |            -622 |
# |      StdTestEpRet |             180 |
# |      MaxTestEpRet |            -508 |
# |      MinTestEpRet |       -1.14e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            79.3 |
# |         StdQ1Vals |            7.22 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |           -11.6 |
# |     AverageQ2Vals |           0.005 |
# |         StdQ2Vals |         0.00799 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0247 |
# |            LossPi |           -80.8 |
# |             LossQ |             1.3 |
# |              Time |            76.3 |
# ---------------------------------------
# t=48000, 76.30732870101929s
# t=48200, 17.082672357559204s
# t=48400, 17.26001286506653s
# t=48600, 17.74000072479248s
# t=48800, 17.17544674873352s
# t=49000, 17.604207038879395s
# t=49200, 17.22178316116333s
# t=49400, 17.1188805103302s
# t=49600, 17.294543504714966s
# t=49800, 17.667710781097412s
# t=50000, 17.66671371459961s
# t=50200, 17.2123384475708s
# t=50400, 17.81559467315674s
# t=50600, 17.383592128753662s
# t=50800, 17.668389320373535s
# t=51000, 17.849225282669067s
# t=51200, 17.235414266586304s
# t=51400, 17.336861848831177s
# t=51600, 17.129567861557007s
# t=51800, 17.711042165756226s
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            10.2 |
# |          StdEpRet |             275 |
# |          MaxEpRet |             434 |
# |          MinEpRet |            -498 |
# |  AverageTestEpRet |            -383 |
# |      StdTestEpRet |             327 |
# |      MaxTestEpRet |             184 |
# |      MinTestEpRet |            -703 |
# |             EpLen |             580 |
# |         TestEpLen |             901 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            92.1 |
# |         StdQ1Vals |            10.3 |
# |         MaxQ1Vals |             142 |
# |         MinQ1Vals |           -15.3 |
# |     AverageQ2Vals |         0.00523 |
# |         StdQ2Vals |         0.00795 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |           -94.3 |
# |             LossQ |            1.99 |
# |              Time |            70.5 |
# ---------------------------------------
# t=52000, 70.5156888961792s
# t=52200, 17.195040464401245s
# t=52400, 17.5618953704834s
# t=52600, 18.536523818969727s
# t=52800, 17.102368116378784s
# t=53000, 17.182048797607422s
# t=53200, 17.180218935012817s
# t=53400, 17.388578414916992s
# t=53600, 17.807899713516235s
# t=53800, 17.495429515838623s
# t=54000, 18.168415546417236s
# t=54200, 17.422904014587402s
# t=54400, 17.86869239807129s
# t=54600, 19.1965970993042s
# t=54800, 18.89980721473694s
# t=55000, 18.586561918258667s
# t=55200, 19.014453649520874s
# t=55400, 18.172374486923218s
# t=55600, 19.573082208633423s
# t=55800, 18.320528268814087s
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             192 |
# |          StdEpRet |             223 |
# |          MaxEpRet |             567 |
# |          MinEpRet |            -105 |
# |  AverageTestEpRet |             132 |
# |      StdTestEpRet |             208 |
# |      MaxTestEpRet |             456 |
# |      MinTestEpRet |            -182 |
# |             EpLen |             908 |
# |         TestEpLen |             781 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |             103 |
# |         StdQ1Vals |            9.96 |
# |         MaxQ1Vals |             149 |
# |         MinQ1Vals |           -22.2 |
# |     AverageQ2Vals |         0.00585 |
# |         StdQ2Vals |         0.00847 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -105 |
# |             LossQ |            2.02 |
# |              Time |            73.5 |
# ---------------------------------------
# t=56000, 73.50102353096008s
# t=56200, 17.42306637763977s
# t=56400, 17.320582389831543s
# t=56600, 20.309435844421387s
# t=56800, 18.45033621788025s
# t=57000, 18.73339557647705s
# t=57200, 17.970239400863647s
# t=57400, 18.776846647262573s
# t=57600, 20.932294607162476s
# t=57800, 20.284602403640747s
# t=58000, 18.885010719299316s
# t=58200, 20.789879322052002s
# t=58400, 18.37936758995056s
# t=58600, 19.5216166973114s
# t=58800, 19.21161198616028s
# t=59000, 19.926256895065308s
# t=59200, 19.237878561019897s
# t=59400, 19.938612937927246s
# t=59600, 19.113839149475098s
# t=59800, 20.40523409843445s
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             176 |
# |          StdEpRet |             252 |
# |          MaxEpRet |             608 |
# |          MinEpRet |           -25.7 |
# |  AverageTestEpRet |             530 |
# |      StdTestEpRet |             258 |
# |      MaxTestEpRet |             727 |
# |      MinTestEpRet |            7.99 |
# |             EpLen |             542 |
# |         TestEpLen |             804 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             110 |
# |         StdQ1Vals |            8.76 |
# |         MaxQ1Vals |             153 |
# |         MinQ1Vals |           -21.8 |
# |     AverageQ2Vals |         0.00631 |
# |         StdQ2Vals |         0.00885 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -112 |
# |             LossQ |             2.1 |
# |              Time |            66.8 |
# ---------------------------------------
# t=60000, 66.83770489692688s
# t=60200, 19.796059370040894s
# t=60400, 20.565452098846436s
# t=60600, 18.244980812072754s
# t=60800, 17.903377532958984s
# t=61000, 20.98948884010315s
# t=61200, 20.407728672027588s
# t=61400, 19.007800579071045s
# t=61600, 17.82069969177246s
# t=61800, 15.801877737045288s
# t=62000, 15.235104084014893s
# t=62200, 16.017226219177246s
# t=62400, 15.507299900054932s
# t=62600, 15.542535066604614s
# t=62800, 17.201523303985596s
# t=63000, 17.411941528320312s
# t=63200, 19.24739670753479s
# t=63400, 19.653077602386475s
# t=63600, 19.855599403381348s
# t=63800, 18.412810564041138s
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             380 |
# |          StdEpRet |             185 |
# |          MaxEpRet |             600 |
# |          MinEpRet |             146 |
# |  AverageTestEpRet |             401 |
# |      StdTestEpRet |             267 |
# |      MaxTestEpRet |             722 |
# |      MinTestEpRet |            7.91 |
# |             EpLen |             682 |
# |         TestEpLen |             712 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             115 |
# |         StdQ1Vals |            8.22 |
# |         MaxQ1Vals |             157 |
# |         MinQ1Vals |           -31.5 |
# |     AverageQ2Vals |         0.00612 |
# |         StdQ2Vals |         0.00878 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -117 |
# |             LossQ |            1.83 |
# |              Time |            58.4 |
# ---------------------------------------
# t=64000, 58.431904554367065s
# t=64200, 18.238909244537354s
# t=64400, 15.636914491653442s
# t=64600, 15.98375129699707s
# t=64800, 15.708032369613647s
# t=65000, 16.473968744277954s
# t=65200, 18.509580850601196s
# t=65400, 16.38804006576538s
# t=65600, 16.157944202423096s
# t=65800, 15.569555044174194s
# t=66000, 16.323097229003906s
# t=66200, 17.260289430618286s
# t=66400, 15.437812566757202s
# t=66600, 15.903721570968628s
# t=66800, 15.57060956954956s
# t=67000, 18.793511867523193s
# t=67200, 19.989208459854126s
# t=67400, 17.665290355682373s
# t=67600, 17.640650272369385s
# t=67800, 19.065656661987305s
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             387 |
# |          StdEpRet |             284 |
# |          MaxEpRet |             623 |
# |          MinEpRet |           -97.4 |
# |  AverageTestEpRet |             354 |
# |      StdTestEpRet |             414 |
# |      MaxTestEpRet |             827 |
# |      MinTestEpRet |            -491 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             928 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             119 |
# |         StdQ1Vals |            8.12 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |           -28.7 |
# |     AverageQ2Vals |         0.00607 |
# |         StdQ2Vals |         0.00871 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -120 |
# |             LossQ |            1.84 |
# |              Time |            67.2 |
# ---------------------------------------
# t=68000, 67.18052196502686s
# t=68200, 18.251428842544556s
# t=68400, 16.806581020355225s
# t=68600, 16.285440683364868s
# t=68800, 16.532209634780884s
# t=69000, 16.669593811035156s
# t=69200, 16.34171223640442s
# t=69400, 16.075612545013428s
# t=69600, 17.39048671722412s
# t=69800, 18.205261945724487s
# t=70000, 16.907562732696533s
# t=70200, 18.112825393676758s
# t=70400, 20.19858717918396s
# t=70600, 26.789120197296143s
# t=70800, 30.316779613494873s
# t=71000, 19.142921686172485s
# t=71200, 19.52785587310791s
# t=71400, 24.416157960891724s
# t=71600, 16.76773238182068s
# t=71800, 17.447770595550537s
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             388 |
# |          StdEpRet |             207 |
# |          MaxEpRet |             613 |
# |          MinEpRet |            10.7 |
# |  AverageTestEpRet |             401 |
# |      StdTestEpRet |             278 |
# |      MaxTestEpRet |             563 |
# |      MinTestEpRet |            -306 |
# |             EpLen |             805 |
# |         TestEpLen |             904 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             120 |
# |         StdQ1Vals |            8.45 |
# |         MaxQ1Vals |             174 |
# |         MinQ1Vals |           -23.4 |
# |     AverageQ2Vals |          0.0061 |
# |         StdQ2Vals |         0.00899 |
# |         MaxQ2Vals |          0.0376 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -122 |
# |             LossQ |            1.31 |
# |              Time |            77.6 |
# ---------------------------------------
# t=72000, 77.62538814544678s
# t=72200, 18.145055770874023s
# t=72400, 25.334744691848755s
# t=72600, 20.247352361679077s
# t=72800, 21.919867038726807s
# t=73000, 20.543639659881592s
# t=73200, 18.886194467544556s
# t=73400, 20.03119206428528s
# t=73600, 19.19398260116577s
# t=73800, 20.231415271759033s
# t=74000, 18.503156661987305s
# t=74200, 18.766894340515137s
# t=74400, 22.89361333847046s
# t=74600, 17.57703471183777s
# t=74800, 18.611860513687134s
# t=75000, 18.86158537864685s
# t=75200, 17.396400451660156s
# t=75400, 19.828648328781128s
# t=75600, 18.35620427131653s
# t=75800, 18.199155807495117s
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             184 |
# |          StdEpRet |             249 |
# |          MaxEpRet |             631 |
# |          MinEpRet |            -197 |
# |  AverageTestEpRet |             544 |
# |      StdTestEpRet |             312 |
# |      MaxTestEpRet |             827 |
# |      MinTestEpRet |           -96.3 |
# |             EpLen |             497 |
# |         TestEpLen |             903 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            9.13 |
# |         MaxQ1Vals |             176 |
# |         MinQ1Vals |           -31.6 |
# |     AverageQ2Vals |         0.00624 |
# |         StdQ2Vals |         0.00912 |
# |         MaxQ2Vals |          0.0416 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -122 |
# |             LossQ |             1.8 |
# |              Time |            68.6 |
# ---------------------------------------
# t=76000, 68.64424133300781s
# t=76200, 15.109652519226074s
# t=76400, 14.99701738357544s
# t=76600, 15.387007474899292s
# t=76800, 15.062859296798706s
# t=77000, 14.987325668334961s
# t=77200, 15.006020545959473s
# t=77400, 15.176802396774292s
# t=77600, 15.120984077453613s
# t=77800, 15.237629652023315s
# t=78000, 14.929978847503662s
# t=78200, 15.40297794342041s
# t=78400, 15.198160886764526s
# t=78600, 15.497512578964233s
# t=78800, 15.043823003768921s
# t=79000, 16.13444471359253s
# t=79200, 16.16777205467224s
# t=79400, 15.392940759658813s
# t=79600, 15.40090823173523s
# t=79800, 15.26723337173462s
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             114 |
# |          StdEpRet |             149 |
# |          MaxEpRet |             362 |
# |          MinEpRet |            -107 |
# |  AverageTestEpRet |             428 |
# |      StdTestEpRet |             316 |
# |      MaxTestEpRet |             753 |
# |      MinTestEpRet |           -59.4 |
# |             EpLen |             410 |
# |         TestEpLen |             739 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             123 |
# |         StdQ1Vals |            9.71 |
# |         MaxQ1Vals |             177 |
# |         MinQ1Vals |           -19.5 |
# |     AverageQ2Vals |          0.0063 |
# |         StdQ2Vals |          0.0091 |
# |         MaxQ2Vals |          0.0416 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -124 |
# |             LossQ |            2.68 |
# |              Time |              52 |
# ---------------------------------------
# t=80000, 51.98990488052368s
# t=80200, 17.180803775787354s
# t=80400, 17.074570655822754s
# t=80600, 17.10374903678894s
# t=80800, 17.409339666366577s
# t=81000, 17.35723614692688s
# t=81200, 17.548576831817627s
# t=81400, 17.160416841506958s
# t=81600, 17.06823468208313s
# t=81800, 17.135205030441284s
# t=82000, 17.32201075553894s
# t=82200, 19.254274368286133s
# t=82400, 18.365888357162476s
# t=82600, 17.1258487701416s
# t=82800, 17.244748830795288s
# t=83000, 17.28492498397827s
# t=83200, 17.086344003677368s
# t=83400, 17.479185104370117s
# t=83600, 17.28149390220642s
# t=83800, 17.291449546813965s
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             225 |
# |          StdEpRet |             190 |
# |          MaxEpRet |             519 |
# |          MinEpRet |           -9.95 |
# |  AverageTestEpRet |             380 |
# |      StdTestEpRet |             263 |
# |      MaxTestEpRet |             883 |
# |      MinTestEpRet |          -0.556 |
# |             EpLen |             737 |
# |         TestEpLen |             722 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             124 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |             175 |
# |         MinQ1Vals |             -23 |
# |     AverageQ2Vals |         0.00631 |
# |         StdQ2Vals |         0.00914 |
# |         MaxQ2Vals |          0.0416 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -125 |
# |             LossQ |             2.8 |
# |              Time |            58.2 |
# ---------------------------------------
# t=84000, 58.195143938064575s
# t=84200, 15.471758604049683s
# t=84400, 15.395510911941528s
# t=84600, 15.224931955337524s
# t=84800, 15.474311590194702s
# t=85000, 15.397648811340332s
# t=85200, 15.61040735244751s
# t=85400, 15.074454069137573s
# t=85600, 15.236403465270996s
# t=85800, 15.234562158584595s
# t=86000, 15.547396183013916s
# t=86200, 15.019420146942139s
# t=86400, 15.332035303115845s
# t=86600, 15.315377950668335s
# t=86800, 15.338796854019165s
# t=87000, 15.122375965118408s
# t=87200, 15.139037370681763s
# t=87400, 15.427003383636475s
# t=87600, 15.53832745552063s
# t=87800, 15.162205457687378s
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             479 |
# |          StdEpRet |              80 |
# |          MaxEpRet |             630 |
# |          MinEpRet |             406 |
# |  AverageTestEpRet |             490 |
# |      StdTestEpRet |             165 |
# |      MaxTestEpRet |             584 |
# |      MinTestEpRet |            9.51 |
# |             EpLen |             866 |
# |         TestEpLen |             904 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             125 |
# |         StdQ1Vals |            10.1 |
# |         MaxQ1Vals |             190 |
# |         MinQ1Vals |             -29 |
# |     AverageQ2Vals |         0.00629 |
# |         StdQ2Vals |         0.00911 |
# |         MaxQ2Vals |          0.0416 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -126 |
# |             LossQ |             2.5 |
# |              Time |              61 |
# ---------------------------------------
# t=88000, 61.02703619003296s
# t=88200, 14.821512460708618s
# t=88400, 15.34082818031311s
# t=88600, 16.33635640144348s
# t=88800, 15.387468576431274s
# t=89000, 15.209618330001831s
# t=89200, 14.99551010131836s
# t=89400, 14.878271579742432s
# t=89600, 15.134779453277588s
# t=89800, 15.292378902435303s
# t=90000, 15.260693073272705s
# t=90200, 15.369140386581421s
# t=90400, 15.336143732070923s
# t=90600, 15.169090270996094s
# t=90800, 15.213451623916626s
# t=91000, 14.912706136703491s
# t=91200, 15.123949766159058s
# t=91400, 15.988377094268799s
# t=91600, 15.943095445632935s
# t=91800, 15.22592282295227s
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             147 |
# |          StdEpRet |             143 |
# |          MaxEpRet |             453 |
# |          MinEpRet |            34.4 |
# |  AverageTestEpRet |             129 |
# |      StdTestEpRet |             160 |
# |      MaxTestEpRet |             405 |
# |      MinTestEpRet |            -124 |
# |             EpLen |             561 |
# |         TestEpLen |             809 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             129 |
# |         StdQ1Vals |            11.3 |
# |         MaxQ1Vals |             191 |
# |         MinQ1Vals |           -39.3 |
# |     AverageQ2Vals |         0.00636 |
# |         StdQ2Vals |         0.00906 |
# |         MaxQ2Vals |          0.0416 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -132 |
# |             LossQ |            2.65 |
# |              Time |            57.2 |
# ---------------------------------------
# t=92000, 57.24587082862854s
# t=92200, 16.728694200515747s
# t=92400, 15.442514419555664s
# t=92600, 16.25463891029358s
# t=92800, 15.681185960769653s
# t=93000, 15.16417908668518s
# t=93200, 15.476284265518188s
# t=93400, 15.33707046508789s
# t=93600, 15.501259565353394s
# t=93800, 15.757515668869019s
# t=94000, 16.105712890625s
# t=94200, 15.377374649047852s
# t=94400, 15.01839280128479s
# t=94600, 15.642305612564087s
# t=94800, 15.280268430709839s
# t=95000, 15.166317224502563s
# t=95200, 14.85026240348816s
# t=95400, 15.397546291351318s
# t=95600, 15.277827739715576s
# t=95800, 15.555537700653076s
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             304 |
# |          StdEpRet |             254 |
# |          MaxEpRet |             627 |
# |          MinEpRet |           -7.75 |
# |  AverageTestEpRet |            89.7 |
# |      StdTestEpRet |             151 |
# |      MaxTestEpRet |             374 |
# |      MinTestEpRet |           -22.1 |
# |             EpLen |             802 |
# |         TestEpLen |             517 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             138 |
# |         StdQ1Vals |            13.9 |
# |         MaxQ1Vals |             210 |
# |         MinQ1Vals |           -28.8 |
# |     AverageQ2Vals |         0.00638 |
# |         StdQ2Vals |         0.00905 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -140 |
# |             LossQ |            2.79 |
# |              Time |            41.1 |
# ---------------------------------------
# t=96000, 41.14563846588135s
# t=96200, 14.921528816223145s
# t=96400, 15.073293685913086s
# t=96600, 14.952305555343628s
# t=96800, 15.194223642349243s
# t=97000, 15.570769786834717s
# t=97200, 15.383389472961426s
# t=97400, 15.096269845962524s
# t=97600, 14.988811016082764s
# t=97800, 15.232093334197998s
# t=98000, 15.36184573173523s
# t=98200, 16.84528136253357s
# t=98400, 16.228466272354126s
# t=98600, 16.686127185821533s
# t=98800, 15.666197776794434s
# t=99000, 20.109021425247192s
# t=99200, 17.581451892852783s
# t=99400, 17.38777470588684s
# t=99600, 17.229414701461792s
# t=99800, 16.835634231567383s
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            8.21 |
# |          StdEpRet |             182 |
# |          MaxEpRet |             385 |
# |          MinEpRet |            -278 |
# |  AverageTestEpRet |            -249 |
# |      StdTestEpRet |             600 |
# |      MaxTestEpRet |             424 |
# |      MinTestEpRet |       -1.36e+03 |
# |             EpLen |             516 |
# |         TestEpLen |             562 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             143 |
# |         StdQ1Vals |            13.7 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             -53 |
# |     AverageQ2Vals |         0.00637 |
# |         StdQ2Vals |         0.00902 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -144 |
# |             LossQ |            2.84 |
# |              Time |            45.9 |
# ---------------------------------------
# t=100000, 45.94948196411133s
# t=100200, 15.150249481201172s
# t=100400, 15.2795250415802s
# t=100600, 15.162535667419434s
# t=100800, 15.297286987304688s
# t=101000, 15.40731430053711s
# t=101200, 15.4765305519104s
# t=101400, 15.292219400405884s
# t=101600, 16.15296459197998s
# t=101800, 15.429679155349731s
# t=102000, 15.075852155685425s
# t=102200, 15.211182117462158s
# t=102400, 15.17772102355957s
# t=102600, 15.494625568389893s
# t=102800, 16.71291971206665s
# t=103000, 16.256054162979126s
# t=103200, 15.06075644493103s
# t=103400, 15.64035940170288s
# t=103600, 15.172301530838013s
# t=103800, 15.196985960006714s
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             403 |
# |          StdEpRet |             285 |
# |          MaxEpRet |             806 |
# |          MinEpRet |          -0.719 |
# |  AverageTestEpRet |             439 |
# |      StdTestEpRet |             318 |
# |      MaxTestEpRet |             758 |
# |      MinTestEpRet |           -1.21 |
# |             EpLen |             650 |
# |         TestEpLen |             715 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             143 |
# |         StdQ1Vals |            13.5 |
# |         MaxQ1Vals |             188 |
# |         MinQ1Vals |           -34.3 |
# |     AverageQ2Vals |         0.00629 |
# |         StdQ2Vals |         0.00902 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -145 |
# |             LossQ |            3.65 |
# |              Time |            50.9 |
# ---------------------------------------
# t=104000, 50.919782638549805s
# t=104200, 15.338492155075073s
# t=104400, 15.10927700996399s
# t=104600, 15.193776607513428s
# t=104800, 15.407092571258545s
# t=105000, 15.321390151977539s
# t=105200, 15.728469371795654s
# t=105400, 15.151867628097534s
# t=105600, 15.110663175582886s
# t=105800, 15.323456525802612s
# t=106000, 15.442266702651978s
# t=106200, 15.181495904922485s
# t=106400, 15.647198677062988s
# t=106600, 15.260570287704468s
# t=106800, 15.56849980354309s
# t=107000, 15.197161197662354s
# t=107200, 15.437843561172485s
# t=107400, 16.79331398010254s
# t=107600, 15.663063764572144s
# t=107800, 15.262173414230347s
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             360 |
# |          StdEpRet |             255 |
# |          MaxEpRet |             728 |
# |          MinEpRet |            28.3 |
# |  AverageTestEpRet |             214 |
# |      StdTestEpRet |             221 |
# |      MaxTestEpRet |             718 |
# |      MinTestEpRet |           -1.25 |
# |             EpLen |             630 |
# |         TestEpLen |             373 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             143 |
# |         StdQ1Vals |            12.9 |
# |         MaxQ1Vals |             180 |
# |         MinQ1Vals |           -30.3 |
# |     AverageQ2Vals |          0.0062 |
# |         StdQ2Vals |         0.00897 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -144 |
# |             LossQ |             3.2 |
# |              Time |            34.1 |
# ---------------------------------------
# t=108000, 34.1029212474823s
# t=108200, 15.511237859725952s
# t=108400, 15.295954465866089s
# t=108600, 15.266948461532593s
# t=108800, 15.368330955505371s
# t=109000, 15.184171438217163s
# t=109200, 15.25670051574707s
# t=109400, 15.247395038604736s
# t=109600, 15.245766162872314s
# t=109800, 17.295235633850098s
# t=110000, 16.836527824401855s
# t=110200, 16.206337213516235s
# t=110400, 15.852392196655273s
# t=110600, 15.438413143157959s
# t=110800, 15.725549221038818s
# t=111000, 17.593608140945435s
# t=111200, 16.961857795715332s
# t=111400, 19.432207584381104s
# t=111600, 16.067492961883545s
# t=111800, 17.13013792037964s
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             196 |
# |          StdEpRet |             186 |
# |          MaxEpRet |             625 |
# |          MinEpRet |           -10.1 |
# |  AverageTestEpRet |             429 |
# |      StdTestEpRet |             333 |
# |      MaxTestEpRet |             636 |
# |      MinTestEpRet |            -416 |
# |             EpLen |             374 |
# |         TestEpLen |             905 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             143 |
# |         StdQ1Vals |            12.4 |
# |         MaxQ1Vals |             177 |
# |         MinQ1Vals |           -29.5 |
# |     AverageQ2Vals |         0.00608 |
# |         StdQ2Vals |         0.00895 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -144 |
# |             LossQ |            4.24 |
# |              Time |            64.9 |
# ---------------------------------------
# t=112000, 64.89161777496338s
# t=112200, 17.863280296325684s
# t=112400, 17.67042827606201s
# t=112600, 16.991219758987427s
# t=112800, 16.360349416732788s
# t=113000, 18.944648265838623s
# t=113200, 17.275118589401245s
# t=113400, 19.38766050338745s
# t=113600, 19.126877307891846s
# t=113800, 20.662635564804077s
# t=114000, 18.395275592803955s
# t=114200, 20.615683555603027s
# t=114400, 19.718924045562744s
# t=114600, 19.019773960113525s
# t=114800, 20.244904041290283s
# t=115000, 23.07573699951172s
# t=115200, 18.83291244506836s
# t=115400, 17.04224395751953s
# t=115600, 21.40222954750061s
# t=115800, 18.812762022018433s
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             198 |
# |          StdEpRet |             283 |
# |          MaxEpRet |             738 |
# |          MinEpRet |            -188 |
# |  AverageTestEpRet |             396 |
# |      StdTestEpRet |             331 |
# |      MaxTestEpRet |             866 |
# |      MinTestEpRet |           -7.57 |
# ...
# ---------------------------------------
# t=160000, 70.85425186157227s
# t=160200, 17.345590114593506s
# t=160400, 19.219682455062866s
# t=160600, 15.419663190841675s
# t=160800, 13.706557989120483s
# t=161000, 13.834938764572144s
# t=161200, 14.259903192520142s
# t=161400, 13.968764066696167s
# t=161600, 14.477993726730347s
# t=161800, 14.053977966308594s
# t=162000, 14.791909217834473s
# t=162200, 14.106475114822388s
# t=162400, 14.177961587905884s
# t=162600, 14.820669889450073s
# t=162800, 17.36826777458191s
# t=163000, 14.98637843132019s
# t=163200, 14.649794101715088s
# t=163400, 14.05568552017212s
# t=163600, 13.899686813354492s
# t=163800, 13.705804347991943s
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             876 |
# |          StdEpRet |             194 |
# |          MaxEpRet |        1.08e+03 |
# |          MinEpRet |             628 |
# |  AverageTestEpRet |             680 |
# |      StdTestEpRet |             244 |
# |      MaxTestEpRet |             862 |
# |      MinTestEpRet |            4.25 |
# |             EpLen |             811 |
# |         TestEpLen |             902 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             122 |
# |         StdQ1Vals |            8.98 |
# |         MaxQ1Vals |             168 |
# |         MinQ1Vals |           -36.5 |
# |     AverageQ2Vals |         0.00508 |
# |         StdQ2Vals |         0.00883 |
# |         MaxQ2Vals |          0.0437 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -123 |
# |             LossQ |            2.25 |
# |              Time |            62.2 |
# ---------------------------------------
# t=164000, 62.21789479255676s
# t=164200, 13.945343971252441s
# t=164400, 14.960386991500854s
# t=164600, 13.926796913146973s
# t=164800, 14.269942283630371s
# t=165000, 14.325753211975098s
# t=165200, 14.489828824996948s
# t=165400, 14.161068677902222s
# t=165600, 13.90621542930603s
# t=165800, 14.223548173904419s
# t=166000, 13.96297574043274s
# t=166200, 14.119267702102661s
# t=166400, 14.302466630935669s
# t=166600, 14.505032062530518s
# t=166800, 13.856302261352539s
# t=167000, 13.676608324050903s
# t=167200, 14.047618389129639s
# t=167400, 14.025663137435913s
# t=167600, 13.72274923324585s
# t=167800, 13.608359098434448s
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             892 |
# |          StdEpRet |             282 |
# |          MaxEpRet |        1.16e+03 |
# |          MinEpRet |             384 |
# |  AverageTestEpRet |             733 |
# |      StdTestEpRet |             303 |
# |      MaxTestEpRet |        1.07e+03 |
# |      MinTestEpRet |             141 |
# |             EpLen |             886 |
# |         TestEpLen |             775 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            8.95 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |           -20.3 |
# |     AverageQ2Vals |         0.00497 |
# |         StdQ2Vals |         0.00878 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -122 |
# |             LossQ |             2.2 |
# |              Time |            49.5 |
# ---------------------------------------
# t=168000, 49.548436880111694s
# t=168200, 13.438836812973022s
# t=168400, 13.979514122009277s
# t=168600, 14.030620574951172s
# t=168800, 15.815217733383179s
# t=169000, 14.315144062042236s
# t=169200, 13.738878726959229s
# t=169400, 16.77690601348877s
# t=169600, 14.6863853931427s
# t=169800, 14.43194842338562s
# t=170000, 14.743594408035278s
# t=170200, 14.665879487991333s
# t=170400, 15.977411985397339s
# t=170600, 15.133596181869507s
# t=170800, 13.876264810562134s
# t=171000, 14.640682935714722s
# t=171200, 14.532498359680176s
# t=171400, 14.892122030258179s
# t=171600, 18.42284083366394s
# t=171800, 18.165091514587402s
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             538 |
# |          StdEpRet |             188 |
# |          MaxEpRet |             702 |
# |          MinEpRet |             222 |
# |  AverageTestEpRet |             894 |
# |      StdTestEpRet |             414 |
# |      MaxTestEpRet |        1.25e+03 |
# |      MinTestEpRet |           -7.64 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             902 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            9.18 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |           -42.9 |
# |     AverageQ2Vals |         0.00488 |
# |         StdQ2Vals |         0.00878 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0306 |
# |            LossPi |            -121 |
# |             LossQ |            2.52 |
# |              Time |            59.9 |
# ---------------------------------------
# t=172000, 59.90639090538025s
# t=172200, 13.853653192520142s
# t=172400, 13.491908311843872s
# t=172600, 15.186288356781006s
# t=172800, 14.100022792816162s
# t=173000, 14.054880619049072s
# t=173200, 14.29193639755249s
# t=173400, 14.68176531791687s
# t=173600, 14.442507266998291s
# t=173800, 14.628628969192505s
# t=174000, 14.292668342590332s
# t=174200, 13.974846363067627s
# t=174400, 13.75940752029419s
# t=174600, 13.892152786254883s
# t=174800, 15.343781471252441s
# t=175000, 14.245289325714111s
# t=175200, 13.982687711715698s
# t=175400, 15.31604266166687s
# t=175600, 14.623892545700073s
# t=175800, 19.072094917297363s
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        1.27e+03 |
# |          StdEpRet |              73 |
# |          MaxEpRet |        1.39e+03 |
# |          MinEpRet |        1.18e+03 |
# |  AverageTestEpRet |             648 |
# |      StdTestEpRet |             374 |
# |      MaxTestEpRet |        1.28e+03 |
# |      MinTestEpRet |             204 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             623 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             120 |
# |         StdQ1Vals |            9.19 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |           -26.4 |
# |     AverageQ2Vals |         0.00487 |
# |         StdQ2Vals |         0.00873 |
# |         MaxQ2Vals |          0.0438 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -121 |
# |             LossQ |            2.16 |
# |              Time |            43.2 |
# ---------------------------------------
# t=176000, 43.163795948028564s
# t=176200, 13.769249677658081s
# t=176400, 14.402074813842773s
# t=176600, 14.21656584739685s
# t=176800, 14.211617946624756s
# t=177000, 14.766337871551514s
# t=177200, 14.260109901428223s
# t=177400, 14.126068830490112s
# t=177600, 13.455016613006592s
# t=177800, 14.436401605606079s
# t=178000, 13.343284845352173s
# t=178200, 13.641554117202759s
# t=178400, 13.924112796783447s
# t=178600, 15.15748381614685s
# t=178800, 15.348490715026855s
# t=179000, 15.66352915763855s
# t=179200, 15.398441314697266s
# t=179400, 14.170721769332886s
# t=179600, 14.256695985794067s
# t=179800, 13.922871112823486s
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             544 |
# |          StdEpRet |             395 |
# |          MaxEpRet |        1.12e+03 |
# |          MinEpRet |            12.8 |
# |  AverageTestEpRet |             742 |
# |      StdTestEpRet |             395 |
# |      MaxTestEpRet |        1.32e+03 |
# |      MinTestEpRet |             158 |
# |             EpLen |             595 |
# |         TestEpLen |             716 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             119 |
# |         StdQ1Vals |            9.24 |
# |         MaxQ1Vals |             175 |
# |         MinQ1Vals |             -29 |
# |     AverageQ2Vals |         0.00478 |
# |         StdQ2Vals |         0.00872 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -120 |
# |             LossQ |            2.36 |
# |              Time |            48.3 |
# ---------------------------------------
# t=180000, 48.34504270553589s
# t=180200, 14.660647869110107s
# t=180400, 16.092967987060547s
# t=180600, 16.824573755264282s
# t=180800, 15.41303563117981s
# t=181000, 15.316043615341187s
# t=181200, 16.17923355102539s
# t=181400, 15.927579641342163s
# t=181600, 14.223990201950073s
# t=181800, 15.166414022445679s
# t=182000, 15.09546160697937s
# t=182200, 14.52316665649414s
# t=182400, 14.712623357772827s
# t=182600, 15.08965015411377s
# t=182800, 15.594317436218262s
# t=183000, 15.19235372543335s
# t=183200, 13.629580020904541s
# t=183400, 13.600635528564453s
# t=183600, 13.780627727508545s
# t=183800, 13.764224290847778s
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |             363 |
# |          StdEpRet |             345 |
# |          MaxEpRet |        1.11e+03 |
# |          MinEpRet |            89.4 |
# |  AverageTestEpRet |             651 |
# |      StdTestEpRet |             329 |
# |      MaxTestEpRet |        1.05e+03 |
# |      MinTestEpRet |             161 |
# |             EpLen |             499 |
# |         TestEpLen |             763 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             119 |
# |         StdQ1Vals |            9.61 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |           -29.9 |
# |     AverageQ2Vals |         0.00469 |
# |         StdQ2Vals |         0.00871 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -120 |
# |             LossQ |            2.57 |
# |              Time |            47.9 |
# ---------------------------------------
# t=184000, 47.882925033569336s
# t=184200, 13.798134326934814s
# t=184400, 13.799101114273071s
# t=184600, 13.603588104248047s
# t=184800, 13.802124500274658s
# t=185000, 13.548765659332275s
# t=185200, 13.347306728363037s
# t=185400, 13.464996337890625s
# t=185600, 14.244883298873901s
# t=185800, 14.698690176010132s
# t=186000, 14.343644857406616s
# t=186200, 13.411169052124023s
# t=186400, 14.331671953201294s
# t=186600, 13.496912956237793s
# t=186800, 13.433078527450562s
# t=187000, 13.576698064804077s
# t=187200, 13.448027849197388s
# t=187400, 13.811068296432495s
# t=187600, 13.54076099395752s
# t=187800, 14.516181945800781s
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |             502 |
# |          StdEpRet |             224 |
# |          MaxEpRet |             870 |
# |          MinEpRet |             157 |
# |  AverageTestEpRet |             663 |
# |      StdTestEpRet |             302 |
# |      MaxTestEpRet |        1.08e+03 |
# |      MinTestEpRet |              67 |
# |             EpLen |             608 |
# |         TestEpLen |             928 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             118 |
# |         StdQ1Vals |              10 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |           -27.2 |
# |     AverageQ2Vals |          0.0047 |
# |         StdQ2Vals |         0.00873 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -119 |
# |             LossQ |            2.94 |
# |              Time |              56 |
# ---------------------------------------
# t=188000, 56.006234645843506s
# t=188200, 13.431082963943481s
# t=188400, 14.053447008132935s
# t=188600, 13.826030015945435s
# t=188800, 13.464991807937622s
# t=189000, 13.417092323303223s
# t=189200, 13.419114112854004s
# t=189400, 13.737854719161987s
# t=189600, 13.47294306755066s
# t=189800, 13.467008352279663s
# t=190000, 13.377207040786743s
# t=190200, 13.698370695114136s
# t=190400, 13.706375122070312s
# t=190600, 13.494917154312134s
# t=190800, 13.412117958068848s
# t=191000, 13.51985788345337s
# t=191200, 13.54977035522461s
# t=191400, 13.454018592834473s
# t=191600, 13.607583045959473s
# t=191800, 13.40319037437439s
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             656 |
# |          StdEpRet |             417 |
# |          MaxEpRet |        1.14e+03 |
# |          MinEpRet |             103 |
# |  AverageTestEpRet |         1.3e+03 |
# |      StdTestEpRet |             360 |
# |      MaxTestEpRet |        1.63e+03 |
# |      MinTestEpRet |             361 |
# |             EpLen |             826 |
# |         TestEpLen |             895 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             118 |
# |         StdQ1Vals |            10.3 |
# |         MaxQ1Vals |             175 |
# |         MinQ1Vals |             -23 |
# |     AverageQ2Vals |         0.00471 |
# |         StdQ2Vals |         0.00873 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -119 |
# |             LossQ |            3.18 |
# |              Time |              54 |
# ---------------------------------------
# t=192000, 54.012558937072754s
# t=192200, 16.633492946624756s
# t=192400, 16.988572120666504s
# t=192600, 16.3782000541687s
# t=192800, 16.5647075176239s
# t=193000, 18.19235134124756s
# t=193200, 17.694682359695435s
# t=193400, 17.831313610076904s
# t=193600, 15.579367876052856s
# t=193800, 15.317013263702393s
# t=194000, 15.041775226593018s
# t=194200, 14.968973398208618s
# t=194400, 15.335011005401611s
# t=194600, 15.283112287521362s
# t=194800, 15.312081098556519s
# t=195000, 15.1185622215271s
# t=195200, 15.237233877182007s
# t=195400, 15.234262943267822s
# t=195600, 15.201350212097168s
# t=195800, 15.44270396232605s
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             994 |
# |          StdEpRet |             219 |
# |          MaxEpRet |        1.15e+03 |
# |          MinEpRet |             616 |
# |  AverageTestEpRet |            -660 |
# |      StdTestEpRet |             565 |
# |      MaxTestEpRet |             246 |
# |      MinTestEpRet |       -1.37e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             901 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             118 |
# |         StdQ1Vals |            10.3 |
# |         MaxQ1Vals |             172 |
# |         MinQ1Vals |           -29.3 |
# |     AverageQ2Vals |         0.00462 |
# |         StdQ2Vals |         0.00869 |
# |         MaxQ2Vals |          0.0464 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -119 |
# |             LossQ |            2.76 |
# |              Time |            59.7 |
# ---------------------------------------
# t=196000, 59.709360122680664s
# t=196200, 13.090989828109741s
# t=196400, 14.0284583568573s
# t=196600, 14.60993218421936s
# t=196800, 13.483972072601318s
# t=197000, 13.566717863082886s
# t=197200, 13.656485795974731s
# t=197400, 13.49738335609436s
# t=197600, 13.437103271484375s
# t=197800, 13.499892473220825s
# t=198000, 14.007514238357544s
# t=198200, 13.651494264602661s
# t=198400, 13.599632740020752s
# t=198600, 13.374236106872559s
# t=198800, 13.582706689834595s
# t=199000, 13.685374975204468s
# t=199200, 13.468982696533203s
# t=199400, 13.606649398803711s
# t=199600, 13.707337141036987s
# t=199800, 13.768185377120972s
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -146 |
# |          StdEpRet |             530 |
# |          MaxEpRet |             320 |
# |          MinEpRet |       -1.02e+03 |
# |  AverageTestEpRet |             212 |
# |      StdTestEpRet |             141 |
# |      MaxTestEpRet |             491 |
# |      MinTestEpRet |           -8.44 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             805 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            12.3 |
# |         MaxQ1Vals |             177 |
# |         MinQ1Vals |           -46.3 |
# |     AverageQ2Vals |         0.00465 |
# |         StdQ2Vals |         0.00869 |
# |         MaxQ2Vals |          0.0469 |
# |         MinQ2Vals |         -0.0309 |
# |            LossPi |            -122 |
# |             LossQ |            3.35 |
# |              Time |            49.1 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 
        'max_hist_len': 5,
        'gamma': 0.99, 'seed': 0, 'epochs': 50, 
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': False,
        'freeze_hist_coding': False,
        'exp_name': 'RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     max_hist_len=args['max_hist_len'],
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
    freeze_hist_coding=args['freeze_hist_coding'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#     "freeze_hist_coding":	false,
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x00000209EA16AE48>":	{
#             "epoch_dict":	{},
#             "exp_name":	"RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\\\RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_NoMemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0"
#     },
#     "max_ep_len":	1000,
#     "max_hist_len":	5,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	10,
#     "partially_observable":	false,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	1000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 189830, 	 q1: 190721, 	 q2: 190721
#
# t=0, 0.0s
# t=200, 0.029920578002929688s
# t=400, 0.02992105484008789s
# t=600, 0.03390836715698242s
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# t=800, 0.039893388748168945s
# t=1000, 0.03490638732910156s
# t=1200, 9.249303579330444s
# t=1400, 8.719646692276001s
# t=1600, 8.617952823638916s
# t=1800, 9.289445161819458s
# t=2000, 8.647948980331421s
# t=2200, 8.492283344268799s
# t=2400, 8.910146474838257s
# t=2600, 9.341049671173096s
# t=2800, 8.919153213500977s
# t=3000, 9.832670211791992s
# t=3200, 10.021872520446777s
# t=3400, 9.572370767593384s
# t=3600, 10.17482304573059s
# t=3800, 9.09268569946289s
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -428 |
# |          StdEpRet |             144 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -551 |
# |  AverageTestEpRet |            -406 |
# |      StdTestEpRet |            32.4 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |            -448 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |          -0.563 |
# |         StdQ1Vals |            1.07 |
# |         MaxQ1Vals |            7.93 |
# |         MinQ1Vals |           -6.94 |
# |     AverageQ2Vals |           0.158 |
# |         StdQ2Vals |           0.195 |
# |         MaxQ2Vals |            1.42 |
# |         MinQ2Vals |          -0.174 |
# |            LossPi |           0.281 |
# |             LossQ |          0.0259 |
# |              Time |            54.2 |
# ---------------------------------------
# t=4000, 54.21351194381714s
# t=4200, 10.18672776222229s
# t=4400, 11.910285472869873s
# t=4600, 10.53384780883789s
# t=4800, 11.125248193740845s
# t=5000, 9.455737352371216s
# t=5200, 9.81174087524414s
# t=5400, 9.622266054153442s
# t=5600, 9.859660625457764s
# t=5800, 10.157843828201294s
# t=6000, 9.627222776412964s
# t=6200, 9.349997758865356s
# t=6400, 9.836725234985352s
# t=6600, 9.976324319839478s
# t=6800, 9.475663185119629s
# t=7000, 9.364929676055908s
# t=7200, 10.211686611175537s
# t=7400, 10.06308913230896s
# t=7600, 10.26155972480774s
# t=7800, 10.35431170463562s
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -356 |
# |          StdEpRet |            60.3 |
# |          MaxEpRet |            -289 |
# |          MinEpRet |            -454 |
# |  AverageTestEpRet |            -351 |
# |      StdTestEpRet |             110 |
# |      MaxTestEpRet |            -257 |
# |      MinTestEpRet |            -635 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            -1.6 |
# |         StdQ1Vals |            2.16 |
# |         MaxQ1Vals |            15.2 |
# |         MinQ1Vals |           -15.9 |
# |     AverageQ2Vals |           0.256 |
# |         StdQ2Vals |           0.259 |
# |         MaxQ2Vals |            1.42 |
# |         MinQ2Vals |          -0.202 |
# |            LossPi |            1.33 |
# |             LossQ |          0.0682 |
# |              Time |            55.3 |
# ---------------------------------------
# t=8000, 55.34352731704712s
# t=8200, 10.271531343460083s
# t=8400, 9.67215633392334s
# t=8600, 10.885903358459473s
# t=8800, 10.795593738555908s
# t=9000, 10.833184719085693s
# t=9200, 11.237977981567383s
# t=9400, 10.149836778640747s
# t=9600, 10.539965391159058s
# t=9800, 11.410281658172607s
# t=10000, 10.632673978805542s
# t=10200, 10.066059827804565s
# t=10400, 9.81777811050415s
# t=10600, 9.558427333831787s
# t=10800, 10.281486749649048s
# t=11000, 10.51912808418274s
# t=11200, 12.56618881225586s
# t=11400, 10.694204807281494s
# t=11600, 12.126544713973999s
# t=11800, 10.684461116790771s
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -101 |
# |          StdEpRet |             130 |
# |          MaxEpRet |            93.8 |
# |          MinEpRet |            -271 |
# |  AverageTestEpRet |             167 |
# |      StdTestEpRet |              49 |
# |      MaxTestEpRet |             259 |
# |      MinTestEpRet |            93.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |           -2.15 |
# |         StdQ1Vals |             3.2 |
# |         MaxQ1Vals |            20.8 |
# |         MinQ1Vals |             -18 |
# |     AverageQ2Vals |           0.333 |
# |         StdQ2Vals |            0.29 |
# |         MaxQ2Vals |            1.48 |
# |         MinQ2Vals |          -0.202 |
# |            LossPi |            1.85 |
# |             LossQ |           0.184 |
# |              Time |              54 |
# ---------------------------------------
# t=12000, 54.00047540664673s
# t=12200, 10.271560192108154s
# t=12400, 9.644219160079956s
# t=12600, 11.26683783531189s
# t=12800, 10.2416410446167s
# t=13000, 10.051315069198608s
# t=13200, 10.987850666046143s
# t=13400, 10.779669284820557s
# t=13600, 9.943382263183594s
# t=13800, 11.382561206817627s
# t=14000, 10.466429233551025s
# t=14200, 10.66611099243164s
# t=14400, 10.383573055267334s
# t=14600, 10.820240497589111s
# t=14800, 10.950695514678955s
# t=15000, 9.75792145729065s
# t=15200, 9.69608759880066s
# t=15400, 9.605310916900635s
# t=15600, 10.5118887424469s
# t=15800, 10.59394121170044s
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             188 |
# |          StdEpRet |            41.7 |
# |          MaxEpRet |             242 |
# |          MinEpRet |             138 |
# |  AverageTestEpRet |            50.4 |
# |      StdTestEpRet |            68.2 |
# |      MaxTestEpRet |             126 |
# |      MinTestEpRet |           -75.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |          -0.702 |
# |         StdQ1Vals |            4.53 |
# |         MaxQ1Vals |            23.7 |
# |         MinQ1Vals |           -19.9 |
# |     AverageQ2Vals |           0.396 |
# |         StdQ2Vals |           0.313 |
# |         MaxQ2Vals |            1.48 |
# |         MinQ2Vals |          -0.214 |
# |            LossPi |             0.3 |
# |             LossQ |           0.364 |
# |              Time |            57.6 |
# ---------------------------------------
# t=16000, 57.613452672958374s
# t=16200, 11.27584457397461s
# t=16400, 10.94274091720581s
# t=16600, 10.364279985427856s
# t=16800, 9.993272066116333s
# t=17000, 10.97365689277649s
# t=17200, 10.441051483154297s
# t=17400, 10.441362619400024s
# t=17600, 10.610316753387451s
# t=17800, 9.870603084564209s
# t=18000, 10.072895288467407s
# t=18200, 10.433074951171875s
# t=18400, 9.953412771224976s
# t=18600, 12.127568483352661s
# t=18800, 11.478277206420898s
# t=19000, 10.265549421310425s
# t=19200, 10.054300785064697s
# t=19400, 11.817370653152466s
# t=19600, 10.034197807312012s
# t=19800, 9.811729907989502s
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             145 |
# |          StdEpRet |             140 |
# |          MaxEpRet |             313 |
# |          MinEpRet |           -26.5 |
# |  AverageTestEpRet |             277 |
# |      StdTestEpRet |            61.5 |
# |      MaxTestEpRet |             333 |
# |      MinTestEpRet |             132 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            2.23 |
# |         StdQ1Vals |            5.42 |
# |         MaxQ1Vals |            32.7 |
# |         MinQ1Vals |           -19.1 |
# |     AverageQ2Vals |           0.426 |
# |         StdQ2Vals |           0.321 |
# |         MaxQ2Vals |            1.49 |
# |         MinQ2Vals |          -0.214 |
# |            LossPi |           -2.72 |
# |             LossQ |           0.617 |
# |              Time |            52.1 |
# ---------------------------------------
# t=20000, 52.07674241065979s
# t=20200, 10.555770874023438s
# t=20400, 12.494620323181152s
# t=20600, 10.424091815948486s
# t=20800, 9.766909837722778s
# t=21000, 9.761904239654541s
# t=21200, 11.2542085647583s
# t=21400, 9.510568141937256s
# t=21600, 10.908218622207642s
# t=21800, 10.124120950698853s
# t=22000, 9.979280710220337s
# t=22200, 10.349039554595947s
# t=22400, 10.124893426895142s
# t=22600, 9.70108151435852s
# t=22800, 10.242586851119995s
# t=23000, 10.566775560379028s
# t=23200, 11.270850896835327s
# t=23400, 10.753253698348999s
# t=23600, 10.20072078704834s
# t=23800, 10.15381646156311s
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             129 |
# |          StdEpRet |             112 |
# |          MaxEpRet |             218 |
# |          MinEpRet |           -62.9 |
# |  AverageTestEpRet |             238 |
# |      StdTestEpRet |            87.1 |
# |      MaxTestEpRet |             317 |
# |      MinTestEpRet |            61.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            5.35 |
# |         StdQ1Vals |            5.83 |
# |         MaxQ1Vals |            40.6 |
# |         MinQ1Vals |           -20.8 |
# |     AverageQ2Vals |           0.443 |
# |         StdQ2Vals |           0.323 |
# |         MaxQ2Vals |            1.49 |
# |         MinQ2Vals |          -0.214 |
# |            LossPi |           -5.86 |
# |             LossQ |           0.804 |
# |              Time |            57.9 |
# ---------------------------------------
# t=24000, 57.93410563468933s
# t=24200, 10.748261213302612s
# t=24400, 10.933730602264404s
# t=24600, 10.224685668945312s
# t=24800, 13.878859758377075s
# t=25000, 11.774051189422607s
# t=25200, 11.63391399383545s
# t=25400, 11.205011367797852s
# t=25600, 12.71602749824524s
# t=25800, 9.935428857803345s
# t=26000, 9.592322587966919s
# t=26200, 11.31181001663208s
# t=26400, 10.081068515777588s
# t=26600, 9.716020822525024s
# t=26800, 9.925459146499634s
# t=27000, 10.363282203674316s
# t=27200, 10.085036277770996s
# t=27400, 11.048423767089844s
# t=27600, 10.677465677261353s
# t=27800, 12.799973726272583s
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             139 |
# |          StdEpRet |             176 |
# |          MaxEpRet |             273 |
# |          MinEpRet |            -163 |
# |  AverageTestEpRet |            23.7 |
# |      StdTestEpRet |             193 |
# |      MaxTestEpRet |             188 |
# |      MinTestEpRet |            -534 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            8.43 |
# |         StdQ1Vals |            6.34 |
# |         MaxQ1Vals |            50.9 |
# |         MinQ1Vals |           -28.1 |
# |     AverageQ2Vals |           0.453 |
# |         StdQ2Vals |           0.323 |
# |         MaxQ2Vals |            1.49 |
# |         MinQ2Vals |          -0.214 |
# |            LossPi |           -8.91 |
# |             LossQ |            1.13 |
# |              Time |            51.6 |
# ---------------------------------------
# t=28000, 51.59491944313049s
# t=28200, 10.433100461959839s
# t=28400, 10.676477432250977s
# t=28600, 10.214689016342163s
# t=28800, 9.728951454162598s
# t=29000, 10.12109899520874s
# t=29200, 10.386229753494263s
# t=29400, 10.790475130081177s
# t=29600, 12.649438858032227s
# t=29800, 12.179722309112549s
# t=30000, 10.407059669494629s
# t=30200, 11.25532841682434s
# t=30400, 9.767873287200928s
# t=30600, 9.949399471282959s
# t=30800, 9.77988862991333s
# t=31000, 9.718989849090576s
# t=31200, 9.604376554489136s
# t=31400, 9.95548963546753s
# t=31600, 9.929261684417725s
# t=31800, 10.256283283233643s
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             146 |
# |          StdEpRet |             119 |
# |          MaxEpRet |             260 |
# |          MinEpRet |           -51.1 |
# |  AverageTestEpRet |             166 |
# |      StdTestEpRet |             218 |
# |      MaxTestEpRet |             371 |
# |      MinTestEpRet |            -276 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            11.4 |
# |         StdQ1Vals |            7.04 |
# |         MaxQ1Vals |            56.4 |
# |         MinQ1Vals |             -30 |
# |     AverageQ2Vals |           0.457 |
# |         StdQ2Vals |           0.326 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -11.8 |
# |             LossQ |             1.3 |
# |              Time |            55.2 |
# ---------------------------------------
# t=32000, 55.15305972099304s
# t=32200, 10.359332084655762s
# t=32400, 13.151177644729614s
# t=32600, 10.846024990081787s
# t=32800, 12.955329179763794s
# t=33000, 12.884014129638672s
# t=33200, 11.004591226577759s
# t=33400, 11.487552881240845s
# t=33600, 10.30940556526184s
# t=33800, 10.205979585647583s
# t=34000, 10.955588817596436s
# t=34200, 10.526699542999268s
# t=34400, 10.074635028839111s
# t=34600, 10.976293802261353s
# t=34800, 10.66737174987793s
# t=35000, 11.21700119972229s
# t=35200, 10.83802318572998s
# t=35400, 10.570732831954956s
# t=35600, 10.23723292350769s
# t=35800, 10.205709218978882s
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             179 |
# |          StdEpRet |              59 |
# |          MaxEpRet |             258 |
# |          MinEpRet |            91.9 |
# |  AverageTestEpRet |           -16.7 |
# |      StdTestEpRet |             138 |
# |      MaxTestEpRet |             148 |
# |      MinTestEpRet |            -307 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            13.9 |
# |         StdQ1Vals |            7.43 |
# |         MaxQ1Vals |            58.2 |
# |         MinQ1Vals |           -33.2 |
# |     AverageQ2Vals |           0.462 |
# |         StdQ2Vals |           0.329 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -14.4 |
# |             LossQ |             1.5 |
# |              Time |            57.9 |
# ---------------------------------------
# t=36000, 57.951064586639404s
# t=36200, 10.622125148773193s
# t=36400, 11.571070194244385s
# t=36600, 11.483548402786255s
# t=36800, 10.149532079696655s
# t=37000, 10.16079831123352s
# t=37200, 10.50792407989502s
# t=37400, 11.227895021438599s
# t=37600, 9.999216556549072s
# t=37800, 10.85603404045105s
# t=38000, 11.384448528289795s
# t=38200, 10.882249593734741s
# t=38400, 10.844576835632324s
# t=38600, 10.823449611663818s
# t=38800, 10.31237530708313s
# t=39000, 10.318747520446777s
# t=39200, 9.949361085891724s
# t=39400, 9.776875257492065s
# t=39600, 9.838765144348145s
# t=39800, 9.284178495407104s
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             139 |
# |          StdEpRet |             116 |
# |          MaxEpRet |             268 |
# |          MinEpRet |           -13.8 |
# |  AverageTestEpRet |             142 |
# |      StdTestEpRet |             263 |
# |      MaxTestEpRet |             388 |
# |      MinTestEpRet |            -389 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            16.3 |
# |         StdQ1Vals |            7.83 |
# |         MaxQ1Vals |            62.8 |
# |         MinQ1Vals |           -32.5 |
# |     AverageQ2Vals |           0.468 |
# |         StdQ2Vals |           0.333 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -16.8 |
# |             LossQ |            1.77 |
# |              Time |              53 |
# ---------------------------------------
# t=40000, 53.00118923187256s
# t=40200, 10.862925052642822s
# t=40400, 9.969933986663818s
# t=40600, 11.500838041305542s
# t=40800, 10.498560428619385s
# t=41000, 10.924813270568848s
# t=41200, 12.14851975440979s
# t=41400, 10.307277202606201s
# t=41600, 10.126946687698364s
# t=41800, 10.450840950012207s
# t=42000, 10.822092056274414s
# t=42200, 11.216795682907104s
# t=42400, 9.959024906158447s
# t=42600, 9.759900569915771s
# t=42800, 13.770174980163574s
# t=43000, 10.312427282333374s
# t=43200, 10.542925596237183s
# t=43400, 9.814701795578003s
# t=43600, 9.320077180862427s
# t=43800, 9.401832103729248s
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             130 |
# |          StdEpRet |             252 |
# |          MaxEpRet |             357 |
# |          MinEpRet |            -297 |
# |  AverageTestEpRet |             288 |
# |      StdTestEpRet |             255 |
# |      MaxTestEpRet |             444 |
# |      MinTestEpRet |            -464 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            18.7 |
# |         StdQ1Vals |            8.61 |
# |         MaxQ1Vals |              71 |
# |         MinQ1Vals |             -30 |
# |     AverageQ2Vals |            0.47 |
# |         StdQ2Vals |           0.333 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -19.2 |
# |             LossQ |            2.08 |
# |              Time |            49.8 |
# ---------------------------------------
# t=44000, 49.83573293685913s
# t=44200, 9.145574808120728s
# t=44400, 9.71199631690979s
# t=44600, 9.739986896514893s
# t=44800, 9.302120923995972s
# t=45000, 9.480651617050171s
# t=45200, 9.80454683303833s
# t=45400, 9.532520055770874s
# t=45600, 9.256250381469727s
# t=45800, 9.656175374984741s
# t=46000, 9.179452419281006s
# t=46200, 9.955347776412964s
# t=46400, 9.689499139785767s
# t=46600, 10.327070713043213s
# t=46800, 9.459701299667358s
# t=47000, 9.24228549003601s
# t=47200, 9.845641613006592s
# t=47400, 9.842709302902222s
# t=47600, 10.163793563842773s
# t=47800, 10.933760643005371s
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             294 |
# |          StdEpRet |             304 |
# |          MaxEpRet |             553 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |             682 |
# |      StdTestEpRet |             120 |
# |      MaxTestEpRet |             931 |
# |      MinTestEpRet |             521 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            21.8 |
# |         StdQ1Vals |            9.36 |
# |         MaxQ1Vals |            72.4 |
# |         MinQ1Vals |           -26.1 |
# |     AverageQ2Vals |           0.459 |
# |         StdQ2Vals |           0.335 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -22.4 |
# |             LossQ |            2.07 |
# |              Time |            55.3 |
# ---------------------------------------
# t=48000, 55.345327377319336s
# t=48200, 9.964354515075684s
# t=48400, 11.190108299255371s
# t=48600, 9.889551639556885s
# t=48800, 9.834705352783203s
# t=49000, 9.376915216445923s
# t=49200, 9.841689348220825s
# t=49400, 9.416785717010498s
# t=49600, 9.537527799606323s
# t=49800, 9.944376707077026s
# t=50000, 9.457740306854248s
# t=50200, 9.183442115783691s
# t=50400, 9.464688301086426s
# t=50600, 9.972304821014404s
# t=50800, 9.972535848617554s
# t=51000, 10.79311203956604s
# t=51200, 11.56813907623291s
# t=51400, 11.001574754714966s
# t=51600, 10.631424903869629s
# t=51800, 10.223690509796143s
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             759 |
# |          StdEpRet |             170 |
# |          MaxEpRet |             920 |
# |          MinEpRet |             510 |
# |  AverageTestEpRet |             628 |
# |      StdTestEpRet |             231 |
# |      MaxTestEpRet |             918 |
# |      MinTestEpRet |            45.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            25.6 |
# |         StdQ1Vals |            10.7 |
# |         MaxQ1Vals |            72.5 |
# |         MinQ1Vals |           -23.2 |
# |     AverageQ2Vals |           0.461 |
# |         StdQ2Vals |           0.333 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -26.2 |
# |             LossQ |            2.32 |
# |              Time |            51.4 |
# ---------------------------------------
# t=52000, 51.37908959388733s
# t=52200, 9.458693027496338s
# t=52400, 9.317086696624756s
# t=52600, 10.405444145202637s
# t=52800, 12.138648986816406s
# t=53000, 11.242750406265259s
# t=53200, 9.579409837722778s
# t=53400, 9.413825511932373s
# t=53600, 9.872604370117188s
# t=53800, 9.847632884979248s
# t=54000, 9.99829649925232s
# t=54200, 9.598336696624756s
# t=54400, 9.588351964950562s
# t=54600, 10.492939710617065s
# t=54800, 9.754913568496704s
# t=55000, 9.985103845596313s
# t=55200, 9.927488327026367s
# t=55400, 10.969524621963501s
# t=55600, 10.805241823196411s
# t=55800, 10.120939493179321s
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             988 |
# |          StdEpRet |             112 |
# |          MaxEpRet |         1.1e+03 |
# |          MinEpRet |             803 |
# |  AverageTestEpRet |             860 |
# |      StdTestEpRet |             298 |
# |      MaxTestEpRet |         1.2e+03 |
# |      MinTestEpRet |             373 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            30.7 |
# |         StdQ1Vals |            12.5 |
# |         MaxQ1Vals |            76.9 |
# |         MinQ1Vals |           -21.6 |
# |     AverageQ2Vals |           0.462 |
# |         StdQ2Vals |           0.331 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -31.5 |
# |             LossQ |            2.55 |
# |              Time |            54.4 |
# ---------------------------------------
# t=56000, 54.41252136230469s
# t=56200, 9.903345108032227s
# t=56400, 9.75095272064209s
# t=56600, 9.944466352462769s
# t=56800, 11.022710800170898s
# t=57000, 10.077625274658203s
# t=57200, 9.751915454864502s
# t=57400, 10.238157033920288s
# t=57600, 10.877913475036621s
# t=57800, 12.221306085586548s
# t=58000, 10.87088656425476s
# t=58200, 10.338319063186646s
# t=58400, 10.22130537033081s
# t=58600, 11.363181352615356s
# t=58800, 10.674197912216187s
# t=59000, 9.678118467330933s
# t=59200, 9.806262016296387s
# t=59400, 14.649861574172974s
# t=59600, 10.913296461105347s
# t=59800, 10.116947412490845s
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        1.31e+03 |
# |          StdEpRet |             157 |
# |          MaxEpRet |        1.54e+03 |
# |          MinEpRet |        1.11e+03 |
# |  AverageTestEpRet |        1.48e+03 |
# |      StdTestEpRet |            71.1 |
# |      MaxTestEpRet |        1.59e+03 |
# |      MinTestEpRet |        1.38e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            37.1 |
# |         StdQ1Vals |            14.1 |
# |         MaxQ1Vals |            91.7 |
# |         MinQ1Vals |           -17.2 |
# |     AverageQ2Vals |           0.463 |
# |         StdQ2Vals |           0.329 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -38.1 |
# |             LossQ |            2.94 |
# |              Time |            53.2 |
# ---------------------------------------
# t=60000, 53.21885323524475s
# t=60200, 9.294173240661621s
# t=60400, 9.329060316085815s
# t=60600, 9.377919673919678s
# t=60800, 9.678106784820557s
# t=61000, 10.080052852630615s
# t=61200, 10.425044536590576s
# t=61400, 9.430748462677002s
# t=61600, 9.580381393432617s
# t=61800, 9.758689403533936s
# t=62000, 11.335603475570679s
# t=62200, 10.875944137573242s
# t=62400, 9.928449630737305s
# t=62600, 10.049126863479614s
# t=62800, 9.869623899459839s
# t=63000, 9.564413070678711s
# t=63200, 9.433740854263306s
# t=63400, 9.251291036605835s
# t=63600, 9.548462629318237s
# t=63800, 10.159677505493164s
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |         1.2e+03 |
# |          StdEpRet |             349 |
# |          MaxEpRet |        1.53e+03 |
# |          MinEpRet |             623 |
# |  AverageTestEpRet |        1.35e+03 |
# |      StdTestEpRet |             526 |
# |      MaxTestEpRet |        1.74e+03 |
# |      MinTestEpRet |            43.1 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            44.2 |
# |         StdQ1Vals |            16.2 |
# |         MaxQ1Vals |             103 |
# |         MinQ1Vals |           -16.8 |
# |     AverageQ2Vals |           0.465 |
# |         StdQ2Vals |           0.327 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -45.2 |
# |             LossQ |             3.5 |
# |              Time |            54.3 |
# ---------------------------------------
# t=64000, 54.253819704055786s
# t=64200, 9.227356910705566s
# t=64400, 9.294148921966553s
# t=64600, 9.312098026275635s
# t=64800, 9.417815923690796s
# t=65000, 9.511531829833984s
# t=65200, 9.765912055969238s
# t=65400, 9.426762342453003s
# t=65600, 9.218385696411133s
# t=65800, 9.374892950057983s
# t=66000, 9.424830675125122s
# t=66200, 9.5634183883667s
# t=66400, 9.295147180557251s
# t=66600, 9.426795482635498s
# t=66800, 9.250263452529907s
# t=67000, 9.213365077972412s
# t=67200, 9.43872594833374s
# t=67400, 9.482673406600952s
# t=67600, 9.393879652023315s
# t=67800, 9.36592149734497s
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        1.59e+03 |
# |          StdEpRet |             255 |
# |          MaxEpRet |        1.93e+03 |
# |          MinEpRet |        1.22e+03 |
# |  AverageTestEpRet |        1.42e+03 |
# |      StdTestEpRet |             506 |
# |      MaxTestEpRet |        1.77e+03 |
# |      MinTestEpRet |             259 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |              51 |
# |         StdQ1Vals |            18.5 |
# |         MaxQ1Vals |             116 |
# |         MinQ1Vals |           -15.6 |
# |     AverageQ2Vals |           0.466 |
# |         StdQ2Vals |           0.326 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -51.9 |
# |             LossQ |            4.08 |
# |              Time |            50.9 |
# ---------------------------------------
# t=68000, 50.90986466407776s
# t=68200, 14.50144076347351s
# t=68400, 10.994627475738525s
# t=68600, 11.050450086593628s
# t=68800, 10.839016914367676s
# t=69000, 10.663451910018921s
# t=69200, 10.97664499282837s
# t=69400, 10.73732304573059s
# t=69600, 10.917767763137817s
# t=69800, 10.743273496627808s
# t=70000, 10.64752745628357s
# t=70200, 10.658497095108032s
# t=70400, 10.738285779953003s
# t=70600, 10.61262035369873s
# t=70800, 10.526875734329224s
# t=71000, 10.736266136169434s
# t=71200, 11.104301691055298s
# t=71400, 11.113310098648071s
# t=71600, 10.809067726135254s
# t=71800, 10.772195100784302s
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        1.73e+03 |
# |          StdEpRet |             102 |
# |          MaxEpRet |        1.84e+03 |
# |          MinEpRet |        1.58e+03 |
# |  AverageTestEpRet |        1.19e+03 |
# |      StdTestEpRet |             689 |
# |      MaxTestEpRet |         1.8e+03 |
# |      MinTestEpRet |            1.28 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            58.1 |
# |         StdQ1Vals |            21.6 |
# |         MaxQ1Vals |             125 |
# |         MinQ1Vals |           -11.3 |
# |     AverageQ2Vals |           0.468 |
# |         StdQ2Vals |           0.323 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -59.1 |
# |             LossQ |             4.9 |
# |              Time |            56.1 |
# ---------------------------------------
# t=72000, 56.12554454803467s
# t=72200, 10.68641471862793s
# t=72400, 10.649534702301025s
# t=72600, 10.736286640167236s
# t=72800, 10.64952301979065s
# t=73000, 10.682435989379883s
# t=73200, 10.709348917007446s
# t=73400, 10.752260446548462s
# t=73600, 10.690399169921875s
# t=73800, 10.60961127281189s
# t=74000, 10.801114082336426s
# t=74200, 10.565746068954468s
# t=74400, 10.565746068954468s
# t=74600, 10.50992751121521s
# t=74800, 10.650511741638184s
# t=75000, 10.934733867645264s
# t=75200, 11.546128988265991s
# t=75400, 10.703375101089478s
# t=75600, 10.574753284454346s
# t=75800, 10.808066129684448s
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |         1.6e+03 |
# |          StdEpRet |             634 |
# |          MaxEpRet |        2.03e+03 |
# |          MinEpRet |             508 |
# |  AverageTestEpRet |        1.52e+03 |
# |      StdTestEpRet |             455 |
# |      MaxTestEpRet |        2.06e+03 |
# |      MinTestEpRet |             652 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            65.2 |
# |         StdQ1Vals |            24.2 |
# |         MaxQ1Vals |             133 |
# |         MinQ1Vals |           -2.81 |
# |     AverageQ2Vals |            0.47 |
# |         StdQ2Vals |           0.321 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |           -66.3 |
# |             LossQ |            5.54 |
# |              Time |            55.4 |
# ---------------------------------------
# t=76000, 55.424819231033325s
# t=76200, 12.034785032272339s
# t=76400, 10.792139768600464s
# t=76600, 10.72432255744934s
# t=76800, 10.662518501281738s
# t=77000, 10.55374813079834s
# t=77200, 10.734326362609863s
# t=77400, 10.885890483856201s
# t=77600, 10.949687004089355s
# t=77800, 10.7322998046875s
# t=78000, 10.652512311935425s
# t=78200, 10.704379320144653s
# t=78400, 10.677474021911621s
# t=78600, 10.764190196990967s
# t=78800, 10.896888017654419s
# t=79000, 10.857917785644531s
# t=79200, 10.686452865600586s
# t=79400, 10.719306707382202s
# t=79600, 10.50889801979065s
# t=79800, 10.974684953689575s
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |        1.25e+03 |
# |          StdEpRet |             921 |
# |          MaxEpRet |        2.02e+03 |
# |          MinEpRet |            -299 |
# |  AverageTestEpRet |        1.26e+03 |
# |      StdTestEpRet |             829 |
# |      MaxTestEpRet |        2.24e+03 |
# |      MinTestEpRet |            -153 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            72.6 |
# |         StdQ1Vals |            27.2 |
# |         MaxQ1Vals |             143 |
# |         MinQ1Vals |           -2.42 |
# |     AverageQ2Vals |            0.47 |
# |         StdQ2Vals |           0.318 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |           -73.8 |
# |             LossQ |            6.24 |
# |              Time |            55.1 |
# ---------------------------------------
# t=80000, 55.0896782875061s
# t=80200, 10.600659608840942s
# t=80400, 10.709361791610718s
# t=80600, 10.613582611083984s
# t=80800, 10.721332788467407s
# t=81000, 11.1322603225708s
# t=81200, 10.789124488830566s
# t=81400, 10.571750402450562s
# t=81600, 10.7123281955719s
# t=81800, 10.595667839050293s
# t=82000, 10.683454513549805s
# t=82200, 10.761224508285522s
# t=82400, 10.88286828994751s
# t=82600, 12.093660831451416s
# t=82800, 10.71737265586853s
# t=83000, 11.066375255584717s
# t=83200, 10.863949298858643s
# t=83400, 10.674484252929688s
# t=83600, 10.552756547927856s
# t=83800, 10.856962203979492s
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |         1.3e+03 |
# |          StdEpRet |             883 |
# |          MaxEpRet |        2.02e+03 |
# |          MinEpRet |            -199 |
# |  AverageTestEpRet |        1.08e+03 |
# |      StdTestEpRet |             567 |
# |      MaxTestEpRet |           2e+03 |
# |      MinTestEpRet |             263 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            78.4 |
# |         StdQ1Vals |            30.5 |
# |         MaxQ1Vals |             152 |
# |         MinQ1Vals |            6.17 |
# |     AverageQ2Vals |           0.469 |
# |         StdQ2Vals |           0.317 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |           -79.5 |
# |             LossQ |            6.58 |
# |              Time |            55.8 |
# ---------------------------------------
# t=84000, 55.75989389419556s
# t=84200, 10.580729961395264s
# t=84400, 10.69038438796997s
# t=84600, 10.719335794448853s
# t=84800, 10.65254807472229s
# t=85000, 10.662465810775757s
# t=85200, 10.81905460357666s
# t=85400, 11.230932712554932s
# t=85600, 10.715321779251099s
# t=85800, 10.721357822418213s
# t=86000, 10.74723482131958s
# t=86200, 11.38555097579956s
# t=86400, 11.069429636001587s
# t=86600, 10.723323822021484s
# t=86800, 10.609602451324463s
# t=87000, 10.693433046340942s
# t=87200, 10.662485599517822s
# t=87400, 10.670471429824829s
# t=87600, 10.784127712249756s
# t=87800, 10.710360050201416s
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        1.14e+03 |
# |          StdEpRet |             298 |
# |          MaxEpRet |        1.52e+03 |
# |          MinEpRet |             701 |
# |  AverageTestEpRet |        1.33e+03 |
# |      StdTestEpRet |             592 |
# |      MaxTestEpRet |           2e+03 |
# |      MinTestEpRet |             306 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            83.6 |
# |         StdQ1Vals |            34.1 |
# |         MaxQ1Vals |             161 |
# |         MinQ1Vals |              10 |
# |     AverageQ2Vals |            0.47 |
# |         StdQ2Vals |           0.316 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |           -84.6 |
# |             LossQ |            6.85 |
# |              Time |            55.5 |
# ---------------------------------------
# t=88000, 55.52252817153931s
# t=88200, 10.698419094085693s
# t=88400, 10.98958134651184s
# t=88600, 10.836049556732178s
# t=88800, 10.573729276657104s
# t=89000, 10.582696437835693s
# t=89200, 10.58468770980835s
# t=89400, 10.590660333633423s
# t=89600, 10.748287200927734s
# t=89800, 10.725290060043335s
# t=90000, 10.649519205093384s
# t=90200, 11.431459188461304s
# t=90400, 12.054767847061157s
# t=90600, 10.913811445236206s
# t=90800, 10.997583150863647s
# t=91000, 10.856979131698608s
# t=91200, 10.779175281524658s
# t=91400, 10.628545999526978s
# t=91600, 10.714353561401367s
# t=91800, 10.750816345214844s
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        1.84e+03 |
# |          StdEpRet |             450 |
# |          MaxEpRet |        2.35e+03 |
# |          MinEpRet |        1.27e+03 |
# |  AverageTestEpRet |         1.6e+03 |
# |      StdTestEpRet |             704 |
# |      MaxTestEpRet |         2.4e+03 |
# |      MinTestEpRet |             460 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            88.7 |
# |         StdQ1Vals |              38 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |            7.53 |
# |     AverageQ2Vals |            0.47 |
# |         StdQ2Vals |           0.314 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |           -89.7 |
# |             LossQ |            7.26 |
# |              Time |            55.5 |
# ---------------------------------------
# t=92000, 55.48465824127197s
# t=92200, 10.698391199111938s
# t=92400, 10.623558759689331s
# t=92600, 10.746291637420654s
# t=92800, 10.725293159484863s
# t=93000, 10.687418699264526s
# t=93200, 11.025544881820679s
# t=93400, 11.239914655685425s
# t=93600, 11.194099187850952s
# t=93800, 10.88286304473877s
# t=94000, 11.004606246948242s
# t=94200, 10.628545045852661s
# t=94400, 10.650520086288452s
# t=94600, 10.587721347808838s
# t=94800, 10.662485361099243s
# t=95000, 10.623587608337402s
# t=95200, 10.620603084564209s
# t=95400, 10.827017784118652s
# t=95600, 10.729305744171143s
# t=95800, 10.59270191192627s
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             995 |
# |          StdEpRet |             707 |
# |          MaxEpRet |         2.2e+03 |
# |          MinEpRet |             460 |
# |  AverageTestEpRet |         1.8e+03 |
# |      StdTestEpRet |             611 |
# |      MaxTestEpRet |        2.57e+03 |
# |      MinTestEpRet |             767 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            92.5 |
# |         StdQ1Vals |            41.7 |
# |         MaxQ1Vals |             179 |
# |         MinQ1Vals |            5.59 |
# |     AverageQ2Vals |           0.472 |
# |         StdQ2Vals |           0.314 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |           -93.6 |
# |             LossQ |            7.54 |
# |              Time |            55.5 |
# ---------------------------------------
# t=96000, 55.51252627372742s
# t=96200, 10.489978790283203s
# t=96400, 10.506903171539307s
# t=96600, 10.791143417358398s
# t=96800, 10.919768333435059s
# t=97000, 10.631571292877197s
# t=97200, 10.54579758644104s
# t=97400, 10.764213562011719s
# t=97600, 10.739309787750244s
# t=97800, 10.607607126235962s
# t=98000, 10.536851167678833s
# t=98200, 11.150460720062256s
# t=98400, 10.808070659637451s
# t=98600, 11.135249614715576s
# t=98800, 12.536309480667114s
# t=99000, 12.9085214138031s
# t=99200, 11.920170783996582s
# t=99400, 11.242465734481812s
# t=99600, 10.733210802078247s
# t=99800, 11.37158989906311s
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        2.08e+03 |
# |          StdEpRet |             133 |
# |          MaxEpRet |        2.24e+03 |
# |          MinEpRet |        1.92e+03 |
# |  AverageTestEpRet |        2.12e+03 |
# |      StdTestEpRet |             821 |
# |      MaxTestEpRet |        2.78e+03 |
# |      MinTestEpRet |             425 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            97.4 |
# |         StdQ1Vals |            45.6 |
# |         MaxQ1Vals |             198 |
# |         MinQ1Vals |            5.82 |
# |     AverageQ2Vals |           0.473 |
# |         StdQ2Vals |           0.312 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |           -98.6 |
# |             LossQ |            7.99 |
# |              Time |            55.1 |
# ---------------------------------------
# t=100000, 55.10049796104431s
# t=100200, 10.145860195159912s
# t=100400, 9.653158187866211s
# t=100600, 9.45274829864502s
# t=100800, 9.64122486114502s
# t=101000, 9.672132968902588s
# t=101200, 9.401862382888794s
# t=101400, 9.50856328010559s
# t=101600, 9.412841081619263s
# t=101800, 9.40983271598816s
# t=102000, 9.500563859939575s
# t=102200, 9.411864519119263s
# t=102400, 9.406845092773438s
# t=102600, 9.416815757751465s
# t=102800, 9.86362361907959s
# t=103000, 9.416820526123047s
# t=103200, 9.642182350158691s
# t=103400, 9.324096918106079s
# t=103600, 9.569405317306519s
# t=103800, 9.411832332611084s
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        2.05e+03 |
# |          StdEpRet |             709 |
# |          MaxEpRet |        2.74e+03 |
# |          MinEpRet |             864 |
# |  AverageTestEpRet |        2.18e+03 |
# |      StdTestEpRet |             618 |
# |      MaxTestEpRet |        2.69e+03 |
# |      MinTestEpRet |             400 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             103 |
# |         StdQ1Vals |            49.4 |
# |         MaxQ1Vals |             206 |
# |         MinQ1Vals |             2.7 |
# |     AverageQ2Vals |           0.473 |
# |         StdQ2Vals |           0.309 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -104 |
# |             LossQ |            8.25 |
# |              Time |            50.6 |
# ---------------------------------------
# t=104000, 50.6276273727417s
# t=104200, 10.69935131072998s
# t=104400, 10.290039300918579s
# t=104600, 10.6445631980896s
# t=104800, 10.69337773323059s
# t=105000, 10.640545845031738s
# t=105200, 10.751250267028809s
# t=105400, 10.800145387649536s
# t=105600, 10.779175758361816s
# t=105800, 10.803110599517822s
# t=106000, 10.888857364654541s
# t=106200, 10.771193742752075s
# t=106400, 10.785157918930054s
# t=106600, 10.82009506225586s
# t=106800, 11.292772054672241s
# t=107000, 10.746264934539795s
# t=107200, 10.704401969909668s
# t=107400, 10.847991466522217s
# t=107600, 10.862922668457031s
# t=107800, 10.869965076446533s
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |        1.83e+03 |
# |          StdEpRet |             819 |
# |          MaxEpRet |        2.71e+03 |
# |          MinEpRet |             850 |
# |  AverageTestEpRet |        2.11e+03 |
# |      StdTestEpRet |             801 |
# |      MaxTestEpRet |        2.84e+03 |
# |      MinTestEpRet |             420 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             107 |
# |         StdQ1Vals |            53.2 |
# |         MaxQ1Vals |             214 |
# |         MinQ1Vals |            2.69 |
# |     AverageQ2Vals |           0.474 |
# |         StdQ2Vals |           0.308 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -109 |
# |             LossQ |            8.68 |
# |              Time |            55.7 |
# ---------------------------------------
# t=108000, 55.720996379852295s
# t=108200, 10.639515161514282s
# t=108400, 10.800120830535889s
# t=108600, 10.7901451587677s
# t=108800, 10.763245105743408s
# t=109000, 10.909800052642822s
# t=109200, 11.015541076660156s
# t=109400, 10.67848014831543s
# t=109600, 10.963674545288086s
# t=109800, 11.636885643005371s
# t=110000, 10.754238367080688s
# t=110200, 10.817047595977783s
# t=110400, 10.905866622924805s
# t=110600, 10.878904581069946s
# t=110800, 10.583696842193604s
# t=111000, 10.932767152786255s
# t=111200, 10.706367254257202s
# t=111400, 10.942711114883423s
# t=111600, 10.988615036010742s
# t=111800, 10.844001531600952s
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        2.58e+03 |
# |          StdEpRet |             128 |
# |          MaxEpRet |        2.75e+03 |
# |          MinEpRet |        2.44e+03 |
# |  AverageTestEpRet |        1.86e+03 |
# |      StdTestEpRet |             821 |
# |      MaxTestEpRet |         2.8e+03 |
# |      MinTestEpRet |             155 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             112 |
# |         StdQ1Vals |            56.9 |
# |         MaxQ1Vals |             222 |
# |         MinQ1Vals |           -2.78 |
# |     AverageQ2Vals |           0.475 |
# |         StdQ2Vals |           0.306 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -114 |
# |             LossQ |            9.09 |
# |              Time |            56.6 |
# ---------------------------------------
# t=112000, 56.62560772895813s
# t=112200, 10.642507553100586s
# t=112400, 10.705402612686157s
# t=112600, 10.879876613616943s
# t=112800, 10.802114009857178s
# t=113000, 10.698394536972046s
# t=113200, 11.272107124328613s
# t=113400, 10.96467399597168s
# t=113600, 10.864944219589233s
# t=113800, 10.812118530273438s
# t=114000, 10.872922420501709s
# t=114200, 10.866911888122559s
# t=114400, 11.658823013305664s
# t=114600, 11.335714101791382s
# t=114800, 10.833003997802734s
# t=115000, 11.024553298950195s
# t=115200, 10.812052726745605s
# t=115400, 10.893898487091064s
# t=115600, 10.83901858329773s
# t=115800, 10.743258237838745s
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        2.61e+03 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |        2.63e+03 |
# |          MinEpRet |        2.58e+03 |
# |  AverageTestEpRet |        2.39e+03 |
# |      StdTestEpRet |             762 |
# |      MaxTestEpRet |        2.87e+03 |
# ...
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -169 |
# |             LossQ |            12.3 |
# |              Time |            51.1 |
# ---------------------------------------
# t=160000, 51.127246618270874s
# t=160200, 9.598333835601807s
# t=160400, 9.25624966621399s
# t=160600, 9.393909454345703s
# t=160800, 9.345999956130981s
# t=161000, 9.521515607833862s
# t=161200, 9.393877983093262s
# t=161400, 9.532522916793823s
# t=161600, 9.805796146392822s
# t=161800, 9.357977867126465s
# t=162000, 9.55341911315918s
# t=162200, 9.679116010665894s
# t=162400, 9.364957571029663s
# t=162600, 9.487658262252808s
# t=162800, 9.413825035095215s
# t=163000, 9.353990316390991s
# t=163200, 10.138884544372559s
# t=163400, 9.458675861358643s
# t=163600, 9.363960027694702s
# t=163800, 9.582264184951782s
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        2.99e+03 |
# |          StdEpRet |            94.1 |
# |          MaxEpRet |        3.13e+03 |
# |          MinEpRet |        2.87e+03 |
# |  AverageTestEpRet |        3.11e+03 |
# |      StdTestEpRet |             327 |
# |      MaxTestEpRet |        3.35e+03 |
# |      MinTestEpRet |        2.15e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             172 |
# |         StdQ1Vals |            89.4 |
# |         MaxQ1Vals |             286 |
# |         MinQ1Vals |            8.48 |
# |     AverageQ2Vals |           0.477 |
# |         StdQ2Vals |           0.291 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -173 |
# |             LossQ |            12.2 |
# |              Time |            49.7 |
# ---------------------------------------
# t=164000, 49.677003145217896s
# t=164200, 9.660162925720215s
# t=164400, 9.366955518722534s
# t=164600, 9.361932039260864s
# t=164800, 9.280183553695679s
# t=165000, 9.332074165344238s
# t=165200, 9.394847869873047s
# t=165400, 9.37094235420227s
# t=165600, 9.3959059715271s
# t=165800, 9.422802448272705s
# t=166000, 9.421804904937744s
# t=166200, 9.42276906967163s
# t=166400, 9.763918399810791s
# t=166600, 9.380913734436035s
# t=166800, 9.332018613815308s
# t=167000, 9.50258755683899s
# t=167200, 9.257247686386108s
# t=167400, 9.499626874923706s
# t=167600, 10.148861169815063s
# t=167800, 9.775856971740723s
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        3.16e+03 |
# |          StdEpRet |            97.1 |
# |          MaxEpRet |        3.26e+03 |
# |          MinEpRet |        3.01e+03 |
# |  AverageTestEpRet |         3.2e+03 |
# |      StdTestEpRet |             372 |
# |      MaxTestEpRet |         3.5e+03 |
# |      MinTestEpRet |        2.14e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             177 |
# |         StdQ1Vals |            90.7 |
# |         MaxQ1Vals |             291 |
# |         MinQ1Vals |            12.2 |
# |     AverageQ2Vals |           0.478 |
# |         StdQ2Vals |           0.291 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -178 |
# |             LossQ |              12 |
# |              Time |            50.2 |
# ---------------------------------------
# t=168000, 50.205740213394165s
# t=168200, 9.42077898979187s
# t=168400, 9.39589810371399s
# t=168600, 9.266230821609497s
# t=168800, 9.171469449996948s
# t=169000, 9.23427963256836s
# t=169200, 9.35800576210022s
# t=169400, 9.13753342628479s
# t=169600, 9.304147481918335s
# t=169800, 9.625226497650146s
# t=170000, 9.243255138397217s
# t=170200, 9.598366022109985s
# t=170400, 9.487595081329346s
# t=170600, 9.520570755004883s
# t=170800, 9.8546462059021s
# t=171000, 9.265196084976196s
# t=171200, 9.181480884552002s
# t=171400, 9.230282068252563s
# t=171600, 9.296174764633179s
# t=171800, 10.146833419799805s
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        3.14e+03 |
# |          StdEpRet |            50.3 |
# |          MaxEpRet |        3.21e+03 |
# |          MinEpRet |        3.07e+03 |
# |  AverageTestEpRet |        3.04e+03 |
# |      StdTestEpRet |             920 |
# |      MaxTestEpRet |        3.45e+03 |
# |      MinTestEpRet |             287 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             181 |
# |         StdQ1Vals |              92 |
# |         MaxQ1Vals |             297 |
# |         MinQ1Vals |            17.6 |
# |     AverageQ2Vals |           0.478 |
# |         StdQ2Vals |            0.29 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -183 |
# |             LossQ |            12.1 |
# |              Time |            48.9 |
# ---------------------------------------
# t=172000, 48.86333346366882s
# t=172200, 9.223367691040039s
# t=172400, 9.301128149032593s
# t=172600, 9.297125816345215s
# t=172800, 9.18641448020935s
# t=173000, 9.168517351150513s
# t=173200, 9.387892723083496s
# t=173400, 9.547463655471802s
# t=173600, 9.206388473510742s
# t=173800, 9.119610786437988s
# t=174000, 9.1824471950531s
# t=174200, 9.394695281982422s
# t=174400, 9.350029230117798s
# t=174600, 9.220311403274536s
# t=174800, 9.305145025253296s
# t=175000, 9.36595892906189s
# t=175200, 9.32004451751709s
# t=175400, 9.398865699768066s
# t=175600, 10.696397304534912s
# t=175800, 9.807779312133789s
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        3.14e+03 |
# |          StdEpRet |             125 |
# |          MaxEpRet |        3.25e+03 |
# |          MinEpRet |        2.93e+03 |
# |  AverageTestEpRet |        3.24e+03 |
# |      StdTestEpRet |            77.1 |
# |      MaxTestEpRet |        3.38e+03 |
# |      MinTestEpRet |        3.11e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             186 |
# |         StdQ1Vals |              93 |
# |         MaxQ1Vals |             299 |
# |         MinQ1Vals |            17.9 |
# |     AverageQ2Vals |           0.476 |
# |         StdQ2Vals |           0.288 |
# |         MaxQ2Vals |             1.6 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -187 |
# |             LossQ |            11.2 |
# |              Time |            49.3 |
# ---------------------------------------
# t=176000, 49.298190116882324s
# t=176200, 9.353995323181152s
# t=176400, 9.330015182495117s
# t=176600, 9.171475410461426s
# t=176800, 9.417850017547607s
# t=177000, 9.354949235916138s
# t=177200, 9.233336925506592s
# t=177400, 9.203360557556152s
# t=177600, 9.31112790107727s
# t=177800, 9.264232158660889s
# t=178000, 9.200392007827759s
# t=178200, 9.254258155822754s
# t=178400, 9.222306251525879s
# t=178600, 9.16651701927185s
# t=178800, 9.321077346801758s
# t=179000, 9.630234241485596s
# t=179200, 9.191434383392334s
# t=179400, 9.198401689529419s
# t=179600, 9.350989580154419s
# t=179800, 9.368945598602295s
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        3.15e+03 |
# |          StdEpRet |             161 |
# |          MaxEpRet |        3.39e+03 |
# |          MinEpRet |        2.99e+03 |
# |  AverageTestEpRet |        3.34e+03 |
# |      StdTestEpRet |            70.3 |
# |      MaxTestEpRet |        3.48e+03 |
# |      MinTestEpRet |        3.23e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             190 |
# |         StdQ1Vals |            94.1 |
# |         MaxQ1Vals |             306 |
# |         MinQ1Vals |            16.9 |
# |     AverageQ2Vals |           0.477 |
# |         StdQ2Vals |           0.288 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -191 |
# |             LossQ |            11.2 |
# |              Time |              49 |
# ---------------------------------------
# t=180000, 48.95705580711365s
# t=180200, 9.239321231842041s
# t=180400, 9.120614528656006s
# t=180600, 9.176461219787598s
# t=180800, 9.371938467025757s
# t=181000, 9.282146215438843s
# t=181200, 9.151527404785156s
# t=181400, 9.28617787361145s
# t=181600, 9.108664274215698s
# t=181800, 9.225325345993042s
# t=182000, 9.869616270065308s
# t=182200, 15.209325313568115s
# t=182400, 12.21729588508606s
# t=182600, 10.283560514450073s
# t=182800, 10.681407928466797s
# t=183000, 9.641228914260864s
# t=183200, 9.736984014511108s
# t=183400, 9.695043802261353s
# t=183600, 9.657201766967773s
# t=183800, 9.666124820709229s
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        3.18e+03 |
# |          StdEpRet |             109 |
# |          MaxEpRet |        3.33e+03 |
# |          MinEpRet |        3.02e+03 |
# |  AverageTestEpRet |        3.38e+03 |
# |      StdTestEpRet |             158 |
# |      MaxTestEpRet |        3.66e+03 |
# |      MinTestEpRet |        3.14e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             195 |
# |         StdQ1Vals |            95.2 |
# |         MaxQ1Vals |             310 |
# |         MinQ1Vals |            15.9 |
# |     AverageQ2Vals |           0.477 |
# |         StdQ2Vals |           0.286 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.255 |
# |            LossPi |            -196 |
# |             LossQ |            11.3 |
# |              Time |            50.3 |
# ---------------------------------------
# t=184000, 50.31847333908081s
# t=184200, 9.468682527542114s
# t=184400, 9.580379247665405s
# t=184600, 9.437756538391113s
# t=184800, 9.61429476737976s
# t=185000, 9.762892723083496s
# t=185200, 10.097373962402344s
# t=185400, 9.574868440628052s
# t=185600, 9.518575429916382s
# t=185800, 9.49261736869812s
# t=186000, 9.606282949447632s
# t=186200, 9.77090573310852s
# t=186400, 9.643208026885986s
# t=186600, 9.47965383529663s
# t=186800, 9.476652145385742s
# t=187000, 9.919475078582764s
# t=187200, 9.678125143051147s
# t=187400, 9.797794580459595s
# t=187600, 9.530516624450684s
# t=187800, 9.564427614212036s
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        3.22e+03 |
# |          StdEpRet |            72.3 |
# |          MaxEpRet |        3.35e+03 |
# |          MinEpRet |        3.16e+03 |
# |  AverageTestEpRet |         3.3e+03 |
# |      StdTestEpRet |            67.8 |
# |      MaxTestEpRet |        3.42e+03 |
# |      MinTestEpRet |        3.17e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             199 |
# |         StdQ1Vals |            96.3 |
# |         MaxQ1Vals |             313 |
# |         MinQ1Vals |            16.2 |
# |     AverageQ2Vals |           0.477 |
# |         StdQ2Vals |           0.286 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -200 |
# |             LossQ |            11.5 |
# |              Time |            50.5 |
# ---------------------------------------
# t=188000, 50.54882216453552s
# t=188200, 9.491585493087769s
# t=188400, 9.664157152175903s
# t=188600, 9.472668409347534s
# t=188800, 10.097000360488892s
# t=189000, 9.650222539901733s
# t=189200, 9.503595352172852s
# t=189400, 9.649192333221436s
# t=189600, 9.469644784927368s
# t=189800, 9.354020118713379s
# t=190000, 9.539490938186646s
# t=190200, 9.422796487808228s
# t=190400, 9.328057527542114s
# t=190600, 9.41878080368042s
# t=190800, 10.140884399414062s
# t=191000, 10.815080642700195s
# t=191200, 9.971352100372314s
# t=191400, 9.61330771446228s
# t=191600, 9.389854669570923s
# t=191800, 9.536503553390503s
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        3.11e+03 |
# |          StdEpRet |            96.4 |
# |          MaxEpRet |        3.21e+03 |
# |          MinEpRet |        2.95e+03 |
# |  AverageTestEpRet |        3.13e+03 |
# |      StdTestEpRet |             471 |
# |      MaxTestEpRet |        3.51e+03 |
# |      MinTestEpRet |        1.76e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             203 |
# |         StdQ1Vals |            97.1 |
# |         MaxQ1Vals |             315 |
# |         MinQ1Vals |            15.1 |
# |     AverageQ2Vals |           0.477 |
# |         StdQ2Vals |           0.285 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -204 |
# |             LossQ |              12 |
# |              Time |            49.7 |
# ---------------------------------------
# t=192000, 49.690117597579956s
# t=192200, 9.482675552368164s
# t=192400, 9.355949878692627s
# t=192600, 9.604347944259644s
# t=192800, 9.370936632156372s
# t=193000, 9.491612434387207s
# t=193200, 9.783849000930786s
# t=193400, 9.580347776412964s
# t=193600, 9.35601019859314s
# t=193800, 9.67509937286377s
# t=194000, 9.585394859313965s
# t=194200, 9.553422927856445s
# t=194400, 9.702090501785278s
# t=194600, 9.508537769317627s
# t=194800, 9.461721181869507s
# t=195000, 9.400773286819458s
# t=195200, 9.471699237823486s
# t=195400, 9.474667072296143s
# t=195600, 9.698064088821411s
# t=195800, 9.485634088516235s
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        3.22e+03 |
# |          StdEpRet |             153 |
# |          MaxEpRet |        3.44e+03 |
# |          MinEpRet |        3.01e+03 |
# |  AverageTestEpRet |         3.4e+03 |
# |      StdTestEpRet |            94.8 |
# |      MaxTestEpRet |        3.58e+03 |
# |      MinTestEpRet |        3.19e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             207 |
# |         StdQ1Vals |            98.1 |
# |         MaxQ1Vals |             319 |
# |         MinQ1Vals |            15.9 |
# |     AverageQ2Vals |           0.476 |
# |         StdQ2Vals |           0.285 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -207 |
# |             LossQ |            11.7 |
# |              Time |            49.9 |
# ---------------------------------------
# t=196000, 49.85568189620972s
# t=196200, 9.493616104125977s
# t=196400, 9.329047918319702s
# t=196600, 9.675126552581787s
# t=196800, 9.560437202453613s
# t=197000, 9.39786672592163s
# t=197200, 9.790790796279907s
# t=197400, 10.668499946594238s
# t=197600, 9.646175622940063s
# t=197800, 9.497630596160889s
# t=198000, 9.58651614189148s
# t=198200, 9.42057466506958s
# t=198400, 9.424823999404907s
# t=198600, 9.558440923690796s
# t=198800, 9.528517723083496s
# t=199000, 9.496610641479492s
# t=199200, 9.482637643814087s
# t=199400, 10.218682050704956s
# t=199600, 9.500585794448853s
# t=199800, 9.527522087097168s
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        3.22e+03 |
# |          StdEpRet |             120 |
# |          MaxEpRet |        3.42e+03 |
# |          MinEpRet |        3.12e+03 |
# |  AverageTestEpRet |        3.17e+03 |
# |      StdTestEpRet |             462 |
# |      MaxTestEpRet |        3.41e+03 |
# |      MinTestEpRet |        1.81e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             210 |
# |         StdQ1Vals |            99.3 |
# |         MaxQ1Vals |             321 |
# |         MinQ1Vals |            15.2 |
# |     AverageQ2Vals |           0.477 |
# |         StdQ2Vals |           0.284 |
# |         MaxQ2Vals |            1.66 |
# |         MinQ2Vals |          -0.268 |
# |            LossPi |            -211 |
# |             LossQ |            11.5 |
# |              Time |            50.3 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 
        'max_hist_len': 5,
        'gamma': 0.99, 'seed': 0, 'epochs': 50, 
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': False,
        'freeze_hist_coding': False,
        'exp_name': 'RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     max_hist_len=args['max_hist_len'],
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
    freeze_hist_coding=args['freeze_hist_coding'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#     "freeze_hist_coding":	false,
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000002098FFA6B08>":	{
#             "epoch_dict":	{},
#             "exp_name":	"RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\\\RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_MemGate_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0"
#     },
#     "max_ep_len":	1000,
#     "max_hist_len":	5,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	10,
#     "partially_observable":	false,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	1000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 189830, 	 q1: 190721, 	 q2: 190721
#
# t=0, 0.0s
# t=200, 0.025931596755981445s
# t=400, 0.034906864166259766s
# t=600, 0.041887521743774414s
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# t=800, 0.04588007926940918s
# t=1000, 0.03290820121765137s
# t=1200, 9.148796081542969s
# t=1400, 8.632375717163086s
# t=1600, 9.247405052185059s
# t=1800, 9.051406621932983s
# t=2000, 8.358648777008057s
# t=2200, 9.787456750869751s
# t=2400, 9.633272171020508s
# t=2600, 9.167623043060303s
# t=2800, 8.793485641479492s
# t=3000, 8.858311653137207s
# t=3200, 9.356375455856323s
# t=3400, 8.833376169204712s
# t=3600, 8.989960193634033s
# t=3800, 9.163513898849487s
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -457 |
# |          StdEpRet |            96.9 |
# |          MaxEpRet |            -290 |
# |          MinEpRet |            -522 |
# |  AverageTestEpRet |            -570 |
# |      StdTestEpRet |            3.49 |
# |      MaxTestEpRet |            -566 |
# |      MinTestEpRet |            -575 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |          -0.627 |
# |         StdQ1Vals |            1.69 |
# |         MaxQ1Vals |            8.71 |
# |         MinQ1Vals |           -7.47 |
# |     AverageQ2Vals |           0.175 |
# |         StdQ2Vals |           0.172 |
# |         MaxQ2Vals |             1.1 |
# |         MinQ2Vals |          -0.155 |
# |            LossPi |           0.218 |
# |             LossQ |          0.0276 |
# |              Time |            48.2 |
# ---------------------------------------
# t=4000, 48.23700714111328s
# t=4200, 9.247271299362183s
# t=4400, 9.114625930786133s
# t=4600, 9.105650424957275s
# t=4800, 9.221341371536255s
# t=5000, 9.162498474121094s
# t=5200, 9.469676733016968s
# t=5400, 9.207378149032593s
# t=5600, 9.268215894699097s
# t=5800, 9.249266147613525s
# t=6000, 9.442749261856079s
# t=6200, 9.28616738319397s
# t=6400, 9.766882419586182s
# t=6600, 9.666152238845825s
# t=6800, 9.348998546600342s
# t=7000, 9.919475555419922s
# t=7200, 10.068076848983765s
# t=7400, 9.423798322677612s
# t=7600, 9.383906364440918s
# t=7800, 9.396871328353882s
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -498 |
# |          StdEpRet |            18.2 |
# |          MaxEpRet |            -479 |
# |          MinEpRet |            -516 |
# |  AverageTestEpRet |            -545 |
# |      StdTestEpRet |            46.8 |
# |      MaxTestEpRet |            -485 |
# |      MinTestEpRet |            -617 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |          -0.721 |
# |         StdQ1Vals |             2.9 |
# |         MaxQ1Vals |            17.9 |
# |         MinQ1Vals |           -16.4 |
# |     AverageQ2Vals |           0.137 |
# |         StdQ2Vals |           0.193 |
# |         MaxQ2Vals |            1.35 |
# |         MinQ2Vals |          -0.164 |
# |            LossPi |           0.232 |
# |             LossQ |          0.0778 |
# |              Time |              50 |
# ---------------------------------------
# t=8000, 49.95541501045227s
# t=8200, 9.286165952682495s
# t=8400, 9.504584550857544s
# t=8600, 9.373932123184204s
# t=8800, 9.386898756027222s
# t=9000, 9.474663496017456s
# t=9200, 9.544476985931396s
# t=9400, 9.524529933929443s
# t=9600, 9.48264455795288s
# t=9800, 9.436763048171997s
# t=10000, 9.398865938186646s
# t=10200, 9.30411982536316s
# t=10400, 9.340023756027222s
# t=10600, 9.410834074020386s
# t=10800, 9.819740772247314s
# t=11000, 9.492615938186646s
# t=11200, 9.524529933929443s
# t=11400, 9.745939016342163s
# t=11600, 9.410833597183228s
# t=11800, 9.7459397315979s
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            24.9 |
# |          StdEpRet |             184 |
# |          MaxEpRet |             232 |
# |          MinEpRet |            -202 |
# |  AverageTestEpRet |             206 |
# |      StdTestEpRet |             173 |
# |      MaxTestEpRet |             381 |
# |      MinTestEpRet |            -182 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |         -0.0604 |
# |         StdQ1Vals |             4.4 |
# |         MaxQ1Vals |            26.8 |
# |         MinQ1Vals |           -20.9 |
# |     AverageQ2Vals |           0.181 |
# |         StdQ2Vals |           0.245 |
# |         MaxQ2Vals |            1.52 |
# |         MinQ2Vals |          -0.164 |
# |            LossPi |          -0.452 |
# |             LossQ |           0.214 |
# |              Time |            50.5 |
# ---------------------------------------
# t=12000, 50.508930921554565s
# t=12200, 9.460701704025269s
# t=12400, 9.911494970321655s
# t=12600, 9.533506393432617s
# t=12800, 9.526525735855103s
# t=13000, 9.448732376098633s
# t=13200, 9.479650020599365s
# t=13400, 9.522535800933838s
# t=13600, 9.549463272094727s
# t=13800, 9.543479681015015s
# t=14000, 9.521539211273193s
# t=14200, 9.645206451416016s
# t=14400, 9.652189254760742s
# t=14600, 9.450727701187134s
# t=14800, 9.435767650604248s
# t=15000, 9.451725244522095s
# t=15200, 9.480647087097168s
# t=15400, 9.497602224349976s
# t=15600, 9.463692903518677s
# t=15800, 9.473666429519653s
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             575 |
# |          StdEpRet |            73.9 |
# |          MaxEpRet |             662 |
# |          MinEpRet |             465 |
# |  AverageTestEpRet |             486 |
# |      StdTestEpRet |             335 |
# |      MaxTestEpRet |             679 |
# |      MinTestEpRet |            -507 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |             3.8 |
# |         StdQ1Vals |            6.65 |
# |         MaxQ1Vals |            35.1 |
# |         MinQ1Vals |           -24.1 |
# |     AverageQ2Vals |           0.293 |
# |         StdQ2Vals |           0.339 |
# |         MaxQ2Vals |            1.65 |
# |         MinQ2Vals |          -0.164 |
# |            LossPi |            -4.4 |
# |             LossQ |           0.359 |
# |              Time |              50 |
# ---------------------------------------
# t=16000, 49.98832559585571s
# t=16200, 9.371939182281494s
# t=16400, 9.51455569267273s
# t=16600, 9.429783344268799s
# t=16800, 9.630247592926025s
# t=17000, 9.681111812591553s
# t=17200, 9.471670627593994s
# t=17400, 9.541486263275146s
# t=17600, 9.507575273513794s
# t=17800, 9.549463033676147s
# t=18000, 9.658173084259033s
# t=18200, 9.49560809135437s
# t=18400, 9.942373514175415s
# t=18600, 9.696070909500122s
# t=18800, 9.698066473007202s
# t=19000, 9.544477462768555s
# t=19200, 9.554449796676636s
# t=19400, 9.479650259017944s
# t=19600, 9.568413972854614s
# t=19800, 9.520539999008179s
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             249 |
# |          StdEpRet |             488 |
# |          MaxEpRet |             660 |
# |          MinEpRet |            -558 |
# |  AverageTestEpRet |             461 |
# |      StdTestEpRet |            87.1 |
# |      MaxTestEpRet |             583 |
# |      MinTestEpRet |             338 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |              10 |
# |         StdQ1Vals |             9.1 |
# |         MaxQ1Vals |            43.7 |
# |         MinQ1Vals |           -23.1 |
# |     AverageQ2Vals |           0.352 |
# |         StdQ2Vals |           0.374 |
# |         MaxQ2Vals |            1.65 |
# |         MinQ2Vals |          -0.164 |
# |            LossPi |           -10.6 |
# |             LossQ |           0.661 |
# |              Time |            50.8 |
# ---------------------------------------
# t=20000, 50.824071168899536s
# t=20200, 9.581376791000366s
# t=20400, 9.502588748931885s
# t=20600, 9.620274066925049s
# t=20800, 9.565420627593994s
# t=21000, 9.626259088516235s
# t=21200, 9.68908977508545s
# t=21400, 9.597865343093872s
# t=21600, 9.54048752784729s
# t=21800, 9.598333835601807s
# t=22000, 10.379244089126587s
# t=22200, 9.565420866012573s
# t=22400, 9.533507585525513s
# t=22600, 9.560433387756348s
# t=22800, 9.549462795257568s
# t=23000, 9.698066711425781s
# t=23200, 9.96036434173584s
# t=23400, 9.612295627593994s
# t=23600, 9.593346118927002s
# t=23800, 9.599330425262451s
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             576 |
# |          StdEpRet |            96.6 |
# |          MaxEpRet |             738 |
# |          MinEpRet |             483 |
# |  AverageTestEpRet |             569 |
# |      StdTestEpRet |             124 |
# |      MaxTestEpRet |             717 |
# |      MinTestEpRet |             249 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            15.6 |
# |         StdQ1Vals |            9.32 |
# |         MaxQ1Vals |            54.5 |
# |         MinQ1Vals |           -18.3 |
# |     AverageQ2Vals |           0.398 |
# |         StdQ2Vals |           0.392 |
# |         MaxQ2Vals |            1.65 |
# |         MinQ2Vals |          -0.241 |
# |            LossPi |           -16.3 |
# |             LossQ |           0.843 |
# |              Time |              51 |
# ---------------------------------------
# t=24000, 50.95673632621765s
# t=24200, 9.592348098754883s
# t=24400, 9.472669124603271s
# t=24600, 9.631244659423828s
# t=24800, 9.492615461349487s
# t=25000, 9.549463748931885s
# t=25200, 9.538492679595947s
# t=25400, 9.514556646347046s
# t=25600, 9.625260829925537s
# t=25800, 9.95737338066101s
# t=26000, 9.65617823600769s
# t=26200, 9.537495374679565s
# t=26400, 9.729981899261475s
# t=26600, 9.49261474609375s
# t=26800, 9.623266220092773s
# t=27000, 9.526524782180786s
# t=27200, 9.751922845840454s
# t=27400, 9.649197578430176s
# t=27600, 9.643211603164673s
# t=27800, 9.594343662261963s
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             440 |
# |          StdEpRet |             183 |
# |          MaxEpRet |             598 |
# |          MinEpRet |             148 |
# |  AverageTestEpRet |             362 |
# |      StdTestEpRet |             213 |
# |      MaxTestEpRet |             591 |
# |      MinTestEpRet |            -207 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            21.5 |
# |         StdQ1Vals |            9.98 |
# |         MaxQ1Vals |            62.3 |
# |         MinQ1Vals |           -9.63 |
# |     AverageQ2Vals |           0.434 |
# |         StdQ2Vals |           0.406 |
# |         MaxQ2Vals |            1.65 |
# |         MinQ2Vals |          -0.241 |
# |            LossPi |           -22.2 |
# |             LossQ |            1.11 |
# |              Time |            50.1 |
# ---------------------------------------
# t=28000, 50.084070444107056s
# t=28200, 9.414824485778809s
# t=28400, 10.026839256286621s
# t=28600, 10.294471025466919s
# t=28800, 9.493613481521606s
# t=29000, 9.59833288192749s
# t=29200, 9.620274305343628s
# t=29400, 9.486631393432617s
# t=29600, 9.594343900680542s
# t=29800, 9.570407629013062s
# t=30000, 9.529516696929932s
# t=30200, 9.724000453948975s
# t=30400, 9.715021133422852s
# t=30600, 9.636235475540161s
# t=30800, 9.55544400215149s
# t=31000, 9.521538257598877s
# t=31200, 9.531511545181274s
# t=31400, 9.680114984512329s
# t=31600, 9.546470880508423s
# t=31800, 9.897534132003784s
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             427 |
# |          StdEpRet |             564 |
# |          MaxEpRet |             849 |
# |          MinEpRet |            -540 |
# |  AverageTestEpRet |             477 |
# |      StdTestEpRet |             262 |
# |      MaxTestEpRet |             685 |
# |      MinTestEpRet |            -266 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            26.6 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |            71.3 |
# |         MinQ1Vals |           -6.98 |
# |     AverageQ2Vals |           0.452 |
# |         StdQ2Vals |           0.408 |
# |         MaxQ2Vals |            1.65 |
# |         MinQ2Vals |          -0.241 |
# |            LossPi |           -27.3 |
# |             LossQ |            1.48 |
# |              Time |            50.9 |
# ---------------------------------------
# t=32000, 50.9457643032074s
# t=32200, 9.498598575592041s
# t=32400, 9.515553951263428s
# t=32600, 9.549463510513306s
# t=32800, 9.541484832763672s
# t=33000, 9.566418886184692s
# t=33200, 9.587361812591553s
# t=33400, 9.688092947006226s
# t=33600, 9.999325513839722s
# t=33800, 9.564422130584717s
# t=34000, 9.597336053848267s
# t=34200, 9.686098337173462s
# t=34400, 9.486631393432617s
# t=34600, 9.69108510017395s
# t=34800, 9.73596477508545s
# t=35000, 9.410834550857544s
# t=35200, 9.572402000427246s
# t=35400, 9.468679666519165s
# t=35600, 9.517548561096191s
# t=35800, 9.55245590209961s
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |           -31.3 |
# |          StdEpRet |             419 |
# |          MaxEpRet |             404 |
# |          MinEpRet |            -603 |
# |  AverageTestEpRet |             448 |
# |      StdTestEpRet |             258 |
# |      MaxTestEpRet |             651 |
# |      MinTestEpRet |            -291 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            31.3 |
# |         StdQ1Vals |            11.2 |
# |         MaxQ1Vals |            81.2 |
# |         MinQ1Vals |           -6.72 |
# |     AverageQ2Vals |           0.451 |
# |         StdQ2Vals |           0.406 |
# |         MaxQ2Vals |            1.65 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |             -32 |
# |             LossQ |            1.91 |
# |              Time |            50.6 |
# ---------------------------------------
# t=36000, 50.568774700164795s
# t=36200, 9.498597860336304s
# t=36400, 9.704050064086914s
# t=36600, 9.615287780761719s
# t=36800, 9.619276523590088s
# t=37000, 9.499597549438477s
# t=37200, 9.704049587249756s
# t=37400, 9.785831689834595s
# t=37600, 9.607308864593506s
# t=37800, 9.699064016342163s
# t=38000, 9.701056718826294s
# t=38200, 9.517549991607666s
# t=38400, 9.55245590209961s
# t=38600, 9.663158655166626s
# t=38800, 9.71502161026001s
# t=39000, 9.565935850143433s
# t=39200, 9.623265743255615s
# t=39400, 9.535500526428223s
# t=39600, 9.662162780761719s
# t=39800, 9.855644702911377s
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             636 |
# |          StdEpRet |            45.7 |
# |          MaxEpRet |             680 |
# |          MinEpRet |             561 |
# |  AverageTestEpRet |            -254 |
# |      StdTestEpRet |             328 |
# |      MaxTestEpRet |             447 |
# |      MinTestEpRet |            -649 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            35.7 |
# |         StdQ1Vals |            11.9 |
# |         MaxQ1Vals |            88.2 |
# |         MinQ1Vals |           -6.02 |
# |     AverageQ2Vals |           0.455 |
# |         StdQ2Vals |           0.405 |
# |         MaxQ2Vals |            1.65 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -36.4 |
# |             LossQ |            2.23 |
# |              Time |            50.8 |
# ---------------------------------------
# t=40000, 50.84104681015015s
# t=40200, 9.760896921157837s
# t=40400, 9.497601509094238s
# t=40600, 9.71302604675293s
# t=40800, 9.608306407928467s
# t=41000, 9.591351747512817s
# t=41200, 9.55145812034607s
# t=41400, 9.635234117507935s
# t=41600, 9.476658821105957s
# t=41800, 9.569409847259521s
# t=42000, 9.56941032409668s
# t=42200, 9.52951717376709s
# t=42400, 9.58836030960083s
# t=42600, 10.181773662567139s
# t=42800, 9.713023900985718s
# t=43000, 9.53550124168396s
# t=43200, 9.58137822151184s
# t=43400, 9.641217708587646s
# t=43600, 9.74693751335144s
# t=43800, 9.644208908081055s
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             585 |
# |          StdEpRet |             159 |
# |          MaxEpRet |             703 |
# |          MinEpRet |             315 |
# |  AverageTestEpRet |             278 |
# |      StdTestEpRet |             588 |
# |      MaxTestEpRet |             859 |
# |      MinTestEpRet |            -754 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            40.5 |
# |         StdQ1Vals |            12.1 |
# |         MaxQ1Vals |              95 |
# |         MinQ1Vals |           -5.01 |
# |     AverageQ2Vals |           0.468 |
# |         StdQ2Vals |           0.404 |
# |         MaxQ2Vals |            1.65 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -41.2 |
# |             LossQ |            2.62 |
# |              Time |            50.4 |
# ---------------------------------------
# t=44000, 50.39723253250122s
# t=44200, 9.54347825050354s
# t=44400, 9.492614984512329s
# t=44600, 9.603320598602295s
# t=44800, 9.665154457092285s
# t=45000, 9.519543647766113s
# t=45200, 9.556444644927979s
# t=45400, 9.51854681968689s
# t=45600, 9.571404695510864s
# t=45800, 9.5225350856781s
# t=46000, 9.515554428100586s
# t=46200, 9.76488733291626s
# t=46400, 9.719011068344116s
# t=46600, 9.477654933929443s
# t=46800, 9.65518069267273s
# t=47000, 9.599330425262451s
# t=47200, 9.547468662261963s
# t=47400, 9.568413257598877s
# t=47600, 9.481644630432129s
# t=47800, 9.561431646347046s
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             360 |
# |          StdEpRet |             524 |
# |          MaxEpRet |             693 |
# |          MinEpRet |            -547 |
# |  AverageTestEpRet |             193 |
# |      StdTestEpRet |             588 |
# |      MaxTestEpRet |             809 |
# |      MinTestEpRet |            -641 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            45.2 |
# |         StdQ1Vals |              12 |
# |         MaxQ1Vals |             101 |
# |         MinQ1Vals |            0.35 |
# |     AverageQ2Vals |           0.479 |
# |         StdQ2Vals |           0.407 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |             -46 |
# |             LossQ |            2.83 |
# |              Time |            50.8 |
# ---------------------------------------
# t=48000, 50.77225136756897s
# t=48200, 9.6013023853302s
# t=48400, 9.573399543762207s
# t=48600, 9.685102224349976s
# t=48800, 10.073810338973999s
# t=49000, 9.8436758518219s
# t=49200, 9.6302490234375s
# t=49400, 9.545472860336304s
# t=49600, 9.671137809753418s
# t=49800, 9.627255916595459s
# t=50000, 9.588359832763672s
# t=50200, 9.552457094192505s
# t=50400, 9.598331689834595s
# t=50600, 9.867612361907959s
# t=50800, 9.76488733291626s
# t=51000, 9.873596906661987s
# t=51200, 9.757906436920166s
# t=51400, 9.652189016342163s
# t=51600, 9.646204471588135s
# t=51800, 9.731975793838501s
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             126 |
# |          StdEpRet |             466 |
# |          MaxEpRet |             594 |
# |          MinEpRet |            -503 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |             444 |
# |      MaxTestEpRet |             468 |
# |      MinTestEpRet |            -671 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            48.9 |
# |         StdQ1Vals |            12.2 |
# |         MaxQ1Vals |             110 |
# |         MinQ1Vals |            2.43 |
# |     AverageQ2Vals |           0.471 |
# |         StdQ2Vals |           0.405 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -49.6 |
# |             LossQ |               3 |
# |              Time |            51.3 |
# ---------------------------------------
# t=52000, 51.25593638420105s
# t=52200, 9.568412065505981s
# t=52400, 9.759900569915771s
# t=52600, 9.641218662261963s
# t=52800, 9.574396133422852s
# t=53000, 9.606312036514282s
# t=53200, 9.54348087310791s
# t=53400, 9.443744897842407s
# t=53600, 9.44873332977295s
# t=53800, 9.680113792419434s
# t=54000, 9.734967708587646s
# t=54200, 9.6272554397583s
# t=54400, 9.590354204177856s
# t=54600, 9.728983402252197s
# t=54800, 9.664157152175903s
# t=55000, 9.734967231750488s
# t=55200, 9.746935606002808s
# t=55400, 9.534564733505249s
# t=55600, 9.51748776435852s
# t=55800, 9.865618228912354s
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -110 |
# |          StdEpRet |             395 |
# |          MaxEpRet |             556 |
# |          MinEpRet |            -460 |
# |  AverageTestEpRet |             410 |
# |      StdTestEpRet |             416 |
# |      MaxTestEpRet |             801 |
# |      MinTestEpRet |            -454 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            51.9 |
# |         StdQ1Vals |            13.1 |
# |         MaxQ1Vals |             115 |
# |         MinQ1Vals |            2.49 |
# |     AverageQ2Vals |           0.475 |
# |         StdQ2Vals |           0.402 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -52.6 |
# |             LossQ |            3.41 |
# |              Time |            50.7 |
# ---------------------------------------
# t=56000, 50.73133945465088s
# t=56200, 9.522534370422363s
# t=56400, 9.539489984512329s
# t=56600, 9.550501108169556s
# t=56800, 9.565382957458496s
# t=57000, 9.51854419708252s
# t=57200, 9.650752305984497s
# t=57400, 9.690085887908936s
# t=57600, 9.526525974273682s
# t=57800, 9.878583431243896s
# t=58000, 9.617281436920166s
# t=58200, 9.651191473007202s
# t=58400, 9.742945909500122s
# t=58600, 9.659170627593994s
# t=58800, 9.510567426681519s
# t=59000, 9.566419124603271s
# t=59200, 9.55046033859253s
# t=59400, 9.617281913757324s
# t=59600, 9.61528754234314s
# t=59800, 9.547468900680542s
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             417 |
# |          StdEpRet |             462 |
# |          MaxEpRet |             740 |
# |          MinEpRet |            -381 |
# |  AverageTestEpRet |             542 |
# |      StdTestEpRet |             340 |
# |      MaxTestEpRet |             940 |
# |      MinTestEpRet |            -220 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            53.5 |
# |         StdQ1Vals |            15.5 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            4.44 |
# |     AverageQ2Vals |           0.475 |
# |         StdQ2Vals |           0.396 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -54.2 |
# |             LossQ |            3.63 |
# |              Time |            58.1 |
# ---------------------------------------
# t=60000, 58.15149712562561s
# t=60200, 9.743943691253662s
# t=60400, 9.800790071487427s
# t=60600, 10.11694598197937s
# t=60800, 9.930593013763428s
# t=61000, 10.065085887908936s
# t=61200, 9.785830974578857s
# t=61400, 9.78084421157837s
# t=61600, 9.65418267250061s
# t=61800, 9.729981660842896s
# t=62000, 9.599329948425293s
# t=62200, 9.687095880508423s
# t=62400, 9.521538496017456s
# t=62600, 9.553452730178833s
# t=62800, 9.621272087097168s
# t=63000, 9.6860990524292s
# t=63200, 9.597334146499634s
# t=63400, 10.355308294296265s
# t=63600, 9.600328207015991s
# t=63800, 10.199723720550537s
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             735 |
# |          StdEpRet |            83.1 |
# |          MaxEpRet |             828 |
# |          MinEpRet |             626 |
# |  AverageTestEpRet |             365 |
# |      StdTestEpRet |             463 |
# |      MaxTestEpRet |             838 |
# |      MinTestEpRet |            -424 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            56.1 |
# |         StdQ1Vals |            17.3 |
# |         MaxQ1Vals |             126 |
# |         MinQ1Vals |            4.09 |
# |     AverageQ2Vals |           0.481 |
# |         StdQ2Vals |           0.397 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -56.8 |
# |             LossQ |            3.88 |
# |              Time |            50.9 |
# ---------------------------------------
# t=64000, 50.921833753585815s
# t=64200, 9.53948974609375s
# t=64400, 9.846667528152466s
# t=64600, 10.875546932220459s
# t=64800, 10.16282320022583s
# t=65000, 10.560281753540039s
# t=65200, 9.883570194244385s
# t=65400, 10.828045129776001s
# t=65600, 12.183586835861206s
# t=65800, 10.171798944473267s
# t=66000, 10.586689949035645s
# t=66200, 11.05244517326355s
# t=66400, 10.296465158462524s
# t=66600, 11.089346170425415s
# t=66800, 11.282608270645142s
# t=67000, 11.178110122680664s
# t=67200, 11.38016653060913s
# t=67400, 12.40275764465332s
# t=67600, 11.823569536209106s
# t=67800, 10.399190187454224s
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             310 |
# |          StdEpRet |             583 |
# |          MaxEpRet |             847 |
# |          MinEpRet |            -560 |
# |  AverageTestEpRet |             432 |
# |      StdTestEpRet |             457 |
# |      MaxTestEpRet |             850 |
# |      MinTestEpRet |            -456 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            58.3 |
# |         StdQ1Vals |            19.3 |
# |         MaxQ1Vals |             131 |
# |         MinQ1Vals |            5.28 |
# |     AverageQ2Vals |            0.48 |
# |         StdQ2Vals |           0.398 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -58.9 |
# |             LossQ |            4.15 |
# |              Time |            54.6 |
# ---------------------------------------
# t=68000, 54.558841943740845s
# t=68200, 10.352315187454224s
# t=68400, 12.287798404693604s
# t=68600, 12.209553241729736s
# t=68800, 10.403214693069458s
# t=69000, 11.52340030670166s
# t=69200, 13.022847414016724s
# t=69400, 11.370036840438843s
# t=69600, 11.70220685005188s
# t=69800, 12.389691352844238s
# t=70000, 11.383553504943848s
# t=70200, 11.024167776107788s
# t=70400, 11.314509153366089s
# t=70600, 11.200050830841064s
# t=70800, 12.248595237731934s
# t=71000, 12.210932970046997s
# t=71200, 12.540565967559814s
# t=71400, 10.850483179092407s
# t=71600, 9.873597145080566s
# t=71800, 9.653185606002808s
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             439 |
# |          StdEpRet |             414 |
# |          MaxEpRet |             841 |
# |          MinEpRet |            -254 |
# |  AverageTestEpRet |             624 |
# |      StdTestEpRet |             394 |
# |      MaxTestEpRet |        1.07e+03 |
# |      MinTestEpRet |            -500 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            60.2 |
# |         StdQ1Vals |            21.6 |
# |         MaxQ1Vals |             134 |
# |         MinQ1Vals |            3.04 |
# |     AverageQ2Vals |           0.481 |
# |         StdQ2Vals |           0.398 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -60.9 |
# |             LossQ |            4.38 |
# |              Time |            56.6 |
# ---------------------------------------
# t=72000, 56.56676149368286s
# t=72200, 10.933587312698364s
# t=72400, 11.801249265670776s
# t=72600, 10.485958814620972s
# t=72800, 11.949055194854736s
# t=73000, 11.584046125411987s
# t=73200, 11.01953125s
# t=73400, 10.528844356536865s
# t=73600, 10.249591588973999s
# t=73800, 10.432923793792725s
# t=74000, 10.994695663452148s
# t=74200, 10.623591184616089s
# t=74400, 9.44574236869812s
# t=74600, 10.231875896453857s
# t=74800, 10.543612957000732s
# t=75000, 9.723431587219238s
# t=75200, 9.754914283752441s
# t=75400, 10.130887746810913s
# t=75600, 10.705372095108032s
# t=75800, 10.633565187454224s
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             655 |
# |          StdEpRet |             395 |
# |          MaxEpRet |             977 |
# |          MinEpRet |            2.52 |
# |  AverageTestEpRet |             413 |
# |      StdTestEpRet |             387 |
# |      MaxTestEpRet |             921 |
# |      MinTestEpRet |            -368 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            62.5 |
# |         StdQ1Vals |            23.8 |
# |         MaxQ1Vals |             132 |
# |         MinQ1Vals |            0.96 |
# |     AverageQ2Vals |           0.483 |
# |         StdQ2Vals |           0.394 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -63.2 |
# |             LossQ |            4.63 |
# |              Time |            55.9 |
# ---------------------------------------
# t=76000, 55.93938183784485s
# t=76200, 11.410485029220581s
# t=76400, 10.854971170425415s
# t=76600, 10.655505895614624s
# t=76800, 10.643537759780884s
# t=77000, 9.992278814315796s
# t=77200, 9.571405172348022s
# t=77400, 10.240615367889404s
# t=77600, 10.49593186378479s
# t=77800, 11.356631994247437s
# t=78000, 14.7568941116333s
# t=78200, 15.510523319244385s
# t=78400, 11.740607023239136s
# t=78600, 11.207027912139893s
# t=78800, 11.75456714630127s
# t=79000, 15.173424243927002s
# t=79200, 11.213015079498291s
# t=79400, 11.75850772857666s
# t=79600, 11.160157680511475s
# t=79800, 18.867286205291748s
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             578 |
# |          StdEpRet |             435 |
# |          MaxEpRet |             856 |
# |          MinEpRet |            -175 |
# |  AverageTestEpRet |             608 |
# |      StdTestEpRet |             392 |
# |      MaxTestEpRet |             925 |
# |      MinTestEpRet |            -341 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            63.9 |
# |         StdQ1Vals |            26.4 |
# |         MaxQ1Vals |             130 |
# |         MinQ1Vals |              -6 |
# |     AverageQ2Vals |           0.484 |
# |         StdQ2Vals |           0.391 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.245 |
# |            LossPi |           -64.5 |
# |             LossQ |            4.63 |
# |              Time |            94.3 |
# ---------------------------------------
# t=80000, 94.28985691070557s
# t=80200, 15.219302654266357s
# t=80400, 13.492917537689209s
# t=80600, 12.747910499572754s
# t=80800, 12.367927312850952s
# t=81000, 15.556097984313965s
# t=81200, 13.788058996200562s
# t=81400, 13.187230348587036s
# t=81600, 10.08967113494873s
# t=81800, 13.8121817111969s
# t=82000, 10.871927499771118s
# t=82200, 10.691969871520996s
# t=82400, 9.842680215835571s
# t=82600, 10.64652967453003s
# t=82800, 10.31242299079895s
# t=83000, 11.07339859008789s
# t=83200, 11.268524169921875s
# t=83400, 11.238945722579956s
# t=83600, 10.246598958969116s
# t=83800, 10.092012882232666s
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        1.03e+03 |
# |          StdEpRet |             122 |
# |          MaxEpRet |        1.16e+03 |
# |          MinEpRet |             839 |
# |  AverageTestEpRet |             798 |
# |      StdTestEpRet |             540 |
# |      MaxTestEpRet |        1.27e+03 |
# |      MinTestEpRet |            -355 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            66.1 |
# |         StdQ1Vals |            28.5 |
# |         MaxQ1Vals |             134 |
# |         MinQ1Vals |           -4.94 |
# |     AverageQ2Vals |           0.486 |
# |         StdQ2Vals |           0.391 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.247 |
# |            LossPi |           -66.8 |
# |             LossQ |            4.91 |
# |              Time |            57.1 |
# ---------------------------------------
# t=84000, 57.085347414016724s
# t=84200, 13.294880151748657s
# t=84400, 10.055110692977905s
# t=84600, 11.88023042678833s
# t=84800, 12.38575530052185s
# t=85000, 12.146517992019653s
# t=85200, 10.13489818572998s
# t=85400, 10.081043481826782s
# t=85600, 11.379401683807373s
# t=85800, 11.387546300888062s
# t=86000, 12.40383243560791s
# t=86200, 12.845181226730347s
# t=86400, 10.667474031448364s
# t=86600, 13.87959599494934s
# t=86800, 9.981309652328491s
# t=87000, 11.75157380104065s
# t=87200, 13.187735557556152s
# t=87400, 12.380891561508179s
# t=87600, 10.944732427597046s
# t=87800, 13.188732862472534s
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             796 |
# |          StdEpRet |             546 |
# |          MaxEpRet |        1.27e+03 |
# |          MinEpRet |            -131 |
# |  AverageTestEpRet |             921 |
# |      StdTestEpRet |             439 |
# |      MaxTestEpRet |        1.35e+03 |
# |      MinTestEpRet |            -226 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            68.8 |
# |         StdQ1Vals |            30.5 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |           -16.1 |
# |     AverageQ2Vals |           0.486 |
# |         StdQ2Vals |           0.389 |
# |         MaxQ2Vals |            1.68 |
# |         MinQ2Vals |          -0.247 |
# |            LossPi |           -69.4 |
# |             LossQ |            4.96 |
# |              Time |            54.6 |
# ---------------------------------------
# t=88000, 54.647865295410156s
# t=88200, 12.08090329170227s
# t=88400, 21.453914880752563s
# t=88600, 16.76348638534546s
# t=88800, 11.680763721466064s
# t=89000, 12.725970983505249s
# t=89200, 11.124252080917358s
# t=89400, 11.727636814117432s
# t=89600, 11.344663619995117s
# t=89800, 11.491270542144775s
# t=90000, 11.143202304840088s
# t=90200, 12.145523309707642s
# t=90400, 11.667797088623047s
# t=90600, 11.510220289230347s
# t=90800, 12.299117088317871s
# t=91000, 12.081818103790283s
# t=91200, 12.315067768096924s
# t=91400, 12.774025201797485s
# t=91600, 12.810729503631592s
# t=91800, 10.693573236465454s
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        1.09e+03 |
# |          StdEpRet |             235 |
# |          MaxEpRet |        1.37e+03 |
# |          MinEpRet |             776 |
# |  AverageTestEpRet |        1.16e+03 |
# |      StdTestEpRet |            82.5 |
# |      MaxTestEpRet |        1.34e+03 |
# |      MinTestEpRet |        1.06e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            71.2 |
# |         StdQ1Vals |            32.9 |
# |         MaxQ1Vals |             144 |
# |         MinQ1Vals |           -9.95 |
# |     AverageQ2Vals |           0.485 |
# |         StdQ2Vals |           0.387 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.247 |
# |            LossPi |           -71.8 |
# |             LossQ |            5.02 |
# |              Time |            53.9 |
# ---------------------------------------
# t=92000, 53.91393423080444s
# t=92200, 9.982195377349854s
# t=92400, 10.27630877494812s
# t=92600, 10.043718338012695s
# t=92800, 11.984773635864258s
# t=93000, 13.74231743812561s
# t=93200, 14.087112426757812s
# t=93400, 10.92136549949646s
# t=93600, 11.422454595565796s
# t=93800, 11.661817073822021s
# t=94000, 12.746863603591919s
# t=94200, 11.390538215637207s
# t=94400, 11.676778316497803s
# t=94600, 14.959533452987671s
# t=94800, 10.96766710281372s
# t=95000, 10.556769371032715s
# t=95200, 10.014220714569092s
# t=95400, 9.685102462768555s
# t=95600, 10.208699226379395s
# t=95800, 10.462023496627808s
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        1.25e+03 |
# |          StdEpRet |            86.5 |
# |          MaxEpRet |        1.33e+03 |
# |          MinEpRet |         1.1e+03 |
# |  AverageTestEpRet |         1.2e+03 |
# |      StdTestEpRet |             387 |
# |      MaxTestEpRet |        1.66e+03 |
# |      MinTestEpRet |             189 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            74.3 |
# |         StdQ1Vals |            34.7 |
# |         MaxQ1Vals |             152 |
# |         MinQ1Vals |           -15.4 |
# |     AverageQ2Vals |           0.488 |
# |         StdQ2Vals |           0.387 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.247 |
# |            LossPi |           -75.1 |
# |             LossQ |            5.28 |
# |              Time |            55.3 |
# ---------------------------------------
# t=96000, 55.29302358627319s
# t=96200, 11.522188663482666s
# t=96400, 10.46002721786499s
# t=96600, 10.16182565689087s
# t=96800, 9.511564493179321s
# t=97000, 11.149187564849854s
# t=97200, 10.606634378433228s
# t=97400, 9.942413330078125s
# t=97600, 10.398194551467896s
# t=97800, 9.814753532409668s
# t=98000, 9.7080397605896s
# t=98200, 11.108295917510986s
# t=98400, 9.929446458816528s
# t=98600, 10.034167051315308s
# t=98800, 11.088348865509033s
# t=99000, 10.108968257904053s
# t=99200, 9.705046653747559s
# t=99400, 9.81774640083313s
# t=99600, 10.659494638442993s
# t=99800, 9.776855707168579s
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        1.39e+03 |
# |          StdEpRet |             177 |
# |          MaxEpRet |         1.6e+03 |
# |          MinEpRet |        1.14e+03 |
# |  AverageTestEpRet |        1.23e+03 |
# |      StdTestEpRet |             618 |
# |      MaxTestEpRet |        1.83e+03 |
# |      MinTestEpRet |            -554 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            78.1 |
# |         StdQ1Vals |            36.8 |
# |         MaxQ1Vals |             157 |
# |         MinQ1Vals |           -15.5 |
# |     AverageQ2Vals |           0.486 |
# |         StdQ2Vals |           0.386 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.247 |
# |            LossPi |           -78.9 |
# |             LossQ |            5.71 |
# |              Time |            52.2 |
# ---------------------------------------
# t=100000, 52.17846989631653s
# t=100200, 9.375926494598389s
# t=100400, 9.290156841278076s
# t=100600, 9.312098264694214s
# t=100800, 9.324065923690796s
# t=101000, 9.46448040008545s
# t=101200, 9.353987693786621s
# t=101400, 9.771867513656616s
# t=101600, 9.176461219787598s
# t=101800, 9.206380844116211s
# t=102000, 9.330050468444824s
# t=102200, 9.147539138793945s
# t=102400, 9.26123332977295s
# t=102600, 9.560434579849243s
# t=102800, 9.713030576705933s
# t=103000, 9.412824392318726s
# t=103200, 9.572402000427246s
# t=103400, 9.406845092773438s
# t=103600, 9.370950937271118s
# t=103800, 9.797789573669434s
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        1.56e+03 |
# |          StdEpRet |            48.1 |
# |          MaxEpRet |        1.61e+03 |
# |          MinEpRet |        1.49e+03 |
# |  AverageTestEpRet |        1.12e+03 |
# |      StdTestEpRet |             561 |
# |      MaxTestEpRet |        1.68e+03 |
# |      MinTestEpRet |          -0.624 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |              82 |
# |         StdQ1Vals |            38.5 |
# |         MaxQ1Vals |             164 |
# |         MinQ1Vals |           -16.4 |
# |     AverageQ2Vals |           0.487 |
# |         StdQ2Vals |           0.385 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.247 |
# |            LossPi |           -82.8 |
# |             LossQ |            5.92 |
# |              Time |            49.6 |
# ---------------------------------------
# t=104000, 49.592384338378906s
# t=104200, 9.293148756027222s
# t=104400, 9.531947374343872s
# t=104600, 9.410834312438965s
# t=104800, 11.153176069259644s
# t=105000, 9.51655101776123s
# t=105200, 9.575393915176392s
# t=105400, 10.993096590042114s
# t=105600, 10.378242254257202s
# t=105800, 9.989288806915283s
# t=106000, 10.221665382385254s
# t=106200, 9.860632181167603s
# t=106400, 10.100988149642944s
# t=106600, 9.875591278076172s
# t=106800, 9.934434175491333s
# t=107000, 9.918477058410645s
# t=107200, 9.546471118927002s
# t=107400, 10.257570028305054s
# t=107600, 9.925458431243896s
# t=107800, 9.668145656585693s
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |        1.46e+03 |
# |          StdEpRet |             189 |
# |          MaxEpRet |        1.72e+03 |
# |          MinEpRet |        1.27e+03 |
# |  AverageTestEpRet |         1.4e+03 |
# |      StdTestEpRet |             563 |
# |      MaxTestEpRet |        1.94e+03 |
# |      MinTestEpRet |           -67.7 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            86.3 |
# |         StdQ1Vals |            40.5 |
# |         MaxQ1Vals |             167 |
# |         MinQ1Vals |           -22.7 |
# |     AverageQ2Vals |           0.486 |
# |         StdQ2Vals |           0.385 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.247 |
# |            LossPi |             -87 |
# |             LossQ |            6.23 |
# |              Time |            50.6 |
# ---------------------------------------
# t=108000, 50.582738161087036s
# t=108200, 9.821733474731445s
# t=108400, 10.877747297286987s
# t=108600, 10.685241937637329s
# t=108800, 11.232961893081665s
# t=109000, 11.844326496124268s
# t=109200, 11.192071437835693s
# t=109400, 9.626258611679077s
# t=109600, 9.405847311019897s
# t=109800, 10.080044507980347s
# t=110000, 9.344012975692749s
# t=110200, 9.536499500274658s
# t=110400, 9.877585887908936s
# t=110600, 9.877587080001831s
# t=110800, 10.876526594161987s
# t=111000, 12.290450096130371s
# t=111200, 13.144829511642456s
# t=111400, 12.26437258720398s
# t=111600, 10.325849771499634s
# t=111800, 14.95646071434021s
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             863 |
# |          StdEpRet |             751 |
# |          MaxEpRet |        1.69e+03 |
# |          MinEpRet |            69.8 |
# |  AverageTestEpRet |        1.55e+03 |
# |      StdTestEpRet |             446 |
# |      MaxTestEpRet |        2.06e+03 |
# |      MinTestEpRet |             302 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            90.4 |
# |         StdQ1Vals |            42.8 |
# |         MaxQ1Vals |             174 |
# |         MinQ1Vals |           -18.2 |
# |     AverageQ2Vals |           0.487 |
# |         StdQ2Vals |           0.384 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.247 |
# |            LossPi |           -91.2 |
# |             LossQ |            6.39 |
# |              Time |            62.2 |
# ---------------------------------------
# t=112000, 62.226152420043945s
# t=112200, 9.997878074645996s
# t=112400, 9.893267631530762s
# t=112600, 9.994768142700195s
# t=112800, 10.463873147964478s
# t=113000, 10.236756563186646s
# t=113200, 9.581377267837524s
# t=113400, 10.112875699996948s
# t=113600, 10.114633798599243s
# t=113800, 10.886504411697388s
# t=114000, 9.426788091659546s
# t=114200, 10.698430061340332s
# t=114400, 10.334571599960327s
# t=114600, 10.984435319900513s
# t=114800, 10.432268857955933s
# t=115000, 9.678120136260986s
# t=115200, 10.810091972351074s
# t=115400, 10.803112030029297s
# t=115600, 10.867936611175537s
# t=115800, 9.275198221206665s
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        1.75e+03 |
# |          StdEpRet |             153 |
# |          MaxEpRet |         1.9e+03 |
# |          MinEpRet |        1.51e+03 |
# |  AverageTestEpRet |        1.87e+03 |
# |      StdTestEpRet |             186 |
# |      MaxTestEpRet |        2.15e+03 |
# |      MinTestEpRet |        1.45e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            93.5 |
# |         StdQ1Vals |              46 |
# ...
# |              Time |              54 |
# ---------------------------------------
# t=160000, 53.998602628707886s
# t=160200, 9.351989984512329s
# t=160400, 9.467682600021362s
# t=160600, 9.58137822151184s
# t=160800, 10.38323426246643s
# t=161000, 11.535153150558472s
# t=161200, 11.947052001953125s
# t=161400, 10.718040466308594s
# t=161600, 9.937450408935547s
# t=161800, 9.692081689834595s
# t=162000, 10.135895490646362s
# t=162200, 9.902519464492798s
# t=162400, 9.93295407295227s
# t=162600, 9.776854038238525s
# t=162800, 10.217679262161255s
# t=163000, 11.477306842803955s
# t=163200, 11.920124530792236s
# t=163400, 11.420955181121826s
# t=163600, 10.899604797363281s
# t=163800, 9.845671892166138s
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        3.26e+03 |
# |          StdEpRet |             201 |
# |          MaxEpRet |        3.46e+03 |
# |          MinEpRet |        2.96e+03 |
# |  AverageTestEpRet |        3.13e+03 |
# |      StdTestEpRet |             186 |
# |      MaxTestEpRet |        3.35e+03 |
# |      MinTestEpRet |        2.73e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             155 |
# |         StdQ1Vals |            75.2 |
# |         MaxQ1Vals |             291 |
# |         MinQ1Vals |           -15.6 |
# |     AverageQ2Vals |           0.473 |
# |         StdQ2Vals |            0.37 |
# |         MaxQ2Vals |            1.74 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -156 |
# |             LossQ |            12.4 |
# |              Time |            55.4 |
# ---------------------------------------
# t=164000, 55.42327165603638s
# t=164200, 12.241569757461548s
# t=164400, 10.723514795303345s
# t=164600, 10.700371980667114s
# t=164800, 11.828924655914307s
# t=165000, 9.566418647766113s
# t=165200, 9.942412376403809s
# t=165400, 10.844999551773071s
# t=165600, 10.329377889633179s
# t=165800, 10.112956762313843s
# t=166000, 10.606637001037598s
# t=166200, 10.654507637023926s
# t=166400, 9.667149543762207s
# t=166600, 9.865618228912354s
# t=166800, 10.012227773666382s
# t=167000, 9.980309963226318s
# t=167200, 10.121932983398438s
# t=167400, 11.945056915283203s
# t=167600, 12.063740253448486s
# t=167800, 10.651643753051758s
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        3.06e+03 |
# |          StdEpRet |             169 |
# |          MaxEpRet |        3.35e+03 |
# |          MinEpRet |        2.95e+03 |
# |  AverageTestEpRet |        2.64e+03 |
# |      StdTestEpRet |        1.11e+03 |
# |      MaxTestEpRet |        3.21e+03 |
# |      MinTestEpRet |            -579 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             162 |
# |         StdQ1Vals |            78.3 |
# |         MaxQ1Vals |             303 |
# |         MinQ1Vals |           -19.4 |
# |     AverageQ2Vals |           0.471 |
# |         StdQ2Vals |           0.369 |
# |         MaxQ2Vals |            1.74 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -163 |
# |             LossQ |            12.8 |
# |              Time |            59.8 |
# ---------------------------------------
# t=168000, 59.79079031944275s
# t=168200, 11.860283613204956s
# t=168400, 10.13158369064331s
# t=168600, 10.121929407119751s
# t=168800, 9.870606660842896s
# t=169000, 11.216007471084595s
# t=169200, 9.832704544067383s
# t=169400, 12.062956094741821s
# t=169600, 10.746262788772583s
# t=169800, 11.406654357910156s
# t=170000, 9.829714059829712s
# t=170200, 11.587971687316895s
# t=170400, 9.615287780761719s
# t=170600, 9.529516458511353s
# t=170800, 10.15285038948059s
# t=171000, 9.387895345687866s
# t=171200, 9.599331378936768s
# t=171400, 9.349996089935303s
# t=171600, 9.173468589782715s
# t=171800, 9.21834921836853s
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        3.01e+03 |
# |          StdEpRet |             717 |
# |          MaxEpRet |        3.59e+03 |
# |          MinEpRet |        1.81e+03 |
# |  AverageTestEpRet |         3.6e+03 |
# |      StdTestEpRet |             148 |
# |      MaxTestEpRet |        3.96e+03 |
# |      MinTestEpRet |         3.4e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             168 |
# |         StdQ1Vals |            81.2 |
# |         MaxQ1Vals |             312 |
# |         MinQ1Vals |           -22.1 |
# |     AverageQ2Vals |           0.469 |
# |         StdQ2Vals |           0.368 |
# |         MaxQ2Vals |            1.74 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -169 |
# |             LossQ |            13.5 |
# |              Time |            55.3 |
# ---------------------------------------
# t=172000, 55.320863485336304s
# t=172200, 10.126035690307617s
# t=172400, 10.530072212219238s
# t=172600, 10.502913475036621s
# t=172800, 9.738956928253174s
# t=173000, 12.748980522155762s
# t=173200, 10.581701040267944s
# t=173400, 10.859959363937378s
# t=173600, 11.021140575408936s
# t=173800, 9.87267780303955s
# t=174000, 9.552457332611084s
# t=174200, 9.292149782180786s
# t=174400, 9.80079197883606s
# t=174600, 10.924785852432251s
# t=174800, 11.050449132919312s
# t=175000, 10.836024045944214s
# t=175200, 10.85597014427185s
# t=175400, 9.835697174072266s
# t=175600, 10.960370540618896s
# t=175800, 10.86594271659851s
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        3.59e+03 |
# |          StdEpRet |             134 |
# |          MaxEpRet |        3.82e+03 |
# |          MinEpRet |        3.49e+03 |
# |  AverageTestEpRet |        3.34e+03 |
# |      StdTestEpRet |             968 |
# |      MaxTestEpRet |        3.83e+03 |
# |      MinTestEpRet |             456 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             174 |
# |         StdQ1Vals |              84 |
# |         MaxQ1Vals |             324 |
# |         MinQ1Vals |             -16 |
# |     AverageQ2Vals |           0.468 |
# |         StdQ2Vals |           0.367 |
# |         MaxQ2Vals |            1.74 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -175 |
# |             LossQ |            13.9 |
# |              Time |            60.9 |
# ---------------------------------------
# t=176000, 60.946274757385254s
# t=176200, 9.986915588378906s
# t=176400, 11.151064157485962s
# t=176600, 11.369596481323242s
# t=176800, 11.25553584098816s
# t=177000, 14.042449474334717s
# t=177200, 13.971886157989502s
# t=177400, 10.524012327194214s
# t=177600, 9.873596668243408s
# t=177800, 11.295794010162354s
# t=178000, 10.60663628578186s
# t=178200, 12.447539567947388s
# t=178400, 10.828044414520264s
# t=178600, 13.697766304016113s
# t=178800, 10.926006317138672s
# t=179000, 10.225281000137329s
# t=179200, 10.788708448410034s
# t=179400, 9.649198055267334s
# t=179600, 10.494267702102661s
# t=179800, 10.31137990951538s
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        2.92e+03 |
# |          StdEpRet |        1.19e+03 |
# |          MaxEpRet |        3.66e+03 |
# |          MinEpRet |             863 |
# |  AverageTestEpRet |         3.5e+03 |
# |      StdTestEpRet |        1.32e+03 |
# |      MaxTestEpRet |        4.22e+03 |
# |      MinTestEpRet |            -440 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             180 |
# |         StdQ1Vals |              87 |
# |         MaxQ1Vals |             336 |
# |         MinQ1Vals |           -3.32 |
# |     AverageQ2Vals |           0.467 |
# |         StdQ2Vals |           0.366 |
# |         MaxQ2Vals |            1.74 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -181 |
# |             LossQ |            14.3 |
# |              Time |            55.3 |
# ---------------------------------------
# t=180000, 55.257241010665894s
# t=180200, 10.24260425567627s
# t=180400, 10.290482521057129s
# t=180600, 9.897533178329468s
# t=180800, 11.065409183502197s
# t=181000, 10.854380369186401s
# t=181200, 9.895536661148071s
# t=181400, 12.10835599899292s
# t=181600, 10.703377485275269s
# t=181800, 10.319405317306519s
# t=182000, 9.895537853240967s
# t=182200, 9.382908821105957s
# t=182400, 9.743943691253662s
# t=182600, 10.45703673362732s
# t=182800, 9.934433937072754s
# t=183000, 9.854647636413574s
# t=183200, 11.047457695007324s
# t=183400, 12.011878967285156s
# t=183600, 9.89653491973877s
# t=183800, 10.28432035446167s
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        3.26e+03 |
# |          StdEpRet |             682 |
# |          MaxEpRet |        3.78e+03 |
# |          MinEpRet |        2.09e+03 |
# |  AverageTestEpRet |         3.8e+03 |
# |      StdTestEpRet |             139 |
# |      MaxTestEpRet |        4.01e+03 |
# |      MinTestEpRet |        3.51e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             186 |
# |         StdQ1Vals |            90.1 |
# |         MaxQ1Vals |             347 |
# |         MinQ1Vals |           -16.5 |
# |     AverageQ2Vals |           0.466 |
# |         StdQ2Vals |           0.365 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -187 |
# |             LossQ |            15.3 |
# |              Time |            56.4 |
# ---------------------------------------
# t=184000, 56.413259983062744s
# t=184200, 13.50987434387207s
# t=184400, 13.782323598861694s
# t=184600, 14.174673318862915s
# t=184800, 13.139863014221191s
# t=185000, 13.108945846557617s
# t=185200, 13.675429821014404s
# t=185400, 13.060075044631958s
# t=185600, 13.203690528869629s
# t=185800, 13.17975664138794s
# t=186000, 13.152169227600098s
# t=186200, 13.088998556137085s
# t=186400, 13.043120861053467s
# t=186600, 13.137871980667114s
# t=186800, 13.205686092376709s
# t=187000, 13.254552125930786s
# t=187200, 13.55176043510437s
# t=187400, 13.080023288726807s
# t=187600, 13.217653751373291s
# t=187800, 13.368251323699951s
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        3.96e+03 |
# |          StdEpRet |             199 |
# |          MaxEpRet |        4.12e+03 |
# |          MinEpRet |        3.62e+03 |
# |  AverageTestEpRet |        3.49e+03 |
# |      StdTestEpRet |             948 |
# |      MaxTestEpRet |        4.12e+03 |
# |      MinTestEpRet |             825 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             192 |
# |         StdQ1Vals |            93.7 |
# |         MaxQ1Vals |             361 |
# |         MinQ1Vals |           -4.53 |
# |     AverageQ2Vals |           0.466 |
# |         StdQ2Vals |           0.366 |
# |         MaxQ2Vals |            1.74 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -194 |
# |             LossQ |            16.4 |
# |              Time |            70.7 |
# ---------------------------------------
# t=188000, 70.71789169311523s
# t=188200, 13.217655897140503s
# t=188400, 13.495911121368408s
# t=188600, 13.122905969619751s
# t=188800, 14.70161771774292s
# t=189000, 13.66545295715332s
# t=189200, 13.275501489639282s
# t=189400, 13.307422876358032s
# t=189600, 13.252552032470703s
# t=189800, 13.234607934951782s
# t=190000, 13.031156778335571s
# t=190200, 12.965326309204102s
# t=190400, 11.531164169311523s
# t=190600, 9.95537781715393s
# t=190800, 9.995271682739258s
# t=191000, 9.771868705749512s
# t=191200, 9.731975317001343s
# t=191400, 9.690088510513306s
# t=191600, 9.699063301086426s
# t=191800, 10.2376229763031s
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        4.16e+03 |
# |          StdEpRet |             112 |
# |          MaxEpRet |        4.33e+03 |
# |          MinEpRet |        4.04e+03 |
# |  AverageTestEpRet |        4.24e+03 |
# |      StdTestEpRet |             199 |
# |      MaxTestEpRet |        4.49e+03 |
# |      MinTestEpRet |        3.77e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             200 |
# |         StdQ1Vals |            97.5 |
# |         MaxQ1Vals |             383 |
# |         MinQ1Vals |           -1.97 |
# |     AverageQ2Vals |           0.463 |
# |         StdQ2Vals |           0.364 |
# |         MaxQ2Vals |            1.71 |
# |         MinQ2Vals |          -0.251 |
# |            LossPi |            -201 |
# |             LossQ |            17.4 |
# |              Time |            51.3 |
# ---------------------------------------
# t=192000, 51.270896434783936s
# t=192200, 10.037157773971558s
# t=192400, 9.635234594345093s
# t=192600, 9.596338272094727s
# t=192800, 9.625261068344116s
# t=193000, 9.657175540924072s
# t=193200, 9.755911350250244s
# t=193400, 9.718012571334839s
# t=193600, 10.709361791610718s
# t=193800, 12.229297876358032s
# t=194000, 11.44439697265625s
# t=194200, 10.860955476760864s
# t=194400, 9.880584478378296s
# t=194600, 9.603313446044922s
# t=194800, 9.571405172348022s
# t=195000, 9.553452968597412s
# t=195200, 9.729980707168579s
# t=195400, 9.765884637832642s
# t=195600, 9.803783178329468s
# t=195800, 9.612297058105469s
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        4.18e+03 |
# |          StdEpRet |             235 |
# |          MaxEpRet |        4.55e+03 |
# |          MinEpRet |        3.96e+03 |
# |  AverageTestEpRet |        4.09e+03 |
# |      StdTestEpRet |             151 |
# |      MaxTestEpRet |        4.29e+03 |
# |      MinTestEpRet |        3.79e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             207 |
# |         StdQ1Vals |             101 |
# |         MaxQ1Vals |             393 |
# |         MinQ1Vals |            -9.8 |
# |     AverageQ2Vals |           0.461 |
# |         StdQ2Vals |           0.362 |
# |         MaxQ2Vals |            1.74 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -208 |
# |             LossQ |            18.2 |
# |              Time |            51.2 |
# ---------------------------------------
# t=196000, 51.19809007644653s
# t=196200, 9.85863709449768s
# t=196400, 10.376251220703125s
# t=196600, 9.838690519332886s
# t=196800, 9.871602535247803s
# t=197000, 10.020204305648804s
# t=197200, 9.821736812591553s
# t=197400, 9.775859355926514s
# t=197600, 10.232633829116821s
# t=197800, 9.890551567077637s
# t=198000, 9.846669435501099s
# t=198200, 10.019206762313843s
# t=198400, 9.84567141532898s
# t=198600, 9.719010353088379s
# t=198800, 9.877587080001831s
# t=199000, 9.809768915176392s
# t=199200, 9.882570743560791s
# t=199400, 9.91648244857788s
# t=199600, 10.777180194854736s
# t=199800, 11.116273164749146s
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        4.41e+03 |
# |          StdEpRet |             188 |
# |          MaxEpRet |        4.54e+03 |
# |          MinEpRet |        4.08e+03 |
# |  AverageTestEpRet |        4.33e+03 |
# |      StdTestEpRet |             942 |
# |      MaxTestEpRet |        4.81e+03 |
# |      MinTestEpRet |        1.53e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             214 |
# |         StdQ1Vals |             106 |
# |         MaxQ1Vals |             399 |
# |         MinQ1Vals |           -17.2 |
# |     AverageQ2Vals |           0.461 |
# |         StdQ2Vals |           0.361 |
# |         MaxQ2Vals |            1.74 |
# |         MinQ2Vals |          -0.253 |
# |            LossPi |            -216 |
# |             LossQ |            18.8 |
# |              Time |            56.9 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 
        'max_hist_len': 5,
        'gamma': 0.99, 'seed': 0, 'epochs': 50, 
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'freeze_hist_coding': False,
        'exp_name': 'RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     max_hist_len=args['max_hist_len'],
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
    freeze_hist_coding=args['freeze_hist_coding'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#     "freeze_hist_coding":	false,
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000002098BDB6C08>":	{
#             "epoch_dict":	{},
#             "exp_name":	"RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\\\RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_MemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0"
#     },
#     "max_ep_len":	1000,
#     "max_hist_len":	5,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	1000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Number of parameters: 	 pi: 186374, 	 q1: 187265, 	 q2: 187265
#
# t=0, 0.0s
# t=200, 0.03789877891540527s
# t=400, 0.028923749923706055s
# t=600, 0.030918121337890625s
# t=800, 0.027924537658691406s
# t=1000, 0.02892303466796875s
# t=1200, 9.28517460823059s
# t=1400, 10.71418571472168s
# t=1600, 10.764217138290405s
# t=1800, 10.88688611984253s
# t=2000, 10.978641271591187s
# t=2200, 11.200080871582031s
# t=2400, 9.960334539413452s
# t=2600, 10.463020324707031s
# t=2800, 10.324418544769287s
# t=3000, 10.81298279762268s
# t=3200, 10.512996196746826s
# t=3400, 11.822676420211792s
# t=3600, 10.832135200500488s
# t=3800, 10.281315565109253s
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -373 |
# |          StdEpRet |             120 |
# |          MaxEpRet |            -191 |
# |          MinEpRet |            -527 |
# |  AverageTestEpRet |            -379 |
# |      StdTestEpRet |            22.8 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |            -448 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |           0.823 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |           -3.29 |
# |     AverageQ2Vals |          -0.183 |
# |         StdQ2Vals |          0.0333 |
# |         MaxQ2Vals |          -0.065 |
# |         MinQ2Vals |          -0.271 |
# |            LossPi |           -1.48 |
# |             LossQ |          0.0249 |
# |              Time |            54.3 |
# ---------------------------------------
# t=4000, 54.273598432540894s
# t=4200, 11.132001399993896s
# t=4400, 10.944613218307495s
# t=4600, 10.772955417633057s
# t=4800, 10.399048805236816s
# t=5000, 10.594199657440186s
# t=5200, 10.010231733322144s
# t=5400, 9.857670307159424s
# t=5600, 9.970335006713867s
# t=5800, 10.00421953201294s
# t=6000, 9.956375122070312s
# t=6200, 9.797359943389893s
# t=6400, 10.117941856384277s
# t=6600, 9.855646848678589s
# t=6800, 9.938423156738281s
# t=7000, 9.804781675338745s
# t=7200, 9.841681241989136s
# t=7400, 9.95039176940918s
# t=7600, 9.923461675643921s
# t=7800, 10.019213676452637s
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -372 |
# |          StdEpRet |            95.4 |
# |          MaxEpRet |            -225 |
# |          MinEpRet |            -475 |
# |  AverageTestEpRet |            -229 |
# |      StdTestEpRet |             124 |
# |      MaxTestEpRet |            -134 |
# |      MinTestEpRet |            -549 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            4.25 |
# |         StdQ1Vals |            2.99 |
# |         MaxQ1Vals |              31 |
# |         MinQ1Vals |           -3.05 |
# |     AverageQ2Vals |          -0.182 |
# |         StdQ2Vals |          0.0382 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -5.17 |
# |             LossQ |          0.0358 |
# |              Time |            52.3 |
# ---------------------------------------
# t=8000, 52.28797960281372s
# t=8200, 10.116687536239624s
# t=8400, 9.976321935653687s
# t=8600, 9.944407224655151s
# t=8800, 10.031207084655762s
# t=9000, 10.405144929885864s
# t=9200, 10.23872971534729s
# t=9400, 11.28582239151001s
# t=9600, 11.000580787658691s
# t=9800, 11.481299638748169s
# t=10000, 11.1250638961792s
# t=10200, 11.008085250854492s
# t=10400, 11.201843500137329s
# t=10600, 11.716673612594604s
# t=10800, 10.041151762008667s
# t=11000, 10.117168664932251s
# t=11200, 9.956523418426514s
# t=11400, 10.538675785064697s
# t=11600, 9.953384637832642s
# t=11800, 10.044141054153442s
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -132 |
# |          StdEpRet |            82.7 |
# |          MaxEpRet |           -22.6 |
# |          MinEpRet |            -244 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |             103 |
# |      MaxTestEpRet |            76.2 |
# |      MinTestEpRet |            -340 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            8.76 |
# |         StdQ1Vals |             5.4 |
# |         MaxQ1Vals |            43.5 |
# |         MinQ1Vals |           -3.38 |
# |     AverageQ2Vals |          -0.178 |
# |         StdQ2Vals |          0.0375 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -9.54 |
# |             LossQ |          0.0714 |
# |              Time |            52.9 |
# ---------------------------------------
# t=12000, 52.89331817626953s
# t=12200, 10.01920771598816s
# t=12400, 9.993870496749878s
# t=12600, 10.020724773406982s
# t=12800, 10.031203031539917s
# t=13000, 10.190749168395996s
# t=13200, 10.1079421043396s
# t=13400, 9.949394226074219s
# t=13600, 10.171799182891846s
# t=13800, 10.227650880813599s
# t=14000, 12.158682584762573s
# t=14200, 10.507929563522339s
# t=14400, 9.107643842697144s
# t=14600, 9.628271102905273s
# t=14800, 10.565776109695435s
# t=15000, 9.55397367477417s
# t=15200, 9.424797296524048s
# t=15400, 9.273200988769531s
# t=15600, 8.96103811264038s
# t=15800, 8.856317281723022s
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -186 |
# |          StdEpRet |             435 |
# |          MaxEpRet |             397 |
# |          MinEpRet |            -671 |
# |  AverageTestEpRet |             338 |
# |      StdTestEpRet |             292 |
# |      MaxTestEpRet |             621 |
# |      MinTestEpRet |            -479 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            14.9 |
# |         StdQ1Vals |              10 |
# |         MaxQ1Vals |            56.3 |
# |         MinQ1Vals |           -1.48 |
# |     AverageQ2Vals |          -0.175 |
# |         StdQ2Vals |          0.0394 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -15.8 |
# |             LossQ |           0.122 |
# |              Time |            48.8 |
# ---------------------------------------
# t=16000, 48.82768630981445s
# t=16200, 8.833379983901978s
# t=16400, 10.730614185333252s
# t=16600, 10.163819789886475s
# t=16800, 9.662169933319092s
# t=17000, 9.228378534317017s
# t=17200, 9.481645107269287s
# t=17400, 9.445741653442383s
# t=17600, 8.974001407623291s
# t=17800, 9.334038972854614s
# t=18000, 9.81176471710205s
# t=18200, 10.780171871185303s
# t=18400, 9.766881704330444s
# t=18600, 11.128241539001465s
# t=18800, 11.067402362823486s
# t=19000, 11.319732189178467s
# t=19200, 11.94334101676941s
# t=19400, 9.425782203674316s
# t=19600, 9.849068880081177s
# t=19800, 10.322063446044922s
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |           -17.6 |
# |          StdEpRet |             275 |
# |          MaxEpRet |             453 |
# |          MinEpRet |            -242 |
# |  AverageTestEpRet |            -384 |
# |      StdTestEpRet |              42 |
# |      MaxTestEpRet |            -313 |
# |      MinTestEpRet |            -449 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            22.7 |
# |         StdQ1Vals |            11.9 |
# |         MaxQ1Vals |            62.4 |
# |         MinQ1Vals |            2.55 |
# |     AverageQ2Vals |          -0.168 |
# |         StdQ2Vals |          0.0419 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -23.8 |
# |             LossQ |           0.176 |
# |              Time |            54.7 |
# ---------------------------------------
# t=20000, 54.71469497680664s
# t=20200, 9.361386775970459s
# t=20400, 9.329823732376099s
# t=20600, 9.404895305633545s
# t=20800, 10.756433248519897s
# t=21000, 9.545472621917725s
# t=21200, 10.38124132156372s
# t=21400, 9.93944764137268s
# t=21600, 9.81871747970581s
# t=21800, 9.994880437850952s
# t=22000, 9.989711284637451s
# t=22200, 11.93408203125s
# t=22400, 10.400225639343262s
# t=22600, 12.547646284103394s
# t=22800, 9.514557600021362s
# t=23000, 9.130584001541138s
# t=23200, 9.07972526550293s
# t=23400, 9.581375360488892s
# t=23600, 9.188426971435547s
# t=23800, 9.149534702301025s
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            93.4 |
# |          StdEpRet |             307 |
# |          MaxEpRet |             331 |
# |          MinEpRet |            -428 |
# |  AverageTestEpRet |          0.0992 |
# |      StdTestEpRet |            20.1 |
# |      MaxTestEpRet |            44.6 |
# |      MinTestEpRet |           -25.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            32.2 |
# |         StdQ1Vals |            13.4 |
# |         MaxQ1Vals |            67.7 |
# |         MinQ1Vals |            8.19 |
# |     AverageQ2Vals |          -0.163 |
# |         StdQ2Vals |          0.0409 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -33.4 |
# |             LossQ |           0.229 |
# |              Time |            48.4 |
# ---------------------------------------
# t=24000, 48.44771695137024s
# t=24200, 8.801486492156982s
# t=24400, 9.386877059936523s
# t=24600, 9.370946168899536s
# t=24800, 9.182449579238892s
# t=25000, 9.192444324493408s
# t=25200, 9.499598503112793s
# t=25400, 9.991280555725098s
# t=25600, 9.045810461044312s
# t=25800, 9.188478708267212s
# t=26000, 9.160503625869751s
# t=26200, 9.551467895507812s
# t=26400, 9.474664449691772s
# t=26600, 10.038156032562256s
# t=26800, 10.48795461654663s
# t=27000, 10.766035556793213s
# t=27200, 10.542460203170776s
# t=27400, 9.691240787506104s
# t=27600, 10.209181547164917s
# t=27800, 10.159861087799072s
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             223 |
# |          StdEpRet |             629 |
# |          MaxEpRet |         1.1e+03 |
# |          MinEpRet |            -473 |
# |  AverageTestEpRet |            -354 |
# |      StdTestEpRet |             136 |
# |      MaxTestEpRet |            -127 |
# |      MinTestEpRet |            -571 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            40.7 |
# |         StdQ1Vals |            13.3 |
# |         MaxQ1Vals |            76.1 |
# |         MinQ1Vals |            13.2 |
# |     AverageQ2Vals |          -0.158 |
# |         StdQ2Vals |          0.0399 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |             -42 |
# |             LossQ |           0.279 |
# |              Time |            50.7 |
# ---------------------------------------
# t=28000, 50.68779969215393s
# t=28200, 10.415849447250366s
# t=28400, 9.778852462768555s
# t=28600, 9.635233640670776s
# t=28800, 10.171081781387329s
# t=29000, 9.632242202758789s
# t=29200, 9.974328756332397s
# t=29400, 9.750924587249756s
# t=29600, 9.630281209945679s
# t=29800, 10.227628946304321s
# t=30000, 10.093008518218994s
# t=30200, 9.30212688446045s
# t=30400, 14.38852334022522s
# t=30600, 18.78138518333435s
# t=30800, 15.169208288192749s
# t=31000, 15.051375389099121s
# t=31200, 16.428056001663208s
# t=31400, 12.188440799713135s
# t=31600, 15.46564245223999s
# t=31800, 19.33529281616211s
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -255 |
# |          StdEpRet |             244 |
# |          MaxEpRet |            62.4 |
# |          MinEpRet |            -596 |
# |  AverageTestEpRet |             283 |
# |      StdTestEpRet |             597 |
# |      MaxTestEpRet |        1.14e+03 |
# |      MinTestEpRet |            -397 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            46.9 |
# |         StdQ1Vals |              13 |
# |         MaxQ1Vals |            87.2 |
# |         MinQ1Vals |            19.4 |
# |     AverageQ2Vals |          -0.157 |
# |         StdQ2Vals |          0.0393 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -48.2 |
# |             LossQ |           0.433 |
# |              Time |            84.9 |
# ---------------------------------------
# t=32000, 84.92308592796326s
# t=32200, 15.472181558609009s
# t=32400, 13.059450387954712s
# t=32600, 11.301127195358276s
# t=32800, 12.261211395263672s
# t=33000, 12.967682123184204s
# t=33200, 10.291481018066406s
# t=33400, 9.920470237731934s
# t=33600, 11.492285966873169s
# t=33800, 9.846670627593994s
# t=34000, 9.455740451812744s
# t=34200, 9.27517318725586s
# t=34400, 9.225327014923096s
# t=34600, 9.20737910270691s
# t=34800, 9.399863719940186s
# t=35000, 9.177457571029663s
# t=35200, 9.200397968292236s
# t=35400, 9.29813528060913s
# t=35600, 9.166486740112305s
# t=35800, 9.128589868545532s
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |        1.21e+03 |
# |          StdEpRet |             743 |
# |          MaxEpRet |        1.68e+03 |
# |          MinEpRet |           -80.5 |
# |  AverageTestEpRet |         1.9e+03 |
# |      StdTestEpRet |            84.6 |
# |      MaxTestEpRet |        2.08e+03 |
# |      MinTestEpRet |        1.75e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            51.7 |
# |         StdQ1Vals |            16.3 |
# |         MaxQ1Vals |              95 |
# |         MinQ1Vals |            22.6 |
# |     AverageQ2Vals |          -0.157 |
# |         StdQ2Vals |          0.0395 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -52.9 |
# |             LossQ |           0.576 |
# |              Time |            48.8 |
# ---------------------------------------
# t=36000, 48.781290769577026s
# t=36200, 9.700608491897583s
# t=36400, 10.150856733322144s
# t=36600, 9.207378387451172s
# t=36800, 9.168489456176758s
# t=37000, 9.152516603469849s
# t=37200, 9.233338356018066s
# t=37400, 9.09864091873169s
# t=37600, 9.476692199707031s
# t=37800, 9.223301649093628s
# t=38000, 9.162525177001953s
# t=38200, 9.30508828163147s
# t=38400, 9.18942642211914s
# t=38600, 9.312091827392578s
# t=38800, 9.535501480102539s
# t=39000, 9.811761617660522s
# t=39200, 9.199399471282959s
# t=39400, 9.088696002960205s
# t=39600, 9.134572982788086s
# t=39800, 9.157038927078247s
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |        1.77e+03 |
# |          StdEpRet |            94.1 |
# |          MaxEpRet |        1.92e+03 |
# |          MinEpRet |        1.67e+03 |
# |  AverageTestEpRet |        2.35e+03 |
# |      StdTestEpRet |            74.3 |
# |      MaxTestEpRet |         2.5e+03 |
# |      MinTestEpRet |        2.23e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            59.9 |
# |         StdQ1Vals |            21.3 |
# |         MaxQ1Vals |             105 |
# |         MinQ1Vals |            24.5 |
# |     AverageQ2Vals |          -0.155 |
# |         StdQ2Vals |          0.0394 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -61.2 |
# |             LossQ |           0.637 |
# |              Time |            51.3 |
# ---------------------------------------
# t=40000, 51.29743432998657s
# t=40200, 9.173467874526978s
# t=40400, 9.457525968551636s
# t=40600, 10.440693378448486s
# t=40800, 10.183767318725586s
# t=41000, 9.569410800933838s
# t=41200, 9.896535396575928s
# t=41400, 9.839688062667847s
# t=41600, 9.536497354507446s
# t=41800, 9.436764001846313s
# t=42000, 10.386667966842651s
# t=42200, 13.680143356323242s
# t=42400, 10.105818510055542s
# t=42600, 10.094007730484009s
# t=42800, 11.358625888824463s
# t=43000, 10.39719820022583s
# t=43200, 9.408839225769043s
# t=43400, 9.484637260437012s
# t=43600, 9.85068964958191s
# t=43800, 9.655174970626831s
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |        2.25e+03 |
# |          StdEpRet |            78.4 |
# |          MaxEpRet |        2.36e+03 |
# |          MinEpRet |        2.15e+03 |
# |  AverageTestEpRet |        2.78e+03 |
# |      StdTestEpRet |            30.2 |
# |      MaxTestEpRet |        2.83e+03 |
# |      MinTestEpRet |        2.72e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            68.8 |
# |         StdQ1Vals |            24.8 |
# |         MaxQ1Vals |             114 |
# |         MinQ1Vals |            26.7 |
# |     AverageQ2Vals |          -0.153 |
# |         StdQ2Vals |          0.0393 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -70.1 |
# |             LossQ |           0.637 |
# |              Time |            54.3 |
# ---------------------------------------
# t=44000, 54.326438903808594s
# t=44200, 10.341366529464722s
# t=44400, 10.427888870239258s
# t=44600, 10.851979732513428s
# t=44800, 11.466341972351074s
# t=45000, 16.90482807159424s
# t=45200, 12.298112630844116s
# t=45400, 11.50523567199707s
# t=45600, 12.583844184875488s
# t=45800, 9.699061393737793s
# t=46000, 11.33967900276184s
# t=46200, 11.796453952789307s
# t=46400, 9.84666895866394s
# t=46600, 10.046038389205933s
# t=46800, 10.885890007019043s
# t=47000, 10.358299732208252s
# t=47200, 10.645785808563232s
# t=47400, 11.056997537612915s
# t=47600, 10.256572246551514s
# t=47800, 11.07538366317749s
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |         2.3e+03 |
# |          StdEpRet |            68.9 |
# |          MaxEpRet |        2.39e+03 |
# |          MinEpRet |         2.2e+03 |
# |  AverageTestEpRet |        2.57e+03 |
# |      StdTestEpRet |            93.6 |
# |      MaxTestEpRet |         2.7e+03 |
# |      MinTestEpRet |        2.41e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            78.4 |
# |         StdQ1Vals |            27.7 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            27.4 |
# |     AverageQ2Vals |          -0.151 |
# |         StdQ2Vals |          0.0392 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -79.8 |
# |             LossQ |           0.684 |
# |              Time |             113 |
# ---------------------------------------
# t=48000, 113.1174418926239s
# t=48200, 16.131654500961304s
# t=48400, 16.706448554992676s
# t=48600, 11.055434465408325s
# t=48800, 10.399192333221436s
# t=49000, 9.58436918258667s
# t=49200, 9.53849482536316s
# t=49400, 9.841681241989136s
# t=49600, 9.473666906356812s
# t=49800, 9.48862624168396s
# t=50000, 9.656177997589111s
# t=50200, 9.418813228607178s
# t=50400, 9.299132823944092s
# t=50600, 9.247299194335938s
# t=50800, 9.42277479171753s
# t=51000, 9.71402382850647s
# t=51200, 9.454715013504028s
# t=51400, 10.01721453666687s
# t=51600, 9.333073616027832s
# t=51800, 9.463660478591919s
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |        2.36e+03 |
# |          StdEpRet |            29.1 |
# |          MaxEpRet |        2.41e+03 |
# |          MinEpRet |        2.34e+03 |
# |  AverageTestEpRet |         2.3e+03 |
# |      StdTestEpRet |             972 |
# |      MaxTestEpRet |        2.74e+03 |
# |      MinTestEpRet |            -602 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            87.9 |
# |         StdQ1Vals |            30.3 |
# |         MaxQ1Vals |             130 |
# |         MinQ1Vals |              27 |
# |     AverageQ2Vals |           -0.15 |
# |         StdQ2Vals |          0.0391 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -89.3 |
# |             LossQ |           0.742 |
# |              Time |            49.3 |
# ---------------------------------------
# t=52000, 49.3330774307251s
# t=52200, 11.498795986175537s
# t=52400, 9.841194868087769s
# t=52600, 9.567415952682495s
# t=52800, 9.398866415023804s
# t=53000, 9.533533334732056s
# t=53200, 9.94836950302124s
# t=53400, 9.534504175186157s
# t=53600, 9.764903545379639s
# t=53800, 9.970829486846924s
# t=54000, 10.203715562820435s
# t=54200, 11.82264494895935s
# t=54400, 9.564423322677612s
# t=54600, 9.294174909591675s
# t=54800, 9.425767183303833s
# t=55000, 9.387892723083496s
# t=55200, 9.282206773757935s
# t=55400, 9.406818628311157s
# t=55600, 9.268215656280518s
# t=55800, 9.328055143356323s
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        2.34e+03 |
# |          StdEpRet |            28.3 |
# |          MaxEpRet |        2.37e+03 |
# |          MinEpRet |        2.29e+03 |
# |  AverageTestEpRet |        2.73e+03 |
# |      StdTestEpRet |            41.6 |
# |      MaxTestEpRet |        2.81e+03 |
# |      MinTestEpRet |        2.66e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            97.1 |
# |         StdQ1Vals |            32.2 |
# |         MaxQ1Vals |             139 |
# |         MinQ1Vals |            28.8 |
# |     AverageQ2Vals |          -0.148 |
# |         StdQ2Vals |          0.0388 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |           -98.3 |
# |             LossQ |           0.806 |
# |              Time |            49.4 |
# ---------------------------------------
# t=56000, 49.359007358551025s
# t=56200, 9.642216920852661s
# t=56400, 9.34301495552063s
# t=56600, 9.254253387451172s
# t=56800, 10.017212867736816s
# t=57000, 9.280182838439941s
# t=57200, 9.349000215530396s
# t=57400, 9.399863719940186s
# t=57600, 9.432805299758911s
# t=57800, 9.247241735458374s
# t=58000, 9.348002910614014s
# t=58200, 9.247271060943604s
# t=58400, 10.379243612289429s
# t=58600, 10.502915382385254s
# t=58800, 10.431105375289917s
# t=59000, 10.238618612289429s
# t=59200, 10.404180526733398s
# t=59400, 10.185762166976929s
# t=59600, 10.350351095199585s
# t=59800, 11.285792112350464s
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        2.45e+03 |
# |          StdEpRet |            38.9 |
# |          MaxEpRet |        2.48e+03 |
# |          MinEpRet |        2.38e+03 |
# |  AverageTestEpRet |        2.67e+03 |
# |      StdTestEpRet |              31 |
# |      MaxTestEpRet |         2.7e+03 |
# |      MinTestEpRet |         2.6e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             106 |
# |         StdQ1Vals |            33.7 |
# |         MaxQ1Vals |             144 |
# |         MinQ1Vals |              30 |
# |     AverageQ2Vals |          -0.147 |
# |         StdQ2Vals |          0.0384 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -107 |
# |             LossQ |           0.843 |
# |              Time |            58.2 |
# ---------------------------------------
# t=60000, 58.18248391151428s
# t=60200, 9.935431003570557s
# t=60400, 9.508573055267334s
# t=60600, 9.719011306762695s
# t=60800, 9.219346523284912s
# t=61000, 9.061767578125s
# t=61200, 9.414823770523071s
# t=61400, 9.0727379322052s
# t=61600, 9.812786340713501s
# t=61800, 10.097968578338623s
# t=62000, 10.82405710220337s
# t=62200, 9.920469522476196s
# t=62400, 10.457842350006104s
# t=62600, 10.254178047180176s
# t=62800, 10.314416885375977s
# t=63000, 10.13988447189331s
# t=63200, 9.22533130645752s
# t=63400, 9.812769889831543s
# t=63600, 9.54447627067566s
# t=63800, 9.512621402740479s
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |        2.52e+03 |
# |          StdEpRet |            40.2 |
# |          MaxEpRet |        2.57e+03 |
# |          MinEpRet |        2.47e+03 |
# |  AverageTestEpRet |         2.8e+03 |
# |      StdTestEpRet |            37.7 |
# |      MaxTestEpRet |        2.86e+03 |
# |      MinTestEpRet |        2.71e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             115 |
# |         StdQ1Vals |            34.8 |
# |         MaxQ1Vals |             152 |
# |         MinQ1Vals |            29.2 |
# |     AverageQ2Vals |          -0.146 |
# |         StdQ2Vals |          0.0382 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -116 |
# |             LossQ |           0.886 |
# |              Time |            52.1 |
# ---------------------------------------
# t=64000, 52.0897216796875s
# t=64200, 9.532509803771973s
# t=64400, 9.79680061340332s
# t=64600, 10.109965324401855s
# t=64800, 11.20154857635498s
# t=65000, 10.178780555725098s
# t=65200, 9.942410469055176s
# t=65400, 10.131909608840942s
# t=65600, 9.350047588348389s
# t=65800, 9.790817499160767s
# t=66000, 9.359970092773438s
# t=66200, 9.649196147918701s
# t=66400, 9.522536277770996s
# t=66600, 9.713027954101562s
# t=66800, 9.511563062667847s
# t=67000, 9.499595880508423s
# t=67200, 10.465016841888428s
# t=67400, 9.648226261138916s
# t=67600, 9.654154777526855s
# t=67800, 9.632244110107422s
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        2.52e+03 |
# |          StdEpRet |            45.4 |
# |          MaxEpRet |        2.57e+03 |
# |          MinEpRet |        2.44e+03 |
# |  AverageTestEpRet |        2.86e+03 |
# |      StdTestEpRet |            54.4 |
# |      MaxTestEpRet |        2.95e+03 |
# |      MinTestEpRet |        2.78e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             124 |
# |         StdQ1Vals |              35 |
# |         MaxQ1Vals |             159 |
# |         MinQ1Vals |            31.6 |
# |     AverageQ2Vals |          -0.145 |
# |         StdQ2Vals |          0.0381 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -125 |
# |             LossQ |            0.91 |
# |              Time |            50.2 |
# ---------------------------------------
# t=68000, 50.24763202667236s
# t=68200, 9.075730323791504s
# t=68400, 9.458110809326172s
# t=68600, 9.49069881439209s
# t=68800, 9.054812908172607s
# t=69000, 9.158508062362671s
# t=69200, 9.09465479850769s
# t=69400, 9.030849695205688s
# t=69600, 9.091686487197876s
# t=69800, 9.256248950958252s
# t=70000, 9.036834716796875s
# t=70200, 9.038851022720337s
# t=70400, 8.961014747619629s
# t=70600, 9.104652881622314s
# t=70800, 8.993949174880981s
# t=71000, 9.157538890838623s
# t=71200, 10.288789510726929s
# t=71400, 10.188753128051758s
# t=71600, 9.346009016036987s
# t=71800, 9.149534225463867s
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        2.57e+03 |
# |          StdEpRet |            33.4 |
# |          MaxEpRet |        2.62e+03 |
# |          MinEpRet |        2.54e+03 |
# |  AverageTestEpRet |        2.91e+03 |
# |      StdTestEpRet |              48 |
# |      MaxTestEpRet |        3.01e+03 |
# |      MinTestEpRet |        2.82e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             132 |
# |         StdQ1Vals |            35.2 |
# |         MaxQ1Vals |             166 |
# |         MinQ1Vals |            37.1 |
# |     AverageQ2Vals |          -0.144 |
# |         StdQ2Vals |          0.0379 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -133 |
# |             LossQ |           0.909 |
# |              Time |            48.3 |
# ---------------------------------------
# t=72000, 48.327763080596924s
# t=72200, 8.924136400222778s
# t=72400, 9.050797700881958s
# t=72600, 9.756910562515259s
# t=72800, 9.946916341781616s
# t=73000, 9.31010389328003s
# t=73200, 9.995948314666748s
# t=73400, 9.22333574295044s
# t=73600, 9.141554594039917s
# t=73800, 9.174466848373413s
# t=74000, 9.04880166053772s
# t=74200, 8.948071956634521s
# t=74400, 9.524531364440918s
# t=74600, 9.097670555114746s
# t=74800, 8.982978343963623s
# t=75000, 9.029853582382202s
# t=75200, 9.04783582687378s
# t=75400, 9.077693939208984s
# t=75600, 11.532291889190674s
# t=75800, 10.15567684173584s
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |        2.62e+03 |
# |          StdEpRet |            23.1 |
# |          MaxEpRet |        2.66e+03 |
# |          MinEpRet |         2.6e+03 |
# |  AverageTestEpRet |        3.04e+03 |
# |      StdTestEpRet |            39.3 |
# |      MaxTestEpRet |        3.13e+03 |
# |      MinTestEpRet |        2.99e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             140 |
# |         StdQ1Vals |              35 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |            42.3 |
# |     AverageQ2Vals |          -0.143 |
# |         StdQ2Vals |          0.0379 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -142 |
# |             LossQ |           0.908 |
# |              Time |            55.2 |
# ---------------------------------------
# t=76000, 55.16853618621826s
# t=76200, 10.102986097335815s
# t=76400, 12.855116367340088s
# t=76600, 11.044057130813599s
# t=76800, 10.318406105041504s
# t=77000, 11.246604681015015s
# t=77200, 11.837777376174927s
# t=77400, 10.140027046203613s
# t=77600, 9.462696075439453s
# t=77800, 9.091687440872192s
# t=78000, 9.061768293380737s
# t=78200, 10.326847553253174s
# t=78400, 9.771869659423828s
# t=78600, 9.59733510017395s
# t=78800, 9.167482852935791s
# t=79000, 8.978021621704102s
# t=79200, 8.975969314575195s
# t=79400, 9.800918340682983s
# t=79600, 10.291054964065552s
# t=79800, 10.467989683151245s
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |        2.68e+03 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |        2.72e+03 |
# |          MinEpRet |        2.65e+03 |
# |  AverageTestEpRet |        2.68e+03 |
# |      StdTestEpRet |        1.04e+03 |
# |      MaxTestEpRet |         3.1e+03 |
# |      MinTestEpRet |            -452 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             149 |
# |         StdQ1Vals |            33.7 |
# |         MaxQ1Vals |             180 |
# |         MinQ1Vals |            51.3 |
# |     AverageQ2Vals |          -0.143 |
# |         StdQ2Vals |          0.0378 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -150 |
# |             LossQ |           0.917 |
# |              Time |            53.4 |
# ---------------------------------------
# t=80000, 53.43160057067871s
# t=80200, 9.806777000427246s
# t=80400, 9.975916385650635s
# t=80600, 10.151865720748901s
# t=80800, 9.982304573059082s
# t=81000, 9.191422462463379s
# t=81200, 9.415819644927979s
# t=81400, 9.405848741531372s
# t=81600, 9.866615772247314s
# t=81800, 9.163495779037476s
# t=82000, 9.088724851608276s
# t=82200, 9.036805152893066s
# t=82400, 9.313121318817139s
# t=82600, 9.165464878082275s
# t=82800, 9.089693069458008s
# t=83000, 9.108668804168701s
# t=83200, 8.958017587661743s
# t=83400, 9.11166262626648s
# t=83600, 9.06074333190918s
# t=83800, 9.230316638946533s
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        1.95e+03 |
# |          StdEpRet |         1.4e+03 |
# |          MaxEpRet |        2.82e+03 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |        3.18e+03 |
# |      StdTestEpRet |              42 |
# |      MaxTestEpRet |        3.22e+03 |
# |      MinTestEpRet |         3.1e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             157 |
# |         StdQ1Vals |            31.5 |
# |         MaxQ1Vals |             188 |
# |         MinQ1Vals |            67.3 |
# |     AverageQ2Vals |          -0.142 |
# |         StdQ2Vals |          0.0377 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -159 |
# |             LossQ |           0.967 |
# |              Time |            49.4 |
# ---------------------------------------
# t=84000, 49.429330348968506s
# t=84200, 9.256744146347046s
# t=84400, 10.160336017608643s
# t=84600, 10.423106670379639s
# t=84800, 10.18476390838623s
# t=85000, 10.20773458480835s
# t=85200, 9.75588083267212s
# t=85400, 10.133906602859497s
# t=85600, 10.657492876052856s
# t=85800, 10.848321914672852s
# t=86000, 10.28250503540039s
# t=86200, 10.109963417053223s
# t=86400, 9.711166381835938s
# t=86600, 10.105306386947632s
# t=86800, 9.813284873962402s
# t=87000, 11.242648839950562s
# t=87200, 9.962332487106323s
# t=87400, 10.326987743377686s
# t=87600, 10.324546813964844s
# t=87800, 9.57598090171814s
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |         2.6e+03 |
# |          StdEpRet |             168 |
# |          MaxEpRet |        2.82e+03 |
# |          MinEpRet |        2.42e+03 |
# |  AverageTestEpRet |        2.99e+03 |
# |      StdTestEpRet |         1.1e+03 |
# |      MaxTestEpRet |        3.41e+03 |
# |      MinTestEpRet |            -295 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             165 |
# |         StdQ1Vals |            29.6 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |              74 |
# |     AverageQ2Vals |          -0.142 |
# |         StdQ2Vals |          0.0376 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -166 |
# |             LossQ |            1.06 |
# |              Time |            52.4 |
# ---------------------------------------
# t=88000, 52.37634634971619s
# t=88200, 9.56535029411316s
# t=88400, 9.66537070274353s
# t=88600, 9.377922773361206s
# t=88800, 9.207378625869751s
# t=89000, 9.409834861755371s
# t=89200, 9.242286920547485s
# t=89400, 9.220343351364136s
# t=89600, 9.262231588363647s
# t=89800, 9.250262260437012s
# t=90000, 9.238297462463379s
# t=90200, 9.528519630432129s
# t=90400, 10.130125284194946s
# t=90600, 9.233308792114258s
# t=90800, 10.460372924804688s
# t=91000, 10.259563446044922s
# t=91200, 9.961814403533936s
# t=91400, 11.154236793518066s
# t=91600, 9.695054531097412s
# t=91800, 10.118622303009033s
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        2.81e+03 |
# |          StdEpRet |            82.8 |
# |          MaxEpRet |        2.93e+03 |
# |          MinEpRet |        2.71e+03 |
# |  AverageTestEpRet |        2.17e+03 |
# |      StdTestEpRet |         1.7e+03 |
# |      MaxTestEpRet |        3.35e+03 |
# |      MinTestEpRet |            -576 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             172 |
# |         StdQ1Vals |            29.1 |
# |         MaxQ1Vals |             199 |
# |         MinQ1Vals |            80.1 |
# |     AverageQ2Vals |          -0.142 |
# |         StdQ2Vals |          0.0375 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -173 |
# |             LossQ |            1.05 |
# |              Time |            54.2 |
# ---------------------------------------
# t=92000, 54.19368648529053s
# t=92200, 9.517569303512573s
# t=92400, 10.907809972763062s
# t=92600, 10.331400871276855s
# t=92800, 9.385874271392822s
# t=93000, 9.399863719940186s
# t=93200, 9.294145822525024s
# t=93400, 9.31708550453186s
# t=93600, 9.250262975692749s
# t=93800, 9.761080026626587s
# t=94000, 9.924896955490112s
# t=94200, 9.513979196548462s
# t=94400, 9.346006155014038s
# t=94600, 9.39288330078125s
# t=94800, 9.281180620193481s
# t=95000, 9.22732663154602s
# t=95200, 9.215354919433594s
# t=95400, 9.147539138793945s
# t=95600, 9.150529861450195s
# t=95800, 9.667147397994995s
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        1.96e+03 |
# |          StdEpRet |        1.46e+03 |
# |          MaxEpRet |        2.86e+03 |
# |          MinEpRet |            -564 |
# |  AverageTestEpRet |        3.39e+03 |
# |      StdTestEpRet |            38.3 |
# |      MaxTestEpRet |        3.43e+03 |
# |      MinTestEpRet |         3.3e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             178 |
# |         StdQ1Vals |            29.5 |
# |         MaxQ1Vals |             205 |
# |         MinQ1Vals |              85 |
# |     AverageQ2Vals |          -0.141 |
# |         StdQ2Vals |          0.0373 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -179 |
# |             LossQ |            1.07 |
# |              Time |            49.7 |
# ---------------------------------------
# t=96000, 49.749963998794556s
# t=96200, 9.227325439453125s
# t=96400, 9.34703540802002s
# t=96600, 9.446707487106323s
# t=96800, 9.637228965759277s
# t=97000, 9.150530576705933s
# t=97200, 9.272235870361328s
# t=97400, 9.314062118530273s
# t=97600, 9.263229370117188s
# t=97800, 9.973329782485962s
# t=98000, 9.185436964035034s
# t=98200, 9.728528261184692s
# t=98400, 9.254226207733154s
# t=98600, 10.236656427383423s
# t=98800, 10.078864097595215s
# t=99000, 10.804559230804443s
# t=99200, 9.713885307312012s
# t=99400, 9.57932424545288s
# t=99600, 9.265655755996704s
# t=99800, 9.49862551689148s
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        2.97e+03 |
# |          StdEpRet |            31.1 |
# |          MaxEpRet |        3.02e+03 |
# |          MinEpRet |        2.93e+03 |
# |  AverageTestEpRet |        3.37e+03 |
# |      StdTestEpRet |              35 |
# |      MaxTestEpRet |        3.42e+03 |
# |      MinTestEpRet |         3.3e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             182 |
# |         StdQ1Vals |            31.3 |
# |         MaxQ1Vals |             211 |
# |         MinQ1Vals |            86.5 |
# |     AverageQ2Vals |          -0.141 |
# |         StdQ2Vals |          0.0371 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -184 |
# |             LossQ |            1.07 |
# |              Time |            51.5 |
# ---------------------------------------
# t=100000, 51.46810579299927s
# t=100200, 10.17503571510315s
# t=100400, 10.362288236618042s
# t=100600, 10.35431170463562s
# t=100800, 10.524854898452759s
# t=101000, 10.157840013504028s
# t=101200, 10.058133840560913s
# t=101400, 10.024161100387573s
# t=101600, 10.542808294296265s
# t=101800, 9.973330020904541s
# t=102000, 10.007240533828735s
# t=102200, 10.457036256790161s
# t=102400, 9.496602773666382s
# t=102600, 10.36328935623169s
# t=102800, 9.184439897537231s
# t=103000, 9.952838659286499s
# t=103200, 10.372297048568726s
# t=103400, 10.067376613616943s
# t=103600, 10.655472993850708s
# t=103800, 10.671595335006714s
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        2.93e+03 |
# |          StdEpRet |             101 |
# |          MaxEpRet |        3.07e+03 |
# |          MinEpRet |        2.82e+03 |
# |  AverageTestEpRet |        3.49e+03 |
# |      StdTestEpRet |            23.1 |
# |      MaxTestEpRet |        3.53e+03 |
# |      MinTestEpRet |        3.46e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             187 |
# |         StdQ1Vals |            32.8 |
# |         MaxQ1Vals |             216 |
# |         MinQ1Vals |            85.1 |
# |     AverageQ2Vals |           -0.14 |
# |         StdQ2Vals |          0.0369 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -188 |
# |             LossQ |            1.09 |
# |              Time |              58 |
# ---------------------------------------
# t=104000, 58.04469680786133s
# t=104200, 10.404156923294067s
# t=104400, 10.480754613876343s
# t=104600, 9.419809818267822s
# t=104800, 9.33803129196167s
# t=105000, 11.341429710388184s
# t=105200, 9.850383281707764s
# t=105400, 11.880970001220703s
# t=105600, 12.398279905319214s
# t=105800, 10.729477882385254s
# t=106000, 10.946725130081177s
# t=106200, 9.647677898406982s
# t=106400, 9.396871089935303s
# t=106600, 9.752919435501099s
# t=106800, 10.159179925918579s
# t=107000, 10.697454929351807s
# t=107200, 10.321557521820068s
# t=107400, 9.779204368591309s
# t=107600, 10.310468673706055s
# t=107800, 9.752922773361206s
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |        2.96e+03 |
# |          StdEpRet |              79 |
# |          MaxEpRet |        3.03e+03 |
# |          MinEpRet |        2.85e+03 |
# |  AverageTestEpRet |        3.44e+03 |
# |      StdTestEpRet |            24.9 |
# |      MaxTestEpRet |        3.48e+03 |
# |      MinTestEpRet |        3.39e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             192 |
# |         StdQ1Vals |            34.1 |
# |         MaxQ1Vals |             221 |
# |         MinQ1Vals |            89.3 |
# |     AverageQ2Vals |           -0.14 |
# |         StdQ2Vals |          0.0368 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -193 |
# |             LossQ |            1.09 |
# |              Time |            50.8 |
# ---------------------------------------
# t=108000, 50.80194926261902s
# t=108200, 9.470665454864502s
# t=108400, 10.812493562698364s
# t=108600, 10.514850616455078s
# t=108800, 10.848139524459839s
# t=109000, 9.866177082061768s
# t=109200, 9.9583420753479s
# t=109400, 10.705381393432617s
# t=109600, 10.422111749649048s
# t=109800, 9.938396215438843s
# t=110000, 10.222465753555298s
# t=110200, 10.35066032409668s
# t=110400, 11.336684465408325s
# t=110600, 11.057981729507446s
# t=110800, 10.81603193283081s
# t=111000, 10.830220460891724s
# t=111200, 10.009233236312866s
# t=111400, 10.590304851531982s
# t=111600, 9.96044921875s
# t=111800, 10.019225120544434s
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        2.96e+03 |
# |          StdEpRet |            29.2 |
# |          MaxEpRet |        2.98e+03 |
# |          MinEpRet |        2.91e+03 |
# |  AverageTestEpRet |        3.35e+03 |
# |      StdTestEpRet |            38.7 |
# |      MaxTestEpRet |        3.41e+03 |
# |      MinTestEpRet |        3.29e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             197 |
# |         StdQ1Vals |            34.4 |
# |         MaxQ1Vals |             226 |
# |         MinQ1Vals |            96.1 |
# |     AverageQ2Vals |           -0.14 |
# |         StdQ2Vals |          0.0367 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -199 |
# |             LossQ |            1.17 |
# |              Time |            50.8 |
# ---------------------------------------
# t=112000, 50.843039989471436s
# t=112200, 9.378921508789062s
# t=112400, 11.606959819793701s
# t=112600, 10.722668170928955s
# t=112800, 10.978228569030762s
# t=113000, 10.33194375038147s
# t=113200, 11.830212354660034s
# t=113400, 10.1357421875s
# t=113600, 10.290466070175171s
# t=113800, 10.413075685501099s
# t=114000, 9.853651762008667s
# t=114200, 9.589270114898682s
# t=114400, 9.705947637557983s
# t=114600, 9.870769500732422s
# t=114800, 9.84968090057373s
# t=115000, 9.892585515975952s
# t=115200, 9.898498058319092s
# t=115400, 10.512674808502197s
# t=115600, 10.27710223197937s
# t=115800, 10.128180980682373s
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        2.97e+03 |
# |          StdEpRet |             126 |
# |          MaxEpRet |        3.07e+03 |
# |          MinEpRet |        2.76e+03 |
# |  AverageTestEpRet |         3.6e+03 |
# |      StdTestEpRet |            24.4 |
# |      MaxTestEpRet |        3.64e+03 |
# |      MinTestEpRet |        3.57e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# ...
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -247 |
# |             LossQ |            1.29 |
# |              Time |            53.8 |
# ---------------------------------------
# t=160000, 53.81059193611145s
# t=160200, 9.674129486083984s
# t=160400, 9.940418720245361s
# t=160600, 10.395201683044434s
# t=160800, 9.673131465911865s
# t=161000, 9.725992679595947s
# t=161200, 9.456738233566284s
# t=161400, 9.478626489639282s
# t=161600, 9.509568452835083s
# t=161800, 9.318084955215454s
# t=162000, 9.221340894699097s
# t=162200, 9.511562585830688s
# t=162400, 9.305117130279541s
# t=162600, 9.276195526123047s
# t=162800, 9.314094066619873s
# t=163000, 9.244279384613037s
# t=163200, 9.300129652023315s
# t=163400, 9.3380286693573s
# t=163600, 9.442771911621094s
# t=163800, 9.247249364852905s
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |         3.3e+03 |
# |          StdEpRet |              20 |
# |          MaxEpRet |        3.32e+03 |
# |          MinEpRet |        3.27e+03 |
# |  AverageTestEpRet |        4.02e+03 |
# |      StdTestEpRet |            45.4 |
# |      MaxTestEpRet |         4.1e+03 |
# |      MinTestEpRet |        3.93e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             249 |
# |         StdQ1Vals |            26.2 |
# |         MaxQ1Vals |             270 |
# |         MinQ1Vals |             139 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0355 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |          -0.295 |
# |            LossPi |            -250 |
# |             LossQ |            1.25 |
# |              Time |            49.3 |
# ---------------------------------------
# t=164000, 49.335070848464966s
# t=164200, 9.075757026672363s
# t=164400, 9.396845817565918s
# t=164600, 9.440752983093262s
# t=164800, 9.424798250198364s
# t=165000, 9.927450895309448s
# t=165200, 11.452378034591675s
# t=165400, 11.328703165054321s
# t=165600, 11.994925737380981s
# t=165800, 10.328380823135376s
# t=166000, 11.116273164749146s
# t=166200, 11.082362413406372s
# t=166400, 11.521191596984863s
# t=166600, 11.09533143043518s
# t=166800, 10.455042123794556s
# t=167000, 11.393532514572144s
# t=167200, 10.408167362213135s
# t=167400, 10.765246629714966s
# t=167600, 10.475951194763184s
# t=167800, 9.354013204574585s
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        3.32e+03 |
# |          StdEpRet |            28.9 |
# |          MaxEpRet |        3.36e+03 |
# |          MinEpRet |        3.29e+03 |
# |  AverageTestEpRet |         3.8e+03 |
# |      StdTestEpRet |            30.8 |
# |      MaxTestEpRet |        3.85e+03 |
# |      MinTestEpRet |        3.73e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             251 |
# |         StdQ1Vals |            26.4 |
# |         MaxQ1Vals |             272 |
# |         MinQ1Vals |             141 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0354 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -252 |
# |             LossQ |            1.26 |
# |              Time |            49.1 |
# ---------------------------------------
# t=168000, 49.104384422302246s
# t=168200, 9.412829875946045s
# t=168400, 9.09767198562622s
# t=168600, 9.268215417861938s
# t=168800, 9.322070360183716s
# t=169000, 9.351993322372437s
# t=169200, 9.152551412582397s
# t=169400, 9.229292869567871s
# t=169600, 9.261235475540161s
# t=169800, 9.239291906356812s
# t=170000, 9.218383550643921s
# t=170200, 9.204351425170898s
# t=170400, 9.33506464958191s
# t=170600, 9.294119596481323s
# t=170800, 9.223334312438965s
# t=171000, 9.295173645019531s
# t=171200, 9.198371410369873s
# t=171400, 9.134575366973877s
# t=171600, 9.343015193939209s
# t=171800, 9.23929214477539s
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |         3.3e+03 |
# |          StdEpRet |            29.7 |
# |          MaxEpRet |        3.33e+03 |
# |          MinEpRet |        3.26e+03 |
# |  AverageTestEpRet |        4.03e+03 |
# |      StdTestEpRet |            30.4 |
# |      MaxTestEpRet |        4.08e+03 |
# |      MinTestEpRet |        3.98e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             253 |
# |         StdQ1Vals |            26.7 |
# |         MaxQ1Vals |             274 |
# |         MinQ1Vals |             141 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0352 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -254 |
# |             LossQ |            1.29 |
# |              Time |            49.4 |
# ---------------------------------------
# t=172000, 49.40289115905762s
# t=172200, 9.14255166053772s
# t=172400, 9.22533106803894s
# t=172600, 9.173494815826416s
# t=172800, 9.195383310317993s
# t=173000, 9.22834300994873s
# t=173200, 9.229300022125244s
# t=173400, 9.36695146560669s
# t=173600, 9.2243332862854s
# t=173800, 9.147538900375366s
# t=174000, 9.239320039749146s
# t=174200, 9.291124820709229s
# t=174400, 9.359973430633545s
# t=174600, 9.232311010360718s
# t=174800, 9.167484521865845s
# t=175000, 9.196407794952393s
# t=175200, 9.239294290542603s
# t=175400, 9.645206451416016s
# t=175600, 9.235303401947021s
# t=175800, 9.202391862869263s
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        3.37e+03 |
# |          StdEpRet |             110 |
# |          MaxEpRet |        3.47e+03 |
# |          MinEpRet |         3.2e+03 |
# |  AverageTestEpRet |        4.02e+03 |
# |      StdTestEpRet |            39.6 |
# |      MaxTestEpRet |        4.07e+03 |
# |      MinTestEpRet |        3.95e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             256 |
# |         StdQ1Vals |            26.5 |
# |         MaxQ1Vals |             277 |
# |         MinQ1Vals |             145 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0352 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -257 |
# |             LossQ |            1.34 |
# |              Time |            48.8 |
# ---------------------------------------
# t=176000, 48.80249500274658s
# t=176200, 9.26425838470459s
# t=176400, 9.321043491363525s
# t=176600, 9.135600090026855s
# t=176800, 9.153493165969849s
# t=177000, 9.315089225769043s
# t=177200, 9.14956021308899s
# t=177400, 9.141528844833374s
# t=177600, 9.257245779037476s
# t=177800, 9.218345880508423s
# t=178000, 9.157511472702026s
# t=178200, 9.215357542037964s
# t=178400, 9.751941919326782s
# t=178600, 9.861611127853394s
# t=178800, 9.184438943862915s
# t=179000, 9.232311725616455s
# t=179200, 9.312098741531372s
# t=179400, 9.269212245941162s
# t=179600, 9.265224933624268s
# t=179800, 9.343014478683472s
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        3.31e+03 |
# |          StdEpRet |            76.1 |
# |          MaxEpRet |        3.42e+03 |
# |          MinEpRet |        3.21e+03 |
# |  AverageTestEpRet |         4.2e+03 |
# |      StdTestEpRet |            52.5 |
# |      MaxTestEpRet |        4.29e+03 |
# |      MinTestEpRet |        4.11e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             258 |
# |         StdQ1Vals |            26.4 |
# |         MaxQ1Vals |             279 |
# |         MinQ1Vals |             148 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0351 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -260 |
# |             LossQ |            1.37 |
# |              Time |            48.9 |
# ---------------------------------------
# t=180000, 48.87131118774414s
# t=180200, 9.301128625869751s
# t=180400, 9.08669924736023s
# t=180600, 9.244282484054565s
# t=180800, 9.213380575180054s
# t=181000, 9.156495332717896s
# t=181200, 9.353015661239624s
# t=181400, 9.21732497215271s
# t=181600, 9.190423727035522s
# t=181800, 9.156550645828247s
# t=182000, 9.060734033584595s
# t=182200, 9.081714153289795s
# t=182400, 9.101661205291748s
# t=182600, 9.649195909500122s
# t=182800, 9.28317642211914s
# t=183000, 9.055783987045288s
# t=183200, 9.088696479797363s
# t=183400, 9.20644235610962s
# t=183600, 9.090662956237793s
# t=183800, 9.08769702911377s
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        3.42e+03 |
# |          StdEpRet |            56.9 |
# |          MaxEpRet |        3.49e+03 |
# |          MinEpRet |        3.34e+03 |
# |  AverageTestEpRet |        4.08e+03 |
# |      StdTestEpRet |            38.6 |
# |      MaxTestEpRet |        4.14e+03 |
# |      MinTestEpRet |           4e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             261 |
# |         StdQ1Vals |            26.2 |
# |         MaxQ1Vals |             282 |
# |         MinQ1Vals |             150 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |           0.035 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |          -0.295 |
# |            LossPi |            -262 |
# |             LossQ |            1.43 |
# |              Time |            48.4 |
# ---------------------------------------
# t=184000, 48.44551920890808s
# t=184200, 9.068750143051147s
# t=184400, 8.98696756362915s
# t=184600, 8.986965894699097s
# t=184800, 9.19840407371521s
# t=185000, 9.209371566772461s
# t=185200, 9.044817447662354s
# t=185400, 9.18842625617981s
# t=185600, 9.110655307769775s
# t=185800, 9.056760787963867s
# t=186000, 9.052793741226196s
# t=186200, 9.031847953796387s
# t=186400, 9.114625930786133s
# t=186600, 9.093683242797852s
# t=186800, 9.063762187957764s
# t=187000, 9.114628076553345s
# t=187200, 9.02586054801941s
# t=187400, 9.143550157546997s
# t=187600, 9.105650424957275s
# t=187800, 8.992952108383179s
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        3.45e+03 |
# |          StdEpRet |            42.4 |
# |          MaxEpRet |        3.52e+03 |
# |          MinEpRet |         3.4e+03 |
# |  AverageTestEpRet |        4.26e+03 |
# |      StdTestEpRet |            36.8 |
# |      MaxTestEpRet |        4.32e+03 |
# |      MinTestEpRet |        4.22e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             264 |
# |         StdQ1Vals |            25.9 |
# |         MaxQ1Vals |             284 |
# |         MinQ1Vals |             150 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0349 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -265 |
# |             LossQ |            1.42 |
# |              Time |            48.2 |
# ---------------------------------------
# t=188000, 48.169188499450684s
# t=188200, 9.062763929367065s
# t=188400, 9.163496255874634s
# t=188600, 9.13158130645752s
# t=188800, 9.129613876342773s
# t=189000, 9.064733266830444s
# t=189200, 9.126594305038452s
# t=189400, 9.107645034790039s
# t=189600, 9.103655815124512s
# t=189800, 9.083709955215454s
# t=190000, 9.04979920387268s
# t=190200, 9.394875049591064s
# t=190400, 9.115626096725464s
# t=190600, 9.135568857192993s
# t=190800, 9.164493799209595s
# t=191000, 9.060770750045776s
# t=191200, 9.155516624450684s
# t=191400, 9.121608018875122s
# t=191600, 9.09069037437439s
# t=191800, 9.132578372955322s
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        3.44e+03 |
# |          StdEpRet |            60.4 |
# |          MaxEpRet |        3.54e+03 |
# |          MinEpRet |        3.37e+03 |
# |  AverageTestEpRet |        3.91e+03 |
# |      StdTestEpRet |            19.8 |
# |      MaxTestEpRet |        3.95e+03 |
# |      MinTestEpRet |        3.88e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             266 |
# |         StdQ1Vals |            25.8 |
# |         MaxQ1Vals |             287 |
# |         MinQ1Vals |             156 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0348 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -267 |
# |             LossQ |            1.43 |
# |              Time |            48.4 |
# ---------------------------------------
# t=192000, 48.351701498031616s
# t=192200, 9.228351354598999s
# t=192400, 9.09764289855957s
# t=192600, 9.147538185119629s
# t=192800, 8.96305799484253s
# t=193000, 9.271181344985962s
# t=193200, 9.48264193534851s
# t=193400, 9.243281841278076s
# t=193600, 9.025864839553833s
# t=193800, 9.017889022827148s
# t=194000, 9.179481983184814s
# t=194200, 9.003893613815308s
# t=194400, 9.044815301895142s
# t=194600, 9.238292932510376s
# t=194800, 9.216356754302979s
# t=195000, 9.174465656280518s
# t=195200, 9.131579399108887s
# t=195400, 9.04381775856018s
# t=195600, 9.072736978530884s
# t=195800, 9.225331544876099s
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        3.45e+03 |
# |          StdEpRet |              32 |
# |          MaxEpRet |        3.49e+03 |
# |          MinEpRet |         3.4e+03 |
# |  AverageTestEpRet |        4.39e+03 |
# |      StdTestEpRet |            50.7 |
# |      MaxTestEpRet |        4.46e+03 |
# |      MinTestEpRet |        4.31e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             269 |
# |         StdQ1Vals |            25.9 |
# |         MaxQ1Vals |             289 |
# |         MinQ1Vals |             156 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0349 |
# |         MaxQ2Vals |         -0.0308 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -270 |
# |             LossQ |            1.42 |
# |              Time |            48.5 |
# ---------------------------------------
# t=196000, 48.519254207611084s
# t=196200, 9.0258629322052s
# t=196400, 9.005917072296143s
# t=196600, 9.116621732711792s
# t=196800, 9.101661205291748s
# t=197000, 9.177457571029663s
# t=197200, 9.081759691238403s
# t=197400, 9.11657452583313s
# t=197600, 9.251262187957764s
# t=197800, 9.245277643203735s
# t=198000, 9.118614673614502s
# t=198200, 9.058777570724487s
# t=198400, 9.31409215927124s
# t=198600, 9.080716848373413s
# t=198800, 9.123602151870728s
# t=199000, 9.103655338287354s
# t=199200, 9.129587173461914s
# t=199400, 9.125596523284912s
# t=199600, 9.192418813705444s
# t=199800, 9.058775424957275s
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        3.52e+03 |
# |          StdEpRet |            16.4 |
# |          MaxEpRet |        3.55e+03 |
# |          MinEpRet |         3.5e+03 |
# |  AverageTestEpRet |        4.34e+03 |
# |      StdTestEpRet |              44 |
# |      MaxTestEpRet |        4.41e+03 |
# |      MinTestEpRet |        4.26e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             271 |
# |         StdQ1Vals |            25.9 |
# |         MaxQ1Vals |             291 |
# |         MinQ1Vals |             156 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0347 |
# |         MaxQ2Vals |           -0.03 |
# |         MinQ2Vals |            -0.3 |
# |            LossPi |            -272 |
# |             LossQ |            1.42 |
# |              Time |            48.7 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 
        'max_hist_len': 5,
        'gamma': 0.99, 'seed': 0, 'epochs': 50, 
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'freeze_hist_coding': False,
        'exp_name': 'RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     max_hist_len=args['max_hist_len'],
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
    freeze_hist_coding=args['freeze_hist_coding'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#     "freeze_hist_coding":	false,
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000002098BDB6C08>":	{
#             "epoch_dict":	{},
#             "exp_name":	"RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\\\RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze\\RTD3_NoMemGate_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_1L128_NoFreeze_s0"
#     },
#     "max_ep_len":	1000,
#     "max_hist_len":	5,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	1000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Number of parameters: 	 pi: 186374, 	 q1: 187265, 	 q2: 187265
#
# t=0, 0.0s
# t=200, 0.039893150329589844s
# t=400, 0.03490638732910156s
# t=600, 0.03390979766845703s
# t=800, 0.0319516658782959s
# t=1000, 0.04387617111206055s
# t=1200, 9.922784566879272s
# t=1400, 9.478551387786865s
# t=1600, 9.07471776008606s
# t=1800, 9.385892391204834s
# t=2000, 9.4318106174469s
# t=2200, 9.666118621826172s
# t=2400, 9.423826694488525s
# t=2600, 9.5464768409729s
# t=2800, 10.541809320449829s
# t=3000, 10.297365188598633s
# t=3200, 10.484933376312256s
# t=3400, 10.098025560379028s
# t=3600, 10.224345207214355s
# t=3800, 9.932472229003906s
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -392 |
# |          StdEpRet |            17.5 |
# |          MaxEpRet |            -365 |
# |          MinEpRet |            -409 |
# |  AverageTestEpRet |             148 |
# |      StdTestEpRet |             6.7 |
# |      MaxTestEpRet |             157 |
# |      MinTestEpRet |             131 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |         -0.0237 |
# |         StdQ1Vals |            1.29 |
# |         MaxQ1Vals |            9.62 |
# |         MinQ1Vals |            -5.2 |
# |     AverageQ2Vals |          -0.153 |
# |         StdQ2Vals |          0.0439 |
# |         MaxQ2Vals |          -0.066 |
# |         MinQ2Vals |          -0.262 |
# |            LossPi |          -0.543 |
# |             LossQ |          0.0347 |
# |              Time |            57.4 |
# ---------------------------------------
# t=4000, 57.43730902671814s
# t=4200, 10.127948999404907s
# t=4400, 10.046122789382935s
# t=4600, 10.671443223953247s
# t=4800, 12.423144340515137s
# t=5000, 10.90882921218872s
# t=5200, 11.057430267333984s
# t=5400, 10.42312741279602s
# t=5600, 11.045684099197388s
# t=5800, 10.605610370635986s
# t=6000, 10.582728624343872s
# t=6200, 10.532837390899658s
# t=6400, 10.380847930908203s
# t=6600, 10.15982985496521s
# t=6800, 10.256606578826904s
# t=7000, 10.48193621635437s
# t=7200, 11.071428537368774s
# t=7400, 11.04645824432373s
# t=7600, 11.10926079750061s
# t=7800, 11.4783353805542s
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -171 |
# |          StdEpRet |            69.8 |
# |          MaxEpRet |           -61.8 |
# |          MinEpRet |            -235 |
# |  AverageTestEpRet |            -526 |
# |      StdTestEpRet |             169 |
# |      MaxTestEpRet |            -325 |
# |      MinTestEpRet |            -765 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            2.17 |
# |         StdQ1Vals |             4.5 |
# |         MaxQ1Vals |            21.6 |
# |         MinQ1Vals |           -4.88 |
# |     AverageQ2Vals |          -0.187 |
# |         StdQ2Vals |          0.0505 |
# |         MaxQ2Vals |         -0.0483 |
# |         MinQ2Vals |          -0.262 |
# |            LossPi |           -2.98 |
# |             LossQ |          0.0418 |
# |              Time |              58 |
# ---------------------------------------
# t=8000, 58.03342247009277s
# t=8200, 10.433103799819946s
# t=8400, 10.242605924606323s
# t=8600, 10.892871618270874s
# t=8800, 11.445366144180298s
# t=9000, 11.125277280807495s
# t=9200, 11.325734376907349s
# t=9400, 11.014525651931763s
# t=9600, 11.082245111465454s
# t=9800, 10.754245519638062s
# t=10000, 11.045660734176636s
# t=10200, 11.132230520248413s
# t=10400, 11.437415361404419s
# t=10600, 11.598724603652954s
# t=10800, 10.316420316696167s
# t=11000, 11.048214435577393s
# t=11200, 12.139262914657593s
# t=11400, 12.214701652526855s
# t=11600, 11.742228507995605s
# t=11800, 10.821733474731445s
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -480 |
# |          StdEpRet |            43.2 |
# |          MaxEpRet |            -414 |
# |          MinEpRet |            -522 |
# |  AverageTestEpRet |            -490 |
# |      StdTestEpRet |            2.19 |
# |      MaxTestEpRet |            -488 |
# |      MinTestEpRet |            -494 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            3.71 |
# |         StdQ1Vals |            8.75 |
# |         MaxQ1Vals |            32.8 |
# |         MinQ1Vals |           -6.53 |
# |     AverageQ2Vals |          -0.191 |
# |         StdQ2Vals |          0.0457 |
# |         MaxQ2Vals |         -0.0483 |
# |         MinQ2Vals |          -0.262 |
# |            LossPi |           -4.39 |
# |             LossQ |          0.0587 |
# |              Time |            62.2 |
# ---------------------------------------
# t=12000, 62.18858480453491s
# t=12200, 11.189566850662231s
# t=12400, 10.636561393737793s
# t=12600, 10.641512393951416s
# t=12800, 11.961710929870605s
# t=13000, 11.208954095840454s
# t=13200, 12.552456617355347s
# t=13400, 12.043093204498291s
# t=13600, 11.274824142456055s
# t=13800, 12.153889179229736s
# t=14000, 11.921106338500977s
# t=14200, 11.347055673599243s
# t=14400, 10.90880799293518s
# t=14600, 10.409191846847534s
# t=14800, 10.678791522979736s
# t=15000, 11.358268976211548s
# t=15200, 11.112794637680054s
# t=15400, 11.018872737884521s
# t=15600, 11.735787391662598s
# t=15800, 11.457743883132935s
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -118 |
# |          StdEpRet |             381 |
# |          MaxEpRet |             527 |
# |          MinEpRet |            -419 |
# |  AverageTestEpRet |             346 |
# |      StdTestEpRet |             244 |
# |      MaxTestEpRet |             815 |
# |      MinTestEpRet |           -49.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            6.68 |
# |         StdQ1Vals |            14.4 |
# |         MaxQ1Vals |            40.1 |
# |         MinQ1Vals |           -9.27 |
# |     AverageQ2Vals |          -0.181 |
# |         StdQ2Vals |          0.0432 |
# |         MaxQ2Vals |         -0.0483 |
# |         MinQ2Vals |          -0.262 |
# |            LossPi |           -7.25 |
# |             LossQ |          0.0986 |
# |              Time |            60.4 |
# ---------------------------------------
# t=16000, 60.369576930999756s
# t=16200, 11.582923173904419s
# t=16400, 11.05294132232666s
# t=16600, 10.612622261047363s
# t=16800, 10.753156185150146s
# t=17000, 10.769253253936768s
# t=17200, 10.564747095108032s
# t=17400, 10.592821836471558s
# t=17600, 10.526852369308472s
# t=17800, 11.148832559585571s
# t=18000, 11.012571573257446s
# t=18200, 10.578680276870728s
# t=18400, 11.218780040740967s
# t=18600, 10.582673788070679s
# t=18800, 11.375426054000854s
# t=19000, 10.658796072006226s
# t=19200, 10.318376779556274s
# t=19400, 10.753422737121582s
# t=19600, 10.850982904434204s
# t=19800, 10.483964681625366s
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             829 |
# |          StdEpRet |             167 |
# |          MaxEpRet |        1.04e+03 |
# |          MinEpRet |             581 |
# |  AverageTestEpRet |        1.33e+03 |
# |      StdTestEpRet |            53.3 |
# |      MaxTestEpRet |        1.42e+03 |
# |      MinTestEpRet |        1.22e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            13.2 |
# |         StdQ1Vals |            19.4 |
# |         MaxQ1Vals |            48.6 |
# |         MinQ1Vals |           -10.7 |
# |     AverageQ2Vals |          -0.172 |
# |         StdQ2Vals |           0.044 |
# |         MaxQ2Vals |         -0.0483 |
# |         MinQ2Vals |          -0.262 |
# |            LossPi |             -14 |
# |             LossQ |           0.156 |
# |              Time |            56.1 |
# ---------------------------------------
# t=20000, 56.13441014289856s
# t=20200, 11.1429922580719s
# t=20400, 10.597679376602173s
# t=20600, 11.585634231567383s
# t=20800, 12.013866186141968s
# t=21000, 11.257450342178345s
# t=21200, 11.604400873184204s
# t=21400, 10.994539260864258s
# t=21600, 10.502944946289062s
# t=21800, 10.809510946273804s
# t=22000, 11.107457399368286s
# t=22200, 11.751903772354126s
# t=22400, 11.547977685928345s
# t=22600, 10.532835721969604s
# t=22800, 10.915133237838745s
# t=23000, 10.862971782684326s
# t=23200, 10.623571872711182s
# t=23400, 10.580738067626953s
# t=23600, 10.599622249603271s
# t=23800, 11.405425071716309s
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             555 |
# |          StdEpRet |             243 |
# |          MaxEpRet |             898 |
# |          MinEpRet |             247 |
# |  AverageTestEpRet |             818 |
# |      StdTestEpRet |             448 |
# |      MaxTestEpRet |        1.18e+03 |
# |      MinTestEpRet |            -124 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            22.4 |
# |         StdQ1Vals |            22.5 |
# |         MaxQ1Vals |            57.6 |
# |         MinQ1Vals |           -10.7 |
# |     AverageQ2Vals |          -0.166 |
# |         StdQ2Vals |          0.0444 |
# |         MaxQ2Vals |         -0.0483 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |           -23.4 |
# |             LossQ |           0.241 |
# |              Time |            58.1 |
# ---------------------------------------
# t=24000, 58.11198544502258s
# t=24200, 10.878967523574829s
# t=24400, 10.767012357711792s
# t=24600, 11.536571264266968s
# t=24800, 11.634791851043701s
# t=25000, 10.924431562423706s
# t=25200, 10.890905141830444s
# t=25400, 11.56116795539856s
# t=25600, 10.504760265350342s
# t=25800, 10.826022386550903s
# t=26000, 10.685426712036133s
# t=26200, 10.789147853851318s
# t=26400, 11.455890893936157s
# t=26600, 10.847963094711304s
# t=26800, 10.994632720947266s
# t=27000, 10.996588468551636s
# t=27200, 10.542778491973877s
# t=27400, 10.66151762008667s
# t=27600, 10.683405876159668s
# t=27800, 10.497955322265625s
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |        1.08e+03 |
# |          StdEpRet |             257 |
# |          MaxEpRet |         1.3e+03 |
# |          MinEpRet |             664 |
# |  AverageTestEpRet |        1.66e+03 |
# |      StdTestEpRet |             589 |
# |      MaxTestEpRet |        2.16e+03 |
# |      MinTestEpRet |             189 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            30.6 |
# |         StdQ1Vals |            24.8 |
# |         MaxQ1Vals |            67.3 |
# |         MinQ1Vals |           -7.42 |
# |     AverageQ2Vals |          -0.166 |
# |         StdQ2Vals |          0.0452 |
# |         MaxQ2Vals |         -0.0483 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |           -31.5 |
# |             LossQ |           0.325 |
# |              Time |            55.2 |
# ---------------------------------------
# t=28000, 55.16547894477844s
# t=28200, 10.834670066833496s
# t=28400, 10.837018966674805s
# t=28600, 11.310228109359741s
# t=28800, 11.278866529464722s
# t=29000, 10.564739465713501s
# t=29200, 10.494915008544922s
# t=29400, 10.415148496627808s
# t=29600, 10.658531188964844s
# t=29800, 10.482935667037964s
# t=30000, 10.519904375076294s
# t=30200, 10.66344928741455s
# t=30400, 10.979637861251831s
# t=30600, 12.156015634536743s
# t=30800, 11.670139789581299s
# t=31000, 11.564797639846802s
# t=31200, 10.72634243965149s
# t=31400, 11.505435943603516s
# t=31600, 11.07039499282837s
# t=31800, 10.845996618270874s
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |        1.46e+03 |
# |          StdEpRet |             178 |
# |          MaxEpRet |        1.68e+03 |
# |          MinEpRet |        1.18e+03 |
# |  AverageTestEpRet |             738 |
# |      StdTestEpRet |             798 |
# |      MaxTestEpRet |        1.96e+03 |
# |      MinTestEpRet |            -107 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            39.2 |
# |         StdQ1Vals |            30.3 |
# |         MaxQ1Vals |            82.3 |
# |         MinQ1Vals |           -7.13 |
# |     AverageQ2Vals |          -0.164 |
# |         StdQ2Vals |          0.0458 |
# |         MaxQ2Vals |         -0.0483 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |           -40.3 |
# |             LossQ |           0.497 |
# |              Time |            60.7 |
# ---------------------------------------
# t=32000, 60.69690775871277s
# t=32200, 12.103924036026001s
# t=32400, 12.298241138458252s
# t=32600, 12.45207166671753s
# t=32800, 12.585453271865845s
# t=33000, 12.463489532470703s
# t=33200, 11.995689153671265s
# t=33400, 12.5886390209198s
# t=33600, 12.038837909698486s
# t=33800, 12.34043836593628s
# t=34000, 11.605991125106812s
# t=34200, 11.585992336273193s
# t=34400, 11.623390197753906s
# t=34600, 12.423650741577148s
# t=34800, 12.20930552482605s
# t=35000, 11.467551708221436s
# t=35200, 11.615156650543213s
# t=35400, 11.327707052230835s
# t=35600, 11.20406723022461s
# t=35800, 11.275441884994507s
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |        1.32e+03 |
# |          StdEpRet |             412 |
# |          MaxEpRet |        1.64e+03 |
# |          MinEpRet |             618 |
# |  AverageTestEpRet |             947 |
# |      StdTestEpRet |             754 |
# |      MaxTestEpRet |        1.85e+03 |
# |      MinTestEpRet |            -244 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            49.2 |
# |         StdQ1Vals |            35.5 |
# |         MaxQ1Vals |            95.5 |
# |         MinQ1Vals |           -9.18 |
# |     AverageQ2Vals |          -0.162 |
# |         StdQ2Vals |          0.0449 |
# |         MaxQ2Vals |         -0.0483 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |           -50.2 |
# |             LossQ |           0.807 |
# |              Time |            62.7 |
# ---------------------------------------
# t=36000, 62.68162822723389s
# t=36200, 12.340670585632324s
# t=36400, 11.644399881362915s
# t=36600, 12.038412094116211s
# t=36800, 11.9809889793396s
# t=37000, 12.086164712905884s
# t=37200, 11.512218475341797s
# t=37400, 11.530463218688965s
# t=37600, 10.704378843307495s
# t=37800, 11.254102945327759s
# t=38000, 12.242289781570435s
# t=38200, 10.993573665618896s
# t=38400, 11.91812801361084s
# t=38600, 11.579063415527344s
# t=38800, 11.540113687515259s
# t=39000, 11.885218858718872s
# t=39200, 11.817435503005981s
# t=39400, 12.804784059524536s
# t=39600, 13.125168323516846s
# t=39800, 13.52307939529419s
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |        1.54e+03 |
# |          StdEpRet |             743 |
# |          MaxEpRet |        2.05e+03 |
# |          MinEpRet |             257 |
# |  AverageTestEpRet |        1.38e+03 |
# |      StdTestEpRet |        1.21e+03 |
# |      MaxTestEpRet |        3.07e+03 |
# |      MinTestEpRet |            -235 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            59.3 |
# |         StdQ1Vals |            40.2 |
# |         MaxQ1Vals |             107 |
# |         MinQ1Vals |           -8.69 |
# |     AverageQ2Vals |           -0.16 |
# |         StdQ2Vals |          0.0442 |
# |         MaxQ2Vals |         -0.0287 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |           -60.3 |
# |             LossQ |             1.1 |
# |              Time |            72.4 |
# ---------------------------------------
# t=40000, 72.44049334526062s
# t=40200, 13.451070070266724s
# t=40400, 12.943385124206543s
# t=40600, 12.929344654083252s
# t=40800, 13.758534669876099s
# t=41000, 13.201424837112427s
# t=41200, 13.105207443237305s
# t=41400, 13.049066543579102s
# t=41600, 13.103213787078857s
# t=41800, 13.293243408203125s
# t=42000, 13.191424131393433s
# t=42200, 13.031046152114868s
# t=42400, 13.464587926864624s
# t=42600, 13.090112686157227s
# t=42800, 13.454451322555542s
# t=43000, 13.102968454360962s
# t=43200, 13.116641521453857s
# t=43400, 13.175478219985962s
# t=43600, 13.118516683578491s
# t=43800, 12.997264623641968s
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |        1.22e+03 |
# |          StdEpRet |             949 |
# |          MaxEpRet |        2.67e+03 |
# |          MinEpRet |             251 |
# |  AverageTestEpRet |        3.32e+03 |
# |      StdTestEpRet |        1.24e+03 |
# |      MaxTestEpRet |        4.01e+03 |
# |      MinTestEpRet |            -329 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            67.2 |
# |         StdQ1Vals |            46.2 |
# |         MaxQ1Vals |             125 |
# |         MinQ1Vals |           -8.51 |
# |     AverageQ2Vals |           -0.16 |
# |         StdQ2Vals |          0.0448 |
# |         MaxQ2Vals |         -0.0287 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |           -68.3 |
# |             LossQ |            1.37 |
# |              Time |            70.8 |
# ---------------------------------------
# t=44000, 70.81717848777771s
# t=44200, 13.234134674072266s
# t=44400, 13.521505117416382s
# t=44600, 13.678949117660522s
# t=44800, 12.925130605697632s
# t=45000, 14.43793511390686s
# t=45200, 13.80553913116455s
# t=45400, 14.06374716758728s
# t=45600, 13.423979043960571s
# t=45800, 13.783989191055298s
# t=46000, 13.381061553955078s
# t=46200, 14.429599523544312s
# t=46400, 14.02390432357788s
# t=46600, 13.049471855163574s
# t=46800, 13.197707891464233s
# t=47000, 13.47475290298462s
# t=47200, 13.16113829612732s
# t=47400, 13.27426528930664s
# t=47600, 13.083685398101807s
# t=47800, 13.224842548370361s
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |        1.11e+03 |
# |          StdEpRet |        1.03e+03 |
# |          MaxEpRet |        2.85e+03 |
# |          MinEpRet |             186 |
# |  AverageTestEpRet |             658 |
# |      StdTestEpRet |             587 |
# |      MaxTestEpRet |        1.59e+03 |
# |      MinTestEpRet |            -187 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            75.2 |
# |         StdQ1Vals |              54 |
# |         MaxQ1Vals |             147 |
# |         MinQ1Vals |           -11.2 |
# |     AverageQ2Vals |          -0.161 |
# |         StdQ2Vals |          0.0461 |
# |         MaxQ2Vals |         -0.0273 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |           -76.5 |
# |             LossQ |            1.92 |
# |              Time |            72.4 |
# ---------------------------------------
# t=48000, 72.42238712310791s
# t=48200, 13.1078622341156s
# t=48400, 13.702450037002563s
# t=48600, 13.887397766113281s
# t=48800, 13.23449444770813s
# t=49000, 13.58849573135376s
# t=49200, 13.264756441116333s
# t=49400, 13.170909881591797s
# t=49600, 14.218011856079102s
# t=49800, 13.8383309841156s
# t=50000, 14.484652757644653s
# t=50200, 13.80989956855774s
# t=50400, 13.784364938735962s
# t=50600, 13.225873947143555s
# t=50800, 13.37556791305542s
# t=51000, 13.889463186264038s
# t=51200, 14.629575490951538s
# t=51400, 13.449228763580322s
# t=51600, 13.361278533935547s
# t=51800, 14.074103832244873s
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |        2.44e+03 |
# |          StdEpRet |             771 |
# |          MaxEpRet |        3.25e+03 |
# |          MinEpRet |        1.28e+03 |
# |  AverageTestEpRet |        3.09e+03 |
# |      StdTestEpRet |             520 |
# |      MaxTestEpRet |        3.78e+03 |
# |      MinTestEpRet |        2.11e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            85.1 |
# |         StdQ1Vals |            62.4 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |           -15.9 |
# |     AverageQ2Vals |          -0.161 |
# |         StdQ2Vals |          0.0469 |
# |         MaxQ2Vals |         -0.0273 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |           -86.6 |
# |             LossQ |            2.96 |
# |              Time |            70.4 |
# ---------------------------------------
# t=52000, 70.3601462841034s
# t=52200, 13.056235074996948s
# t=52400, 13.109927654266357s
# t=52600, 13.548604249954224s
# t=52800, 14.004928827285767s
# t=53000, 13.457939386367798s
# t=53200, 11.950071096420288s
# t=53400, 11.692705154418945s
# t=53600, 11.029505252838135s
# t=53800, 10.89988398551941s
# t=54000, 10.807069301605225s
# t=54200, 10.828044176101685s
# t=54400, 10.677448034286499s
# t=54600, 11.670367956161499s
# t=54800, 13.166792154312134s
# t=55000, 11.56706690788269s
# t=55200, 14.271854877471924s
# t=55400, 15.249204397201538s
# t=55600, 14.689152002334595s
# t=55800, 11.94006896018982s
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        1.99e+03 |
# |          StdEpRet |        1.18e+03 |
# |          MaxEpRet |        3.71e+03 |
# |          MinEpRet |             428 |
# |  AverageTestEpRet |        4.46e+03 |
# |      StdTestEpRet |            56.8 |
# |      MaxTestEpRet |        4.57e+03 |
# |      MinTestEpRet |        4.39e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            98.9 |
# |         StdQ1Vals |            69.7 |
# |         MaxQ1Vals |             190 |
# |         MinQ1Vals |           -18.3 |
# |     AverageQ2Vals |          -0.159 |
# |         StdQ2Vals |          0.0472 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -101 |
# |             LossQ |            4.17 |
# |              Time |            71.6 |
# ---------------------------------------
# t=56000, 71.64765548706055s
# t=56200, 11.768718719482422s
# t=56400, 11.974493741989136s
# t=56600, 11.847330808639526s
# t=56800, 11.815035581588745s
# t=57000, 11.671329736709595s
# t=57200, 11.641226768493652s
# t=57400, 11.763953924179077s
# t=57600, 11.820406913757324s
# t=57800, 11.641831636428833s
# t=58000, 13.09298825263977s
# t=58200, 12.557690382003784s
# t=58400, 13.622004270553589s
# t=58600, 12.699809551239014s
# t=58800, 12.037780046463013s
# t=59000, 15.890460968017578s
# t=59200, 13.884500741958618s
# t=59400, 12.531246662139893s
# t=59600, 12.441317796707153s
# t=59800, 12.320786714553833s
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        3.77e+03 |
# |          StdEpRet |             227 |
# |          MaxEpRet |        3.97e+03 |
# |          MinEpRet |         3.4e+03 |
# |  AverageTestEpRet |        4.66e+03 |
# |      StdTestEpRet |             161 |
# |      MaxTestEpRet |        4.93e+03 |
# |      MinTestEpRet |        4.37e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             114 |
# |         StdQ1Vals |            76.8 |
# |         MaxQ1Vals |             210 |
# |         MinQ1Vals |           -17.8 |
# |     AverageQ2Vals |          -0.157 |
# |         StdQ2Vals |          0.0475 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -116 |
# |             LossQ |            4.46 |
# |              Time |            64.9 |
# ---------------------------------------
# t=60000, 64.91067171096802s
# t=60200, 12.00895071029663s
# t=60400, 11.950711250305176s
# t=60600, 11.903599977493286s
# t=60800, 11.922767877578735s
# t=61000, 12.00071907043457s
# t=61200, 11.841830253601074s
# t=61400, 11.819387912750244s
# t=61600, 12.306716203689575s
# t=61800, 12.169662714004517s
# t=62000, 12.295326709747314s
# t=62200, 11.971263885498047s
# t=62400, 11.835598707199097s
# t=62600, 11.956305742263794s
# t=62800, 11.7603178024292s
# t=63000, 11.570404767990112s
# t=63200, 11.680039167404175s
# t=63400, 11.985730171203613s
# t=63600, 15.911640882492065s
# t=63800, 12.663769483566284s
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |        4.05e+03 |
# |          StdEpRet |             263 |
# |          MaxEpRet |         4.4e+03 |
# |          MinEpRet |        3.76e+03 |
# |  AverageTestEpRet |        4.13e+03 |
# |      StdTestEpRet |             291 |
# |      MaxTestEpRet |        4.57e+03 |
# |      MinTestEpRet |        3.68e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             133 |
# |         StdQ1Vals |            82.7 |
# |         MaxQ1Vals |             231 |
# |         MinQ1Vals |           -18.4 |
# |     AverageQ2Vals |          -0.154 |
# |         StdQ2Vals |          0.0476 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -135 |
# |             LossQ |            5.13 |
# |              Time |            64.8 |
# ---------------------------------------
# t=64000, 64.80440211296082s
# t=64200, 11.829732894897461s
# t=64400, 12.04333758354187s
# t=64600, 12.366870164871216s
# t=64800, 11.78070616722107s
# t=65000, 11.677306413650513s
# t=65200, 11.678121328353882s
# t=65400, 11.525214433670044s
# t=65600, 11.704255104064941s
# t=65800, 11.738182544708252s
# t=66000, 14.35779857635498s
# t=66200, 15.125750303268433s
# t=66400, 12.267898797988892s
# t=66600, 12.21111536026001s
# t=66800, 12.150587320327759s
# t=67000, 12.273864030838013s
# t=67200, 11.912093162536621s
# t=67400, 12.105188846588135s
# t=67600, 11.692296266555786s
# t=67800, 11.818263292312622s
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        4.19e+03 |
# |          StdEpRet |            88.4 |
# |          MaxEpRet |        4.31e+03 |
# |          MinEpRet |        4.09e+03 |
# |  AverageTestEpRet |         4.7e+03 |
# |      StdTestEpRet |             112 |
# |      MaxTestEpRet |        4.88e+03 |
# |      MinTestEpRet |        4.46e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             151 |
# |         StdQ1Vals |            88.4 |
# |         MaxQ1Vals |             249 |
# |         MinQ1Vals |           -14.5 |
# |     AverageQ2Vals |          -0.152 |
# |         StdQ2Vals |          0.0476 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -153 |
# |             LossQ |            5.49 |
# |              Time |            70.9 |
# ---------------------------------------
# t=68000, 70.88458299636841s
# t=68200, 13.31173062324524s
# t=68400, 12.410410642623901s
# t=68600, 12.292649507522583s
# t=68800, 11.734671831130981s
# t=69000, 11.66121530532837s
# t=69200, 13.1895592212677s
# t=69400, 11.921457290649414s
# t=69600, 11.925842761993408s
# t=69800, 11.937590837478638s
# t=70000, 11.957039833068848s
# t=70200, 11.932344436645508s
# t=70400, 12.184719800949097s
# t=70600, 12.201220512390137s
# t=70800, 11.79464340209961s
# t=71000, 12.055835723876953s
# t=71200, 11.807060241699219s
# t=71400, 12.00248408317566s
# t=71600, 11.86839485168457s
# t=71800, 11.88027048110962s
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        4.33e+03 |
# |          StdEpRet |             161 |
# |          MaxEpRet |        4.55e+03 |
# |          MinEpRet |        4.16e+03 |
# |  AverageTestEpRet |        4.94e+03 |
# |      StdTestEpRet |             122 |
# |      MaxTestEpRet |        5.11e+03 |
# |      MinTestEpRet |        4.71e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             170 |
# |         StdQ1Vals |            93.6 |
# |         MaxQ1Vals |             266 |
# |         MinQ1Vals |           -8.75 |
# |     AverageQ2Vals |           -0.15 |
# |         StdQ2Vals |          0.0475 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -172 |
# |             LossQ |            5.44 |
# |              Time |            63.7 |
# ---------------------------------------
# t=72000, 63.67132639884949s
# t=72200, 12.156490325927734s
# t=72400, 12.11779499053955s
# t=72600, 12.28254508972168s
# t=72800, 11.596892595291138s
# t=73000, 11.635605335235596s
# t=73200, 11.750920534133911s
# t=73400, 12.985294103622437s
# t=73600, 11.686746835708618s
# t=73800, 11.991931200027466s
# t=74000, 11.668796062469482s
# t=74200, 12.329062461853027s
# t=74400, 12.147485971450806s
# t=74600, 13.06408429145813s
# t=74800, 12.227312803268433s
# t=75000, 12.441726684570312s
# t=75200, 11.49625849723816s
# t=75400, 17.907039642333984s
# t=75600, 16.32223892211914s
# t=75800, 17.889135599136353s
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |        4.43e+03 |
# |          StdEpRet |             232 |
# |          MaxEpRet |        4.58e+03 |
# |          MinEpRet |        4.03e+03 |
# |  AverageTestEpRet |        4.55e+03 |
# |      StdTestEpRet |             201 |
# |      MaxTestEpRet |        4.82e+03 |
# |      MinTestEpRet |        4.17e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             187 |
# |         StdQ1Vals |            98.6 |
# |         MaxQ1Vals |             280 |
# |         MinQ1Vals |           -8.27 |
# |     AverageQ2Vals |          -0.148 |
# |         StdQ2Vals |          0.0473 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -189 |
# |             LossQ |            5.52 |
# |              Time |            70.8 |
# ---------------------------------------
# t=76000, 70.77406668663025s
# t=76200, 12.457814693450928s
# t=76400, 12.756501197814941s
# t=76600, 12.258324146270752s
# t=76800, 12.197550773620605s
# t=77000, 11.953336954116821s
# t=77200, 11.86466646194458s
# t=77400, 11.888640880584717s
# t=77600, 12.07049012184143s
# t=77800, 13.301239728927612s
# t=78000, 11.948898792266846s
# t=78200, 11.719662189483643s
# t=78400, 13.189698219299316s
# t=78600, 12.251883745193481s
# t=78800, 13.817084550857544s
# t=79000, 12.912477254867554s
# t=79200, 11.743372917175293s
# t=79400, 11.14020848274231s
# t=79600, 11.000587940216064s
# t=79800, 11.073357105255127s
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |        4.56e+03 |
# |          StdEpRet |             300 |
# |          MaxEpRet |        4.85e+03 |
# |          MinEpRet |        4.09e+03 |
# |  AverageTestEpRet |        5.48e+03 |
# |      StdTestEpRet |            90.9 |
# |      MaxTestEpRet |        5.59e+03 |
# |      MinTestEpRet |        5.33e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             204 |
# |         StdQ1Vals |             103 |
# |         MaxQ1Vals |             295 |
# |         MinQ1Vals |           -12.9 |
# |     AverageQ2Vals |          -0.146 |
# |         StdQ2Vals |          0.0473 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -205 |
# |             LossQ |            4.92 |
# |              Time |              59 |
# ---------------------------------------
# t=80000, 59.01406455039978s
# t=80200, 10.913795471191406s
# t=80400, 11.116273641586304s
# t=80600, 10.90984845161438s
# t=80800, 10.952690362930298s
# t=81000, 10.932792663574219s
# t=81200, 11.08732295036316s
# t=81400, 10.944732427597046s
# t=81600, 10.737318754196167s
# t=81800, 11.20702576637268s
# t=82000, 10.932766675949097s
# t=82200, 11.000552892684937s
# t=82400, 11.11727237701416s
# t=82600, 11.027510404586792s
# t=82800, 11.30742359161377s
# t=83000, 10.791143894195557s
# t=83200, 11.097326278686523s
# t=83400, 11.28880786895752s
# t=83600, 11.01753282546997s
# t=83800, 10.976626873016357s
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        4.34e+03 |
# |          StdEpRet |             379 |
# |          MaxEpRet |        4.98e+03 |
# |          MinEpRet |        4.05e+03 |
# |  AverageTestEpRet |        3.94e+03 |
# |      StdTestEpRet |             541 |
# |      MaxTestEpRet |        4.51e+03 |
# |      MinTestEpRet |         2.7e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             219 |
# |         StdQ1Vals |             107 |
# |         MaxQ1Vals |             310 |
# |         MinQ1Vals |           -10.8 |
# |     AverageQ2Vals |          -0.145 |
# |         StdQ2Vals |          0.0473 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -220 |
# |             LossQ |            5.45 |
# |              Time |            57.5 |
# ---------------------------------------
# t=84000, 57.48926854133606s
# t=84200, 10.890907049179077s
# t=84400, 11.548086404800415s
# t=84600, 11.109321355819702s
# t=84800, 10.917774438858032s
# t=85000, 11.010583400726318s
# t=85200, 10.799095392227173s
# t=85400, 10.831037998199463s
# t=85600, 10.904857158660889s
# t=85800, 10.924766778945923s
# t=86000, 10.917834520339966s
# t=86200, 10.893837928771973s
# t=86400, 10.946759700775146s
# t=86600, 10.934754610061646s
# t=86800, 10.89287543296814s
# t=87000, 11.023523092269897s
# t=87200, 10.764212608337402s
# t=87400, 12.121554613113403s
# t=87600, 10.856996059417725s
# t=87800, 10.865946769714355s
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |         4.4e+03 |
# |          StdEpRet |             264 |
# |          MaxEpRet |        4.79e+03 |
# |          MinEpRet |        4.07e+03 |
# |  AverageTestEpRet |        4.55e+03 |
# |      StdTestEpRet |             858 |
# |      MaxTestEpRet |        5.47e+03 |
# |      MinTestEpRet |        2.57e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             233 |
# |         StdQ1Vals |             109 |
# |         MaxQ1Vals |             325 |
# |         MinQ1Vals |           -10.2 |
# |     AverageQ2Vals |          -0.144 |
# |         StdQ2Vals |           0.047 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -235 |
# |             LossQ |            5.41 |
# |              Time |            57.4 |
# ---------------------------------------
# t=88000, 57.43640375137329s
# t=88200, 10.776184320449829s
# t=88400, 11.390538692474365s
# t=88600, 10.80809497833252s
# t=88800, 10.863923072814941s
# t=89000, 10.880905866622925s
# t=89200, 10.86298131942749s
# t=89400, 10.868903398513794s
# t=89600, 10.830066204071045s
# t=89800, 10.943735361099243s
# t=90000, 10.787127256393433s
# t=90200, 10.862949132919312s
# t=90400, 11.002608060836792s
# t=90600, 10.804079294204712s
# t=90800, 10.835050106048584s
# t=91000, 10.781173706054688s
# t=91200, 10.837013244628906s
# t=91400, 10.964680671691895s
# t=91600, 10.930747747421265s
# t=91800, 10.803112030029297s
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        4.38e+03 |
# |          StdEpRet |             313 |
# |          MaxEpRet |         4.8e+03 |
# |          MinEpRet |        3.92e+03 |
# |  AverageTestEpRet |        5.45e+03 |
# |      StdTestEpRet |             264 |
# |      MaxTestEpRet |        5.71e+03 |
# |      MinTestEpRet |        4.96e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             246 |
# |         StdQ1Vals |             112 |
# |         MaxQ1Vals |             339 |
# |         MinQ1Vals |           -13.9 |
# |     AverageQ2Vals |          -0.143 |
# |         StdQ2Vals |           0.047 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -247 |
# |             LossQ |            6.42 |
# |              Time |            57.2 |
# ---------------------------------------
# t=92000, 57.17012023925781s
# t=92200, 10.761225461959839s
# t=92400, 11.012574672698975s
# t=92600, 10.98861575126648s
# t=92800, 10.813076257705688s
# t=93000, 11.043478012084961s
# t=93200, 10.767177104949951s
# t=93400, 11.196559429168701s
# t=93600, 11.137207746505737s
# t=93800, 11.248926639556885s
# t=94000, 10.905810117721558s
# t=94200, 10.997591733932495s
# t=94400, 10.771225690841675s
# t=94600, 10.859955310821533s
# t=94800, 10.910796403884888s
# t=95000, 10.846027851104736s
# t=95200, 10.864678144454956s
# t=95400, 10.886855602264404s
# t=95600, 10.889901876449585s
# t=95800, 11.035467863082886s
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        4.74e+03 |
# |          StdEpRet |             307 |
# |          MaxEpRet |        4.99e+03 |
# |          MinEpRet |        4.23e+03 |
# |  AverageTestEpRet |        5.52e+03 |
# |      StdTestEpRet |            96.1 |
# |      MaxTestEpRet |        5.64e+03 |
# |      MinTestEpRet |        5.36e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             259 |
# |         StdQ1Vals |             115 |
# |         MaxQ1Vals |             352 |
# |         MinQ1Vals |           -14.5 |
# |     AverageQ2Vals |          -0.141 |
# |         StdQ2Vals |          0.0467 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -261 |
# |             LossQ |            6.41 |
# |              Time |            57.2 |
# ---------------------------------------
# t=96000, 57.23497295379639s
# t=96200, 10.78315782546997s
# t=96400, 10.872925043106079s
# t=96600, 10.83201289176941s
# t=96800, 10.756239652633667s
# t=97000, 10.847989320755005s
# t=97200, 10.790176391601562s
# t=97400, 10.768174409866333s
# t=97600, 11.015543460845947s
# t=97800, 10.890894651412964s
# t=98000, 11.15318775177002s
# t=98200, 10.824051141738892s
# t=98400, 10.8719003200531s
# t=98600, 10.824053525924683s
# t=98800, 11.049452066421509s
# t=99000, 11.007564306259155s
# t=99200, 10.887531042098999s
# t=99400, 10.881901979446411s
# t=99600, 10.81105923652649s
# t=99800, 10.840040683746338s
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        4.85e+03 |
# |          StdEpRet |             263 |
# |          MaxEpRet |        5.19e+03 |
# |          MinEpRet |        4.46e+03 |
# |  AverageTestEpRet |        5.36e+03 |
# |      StdTestEpRet |            92.1 |
# |      MaxTestEpRet |        5.51e+03 |
# |      MinTestEpRet |        5.22e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             270 |
# |         StdQ1Vals |             117 |
# |         MaxQ1Vals |             364 |
# |         MinQ1Vals |           -21.3 |
# |     AverageQ2Vals |           -0.14 |
# |         StdQ2Vals |          0.0466 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -272 |
# |             LossQ |            6.51 |
# |              Time |            57.1 |
# ---------------------------------------
# t=100000, 57.09033989906311s
# t=100200, 11.056401491165161s
# t=100400, 10.864975929260254s
# t=100600, 10.7881178855896s
# t=100800, 10.868936538696289s
# t=101000, 10.800146341323853s
# t=101200, 10.834030866622925s
# t=101400, 10.811061382293701s
# t=101600, 10.920827627182007s
# t=101800, 10.8310387134552s
# t=102000, 10.848979473114014s
# t=102200, 10.799115896224976s
# t=102400, 10.867947578430176s
# t=102600, 10.881898880004883s
# t=102800, 10.796100854873657s
# t=103000, 10.979672193527222s
# t=103200, 10.909793853759766s
# t=103400, 10.963681936264038s
# t=103600, 10.882925510406494s
# t=103800, 10.914785146713257s
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |         4.9e+03 |
# |          StdEpRet |             180 |
# |          MaxEpRet |        5.21e+03 |
# |          MinEpRet |        4.77e+03 |
# |  AverageTestEpRet |        5.76e+03 |
# |      StdTestEpRet |            82.9 |
# |      MaxTestEpRet |        5.85e+03 |
# |      MinTestEpRet |        5.62e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             282 |
# |         StdQ1Vals |             120 |
# |         MaxQ1Vals |             375 |
# |         MinQ1Vals |           -20.5 |
# |     AverageQ2Vals |           -0.14 |
# |         StdQ2Vals |          0.0464 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -284 |
# |             LossQ |            6.71 |
# |              Time |            57.1 |
# ---------------------------------------
# t=104000, 57.09635019302368s
# t=104200, 10.852977514266968s
# t=104400, 10.972657203674316s
# t=104600, 10.917805433273315s
# t=104800, 10.81308364868164s
# t=105000, 10.883894920349121s
# t=105200, 10.846031427383423s
# t=105400, 10.86194896697998s
# t=105600, 10.986612319946289s
# t=105800, 10.691417217254639s
# t=106000, 10.55676794052124s
# t=106200, 10.634564876556396s
# t=106400, 10.562750577926636s
# t=106600, 10.659499883651733s
# t=106800, 10.712345600128174s
# t=107000, 11.098300457000732s
# t=107200, 10.68146300315857s
# t=107400, 10.837445259094238s
# t=107600, 10.628578662872314s
# t=107800, 10.617633581161499s
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |        5.02e+03 |
# |          StdEpRet |             138 |
# |          MaxEpRet |        5.24e+03 |
# |          MinEpRet |        4.88e+03 |
# |  AverageTestEpRet |        5.58e+03 |
# |      StdTestEpRet |             139 |
# |      MaxTestEpRet |        5.72e+03 |
# |      MinTestEpRet |        5.28e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             294 |
# |         StdQ1Vals |             122 |
# |         MaxQ1Vals |             387 |
# |         MinQ1Vals |             -24 |
# |     AverageQ2Vals |          -0.139 |
# |         StdQ2Vals |          0.0463 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -296 |
# |             LossQ |            6.99 |
# |              Time |            56.2 |
# ---------------------------------------
# t=108000, 56.23462462425232s
# t=108200, 10.578680992126465s
# t=108400, 10.664482116699219s
# t=108600, 10.565773487091064s
# t=108800, 10.620603799819946s
# t=109000, 10.476950883865356s
# t=109200, 10.698418617248535s
# t=109400, 10.597652912139893s
# t=109600, 10.614597797393799s
# t=109800, 10.634591102600098s
# t=110000, 10.647495746612549s
# t=110200, 10.74329948425293s
# t=110400, 10.717343091964722s
# t=110600, 10.620598554611206s
# t=110800, 10.579710721969604s
# t=111000, 10.694401502609253s
# t=111200, 10.659464120864868s
# t=111400, 10.681463479995728s
# t=111600, 10.731308698654175s
# t=111800, 10.800113916397095s
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        4.92e+03 |
# |          StdEpRet |             149 |
# |          MaxEpRet |        5.15e+03 |
# |          MinEpRet |        4.75e+03 |
# |  AverageTestEpRet |        4.81e+03 |
# |      StdTestEpRet |             397 |
# |      MaxTestEpRet |        5.14e+03 |
# |      MinTestEpRet |        3.76e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             305 |
# |         StdQ1Vals |             124 |
# |         MaxQ1Vals |             398 |
# |         MinQ1Vals |           -28.4 |
# |     AverageQ2Vals |          -0.138 |
# |         StdQ2Vals |          0.0461 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -307 |
# |             LossQ |             7.9 |
# |              Time |            57.2 |
# ---------------------------------------
# t=112000, 57.20898795127869s
# t=112200, 10.641571521759033s
# t=112400, 10.665485858917236s
# t=112600, 10.639512777328491s
# t=112800, 10.584724187850952s
# t=113000, 10.563750743865967s
# t=113200, 10.575719594955444s
# t=113400, 10.681410074234009s
# t=113600, 10.80015254020691s
# t=113800, 10.588669300079346s
# t=114000, 10.658508777618408s
# t=114200, 10.671452760696411s
# t=114400, 10.68842625617981s
# t=114600, 10.624590635299683s
# t=114800, 10.598654985427856s
# t=115000, 10.678418397903442s
# t=115200, 10.654506921768188s
# t=115400, 10.598658561706543s
# t=115600, 10.659538745880127s
# t=115800, 10.71134328842163s
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        4.69e+03 |
# |          StdEpRet |             254 |
# |          MaxEpRet |        5.02e+03 |
# ...
# ---------------------------------------
# t=160000, 55.946396350860596s
# t=160200, 10.551782369613647s
# t=160400, 10.793133735656738s
# t=160600, 10.736293077468872s
# t=160800, 10.621595859527588s
# t=161000, 10.626586437225342s
# t=161200, 10.610596179962158s
# t=161400, 10.922810792922974s
# t=161600, 10.641555547714233s
# t=161800, 10.66644549369812s
# t=162000, 10.619633913040161s
# t=162200, 10.693373680114746s
# t=162400, 11.134251356124878s
# t=162600, 10.611623048782349s
# t=162800, 11.104252815246582s
# t=163000, 10.703381776809692s
# t=163200, 10.859953880310059s
# t=163400, 10.76518440246582s
# t=163600, 11.251940727233887s
# t=163800, 12.37547516822815s
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        5.14e+03 |
# |          StdEpRet |             269 |
# |          MaxEpRet |        5.37e+03 |
# |          MinEpRet |        4.69e+03 |
# |  AverageTestEpRet |        5.37e+03 |
# |      StdTestEpRet |             216 |
# |      MaxTestEpRet |        5.88e+03 |
# |      MinTestEpRet |        5.09e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             399 |
# |         StdQ1Vals |             134 |
# |         MaxQ1Vals |             481 |
# |         MinQ1Vals |           -16.3 |
# |     AverageQ2Vals |          -0.132 |
# |         StdQ2Vals |           0.045 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -401 |
# |             LossQ |            12.1 |
# |              Time |              65 |
# ---------------------------------------
# t=164000, 65.02073216438293s
# t=164200, 12.311079978942871s
# t=164400, 11.603001117706299s
# t=164600, 11.387517929077148s
# t=164800, 11.589010953903198s
# t=165000, 12.506883144378662s
# t=165200, 11.400499820709229s
# t=165400, 11.645219564437866s
# t=165600, 12.868607759475708s
# t=165800, 11.069377899169922s
# t=166000, 11.415472507476807s
# t=166200, 11.789502382278442s
# t=166400, 10.836024761199951s
# t=166600, 10.698390245437622s
# t=166800, 10.769197225570679s
# t=167000, 10.613621234893799s
# t=167200, 10.791117668151855s
# t=167400, 10.710376501083374s
# t=167600, 10.96166729927063s
# t=167800, 10.730308532714844s
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        5.15e+03 |
# |          StdEpRet |             188 |
# |          MaxEpRet |        5.34e+03 |
# |          MinEpRet |        4.85e+03 |
# |  AverageTestEpRet |        4.75e+03 |
# |      StdTestEpRet |             230 |
# |      MaxTestEpRet |        5.25e+03 |
# |      MinTestEpRet |        4.54e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             404 |
# |         StdQ1Vals |             134 |
# |         MaxQ1Vals |             484 |
# |         MinQ1Vals |            4.48 |
# |     AverageQ2Vals |          -0.132 |
# |         StdQ2Vals |          0.0449 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -405 |
# |             LossQ |              11 |
# |              Time |            56.1 |
# ---------------------------------------
# t=168000, 56.096017599105835s
# t=168200, 10.492945671081543s
# t=168400, 10.611590147018433s
# t=168600, 10.704376220703125s
# t=168800, 10.97564959526062s
# t=169000, 10.723325490951538s
# t=169200, 10.655534744262695s
# t=169400, 10.747260332107544s
# t=169600, 10.781139850616455s
# t=169800, 10.79017424583435s
# t=170000, 10.64151644706726s
# t=170200, 10.754241704940796s
# t=170400, 10.635558605194092s
# t=170600, 10.712382078170776s
# t=170800, 10.685428619384766s
# t=171000, 10.954703330993652s
# t=171200, 10.685418367385864s
# t=171400, 11.394540786743164s
# t=171600, 11.416473388671875s
# t=171800, 10.721296548843384s
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        5.07e+03 |
# |          StdEpRet |             213 |
# |          MaxEpRet |        5.39e+03 |
# |          MinEpRet |        4.83e+03 |
# |  AverageTestEpRet |        5.21e+03 |
# |      StdTestEpRet |             314 |
# |      MaxTestEpRet |        5.78e+03 |
# |      MinTestEpRet |        4.59e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             408 |
# |         StdQ1Vals |             133 |
# |         MaxQ1Vals |             488 |
# |         MinQ1Vals |           -24.1 |
# |     AverageQ2Vals |          -0.132 |
# |         StdQ2Vals |          0.0448 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -410 |
# |             LossQ |              12 |
# |              Time |            56.3 |
# ---------------------------------------
# t=172000, 56.2944598197937s
# t=172200, 10.666476964950562s
# t=172400, 10.756269931793213s
# t=172600, 10.630539417266846s
# t=172800, 10.723323822021484s
# t=173000, 10.655535697937012s
# t=173200, 10.720337152481079s
# t=173400, 10.933755874633789s
# t=173600, 10.742275953292847s
# t=173800, 10.869933605194092s
# t=174000, 10.7572021484375s
# t=174200, 10.846018314361572s
# t=174400, 10.692414045333862s
# t=174600, 10.677448749542236s
# t=174800, 10.825055599212646s
# t=175000, 10.755206108093262s
# t=175200, 10.721331596374512s
# t=175400, 10.721356391906738s
# t=175600, 10.708365440368652s
# t=175800, 10.759219884872437s
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |         4.8e+03 |
# |          StdEpRet |             244 |
# |          MaxEpRet |        5.09e+03 |
# |          MinEpRet |        4.42e+03 |
# |  AverageTestEpRet |        4.54e+03 |
# |      StdTestEpRet |        1.64e+03 |
# |      MaxTestEpRet |        6.01e+03 |
# |      MinTestEpRet |             509 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             413 |
# |         StdQ1Vals |             132 |
# |         MaxQ1Vals |             490 |
# |         MinQ1Vals |            3.04 |
# |     AverageQ2Vals |          -0.131 |
# |         StdQ2Vals |          0.0447 |
# |         MaxQ2Vals |         -0.0261 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -414 |
# |             LossQ |            12.8 |
# |              Time |            56.6 |
# ---------------------------------------
# t=176000, 56.58552861213684s
# t=176200, 10.986621379852295s
# t=176400, 10.754241704940796s
# t=176600, 10.66151738166809s
# t=176800, 10.736263751983643s
# t=177000, 10.621625423431396s
# t=177200, 10.576714038848877s
# t=177400, 10.982630491256714s
# t=177600, 10.708365440368652s
# t=177800, 10.64254093170166s
# t=178000, 10.72731328010559s
# t=178200, 10.980609655380249s
# t=178400, 10.747278928756714s
# t=178600, 10.685434818267822s
# t=178800, 10.821035146713257s
# t=179000, 10.64852523803711s
# t=179200, 10.760253667831421s
# t=179400, 10.690384864807129s
# t=179600, 10.74030613899231s
# t=179800, 10.786128759384155s
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |           5e+03 |
# |          StdEpRet |             397 |
# |          MaxEpRet |         5.4e+03 |
# |          MinEpRet |        4.35e+03 |
# |  AverageTestEpRet |         4.4e+03 |
# |      StdTestEpRet |        1.82e+03 |
# |      MaxTestEpRet |        5.79e+03 |
# |      MinTestEpRet |             516 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             416 |
# |         StdQ1Vals |             131 |
# |         MaxQ1Vals |             493 |
# |         MinQ1Vals |            6.46 |
# |     AverageQ2Vals |          -0.131 |
# |         StdQ2Vals |          0.0447 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -417 |
# |             LossQ |            11.8 |
# |              Time |            56.7 |
# ---------------------------------------
# t=180000, 56.65564823150635s
# t=180200, 11.145197868347168s
# t=180400, 10.626617431640625s
# t=180600, 10.66344928741455s
# t=180800, 10.6654794216156s
# t=181000, 10.73030424118042s
# t=181200, 10.852008581161499s
# t=181400, 10.766201972961426s
# t=181600, 10.603652715682983s
# t=181800, 10.678446769714355s
# t=182000, 10.684398889541626s
# t=182200, 10.665479898452759s
# t=182400, 10.71835732460022s
# t=182600, 10.641523122787476s
# t=182800, 10.627584218978882s
# t=183000, 10.724275588989258s
# t=183200, 10.741276264190674s
# t=183400, 10.737292289733887s
# t=183600, 10.591671705245972s
# t=183800, 10.728303909301758s
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        4.92e+03 |
# |          StdEpRet |             345 |
# |          MaxEpRet |        5.44e+03 |
# |          MinEpRet |        4.59e+03 |
# |  AverageTestEpRet |        5.45e+03 |
# |      StdTestEpRet |             132 |
# |      MaxTestEpRet |        5.67e+03 |
# |      MinTestEpRet |        5.25e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             419 |
# |         StdQ1Vals |             129 |
# |         MaxQ1Vals |             495 |
# |         MinQ1Vals |          -0.916 |
# |     AverageQ2Vals |          -0.131 |
# |         StdQ2Vals |          0.0445 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -421 |
# |             LossQ |            11.8 |
# |              Time |              56 |
# ---------------------------------------
# t=184000, 55.95437932014465s
# t=184200, 10.552751541137695s
# t=184400, 10.763218879699707s
# t=184600, 10.721357107162476s
# t=184800, 10.805105209350586s
# t=185000, 10.703380346298218s
# t=185200, 10.711327314376831s
# t=185400, 10.628597736358643s
# t=185600, 10.67446255683899s
# t=185800, 10.696396112442017s
# t=186000, 10.709363222122192s
# t=186200, 10.593642473220825s
# t=186400, 10.714348793029785s
# t=186600, 10.874946117401123s
# t=186800, 10.69337797164917s
# t=187000, 10.69240689277649s
# t=187200, 10.673486232757568s
# t=187400, 10.682433366775513s
# t=187600, 10.669440507888794s
# t=187800, 10.714380979537964s
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        4.53e+03 |
# |          StdEpRet |             392 |
# |          MaxEpRet |         5.1e+03 |
# |          MinEpRet |        4.05e+03 |
# |  AverageTestEpRet |        5.51e+03 |
# |      StdTestEpRet |             320 |
# |      MaxTestEpRet |         5.9e+03 |
# |      MinTestEpRet |        4.85e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             422 |
# |         StdQ1Vals |             128 |
# |         MaxQ1Vals |             497 |
# |         MinQ1Vals |           -5.47 |
# |     AverageQ2Vals |           -0.13 |
# |         StdQ2Vals |          0.0444 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -424 |
# |             LossQ |            11.5 |
# |              Time |            56.1 |
# ---------------------------------------
# t=188000, 56.13488292694092s
# t=188200, 10.72230076789856s
# t=188400, 10.700386047363281s
# t=188600, 10.639580488204956s
# t=188800, 10.83599042892456s
# t=189000, 10.815108299255371s
# t=189200, 10.56474757194519s
# t=189400, 10.67645001411438s
# t=189600, 10.863921403884888s
# t=189800, 10.74426817893982s
# t=190000, 11.119266748428345s
# t=190200, 10.761220693588257s
# t=190400, 10.902873277664185s
# t=190600, 10.694393873214722s
# t=190800, 10.777188301086426s
# t=191000, 11.020522356033325s
# t=191200, 10.751261234283447s
# t=191400, 10.67243242263794s
# t=191600, 10.793134689331055s
# t=191800, 10.584723949432373s
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        4.95e+03 |
# |          StdEpRet |             134 |
# |          MaxEpRet |        5.11e+03 |
# |          MinEpRet |        4.74e+03 |
# |  AverageTestEpRet |        5.58e+03 |
# |      StdTestEpRet |             763 |
# |      MaxTestEpRet |        6.06e+03 |
# |      MinTestEpRet |        3.33e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             425 |
# |         StdQ1Vals |             128 |
# |         MaxQ1Vals |             500 |
# |         MinQ1Vals |           -2.97 |
# |     AverageQ2Vals |           -0.13 |
# |         StdQ2Vals |          0.0444 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -427 |
# |             LossQ |            12.2 |
# |              Time |            62.1 |
# ---------------------------------------
# t=192000, 62.143717765808105s
# t=192200, 12.590580940246582s
# t=192400, 14.194432497024536s
# t=192600, 14.033039808273315s
# t=192800, 11.65685486793518s
# t=193000, 11.54213571548462s
# t=193200, 10.892871379852295s
# t=193400, 10.67046570777893s
# t=193600, 10.68142819404602s
# t=193800, 10.830048084259033s
# t=194000, 11.035488605499268s
# t=194200, 10.79909348487854s
# t=194400, 10.833032608032227s
# t=194600, 10.929803848266602s
# t=194800, 12.52849268913269s
# t=195000, 11.582266330718994s
# t=195200, 11.587042331695557s
# t=195400, 12.50442886352539s
# t=195600, 12.351378679275513s
# t=195800, 12.072893142700195s
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |         5.3e+03 |
# |          StdEpRet |             228 |
# |          MaxEpRet |        5.52e+03 |
# |          MinEpRet |        4.92e+03 |
# |  AverageTestEpRet |        5.76e+03 |
# |      StdTestEpRet |             211 |
# |      MaxTestEpRet |        6.01e+03 |
# |      MinTestEpRet |        5.34e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             427 |
# |         StdQ1Vals |             129 |
# |         MaxQ1Vals |             503 |
# |         MinQ1Vals |             8.2 |
# |     AverageQ2Vals |           -0.13 |
# |         StdQ2Vals |          0.0442 |
# |         MaxQ2Vals |          -0.024 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -428 |
# |             LossQ |            12.3 |
# |              Time |            71.3 |
# ---------------------------------------
# t=196000, 71.2740707397461s
# t=196200, 13.56315016746521s
# t=196400, 12.538796663284302s
# t=196600, 12.104965686798096s
# t=196800, 11.932057619094849s
# t=197000, 11.847808122634888s
# t=197200, 11.891539335250854s
# t=197400, 11.875412940979004s
# t=197600, 11.735165119171143s
# t=197800, 11.716732263565063s
# t=198000, 12.3042733669281s
# t=198200, 12.42046570777893s
# t=198400, 12.306018352508545s
# t=198600, 11.769380331039429s
# t=198800, 11.984005451202393s
# t=199000, 11.805631160736084s
# t=199200, 11.739735126495361s
# t=199400, 11.991089344024658s
# t=199600, 11.739363670349121s
# t=199800, 11.736295700073242s
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        5.33e+03 |
# |          StdEpRet |             281 |
# |          MaxEpRet |        5.74e+03 |
# |          MinEpRet |        5.01e+03 |
# |  AverageTestEpRet |        6.33e+03 |
# |      StdTestEpRet |             180 |
# |      MaxTestEpRet |         6.8e+03 |
# |      MinTestEpRet |        6.13e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             429 |
# |         StdQ1Vals |             130 |
# |         MaxQ1Vals |             505 |
# |         MinQ1Vals |            2.21 |
# |     AverageQ2Vals |           -0.13 |
# |         StdQ2Vals |          0.0442 |
# |         MaxQ2Vals |         -0.0253 |
# |         MinQ2Vals |          -0.269 |
# |            LossPi |            -431 |
# |             LossQ |            12.6 |
# |              Time |              64 |
# ---------------------------------------

# %%
args = {'env': 'Ant-v2', 'hid': 256, 'l': 2, 
        'max_hist_len': 5,
        'gamma': 0.99, 'seed': 0, 'epochs': 50, 
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'freeze_hist_coding': False,
        'exp_name': 'test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     max_hist_len=args['max_hist_len'],
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
    freeze_hist_coding=args['freeze_hist_coding'],
     logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze_s0 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"Ant-v2",
#     "epochs":	50,
#     "exp_name":	"test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze",
#     "freeze_hist_coding":	false,
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000002098FFC2548>":	{
#             "epoch_dict":	{},
#             "exp_name":	"test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze\\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze\\\\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze\\test_pre_feature_extraction_gated_lstm_DDPG_POMDP_Ant_PreLSTM1L128_HistMemory5Len_LSTM1L128_HidStateLayer0_2L128_NoFreeze_s0"
#     },
#     "max_ep_len":	1000,
#     "max_hist_len":	5,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	1000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 221064, 	 q1: 222209, 	 q2: 222209
#
# t=0, 0.0s
# t=200, 0.24135327339172363s
# t=400, 0.1934826374053955s
# t=600, 0.19248533248901367s
# t=800, 0.21442627906799316s
# t=1000, 0.25531888008117676s
# t=1200, 21.64711308479309s
# t=1400, 21.825634717941284s
# t=1600, 21.256158113479614s
# t=1800, 21.02677321434021s
# t=2000, 28306.789645433426s
# t=2200, 18.284823179244995s
# t=2400, 16.80972719192505s
# t=2600, 15.22628378868103s
# t=2800, 15.415776014328003s
# t=3000, 15.69802188873291s
# t=3200, 16.001210689544678s
# t=3400, 16.280463695526123s
# t=3600, 16.31636905670166s
# t=3800, 16.505861043930054s
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |             351 |
# |          StdEpRet |             449 |
# |          MaxEpRet |             923 |
# |          MinEpRet |            -108 |
# |  AverageTestEpRet |             836 |
# |      StdTestEpRet |              16 |
# |      MaxTestEpRet |             871 |
# |      MinTestEpRet |             818 |
# |             EpLen |             681 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            1.82 |
# |         StdQ1Vals |            1.94 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |            -4.1 |
# |     AverageQ2Vals |         0.00608 |
# |         StdQ2Vals |         0.00882 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -2.51 |
# |             LossQ |          0.0574 |
# |              Time |            74.6 |
# ---------------------------------------
# t=4000, 74.55425214767456s
# t=4200, 13.540053129196167s
# t=4400, 13.377195119857788s
# t=4600, 13.397173881530762s
# t=4800, 13.609607934951782s
# t=5000, 17.49321937561035s
# t=5200, 17.884175539016724s
# t=5400, 17.715625762939453s
# t=5600, 18.009840488433838s
# t=5800, 18.073668718338013s
# t=6000, 18.176393747329712s
# t=6200, 18.33297562599182s
# t=6400, 18.30405330657959s
# t=6600, 18.573840856552124s
# t=6800, 18.436697959899902s
# t=7000, 18.798731088638306s
# t=7200, 18.491549015045166s
# t=7400, 18.68603277206421s
# t=7600, 18.788756608963013s
# t=7800, 19.707299947738647s
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |             665 |
# |          StdEpRet |             230 |
# |          MaxEpRet |             877 |
# |          MinEpRet |             277 |
# |  AverageTestEpRet |             670 |
# |      StdTestEpRet |            82.2 |
# |      MaxTestEpRet |             915 |
# |      MinTestEpRet |             623 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            9.44 |
# |         StdQ1Vals |            3.26 |
# |         MaxQ1Vals |            29.6 |
# |         MinQ1Vals |           -3.81 |
# |     AverageQ2Vals |         0.00758 |
# |         StdQ2Vals |         0.00789 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |             -10 |
# |             LossQ |          0.0857 |
# |              Time |            88.5 |
# ---------------------------------------
# t=8000, 88.51891875267029s
# t=8200, 19.224591970443726s
# t=8400, 19.122863292694092s
# t=8600, 19.203645944595337s
# t=8800, 19.227583408355713s
# t=9000, 19.403114318847656s
# t=9200, 17.511173009872437s
# t=9400, 15.1165771484375s
# t=9600, 14.839316844940186s
# t=9800, 14.69470477104187s
# t=10000, 14.906139373779297s
# t=10200, 16.738239288330078s
# t=10400, 19.653444290161133s
# t=10600, 19.591609954833984s
# t=10800, 19.655948877334595s
# t=11000, 19.315348148345947s
# t=11200, 19.459961652755737s
# t=11400, 19.333300352096558s
# t=11600, 19.30038833618164s
# t=11800, 19.262998819351196s
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |             113 |
# |          StdEpRet |             300 |
# |          MaxEpRet |             605 |
# |          MinEpRet |            -461 |
# |  AverageTestEpRet |            65.2 |
# |      StdTestEpRet |              63 |
# |      MaxTestEpRet |             216 |
# |      MinTestEpRet |            9.94 |
# |             EpLen |             498 |
# |         TestEpLen |              56 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            19.8 |
# |         StdQ1Vals |            3.96 |
# |         MaxQ1Vals |            47.3 |
# |         MinQ1Vals |            -4.7 |
# |     AverageQ2Vals |         0.00727 |
# |         StdQ2Vals |         0.00785 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -20.6 |
# |             LossQ |            0.19 |
# |              Time |            23.4 |
# ---------------------------------------
# t=12000, 23.404412269592285s
# t=12200, 19.285428762435913s
# t=12400, 19.154778003692627s
# t=12600, 19.178714513778687s
# t=12800, 19.360227346420288s
# t=13000, 19.374191284179688s
# t=13200, 19.23057532310486s
# t=13400, 19.111891984939575s
# t=13600, 19.092944383621216s
# t=13800, 19.529773712158203s
# t=14000, 24.106394290924072s
# t=14200, 22.09591317176819s
# t=14400, 23.3355975151062s
# t=14600, 23.79046630859375s
# t=14800, 23.881932020187378s
# t=15000, 23.43887495994568s
# t=15200, 21.95389676094055s
# t=15400, 20.73177409172058s
# t=15600, 20.800600290298462s
# t=15800, 20.166339635849s
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             207 |
# |          StdEpRet |             223 |
# |          MaxEpRet |             620 |
# |          MinEpRet |            7.44 |
# |  AverageTestEpRet |             466 |
# |      StdTestEpRet |             391 |
# |      MaxTestEpRet |             865 |
# |      MinTestEpRet |            4.46 |
# |             EpLen |             359 |
# |         TestEpLen |             616 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            29.7 |
# |         StdQ1Vals |            4.83 |
# |         MaxQ1Vals |            66.5 |
# |         MinQ1Vals |             -14 |
# |     AverageQ2Vals |         0.00686 |
# |         StdQ2Vals |          0.0082 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -30.8 |
# |             LossQ |           0.548 |
# |              Time |            72.8 |
# ---------------------------------------
# t=16000, 72.76844501495361s
# t=16200, 21.372586011886597s
# t=16400, 23.378233194351196s
# t=16600, 21.696740865707397s
# t=16800, 21.313453674316406s
# t=17000, 21.260667324066162s
# t=17200, 21.183499574661255s
# t=17400, 21.38391613960266s
# t=17600, 22.43328309059143s
# t=17800, 23.22737431526184s
# t=18000, 22.297476768493652s
# t=18200, 21.668603897094727s
# t=18400, 21.189380407333374s
# t=18600, 21.113168716430664s
# t=18800, 22.097371578216553s
# t=19000, 22.876589059829712s
# t=19200, 21.522237062454224s
# t=19400, 21.463472604751587s
# t=19600, 20.83443832397461s
# t=19800, 20.653769493103027s
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             150 |
# |          StdEpRet |             186 |
# |          MaxEpRet |             527 |
# |          MinEpRet |           -18.9 |
# |  AverageTestEpRet |             171 |
# |      StdTestEpRet |             201 |
# |      MaxTestEpRet |             688 |
# |      MinTestEpRet |           -36.2 |
# |             EpLen |             307 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            40.1 |
# |         StdQ1Vals |            5.62 |
# |         MaxQ1Vals |            76.6 |
# |         MinQ1Vals |           -19.9 |
# |     AverageQ2Vals |          0.0063 |
# |         StdQ2Vals |         0.00879 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -41.3 |
# |             LossQ |           0.744 |
# |              Time |             104 |
# ---------------------------------------
# t=20000, 104.40333962440491s
# t=20200, 18.75285267829895s
# t=20400, 17.930481910705566s
# t=20600, 18.305665493011475s
# t=20800, 17.330634593963623s
# t=21000, 18.805147409439087s
# t=21200, 21.447646617889404s
# t=21400, 20.617216110229492s
# t=21600, 20.086286783218384s
# t=21800, 21.816660165786743s
# t=22000, 23.728013515472412s
# t=22200, 20.769461631774902s
# t=22400, 21.394787311553955s
# t=22600, 21.090601205825806s
# t=22800, 20.852238655090332s
# t=23000, 21.096584796905518s
# t=23200, 21.2471821308136s
# t=23400, 20.963939905166626s
# t=23600, 20.95396661758423s
# t=23800, 20.744525909423828s
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             104 |
# |          StdEpRet |             150 |
# |          MaxEpRet |             456 |
# |          MinEpRet |            -8.1 |
# |  AverageTestEpRet |             511 |
# |      StdTestEpRet |             276 |
# |      MaxTestEpRet |             938 |
# |      MinTestEpRet |            1.68 |
# |             EpLen |             296 |
# |         TestEpLen |             803 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            50.5 |
# |         StdQ1Vals |            6.72 |
# |         MaxQ1Vals |            86.8 |
# |         MinQ1Vals |           -11.6 |
# |     AverageQ2Vals |         0.00694 |
# |         StdQ2Vals |          0.0098 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -51.8 |
# |             LossQ |           0.938 |
# |              Time |            86.7 |
# ---------------------------------------
# t=24000, 86.66026091575623s
# t=24200, 20.840270280838013s
# t=24400, 20.614383697509766s
# t=24600, 20.674713611602783s
# t=24800, 20.900110483169556s
# t=25000, 21.078633308410645s
# t=25200, 21.125508069992065s
# t=25400, 21.088606595993042s
# t=25600, 20.777437925338745s
# t=25800, 19.88382840156555s
# t=26000, 17.25484824180603s
# t=26200, 17.977906703948975s
# t=26400, 17.883564710617065s
# t=26600, 17.196016788482666s
# t=26800, 18.027522325515747s
# t=27000, 18.42273497581482s
# t=27200, 15.220299005508423s
# t=27400, 14.407474517822266s
# t=27600, 14.3386549949646s
# t=27800, 14.257901430130005s
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             159 |
# |          StdEpRet |             154 |
# |          MaxEpRet |             448 |
# |          MinEpRet |            4.78 |
# |  AverageTestEpRet |            -391 |
# |      StdTestEpRet |             456 |
# |      MaxTestEpRet |             123 |
# |      MinTestEpRet |            -931 |
# |             EpLen |             273 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            59.4 |
# |         StdQ1Vals |            7.35 |
# |         MaxQ1Vals |            96.4 |
# |         MinQ1Vals |           -18.9 |
# |     AverageQ2Vals |         0.00764 |
# |         StdQ2Vals |         0.00975 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -60.8 |
# |             LossQ |            1.77 |
# |              Time |            63.3 |
# ---------------------------------------
# t=28000, 63.34056258201599s
# t=28200, 13.742282390594482s
# t=28400, 14.701127767562866s
# t=28600, 14.815381526947021s
# t=28800, 15.18741488456726s
# t=29000, 14.693680047988892s
# t=29200, 14.563083171844482s
# t=29400, 14.563029289245605s
# t=29600, 14.9560067653656s
# t=29800, 14.459333181381226s
# t=30000, 14.94706130027771s
# t=30200, 14.78842282295227s
# t=30400, 14.98393726348877s
# t=30600, 14.552086591720581s
# t=30800, 15.008893728256226s
# t=31000, 14.686696767807007s
# t=31200, 15.522215843200684s
# t=31400, 14.97794771194458s
# t=31600, 14.499226093292236s
# t=31800, 15.734923839569092s
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             203 |
# |          StdEpRet |             166 |
# |          MaxEpRet |             517 |
# |          MinEpRet |            40.9 |
# |  AverageTestEpRet |             616 |
# |      StdTestEpRet |             234 |
# |      MaxTestEpRet |             918 |
# |      MinTestEpRet |            68.1 |
# |             EpLen |             756 |
# |         TestEpLen |             909 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            67.6 |
# |         StdQ1Vals |            7.31 |
# |         MaxQ1Vals |             110 |
# |         MinQ1Vals |           -17.6 |
# |     AverageQ2Vals |         0.00808 |
# |         StdQ2Vals |         0.00977 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |             -69 |
# |             LossQ |            1.53 |
# |              Time |            62.4 |
# ---------------------------------------
# t=32000, 62.37832045555115s
# t=32200, 14.96099305152893s
# t=32400, 15.644670009613037s
# t=32600, 14.753547668457031s
# t=32800, 15.04180359840393s
# t=33000, 14.936060190200806s
# t=33200, 14.790449142456055s
# t=33400, 14.646831035614014s
# t=33600, 15.06269383430481s
# t=33800, 14.791444301605225s
# t=34000, 14.378578186035156s
# t=34200, 14.176063060760498s
# t=34400, 14.5151846408844s
# t=34600, 14.5750253200531s
# t=34800, 14.720634937286377s
# t=35000, 14.67778205871582s
# t=35200, 14.125195264816284s
# t=35400, 14.734626054763794s
# t=35600, 14.780448913574219s
# t=35800, 14.909130334854126s
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             449 |
# |          StdEpRet |             266 |
# |          MaxEpRet |             792 |
# |          MinEpRet |            46.1 |
# |  AverageTestEpRet |             405 |
# |      StdTestEpRet |             281 |
# |      MaxTestEpRet |             803 |
# |      MinTestEpRet |            2.44 |
# |             EpLen |             708 |
# |         TestEpLen |             731 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            74.8 |
# |         StdQ1Vals |             7.7 |
# |         MaxQ1Vals |             119 |
# |         MinQ1Vals |           -24.7 |
# |     AverageQ2Vals |         0.00842 |
# |         StdQ2Vals |         0.00967 |
# |         MaxQ2Vals |          0.0401 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -76.1 |
# |             LossQ |            1.55 |
# |              Time |            50.4 |
# ---------------------------------------
# t=36000, 50.37429213523865s
# t=36200, 13.260567903518677s
# t=36400, 13.348939895629883s
# t=36600, 13.122877597808838s
# t=36800, 12.893521308898926s
# t=37000, 13.512894868850708s
# t=37200, 13.170576572418213s
# t=37400, 13.149683713912964s
# t=37600, 13.058082818984985s
# t=37800, 12.70904541015625s
# t=38000, 13.413100004196167s
# t=38200, 13.340327501296997s
# t=38400, 21.33295202255249s
# t=38600, 21.193326711654663s
# t=38800, 21.12052083015442s
# t=39000, 21.06267547607422s
# t=39200, 24.008525848388672s
# t=39400, 21.582287073135376s
# t=39600, 21.847576141357422s
# t=39800, 21.38033628463745s
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             249 |
# |          StdEpRet |             252 |
# |          MaxEpRet |             616 |
# |          MinEpRet |            3.93 |
# |  AverageTestEpRet |             316 |
# |      StdTestEpRet |             233 |
# |      MaxTestEpRet |             606 |
# |      MinTestEpRet |           0.317 |
# |             EpLen |             490 |
# |         TestEpLen |             584 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |              81 |
# |         StdQ1Vals |            7.67 |
# |         MaxQ1Vals |             124 |
# |         MinQ1Vals |           -25.3 |
# |     AverageQ2Vals |         0.00855 |
# |         StdQ2Vals |         0.00977 |
# |         MaxQ2Vals |          0.0402 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -82.2 |
# |             LossQ |            1.67 |
# |              Time |            83.3 |
# ---------------------------------------
# t=40000, 83.31520628929138s
# t=40200, 21.05038070678711s
# t=40400, 20.86221146583557s
# t=40600, 20.800377368927002s
# t=40800, 21.046720266342163s
# t=41000, 20.85123920440674s
# t=41200, 20.72457981109619s
# t=41400, 20.943994522094727s
# t=41600, 20.790403604507446s
# t=41800, 20.822317123413086s
# t=42000, 20.865665912628174s
# t=42200, 20.94698691368103s
# t=42400, 20.752503395080566s
# t=42600, 20.73455309867859s
# t=42800, 20.895124197006226s
# t=43000, 20.865203380584717s
# t=43200, 20.852238655090332s
# t=43400, 20.77843689918518s
# t=43600, 20.75848913192749s
# t=43800, 20.719592571258545s
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             346 |
# |          StdEpRet |             219 |
# |          MaxEpRet |             638 |
# |          MinEpRet |            23.7 |
# |  AverageTestEpRet |             499 |
# |      StdTestEpRet |             354 |
# |      MaxTestEpRet |             997 |
# |      MinTestEpRet |            12.3 |
# |             EpLen |             487 |
# |         TestEpLen |             636 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            85.5 |
# |         StdQ1Vals |            7.88 |
# |         MaxQ1Vals |             132 |
# |         MinQ1Vals |           -19.3 |
# |     AverageQ2Vals |         0.00884 |
# |         StdQ2Vals |            0.01 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -86.7 |
# |             LossQ |            1.83 |
# |              Time |            82.4 |
# ---------------------------------------
# t=44000, 82.43708229064941s
# t=44200, 20.70662784576416s
# t=44400, 20.836793661117554s
# t=44600, 20.75848937034607s
# t=44800, 20.817333221435547s
# t=45000, 20.88814091682434s
# t=45200, 20.90908646583557s
# t=45400, 20.856229305267334s
# t=45600, 21.41473364830017s
# t=45800, 21.344510555267334s
# t=46000, 21.17695426940918s
# t=46200, 20.961944341659546s
# t=46400, 20.912079095840454s
# t=46600, 20.84326195716858s
# t=46800, 20.89811611175537s
# t=47000, 20.914073944091797s
# t=47200, 21.364866495132446s
# t=47400, 21.838600873947144s
# t=47600, 21.853580951690674s
# t=47800, 21.412739992141724s
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             426 |
# |          StdEpRet |             362 |
# |          MaxEpRet |             797 |
# |          MinEpRet |            -181 |
# |  AverageTestEpRet |             200 |
# |      StdTestEpRet |             367 |
# |      MaxTestEpRet |             838 |
# |      MinTestEpRet |            -339 |
# |             EpLen |             786 |
# |         TestEpLen |             426 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            89.8 |
# |         StdQ1Vals |            8.24 |
# |         MaxQ1Vals |             141 |
# |         MinQ1Vals |           -19.7 |
# |     AverageQ2Vals |         0.00888 |
# |         StdQ2Vals |         0.00987 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -91.1 |
# |             LossQ |            1.66 |
# |              Time |              68 |
# ---------------------------------------
# t=48000, 68.02266454696655s
# t=48200, 21.33594584465027s
# t=48400, 21.167396068572998s
# t=48600, 21.140466451644897s
# t=48800, 21.011812925338745s
# t=49000, 21.34296751022339s
# t=49200, 21.447645902633667s
# t=49400, 21.174376726150513s
# t=49600, 21.16639733314514s
# t=49800, 20.88215923309326s
# t=50000, 21.296051740646362s
# t=50200, 21.241198778152466s
# t=50400, 21.635145664215088s
# t=50600, 21.054696321487427s
# t=50800, 20.985880851745605s
# t=51000, 21.098580598831177s
# t=51200, 21.2132728099823s
# t=51400, 21.675040006637573s
# t=51600, 21.501499891281128s
# t=51800, 21.262143850326538s
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             242 |
# |          StdEpRet |             295 |
# |          MaxEpRet |             725 |
# |          MinEpRet |            16.3 |
# |  AverageTestEpRet |             465 |
# |      StdTestEpRet |             191 |
# |      MaxTestEpRet |             734 |
# |      MinTestEpRet |            56.5 |
# |             EpLen |             487 |
# |         TestEpLen |             906 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            94.8 |
# |         StdQ1Vals |            8.67 |
# |         MaxQ1Vals |             148 |
# |         MinQ1Vals |           -27.8 |
# |     AverageQ2Vals |         0.00861 |
# |         StdQ2Vals |         0.00978 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |           -96.1 |
# |             LossQ |            1.81 |
# |              Time |             117 |
# ---------------------------------------
# t=52000, 117.42377996444702s
# t=52200, 21.137477159500122s
# t=52400, 21.78773593902588s
# t=52600, 21.746845960617065s
# t=52800, 21.933401346206665s
# t=53000, 21.16639995574951s
# t=53200, 21.32796573638916s
# t=53400, 21.618189334869385s
# t=53600, 21.059683799743652s
# t=53800, 20.975907802581787s
# t=54000, 21.090112924575806s
# t=54200, 21.437673091888428s
# t=54400, 22.509807109832764s
# t=54600, 21.453628540039062s
# t=54800, 21.888468980789185s
# t=55000, 22.780083417892456s
# t=55200, 22.813992023468018s
# t=55400, 22.252074718475342s
# t=55600, 22.640469074249268s
# t=55800, 21.57785701751709s
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             510 |
# |          StdEpRet |             333 |
# |          MaxEpRet |             995 |
# |          MinEpRet |            87.2 |
# |  AverageTestEpRet |             653 |
# |      StdTestEpRet |             219 |
# |      MaxTestEpRet |             883 |
# |      MinTestEpRet |            26.7 |
# |             EpLen |             706 |
# |         TestEpLen |             903 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            98.8 |
# |         StdQ1Vals |            8.86 |
# |         MaxQ1Vals |             152 |
# |         MinQ1Vals |           -23.9 |
# |     AverageQ2Vals |         0.00848 |
# |         StdQ2Vals |         0.00969 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |            -100 |
# |             LossQ |            1.72 |
# |              Time |             121 |
# ---------------------------------------
# t=56000, 121.27962851524353s
# t=56200, 23.70671558380127s
# t=56400, 22.95098853111267s
# t=56600, 22.009145498275757s
# t=56800, 21.819651126861572s
# t=57000, 21.865529775619507s
# t=57200, 21.693987607955933s
# t=57400, 21.117528200149536s
# t=57600, 21.544387817382812s
# t=57800, 21.640131950378418s
# t=58000, 22.001166105270386s
# t=58200, 21.442659616470337s
# t=58400, 21.770781993865967s
# t=58600, 21.798736572265625s
# t=58800, 21.278098821640015s
# t=59000, 22.007149934768677s
# t=59200, 22.041058778762817s
# t=59400, 21.625173091888428s
# t=59600, 21.149442434310913s
# t=59800, 22.82350468635559s
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             578 |
# |          StdEpRet |             253 |
# |          MaxEpRet |             920 |
# |          MinEpRet |             191 |
# |  AverageTestEpRet |             512 |
# |      StdTestEpRet |            43.4 |
# |      MaxTestEpRet |             580 |
# |      MinTestEpRet |             462 |
# |             EpLen |             838 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             102 |
# |         StdQ1Vals |            9.21 |
# |         MaxQ1Vals |             168 |
# |         MinQ1Vals |           -21.8 |
# |     AverageQ2Vals |         0.00857 |
# |         StdQ2Vals |          0.0097 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |            -103 |
# |             LossQ |            1.89 |
# |              Time |             131 |
# ---------------------------------------
# t=60000, 131.1280198097229s
# t=60200, 21.274110555648804s
# t=60400, 21.58827018737793s
# t=60600, 21.287075757980347s
# t=60800, 21.523950576782227s
# t=61000, 21.436716079711914s
# t=61200, 21.762804985046387s
# t=61400, 21.832617044448853s
# t=61600, 22.77310276031494s
# t=61800, 22.896769285202026s
# t=62000, 21.960275411605835s
# t=62200, 21.65908145904541s
# t=62400, 22.011139154434204s
# t=62600, 21.994187593460083s
# t=62800, 21.678027629852295s
# t=63000, 22.025672435760498s
# t=63200, 21.23022747039795s
# t=63400, 22.03407859802246s
# t=63600, 22.18268060684204s
# t=63800, 21.142462968826294s
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             617 |
# |          StdEpRet |            36.7 |
# |          MaxEpRet |             678 |
# |          MinEpRet |             583 |
# |  AverageTestEpRet |             465 |
# |      StdTestEpRet |             354 |
# |      MaxTestEpRet |             897 |
# |      MinTestEpRet |            55.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             510 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             105 |
# |         StdQ1Vals |            9.79 |
# |         MaxQ1Vals |             161 |
# |         MinQ1Vals |           -24.9 |
# |     AverageQ2Vals |         0.00886 |
# |         StdQ2Vals |         0.00955 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |            -107 |
# |             LossQ |             1.7 |
# |              Time |            73.3 |
# ---------------------------------------
# t=64000, 73.26160764694214s
# t=64200, 22.365193128585815s
# t=64400, 22.55169415473938s
# t=64600, 22.273438215255737s
# t=64800, 22.176696300506592s
# t=65000, 21.381821870803833s
# t=65200, 21.656616926193237s
# t=65400, 22.208612203598022s
# t=65600, 23.426073789596558s
# t=65800, 24.219894886016846s
# t=66000, 25.760114431381226s
# t=66200, 22.214595317840576s
# t=66400, 21.940330028533936s
# t=66600, 29.20261836051941s
# t=66800, 34.58501577377319s
# t=67000, 30.42214035987854s
# t=67200, 27.903379440307617s
# t=67400, 22.780084371566772s
# t=67600, 22.639458417892456s
# t=67800, 21.94431710243225s
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             532 |
# |          StdEpRet |             286 |
# |          MaxEpRet |             840 |
# |          MinEpRet |            98.2 |
# |  AverageTestEpRet |             292 |
# |      StdTestEpRet |             209 |
# |      MaxTestEpRet |             584 |
# |      MinTestEpRet |            28.8 |
# |             EpLen |             701 |
# |         TestEpLen |             637 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             109 |
# |         StdQ1Vals |            9.92 |
# |         MaxQ1Vals |             155 |
# |         MinQ1Vals |           -29.2 |
# |     AverageQ2Vals |         0.00904 |
# |         StdQ2Vals |         0.00944 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0248 |
# |            LossPi |            -110 |
# |             LossQ |            1.59 |
# |              Time |            92.8 |
# ---------------------------------------
# t=68000, 92.76426768302917s
# t=68200, 16.368229866027832s
# t=68400, 12.991290807723999s
# t=68600, 21.815630674362183s
# t=68800, 21.375837802886963s
# t=69000, 21.18534755706787s
# t=69200, 21.19035506248474s
# t=69400, 21.17936396598816s
# t=69600, 21.112542390823364s
# t=69800, 21.10556149482727s
# t=70000, 21.238205671310425s
# t=70200, 20.965933799743652s
# t=70400, 21.165401935577393s
# t=70600, 20.9640212059021s
# t=70800, 21.04372525215149s
# t=71000, 21.074644088745117s
# t=71200, 20.913076162338257s
# t=71400, 21.160414218902588s
# t=71600, 21.455625772476196s
# t=71800, 21.00981640815735s
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             144 |
# |          StdEpRet |             142 |
# |          MaxEpRet |             537 |
# |          MinEpRet |           -3.09 |
# |  AverageTestEpRet |             150 |
# |      StdTestEpRet |             145 |
# |      MaxTestEpRet |             461 |
# |      MinTestEpRet |            4.71 |
# |             EpLen |             278 |
# |         TestEpLen |             182 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             112 |
# |         StdQ1Vals |            9.95 |
# |         MaxQ1Vals |             159 |
# |         MinQ1Vals |           -22.6 |
# |     AverageQ2Vals |         0.00874 |
# |         StdQ2Vals |         0.00971 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -113 |
# |             LossQ |            2.91 |
# |              Time |            40.5 |
# ---------------------------------------
# t=72000, 40.46279764175415s
# t=72200, 21.12351417541504s
# t=72400, 20.870190143585205s
# t=72600, 20.941999673843384s
# t=72800, 20.95895218849182s
# t=73000, 21.021785497665405s
# t=73200, 20.888142347335815s
# t=73400, 20.97291612625122s
# t=73600, 20.824313163757324s
# t=73800, 20.888142824172974s
# t=74000, 20.90609335899353s
# t=74200, 20.845258951187134s
# t=74400, 20.916067123413086s
# t=74600, 20.94100069999695s
# t=74800, 20.878169059753418s
# t=75000, 21.023780584335327s
# t=75200, 21.05768847465515s
# t=75400, 21.00782322883606s
# t=75600, 21.01979088783264s
# t=75800, 21.006824254989624s
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             350 |
# |          StdEpRet |             198 |
# |          MaxEpRet |             633 |
# |          MinEpRet |             122 |
# |  AverageTestEpRet |             360 |
# |      StdTestEpRet |             262 |
# |      MaxTestEpRet |             701 |
# |      MinTestEpRet |              32 |
# |             EpLen |             662 |
# |         TestEpLen |             642 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             114 |
# |         StdQ1Vals |            10.5 |
# |         MaxQ1Vals |             168 |
# |         MinQ1Vals |           -31.9 |
# |     AverageQ2Vals |         0.00835 |
# |         StdQ2Vals |          0.0098 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -116 |
# |             LossQ |            2.23 |
# |              Time |            87.8 |
# ---------------------------------------
# t=76000, 87.80924868583679s
# t=76200, 20.88614845275879s
# t=76400, 20.975907564163208s
# t=76600, 20.929033756256104s
# t=76800, 22.503822088241577s
# t=77000, 22.749165296554565s
# t=77200, 21.518041610717773s
# t=77400, 21.53142261505127s
# t=77600, 22.6105375289917s
# t=77800, 21.550370693206787s
# t=78000, 21.551369428634644s
# t=78200, 21.756819248199463s
# t=78400, 21.777763843536377s
# t=78600, 21.834612369537354s
# t=78800, 21.990201473236084s
# t=79000, 21.42569851875305s
# t=79200, 21.095587730407715s
# t=79400, 21.162408590316772s
# t=79600, 21.085614919662476s
# t=79800, 21.10456347465515s
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             224 |
# |          StdEpRet |             229 |
# |          MaxEpRet |             679 |
# |          MinEpRet |            3.69 |
# |  AverageTestEpRet |             303 |
# |      StdTestEpRet |             142 |
# |      MaxTestEpRet |             586 |
# |      MinTestEpRet |             120 |
# |             EpLen |             538 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             117 |
# |         StdQ1Vals |            11.2 |
# |         MaxQ1Vals |             172 |
# |         MinQ1Vals |           -36.3 |
# |     AverageQ2Vals |         0.00811 |
# |         StdQ2Vals |         0.00985 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -118 |
# |             LossQ |            2.32 |
# |              Time |             128 |
# ---------------------------------------
# t=80000, 127.70307111740112s
# t=80200, 21.395785093307495s
# t=80400, 21.69398784637451s
# t=80600, 21.440664768218994s
# t=80800, 21.692991018295288s
# t=81000, 21.413737773895264s
# t=81200, 21.809677362442017s
# t=81400, 22.340951442718506s
# t=81600, 21.980008363723755s
# t=81800, 21.859973669052124s
# t=82000, 21.73902726173401s
# t=82200, 21.713966608047485s
# t=82400, 21.915990352630615s
# t=82600, 21.515990495681763s
# t=82800, 21.932995557785034s
# t=83000, 21.681942224502563s
# t=83200, 21.92208242416382s
# t=83400, 22.116950035095215s
# t=83600, 21.91887068748474s
# t=83800, 21.573310375213623s
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -165 |
# |          StdEpRet |             203 |
# |          MaxEpRet |             123 |
# |          MinEpRet |            -449 |
# |  AverageTestEpRet |            60.5 |
# |      StdTestEpRet |             334 |
# |      MaxTestEpRet |             558 |
# |      MinTestEpRet |            -282 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             120 |
# |         StdQ1Vals |              12 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |             -31 |
# |     AverageQ2Vals |         0.00875 |
# |         StdQ2Vals |          0.0102 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -121 |
# |             LossQ |            2.07 |
# |              Time |             125 |
# ---------------------------------------
# t=84000, 124.82520246505737s
# t=84200, 21.548377752304077s
# t=84400, 21.51247215270996s
# t=84600, 21.57031798362732s
# t=84800, 21.47956132888794s
# t=85000, 21.54438853263855s
# t=85200, 21.616195678710938s
# t=85400, 21.632152318954468s
# t=85600, 21.656090021133423s
# t=85800, 21.506488800048828s
# t=86000, 21.492526054382324s
# t=86200, 21.501502752304077s
# t=86400, 21.46759295463562s
# t=86600, 21.420756816864014s
# t=86800, 21.320985317230225s
# t=87000, 21.575305461883545s
# t=87200, 22.02673840522766s
# t=87400, 21.676035165786743s
# t=87600, 21.763800859451294s
# t=87800, 21.62317705154419s
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             131 |
# |          StdEpRet |             242 |
# |          MaxEpRet |             383 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |             482 |
# |      StdTestEpRet |            30.2 |
# |      MaxTestEpRet |             541 |
# |      MinTestEpRet |             455 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             123 |
# |         StdQ1Vals |            12.5 |
# |         MaxQ1Vals |             165 |
# |         MinQ1Vals |             -39 |
# |     AverageQ2Vals |         0.00897 |
# |         StdQ2Vals |          0.0101 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -125 |
# |             LossQ |            1.99 |
# |              Time |             126 |
# ---------------------------------------
# t=88000, 125.52134084701538s
# t=88200, 21.55037260055542s
# t=88400, 21.533417463302612s
# t=88600, 21.86652636528015s
# t=88800, 21.73687243461609s
# t=89000, 21.432685375213623s
# t=89200, 21.966259717941284s
# t=89400, 21.834612607955933s
# t=89600, 22.061007022857666s
# t=89800, 21.705955743789673s
# t=90000, 21.73288345336914s
# t=90200, 21.61519718170166s
# t=90400, 21.86353349685669s
# t=90600, 21.472580671310425s
# t=90800, 21.498510360717773s
# t=91000, 21.399774312973022s
# t=91200, 21.435678720474243s
# t=91400, 21.382818698883057s
# t=91600, 21.534415245056152s
# t=91800, 21.450637578964233s
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             446 |
# |          StdEpRet |             199 |
# |          MaxEpRet |             658 |
# |          MinEpRet |             244 |
# |  AverageTestEpRet |             573 |
# |      StdTestEpRet |             189 |
# |      MaxTestEpRet |             674 |
# |      MinTestEpRet |            14.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             927 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             127 |
# |         StdQ1Vals |            12.2 |
# |         MaxQ1Vals |             167 |
# |         MinQ1Vals |           -33.8 |
# |     AverageQ2Vals |         0.00912 |
# |         StdQ2Vals |         0.00999 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -128 |
# |             LossQ |             1.8 |
# |              Time |             115 |
# ---------------------------------------
# t=92000, 115.38644289970398s
# t=92200, 21.466597318649292s
# t=92400, 21.463603019714355s
# t=92600, 21.576303243637085s
# t=92800, 21.578296422958374s
# t=93000, 21.57231307029724s
# t=93200, 21.478564023971558s
# t=93400, 21.384814262390137s
# t=93600, 21.320985555648804s
# t=93800, 21.592257976531982s
# t=94000, 21.397780656814575s
# t=94200, 21.454627990722656s
# t=94400, 21.488536834716797s
# t=94600, 21.480557918548584s
# t=94800, 21.463603973388672s
# t=95000, 21.337939500808716s
# t=95200, 21.400771379470825s
# t=95400, 21.499507904052734s
# t=95600, 21.612226724624634s
# t=95800, 21.450618267059326s
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             234 |
# |          StdEpRet |             283 |
# |          MaxEpRet |             675 |
# |          MinEpRet |           -76.9 |
# |  AverageTestEpRet |             534 |
# |      StdTestEpRet |             330 |
# |      MaxTestEpRet |             837 |
# |      MinTestEpRet |            7.63 |
# |             EpLen |             589 |
# |         TestEpLen |             687 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             129 |
# |         StdQ1Vals |            11.4 |
# |         MaxQ1Vals |             162 |
# |         MinQ1Vals |           -30.1 |
# |     AverageQ2Vals |         0.00936 |
# |         StdQ2Vals |         0.00991 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -130 |
# |             LossQ |             1.9 |
# |              Time |            91.7 |
# ---------------------------------------
# t=96000, 91.68083381652832s
# t=96200, 21.519454956054688s
# t=96400, 21.451635122299194s
# t=96600, 21.531423568725586s
# t=96800, 21.47257947921753s
# t=97000, 21.3768367767334s
# t=97200, 21.30502676963806s
# t=97400, 21.401768445968628s
# t=97600, 21.449642181396484s
# t=97800, 21.815661668777466s
# t=98000, 21.932350397109985s
# t=98200, 21.578298330307007s
# t=98400, 21.371846914291382s
# t=98600, 22.14976978302002s
# t=98800, 22.22968602180481s
# t=99000, 22.06499481201172s
# t=99200, 21.9393310546875s
# t=99400, 21.626169204711914s
# t=99600, 21.938333749771118s
# t=99800, 22.19068670272827s
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             225 |
# |          StdEpRet |             256 |
# |          MaxEpRet |             737 |
# |          MinEpRet |            4.81 |
# |  AverageTestEpRet |             586 |
# |      StdTestEpRet |            41.5 |
# |      MaxTestEpRet |             638 |
# |      MinTestEpRet |             474 |
# |             EpLen |             483 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             129 |
# |         StdQ1Vals |            11.2 |
# |         MaxQ1Vals |             166 |
# |         MinQ1Vals |           -29.5 |
# |     AverageQ2Vals |         0.00935 |
# |         StdQ2Vals |         0.00982 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -131 |
# |             LossQ |            2.08 |
# |              Time |             126 |
# ---------------------------------------
# t=100000, 126.17259931564331s
# t=100200, 21.68501305580139s
# t=100400, 21.416728019714355s
# t=100600, 21.61419987678528s
# t=100800, 21.42770028114319s
# t=101000, 21.364869832992554s
# t=101200, 21.622177600860596s
# t=101400, 21.643147706985474s
# t=101600, 21.736850023269653s
# t=101800, 21.831618785858154s
# t=102000, 21.926366567611694s
# t=102200, 21.859545946121216s
# t=102400, 21.90342617034912s
# t=102600, 21.69099521636963s
# t=102800, 21.533418655395508s
# t=103000, 21.760807514190674s
# t=103200, 21.571316242218018s
# t=103400, 21.56333637237549s
# t=103600, 21.846580505371094s
# t=103800, 21.72940158843994s
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             431 |
# |          StdEpRet |             280 |
# |          MaxEpRet |             830 |
# |          MinEpRet |              51 |
# |  AverageTestEpRet |             943 |
# |      StdTestEpRet |            16.7 |
# |      MaxTestEpRet |             959 |
# |      MinTestEpRet |             895 |
# |             EpLen |             731 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             130 |
# |         StdQ1Vals |            11.3 |
# |         MaxQ1Vals |             177 |
# |         MinQ1Vals |           -24.4 |
# |     AverageQ2Vals |         0.00921 |
# |         StdQ2Vals |         0.00984 |
# |         MaxQ2Vals |          0.0411 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -131 |
# |             LossQ |             2.2 |
# |              Time |             123 |
# ---------------------------------------
# t=104000, 123.3381781578064s
# t=104200, 21.248180150985718s
# t=104400, 21.131492614746094s
# t=104600, 21.42570447921753s
# t=104800, 21.42470693588257s
# t=105000, 21.440665006637573s
# t=105200, 21.36087918281555s
# t=105400, 21.42470932006836s
# t=105600, 21.23820424079895s
# t=105800, 21.228233337402344s
# t=106000, 21.261146068572998s
# t=106200, 21.306024312973022s
# t=106400, 21.339935302734375s
# t=106600, 21.3618745803833s
# t=106800, 21.21028184890747s
# t=107000, 21.31998872756958s
# t=107200, 21.59325671195984s
# t=107400, 21.388803243637085s
# t=107600, 21.444653749465942s
# t=107800, 21.422912120819092s
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             428 |
# |          StdEpRet |             275 |
# |          MaxEpRet |             746 |
# |          MinEpRet |            94.1 |
# |  AverageTestEpRet |             285 |
# |      StdTestEpRet |             258 |
# |      MaxTestEpRet |             768 |
# |      MinTestEpRet |            13.5 |
# |             EpLen |             648 |
# |         TestEpLen |             472 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             129 |
# |         StdQ1Vals |            11.5 |
# |         MaxQ1Vals |             185 |
# |         MinQ1Vals |           -29.9 |
# |     AverageQ2Vals |         0.00908 |
# |         StdQ2Vals |         0.00987 |
# |         MaxQ2Vals |          0.0439 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -131 |
# |             LossQ |            2.61 |
# |              Time |            71.5 |
# ---------------------------------------
# t=108000, 71.53370928764343s
# t=108200, 21.19731616973877s
# t=108400, 21.37384295463562s
# t=108600, 21.51147747039795s
# t=108800, 21.41573143005371s
# t=109000, 21.490530967712402s
# t=109200, 21.355892181396484s
# t=109400, 21.285080194473267s
# t=109600, 21.362873792648315s
# t=109800, 21.73388147354126s
# t=110000, 21.948840141296387s
# t=110200, 23.07389235496521s
# t=110400, 23.70694923400879s
# t=110600, 21.952021598815918s
# t=110800, 21.95196557044983s
# t=111000, 21.800541400909424s
# t=111200, 22.25048589706421s
# t=111400, 21.75003933906555s
# t=111600, 21.973950386047363s
# t=111800, 21.903934717178345s
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             291 |
# |          StdEpRet |             286 |
# |          MaxEpRet |             774 |
# |          MinEpRet |            17.7 |
# |  AverageTestEpRet |             732 |
# |      StdTestEpRet |             288 |
# |      MaxTestEpRet |             952 |
# |      MinTestEpRet |            27.8 |
# |             EpLen |             356 |
# |         TestEpLen |             842 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             129 |
# |         StdQ1Vals |            11.6 |
# |         MaxQ1Vals |             180 |
# |         MinQ1Vals |           -25.4 |
# |     AverageQ2Vals |         0.00899 |
# |         StdQ2Vals |         0.00981 |
# |         MaxQ2Vals |          0.0439 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -130 |
# |             LossQ |            2.54 |
# |              Time |             113 |
# ---------------------------------------
# t=112000, 112.85003089904785s
# t=112200, 21.708465099334717s
# t=112400, 21.87057065963745s
# t=112600, 21.658913612365723s
# t=112800, 23.21300506591797s
# t=113000, 22.824462175369263s
# t=113200, 23.684224128723145s
# t=113400, 22.12513518333435s
# t=113600, 22.33505129814148s
# t=113800, 22.589901447296143s
# t=114000, 22.026999950408936s
# t=114200, 21.916012048721313s
# t=114400, 21.82099223136902s
# t=114600, 22.045258283615112s
# t=114800, 21.742939472198486s
# t=115000, 21.744956731796265s
# ...
# ---------------------------------------
# t=160000, 107.93437075614929s
# t=160200, 21.29117178916931s
# t=160400, 21.119522094726562s
# t=160600, 21.487539291381836s
# t=160800, 21.125508069992065s
# t=161000, 21.196348905563354s
# t=161200, 21.33491802215576s
# t=161400, 21.305027961730957s
# t=161600, 21.357887029647827s
# t=161800, 21.205293655395508s
# t=162000, 21.134483337402344s
# t=162200, 21.26114559173584s
# t=162400, 21.308021068572998s
# t=162600, 21.140467405319214s
# t=162800, 21.322978973388672s
# t=163000, 21.360878229141235s
# t=163200, 21.379828691482544s
# t=163400, 21.306024312973022s
# t=163600, 21.365865230560303s
# t=163800, 21.28408455848694s
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             786 |
# |          StdEpRet |            94.5 |
# |          MaxEpRet |             946 |
# |          MinEpRet |             699 |
# |  AverageTestEpRet |             375 |
# |      StdTestEpRet |             429 |
# |      MaxTestEpRet |             987 |
# |      MinTestEpRet |            -211 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             717 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             123 |
# |         StdQ1Vals |            11.4 |
# |         MaxQ1Vals |             151 |
# |         MinQ1Vals |           -29.6 |
# |     AverageQ2Vals |         0.00835 |
# |         StdQ2Vals |         0.00998 |
# |         MaxQ2Vals |          0.0439 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -124 |
# |             LossQ |            2.55 |
# |              Time |            96.4 |
# ---------------------------------------
# t=164000, 96.38226175308228s
# t=164200, 21.264136791229248s
# t=164400, 21.23720932006836s
# t=164600, 21.329960107803345s
# t=164800, 21.427700757980347s
# t=165000, 21.227236032485962s
# t=165200, 21.231226444244385s
# t=165400, 21.328963041305542s
# t=165600, 21.28907012939453s
# t=165800, 21.423709869384766s
# t=166000, 21.29405689239502s
# t=166200, 21.325971603393555s
# t=166400, 21.53142261505127s
# t=166600, 21.2432279586792s
# t=166800, 21.147448778152466s
# t=167000, 21.366862535476685s
# t=167200, 21.212275743484497s
# t=167400, 21.30901789665222s
# t=167600, 21.23621129989624s
# t=167800, 21.20828652381897s
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             542 |
# |          StdEpRet |             325 |
# |          MaxEpRet |             968 |
# |          MinEpRet |            79.9 |
# |  AverageTestEpRet |             592 |
# |      StdTestEpRet |             317 |
# |      MaxTestEpRet |             893 |
# |      MinTestEpRet |           0.881 |
# |             EpLen |             652 |
# |         TestEpLen |             805 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            11.3 |
# |         MaxQ1Vals |             147 |
# |         MinQ1Vals |           -36.6 |
# |     AverageQ2Vals |         0.00828 |
# |         StdQ2Vals |            0.01 |
# |         MaxQ2Vals |          0.0439 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -122 |
# |             LossQ |            2.15 |
# |              Time |             108 |
# ---------------------------------------
# t=168000, 107.514493227005s
# t=168200, 21.17337918281555s
# t=168400, 21.090601682662964s
# t=168600, 21.11852788925171s
# t=168800, 21.21825861930847s
# t=169000, 21.13448405265808s
# t=169200, 21.197315454483032s
# t=169400, 21.318990230560303s
# t=169600, 21.233220100402832s
# t=169800, 21.486542224884033s
# t=170000, 21.71094298362732s
# t=170200, 21.525437355041504s
# t=170400, 21.415732622146606s
# t=170600, 21.432687044143677s
# t=170800, 21.367368698120117s
# t=171000, 21.747844219207764s
# t=171200, 21.857550621032715s
# t=171400, 21.318989038467407s
# t=171600, 21.457621097564697s
# t=171800, 21.34890913963318s
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             471 |
# |          StdEpRet |             451 |
# |          MaxEpRet |        1.11e+03 |
# |          MinEpRet |           -1.82 |
# |  AverageTestEpRet |             524 |
# |      StdTestEpRet |             609 |
# |      MaxTestEpRet |        1.04e+03 |
# |      MinTestEpRet |       -1.15e+03 |
# |             EpLen |             517 |
# |         TestEpLen |             904 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            10.7 |
# |         MaxQ1Vals |             150 |
# |         MinQ1Vals |           -24.8 |
# |     AverageQ2Vals |         0.00824 |
# |         StdQ2Vals |         0.00998 |
# |         MaxQ2Vals |          0.0439 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -122 |
# |             LossQ |             2.8 |
# |              Time |             117 |
# ---------------------------------------
# t=172000, 117.19560527801514s
# t=172200, 21.274110555648804s
# t=172400, 21.305028915405273s
# t=172600, 21.254162549972534s
# t=172800, 21.29405689239502s
# t=173000, 21.413737773895264s
# t=173200, 21.286078453063965s
# t=173400, 21.469587564468384s
# t=173600, 21.315999031066895s
# t=173800, 21.393789529800415s
# t=174000, 21.29107165336609s
# t=174200, 21.36685585975647s
# t=174400, 21.3299617767334s
# t=174600, 21.418723821640015s
# t=174800, 21.323976516723633s
# t=175000, 21.487540245056152s
# t=175200, 21.37284541130066s
# t=175400, 21.383817195892334s
# t=175600, 21.3429274559021s
# t=175800, 21.41972064971924s
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             824 |
# |          StdEpRet |             277 |
# |          MaxEpRet |        1.03e+03 |
# |          MinEpRet |             346 |
# |  AverageTestEpRet |             786 |
# |      StdTestEpRet |             272 |
# |      MaxTestEpRet |             917 |
# |      MinTestEpRet |           -20.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             122 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |           -30.9 |
# |     AverageQ2Vals |         0.00814 |
# |         StdQ2Vals |         0.00999 |
# |         MaxQ2Vals |          0.0439 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -123 |
# |             LossQ |             3.1 |
# |              Time |             130 |
# ---------------------------------------
# t=176000, 129.9321792125702s
# t=176200, 22.13680338859558s
# t=176400, 21.673043727874756s
# t=176600, 22.724233150482178s
# t=176800, 22.240525722503662s
# t=177000, 23.283737421035767s
# t=177200, 22.016125202178955s
# t=177400, 22.46293306350708s
# t=177600, 22.300365447998047s
# t=177800, 22.01612687110901s
# t=178000, 22.027095794677734s
# t=178200, 21.82663369178772s
# t=178400, 21.649107217788696s
# t=178600, 21.799704790115356s
# t=178800, 22.335736989974976s
# t=179000, 21.683977603912354s
# t=179200, 21.851113080978394s
# t=179400, 21.467592239379883s
# t=179600, 22.588595151901245s
# t=179800, 21.415732383728027s
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             395 |
# |          StdEpRet |             412 |
# |          MaxEpRet |             927 |
# |          MinEpRet |            -283 |
# |  AverageTestEpRet |             134 |
# |      StdTestEpRet |             287 |
# |      MaxTestEpRet |             760 |
# |      MinTestEpRet |            -304 |
# |             EpLen |             772 |
# |         TestEpLen |             808 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             122 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |             151 |
# |         MinQ1Vals |           -38.5 |
# |     AverageQ2Vals |         0.00802 |
# |         StdQ2Vals |            0.01 |
# |         MaxQ2Vals |          0.0421 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -123 |
# |             LossQ |            2.41 |
# |              Time |             106 |
# ---------------------------------------
# t=180000, 105.57368302345276s
# t=180200, 21.182356595993042s
# t=180400, 21.266131162643433s
# t=180600, 21.3189914226532s
# t=180800, 21.256158590316772s
# t=181000, 21.208285570144653s
# t=181200, 21.356889724731445s
# t=181400, 21.338937044143677s
# t=181600, 21.234216690063477s
# t=181800, 21.169389963150024s
# t=182000, 21.196319341659546s
# t=182200, 21.32397723197937s
# t=182400, 21.22025465965271s
# t=182600, 21.302034854888916s
# t=182800, 21.427700519561768s
# t=183000, 21.27211570739746s
# t=183200, 21.441662549972534s
# t=183400, 21.19432234764099s
# t=183600, 21.33694362640381s
# t=183800, 21.43069100379944s
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |             362 |
# |          StdEpRet |             455 |
# |          MaxEpRet |             857 |
# |          MinEpRet |            -346 |
# |  AverageTestEpRet |             696 |
# |      StdTestEpRet |             385 |
# |      MaxTestEpRet |        1.15e+03 |
# |      MinTestEpRet |            57.4 |
# |             EpLen |             821 |
# |         TestEpLen |             866 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             122 |
# |         StdQ1Vals |            10.4 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |           -22.7 |
# |     AverageQ2Vals |         0.00793 |
# |         StdQ2Vals |            0.01 |
# |         MaxQ2Vals |          0.0439 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -123 |
# |             LossQ |            2.28 |
# |              Time |             112 |
# ---------------------------------------
# t=184000, 112.05136132240295s
# t=184200, 21.314002990722656s
# t=184400, 21.10157346725464s
# t=184600, 21.39877724647522s
# t=184800, 21.63314986228943s
# t=185000, 21.460611581802368s
# t=185200, 21.26712942123413s
# t=185400, 21.890462636947632s
# t=185600, 21.544387102127075s
# t=185800, 20.979897022247314s
# t=186000, 21.44516658782959s
# t=186200, 21.636142015457153s
# t=186400, 21.901432991027832s
# t=186600, 21.983214378356934s
# t=186800, 21.483551025390625s
# t=187000, 21.26114320755005s
# t=187200, 21.531423807144165s
# t=187400, 21.25516152381897s
# t=187600, 21.322978734970093s
# t=187800, 21.29206156730652s
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |             523 |
# |          StdEpRet |             336 |
# |          MaxEpRet |             952 |
# |          MinEpRet |             118 |
# |  AverageTestEpRet |             575 |
# |      StdTestEpRet |             486 |
# |      MaxTestEpRet |        1.09e+03 |
# |      MinTestEpRet |            -380 |
# |             EpLen |             723 |
# |         TestEpLen |             908 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |             151 |
# |         MinQ1Vals |           -27.3 |
# |     AverageQ2Vals |         0.00777 |
# |         StdQ2Vals |            0.01 |
# |         MaxQ2Vals |          0.0446 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -122 |
# |             LossQ |            2.46 |
# |              Time |             117 |
# ---------------------------------------
# t=188000, 117.12042427062988s
# t=188200, 21.331955671310425s
# t=188400, 21.25416326522827s
# t=188600, 21.227236032485962s
# t=188800, 21.174376964569092s
# t=189000, 21.322978258132935s
# t=189200, 21.178367137908936s
# t=189400, 21.24917769432068s
# t=189600, 21.24618411064148s
# t=189800, 21.316996335983276s
# t=190000, 21.421716928482056s
# t=190200, 21.332951545715332s
# t=190400, 21.28907084465027s
# t=190600, 21.2711181640625s
# t=190800, 21.38680911064148s
# t=191000, 21.31200909614563s
# t=191200, 21.24618625640869s
# t=191400, 21.328471183776855s
# t=191600, 21.240201473236084s
# t=191800, 21.273113250732422s
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             671 |
# |          StdEpRet |             460 |
# |          MaxEpRet |        1.26e+03 |
# |          MinEpRet |            30.4 |
# |  AverageTestEpRet |             623 |
# |      StdTestEpRet |             316 |
# |      MaxTestEpRet |        1.11e+03 |
# |      MinTestEpRet |             137 |
# |             EpLen |             692 |
# |         TestEpLen |             760 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            11.1 |
# |         MaxQ1Vals |             156 |
# |         MinQ1Vals |           -25.9 |
# |     AverageQ2Vals |         0.00783 |
# |         StdQ2Vals |            0.01 |
# |         MaxQ2Vals |          0.0446 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -122 |
# |             LossQ |            2.22 |
# |              Time |            99.5 |
# ---------------------------------------
# t=192000, 99.54580235481262s
# t=192200, 20.967929124832153s
# t=192400, 21.142462491989136s
# t=192600, 21.048712730407715s
# t=192800, 21.370363235473633s
# t=193000, 21.18734312057495s
# t=193200, 21.40276575088501s
# t=193400, 21.19033455848694s
# t=193600, 21.183353424072266s
# t=193800, 21.167423009872437s
# t=194000, 13.149808168411255s
# t=194200, 13.132909059524536s
# t=194400, 14.149135828018188s
# t=194600, 14.091346502304077s
# t=194800, 13.226629734039307s
# t=195000, 13.053094863891602s
# t=195200, 13.020182132720947s
# t=195400, 12.948381423950195s
# t=195600, 13.23756718635559s
# t=195800, 12.996272802352905s
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             523 |
# |          StdEpRet |             399 |
# |          MaxEpRet |        1.02e+03 |
# |          MinEpRet |            9.46 |
# |  AverageTestEpRet |             956 |
# |      StdTestEpRet |             365 |
# |      MaxTestEpRet |        1.29e+03 |
# |      MinTestEpRet |             155 |
# |             EpLen |             545 |
# |         TestEpLen |             911 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             120 |
# |         StdQ1Vals |            11.1 |
# |         MaxQ1Vals |             157 |
# |         MinQ1Vals |             -28 |
# |     AverageQ2Vals |         0.00783 |
# |         StdQ2Vals |         0.00995 |
# |         MaxQ2Vals |          0.0446 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -121 |
# |             LossQ |            2.79 |
# |              Time |            53.1 |
# ---------------------------------------
# t=196000, 53.0800576210022s
# t=196200, 14.540092706680298s
# t=196400, 15.35157036781311s
# t=196600, 13.747233629226685s
# t=196800, 13.804057359695435s
# t=197000, 15.846656560897827s
# t=197200, 13.6036217212677s
# t=197400, 15.16943097114563s
# t=197600, 16.695370197296143s
# t=197800, 14.242924690246582s
# t=198000, 13.314383745193481s
# t=198200, 13.353318214416504s
# t=198400, 14.695678234100342s
# t=198600, 14.404507398605347s
# t=198800, 13.531908750534058s
# t=199000, 14.1922767162323s
# t=199200, 13.62495231628418s
# t=199400, 13.433043003082275s
# t=199600, 13.175767421722412s
# t=199800, 13.363292694091797s
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |             565 |
# |          StdEpRet |             314 |
# |          MaxEpRet |             910 |
# |          MinEpRet |              35 |
# |  AverageTestEpRet |             660 |
# |      StdTestEpRet |             376 |
# |      MaxTestEpRet |         1.1e+03 |
# |      MinTestEpRet |            81.2 |
# |             EpLen |             809 |
# |         TestEpLen |             867 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             120 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |             159 |
# |         MinQ1Vals |           -30.6 |
# |     AverageQ2Vals |         0.00791 |
# |         StdQ2Vals |         0.00992 |
# |         MaxQ2Vals |          0.0421 |
# |         MinQ2Vals |         -0.0272 |
# |            LossPi |            -121 |
# |             LossQ |            2.34 |
# |              Time |            53.3 |
# ---------------------------------------
