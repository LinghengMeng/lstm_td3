# %% [markdown]
# # Non-stationary

# %%
from copy import deepcopy
import itertools
import numpy as np
import torch
from torch.optim import Adam
import pybulletgym
import gym
import time
import spinup.algos.pytorch.td3.core as core
from spinup.utils.logx import EpochLogger


class ReplayBuffer:
    """
    A simple FIFO experience replay buffer for TD3 agents.
    """

    def __init__(self, obs_dim, act_dim, size):
        self.obs_buf = np.zeros(core.combined_shape(size, obs_dim), dtype=np.float32)
        self.obs2_buf = np.zeros(core.combined_shape(size, obs_dim), dtype=np.float32)
        self.act_buf = np.zeros(core.combined_shape(size, act_dim), dtype=np.float32)
        self.rew_buf = np.zeros(size, dtype=np.float32)
        self.done_buf = np.zeros(size, dtype=np.float32)
        self.ptr, self.size, self.max_size = 0, 0, size

    def store(self, obs, act, rew, next_obs, done):
        self.obs_buf[self.ptr] = obs
        self.obs2_buf[self.ptr] = next_obs
        self.act_buf[self.ptr] = act
        self.rew_buf[self.ptr] = rew
        self.done_buf[self.ptr] = done
        self.ptr = (self.ptr+1) % self.max_size
        self.size = min(self.size+1, self.max_size)

    def sample_batch(self, batch_size=32):
        idxs = np.random.randint(0, self.size, size=batch_size)
        batch = dict(obs=self.obs_buf[idxs],
                     obs2=self.obs2_buf[idxs],
                     act=self.act_buf[idxs],
                     rew=self.rew_buf[idxs],
                     done=self.done_buf[idxs])
        return {k: torch.as_tensor(v, dtype=torch.float32) for k,v in batch.items()}

# %%
class POMDPWrapper(gym.ObservationWrapper):
    def __init__(self, env_name):
        super().__init__(gym.make(env_name))
        
        # Remove velocity info
        # OpenAIGym
        #  1. MuJoCo
        if env_name == "HalfCheetah-v3" or env_name == "HalfCheetah-v2":
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == "Ant-v3" or env_name == "Ant-v2":
            self.remain_obs_idx = list(np.arange(0, 13)) + list(np.arange(27, 111))
        elif env_name == 'Walker2d-v3' or env_name == "Walker2d-v2":
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'Hopper-v3' or env_name == "Hopper-v2":
            self.remain_obs_idx = np.arange(0, 5)
        elif env_name == "InvertedPendulum-v2":
            self.remain_obs_idx = np.arange(0, 2)
        elif env_name == "InvertedDoublePendulum-v2":
            self.remain_obs_idx = list(np.arange(0, 5)) + list(np.arange(8, 11))
        elif env_name == "Swimmer-v3" or env_name == "Swimmer-v2":
            self.remain_obs_idx = np.arange(0, 3)
        elif env_name == "Thrower-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Striker-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Pusher-v2":
            self.remain_obs_idx = list(np.arange(0, 7)) + list(np.arange(14, 23))
        elif env_name == "Reacher-v2":
            self.remain_obs_idx = list(np.arange(0, 6)) + list(np.arange(8, 11))
        elif env_name == 'Humanoid-v3' or env_name == "Humanoid-v2":
            self.remain_obs_idx = list(np.arange(0, 22)) + list(np.arange(45, 185)) + list(np.arange(269, 376))
        elif env_name == 'HumanoidStandup-v2':
            self.remain_obs_idx = list(np.arange(0, 22)) + list(np.arange(45, 185)) + list(np.arange(269, 376))
        # PyBulletGym
        #  1. MuJoCo
        elif env_name == 'HalfCheetahMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'AntMuJoCoEnv-v0':
            self.remain_obs_idx = list(np.arange(0, 13)) + list(np.arange(27, 111))
        elif env_name == 'Walker2DMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 8)
        elif env_name == 'HopperMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 7)
        elif env_name == 'InvertedPendulumMuJoCoEnv-v0':
            self.remain_obs_idx = np.arange(0, 3)
        elif env_name == 'InvertedDoublePendulumMuJoCoEnv-v0':
            self.remain_obs_idx = list(np.arange(0, 5)) + list(np.arange(8, 11))
        #  2. Roboschool
        elif env_name == 'HalfCheetahPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,26)) - set(np.arange(3,6)))
        elif env_name ==  'AntPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,28)) - set(np.arange(3,6)))
        elif env_name == 'Walker2DPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,22)) - set(np.arange(3,6)))
        elif env_name == 'HopperPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,15)) - set(np.arange(3,6)))
        elif env_name == 'InvertedPendulumPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,5)) - set([1,4]))
        elif env_name == 'InvertedDoublePendulumPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,9)) - set([1,5,8]))
        elif env_name == 'ReacherPyBulletEnv-v0':
            self.remain_obs_idx = list(set(np.arange(0,9)) - set([6,8]))
        else:
            raise ValueError('POMDP for {} is not defined!'.format(env_name))
            
        # Redefine observation_space
        obs_low = np.array([-np.inf for i in range(len(self.remain_obs_idx))], dtype="float32")
        obs_high = np.array([np.inf for i in range(len(self.remain_obs_idx))], dtype="float32")
        self.observation_space = gym.spaces.Box(obs_low, obs_high)
        
    def observation(self, obs):
        return obs.flatten()[self.remain_obs_idx]

# %%
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence

# %%
class MLPCritic(nn.Module):
    def __init__(self, obs_dim, act_dim, hidden_sizes=(128, 128)):
        super(MLPCritic, self).__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        
        self.layers = nn.ModuleList()
        layer_size = [obs_dim+act_dim]+list(hidden_sizes) + [1]
        for h in range(len(layer_size)-2):
            self.layers += [nn.Linear(layer_size[h], layer_size[h+1]), nn.ReLU()]
        self.layers += [nn.Linear(layer_size[-2], layer_size[-1]), nn.Identity()]
    
    def forward(self, obs, act):
        cat_input = torch.cat([obs, act], dim=-1)
        x = cat_input
        for layer in self.layers:
            x = layer(x)
        return torch.squeeze(x, -1) # Critical to ensure q has right shape.

class MLPActor(nn.Module):
    def __init__(self, obs_dim, act_dim, act_limit, hidden_sizes=(128, 128)):
        super(MLPActor, self).__init__()
        self.obs_dim = obs_dim
        self.act_dim = act_dim
        self.act_limit = act_limit
        
        self.layers = nn.ModuleList()
        layer_size = [obs_dim]+list(hidden_sizes) + [act_dim]
        for h in range(len(layer_size)-2):
            self.layers += [nn.Linear(layer_size[h], layer_size[h+1]), nn.ReLU()]
        self.layers += [nn.Linear(layer_size[-2], layer_size[-1]), nn.Tanh()]
    
    def forward(self, obs):
        x = obs
        for layer in self.layers:
            x = layer(x)
        return self.act_limit * x

class MLPActorCritic(nn.Module):
    def __init__(self, obs_dim, act_dim, act_limit, hidden_sizes=(128, 128)):
        super(MLPActorCritic, self).__init__()
        self.q1 = MLPCritic(obs_dim, act_dim)
        self.q2 = MLPCritic(obs_dim, act_dim)
        self.pi = MLPActor(obs_dim, act_dim, act_limit=1)
    
    def act(self, obs):
        with torch.no_grad():
            return self.pi(obs).numpy()

# %%
cuda = torch.device('cuda')

# %%
def td3(env_name, actor_critic=core.MLPActorCritic, ac_kwargs=dict(), seed=0, 
        steps_per_epoch=4000, epochs=100, replay_size=int(1e6), gamma=0.99, 
        polyak=0.995, pi_lr=1e-3, q_lr=1e-3, batch_size=100, start_steps=10000, 
        update_after=1000, update_every=50, act_noise=0.1, target_noise=0.2, 
        noise_clip=0.5, policy_delay=2, num_test_episodes=5, max_ep_len=1000, 
        nonstationary_env = True,
        gravity_change_pattern = 'gravity_averagely_equal',
        partially_observable = False,
        logger_kwargs=dict(), save_freq=1):
    """
    Twin Delayed Deep Deterministic Policy Gradient (TD3)


    Args:
        env_fn : A function which creates a copy of the environment.
            The environment must satisfy the OpenAI Gym API.

        actor_critic: The constructor method for a PyTorch Module with an ``act`` 
            method, a ``pi`` module, a ``q1`` module, and a ``q2`` module.
            The ``act`` method and ``pi`` module should accept batches of 
            observations as inputs, and ``q1`` and ``q2`` should accept a batch 
            of observations and a batch of actions as inputs. When called, 
            these should return:

            ===========  ================  ======================================
            Call         Output Shape      Description
            ===========  ================  ======================================
            ``act``      (batch, act_dim)  | Numpy array of actions for each 
                                           | observation.
            ``pi``       (batch, act_dim)  | Tensor containing actions from policy
                                           | given observations.
            ``q1``       (batch,)          | Tensor containing one current estimate
                                           | of Q* for the provided observations
                                           | and actions. (Critical: make sure to
                                           | flatten this!)
            ``q2``       (batch,)          | Tensor containing the other current 
                                           | estimate of Q* for the provided observations
                                           | and actions. (Critical: make sure to
                                           | flatten this!)
            ===========  ================  ======================================

        ac_kwargs (dict): Any kwargs appropriate for the ActorCritic object 
            you provided to TD3.

        seed (int): Seed for random number generators.

        steps_per_epoch (int): Number of steps of interaction (state-action pairs) 
            for the agent and the environment in each epoch.

        epochs (int): Number of epochs to run and train agent.

        replay_size (int): Maximum length of replay buffer.

        gamma (float): Discount factor. (Always between 0 and 1.)

        polyak (float): Interpolation factor in polyak averaging for target 
            networks. Target networks are updated towards main networks 
            according to:

            .. math:: \\theta_{\\text{targ}} \\leftarrow 
                \\rho \\theta_{\\text{targ}} + (1-\\rho) \\theta

            where :math:`\\rho` is polyak. (Always between 0 and 1, usually 
            close to 1.)

        pi_lr (float): Learning rate for policy.

        q_lr (float): Learning rate for Q-networks.

        batch_size (int): Minibatch size for SGD.

        start_steps (int): Number of steps for uniform-random action selection,
            before running real policy. Helps exploration.

        update_after (int): Number of env interactions to collect before
            starting to do gradient descent updates. Ensures replay buffer
            is full enough for useful updates.

        update_every (int): Number of env interactions that should elapse
            between gradient descent updates. Note: Regardless of how long 
            you wait between updates, the ratio of env steps to gradient steps 
            is locked to 1.

        act_noise (float): Stddev for Gaussian exploration noise added to 
            policy at training time. (At test time, no noise is added.)

        target_noise (float): Stddev for smoothing noise added to target 
            policy.

        noise_clip (float): Limit for absolute value of target policy 
            smoothing noise.

        policy_delay (int): Policy will only be updated once every 
            policy_delay times for each update of the Q-networks.

        num_test_episodes (int): Number of episodes to test the deterministic
            policy at the end of each epoch.

        max_ep_len (int): Maximum length of trajectory / episode / rollout.

        logger_kwargs (dict): Keyword args for EpochLogger.

        save_freq (int): How often (in terms of gap between epochs) to save
            the current policy and value function.

    """

    logger = EpochLogger(**logger_kwargs)
    logger.save_config(locals())

    torch.manual_seed(seed)
    np.random.seed(seed)

    # Wrapper environment if using POMDP
    if partially_observable == True:
        env, test_env = POMDPWrapper(env_name), POMDPWrapper(env_name)
    else:
        env, test_env = gym.make(env_name), gym.make(env_name)
    obs_dim = env.observation_space.shape[0]   
    act_dim = env.action_space.shape[0]

    # Action limit for clamping: critically, assumes all dimensions share the same bound!
    act_limit = env.action_space.high[0]

    # Create actor-critic module and target networks
    mlp_c1 = MLPCritic(obs_dim, act_dim)
    mlp_c2 = MLPCritic(obs_dim, act_dim)
    mlp_a = MLPActor(obs_dim, act_dim, act_limit)
    
    mlp_c1_targ = deepcopy(mlp_c1)
    mlp_c2_targ = deepcopy(mlp_c2)
    mlp_a_targ = deepcopy(mlp_a)
    mlp_c1.cuda()
    mlp_c2.cuda()
    mlp_a.cuda()
    mlp_c1_targ.cuda()
    mlp_c2_targ.cuda()
    mlp_a_targ.cuda()

    # Freeze target networks with respect to optimizers (only update via polyak averaging)
    for p in mlp_c1_targ.parameters():
        p.requires_grad = False
    for p in mlp_c2_targ.parameters():
        p.requires_grad = False
    for p in mlp_a_targ.parameters():
        p.requires_grad = False
        
    # List of parameters for both Q-networks (save this for convenience)
    q_params = itertools.chain(mlp_c1.parameters(), mlp_c2.parameters())

    # Experience buffer
    replay_buffer = ReplayBuffer(obs_dim=obs_dim, act_dim=act_dim, size=replay_size)

#     # Count variables (protip: try to get a feel for how different size networks behave!)
#     var_counts = tuple(core.count_vars(module) for module in [ac.pi, ac.q1, ac.q2])
#     logger.log('\nNumber of parameters: \t pi: %d, \t q1: %d, \t q2: %d\n'%var_counts)

    # Set up function for computing TD3 Q-losses
    def compute_loss_q(data):
        o, a, r, o2, d = data['obs'].to(device=cuda), data['act'].to(device=cuda), data['rew'].to(device=cuda), data['obs2'].to(device=cuda), data['done'].to(device=cuda)
        
        q1 = mlp_c1(o, a)
        q2 = mlp_c2(o, a)

        # Bellman backup for Q functions
        with torch.no_grad():
            pi_targ = mlp_a_targ(o2)
            a2 = pi_targ

            # Target Q-values
            q1_pi_targ = mlp_c1_targ(o2, a2)
            q2_pi_targ = mlp_c2_targ(o2, a2)
            q_pi_targ = torch.min(q1_pi_targ, q2_pi_targ)
            backup = r + gamma * (1 - d) * q_pi_targ

        # MSE loss against Bellman backup
        loss_q1 = ((q1 - backup)**2).mean()
        loss_q2 = ((q2 - backup)**2).mean()
        loss_q = loss_q1 + loss_q2

        # Useful info for logging
        loss_info = dict(Q1Vals=q1.detach().cpu().numpy(),
                         Q2Vals=q2.detach().cpu().numpy())

        return loss_q, loss_info

    # Set up function for computing TD3 pi loss
    def compute_loss_pi(data):
        o = data['obs'].to(device=cuda)
        q1_pi = mlp_c1(o, mlp_a(o))
        return -q1_pi.mean()

    # Set up optimizers for policy and q-function
    pi_optimizer = Adam(mlp_a.parameters(), lr=pi_lr)
    q_optimizer = Adam(q_params, lr=q_lr)

#     # Set up model saving
#     logger.setup_pytorch_saver(ac)

    def update(data, timer):
        # First run one gradient descent step for Q1 and Q2
        q_optimizer.zero_grad()
        loss_q, loss_info = compute_loss_q(data)
        loss_q.backward()
        q_optimizer.step()

        # Record things
        logger.store(LossQ=loss_q.item(), **loss_info)

        # Freeze Q-networks so you don't waste computational effort 
        # computing gradients for them during the policy learning step.
        for p in q_params:
            p.requires_grad = False

        # Next run one gradient descent step for pi.
        pi_optimizer.zero_grad()
        loss_pi = compute_loss_pi(data)
        loss_pi.backward()
        pi_optimizer.step()

        # Unfreeze Q-networks so you can optimize it at next DDPG step.
        for p in q_params:
            p.requires_grad = True

        # Record things
        logger.store(LossPi=loss_pi.item())

        # Finally, update target networks by polyak averaging.
        with torch.no_grad():
            for p, p_targ in zip(mlp_a.parameters(), mlp_a_targ.parameters()):
                p_targ.data.mul_(polyak)
                p_targ.data.add_((1 - polyak) * p.data)
            for p, p_targ in zip(mlp_c1.parameters(), mlp_c1_targ.parameters()):
                p_targ.data.mul_(polyak)
                p_targ.data.add_((1 - polyak) * p.data)
            for p, p_targ in zip(mlp_c2.parameters(), mlp_c2_targ.parameters()):
                p_targ.data.mul_(polyak)
                p_targ.data.add_((1 - polyak) * p.data)

    def get_action(o, noise_scale):
        o = torch.tensor(o).view(1, -1).float().to(device=cuda)
        with torch.no_grad():
            a = mlp_a(o)
        a = a.cpu().numpy().flatten()
        a += noise_scale * np.random.randn(act_dim)
        return np.clip(a, -act_limit, act_limit)

    def test_agent():
        for j in range(num_test_episodes):
            o, d, ep_ret, ep_len = test_env.reset(), False, 0, 0
            
            while not(d or (ep_len == max_ep_len)):
                # Take deterministic actions at test time (noise_scale=0)
                o, r, d, _ = test_env.step(get_action(o, 0))
                ep_ret += r
                ep_len += 1
            logger.store(TestEpRet=ep_ret, TestEpLen=ep_len)

    # Prepare for interaction with environment
    total_steps = steps_per_epoch * epochs
    start_time = time.time()
    o, ep_ret, ep_len = env.reset(), 0, 0

    # Main loop: collect experience in env and update/log each epoch
    for t in range(total_steps):
        
        # Until start_steps have elapsed, randomly sample actions
        # from a uniform distribution for better exploration. Afterwards, 
        # use the learned policy (with some noise, via act_noise). 
        if t > start_steps:
            a = get_action(o, act_noise)
        else:
            a = env.action_space.sample()
        
        if nonstationary_env == True:
            gravity_cycle = 1000
            gravity_base = -9.81
            if gravity_change_pattern == 'gravity_averagely_equal':
                gravity = gravity_base * 1 / 2 * (np.cos(2 * np.pi / gravity_cycle * t) + 1) + gravity_base / 2
            elif gravity_change_pattern == 'gravity_averagely_easier':
                gravity = gravity_base * 1 / 2 * (np.cos(2 * np.pi / gravity_cycle * t) + 1)
            elif gravity_change_pattern == 'gravity_averagely_harder':
                gravity = gravity_base * 1 / 2 * (-np.cos(2 * np.pi / gravity_cycle * t) + 1) + gravity_base
            else:
                pass

            if 'PyBulletEnv' in env_name:
                env.env._p.setGravity(0, 0, gravity)
            elif 'Roboschool' in env_name:
                pass
            else:
                env.model.opt.gravity[2] = gravity
        
        # Step the env
        o2, r, d, _ = env.step(a)
            
        ep_ret += r
        ep_len += 1

        # Ignore the "done" signal if it comes from hitting the time
        # horizon (that is, when it's an artificial terminal signal
        # that isn't based on the agent's state)
        d = False if ep_len==max_ep_len else d

        # Store experience to replay buffer
        replay_buffer.store(o, a, r, o2, d)

        # Super critical, easy to overlook step: make sure to update 
        # most recent observation!
        o = o2

        # End of trajectory handling
        if d or (ep_len == max_ep_len):
            logger.store(EpRet=ep_ret, EpLen=ep_len)
            o, ep_ret, ep_len = env.reset(), 0, 0

        # Update handling
        if t >= update_after and t % update_every == 0:
            for j in range(update_every):
                batch = replay_buffer.sample_batch(batch_size)
                update(data=batch, timer=j)

        # End of epoch handling
        if (t+1) % steps_per_epoch == 0:
            epoch = (t+1) // steps_per_epoch

#             # Save model
#             if (epoch % save_freq == 0) or (epoch == epochs):
#                 logger.save_state({'env': env}, None)

            # Test the performance of the deterministic version of the agent.
            test_agent()

            # Log info about epoch
            logger.log_tabular('Epoch', epoch)
            logger.log_tabular('EpRet', with_min_and_max=True)
            logger.log_tabular('TestEpRet', with_min_and_max=True)
            logger.log_tabular('EpLen', average_only=True)
            logger.log_tabular('TestEpLen', average_only=True)
            logger.log_tabular('TotalEnvInteracts', t)
            logger.log_tabular('Q1Vals', with_min_and_max=True)
            logger.log_tabular('Q2Vals', with_min_and_max=True)
            logger.log_tabular('LossPi', average_only=True)
            logger.log_tabular('LossQ', average_only=True)
            logger.log_tabular('Time', time.time()-start_time)
            logger.dump_tabular()

# %%
args = {'env': 'Ant-v2', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'exp_name': 'td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"Ant-v2",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001EFDC0CF2C8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\\\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |             -84 |
# |          StdEpRet |             118 |
# |          MaxEpRet |            14.5 |
# |          MinEpRet |            -356 |
# |  AverageTestEpRet |             484 |
# |      StdTestEpRet |             120 |
# |      MaxTestEpRet |             590 |
# |      MinTestEpRet |             316 |
# |             EpLen |             260 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            3.93 |
# |         StdQ1Vals |            3.34 |
# |         MaxQ1Vals |            18.6 |
# |         MinQ1Vals |           -2.75 |
# |     AverageQ2Vals |            3.93 |
# |         StdQ2Vals |            3.34 |
# |         MaxQ2Vals |            18.7 |
# |         MinQ2Vals |           -2.55 |
# |            LossPi |            -5.5 |
# |             LossQ |           0.487 |
# |              Time |            83.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |           -42.8 |
# |          StdEpRet |            63.8 |
# |          MaxEpRet |              12 |
# |          MinEpRet |            -366 |
# |  AverageTestEpRet |             137 |
# |      StdTestEpRet |            8.63 |
# |      MaxTestEpRet |             152 |
# |      MinTestEpRet |             127 |
# |             EpLen |             145 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            17.6 |
# |         StdQ1Vals |            7.72 |
# |         MaxQ1Vals |            39.3 |
# |         MinQ1Vals |           -8.75 |
# |     AverageQ2Vals |            17.6 |
# |         StdQ2Vals |            7.73 |
# |         MaxQ2Vals |            39.9 |
# |         MinQ2Vals |           -7.58 |
# |            LossPi |           -20.3 |
# |             LossQ |            3.14 |
# |              Time |             199 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |           -40.8 |
# |          StdEpRet |              95 |
# |          MaxEpRet |             119 |
# |          MinEpRet |            -417 |
# |  AverageTestEpRet |             373 |
# |      StdTestEpRet |             190 |
# |      MaxTestEpRet |             522 |
# |      MinTestEpRet |            5.05 |
# |             EpLen |             158 |
# |         TestEpLen |             806 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            26.9 |
# |         StdQ1Vals |            9.44 |
# |         MaxQ1Vals |            46.3 |
# |         MinQ1Vals |           -16.8 |
# |     AverageQ2Vals |            26.9 |
# |         StdQ2Vals |            9.45 |
# |         MaxQ2Vals |              46 |
# |         MinQ2Vals |           -17.8 |
# |            LossPi |           -29.5 |
# |             LossQ |            5.58 |
# |              Time |             322 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             185 |
# |          StdEpRet |             139 |
# |          MaxEpRet |             388 |
# |          MinEpRet |            31.9 |
# |  AverageTestEpRet |             666 |
# |      StdTestEpRet |             116 |
# |      MaxTestEpRet |             750 |
# |      MinTestEpRet |             436 |
# |             EpLen |             822 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            29.9 |
# |         StdQ1Vals |            11.8 |
# |         MaxQ1Vals |            48.9 |
# |         MinQ1Vals |           -35.6 |
# |     AverageQ2Vals |            29.9 |
# |         StdQ2Vals |            11.8 |
# |         MaxQ2Vals |            49.1 |
# |         MinQ2Vals |           -29.9 |
# |            LossPi |             -32 |
# |             LossQ |            4.56 |
# |              Time |             458 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             285 |
# |          StdEpRet |             257 |
# |          MaxEpRet |             632 |
# |          MinEpRet |           -41.4 |
# |  AverageTestEpRet |             608 |
# |      StdTestEpRet |             189 |
# |      MaxTestEpRet |             759 |
# |      MinTestEpRet |             236 |
# |             EpLen |             988 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |              31 |
# |         StdQ1Vals |            12.5 |
# |         MaxQ1Vals |            53.8 |
# |         MinQ1Vals |           -48.5 |
# |     AverageQ2Vals |              31 |
# |         StdQ2Vals |            12.5 |
# |         MaxQ2Vals |            54.2 |
# |         MinQ2Vals |           -41.6 |
# |            LossPi |           -32.9 |
# |             LossQ |             3.4 |
# |              Time |             593 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             467 |
# |          StdEpRet |             211 |
# |          MaxEpRet |             743 |
# |          MinEpRet |             217 |
# |  AverageTestEpRet |             443 |
# |      StdTestEpRet |             434 |
# |      MaxTestEpRet |             749 |
# |      MinTestEpRet |            -416 |
# |             EpLen |             870 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            34.9 |
# |         StdQ1Vals |            12.2 |
# |         MaxQ1Vals |            57.1 |
# |         MinQ1Vals |           -58.3 |
# |     AverageQ2Vals |            34.9 |
# |         StdQ2Vals |            12.2 |
# |         MaxQ2Vals |            57.4 |
# |         MinQ2Vals |           -53.2 |
# |            LossPi |           -36.8 |
# |             LossQ |            3.21 |
# |              Time |             718 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             207 |
# |          StdEpRet |             202 |
# |          MaxEpRet |             429 |
# |          MinEpRet |           -53.7 |
# |  AverageTestEpRet |             517 |
# |      StdTestEpRet |             103 |
# |      MaxTestEpRet |             586 |
# |      MinTestEpRet |             314 |
# |             EpLen |             848 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            38.7 |
# |         StdQ1Vals |              12 |
# |         MaxQ1Vals |            67.6 |
# |         MinQ1Vals |           -51.9 |
# |     AverageQ2Vals |            38.7 |
# |         StdQ2Vals |              12 |
# |         MaxQ2Vals |            67.6 |
# |         MinQ2Vals |           -50.4 |
# |            LossPi |           -40.4 |
# |             LossQ |            3.22 |
# |              Time |             843 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             242 |
# |          StdEpRet |             160 |
# |          MaxEpRet |             528 |
# |          MinEpRet |           -17.9 |
# |  AverageTestEpRet |             499 |
# |      StdTestEpRet |             214 |
# |      MaxTestEpRet |             629 |
# |      MinTestEpRet |            72.4 |
# |             EpLen |             537 |
# |         TestEpLen |             823 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            40.7 |
# |         StdQ1Vals |            12.8 |
# |         MaxQ1Vals |            85.8 |
# |         MinQ1Vals |           -47.2 |
# |     AverageQ2Vals |            40.7 |
# |         StdQ2Vals |            12.8 |
# |         MaxQ2Vals |            86.9 |
# |         MinQ2Vals |           -47.2 |
# |            LossPi |           -42.6 |
# |             LossQ |            3.79 |
# |              Time |             966 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             261 |
# |          StdEpRet |             265 |
# |          MaxEpRet |             566 |
# |          MinEpRet |            -146 |
# |  AverageTestEpRet |             157 |
# |      StdTestEpRet |             980 |
# |      MaxTestEpRet |             663 |
# |      MinTestEpRet |        -1.8e+03 |
# |             EpLen |             750 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |              44 |
# |         StdQ1Vals |            13.7 |
# |         MaxQ1Vals |             112 |
# |         MinQ1Vals |           -37.1 |
# |     AverageQ2Vals |              44 |
# |         StdQ2Vals |            13.7 |
# |         MaxQ2Vals |             112 |
# |         MinQ2Vals |           -28.7 |
# |            LossPi |           -45.9 |
# |             LossQ |            4.42 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             399 |
# |          StdEpRet |             104 |
# |          MaxEpRet |             540 |
# |          MinEpRet |             249 |
# |  AverageTestEpRet |             534 |
# |      StdTestEpRet |             321 |
# |      MaxTestEpRet |             806 |
# |      MinTestEpRet |           0.704 |
# |             EpLen |             792 |
# |         TestEpLen |             712 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            47.4 |
# |         StdQ1Vals |            14.4 |
# |         MaxQ1Vals |             114 |
# |         MinQ1Vals |           -45.8 |
# |     AverageQ2Vals |            47.4 |
# |         StdQ2Vals |            14.4 |
# |         MaxQ2Vals |             114 |
# |         MinQ2Vals |           -41.7 |
# |            LossPi |           -49.3 |
# |             LossQ |             4.6 |
# |              Time |        1.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             664 |
# |          StdEpRet |             128 |
# |          MaxEpRet |             835 |
# |          MinEpRet |             478 |
# |  AverageTestEpRet |             498 |
# |      StdTestEpRet |             236 |
# |      MaxTestEpRet |             676 |
# |      MinTestEpRet |            31.8 |
# |             EpLen |             910 |
# |         TestEpLen |             811 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            49.7 |
# |         StdQ1Vals |            15.8 |
# |         MaxQ1Vals |             110 |
# |         MinQ1Vals |           -44.4 |
# |     AverageQ2Vals |            49.7 |
# |         StdQ2Vals |            15.8 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |           -50.3 |
# |            LossPi |           -51.7 |
# |             LossQ |            4.52 |
# |              Time |        1.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             260 |
# |          StdEpRet |             317 |
# |          MaxEpRet |             711 |
# |          MinEpRet |            -233 |
# |  AverageTestEpRet |             430 |
# |      StdTestEpRet |             291 |
# |      MaxTestEpRet |             883 |
# |      MinTestEpRet |             111 |
# |             EpLen |             865 |
# |         TestEpLen |             823 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            51.6 |
# |         StdQ1Vals |            16.9 |
# |         MaxQ1Vals |             106 |
# |         MinQ1Vals |           -81.3 |
# |     AverageQ2Vals |            51.6 |
# |         StdQ2Vals |            16.9 |
# |         MaxQ2Vals |             109 |
# |         MinQ2Vals |           -85.7 |
# |            LossPi |           -53.6 |
# |             LossQ |            5.12 |
# |              Time |        1.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             285 |
# |          StdEpRet |             403 |
# |          MaxEpRet |             945 |
# |          MinEpRet |            -304 |
# |  AverageTestEpRet |             653 |
# |      StdTestEpRet |             186 |
# |      MaxTestEpRet |             890 |
# |      MinTestEpRet |             428 |
# |             EpLen |             544 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |              53 |
# |         StdQ1Vals |              18 |
# |         MaxQ1Vals |            91.9 |
# |         MinQ1Vals |           -71.1 |
# |     AverageQ2Vals |              53 |
# |         StdQ2Vals |              18 |
# |         MaxQ2Vals |            90.5 |
# |         MinQ2Vals |           -77.8 |
# |            LossPi |             -55 |
# |             LossQ |            5.08 |
# |              Time |        1.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             259 |
# |          StdEpRet |             544 |
# |          MaxEpRet |             903 |
# |          MinEpRet |            -535 |
# |  AverageTestEpRet |             742 |
# |      StdTestEpRet |            40.6 |
# |      MaxTestEpRet |             822 |
# |      MinTestEpRet |             712 |
# |             EpLen |             943 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            55.6 |
# |         StdQ1Vals |            18.4 |
# |         MaxQ1Vals |            92.3 |
# |         MinQ1Vals |           -97.3 |
# |     AverageQ2Vals |            55.6 |
# |         StdQ2Vals |            18.4 |
# |         MaxQ2Vals |            90.1 |
# |         MinQ2Vals |           -93.5 |
# |            LossPi |           -57.7 |
# |             LossQ |            5.26 |
# |              Time |        1.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             676 |
# |          StdEpRet |             232 |
# |          MaxEpRet |             864 |
# |          MinEpRet |             280 |
# |  AverageTestEpRet |             534 |
# |      StdTestEpRet |            89.3 |
# |      MaxTestEpRet |             707 |
# |      MinTestEpRet |             457 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            56.5 |
# |         StdQ1Vals |            20.5 |
# |         MaxQ1Vals |            93.6 |
# |         MinQ1Vals |           -58.1 |
# |     AverageQ2Vals |            56.5 |
# |         StdQ2Vals |            20.5 |
# |         MaxQ2Vals |            90.8 |
# |         MinQ2Vals |           -57.5 |
# |            LossPi |           -58.5 |
# |             LossQ |            5.01 |
# |              Time |        1.83e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             549 |
# |          StdEpRet |             267 |
# |          MaxEpRet |             800 |
# |          MinEpRet |            99.6 |
# |  AverageTestEpRet |             805 |
# |      StdTestEpRet |            48.8 |
# |      MaxTestEpRet |             856 |
# |      MinTestEpRet |             722 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            58.4 |
# |         StdQ1Vals |            22.3 |
# |         MaxQ1Vals |            86.6 |
# |         MinQ1Vals |           -35.7 |
# |     AverageQ2Vals |            58.4 |
# |         StdQ2Vals |            22.3 |
# |         MaxQ2Vals |            85.9 |
# |         MinQ2Vals |             -56 |
# |            LossPi |           -60.3 |
# |             LossQ |            4.68 |
# |              Time |        1.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             339 |
# |          StdEpRet |             332 |
# |          MaxEpRet |             930 |
# |          MinEpRet |            36.8 |
# |  AverageTestEpRet |             795 |
# |      StdTestEpRet |            12.4 |
# |      MaxTestEpRet |             811 |
# |      MinTestEpRet |             774 |
# |             EpLen |             572 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            60.7 |
# |         StdQ1Vals |            23.5 |
# |         MaxQ1Vals |            87.8 |
# |         MinQ1Vals |           -26.8 |
# |     AverageQ2Vals |            60.7 |
# |         StdQ2Vals |            23.5 |
# |         MaxQ2Vals |            87.8 |
# |         MinQ2Vals |             -35 |
# |            LossPi |           -62.5 |
# |             LossQ |            4.96 |
# |              Time |        2.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             296 |
# |          StdEpRet |             513 |
# |          MaxEpRet |             842 |
# |          MinEpRet |            -548 |
# |  AverageTestEpRet |             735 |
# |      StdTestEpRet |            18.2 |
# |      MaxTestEpRet |             760 |
# |      MinTestEpRet |             709 |
# |             EpLen |             817 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            62.6 |
# |         StdQ1Vals |            23.7 |
# |         MaxQ1Vals |              92 |
# |         MinQ1Vals |           -35.2 |
# |     AverageQ2Vals |            62.6 |
# |         StdQ2Vals |            23.7 |
# |         MaxQ2Vals |            91.6 |
# |         MinQ2Vals |           -34.9 |
# |            LossPi |           -64.6 |
# |             LossQ |            5.62 |
# |              Time |        2.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             623 |
# |          StdEpRet |             117 |
# |          MaxEpRet |             721 |
# |          MinEpRet |             424 |
# |  AverageTestEpRet |             820 |
# |      StdTestEpRet |            12.7 |
# |      MaxTestEpRet |             832 |
# |      MinTestEpRet |             796 |
# |             EpLen |             962 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            64.4 |
# |         StdQ1Vals |              24 |
# |         MaxQ1Vals |              92 |
# |         MinQ1Vals |           -44.1 |
# |     AverageQ2Vals |            64.4 |
# |         StdQ2Vals |              24 |
# |         MaxQ2Vals |            92.3 |
# |         MinQ2Vals |           -72.9 |
# |            LossPi |           -66.2 |
# |             LossQ |            5.16 |
# |              Time |        2.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             561 |
# |          StdEpRet |             161 |
# |          MaxEpRet |             862 |
# |          MinEpRet |             399 |
# |  AverageTestEpRet |             828 |
# |      StdTestEpRet |             215 |
# |      MaxTestEpRet |           1e+03 |
# |      MinTestEpRet |             431 |
# |             EpLen |             752 |
# |         TestEpLen |             895 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            64.8 |
# |         StdQ1Vals |            24.5 |
# |         MaxQ1Vals |            92.9 |
# |         MinQ1Vals |             -46 |
# |     AverageQ2Vals |            64.8 |
# |         StdQ2Vals |            24.5 |
# |         MaxQ2Vals |            92.7 |
# |         MinQ2Vals |           -37.2 |
# |            LossPi |           -66.5 |
# |             LossQ |            4.64 |
# |              Time |        2.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             530 |
# |          StdEpRet |             391 |
# |          MaxEpRet |             989 |
# |          MinEpRet |          -0.757 |
# |  AverageTestEpRet |             892 |
# |      StdTestEpRet |             248 |
# |      MaxTestEpRet |        1.13e+03 |
# |      MinTestEpRet |             498 |
# |             EpLen |             836 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            64.9 |
# |         StdQ1Vals |            26.2 |
# |         MaxQ1Vals |            94.5 |
# |         MinQ1Vals |           -37.2 |
# |     AverageQ2Vals |            64.9 |
# |         StdQ2Vals |            26.2 |
# |         MaxQ2Vals |            94.2 |
# |         MinQ2Vals |           -36.6 |
# |            LossPi |           -66.6 |
# |             LossQ |            4.99 |
# |              Time |        2.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             662 |
# |          StdEpRet |             242 |
# |          MaxEpRet |             884 |
# |          MinEpRet |             193 |
# |  AverageTestEpRet |             625 |
# |      StdTestEpRet |             291 |
# |      MaxTestEpRet |             915 |
# |      MinTestEpRet |             102 |
# |             EpLen |             724 |
# |         TestEpLen |             821 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            65.6 |
# |         StdQ1Vals |            28.3 |
# |         MaxQ1Vals |            95.4 |
# |         MinQ1Vals |           -81.7 |
# |     AverageQ2Vals |            65.6 |
# |         StdQ2Vals |            28.3 |
# |         MaxQ2Vals |            95.2 |
# |         MinQ2Vals |             -89 |
# |            LossPi |           -67.3 |
# |             LossQ |             5.7 |
# |              Time |         2.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             269 |
# |          StdEpRet |             295 |
# |          MaxEpRet |             793 |
# |          MinEpRet |           -54.8 |
# |  AverageTestEpRet |             593 |
# |      StdTestEpRet |             317 |
# |      MaxTestEpRet |             961 |
# |      MinTestEpRet |            58.1 |
# |             EpLen |             434 |
# |         TestEpLen |             809 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            67.3 |
# |         StdQ1Vals |            29.2 |
# |         MaxQ1Vals |            95.8 |
# |         MinQ1Vals |           -94.8 |
# |     AverageQ2Vals |            67.3 |
# |         StdQ2Vals |            29.2 |
# |         MaxQ2Vals |            95.4 |
# |         MinQ2Vals |            -108 |
# |            LossPi |             -69 |
# |             LossQ |            5.88 |
# |              Time |        2.83e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             108 |
# |          StdEpRet |             256 |
# |          MaxEpRet |             558 |
# |          MinEpRet |            -454 |
# |  AverageTestEpRet |             520 |
# |      StdTestEpRet |             377 |
# |      MaxTestEpRet |             890 |
# |      MinTestEpRet |              23 |
# |             EpLen |             380 |
# |         TestEpLen |             658 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            67.9 |
# |         StdQ1Vals |            30.7 |
# |         MaxQ1Vals |            98.9 |
# |         MinQ1Vals |           -80.3 |
# |     AverageQ2Vals |            67.9 |
# |         StdQ2Vals |            30.7 |
# |         MaxQ2Vals |            98.5 |
# |         MinQ2Vals |           -75.4 |
# |            LossPi |           -69.6 |
# |             LossQ |            6.94 |
# |              Time |        2.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             233 |
# |          StdEpRet |             160 |
# |          MaxEpRet |             491 |
# |          MinEpRet |              51 |
# |  AverageTestEpRet |             334 |
# |      StdTestEpRet |              37 |
# |      MaxTestEpRet |             399 |
# |      MinTestEpRet |             284 |
# |             EpLen |             449 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            68.9 |
# |         StdQ1Vals |            30.6 |
# |         MaxQ1Vals |             100 |
# |         MinQ1Vals |             -67 |
# |     AverageQ2Vals |            68.9 |
# |         StdQ2Vals |            30.6 |
# |         MaxQ2Vals |            99.3 |
# |         MinQ2Vals |           -81.9 |
# |            LossPi |           -70.6 |
# |             LossQ |            6.85 |
# |              Time |        3.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             110 |
# |          StdEpRet |             199 |
# |          MaxEpRet |             492 |
# |          MinEpRet |            -197 |
# |  AverageTestEpRet |             252 |
# |      StdTestEpRet |             333 |
# |      MaxTestEpRet |             870 |
# |      MinTestEpRet |           -94.3 |
# |             EpLen |             605 |
# |         TestEpLen |             717 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            69.3 |
# |         StdQ1Vals |            29.9 |
# |         MaxQ1Vals |             102 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |            69.3 |
# |         StdQ2Vals |            29.9 |
# |         MaxQ2Vals |             101 |
# |         MinQ2Vals |            -119 |
# |            LossPi |           -71.1 |
# |             LossQ |            6.95 |
# |              Time |        3.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             419 |
# |          StdEpRet |             336 |
# |          MaxEpRet |             805 |
# |          MinEpRet |           -21.8 |
# |  AverageTestEpRet |             431 |
# |      StdTestEpRet |             296 |
# |      MaxTestEpRet |             945 |
# |      MinTestEpRet |             133 |
# |             EpLen |             759 |
# |         TestEpLen |             532 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            69.1 |
# |         StdQ1Vals |            30.7 |
# |         MaxQ1Vals |             102 |
# |         MinQ1Vals |           -66.1 |
# |     AverageQ2Vals |            69.1 |
# |         StdQ2Vals |            30.7 |
# |         MaxQ2Vals |             102 |
# |         MinQ2Vals |           -65.8 |
# |            LossPi |           -70.8 |
# |             LossQ |            6.83 |
# |              Time |        3.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             198 |
# |          StdEpRet |             447 |
# |          MaxEpRet |             743 |
# |          MinEpRet |            -756 |
# |  AverageTestEpRet |             410 |
# |      StdTestEpRet |             297 |
# |      MaxTestEpRet |             918 |
# |      MinTestEpRet |            54.1 |
# |             EpLen |             554 |
# |         TestEpLen |             446 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            68.5 |
# |         StdQ1Vals |            30.7 |
# |         MaxQ1Vals |             102 |
# |         MinQ1Vals |           -87.8 |
# |     AverageQ2Vals |            68.5 |
# |         StdQ2Vals |            30.7 |
# |         MaxQ2Vals |             102 |
# |         MinQ2Vals |           -88.1 |
# |            LossPi |           -70.4 |
# |             LossQ |            7.56 |
# |              Time |        3.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             167 |
# |          StdEpRet |             345 |
# |          MaxEpRet |             882 |
# |          MinEpRet |            -329 |
# |  AverageTestEpRet |            -115 |
# |      StdTestEpRet |             432 |
# |      MaxTestEpRet |             345 |
# |      MinTestEpRet |            -891 |
# |             EpLen |             528 |
# |         TestEpLen |             510 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |              67 |
# |         StdQ1Vals |            31.8 |
# |         MaxQ1Vals |             102 |
# |         MinQ1Vals |           -96.4 |
# |     AverageQ2Vals |              67 |
# |         StdQ2Vals |            31.8 |
# |         MaxQ2Vals |             102 |
# |         MinQ2Vals |           -92.2 |
# |            LossPi |           -68.9 |
# |             LossQ |            7.69 |
# |              Time |        3.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             241 |
# |          StdEpRet |             519 |
# |          MaxEpRet |             637 |
# |          MinEpRet |            -809 |
# |  AverageTestEpRet |             115 |
# |      StdTestEpRet |             298 |
# |      MaxTestEpRet |             432 |
# |      MinTestEpRet |            -406 |
# |             EpLen |             759 |
# |         TestEpLen |             451 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            63.8 |
# |         StdQ1Vals |            33.9 |
# |         MaxQ1Vals |            99.7 |
# |         MinQ1Vals |            -118 |
# |     AverageQ2Vals |            63.8 |
# |         StdQ2Vals |            33.9 |
# |         MaxQ2Vals |            99.9 |
# |         MinQ2Vals |            -124 |
# |            LossPi |           -65.7 |
# |             LossQ |            8.59 |
# |              Time |        3.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             212 |
# |          StdEpRet |             572 |
# |          MaxEpRet |             879 |
# |          MinEpRet |            -616 |
# |  AverageTestEpRet |             722 |
# |      StdTestEpRet |            32.2 |
# |      MaxTestEpRet |             773 |
# |      MinTestEpRet |             675 |
# |             EpLen |             984 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |              62 |
# |         StdQ1Vals |            35.5 |
# |         MaxQ1Vals |            99.4 |
# |         MinQ1Vals |            -120 |
# |     AverageQ2Vals |              62 |
# |         StdQ2Vals |            35.5 |
# |         MaxQ2Vals |            98.8 |
# |         MinQ2Vals |            -108 |
# |            LossPi |           -64.1 |
# |             LossQ |            9.11 |
# |              Time |         3.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             114 |
# |          StdEpRet |             313 |
# |          MaxEpRet |             735 |
# |          MinEpRet |            -470 |
# |  AverageTestEpRet |             751 |
# |      StdTestEpRet |             195 |
# |      MaxTestEpRet |             871 |
# |      MinTestEpRet |             363 |
# |             EpLen |             420 |
# |         TestEpLen |             882 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            60.6 |
# |         StdQ1Vals |            34.4 |
# |         MaxQ1Vals |            96.3 |
# |         MinQ1Vals |            -127 |
# |     AverageQ2Vals |            60.6 |
# |         StdQ2Vals |            34.4 |
# |         MaxQ2Vals |            95.4 |
# |         MinQ2Vals |            -126 |
# |            LossPi |           -63.2 |
# |             LossQ |            10.3 |
# |              Time |        3.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             601 |
# |          StdEpRet |            44.1 |
# |          MaxEpRet |             654 |
# |          MinEpRet |             545 |
# |  AverageTestEpRet |           -75.3 |
# |      StdTestEpRet |             660 |
# |      MaxTestEpRet |             771 |
# |      MinTestEpRet |       -1.22e+03 |
# |             EpLen |             927 |
# |         TestEpLen |             819 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            62.3 |
# |         StdQ1Vals |            32.6 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |           -59.1 |
# |     AverageQ2Vals |            62.3 |
# |         StdQ2Vals |            32.6 |
# |         MaxQ2Vals |             149 |
# |         MinQ2Vals |             -64 |
# |            LossPi |           -64.9 |
# |             LossQ |            10.9 |
# |              Time |        4.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            40.9 |
# |          StdEpRet |            89.5 |
# |          MaxEpRet |             149 |
# |          MinEpRet |            -122 |
# |  AverageTestEpRet |           -28.2 |
# |      StdTestEpRet |             389 |
# |      MaxTestEpRet |             309 |
# |      MinTestEpRet |            -769 |
# |             EpLen |             411 |
# |         TestEpLen |             621 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |            64.3 |
# |         StdQ1Vals |            35.2 |
# |         MaxQ1Vals |             174 |
# |         MinQ1Vals |            -103 |
# |     AverageQ2Vals |            64.3 |
# |         StdQ2Vals |            35.3 |
# |         MaxQ2Vals |             177 |
# |         MinQ2Vals |            -111 |
# |            LossPi |             -67 |
# |             LossQ |            12.6 |
# |              Time |        4.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             161 |
# |          StdEpRet |             300 |
# |          MaxEpRet |             704 |
# |          MinEpRet |            -205 |
# |  AverageTestEpRet |             165 |
# |      StdTestEpRet |            73.3 |
# |      MaxTestEpRet |             235 |
# |      MinTestEpRet |            24.1 |
# |             EpLen |             427 |
# |         TestEpLen |             809 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            63.3 |
# |         StdQ1Vals |            36.9 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |            63.3 |
# |         StdQ2Vals |            36.9 |
# |         MaxQ2Vals |             176 |
# |         MinQ2Vals |            -119 |
# |            LossPi |           -65.7 |
# |             LossQ |            13.1 |
# |              Time |         4.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            30.3 |
# |          StdEpRet |             288 |
# |          MaxEpRet |             534 |
# |          MinEpRet |            -794 |
# |  AverageTestEpRet |             207 |
# |      StdTestEpRet |            99.8 |
# |      MaxTestEpRet |             312 |
# |      MinTestEpRet |            33.8 |
# |             EpLen |             355 |
# |         TestEpLen |             806 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |            61.9 |
# |         StdQ1Vals |            36.6 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |            61.9 |
# |         StdQ2Vals |            36.6 |
# |         MaxQ2Vals |             170 |
# |         MinQ2Vals |           -99.9 |
# |            LossPi |             -64 |
# |             LossQ |            12.4 |
# |              Time |        4.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -263 |
# |          StdEpRet |             628 |
# |          MaxEpRet |             249 |
# |          MinEpRet |       -1.23e+03 |
# |  AverageTestEpRet |             174 |
# |      StdTestEpRet |             322 |
# |      MaxTestEpRet |             654 |
# |      MinTestEpRet |            -228 |
# |             EpLen |             651 |
# |         TestEpLen |             628 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            59.6 |
# |         StdQ1Vals |              39 |
# |         MaxQ1Vals |             148 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |            59.6 |
# |         StdQ2Vals |              39 |
# |         MaxQ2Vals |             150 |
# |         MinQ2Vals |            -107 |
# |            LossPi |           -61.8 |
# |             LossQ |            11.8 |
# |              Time |        4.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            50.5 |
# |          StdEpRet |             187 |
# |          MaxEpRet |             529 |
# |          MinEpRet |            -280 |
# |  AverageTestEpRet |             135 |
# |      StdTestEpRet |             154 |
# |      MaxTestEpRet |             372 |
# |      MinTestEpRet |           -10.2 |
# |             EpLen |             241 |
# |         TestEpLen |             446 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |              56 |
# |         StdQ1Vals |            39.7 |
# |         MaxQ1Vals |             131 |
# |         MinQ1Vals |            -119 |
# |     AverageQ2Vals |              56 |
# |         StdQ2Vals |            39.7 |
# |         MaxQ2Vals |             133 |
# |         MinQ2Vals |            -121 |
# |            LossPi |           -58.4 |
# |             LossQ |            11.5 |
# |              Time |        4.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |           -15.1 |
# |          StdEpRet |             206 |
# |          MaxEpRet |             236 |
# |          MinEpRet |            -740 |
# |  AverageTestEpRet |            36.4 |
# |      StdTestEpRet |            37.7 |
# |      MaxTestEpRet |            87.4 |
# |      MinTestEpRet |           -20.1 |
# |             EpLen |             207 |
# |         TestEpLen |             445 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |            54.3 |
# |         StdQ1Vals |            39.6 |
# |         MaxQ1Vals |             130 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |            54.3 |
# |         StdQ2Vals |            39.6 |
# |         MaxQ2Vals |             130 |
# |         MinQ2Vals |            -107 |
# |            LossPi |           -56.4 |
# |             LossQ |            11.7 |
# |              Time |        4.78e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -186 |
# |          StdEpRet |             366 |
# |          MaxEpRet |             103 |
# |          MinEpRet |       -1.03e+03 |
# |  AverageTestEpRet |            -230 |
# |      StdTestEpRet |             442 |
# |      MaxTestEpRet |             293 |
# |      MinTestEpRet |            -838 |
# |             EpLen |             462 |
# |         TestEpLen |             654 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |            49.9 |
# |         StdQ1Vals |            40.5 |
# |         MaxQ1Vals |             121 |
# |         MinQ1Vals |           -91.3 |
# |     AverageQ2Vals |            49.9 |
# |         StdQ2Vals |            40.5 |
# |         MaxQ2Vals |             122 |
# |         MinQ2Vals |            -109 |
# |            LossPi |           -51.9 |
# |             LossQ |            12.5 |
# |              Time |         4.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            72.6 |
# |          StdEpRet |             293 |
# |          MaxEpRet |             893 |
# |          MinEpRet |            -464 |
# |  AverageTestEpRet |             675 |
# |      StdTestEpRet |             329 |
# |      MaxTestEpRet |             897 |
# |      MinTestEpRet |            19.3 |
# |             EpLen |             298 |
# |         TestEpLen |             805 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |            47.4 |
# |         StdQ1Vals |            40.7 |
# |         MaxQ1Vals |             105 |
# |         MinQ1Vals |           -90.8 |
# |     AverageQ2Vals |            47.4 |
# |         StdQ2Vals |            40.7 |
# |         MaxQ2Vals |             105 |
# |         MinQ2Vals |           -92.2 |
# |            LossPi |           -49.3 |
# |             LossQ |              12 |
# |              Time |        5.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             359 |
# |          StdEpRet |             260 |
# |          MaxEpRet |             678 |
# |          MinEpRet |           -6.46 |
# |  AverageTestEpRet |             336 |
# |      StdTestEpRet |             150 |
# |      MaxTestEpRet |             495 |
# |      MinTestEpRet |            55.9 |
# |             EpLen |             551 |
# |         TestEpLen |             766 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |            47.9 |
# |         StdQ1Vals |            39.7 |
# |         MaxQ1Vals |            92.7 |
# |         MinQ1Vals |             -93 |
# |     AverageQ2Vals |            47.9 |
# |         StdQ2Vals |            39.7 |
# |         MaxQ2Vals |            92.1 |
# |         MinQ2Vals |            -100 |
# |            LossPi |           -49.7 |
# |             LossQ |            11.5 |
# |              Time |        5.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             198 |
# |          StdEpRet |             173 |
# |          MaxEpRet |             475 |
# |          MinEpRet |            29.9 |
# |  AverageTestEpRet |             145 |
# |      StdTestEpRet |             144 |
# |      MaxTestEpRet |             421 |
# |      MinTestEpRet |            30.3 |
# |             EpLen |             508 |
# |         TestEpLen |             536 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |            49.2 |
# |         StdQ1Vals |            38.2 |
# |         MaxQ1Vals |            88.8 |
# |         MinQ1Vals |            -112 |
# |     AverageQ2Vals |            49.2 |
# |         StdQ2Vals |            38.2 |
# |         MaxQ2Vals |              88 |
# |         MinQ2Vals |            -108 |
# |            LossPi |           -50.9 |
# |             LossQ |            10.2 |
# |              Time |        5.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            65.4 |
# |          StdEpRet |             264 |
# |          MaxEpRet |             712 |
# |          MinEpRet |            -397 |
# |  AverageTestEpRet |           -5.19 |
# |      StdTestEpRet |             299 |
# |      MaxTestEpRet |             355 |
# |      MinTestEpRet |            -526 |
# |             EpLen |             354 |
# |         TestEpLen |             523 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |            49.8 |
# |         StdQ1Vals |            38.2 |
# |         MaxQ1Vals |            90.1 |
# |         MinQ1Vals |           -83.7 |
# |     AverageQ2Vals |            49.8 |
# |         StdQ2Vals |            38.2 |
# |         MaxQ2Vals |            89.1 |
# |         MinQ2Vals |           -79.2 |
# |            LossPi |           -51.5 |
# |             LossQ |            9.77 |
# |              Time |         5.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             161 |
# |          StdEpRet |             232 |
# |          MaxEpRet |             659 |
# |          MinEpRet |           -51.5 |
# |  AverageTestEpRet |             270 |
# |      StdTestEpRet |             189 |
# |      MaxTestEpRet |             462 |
# |      MinTestEpRet |            20.3 |
# |             EpLen |             502 |
# |         TestEpLen |             627 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |            48.4 |
# |         StdQ1Vals |              39 |
# |         MaxQ1Vals |            89.2 |
# |         MinQ1Vals |           -80.8 |
# |     AverageQ2Vals |            48.4 |
# |         StdQ2Vals |              39 |
# |         MaxQ2Vals |            89.1 |
# |         MinQ2Vals |           -82.2 |
# |            LossPi |           -50.3 |
# |             LossQ |            9.74 |
# |              Time |        5.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |           -56.1 |
# |          StdEpRet |             384 |
# |          MaxEpRet |             245 |
# |          MinEpRet |            -942 |
# |  AverageTestEpRet |             597 |
# |      StdTestEpRet |             186 |
# |      MaxTestEpRet |             741 |
# |      MinTestEpRet |             234 |
# |             EpLen |             586 |
# |         TestEpLen |             883 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |            47.6 |
# |         StdQ1Vals |            39.6 |
# |         MaxQ1Vals |              88 |
# |         MinQ1Vals |           -80.8 |
# |     AverageQ2Vals |            47.6 |
# |         StdQ2Vals |            39.6 |
# |         MaxQ2Vals |            88.6 |
# |         MinQ2Vals |           -81.4 |
# |            LossPi |           -49.6 |
# |             LossQ |            11.1 |
# |              Time |        5.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |              42 |
# |          StdEpRet |             499 |
# |          MaxEpRet |             762 |
# |          MinEpRet |            -998 |
# |  AverageTestEpRet |             112 |
# |      StdTestEpRet |             160 |
# |      MaxTestEpRet |             415 |
# |      MinTestEpRet |           -9.64 |
# |             EpLen |             570 |
# |         TestEpLen |             277 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |            46.1 |
# |         StdQ1Vals |            41.4 |
# |         MaxQ1Vals |              89 |
# |         MinQ1Vals |           -96.2 |
# |     AverageQ2Vals |            46.1 |
# |         StdQ2Vals |            41.4 |
# |         MaxQ2Vals |            89.4 |
# |         MinQ2Vals |           -98.6 |
# |            LossPi |           -48.1 |
# |             LossQ |            11.6 |
# |              Time |        5.78e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            51.3 |
# |          StdEpRet |              70 |
# |          MaxEpRet |             162 |
# |          MinEpRet |           -98.5 |
# |  AverageTestEpRet |             144 |
# |      StdTestEpRet |             305 |
# |      MaxTestEpRet |             678 |
# |      MinTestEpRet |            -257 |
# |             EpLen |             303 |
# |         TestEpLen |             473 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |            43.4 |
# |         StdQ1Vals |            43.2 |
# |         MaxQ1Vals |            92.3 |
# |         MinQ1Vals |            -104 |
# |     AverageQ2Vals |            43.4 |
# |         StdQ2Vals |            43.2 |
# |         MaxQ2Vals |            92.2 |
# |         MinQ2Vals |            -106 |
# |            LossPi |           -45.5 |
# |             LossQ |            12.4 |
# |              Time |        5.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |           -15.9 |
# |          StdEpRet |             130 |
# |          MaxEpRet |             129 |
# |          MinEpRet |            -289 |
# |  AverageTestEpRet |             679 |
# |      StdTestEpRet |            14.3 |
# |      MaxTestEpRet |             700 |
# |      MinTestEpRet |             658 |
# |             EpLen |             508 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |            40.5 |
# |         StdQ1Vals |            44.7 |
# |         MaxQ1Vals |            91.3 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |            40.5 |
# |         StdQ2Vals |            44.7 |
# |         MaxQ2Vals |            91.3 |
# |         MinQ2Vals |            -102 |
# |            LossPi |           -42.6 |
# |             LossQ |            13.3 |
# |              Time |        6.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -133 |
# |          StdEpRet |             484 |
# |          MaxEpRet |             147 |
# |          MinEpRet |       -1.31e+03 |
# |  AverageTestEpRet |            -523 |
# |      StdTestEpRet |             271 |
# |      MaxTestEpRet |            5.46 |
# |      MinTestEpRet |            -729 |
# |             EpLen |             433 |
# |         TestEpLen |             822 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |              37 |
# |         StdQ1Vals |            45.7 |
# |         MaxQ1Vals |            88.9 |
# |         MinQ1Vals |            -113 |
# |     AverageQ2Vals |              37 |
# |         StdQ2Vals |            45.7 |
# |         MaxQ2Vals |            89.2 |
# |         MinQ2Vals |            -114 |
# |            LossPi |           -39.4 |
# |             LossQ |            14.4 |
# |              Time |        6.17e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'exp_name': 'td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x000001EFDC067188>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True\\\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -336 |
# |          StdEpRet |            75.1 |
# |          MaxEpRet |            -243 |
# |          MinEpRet |            -445 |
# |  AverageTestEpRet |            -318 |
# |      StdTestEpRet |            3.27 |
# |      MaxTestEpRet |            -314 |
# |      MinTestEpRet |            -323 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            1.97 |
# |         StdQ1Vals |            2.41 |
# |         MaxQ1Vals |            10.8 |
# |         MinQ1Vals |           -2.22 |
# |     AverageQ2Vals |            1.97 |
# |         StdQ2Vals |            2.41 |
# |         MaxQ2Vals |            10.6 |
# |         MinQ2Vals |           -2.14 |
# |            LossPi |           -3.06 |
# |             LossQ |            0.27 |
# |              Time |            78.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -356 |
# |          StdEpRet |            79.9 |
# |          MaxEpRet |            -230 |
# |          MinEpRet |            -443 |
# |  AverageTestEpRet |            -599 |
# |      StdTestEpRet |            1.06 |
# |      MaxTestEpRet |            -598 |
# |      MinTestEpRet |            -601 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            8.42 |
# |         StdQ1Vals |            1.65 |
# |         MaxQ1Vals |            14.2 |
# |         MinQ1Vals |            1.96 |
# |     AverageQ2Vals |            8.42 |
# |         StdQ2Vals |            1.65 |
# |         MaxQ2Vals |            14.2 |
# |         MinQ2Vals |            2.08 |
# |            LossPi |           -9.41 |
# |             LossQ |           0.421 |
# |              Time |             196 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -296 |
# |          StdEpRet |             121 |
# |          MaxEpRet |            -113 |
# |          MinEpRet |            -434 |
# |  AverageTestEpRet |            -238 |
# |      StdTestEpRet |           0.628 |
# |      MaxTestEpRet |            -237 |
# |      MinTestEpRet |            -239 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            11.6 |
# |         StdQ1Vals |            1.51 |
# |         MaxQ1Vals |              17 |
# |         MinQ1Vals |            5.43 |
# |     AverageQ2Vals |            11.6 |
# |         StdQ2Vals |            1.51 |
# |         MaxQ2Vals |            16.9 |
# |         MinQ2Vals |            5.08 |
# |            LossPi |           -12.4 |
# |             LossQ |           0.473 |
# |              Time |             324 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |             149 |
# |          MaxEpRet |           -4.79 |
# |          MinEpRet |            -423 |
# |  AverageTestEpRet |            -386 |
# |      StdTestEpRet |             332 |
# |      MaxTestEpRet |             278 |
# |      MinTestEpRet |            -570 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            12.7 |
# |         StdQ1Vals |            2.26 |
# |         MaxQ1Vals |            20.9 |
# |         MinQ1Vals |            3.97 |
# |     AverageQ2Vals |            12.7 |
# |         StdQ2Vals |            2.26 |
# |         MaxQ2Vals |            20.6 |
# |         MinQ2Vals |            3.98 |
# |            LossPi |           -13.9 |
# |             LossQ |           0.418 |
# |              Time |             449 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             128 |
# |          StdEpRet |             113 |
# |          MaxEpRet |             292 |
# |          MinEpRet |           -25.6 |
# |  AverageTestEpRet |             213 |
# |      StdTestEpRet |             133 |
# |      MaxTestEpRet |             354 |
# |      MinTestEpRet |            11.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            16.1 |
# |         StdQ1Vals |            5.83 |
# |         MaxQ1Vals |            27.4 |
# |         MinQ1Vals |            2.78 |
# |     AverageQ2Vals |            16.1 |
# |         StdQ2Vals |            5.83 |
# |         MaxQ2Vals |            27.4 |
# |         MinQ2Vals |            2.69 |
# |            LossPi |           -17.1 |
# |             LossQ |            0.41 |
# |              Time |             571 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             383 |
# |          StdEpRet |              48 |
# |          MaxEpRet |             434 |
# |          MinEpRet |             306 |
# |  AverageTestEpRet |             343 |
# |      StdTestEpRet |             222 |
# |      MaxTestEpRet |             560 |
# |      MinTestEpRet |           -33.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            18.6 |
# |         StdQ1Vals |            6.88 |
# |         MaxQ1Vals |            31.4 |
# |         MinQ1Vals |            5.09 |
# |     AverageQ2Vals |            18.6 |
# |         StdQ2Vals |            6.88 |
# |         MaxQ2Vals |            31.3 |
# |         MinQ2Vals |            5.09 |
# |            LossPi |           -19.5 |
# |             LossQ |           0.407 |
# |              Time |             691 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             372 |
# |          StdEpRet |             117 |
# |          MaxEpRet |             481 |
# |          MinEpRet |             176 |
# |  AverageTestEpRet |             620 |
# |      StdTestEpRet |              92 |
# |      MaxTestEpRet |             799 |
# |      MinTestEpRet |             544 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            21.6 |
# |         StdQ1Vals |            5.96 |
# |         MaxQ1Vals |            34.1 |
# |         MinQ1Vals |            7.46 |
# |     AverageQ2Vals |            21.6 |
# |         StdQ2Vals |            5.96 |
# |         MaxQ2Vals |            33.6 |
# |         MinQ2Vals |            8.06 |
# |            LossPi |           -22.4 |
# |             LossQ |           0.385 |
# |              Time |             815 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             178 |
# |          StdEpRet |             441 |
# |          MaxEpRet |             617 |
# |          MinEpRet |            -467 |
# |  AverageTestEpRet |            64.5 |
# |      StdTestEpRet |             199 |
# |      MaxTestEpRet |             359 |
# |      MinTestEpRet |            -150 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |              26 |
# |         StdQ1Vals |            4.67 |
# |         MaxQ1Vals |            38.1 |
# |         MinQ1Vals |            12.8 |
# |     AverageQ2Vals |              26 |
# |         StdQ2Vals |            4.67 |
# |         MaxQ2Vals |            37.3 |
# |         MinQ2Vals |            12.8 |
# |            LossPi |           -26.8 |
# |             LossQ |           0.418 |
# |              Time |             936 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             395 |
# |          StdEpRet |             196 |
# |          MaxEpRet |             578 |
# |          MinEpRet |            89.2 |
# |  AverageTestEpRet |             546 |
# |      StdTestEpRet |            30.6 |
# |      MaxTestEpRet |             588 |
# |      MinTestEpRet |             508 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |              30 |
# |         StdQ1Vals |            5.34 |
# |         MaxQ1Vals |            43.1 |
# |         MinQ1Vals |            18.8 |
# |     AverageQ2Vals |              30 |
# |         StdQ2Vals |            5.34 |
# |         MaxQ2Vals |            42.8 |
# |         MinQ2Vals |            18.8 |
# |            LossPi |           -30.8 |
# |             LossQ |           0.432 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             289 |
# |          StdEpRet |             432 |
# |          MaxEpRet |             665 |
# |          MinEpRet |            -445 |
# |  AverageTestEpRet |             199 |
# |      StdTestEpRet |             398 |
# |      MaxTestEpRet |             551 |
# |      MinTestEpRet |            -295 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            34.9 |
# |         StdQ1Vals |            5.89 |
# |         MaxQ1Vals |            47.4 |
# |         MinQ1Vals |            21.6 |
# |     AverageQ2Vals |            34.9 |
# |         StdQ2Vals |            5.89 |
# |         MaxQ2Vals |            47.6 |
# |         MinQ2Vals |            21.7 |
# |            LossPi |           -35.8 |
# |             LossQ |           0.414 |
# |              Time |        1.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             474 |
# |          StdEpRet |            43.7 |
# |          MaxEpRet |             541 |
# |          MinEpRet |             427 |
# |  AverageTestEpRet |             571 |
# |      StdTestEpRet |            48.7 |
# |      MaxTestEpRet |             662 |
# |      MinTestEpRet |             528 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            39.2 |
# |         StdQ1Vals |            6.34 |
# |         MaxQ1Vals |            53.1 |
# |         MinQ1Vals |            20.4 |
# |     AverageQ2Vals |            39.2 |
# |         StdQ2Vals |            6.34 |
# |         MaxQ2Vals |            52.9 |
# |         MinQ2Vals |            20.6 |
# |            LossPi |             -40 |
# |             LossQ |           0.441 |
# |              Time |         1.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             221 |
# |          StdEpRet |             374 |
# |          MaxEpRet |             673 |
# |          MinEpRet |            -250 |
# |  AverageTestEpRet |             767 |
# |      StdTestEpRet |             126 |
# |      MaxTestEpRet |             931 |
# |      MinTestEpRet |             578 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            42.4 |
# |         StdQ1Vals |            8.14 |
# |         MaxQ1Vals |            59.5 |
# |         MinQ1Vals |            14.4 |
# |     AverageQ2Vals |            42.4 |
# |         StdQ2Vals |            8.14 |
# |         MaxQ2Vals |            59.2 |
# |         MinQ2Vals |            14.7 |
# |            LossPi |           -43.2 |
# |             LossQ |           0.495 |
# |              Time |        1.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             554 |
# |          StdEpRet |            52.3 |
# |          MaxEpRet |             622 |
# |          MinEpRet |             496 |
# |  AverageTestEpRet |             560 |
# |      StdTestEpRet |            47.1 |
# |      MaxTestEpRet |             629 |
# |      MinTestEpRet |             482 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            45.7 |
# |         StdQ1Vals |            9.55 |
# |         MaxQ1Vals |            64.2 |
# |         MinQ1Vals |            14.1 |
# |     AverageQ2Vals |            45.7 |
# |         StdQ2Vals |            9.55 |
# |         MaxQ2Vals |            63.9 |
# |         MinQ2Vals |            14.7 |
# |            LossPi |           -46.5 |
# |             LossQ |           0.525 |
# |              Time |        1.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             534 |
# |          StdEpRet |            54.5 |
# |          MaxEpRet |             585 |
# |          MinEpRet |             447 |
# |  AverageTestEpRet |             734 |
# |      StdTestEpRet |             161 |
# |      MaxTestEpRet |             961 |
# |      MinTestEpRet |             560 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            48.7 |
# |         StdQ1Vals |            10.5 |
# |         MaxQ1Vals |            69.4 |
# |         MinQ1Vals |            17.6 |
# |     AverageQ2Vals |            48.7 |
# |         StdQ2Vals |            10.5 |
# |         MaxQ2Vals |            68.9 |
# |         MinQ2Vals |              18 |
# |            LossPi |           -49.5 |
# |             LossQ |           0.573 |
# |              Time |        1.67e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             544 |
# |          StdEpRet |            57.8 |
# |          MaxEpRet |             610 |
# |          MinEpRet |             462 |
# |  AverageTestEpRet |             508 |
# |      StdTestEpRet |            63.8 |
# |      MaxTestEpRet |             612 |
# |      MinTestEpRet |             435 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            51.3 |
# |         StdQ1Vals |            11.5 |
# |         MaxQ1Vals |            74.9 |
# |         MinQ1Vals |            19.7 |
# |     AverageQ2Vals |            51.3 |
# |         StdQ2Vals |            11.5 |
# |         MaxQ2Vals |            74.6 |
# |         MinQ2Vals |            19.5 |
# |            LossPi |           -52.1 |
# |             LossQ |           0.641 |
# |              Time |         1.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             759 |
# |          StdEpRet |             152 |
# |          MaxEpRet |             908 |
# |          MinEpRet |             546 |
# |  AverageTestEpRet |             994 |
# |      StdTestEpRet |             137 |
# |      MaxTestEpRet |        1.21e+03 |
# |      MinTestEpRet |             811 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            54.4 |
# |         StdQ1Vals |            11.9 |
# |         MaxQ1Vals |            79.6 |
# |         MinQ1Vals |            26.6 |
# |     AverageQ2Vals |            54.4 |
# |         StdQ2Vals |            11.9 |
# |         MaxQ2Vals |            78.9 |
# |         MinQ2Vals |            26.5 |
# |            LossPi |           -55.2 |
# |             LossQ |           0.723 |
# |              Time |        1.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             600 |
# |          StdEpRet |            78.6 |
# |          MaxEpRet |             729 |
# |          MinEpRet |             520 |
# |  AverageTestEpRet |             964 |
# |      StdTestEpRet |             223 |
# |      MaxTestEpRet |        1.18e+03 |
# |      MinTestEpRet |             569 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            57.7 |
# |         StdQ1Vals |            13.6 |
# |         MaxQ1Vals |            86.1 |
# |         MinQ1Vals |            41.5 |
# |     AverageQ2Vals |            57.7 |
# |         StdQ2Vals |            13.6 |
# |         MaxQ2Vals |            85.6 |
# |         MinQ2Vals |            42.1 |
# |            LossPi |           -58.5 |
# |             LossQ |           0.809 |
# |              Time |        2.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             586 |
# |          StdEpRet |            14.4 |
# |          MaxEpRet |             600 |
# |          MinEpRet |             564 |
# |  AverageTestEpRet |        1.47e+03 |
# |      StdTestEpRet |             205 |
# |      MaxTestEpRet |        1.66e+03 |
# |      MinTestEpRet |        1.14e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            60.3 |
# |         StdQ1Vals |            15.7 |
# |         MaxQ1Vals |            91.3 |
# |         MinQ1Vals |            42.8 |
# |     AverageQ2Vals |            60.3 |
# |         StdQ2Vals |            15.7 |
# |         MaxQ2Vals |            91.2 |
# |         MinQ2Vals |            43.1 |
# |            LossPi |           -61.1 |
# |             LossQ |           0.921 |
# |              Time |        2.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             955 |
# |          StdEpRet |             212 |
# |          MaxEpRet |        1.25e+03 |
# |          MinEpRet |             731 |
# |  AverageTestEpRet |             742 |
# |      StdTestEpRet |             229 |
# |      MaxTestEpRet |        1.18e+03 |
# |      MinTestEpRet |             560 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            62.8 |
# |         StdQ1Vals |            17.7 |
# |         MaxQ1Vals |            97.3 |
# |         MinQ1Vals |            43.4 |
# |     AverageQ2Vals |            62.8 |
# |         StdQ2Vals |            17.7 |
# |         MaxQ2Vals |            97.3 |
# |         MinQ2Vals |            43.6 |
# |            LossPi |           -63.6 |
# |             LossQ |             1.1 |
# |              Time |         2.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             782 |
# |          StdEpRet |             143 |
# |          MaxEpRet |             925 |
# |          MinEpRet |             601 |
# |  AverageTestEpRet |         1.7e+03 |
# |      StdTestEpRet |            92.1 |
# |      MaxTestEpRet |        1.81e+03 |
# |      MinTestEpRet |        1.55e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            65.4 |
# |         StdQ1Vals |            19.6 |
# |         MaxQ1Vals |             101 |
# |         MinQ1Vals |            43.5 |
# |     AverageQ2Vals |            65.4 |
# |         StdQ2Vals |            19.6 |
# |         MaxQ2Vals |             101 |
# |         MinQ2Vals |            43.8 |
# |            LossPi |           -66.2 |
# |             LossQ |            1.18 |
# |              Time |        2.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        1.16e+03 |
# |          StdEpRet |             245 |
# |          MaxEpRet |        1.38e+03 |
# |          MinEpRet |             748 |
# |  AverageTestEpRet |        1.43e+03 |
# |      StdTestEpRet |              50 |
# |      MaxTestEpRet |        1.48e+03 |
# |      MinTestEpRet |        1.34e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |              68 |
# |         StdQ1Vals |            21.7 |
# |         MaxQ1Vals |             107 |
# |         MinQ1Vals |            43.6 |
# |     AverageQ2Vals |              68 |
# |         StdQ2Vals |            21.7 |
# |         MaxQ2Vals |             106 |
# |         MinQ2Vals |            43.9 |
# |            LossPi |           -68.8 |
# |             LossQ |            1.31 |
# |              Time |        2.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        1.02e+03 |
# |          StdEpRet |             293 |
# |          MaxEpRet |        1.29e+03 |
# |          MinEpRet |             527 |
# |  AverageTestEpRet |             986 |
# |      StdTestEpRet |             196 |
# |      MaxTestEpRet |         1.2e+03 |
# |      MinTestEpRet |             633 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            71.2 |
# |         StdQ1Vals |            24.4 |
# |         MaxQ1Vals |             112 |
# |         MinQ1Vals |            44.9 |
# |     AverageQ2Vals |            71.2 |
# |         StdQ2Vals |            24.4 |
# |         MaxQ2Vals |             112 |
# |         MinQ2Vals |              45 |
# |            LossPi |           -71.9 |
# |             LossQ |            1.55 |
# |              Time |        2.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        1.07e+03 |
# |          StdEpRet |            50.2 |
# |          MaxEpRet |        1.13e+03 |
# |          MinEpRet |             991 |
# |  AverageTestEpRet |         1.1e+03 |
# |      StdTestEpRet |             270 |
# |      MaxTestEpRet |        1.35e+03 |
# |      MinTestEpRet |             613 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            74.2 |
# |         StdQ1Vals |            26.9 |
# |         MaxQ1Vals |             116 |
# |         MinQ1Vals |            42.5 |
# |     AverageQ2Vals |            74.2 |
# |         StdQ2Vals |            26.9 |
# |         MaxQ2Vals |             116 |
# |         MinQ2Vals |            44.4 |
# |            LossPi |           -74.9 |
# |             LossQ |            1.76 |
# |              Time |        2.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             947 |
# |          StdEpRet |             221 |
# |          MaxEpRet |        1.24e+03 |
# |          MinEpRet |             680 |
# |  AverageTestEpRet |        1.18e+03 |
# |      StdTestEpRet |             304 |
# |      MaxTestEpRet |        1.54e+03 |
# |      MinTestEpRet |             681 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            76.4 |
# |         StdQ1Vals |            29.1 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            38.4 |
# |     AverageQ2Vals |            76.4 |
# |         StdQ2Vals |            29.1 |
# |         MaxQ2Vals |             122 |
# |         MinQ2Vals |            39.4 |
# |            LossPi |           -77.2 |
# |             LossQ |            1.81 |
# |              Time |        2.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             833 |
# |          StdEpRet |             182 |
# |          MaxEpRet |        1.04e+03 |
# |          MinEpRet |             593 |
# |  AverageTestEpRet |        1.16e+03 |
# |      StdTestEpRet |             144 |
# |      MaxTestEpRet |        1.28e+03 |
# |      MinTestEpRet |             888 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            77.8 |
# |         StdQ1Vals |              31 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |            23.2 |
# |     AverageQ2Vals |            77.8 |
# |         StdQ2Vals |              31 |
# |         MaxQ2Vals |             122 |
# |         MinQ2Vals |            24.3 |
# |            LossPi |           -78.5 |
# |             LossQ |            1.97 |
# |              Time |        3.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        1.07e+03 |
# |          StdEpRet |             273 |
# |          MaxEpRet |         1.4e+03 |
# |          MinEpRet |             712 |
# |  AverageTestEpRet |             873 |
# |      StdTestEpRet |            88.1 |
# |      MaxTestEpRet |             981 |
# |      MinTestEpRet |             761 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            79.5 |
# |         StdQ1Vals |            32.5 |
# |         MaxQ1Vals |             125 |
# |         MinQ1Vals |            11.2 |
# |     AverageQ2Vals |            79.5 |
# |         StdQ2Vals |            32.5 |
# |         MaxQ2Vals |             125 |
# |         MinQ2Vals |            12.1 |
# |            LossPi |           -80.2 |
# |             LossQ |            2.01 |
# |              Time |        3.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             958 |
# |          StdEpRet |             258 |
# |          MaxEpRet |        1.29e+03 |
# |          MinEpRet |             582 |
# |  AverageTestEpRet |             901 |
# |      StdTestEpRet |             251 |
# |      MaxTestEpRet |        1.35e+03 |
# |      MinTestEpRet |             653 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            81.3 |
# |         StdQ1Vals |            34.2 |
# |         MaxQ1Vals |             127 |
# |         MinQ1Vals |             4.2 |
# |     AverageQ2Vals |            81.3 |
# |         StdQ2Vals |            34.2 |
# |         MaxQ2Vals |             127 |
# |         MinQ2Vals |            4.49 |
# |            LossPi |             -82 |
# |             LossQ |            2.11 |
# |              Time |        3.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             958 |
# |          StdEpRet |             274 |
# |          MaxEpRet |        1.28e+03 |
# |          MinEpRet |             684 |
# |  AverageTestEpRet |        1.42e+03 |
# |      StdTestEpRet |            52.4 |
# |      MaxTestEpRet |        1.48e+03 |
# |      MinTestEpRet |        1.34e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            82.7 |
# |         StdQ1Vals |            35.5 |
# |         MaxQ1Vals |             128 |
# |         MinQ1Vals |           -9.36 |
# |     AverageQ2Vals |            82.7 |
# |         StdQ2Vals |            35.5 |
# |         MaxQ2Vals |             129 |
# |         MinQ2Vals |           -8.96 |
# |            LossPi |           -83.3 |
# |             LossQ |            2.06 |
# |              Time |        3.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        1.07e+03 |
# |          StdEpRet |             169 |
# |          MaxEpRet |         1.3e+03 |
# |          MinEpRet |             854 |
# |  AverageTestEpRet |        1.41e+03 |
# |      StdTestEpRet |            78.4 |
# |      MaxTestEpRet |        1.55e+03 |
# |      MinTestEpRet |        1.32e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            84.1 |
# |         StdQ1Vals |            36.7 |
# |         MaxQ1Vals |             130 |
# |         MinQ1Vals |           -18.4 |
# |     AverageQ2Vals |            84.1 |
# |         StdQ2Vals |            36.7 |
# |         MaxQ2Vals |             130 |
# |         MinQ2Vals |           -18.6 |
# |            LossPi |           -84.7 |
# |             LossQ |            2.19 |
# |              Time |        3.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        1.13e+03 |
# |          StdEpRet |             139 |
# |          MaxEpRet |        1.27e+03 |
# |          MinEpRet |             912 |
# |  AverageTestEpRet |        1.43e+03 |
# |      StdTestEpRet |             432 |
# |      MaxTestEpRet |        1.83e+03 |
# |      MinTestEpRet |             752 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            85.6 |
# |         StdQ1Vals |            37.4 |
# |         MaxQ1Vals |             132 |
# |         MinQ1Vals |           -20.7 |
# |     AverageQ2Vals |            85.6 |
# |         StdQ2Vals |            37.4 |
# |         MaxQ2Vals |             131 |
# |         MinQ2Vals |           -20.8 |
# |            LossPi |           -86.3 |
# |             LossQ |            2.35 |
# |              Time |        3.74e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             994 |
# |          StdEpRet |             337 |
# |          MaxEpRet |        1.33e+03 |
# |          MinEpRet |             583 |
# |  AverageTestEpRet |        1.37e+03 |
# |      StdTestEpRet |             124 |
# |      MaxTestEpRet |        1.57e+03 |
# |      MinTestEpRet |        1.22e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            87.3 |
# |         StdQ1Vals |            37.7 |
# |         MaxQ1Vals |             133 |
# |         MinQ1Vals |           -12.4 |
# |     AverageQ2Vals |            87.3 |
# |         StdQ2Vals |            37.7 |
# |         MaxQ2Vals |             133 |
# |         MinQ2Vals |           -11.7 |
# |            LossPi |             -88 |
# |             LossQ |            2.44 |
# |              Time |        3.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        1.34e+03 |
# |          StdEpRet |             101 |
# |          MaxEpRet |        1.51e+03 |
# |          MinEpRet |        1.23e+03 |
# |  AverageTestEpRet |        1.52e+03 |
# |      StdTestEpRet |             130 |
# |      MaxTestEpRet |        1.71e+03 |
# |      MinTestEpRet |        1.37e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            88.4 |
# |         StdQ1Vals |              38 |
# |         MaxQ1Vals |             134 |
# |         MinQ1Vals |          -0.817 |
# |     AverageQ2Vals |            88.4 |
# |         StdQ2Vals |              38 |
# |         MaxQ2Vals |             134 |
# |         MinQ2Vals |          -0.487 |
# |            LossPi |           -89.1 |
# |             LossQ |             2.6 |
# |              Time |        3.99e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |        1.31e+03 |
# |          StdEpRet |            77.2 |
# |          MaxEpRet |        1.39e+03 |
# |          MinEpRet |        1.19e+03 |
# |  AverageTestEpRet |        1.77e+03 |
# |      StdTestEpRet |             360 |
# |      MaxTestEpRet |        2.01e+03 |
# |      MinTestEpRet |        1.05e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            90.3 |
# |         StdQ1Vals |            38.3 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |            15.3 |
# |     AverageQ2Vals |            90.3 |
# |         StdQ2Vals |            38.3 |
# |         MaxQ2Vals |             136 |
# |         MinQ2Vals |            15.6 |
# |            LossPi |           -90.9 |
# |             LossQ |            2.78 |
# |              Time |        4.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |        1.27e+03 |
# |          StdEpRet |            62.4 |
# |          MaxEpRet |        1.33e+03 |
# |          MinEpRet |         1.2e+03 |
# |  AverageTestEpRet |        1.08e+03 |
# |      StdTestEpRet |             445 |
# |      MaxTestEpRet |        1.55e+03 |
# |      MinTestEpRet |             540 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |            92.5 |
# |         StdQ1Vals |              39 |
# |         MaxQ1Vals |             138 |
# |         MinQ1Vals |            22.5 |
# |     AverageQ2Vals |            92.5 |
# |         StdQ2Vals |              39 |
# |         MaxQ2Vals |             138 |
# |         MinQ2Vals |            22.6 |
# |            LossPi |           -93.1 |
# |             LossQ |             2.7 |
# |              Time |        4.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |        1.41e+03 |
# |          StdEpRet |             165 |
# |          MaxEpRet |        1.66e+03 |
# |          MinEpRet |        1.24e+03 |
# |  AverageTestEpRet |         1.1e+03 |
# |      StdTestEpRet |             296 |
# |      MaxTestEpRet |        1.51e+03 |
# |      MinTestEpRet |             647 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            94.3 |
# |         StdQ1Vals |            39.6 |
# |         MaxQ1Vals |             139 |
# |         MinQ1Vals |            26.2 |
# |     AverageQ2Vals |            94.3 |
# |         StdQ2Vals |            39.6 |
# |         MaxQ2Vals |             139 |
# |         MinQ2Vals |            26.3 |
# |            LossPi |             -95 |
# |             LossQ |            2.77 |
# |              Time |        4.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |        1.33e+03 |
# |          StdEpRet |            73.9 |
# |          MaxEpRet |        1.42e+03 |
# |          MinEpRet |        1.22e+03 |
# |  AverageTestEpRet |         1.3e+03 |
# |      StdTestEpRet |             345 |
# |      MaxTestEpRet |         1.5e+03 |
# |      MinTestEpRet |             615 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |              96 |
# |         StdQ1Vals |            40.6 |
# |         MaxQ1Vals |             141 |
# |         MinQ1Vals |            40.5 |
# |     AverageQ2Vals |              96 |
# |         StdQ2Vals |            40.6 |
# |         MaxQ2Vals |             142 |
# |         MinQ2Vals |            42.2 |
# |            LossPi |           -96.7 |
# |             LossQ |            3.41 |
# |              Time |        4.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |        1.46e+03 |
# |          StdEpRet |             128 |
# |          MaxEpRet |        1.57e+03 |
# |          MinEpRet |        1.24e+03 |
# |  AverageTestEpRet |             997 |
# |      StdTestEpRet |             350 |
# |      MaxTestEpRet |        1.48e+03 |
# |      MinTestEpRet |             404 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            98.1 |
# |         StdQ1Vals |            41.5 |
# |         MaxQ1Vals |             144 |
# |         MinQ1Vals |            41.6 |
# |     AverageQ2Vals |            98.1 |
# |         StdQ2Vals |            41.5 |
# |         MaxQ2Vals |             144 |
# |         MinQ2Vals |            42.9 |
# |            LossPi |           -98.8 |
# |             LossQ |            3.61 |
# |              Time |        4.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        1.27e+03 |
# |          StdEpRet |             230 |
# |          MaxEpRet |        1.52e+03 |
# |          MinEpRet |             962 |
# |  AverageTestEpRet |        1.39e+03 |
# |      StdTestEpRet |             298 |
# |      MaxTestEpRet |        1.79e+03 |
# |      MinTestEpRet |             914 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             100 |
# |         StdQ1Vals |            42.6 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |            43.6 |
# |     AverageQ2Vals |             100 |
# |         StdQ2Vals |            42.6 |
# |         MaxQ2Vals |             146 |
# |         MinQ2Vals |            43.7 |
# |            LossPi |            -101 |
# |             LossQ |            3.66 |
# |              Time |        4.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        1.25e+03 |
# |          StdEpRet |             231 |
# |          MaxEpRet |        1.53e+03 |
# |          MinEpRet |             899 |
# |  AverageTestEpRet |        1.38e+03 |
# |      StdTestEpRet |             347 |
# |      MaxTestEpRet |        1.64e+03 |
# |      MinTestEpRet |             708 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             102 |
# |         StdQ1Vals |            43.6 |
# |         MaxQ1Vals |             148 |
# |         MinQ1Vals |            44.1 |
# |     AverageQ2Vals |             102 |
# |         StdQ2Vals |            43.6 |
# |         MaxQ2Vals |             148 |
# |         MinQ2Vals |              43 |
# |            LossPi |            -103 |
# |             LossQ |            3.67 |
# |              Time |         4.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        1.55e+03 |
# |          StdEpRet |            57.4 |
# |          MaxEpRet |        1.63e+03 |
# |          MinEpRet |        1.48e+03 |
# |  AverageTestEpRet |        1.78e+03 |
# |      StdTestEpRet |              50 |
# |      MaxTestEpRet |        1.84e+03 |
# |      MinTestEpRet |        1.71e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             104 |
# |         StdQ1Vals |            44.9 |
# |         MaxQ1Vals |             151 |
# |         MinQ1Vals |            41.2 |
# |     AverageQ2Vals |             104 |
# |         StdQ2Vals |            44.9 |
# |         MaxQ2Vals |             151 |
# |         MinQ2Vals |              41 |
# |            LossPi |            -105 |
# |             LossQ |            3.71 |
# |              Time |        5.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        1.18e+03 |
# |          StdEpRet |             441 |
# |          MaxEpRet |        1.53e+03 |
# |          MinEpRet |             425 |
# |  AverageTestEpRet |        1.37e+03 |
# |      StdTestEpRet |             316 |
# |      MaxTestEpRet |        1.66e+03 |
# |      MinTestEpRet |             797 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             105 |
# |         StdQ1Vals |            46.4 |
# |         MaxQ1Vals |             153 |
# |         MinQ1Vals |            24.3 |
# |     AverageQ2Vals |             105 |
# |         StdQ2Vals |            46.4 |
# |         MaxQ2Vals |             153 |
# |         MinQ2Vals |            25.5 |
# |            LossPi |            -106 |
# |             LossQ |            3.98 |
# |              Time |        5.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        1.02e+03 |
# |          StdEpRet |             380 |
# |          MaxEpRet |        1.47e+03 |
# |          MinEpRet |             604 |
# |  AverageTestEpRet |             963 |
# |      StdTestEpRet |             224 |
# |      MaxTestEpRet |        1.38e+03 |
# |      MinTestEpRet |             697 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             106 |
# |         StdQ1Vals |            47.8 |
# |         MaxQ1Vals |             155 |
# |         MinQ1Vals |            14.1 |
# |     AverageQ2Vals |             106 |
# |         StdQ2Vals |            47.8 |
# |         MaxQ2Vals |             155 |
# |         MinQ2Vals |            13.5 |
# |            LossPi |            -107 |
# |             LossQ |            4.28 |
# |              Time |        5.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        1.23e+03 |
# |          StdEpRet |             319 |
# |          MaxEpRet |        1.65e+03 |
# |          MinEpRet |             805 |
# |  AverageTestEpRet |             958 |
# |      StdTestEpRet |             299 |
# |      MaxTestEpRet |        1.49e+03 |
# |      MinTestEpRet |             637 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             107 |
# |         StdQ1Vals |            48.3 |
# |         MaxQ1Vals |             156 |
# |         MinQ1Vals |            13.2 |
# |     AverageQ2Vals |             107 |
# |         StdQ2Vals |            48.3 |
# |         MaxQ2Vals |             156 |
# |         MinQ2Vals |            12.2 |
# |            LossPi |            -108 |
# |             LossQ |            4.44 |
# |              Time |        5.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             946 |
# |          StdEpRet |             340 |
# |          MaxEpRet |        1.34e+03 |
# |          MinEpRet |             561 |
# |  AverageTestEpRet |        1.37e+03 |
# |      StdTestEpRet |             331 |
# |      MaxTestEpRet |        1.78e+03 |
# |      MinTestEpRet |             962 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             108 |
# |         StdQ1Vals |            48.6 |
# |         MaxQ1Vals |             157 |
# |         MinQ1Vals |            23.4 |
# |     AverageQ2Vals |             108 |
# |         StdQ2Vals |            48.6 |
# |         MaxQ2Vals |             157 |
# |         MinQ2Vals |            23.9 |
# |            LossPi |            -109 |
# |             LossQ |            4.54 |
# |              Time |        5.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        1.29e+03 |
# |          StdEpRet |             269 |
# |          MaxEpRet |        1.49e+03 |
# |          MinEpRet |             827 |
# |  AverageTestEpRet |        1.14e+03 |
# |      StdTestEpRet |             198 |
# |      MaxTestEpRet |        1.34e+03 |
# |      MinTestEpRet |             854 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             109 |
# |         StdQ1Vals |            48.7 |
# |         MaxQ1Vals |             158 |
# |         MinQ1Vals |            32.3 |
# |     AverageQ2Vals |             109 |
# |         StdQ2Vals |            48.7 |
# |         MaxQ2Vals |             158 |
# |         MinQ2Vals |            31.6 |
# |            LossPi |            -110 |
# |             LossQ |            4.65 |
# |              Time |        5.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        1.03e+03 |
# |          StdEpRet |             371 |
# |          MaxEpRet |        1.45e+03 |
# |          MinEpRet |             480 |
# |  AverageTestEpRet |        1.33e+03 |
# |      StdTestEpRet |             504 |
# |      MaxTestEpRet |        1.92e+03 |
# |      MinTestEpRet |             694 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             110 |
# |         StdQ1Vals |              49 |
# |         MaxQ1Vals |             159 |
# |         MinQ1Vals |            27.2 |
# |     AverageQ2Vals |             110 |
# |         StdQ2Vals |              49 |
# |         MaxQ2Vals |             159 |
# |         MinQ2Vals |            27.3 |
# |            LossPi |            -111 |
# |             LossQ |            4.78 |
# |              Time |        5.83e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        1.28e+03 |
# |          StdEpRet |             426 |
# |          MaxEpRet |        1.55e+03 |
# |          MinEpRet |             542 |
# |  AverageTestEpRet |        1.56e+03 |
# |      StdTestEpRet |             150 |
# |      MaxTestEpRet |        1.76e+03 |
# |      MinTestEpRet |        1.31e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             110 |
# |         StdQ1Vals |            49.4 |
# |         MaxQ1Vals |             160 |
# |         MinQ1Vals |            25.5 |
# |     AverageQ2Vals |             110 |
# |         StdQ2Vals |            49.4 |
# |         MaxQ2Vals |             160 |
# |         MinQ2Vals |            24.5 |
# |            LossPi |            -111 |
# |             LossQ |            5.15 |
# |              Time |        5.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        1.15e+03 |
# |          StdEpRet |             351 |
# |          MaxEpRet |         1.6e+03 |
# |          MinEpRet |             787 |
# |  AverageTestEpRet |        1.02e+03 |
# |      StdTestEpRet |             227 |
# |      MaxTestEpRet |         1.3e+03 |
# |      MinTestEpRet |             751 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            49.5 |
# |         MaxQ1Vals |             160 |
# |         MinQ1Vals |            26.8 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            49.5 |
# |         MaxQ2Vals |             160 |
# |         MinQ2Vals |            25.8 |
# |            LossPi |            -112 |
# |             LossQ |            5.34 |
# |              Time |         6.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        1.07e+03 |
# |          StdEpRet |             353 |
# |          MaxEpRet |        1.49e+03 |
# |          MinEpRet |             708 |
# |  AverageTestEpRet |        1.21e+03 |
# |      StdTestEpRet |             334 |
# |      MaxTestEpRet |        1.65e+03 |
# |      MinTestEpRet |             779 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             112 |
# |         StdQ1Vals |            49.5 |
# |         MaxQ1Vals |             161 |
# |         MinQ1Vals |            29.6 |
# |     AverageQ2Vals |             112 |
# |         StdQ2Vals |            49.5 |
# |         MaxQ2Vals |             161 |
# |         MinQ2Vals |            29.2 |
# |            LossPi |            -113 |
# |             LossQ |            5.03 |
# |              Time |        6.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |             642 |
# |          StdEpRet |             118 |
# |          MaxEpRet |             798 |
# |          MinEpRet |             502 |
# |  AverageTestEpRet |        1.52e+03 |
# |      StdTestEpRet |             244 |
# |      MaxTestEpRet |        1.69e+03 |
# |      MinTestEpRet |        1.04e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             112 |
# |         StdQ1Vals |            49.8 |
# |         MaxQ1Vals |             161 |
# |         MinQ1Vals |            25.7 |
# |     AverageQ2Vals |             112 |
# |         StdQ2Vals |            49.8 |
# |         MaxQ2Vals |             161 |
# |         MinQ2Vals |            24.9 |
# |            LossPi |            -112 |
# |             LossQ |            5.02 |
# |              Time |        6.35e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': False,
        'exp_name': 'td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D205A6508>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\\\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	false,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -333 |
# |          StdEpRet |            45.5 |
# |          MaxEpRet |            -264 |
# |          MinEpRet |            -382 |
# |  AverageTestEpRet |            -594 |
# |      StdTestEpRet |            1.69 |
# |      MaxTestEpRet |            -591 |
# |      MinTestEpRet |            -595 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |               2 |
# |         StdQ1Vals |            2.98 |
# |         MaxQ1Vals |            16.3 |
# |         MinQ1Vals |           -9.47 |
# |     AverageQ2Vals |               2 |
# |         StdQ2Vals |            2.97 |
# |         MaxQ2Vals |              17 |
# |         MinQ2Vals |            -9.8 |
# |            LossPi |           -3.04 |
# |             LossQ |            1.06 |
# |              Time |            71.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -296 |
# |          StdEpRet |            18.3 |
# |          MaxEpRet |            -267 |
# |          MinEpRet |            -313 |
# |  AverageTestEpRet |            -591 |
# |      StdTestEpRet |              20 |
# |      MaxTestEpRet |            -551 |
# |      MinTestEpRet |            -605 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            3.65 |
# |         StdQ1Vals |            6.18 |
# |         MaxQ1Vals |              37 |
# |         MinQ1Vals |           -17.6 |
# |     AverageQ2Vals |            3.65 |
# |         StdQ2Vals |            6.18 |
# |         MaxQ2Vals |            37.1 |
# |         MinQ2Vals |           -16.8 |
# |            LossPi |           -5.55 |
# |             LossQ |             3.8 |
# |              Time |             184 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -451 |
# |          StdEpRet |              88 |
# |          MaxEpRet |            -363 |
# |          MinEpRet |            -581 |
# |  AverageTestEpRet |            -587 |
# |      StdTestEpRet |            83.3 |
# |      MaxTestEpRet |            -502 |
# |      MinTestEpRet |            -731 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            49.3 |
# |         StdQ1Vals |            19.2 |
# |         MaxQ1Vals |             107 |
# |         MinQ1Vals |          -0.134 |
# |     AverageQ2Vals |            49.3 |
# |         StdQ2Vals |            19.2 |
# |         MaxQ2Vals |             105 |
# |         MinQ2Vals |          -0.711 |
# |            LossPi |           -54.9 |
# |             LossQ |            11.3 |
# |              Time |             312 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -339 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |            -318 |
# |          MinEpRet |            -374 |
# |  AverageTestEpRet |             218 |
# |      StdTestEpRet |             296 |
# |      MaxTestEpRet |             516 |
# |      MinTestEpRet |            -330 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            72.9 |
# |         StdQ1Vals |            18.9 |
# |         MaxQ1Vals |             127 |
# |         MinQ1Vals |            23.9 |
# |     AverageQ2Vals |            72.9 |
# |         StdQ2Vals |            18.9 |
# |         MaxQ2Vals |             126 |
# |         MinQ2Vals |            24.3 |
# |            LossPi |           -75.7 |
# |             LossQ |              11 |
# |              Time |             455 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             594 |
# |          StdEpRet |             301 |
# |          MaxEpRet |        1.01e+03 |
# |          MinEpRet |             203 |
# |  AverageTestEpRet |             582 |
# |      StdTestEpRet |             233 |
# |      MaxTestEpRet |             871 |
# |      MinTestEpRet |             313 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            66.3 |
# |         StdQ1Vals |            24.5 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |            17.5 |
# |     AverageQ2Vals |            66.3 |
# |         StdQ2Vals |            24.5 |
# |         MaxQ2Vals |             124 |
# |         MinQ2Vals |            15.7 |
# |            LossPi |           -68.1 |
# |             LossQ |            7.14 |
# |              Time |             604 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |        1.23e+03 |
# |          StdEpRet |             400 |
# |          MaxEpRet |         1.9e+03 |
# |          MinEpRet |             894 |
# |  AverageTestEpRet |        1.66e+03 |
# |      StdTestEpRet |            59.3 |
# |      MaxTestEpRet |        1.76e+03 |
# |      MinTestEpRet |        1.61e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            66.9 |
# |         StdQ1Vals |            25.2 |
# |         MaxQ1Vals |             125 |
# |         MinQ1Vals |            14.4 |
# |     AverageQ2Vals |            66.9 |
# |         StdQ2Vals |            25.2 |
# |         MaxQ2Vals |             123 |
# |         MinQ2Vals |            12.1 |
# |            LossPi |           -68.5 |
# |             LossQ |            6.14 |
# |              Time |             725 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |        1.49e+03 |
# |          StdEpRet |        1.02e+03 |
# |          MaxEpRet |        2.14e+03 |
# |          MinEpRet |            -269 |
# |  AverageTestEpRet |         1.7e+03 |
# |      StdTestEpRet |             441 |
# |      MaxTestEpRet |        2.31e+03 |
# |      MinTestEpRet |        1.07e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            69.5 |
# |         StdQ1Vals |            31.3 |
# |         MaxQ1Vals |             143 |
# |         MinQ1Vals |            3.29 |
# |     AverageQ2Vals |            69.5 |
# |         StdQ2Vals |            31.3 |
# |         MaxQ2Vals |             141 |
# |         MinQ2Vals |            4.14 |
# |            LossPi |           -71.2 |
# |             LossQ |            7.78 |
# |              Time |             835 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             876 |
# |          StdEpRet |         1.2e+03 |
# |          MaxEpRet |        2.94e+03 |
# |          MinEpRet |           -15.7 |
# |  AverageTestEpRet |        1.29e+03 |
# |      StdTestEpRet |        1.16e+03 |
# |      MaxTestEpRet |           3e+03 |
# |      MinTestEpRet |           -4.08 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            76.8 |
# |         StdQ1Vals |            41.3 |
# |         MaxQ1Vals |             185 |
# |         MinQ1Vals |           -11.2 |
# |     AverageQ2Vals |            76.8 |
# |         StdQ2Vals |            41.3 |
# |         MaxQ2Vals |             188 |
# |         MinQ2Vals |            -8.8 |
# |            LossPi |           -78.7 |
# |             LossQ |            11.2 |
# |              Time |             944 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |        1.68e+03 |
# |          StdEpRet |        1.17e+03 |
# |          MaxEpRet |        2.75e+03 |
# |          MinEpRet |            -149 |
# |  AverageTestEpRet |        1.67e+03 |
# |      StdTestEpRet |        1.26e+03 |
# |      MaxTestEpRet |        3.02e+03 |
# |      MinTestEpRet |            -267 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            83.9 |
# |         StdQ1Vals |            54.2 |
# |         MaxQ1Vals |             213 |
# |         MinQ1Vals |           -24.7 |
# |     AverageQ2Vals |            83.9 |
# |         StdQ2Vals |            54.2 |
# |         MaxQ2Vals |             214 |
# |         MinQ2Vals |           -21.6 |
# |            LossPi |           -85.9 |
# |             LossQ |            15.4 |
# |              Time |        1.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |        2.51e+03 |
# |          StdEpRet |        1.09e+03 |
# |          MaxEpRet |        3.59e+03 |
# |          MinEpRet |             736 |
# |  AverageTestEpRet |        2.42e+03 |
# |      StdTestEpRet |        1.74e+03 |
# |      MaxTestEpRet |        4.05e+03 |
# |      MinTestEpRet |             276 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            97.3 |
# |         StdQ1Vals |            67.1 |
# |         MaxQ1Vals |             250 |
# |         MinQ1Vals |           -35.1 |
# |     AverageQ2Vals |            97.3 |
# |         StdQ2Vals |            67.1 |
# |         MaxQ2Vals |             252 |
# |         MinQ2Vals |           -34.5 |
# |            LossPi |           -99.4 |
# |             LossQ |            21.3 |
# |              Time |        1.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |        2.81e+03 |
# |          StdEpRet |        1.26e+03 |
# |          MaxEpRet |        3.79e+03 |
# |          MinEpRet |             648 |
# |  AverageTestEpRet |        3.63e+03 |
# |      StdTestEpRet |             282 |
# |      MaxTestEpRet |        3.93e+03 |
# |      MinTestEpRet |        3.14e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |             115 |
# |         StdQ1Vals |            79.2 |
# |         MaxQ1Vals |             284 |
# |         MinQ1Vals |           -49.7 |
# |     AverageQ2Vals |             115 |
# |         StdQ2Vals |            79.2 |
# |         MaxQ2Vals |             284 |
# |         MinQ2Vals |           -40.8 |
# |            LossPi |            -118 |
# |             LossQ |              27 |
# |              Time |         1.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |        2.23e+03 |
# |          StdEpRet |        1.67e+03 |
# |          MaxEpRet |        3.91e+03 |
# |          MinEpRet |            56.8 |
# |  AverageTestEpRet |        3.58e+03 |
# |      StdTestEpRet |        1.08e+03 |
# |      MaxTestEpRet |        4.34e+03 |
# |      MinTestEpRet |        1.45e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |             134 |
# |         StdQ1Vals |            91.2 |
# |         MaxQ1Vals |             320 |
# |         MinQ1Vals |           -52.4 |
# |     AverageQ2Vals |             134 |
# |         StdQ2Vals |            91.2 |
# |         MaxQ2Vals |             324 |
# |         MinQ2Vals |           -48.1 |
# |            LossPi |            -137 |
# |             LossQ |            32.7 |
# |              Time |        1.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |        2.39e+03 |
# |          StdEpRet |        1.52e+03 |
# |          MaxEpRet |        3.84e+03 |
# |          MinEpRet |             249 |
# |  AverageTestEpRet |         3.6e+03 |
# |      StdTestEpRet |             888 |
# |      MaxTestEpRet |        4.37e+03 |
# |      MinTestEpRet |        2.22e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |             149 |
# |         StdQ1Vals |             104 |
# |         MaxQ1Vals |             346 |
# |         MinQ1Vals |           -69.3 |
# |     AverageQ2Vals |             149 |
# |         StdQ2Vals |             104 |
# |         MaxQ2Vals |             344 |
# |         MinQ2Vals |           -59.6 |
# |            LossPi |            -151 |
# |             LossQ |              39 |
# |              Time |        1.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        4.08e+03 |
# |          StdEpRet |             162 |
# |          MaxEpRet |        4.34e+03 |
# |          MinEpRet |        3.89e+03 |
# |  AverageTestEpRet |         3.2e+03 |
# |      StdTestEpRet |             864 |
# |      MaxTestEpRet |        4.16e+03 |
# |      MinTestEpRet |        1.74e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |             115 |
# |         MaxQ1Vals |             368 |
# |         MinQ1Vals |           -76.6 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |             115 |
# |         MaxQ2Vals |             367 |
# |         MinQ2Vals |           -74.9 |
# |            LossPi |            -169 |
# |             LossQ |            45.1 |
# |              Time |        1.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        3.95e+03 |
# |          StdEpRet |             666 |
# |          MaxEpRet |        4.45e+03 |
# |          MinEpRet |        2.81e+03 |
# |  AverageTestEpRet |        4.63e+03 |
# |      StdTestEpRet |             191 |
# |      MaxTestEpRet |        4.99e+03 |
# |      MinTestEpRet |        4.45e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             188 |
# |         StdQ1Vals |             126 |
# |         MaxQ1Vals |             403 |
# |         MinQ1Vals |           -59.3 |
# |     AverageQ2Vals |             188 |
# |         StdQ2Vals |             126 |
# |         MaxQ2Vals |             406 |
# |         MinQ2Vals |           -62.6 |
# |            LossPi |            -190 |
# |             LossQ |            50.4 |
# |              Time |        1.83e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |        4.58e+03 |
# |          StdEpRet |             176 |
# |          MaxEpRet |        4.76e+03 |
# |          MinEpRet |        4.33e+03 |
# |  AverageTestEpRet |        4.38e+03 |
# |      StdTestEpRet |             784 |
# |      MaxTestEpRet |        4.84e+03 |
# |      MinTestEpRet |        2.82e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             209 |
# |         StdQ1Vals |             134 |
# |         MaxQ1Vals |             433 |
# |         MinQ1Vals |           -63.4 |
# |     AverageQ2Vals |             209 |
# |         StdQ2Vals |             134 |
# |         MaxQ2Vals |             433 |
# |         MinQ2Vals |             -55 |
# |            LossPi |            -212 |
# |             LossQ |              57 |
# |              Time |        1.99e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        4.69e+03 |
# |          StdEpRet |             102 |
# |          MaxEpRet |        4.81e+03 |
# |          MinEpRet |        4.55e+03 |
# |  AverageTestEpRet |         4.8e+03 |
# |      StdTestEpRet |             271 |
# |      MaxTestEpRet |        5.11e+03 |
# |      MinTestEpRet |        4.38e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             231 |
# |         StdQ1Vals |             142 |
# |         MaxQ1Vals |             455 |
# |         MinQ1Vals |           -56.5 |
# |     AverageQ2Vals |             231 |
# |         StdQ2Vals |             142 |
# |         MaxQ2Vals |             459 |
# |         MinQ2Vals |           -51.8 |
# |            LossPi |            -234 |
# |             LossQ |            61.2 |
# |              Time |        2.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        4.33e+03 |
# |          StdEpRet |        1.09e+03 |
# |          MaxEpRet |        5.12e+03 |
# |          MinEpRet |        2.45e+03 |
# |  AverageTestEpRet |        3.84e+03 |
# |      StdTestEpRet |        1.67e+03 |
# |      MaxTestEpRet |        5.25e+03 |
# |      MinTestEpRet |             575 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             254 |
# |         StdQ1Vals |             148 |
# |         MaxQ1Vals |             490 |
# |         MinQ1Vals |           -55.4 |
# |     AverageQ2Vals |             254 |
# |         StdQ2Vals |             148 |
# |         MaxQ2Vals |             486 |
# |         MinQ2Vals |           -44.9 |
# |            LossPi |            -257 |
# |             LossQ |            65.8 |
# |              Time |        2.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |        3.85e+03 |
# |          StdEpRet |        1.43e+03 |
# |          MaxEpRet |        4.72e+03 |
# |          MinEpRet |        1.37e+03 |
# |  AverageTestEpRet |        4.08e+03 |
# |      StdTestEpRet |             751 |
# |      MaxTestEpRet |        5.53e+03 |
# |      MinTestEpRet |        3.41e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             270 |
# |         StdQ1Vals |             157 |
# |         MaxQ1Vals |             513 |
# |         MinQ1Vals |           -49.9 |
# |     AverageQ2Vals |             270 |
# |         StdQ2Vals |             157 |
# |         MaxQ2Vals |             508 |
# |         MinQ2Vals |           -51.2 |
# |            LossPi |            -273 |
# |             LossQ |            72.6 |
# |              Time |         2.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |        4.25e+03 |
# |          StdEpRet |        1.31e+03 |
# |          MaxEpRet |        5.06e+03 |
# |          MinEpRet |        1.98e+03 |
# |  AverageTestEpRet |        4.38e+03 |
# |      StdTestEpRet |        1.33e+03 |
# |      MaxTestEpRet |        5.21e+03 |
# |      MinTestEpRet |        1.73e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             285 |
# |         StdQ1Vals |             164 |
# |         MaxQ1Vals |             524 |
# |         MinQ1Vals |           -93.9 |
# |     AverageQ2Vals |             285 |
# |         StdQ2Vals |             164 |
# |         MaxQ2Vals |             521 |
# |         MinQ2Vals |           -92.2 |
# |            LossPi |            -288 |
# |             LossQ |            84.7 |
# |              Time |        2.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        5.14e+03 |
# |          StdEpRet |             193 |
# |          MaxEpRet |        5.31e+03 |
# |          MinEpRet |        4.82e+03 |
# |  AverageTestEpRet |        1.82e+03 |
# |      StdTestEpRet |             664 |
# |      MaxTestEpRet |        2.98e+03 |
# |      MinTestEpRet |        1.17e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             303 |
# |         StdQ1Vals |             168 |
# |         MaxQ1Vals |             539 |
# |         MinQ1Vals |            -128 |
# |     AverageQ2Vals |             303 |
# |         StdQ2Vals |             168 |
# |         MaxQ2Vals |             536 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            -306 |
# |             LossQ |            89.2 |
# |              Time |        2.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        5.18e+03 |
# |          StdEpRet |             384 |
# |          MaxEpRet |        5.51e+03 |
# |          MinEpRet |        4.53e+03 |
# |  AverageTestEpRet |        4.13e+03 |
# |      StdTestEpRet |        1.33e+03 |
# |      MaxTestEpRet |         5.6e+03 |
# |      MinTestEpRet |        1.77e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             320 |
# |         StdQ1Vals |             172 |
# |         MaxQ1Vals |             544 |
# |         MinQ1Vals |           -85.6 |
# |     AverageQ2Vals |             320 |
# |         StdQ2Vals |             172 |
# |         MaxQ2Vals |             546 |
# |         MinQ2Vals |           -91.7 |
# |            LossPi |            -323 |
# |             LossQ |            88.2 |
# |              Time |        2.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        5.35e+03 |
# |          StdEpRet |             246 |
# |          MaxEpRet |        5.73e+03 |
# |          MinEpRet |        5.07e+03 |
# |  AverageTestEpRet |        5.82e+03 |
# |      StdTestEpRet |             186 |
# |      MaxTestEpRet |        6.08e+03 |
# |      MinTestEpRet |        5.63e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             336 |
# |         StdQ1Vals |             175 |
# |         MaxQ1Vals |             563 |
# |         MinQ1Vals |             -72 |
# |     AverageQ2Vals |             336 |
# |         StdQ2Vals |             175 |
# |         MaxQ2Vals |             566 |
# |         MinQ2Vals |           -79.2 |
# |            LossPi |            -339 |
# |             LossQ |            85.7 |
# |              Time |        2.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        4.99e+03 |
# |          StdEpRet |             609 |
# |          MaxEpRet |        5.37e+03 |
# |          MinEpRet |        3.94e+03 |
# |  AverageTestEpRet |        5.83e+03 |
# |      StdTestEpRet |             216 |
# |      MaxTestEpRet |         6.2e+03 |
# |      MinTestEpRet |        5.55e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             349 |
# |         StdQ1Vals |             179 |
# |         MaxQ1Vals |             571 |
# |         MinQ1Vals |            -101 |
# |     AverageQ2Vals |             349 |
# |         StdQ2Vals |             179 |
# |         MaxQ2Vals |             573 |
# |         MinQ2Vals |            -132 |
# |            LossPi |            -352 |
# |             LossQ |            86.8 |
# |              Time |        3.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        5.55e+03 |
# |          StdEpRet |             238 |
# |          MaxEpRet |        5.81e+03 |
# |          MinEpRet |        5.31e+03 |
# |  AverageTestEpRet |        4.18e+03 |
# |      StdTestEpRet |        1.51e+03 |
# |      MaxTestEpRet |        5.64e+03 |
# |      MinTestEpRet |        1.74e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             361 |
# |         StdQ1Vals |             182 |
# |         MaxQ1Vals |             584 |
# |         MinQ1Vals |           -79.3 |
# |     AverageQ2Vals |             361 |
# |         StdQ2Vals |             182 |
# |         MaxQ2Vals |             585 |
# |         MinQ2Vals |           -88.1 |
# |            LossPi |            -364 |
# |             LossQ |            84.5 |
# |              Time |        3.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        5.73e+03 |
# |          StdEpRet |             303 |
# |          MaxEpRet |        6.22e+03 |
# |          MinEpRet |         5.4e+03 |
# |  AverageTestEpRet |        4.95e+03 |
# |      StdTestEpRet |        2.06e+03 |
# |      MaxTestEpRet |         6.3e+03 |
# |      MinTestEpRet |             843 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             374 |
# |         StdQ1Vals |             185 |
# |         MaxQ1Vals |             603 |
# |         MinQ1Vals |            -105 |
# |     AverageQ2Vals |             374 |
# |         StdQ2Vals |             185 |
# |         MaxQ2Vals |             607 |
# |         MinQ2Vals |            -120 |
# |            LossPi |            -377 |
# |             LossQ |            86.3 |
# |              Time |        3.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |        5.72e+03 |
# |          StdEpRet |             216 |
# |          MaxEpRet |        5.94e+03 |
# |          MinEpRet |        5.36e+03 |
# |  AverageTestEpRet |        5.07e+03 |
# |      StdTestEpRet |        2.14e+03 |
# |      MaxTestEpRet |        6.41e+03 |
# |      MinTestEpRet |             823 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             386 |
# |         StdQ1Vals |             189 |
# |         MaxQ1Vals |             612 |
# |         MinQ1Vals |            -124 |
# |     AverageQ2Vals |             386 |
# |         StdQ2Vals |             189 |
# |         MaxQ2Vals |             612 |
# |         MinQ2Vals |            -122 |
# |            LossPi |            -389 |
# |             LossQ |            89.2 |
# |              Time |         3.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        5.71e+03 |
# |          StdEpRet |             138 |
# |          MaxEpRet |        5.86e+03 |
# |          MinEpRet |         5.5e+03 |
# |  AverageTestEpRet |         5.1e+03 |
# |      StdTestEpRet |        2.22e+03 |
# |      MaxTestEpRet |        6.37e+03 |
# |      MinTestEpRet |             669 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             398 |
# |         StdQ1Vals |             190 |
# |         MaxQ1Vals |             617 |
# |         MinQ1Vals |            -125 |
# |     AverageQ2Vals |             398 |
# |         StdQ2Vals |             190 |
# |         MaxQ2Vals |             618 |
# |         MinQ2Vals |            -122 |
# |            LossPi |            -401 |
# |             LossQ |            90.2 |
# |              Time |        3.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        5.92e+03 |
# |          StdEpRet |             219 |
# |          MaxEpRet |        6.19e+03 |
# |          MinEpRet |        5.69e+03 |
# |  AverageTestEpRet |        6.01e+03 |
# |      StdTestEpRet |             207 |
# |      MaxTestEpRet |        6.21e+03 |
# |      MinTestEpRet |        5.73e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |             409 |
# |         StdQ1Vals |             192 |
# |         MaxQ1Vals |             626 |
# |         MinQ1Vals |            -120 |
# |     AverageQ2Vals |             409 |
# |         StdQ2Vals |             192 |
# |         MaxQ2Vals |             628 |
# |         MinQ2Vals |            -158 |
# |            LossPi |            -412 |
# |             LossQ |              88 |
# |              Time |        3.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        6.07e+03 |
# |          StdEpRet |             117 |
# |          MaxEpRet |        6.26e+03 |
# |          MinEpRet |        5.94e+03 |
# |  AverageTestEpRet |        6.27e+03 |
# |      StdTestEpRet |             752 |
# |      MaxTestEpRet |        6.88e+03 |
# |      MinTestEpRet |         4.8e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |             420 |
# |         StdQ1Vals |             193 |
# |         MaxQ1Vals |             640 |
# |         MinQ1Vals |            -123 |
# |     AverageQ2Vals |             420 |
# |         StdQ2Vals |             193 |
# |         MaxQ2Vals |             637 |
# |         MinQ2Vals |            -135 |
# |            LossPi |            -423 |
# |             LossQ |            92.3 |
# |              Time |        3.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |        5.85e+03 |
# |          StdEpRet |        1.01e+03 |
# |          MaxEpRet |        6.57e+03 |
# |          MinEpRet |         4.1e+03 |
# |  AverageTestEpRet |        6.62e+03 |
# |      StdTestEpRet |             154 |
# |      MaxTestEpRet |        6.85e+03 |
# |      MinTestEpRet |        6.38e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             431 |
# |         StdQ1Vals |             196 |
# |         MaxQ1Vals |             651 |
# |         MinQ1Vals |            -147 |
# |     AverageQ2Vals |             431 |
# |         StdQ2Vals |             196 |
# |         MaxQ2Vals |             648 |
# |         MinQ2Vals |            -140 |
# |            LossPi |            -434 |
# |             LossQ |            95.2 |
# |              Time |        4.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        6.13e+03 |
# |          StdEpRet |             154 |
# |          MaxEpRet |        6.22e+03 |
# |          MinEpRet |        5.86e+03 |
# |  AverageTestEpRet |        6.59e+03 |
# |      StdTestEpRet |             149 |
# |      MaxTestEpRet |        6.84e+03 |
# |      MinTestEpRet |        6.44e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             441 |
# |         StdQ1Vals |             198 |
# |         MaxQ1Vals |             657 |
# |         MinQ1Vals |            -130 |
# |     AverageQ2Vals |             441 |
# |         StdQ2Vals |             198 |
# |         MaxQ2Vals |             659 |
# |         MinQ2Vals |            -140 |
# |            LossPi |            -445 |
# |             LossQ |            95.1 |
# |              Time |        4.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |        4.63e+03 |
# |          StdEpRet |        1.79e+03 |
# |          MaxEpRet |        6.32e+03 |
# |          MinEpRet |        1.79e+03 |
# |  AverageTestEpRet |        6.87e+03 |
# |      StdTestEpRet |             217 |
# |      MaxTestEpRet |         7.2e+03 |
# |      MinTestEpRet |        6.59e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             451 |
# |         StdQ1Vals |             200 |
# |         MaxQ1Vals |             672 |
# |         MinQ1Vals |            -122 |
# |     AverageQ2Vals |             451 |
# |         StdQ2Vals |             200 |
# |         MaxQ2Vals |             671 |
# |         MinQ2Vals |            -130 |
# |            LossPi |            -454 |
# |             LossQ |            95.4 |
# |              Time |        4.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |         6.1e+03 |
# |          StdEpRet |             968 |
# |          MaxEpRet |        6.78e+03 |
# |          MinEpRet |        4.44e+03 |
# |  AverageTestEpRet |        6.73e+03 |
# |      StdTestEpRet |             164 |
# |      MaxTestEpRet |         6.9e+03 |
# |      MinTestEpRet |         6.5e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             459 |
# |         StdQ1Vals |             204 |
# |         MaxQ1Vals |             686 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |             459 |
# |         StdQ2Vals |             204 |
# |         MaxQ2Vals |             684 |
# |         MinQ2Vals |            -130 |
# |            LossPi |            -462 |
# |             LossQ |             102 |
# |              Time |        4.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |        6.54e+03 |
# |          StdEpRet |             143 |
# |          MaxEpRet |        6.67e+03 |
# |          MinEpRet |        6.31e+03 |
# |  AverageTestEpRet |        5.16e+03 |
# |      StdTestEpRet |        2.02e+03 |
# |      MaxTestEpRet |        7.24e+03 |
# |      MinTestEpRet |        2.05e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             469 |
# |         StdQ1Vals |             207 |
# |         MaxQ1Vals |             692 |
# |         MinQ1Vals |            -166 |
# |     AverageQ2Vals |             469 |
# |         StdQ2Vals |             207 |
# |         MaxQ2Vals |             691 |
# |         MinQ2Vals |            -173 |
# |            LossPi |            -472 |
# |             LossQ |             109 |
# |              Time |        4.69e+03 |
# ---------------------------------------

# %%
args = {'env': 'HopperPyBulletEnv-v0', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': False,
        'exp_name': 'td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HopperPyBulletEnv-v0",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D1E2587C8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False\\\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_False_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	false,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
# options=
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            19.8 |
# |          StdEpRet |            3.02 |
# |          MaxEpRet |            33.7 |
# |          MinEpRet |            12.4 |
# |  AverageTestEpRet |            65.6 |
# |      StdTestEpRet |            6.99 |
# |      MaxTestEpRet |            78.3 |
# |      MinTestEpRet |              57 |
# |             EpLen |            11.8 |
# |         TestEpLen |            42.2 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |              12 |
# |         StdQ1Vals |             7.9 |
# |         MaxQ1Vals |            29.9 |
# |         MinQ1Vals |           -3.37 |
# |     AverageQ2Vals |              12 |
# |         StdQ2Vals |             7.9 |
# |         MaxQ2Vals |            29.8 |
# |         MinQ2Vals |           -3.79 |
# |            LossPi |           -13.5 |
# |             LossQ |           0.842 |
# |              Time |            76.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            20.1 |
# |          StdEpRet |            2.84 |
# |          MaxEpRet |              33 |
# |          MinEpRet |            13.9 |
# |  AverageTestEpRet |            32.4 |
# |      StdTestEpRet |            7.65 |
# |      MaxTestEpRet |              40 |
# |      MinTestEpRet |            22.7 |
# |             EpLen |            11.9 |
# |         TestEpLen |            37.4 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            27.7 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |            63.7 |
# |         MinQ1Vals |            -4.6 |
# |     AverageQ2Vals |            27.7 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |              63 |
# |         MinQ2Vals |           -4.86 |
# |            LossPi |           -30.9 |
# |             LossQ |            1.63 |
# |              Time |             170 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            25.9 |
# |          StdEpRet |              14 |
# |          MaxEpRet |            94.2 |
# |          MinEpRet |            14.1 |
# |  AverageTestEpRet |             226 |
# |      StdTestEpRet |             278 |
# |      MaxTestEpRet |             781 |
# |      MinTestEpRet |            75.7 |
# |             EpLen |            19.2 |
# |         TestEpLen |             255 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            49.3 |
# |         StdQ1Vals |            22.7 |
# |         MaxQ1Vals |             126 |
# |         MinQ1Vals |           -17.8 |
# |     AverageQ2Vals |            49.3 |
# |         StdQ2Vals |            22.7 |
# |         MaxQ2Vals |             125 |
# |         MinQ2Vals |           -12.2 |
# |            LossPi |             -55 |
# |             LossQ |            15.7 |
# |              Time |             269 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             157 |
# |          StdEpRet |             195 |
# |          MaxEpRet |             874 |
# |          MinEpRet |            65.9 |
# |  AverageTestEpRet |             698 |
# |      StdTestEpRet |             270 |
# |      MaxTestEpRet |             839 |
# |      MinTestEpRet |             159 |
# |             EpLen |             147 |
# |         TestEpLen |             827 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            60.7 |
# |         StdQ1Vals |            25.6 |
# |         MaxQ1Vals |            90.4 |
# |         MinQ1Vals |           -17.5 |
# |     AverageQ2Vals |            60.7 |
# |         StdQ2Vals |            25.6 |
# |         MaxQ2Vals |            90.5 |
# |         MinQ2Vals |           -15.3 |
# |            LossPi |           -66.1 |
# |             LossQ |            12.7 |
# |              Time |             381 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             173 |
# |          StdEpRet |            79.7 |
# |          MaxEpRet |             517 |
# |          MinEpRet |             105 |
# |  AverageTestEpRet |             506 |
# |      StdTestEpRet |             337 |
# |      MaxTestEpRet |             912 |
# |      MinTestEpRet |             136 |
# |             EpLen |             151 |
# |         TestEpLen |             536 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            64.4 |
# |         StdQ1Vals |            25.1 |
# |         MaxQ1Vals |            92.2 |
# |         MinQ1Vals |           -29.8 |
# |     AverageQ2Vals |            64.4 |
# |         StdQ2Vals |            25.1 |
# |         MaxQ2Vals |            92.7 |
# |         MinQ2Vals |           -20.8 |
# |            LossPi |           -68.9 |
# |             LossQ |            8.13 |
# |              Time |             486 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             159 |
# |          StdEpRet |            88.8 |
# |          MaxEpRet |             544 |
# |          MinEpRet |              99 |
# |  AverageTestEpRet |             804 |
# |      StdTestEpRet |            1.05 |
# |      MaxTestEpRet |             806 |
# |      MinTestEpRet |             803 |
# |             EpLen |             135 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            65.3 |
# |         StdQ1Vals |            24.9 |
# |         MaxQ1Vals |            93.2 |
# |         MinQ1Vals |           -34.4 |
# |     AverageQ2Vals |            65.3 |
# |         StdQ2Vals |            24.9 |
# |         MaxQ2Vals |            93.2 |
# |         MinQ2Vals |           -28.9 |
# |            LossPi |           -69.2 |
# |             LossQ |            7.91 |
# |              Time |             596 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             792 |
# |          StdEpRet |            34.6 |
# |          MaxEpRet |             835 |
# |          MinEpRet |             744 |
# |  AverageTestEpRet |             901 |
# |      StdTestEpRet |            2.95 |
# |      MaxTestEpRet |             904 |
# |      MinTestEpRet |             896 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            68.2 |
# |         StdQ1Vals |            24.9 |
# |         MaxQ1Vals |            97.2 |
# |         MinQ1Vals |           -24.9 |
# |     AverageQ2Vals |            68.2 |
# |         StdQ2Vals |            24.9 |
# |         MaxQ2Vals |            97.7 |
# |         MinQ2Vals |             -21 |
# |            LossPi |           -71.7 |
# |             LossQ |            6.54 |
# |              Time |             705 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             260 |
# |          StdEpRet |             204 |
# |          MaxEpRet |             833 |
# |          MinEpRet |              99 |
# |  AverageTestEpRet |             160 |
# |      StdTestEpRet |            24.6 |
# |      MaxTestEpRet |             196 |
# |      MinTestEpRet |             125 |
# |             EpLen |             245 |
# |         TestEpLen |             133 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            70.5 |
# |         StdQ1Vals |            24.5 |
# |         MaxQ1Vals |            99.3 |
# |         MinQ1Vals |           -26.1 |
# |     AverageQ2Vals |            70.5 |
# |         StdQ2Vals |            24.5 |
# |         MaxQ2Vals |            98.9 |
# |         MinQ2Vals |           -24.7 |
# |            LossPi |           -73.6 |
# |             LossQ |            6.21 |
# |              Time |             808 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             277 |
# |          StdEpRet |             198 |
# |          MaxEpRet |             866 |
# |          MinEpRet |             141 |
# |  AverageTestEpRet |             642 |
# |      StdTestEpRet |             245 |
# |      MaxTestEpRet |             777 |
# |      MinTestEpRet |             152 |
# |             EpLen |             248 |
# |         TestEpLen |             823 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            72.9 |
# |         StdQ1Vals |            24.6 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |           -28.4 |
# |     AverageQ2Vals |            72.9 |
# |         StdQ2Vals |            24.6 |
# |         MaxQ2Vals |             106 |
# |         MinQ2Vals |           -27.7 |
# |            LossPi |           -75.8 |
# |             LossQ |            6.48 |
# |              Time |             918 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             574 |
# |          StdEpRet |             334 |
# |          MaxEpRet |             841 |
# |          MinEpRet |            72.2 |
# |  AverageTestEpRet |             790 |
# |      StdTestEpRet |            9.87 |
# |      MaxTestEpRet |             797 |
# |      MinTestEpRet |             770 |
# |             EpLen |             710 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            74.9 |
# |         StdQ1Vals |            23.4 |
# |         MaxQ1Vals |             106 |
# |         MinQ1Vals |             -29 |
# |     AverageQ2Vals |            74.9 |
# |         StdQ2Vals |            23.4 |
# |         MaxQ2Vals |             107 |
# |         MinQ2Vals |           -25.2 |
# |            LossPi |           -77.7 |
# |             LossQ |            6.37 |
# |              Time |        1.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             802 |
# |          StdEpRet |             8.2 |
# |          MaxEpRet |             813 |
# |          MinEpRet |             790 |
# |  AverageTestEpRet |             799 |
# |      StdTestEpRet |            1.14 |
# |      MaxTestEpRet |             800 |
# |      MinTestEpRet |             798 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            77.1 |
# |         StdQ1Vals |            22.8 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |             -31 |
# |     AverageQ2Vals |            77.1 |
# |         StdQ2Vals |            22.8 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |           -28.2 |
# |            LossPi |           -79.7 |
# |             LossQ |            6.29 |
# |              Time |        1.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             491 |
# |          StdEpRet |             300 |
# |          MaxEpRet |             839 |
# |          MinEpRet |             158 |
# |  AverageTestEpRet |             323 |
# |      StdTestEpRet |            95.9 |
# |      MaxTestEpRet |             513 |
# |      MinTestEpRet |             250 |
# |             EpLen |             525 |
# |         TestEpLen |             281 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            79.5 |
# |         StdQ1Vals |            22.3 |
# |         MaxQ1Vals |             106 |
# |         MinQ1Vals |           -27.7 |
# |     AverageQ2Vals |            79.5 |
# |         StdQ2Vals |            22.3 |
# |         MaxQ2Vals |             105 |
# |         MinQ2Vals |           -24.6 |
# |            LossPi |           -81.9 |
# |             LossQ |            5.67 |
# |              Time |        1.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             207 |
# |          StdEpRet |             130 |
# |          MaxEpRet |             762 |
# |          MinEpRet |             122 |
# |  AverageTestEpRet |             142 |
# |      StdTestEpRet |             6.2 |
# |      MaxTestEpRet |             153 |
# |      MinTestEpRet |             136 |
# |             EpLen |             171 |
# |         TestEpLen |              89 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            80.8 |
# |         StdQ1Vals |            22.1 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |           -25.5 |
# |     AverageQ2Vals |            80.8 |
# |         StdQ2Vals |            22.1 |
# |         MaxQ2Vals |             107 |
# |         MinQ2Vals |             -25 |
# |            LossPi |           -83.1 |
# |             LossQ |            5.46 |
# |              Time |        1.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             155 |
# |          StdEpRet |            34.1 |
# |          MaxEpRet |             257 |
# |          MinEpRet |             100 |
# |  AverageTestEpRet |             170 |
# |      StdTestEpRet |            18.2 |
# |      MaxTestEpRet |             202 |
# |      MinTestEpRet |             151 |
# |             EpLen |             106 |
# |         TestEpLen |             104 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |              81 |
# |         StdQ1Vals |            23.2 |
# |         MaxQ1Vals |             109 |
# |         MinQ1Vals |             -27 |
# |     AverageQ2Vals |              81 |
# |         StdQ2Vals |            23.2 |
# |         MaxQ2Vals |             109 |
# |         MinQ2Vals |           -36.5 |
# |            LossPi |           -83.3 |
# |             LossQ |             5.5 |
# |              Time |        1.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             362 |
# |          StdEpRet |             316 |
# |          MaxEpRet |        1.12e+03 |
# |          MinEpRet |             147 |
# |  AverageTestEpRet |             861 |
# |      StdTestEpRet |             397 |
# |      MaxTestEpRet |        1.48e+03 |
# |      MinTestEpRet |             277 |
# |             EpLen |             276 |
# |         TestEpLen |             575 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            82.5 |
# |         StdQ1Vals |            24.8 |
# |         MaxQ1Vals |             113 |
# |         MinQ1Vals |           -32.2 |
# |     AverageQ2Vals |            82.5 |
# |         StdQ2Vals |            24.8 |
# |         MaxQ2Vals |             112 |
# |         MinQ2Vals |           -29.9 |
# |            LossPi |           -84.7 |
# |             LossQ |            5.59 |
# |              Time |        1.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             281 |
# |          StdEpRet |             149 |
# |          MaxEpRet |             658 |
# |          MinEpRet |             147 |
# |  AverageTestEpRet |             613 |
# |      StdTestEpRet |             370 |
# |      MaxTestEpRet |             915 |
# |      MinTestEpRet |             138 |
# |             EpLen |             219 |
# |         TestEpLen |             644 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            84.2 |
# |         StdQ1Vals |            25.3 |
# |         MaxQ1Vals |             116 |
# |         MinQ1Vals |           -28.7 |
# |     AverageQ2Vals |            84.2 |
# |         StdQ2Vals |            25.3 |
# |         MaxQ2Vals |             116 |
# |         MinQ2Vals |           -24.2 |
# |            LossPi |           -86.3 |
# |             LossQ |            5.66 |
# |              Time |        1.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             612 |
# |          StdEpRet |             291 |
# |          MaxEpRet |             885 |
# |          MinEpRet |             209 |
# |  AverageTestEpRet |             974 |
# |      StdTestEpRet |             373 |
# |      MaxTestEpRet |        1.29e+03 |
# |      MinTestEpRet |             255 |
# |             EpLen |             711 |
# |         TestEpLen |             783 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            84.1 |
# |         StdQ1Vals |            24.3 |
# |         MaxQ1Vals |             116 |
# |         MinQ1Vals |           -30.1 |
# |     AverageQ2Vals |            84.1 |
# |         StdQ2Vals |            24.3 |
# |         MaxQ2Vals |             118 |
# |         MinQ2Vals |           -29.3 |
# |            LossPi |             -86 |
# |             LossQ |            5.27 |
# |              Time |        1.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             258 |
# |          StdEpRet |             242 |
# |          MaxEpRet |             977 |
# |          MinEpRet |            34.2 |
# |  AverageTestEpRet |             878 |
# |      StdTestEpRet |            26.2 |
# |      MaxTestEpRet |             914 |
# |      MinTestEpRet |             841 |
# |             EpLen |             278 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            84.7 |
# |         StdQ1Vals |            23.4 |
# |         MaxQ1Vals |             120 |
# |         MinQ1Vals |           -42.5 |
# |     AverageQ2Vals |            84.7 |
# |         StdQ2Vals |            23.4 |
# |         MaxQ2Vals |             121 |
# |         MinQ2Vals |           -63.1 |
# |            LossPi |           -86.6 |
# |             LossQ |            6.12 |
# |              Time |        1.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             697 |
# |          StdEpRet |             316 |
# |          MaxEpRet |             872 |
# |          MinEpRet |            64.9 |
# |  AverageTestEpRet |             766 |
# |      StdTestEpRet |             319 |
# |      MaxTestEpRet |             943 |
# |      MinTestEpRet |             129 |
# |             EpLen |             812 |
# |         TestEpLen |             820 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            84.6 |
# |         StdQ1Vals |            22.4 |
# |         MaxQ1Vals |             119 |
# |         MinQ1Vals |           -33.6 |
# |     AverageQ2Vals |            84.6 |
# |         StdQ2Vals |            22.4 |
# |         MaxQ2Vals |             119 |
# |         MinQ2Vals |           -42.6 |
# |            LossPi |           -86.3 |
# |             LossQ |            6.11 |
# |              Time |        2.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             531 |
# |          StdEpRet |             279 |
# |          MaxEpRet |             879 |
# |          MinEpRet |             135 |
# |  AverageTestEpRet |        1.09e+03 |
# |      StdTestEpRet |              41 |
# |      MaxTestEpRet |        1.14e+03 |
# |      MinTestEpRet |        1.03e+03 |
# |             EpLen |             584 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            84.9 |
# |         StdQ1Vals |            21.7 |
# |         MaxQ1Vals |             117 |
# |         MinQ1Vals |           -35.1 |
# |     AverageQ2Vals |            84.9 |
# |         StdQ2Vals |            21.7 |
# |         MaxQ2Vals |             119 |
# |         MinQ2Vals |           -30.1 |
# |            LossPi |           -86.6 |
# |             LossQ |             6.2 |
# |              Time |        2.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             798 |
# |          StdEpRet |             309 |
# |          MaxEpRet |        1.27e+03 |
# |          MinEpRet |             429 |
# |  AverageTestEpRet |             458 |
# |      StdTestEpRet |             240 |
# |      MaxTestEpRet |             827 |
# |      MinTestEpRet |             240 |
# |             EpLen |             669 |
# |         TestEpLen |             270 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |              86 |
# |         StdQ1Vals |            21.7 |
# |         MaxQ1Vals |             121 |
# |         MinQ1Vals |           -33.2 |
# |     AverageQ2Vals |              86 |
# |         StdQ2Vals |            21.7 |
# |         MaxQ2Vals |             123 |
# |         MinQ2Vals |           -27.8 |
# |            LossPi |           -87.7 |
# |             LossQ |            6.18 |
# |              Time |        2.27e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             655 |
# |          StdEpRet |             361 |
# |          MaxEpRet |        1.11e+03 |
# |          MinEpRet |             178 |
# |  AverageTestEpRet |             857 |
# |      StdTestEpRet |             299 |
# |      MaxTestEpRet |        1.08e+03 |
# |      MinTestEpRet |             321 |
# |             EpLen |             581 |
# |         TestEpLen |             775 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            87.6 |
# |         StdQ1Vals |              22 |
# |         MaxQ1Vals |             128 |
# |         MinQ1Vals |           -39.8 |
# |     AverageQ2Vals |            87.6 |
# |         StdQ2Vals |              22 |
# |         MaxQ2Vals |             127 |
# |         MinQ2Vals |           -31.5 |
# |            LossPi |           -89.3 |
# |             LossQ |            6.55 |
# |              Time |        2.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             365 |
# |          StdEpRet |             297 |
# |          MaxEpRet |             864 |
# |          MinEpRet |            87.6 |
# |  AverageTestEpRet |             584 |
# |      StdTestEpRet |             399 |
# |      MaxTestEpRet |             915 |
# |      MinTestEpRet |              87 |
# |             EpLen |             392 |
# |         TestEpLen |             645 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            89.2 |
# |         StdQ1Vals |            22.2 |
# |         MaxQ1Vals |             129 |
# |         MinQ1Vals |           -48.9 |
# |     AverageQ2Vals |            89.2 |
# |         StdQ2Vals |            22.2 |
# |         MaxQ2Vals |             129 |
# |         MinQ2Vals |           -31.3 |
# |            LossPi |           -90.8 |
# |             LossQ |            8.21 |
# |              Time |        2.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             510 |
# |          StdEpRet |             347 |
# |          MaxEpRet |             926 |
# |          MinEpRet |            75.2 |
# |  AverageTestEpRet |             125 |
# |      StdTestEpRet |            63.3 |
# |      MaxTestEpRet |             251 |
# |      MinTestEpRet |            83.2 |
# |             EpLen |             569 |
# |         TestEpLen |             129 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            90.8 |
# |         StdQ1Vals |            22.5 |
# |         MaxQ1Vals |             131 |
# |         MinQ1Vals |           -41.9 |
# |     AverageQ2Vals |            90.8 |
# |         StdQ2Vals |            22.5 |
# |         MaxQ2Vals |             130 |
# |         MinQ2Vals |           -34.6 |
# |            LossPi |           -92.5 |
# |             LossQ |            8.32 |
# |              Time |        2.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             516 |
# |          StdEpRet |             342 |
# |          MaxEpRet |        1.02e+03 |
# |          MinEpRet |            84.2 |
# |  AverageTestEpRet |             456 |
# |      StdTestEpRet |             298 |
# |      MaxTestEpRet |             928 |
# |      MinTestEpRet |             151 |
# |             EpLen |             546 |
# |         TestEpLen |             433 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            91.7 |
# |         StdQ1Vals |            22.7 |
# |         MaxQ1Vals |             132 |
# |         MinQ1Vals |           -46.7 |
# |     AverageQ2Vals |            91.7 |
# |         StdQ2Vals |            22.7 |
# |         MaxQ2Vals |             133 |
# |         MinQ2Vals |           -49.4 |
# |            LossPi |           -93.4 |
# |             LossQ |            9.02 |
# |              Time |        2.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             841 |
# |          StdEpRet |             340 |
# |          MaxEpRet |        1.35e+03 |
# |          MinEpRet |             246 |
# |  AverageTestEpRet |        1.49e+03 |
# |      StdTestEpRet |             200 |
# |      MaxTestEpRet |         1.6e+03 |
# |      MinTestEpRet |        1.09e+03 |
# |             EpLen |             659 |
# |         TestEpLen |             936 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            91.8 |
# |         StdQ1Vals |            22.7 |
# |         MaxQ1Vals |             133 |
# |         MinQ1Vals |           -49.3 |
# |     AverageQ2Vals |            91.8 |
# |         StdQ2Vals |            22.7 |
# |         MaxQ2Vals |             135 |
# |         MinQ2Vals |           -52.9 |
# |            LossPi |           -93.5 |
# |             LossQ |            8.76 |
# |              Time |         2.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |           1e+03 |
# |          StdEpRet |             525 |
# |          MaxEpRet |        1.65e+03 |
# |          MinEpRet |             368 |
# |  AverageTestEpRet |             923 |
# |      StdTestEpRet |            1.58 |
# |      MaxTestEpRet |             925 |
# |      MinTestEpRet |             920 |
# |             EpLen |             711 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            93.8 |
# |         StdQ1Vals |            23.2 |
# |         MaxQ1Vals |             138 |
# |         MinQ1Vals |           -53.1 |
# |     AverageQ2Vals |            93.8 |
# |         StdQ2Vals |            23.2 |
# |         MaxQ2Vals |             137 |
# |         MinQ2Vals |           -55.2 |
# |            LossPi |           -95.5 |
# |             LossQ |            8.73 |
# |              Time |        2.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             593 |
# |          StdEpRet |             364 |
# |          MaxEpRet |             951 |
# |          MinEpRet |            35.3 |
# |  AverageTestEpRet |        1.55e+03 |
# |      StdTestEpRet |              13 |
# |      MaxTestEpRet |        1.58e+03 |
# |      MinTestEpRet |        1.54e+03 |
# |             EpLen |             632 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            94.8 |
# |         StdQ1Vals |            23.2 |
# |         MaxQ1Vals |             141 |
# |         MinQ1Vals |           -47.9 |
# |     AverageQ2Vals |            94.8 |
# |         StdQ2Vals |            23.2 |
# |         MaxQ2Vals |             141 |
# |         MinQ2Vals |           -53.6 |
# |            LossPi |           -96.5 |
# |             LossQ |            8.69 |
# |              Time |        3.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             973 |
# |          StdEpRet |             333 |
# |          MaxEpRet |        1.42e+03 |
# |          MinEpRet |             328 |
# |  AverageTestEpRet |        1.61e+03 |
# |      StdTestEpRet |            14.3 |
# |      MaxTestEpRet |        1.63e+03 |
# |      MinTestEpRet |        1.59e+03 |
# |             EpLen |             738 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            95.7 |
# |         StdQ1Vals |            23.6 |
# |         MaxQ1Vals |             142 |
# |         MinQ1Vals |           -52.9 |
# |     AverageQ2Vals |            95.7 |
# |         StdQ2Vals |            23.6 |
# |         MaxQ2Vals |             142 |
# |         MinQ2Vals |           -57.5 |
# |            LossPi |           -97.4 |
# |             LossQ |            9.01 |
# |              Time |        3.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             710 |
# |          StdEpRet |             578 |
# |          MaxEpRet |        1.73e+03 |
# |          MinEpRet |             181 |
# |  AverageTestEpRet |             370 |
# |      StdTestEpRet |            51.9 |
# |      MaxTestEpRet |             421 |
# |      MinTestEpRet |             282 |
# |             EpLen |             430 |
# |         TestEpLen |             190 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            97.7 |
# |         StdQ1Vals |              24 |
# |         MaxQ1Vals |             155 |
# |         MinQ1Vals |           -61.4 |
# |     AverageQ2Vals |            97.7 |
# |         StdQ2Vals |              24 |
# |         MaxQ2Vals |             155 |
# |         MinQ2Vals |           -47.1 |
# |            LossPi |           -99.4 |
# |             LossQ |            9.82 |
# |              Time |        3.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             416 |
# |          StdEpRet |             324 |
# |          MaxEpRet |        1.46e+03 |
# |          MinEpRet |            21.5 |
# |  AverageTestEpRet |        1.74e+03 |
# |      StdTestEpRet |            34.4 |
# |      MaxTestEpRet |        1.78e+03 |
# |      MinTestEpRet |        1.68e+03 |
# |             EpLen |             226 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             101 |
# |         StdQ1Vals |            25.2 |
# |         MaxQ1Vals |             164 |
# |         MinQ1Vals |           -36.1 |
# |     AverageQ2Vals |             101 |
# |         StdQ2Vals |            25.2 |
# |         MaxQ2Vals |             164 |
# |         MinQ2Vals |           -42.6 |
# |            LossPi |            -103 |
# |             LossQ |            10.8 |
# |              Time |        3.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             911 |
# |          StdEpRet |             467 |
# |          MaxEpRet |        1.61e+03 |
# |          MinEpRet |             314 |
# |  AverageTestEpRet |        1.64e+03 |
# |      StdTestEpRet |            42.9 |
# |      MaxTestEpRet |        1.69e+03 |
# |      MinTestEpRet |        1.58e+03 |
# |             EpLen |             574 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             106 |
# |         StdQ1Vals |            26.2 |
# |         MaxQ1Vals |             167 |
# |         MinQ1Vals |           -44.8 |
# |     AverageQ2Vals |             106 |
# |         StdQ2Vals |            26.2 |
# |         MaxQ2Vals |             170 |
# |         MinQ2Vals |           -56.3 |
# |            LossPi |            -107 |
# |             LossQ |            11.6 |
# |              Time |        3.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             779 |
# |          StdEpRet |             553 |
# |          MaxEpRet |        1.75e+03 |
# |          MinEpRet |             129 |
# |  AverageTestEpRet |             816 |
# |      StdTestEpRet |             552 |
# |      MaxTestEpRet |        1.83e+03 |
# |      MinTestEpRet |             238 |
# |             EpLen |             447 |
# |         TestEpLen |             439 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             107 |
# |         StdQ1Vals |            26.4 |
# |         MaxQ1Vals |             167 |
# |         MinQ1Vals |           -42.1 |
# |     AverageQ2Vals |             107 |
# |         StdQ2Vals |            26.4 |
# |         MaxQ2Vals |             168 |
# |         MinQ2Vals |           -49.5 |
# |            LossPi |            -109 |
# |             LossQ |            12.2 |
# |              Time |        3.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             778 |
# |          StdEpRet |             571 |
# |          MaxEpRet |         1.7e+03 |
# |          MinEpRet |             216 |
# |  AverageTestEpRet |             172 |
# |      StdTestEpRet |            77.6 |
# |      MaxTestEpRet |             252 |
# |      MinTestEpRet |            76.1 |
# |             EpLen |             474 |
# |         TestEpLen |             160 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             110 |
# |         StdQ1Vals |            26.8 |
# |         MaxQ1Vals |             168 |
# |         MinQ1Vals |           -48.1 |
# |     AverageQ2Vals |             110 |
# |         StdQ2Vals |            26.8 |
# |         MaxQ2Vals |             170 |
# |         MinQ2Vals |           -52.3 |
# |            LossPi |            -112 |
# |             LossQ |            12.7 |
# |              Time |        3.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             860 |
# |          StdEpRet |             588 |
# |          MaxEpRet |        1.71e+03 |
# |          MinEpRet |             123 |
# |  AverageTestEpRet |         1.8e+03 |
# |      StdTestEpRet |            8.81 |
# |      MaxTestEpRet |        1.81e+03 |
# |      MinTestEpRet |        1.78e+03 |
# |             EpLen |             544 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             112 |
# |         StdQ1Vals |            28.1 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |           -48.2 |
# |     AverageQ2Vals |             112 |
# |         StdQ2Vals |            28.1 |
# |         MaxQ2Vals |             170 |
# |         MinQ2Vals |           -58.9 |
# |            LossPi |            -114 |
# |             LossQ |              13 |
# |              Time |        3.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             706 |
# |          StdEpRet |             607 |
# |          MaxEpRet |        1.84e+03 |
# |          MinEpRet |             139 |
# |  AverageTestEpRet |             167 |
# |      StdTestEpRet |            33.5 |
# |      MaxTestEpRet |             223 |
# |      MinTestEpRet |             136 |
# |             EpLen |             396 |
# |         TestEpLen |              93 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             116 |
# |         StdQ1Vals |              29 |
# |         MaxQ1Vals |             171 |
# |         MinQ1Vals |           -50.9 |
# |     AverageQ2Vals |             116 |
# |         StdQ2Vals |              29 |
# |         MaxQ2Vals |             171 |
# |         MinQ2Vals |           -61.4 |
# |            LossPi |            -118 |
# |             LossQ |            12.8 |
# |              Time |        3.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             670 |
# |          StdEpRet |             466 |
# |          MaxEpRet |        1.72e+03 |
# |          MinEpRet |             160 |
# |  AverageTestEpRet |             528 |
# |      StdTestEpRet |             224 |
# |      MaxTestEpRet |             712 |
# |      MinTestEpRet |             216 |
# |             EpLen |             365 |
# |         TestEpLen |             277 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             118 |
# |         StdQ1Vals |            29.8 |
# |         MaxQ1Vals |             174 |
# |         MinQ1Vals |           -56.9 |
# |     AverageQ2Vals |             118 |
# |         StdQ2Vals |            29.8 |
# |         MaxQ2Vals |             175 |
# |         MinQ2Vals |           -61.5 |
# |            LossPi |            -120 |
# |             LossQ |            14.2 |
# |              Time |        3.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             638 |
# |          StdEpRet |             558 |
# |          MaxEpRet |        1.83e+03 |
# |          MinEpRet |             153 |
# |  AverageTestEpRet |        1.64e+03 |
# |      StdTestEpRet |             278 |
# |      MaxTestEpRet |        1.81e+03 |
# |      MinTestEpRet |        1.09e+03 |
# |             EpLen |             347 |
# |         TestEpLen |             931 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             119 |
# |         StdQ1Vals |            30.4 |
# |         MaxQ1Vals |             175 |
# |         MinQ1Vals |           -57.8 |
# |     AverageQ2Vals |             119 |
# |         StdQ2Vals |            30.4 |
# |         MaxQ2Vals |             177 |
# |         MinQ2Vals |           -56.1 |
# |            LossPi |            -121 |
# |             LossQ |            13.7 |
# |              Time |         4.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        1.57e+03 |
# |          StdEpRet |             461 |
# |          MaxEpRet |        1.83e+03 |
# |          MinEpRet |             650 |
# |  AverageTestEpRet |        1.84e+03 |
# |      StdTestEpRet |            71.8 |
# |      MaxTestEpRet |        1.92e+03 |
# |      MinTestEpRet |        1.72e+03 |
# |             EpLen |             870 |
# |         TestEpLen |             982 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             122 |
# |         StdQ1Vals |            30.8 |
# |         MaxQ1Vals |             178 |
# |         MinQ1Vals |           -36.5 |
# |     AverageQ2Vals |             122 |
# |         StdQ2Vals |            30.8 |
# |         MaxQ2Vals |             179 |
# |         MinQ2Vals |           -35.4 |
# |            LossPi |            -124 |
# |             LossQ |            13.7 |
# |              Time |        4.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        1.49e+03 |
# |          StdEpRet |             496 |
# |          MaxEpRet |         1.8e+03 |
# |          MinEpRet |             633 |
# |  AverageTestEpRet |        1.73e+03 |
# |      StdTestEpRet |            31.5 |
# |      MaxTestEpRet |        1.76e+03 |
# |      MinTestEpRet |        1.67e+03 |
# |             EpLen |             842 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             125 |
# |         StdQ1Vals |            31.5 |
# |         MaxQ1Vals |             181 |
# |         MinQ1Vals |           -46.6 |
# |     AverageQ2Vals |             125 |
# |         StdQ2Vals |            31.5 |
# |         MaxQ2Vals |             181 |
# |         MinQ2Vals |           -40.8 |
# |            LossPi |            -127 |
# |             LossQ |            13.8 |
# |              Time |        4.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        1.81e+03 |
# |          StdEpRet |            50.7 |
# |          MaxEpRet |        1.87e+03 |
# |          MinEpRet |        1.74e+03 |
# |  AverageTestEpRet |        1.98e+03 |
# |      StdTestEpRet |            25.1 |
# |      MaxTestEpRet |        2.02e+03 |
# |      MinTestEpRet |        1.96e+03 |
# |             EpLen |             988 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             127 |
# |         StdQ1Vals |            31.5 |
# |         MaxQ1Vals |             184 |
# |         MinQ1Vals |           -66.5 |
# |     AverageQ2Vals |             127 |
# |         StdQ2Vals |            31.5 |
# |         MaxQ2Vals |             184 |
# |         MinQ2Vals |           -44.7 |
# |            LossPi |            -129 |
# |             LossQ |            14.2 |
# |              Time |        4.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        1.55e+03 |
# |          StdEpRet |             582 |
# |          MaxEpRet |        1.94e+03 |
# |          MinEpRet |             362 |
# |  AverageTestEpRet |        2.05e+03 |
# |      StdTestEpRet |            10.8 |
# |      MaxTestEpRet |        2.06e+03 |
# |      MinTestEpRet |        2.03e+03 |
# |             EpLen |             805 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             130 |
# |         StdQ1Vals |            31.7 |
# |         MaxQ1Vals |             189 |
# |         MinQ1Vals |           -44.9 |
# |     AverageQ2Vals |             130 |
# |         StdQ2Vals |            31.7 |
# |         MaxQ2Vals |             187 |
# |         MinQ2Vals |           -52.1 |
# |            LossPi |            -131 |
# |             LossQ |            13.8 |
# |              Time |        4.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        1.63e+03 |
# |          StdEpRet |             494 |
# |          MaxEpRet |        1.95e+03 |
# |          MinEpRet |             776 |
# |  AverageTestEpRet |        1.99e+03 |
# |      StdTestEpRet |            14.2 |
# |      MaxTestEpRet |        2.01e+03 |
# |      MinTestEpRet |        1.97e+03 |
# |             EpLen |             848 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             132 |
# |         StdQ1Vals |            32.3 |
# |         MaxQ1Vals |             192 |
# |         MinQ1Vals |           -48.7 |
# |     AverageQ2Vals |             132 |
# |         StdQ2Vals |            32.3 |
# |         MaxQ2Vals |             188 |
# |         MinQ2Vals |           -58.8 |
# |            LossPi |            -134 |
# |             LossQ |            14.4 |
# |              Time |        4.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        1.81e+03 |
# |          StdEpRet |             250 |
# |          MaxEpRet |        1.98e+03 |
# |          MinEpRet |        1.34e+03 |
# |  AverageTestEpRet |        2.03e+03 |
# |      StdTestEpRet |            9.83 |
# |      MaxTestEpRet |        2.04e+03 |
# |      MinTestEpRet |        2.02e+03 |
# |             EpLen |             915 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             135 |
# |         StdQ1Vals |            32.6 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |             -42 |
# |     AverageQ2Vals |             135 |
# |         StdQ2Vals |            32.6 |
# |         MaxQ2Vals |             190 |
# |         MinQ2Vals |           -58.5 |
# |            LossPi |            -137 |
# |             LossQ |            16.1 |
# |              Time |        4.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        1.59e+03 |
# |          StdEpRet |             558 |
# |          MaxEpRet |        1.95e+03 |
# |          MinEpRet |             625 |
# |  AverageTestEpRet |        1.91e+03 |
# |      StdTestEpRet |            8.51 |
# |      MaxTestEpRet |        1.93e+03 |
# |      MinTestEpRet |         1.9e+03 |
# |             EpLen |             834 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             138 |
# |         StdQ1Vals |            32.9 |
# |         MaxQ1Vals |             196 |
# |         MinQ1Vals |           -38.9 |
# |     AverageQ2Vals |             138 |
# |         StdQ2Vals |            32.9 |
# |         MaxQ2Vals |             195 |
# |         MinQ2Vals |           -52.1 |
# |            LossPi |            -140 |
# |             LossQ |            16.5 |
# |              Time |        4.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        1.21e+03 |
# |          StdEpRet |             647 |
# |          MaxEpRet |        1.93e+03 |
# |          MinEpRet |            64.6 |
# |  AverageTestEpRet |        2.02e+03 |
# |      StdTestEpRet |             2.9 |
# |      MaxTestEpRet |        2.02e+03 |
# |      MinTestEpRet |        2.01e+03 |
# |             EpLen |             637 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             140 |
# |         StdQ1Vals |            33.7 |
# |         MaxQ1Vals |             201 |
# |         MinQ1Vals |           -44.1 |
# |     AverageQ2Vals |             140 |
# |         StdQ2Vals |            33.7 |
# |         MaxQ2Vals |             199 |
# |         MinQ2Vals |           -54.8 |
# |            LossPi |            -142 |
# |             LossQ |            16.2 |
# |              Time |        5.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        1.44e+03 |
# |          StdEpRet |             759 |
# |          MaxEpRet |           2e+03 |
# |          MinEpRet |             141 |
# |  AverageTestEpRet |        1.96e+03 |
# |      StdTestEpRet |            2.19 |
# |      MaxTestEpRet |        1.96e+03 |
# |      MinTestEpRet |        1.95e+03 |
# |             EpLen |             734 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             143 |
# |         StdQ1Vals |            33.8 |
# |         MaxQ1Vals |             203 |
# |         MinQ1Vals |           -50.1 |
# |     AverageQ2Vals |             143 |
# |         StdQ2Vals |            33.8 |
# |         MaxQ2Vals |             201 |
# |         MinQ2Vals |           -44.5 |
# |            LossPi |            -145 |
# |             LossQ |              17 |
# |              Time |        5.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        1.73e+03 |
# |          StdEpRet |             360 |
# |          MaxEpRet |        1.97e+03 |
# |          MinEpRet |        1.11e+03 |
# |  AverageTestEpRet |        1.93e+03 |
# |      StdTestEpRet |            4.88 |
# |      MaxTestEpRet |        1.94e+03 |
# |      MinTestEpRet |        1.92e+03 |
# |             EpLen |             891 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             146 |
# |         StdQ1Vals |            34.3 |
# |         MaxQ1Vals |             205 |
# |         MinQ1Vals |           -60.5 |
# |     AverageQ2Vals |             146 |
# |         StdQ2Vals |            34.3 |
# |         MaxQ2Vals |             204 |
# |         MinQ2Vals |           -47.6 |
# |            LossPi |            -148 |
# |             LossQ |            18.2 |
# |              Time |         5.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        1.63e+03 |
# |          StdEpRet |             632 |
# |          MaxEpRet |        1.97e+03 |
# |          MinEpRet |             365 |
# |  AverageTestEpRet |        1.93e+03 |
# |      StdTestEpRet |            6.59 |
# |      MaxTestEpRet |        1.94e+03 |
# |      MinTestEpRet |        1.93e+03 |
# |             EpLen |             832 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             149 |
# |         StdQ1Vals |            35.1 |
# |         MaxQ1Vals |             207 |
# |         MinQ1Vals |           -63.1 |
# |     AverageQ2Vals |             149 |
# |         StdQ2Vals |            35.1 |
# |         MaxQ2Vals |             207 |
# |         MinQ2Vals |           -54.7 |
# |            LossPi |            -151 |
# |             LossQ |            19.2 |
# |              Time |        5.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        1.23e+03 |
# |          StdEpRet |             874 |
# |          MaxEpRet |        2.04e+03 |
# |          MinEpRet |             129 |
# |  AverageTestEpRet |        2.01e+03 |
# |      StdTestEpRet |            6.44 |
# |      MaxTestEpRet |        2.02e+03 |
# |      MinTestEpRet |           2e+03 |
# |             EpLen |             626 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             152 |
# |         StdQ1Vals |            35.6 |
# |         MaxQ1Vals |             210 |
# |         MinQ1Vals |           -48.7 |
# |     AverageQ2Vals |             152 |
# |         StdQ2Vals |            35.6 |
# |         MaxQ2Vals |             211 |
# |         MinQ2Vals |             -62 |
# |            LossPi |            -154 |
# |             LossQ |            19.5 |
# |              Time |        5.57e+03 |
# ---------------------------------------

# %%
args = {'env': 'HopperPyBulletEnv-v0', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'exp_name': 'td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HopperPyBulletEnv-v0",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D1E16B808>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True\\\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True\\td3_NonStationary_False_HopperPyBulletEnv_NoTargSmooth_NoDelayUpdate_POMDP_True_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
# options=
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            19.8 |
# |          StdEpRet |            3.13 |
# |          MaxEpRet |            32.5 |
# |          MinEpRet |            10.7 |
# |  AverageTestEpRet |              67 |
# |      StdTestEpRet |            5.21 |
# |      MaxTestEpRet |              73 |
# |      MinTestEpRet |            57.5 |
# |             EpLen |              12 |
# |         TestEpLen |              42 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            10.5 |
# |         StdQ1Vals |            6.89 |
# |         MaxQ1Vals |            28.4 |
# |         MinQ1Vals |           -3.03 |
# |     AverageQ2Vals |            10.5 |
# |         StdQ2Vals |            6.89 |
# |         MaxQ2Vals |            28.4 |
# |         MinQ2Vals |           -2.66 |
# |            LossPi |           -11.6 |
# |             LossQ |           0.795 |
# |              Time |            67.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            20.4 |
# |          StdEpRet |            3.29 |
# |          MaxEpRet |            32.5 |
# |          MinEpRet |            10.6 |
# |  AverageTestEpRet |            65.8 |
# |      StdTestEpRet |            3.78 |
# |      MaxTestEpRet |              72 |
# |      MinTestEpRet |            61.5 |
# |             EpLen |            12.3 |
# |         TestEpLen |              42 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            23.3 |
# |         StdQ1Vals |            12.3 |
# |         MaxQ1Vals |            49.2 |
# |         MinQ1Vals |           -3.96 |
# |     AverageQ2Vals |            23.3 |
# |         StdQ2Vals |            12.3 |
# |         MaxQ2Vals |            49.8 |
# |         MinQ2Vals |           -3.34 |
# |            LossPi |           -25.7 |
# |             LossQ |            1.11 |
# |              Time |             160 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            26.4 |
# |          StdEpRet |            14.6 |
# |          MaxEpRet |            74.6 |
# |          MinEpRet |            12.8 |
# |  AverageTestEpRet |            41.1 |
# |      StdTestEpRet |            4.09 |
# |      MaxTestEpRet |              49 |
# |      MinTestEpRet |            37.3 |
# |             EpLen |            17.9 |
# |         TestEpLen |            40.8 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            35.5 |
# |         StdQ1Vals |            17.4 |
# |         MaxQ1Vals |            65.3 |
# |         MinQ1Vals |           -8.12 |
# |     AverageQ2Vals |            35.5 |
# |         StdQ2Vals |            17.4 |
# |         MaxQ2Vals |              65 |
# |         MinQ2Vals |           -8.21 |
# |            LossPi |           -39.2 |
# |             LossQ |            4.28 |
# |              Time |             258 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             152 |
# |          StdEpRet |             160 |
# |          MaxEpRet |             950 |
# |          MinEpRet |            43.7 |
# |  AverageTestEpRet |             828 |
# |      StdTestEpRet |             342 |
# |      MaxTestEpRet |        1.01e+03 |
# |      MinTestEpRet |             145 |
# |             EpLen |             122 |
# |         TestEpLen |             820 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            43.3 |
# |         StdQ1Vals |            20.1 |
# |         MaxQ1Vals |              70 |
# |         MinQ1Vals |           -10.8 |
# |     AverageQ2Vals |            43.3 |
# |         StdQ2Vals |            20.1 |
# |         MaxQ2Vals |              70 |
# |         MinQ2Vals |             -12 |
# |            LossPi |           -46.9 |
# |             LossQ |            4.45 |
# |              Time |             366 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             465 |
# |          StdEpRet |             300 |
# |          MaxEpRet |             954 |
# |          MinEpRet |             174 |
# |  AverageTestEpRet |             150 |
# |      StdTestEpRet |            14.2 |
# |      MaxTestEpRet |             167 |
# |      MinTestEpRet |             127 |
# |             EpLen |             439 |
# |         TestEpLen |             105 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            48.8 |
# |         StdQ1Vals |            20.9 |
# |         MaxQ1Vals |            76.3 |
# |         MinQ1Vals |           -11.6 |
# |     AverageQ2Vals |            48.8 |
# |         StdQ2Vals |            20.9 |
# |         MaxQ2Vals |            77.3 |
# |         MinQ2Vals |           -11.9 |
# |            LossPi |           -52.2 |
# |             LossQ |            3.81 |
# |              Time |             478 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             230 |
# |          StdEpRet |             192 |
# |          MaxEpRet |             888 |
# |          MinEpRet |             117 |
# |  AverageTestEpRet |             179 |
# |      StdTestEpRet |            8.91 |
# |      MaxTestEpRet |             187 |
# |      MinTestEpRet |             162 |
# |             EpLen |             208 |
# |         TestEpLen |             118 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            56.5 |
# |         StdQ1Vals |            21.6 |
# |         MaxQ1Vals |            85.4 |
# |         MinQ1Vals |           -16.1 |
# |     AverageQ2Vals |            56.5 |
# |         StdQ2Vals |            21.6 |
# |         MaxQ2Vals |              86 |
# |         MinQ2Vals |           -20.1 |
# |            LossPi |           -59.8 |
# |             LossQ |            5.26 |
# |              Time |             585 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             290 |
# |          StdEpRet |             297 |
# |          MaxEpRet |             943 |
# |          MinEpRet |             117 |
# |  AverageTestEpRet |             326 |
# |      StdTestEpRet |             330 |
# |      MaxTestEpRet |             986 |
# |      MinTestEpRet |             152 |
# |             EpLen |             266 |
# |         TestEpLen |             280 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            63.5 |
# |         StdQ1Vals |            22.5 |
# |         MaxQ1Vals |            90.4 |
# |         MinQ1Vals |           -16.3 |
# |     AverageQ2Vals |            63.5 |
# |         StdQ2Vals |            22.5 |
# |         MaxQ2Vals |            91.3 |
# |         MinQ2Vals |           -19.4 |
# |            LossPi |           -66.6 |
# |             LossQ |            5.59 |
# |              Time |             694 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             169 |
# |          StdEpRet |            74.2 |
# |          MaxEpRet |             467 |
# |          MinEpRet |            83.4 |
# |  AverageTestEpRet |             150 |
# |      StdTestEpRet |            5.02 |
# |      MaxTestEpRet |             155 |
# |      MinTestEpRet |             142 |
# |             EpLen |             118 |
# |         TestEpLen |            88.4 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            67.6 |
# |         StdQ1Vals |            22.9 |
# |         MaxQ1Vals |            93.6 |
# |         MinQ1Vals |           -16.9 |
# |     AverageQ2Vals |            67.6 |
# |         StdQ2Vals |            22.9 |
# |         MaxQ2Vals |            93.7 |
# |         MinQ2Vals |           -17.5 |
# |            LossPi |           -70.5 |
# |             LossQ |            6.31 |
# |              Time |             801 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             177 |
# |          StdEpRet |            72.5 |
# |          MaxEpRet |             427 |
# |          MinEpRet |             103 |
# |  AverageTestEpRet |             777 |
# |      StdTestEpRet |             330 |
# |      MaxTestEpRet |             972 |
# |      MinTestEpRet |             118 |
# |             EpLen |             122 |
# |         TestEpLen |             816 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            70.9 |
# |         StdQ1Vals |            23.7 |
# |         MaxQ1Vals |            97.9 |
# |         MinQ1Vals |             -15 |
# |     AverageQ2Vals |            70.9 |
# |         StdQ2Vals |            23.7 |
# |         MaxQ2Vals |            97.5 |
# |         MinQ2Vals |           -16.9 |
# |            LossPi |           -73.6 |
# |             LossQ |            6.74 |
# |              Time |             912 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             196 |
# |          StdEpRet |             214 |
# |          MaxEpRet |           1e+03 |
# |          MinEpRet |            99.4 |
# |  AverageTestEpRet |             134 |
# |      StdTestEpRet |            15.4 |
# |      MaxTestEpRet |             153 |
# |      MinTestEpRet |             115 |
# |             EpLen |             155 |
# |         TestEpLen |            86.4 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            73.7 |
# |         StdQ1Vals |            24.7 |
# |         MaxQ1Vals |             103 |
# |         MinQ1Vals |           -19.7 |
# |     AverageQ2Vals |            73.7 |
# |         StdQ2Vals |            24.7 |
# |         MaxQ2Vals |             102 |
# |         MinQ2Vals |           -19.2 |
# |            LossPi |           -76.4 |
# |             LossQ |            7.02 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             168 |
# |          StdEpRet |            75.4 |
# |          MaxEpRet |             488 |
# |          MinEpRet |             102 |
# |  AverageTestEpRet |             560 |
# |      StdTestEpRet |             354 |
# |      MaxTestEpRet |             974 |
# |      MinTestEpRet |             179 |
# |             EpLen |             120 |
# |         TestEpLen |             524 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            75.1 |
# |         StdQ1Vals |            26.2 |
# |         MaxQ1Vals |             107 |
# |         MinQ1Vals |             -20 |
# |     AverageQ2Vals |            75.1 |
# |         StdQ2Vals |            26.2 |
# |         MaxQ2Vals |             106 |
# |         MinQ2Vals |           -22.8 |
# |            LossPi |           -77.8 |
# |             LossQ |            7.29 |
# |              Time |        1.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             407 |
# |          StdEpRet |             324 |
# |          MaxEpRet |           1e+03 |
# |          MinEpRet |             121 |
# |  AverageTestEpRet |        1.03e+03 |
# |      StdTestEpRet |             2.8 |
# |      MaxTestEpRet |        1.04e+03 |
# |      MinTestEpRet |        1.03e+03 |
# |             EpLen |             357 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            75.7 |
# |         StdQ1Vals |            26.4 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |           -19.7 |
# |     AverageQ2Vals |            75.7 |
# |         StdQ2Vals |            26.4 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |           -26.7 |
# |            LossPi |           -78.3 |
# |             LossQ |            6.97 |
# |              Time |        1.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             985 |
# |          StdEpRet |            12.6 |
# |          MaxEpRet |           1e+03 |
# |          MinEpRet |             967 |
# |  AverageTestEpRet |             244 |
# |      StdTestEpRet |            34.9 |
# |      MaxTestEpRet |             305 |
# |      MinTestEpRet |             198 |
# |             EpLen |           1e+03 |
# |         TestEpLen |             144 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            77.4 |
# |         StdQ1Vals |            25.3 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |           -21.2 |
# |     AverageQ2Vals |            77.4 |
# |         StdQ2Vals |            25.3 |
# |         MaxQ2Vals |             109 |
# |         MinQ2Vals |           -22.1 |
# |            LossPi |           -79.9 |
# |             LossQ |            6.92 |
# |              Time |        1.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             352 |
# |          StdEpRet |             300 |
# |          MaxEpRet |        1.06e+03 |
# |          MinEpRet |             121 |
# |  AverageTestEpRet |             164 |
# |      StdTestEpRet |            11.8 |
# |      MaxTestEpRet |             181 |
# |      MinTestEpRet |             151 |
# |             EpLen |             292 |
# |         TestEpLen |            97.8 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            80.2 |
# |         StdQ1Vals |            24.3 |
# |         MaxQ1Vals |             107 |
# |         MinQ1Vals |           -22.1 |
# |     AverageQ2Vals |            80.2 |
# |         StdQ2Vals |            24.3 |
# |         MaxQ2Vals |             107 |
# |         MinQ2Vals |           -22.5 |
# |            LossPi |           -82.5 |
# |             LossQ |            6.83 |
# |              Time |        1.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             186 |
# |          StdEpRet |             151 |
# |          MaxEpRet |             974 |
# |          MinEpRet |             126 |
# |  AverageTestEpRet |             561 |
# |      StdTestEpRet |             410 |
# |      MaxTestEpRet |        1.07e+03 |
# |      MinTestEpRet |             199 |
# |             EpLen |             125 |
# |         TestEpLen |             480 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            81.7 |
# |         StdQ1Vals |            24.3 |
# |         MaxQ1Vals |             110 |
# |         MinQ1Vals |           -30.4 |
# |     AverageQ2Vals |            81.7 |
# |         StdQ2Vals |            24.3 |
# |         MaxQ2Vals |             109 |
# |         MinQ2Vals |           -26.4 |
# |            LossPi |           -83.9 |
# |             LossQ |            6.92 |
# |              Time |        1.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             360 |
# |          StdEpRet |             308 |
# |          MaxEpRet |             997 |
# |          MinEpRet |            95.3 |
# |  AverageTestEpRet |        1.05e+03 |
# |      StdTestEpRet |             275 |
# |      MaxTestEpRet |        1.52e+03 |
# |      MinTestEpRet |             763 |
# |             EpLen |             303 |
# |         TestEpLen |             787 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |              83 |
# |         StdQ1Vals |            24.5 |
# |         MaxQ1Vals |             111 |
# |         MinQ1Vals |           -28.2 |
# |     AverageQ2Vals |              83 |
# |         StdQ2Vals |            24.5 |
# |         MaxQ2Vals |             112 |
# |         MinQ2Vals |           -29.5 |
# |            LossPi |             -85 |
# |             LossQ |            7.37 |
# |              Time |         1.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             247 |
# |          StdEpRet |             149 |
# |          MaxEpRet |             890 |
# |          MinEpRet |            87.4 |
# |  AverageTestEpRet |             138 |
# |      StdTestEpRet |            41.6 |
# |      MaxTestEpRet |             194 |
# |      MinTestEpRet |             101 |
# |             EpLen |             155 |
# |         TestEpLen |              97 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |              85 |
# |         StdQ1Vals |            25.2 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |           -33.9 |
# |     AverageQ2Vals |              85 |
# |         StdQ2Vals |            25.2 |
# |         MaxQ2Vals |             122 |
# |         MinQ2Vals |             -42 |
# |            LossPi |           -87.2 |
# |             LossQ |            7.88 |
# |              Time |        1.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             338 |
# |          StdEpRet |             309 |
# |          MaxEpRet |        1.01e+03 |
# |          MinEpRet |             102 |
# |  AverageTestEpRet |             781 |
# |      StdTestEpRet |             237 |
# |      MaxTestEpRet |             902 |
# |      MinTestEpRet |             307 |
# |             EpLen |             307 |
# |         TestEpLen |             842 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            88.3 |
# |         StdQ1Vals |            26.3 |
# |         MaxQ1Vals |             138 |
# |         MinQ1Vals |           -34.9 |
# |     AverageQ2Vals |            88.3 |
# |         StdQ2Vals |            26.3 |
# |         MaxQ2Vals |             138 |
# |         MinQ2Vals |           -34.3 |
# |            LossPi |           -90.6 |
# |             LossQ |            9.94 |
# |              Time |        1.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             150 |
# |          StdEpRet |             235 |
# |          MaxEpRet |             868 |
# |          MinEpRet |            9.95 |
# |  AverageTestEpRet |             135 |
# |      StdTestEpRet |            92.5 |
# |      MaxTestEpRet |             254 |
# |      MinTestEpRet |            21.6 |
# |             EpLen |             158 |
# |         TestEpLen |             174 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            92.6 |
# |         StdQ1Vals |            27.4 |
# |         MaxQ1Vals |             144 |
# |         MinQ1Vals |           -66.4 |
# |     AverageQ2Vals |            92.6 |
# |         StdQ2Vals |            27.4 |
# |         MaxQ2Vals |             146 |
# |         MinQ2Vals |             -69 |
# |            LossPi |           -95.1 |
# |             LossQ |            13.2 |
# |              Time |        2.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             258 |
# |          StdEpRet |             185 |
# |          MaxEpRet |             803 |
# |          MinEpRet |             101 |
# |  AverageTestEpRet |             289 |
# |      StdTestEpRet |             305 |
# |      MaxTestEpRet |             897 |
# |      MinTestEpRet |             117 |
# |             EpLen |             245 |
# |         TestEpLen |             277 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            96.8 |
# |         StdQ1Vals |            28.5 |
# |         MaxQ1Vals |             144 |
# |         MinQ1Vals |           -61.4 |
# |     AverageQ2Vals |            96.8 |
# |         StdQ2Vals |            28.5 |
# |         MaxQ2Vals |             145 |
# |         MinQ2Vals |             -77 |
# |            LossPi |           -99.2 |
# |             LossQ |            14.8 |
# |              Time |        2.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             156 |
# |          StdEpRet |             144 |
# |          MaxEpRet |             705 |
# |          MinEpRet |            55.1 |
# |  AverageTestEpRet |             111 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |             136 |
# |      MinTestEpRet |            78.7 |
# |             EpLen |             153 |
# |         TestEpLen |            83.8 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |              95 |
# |         StdQ1Vals |            28.6 |
# |         MaxQ1Vals |             135 |
# |         MinQ1Vals |           -41.4 |
# |     AverageQ2Vals |              95 |
# |         StdQ2Vals |            28.6 |
# |         MaxQ2Vals |             133 |
# |         MinQ2Vals |             -49 |
# |            LossPi |           -97.8 |
# |             LossQ |            15.1 |
# |              Time |        2.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             109 |
# |          StdEpRet |            46.5 |
# |          MaxEpRet |             270 |
# |          MinEpRet |              41 |
# |  AverageTestEpRet |             134 |
# |      StdTestEpRet |            5.67 |
# |      MaxTestEpRet |             142 |
# |      MinTestEpRet |             126 |
# |             EpLen |            84.3 |
# |         TestEpLen |              85 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            91.2 |
# |         StdQ1Vals |            28.5 |
# |         MaxQ1Vals |             127 |
# |         MinQ1Vals |             -44 |
# |     AverageQ2Vals |            91.2 |
# |         StdQ2Vals |            28.5 |
# |         MaxQ2Vals |             129 |
# |         MinQ2Vals |           -51.1 |
# |            LossPi |           -93.6 |
# |             LossQ |              14 |
# |              Time |        2.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             308 |
# |          StdEpRet |             177 |
# |          MaxEpRet |             778 |
# |          MinEpRet |             122 |
# |  AverageTestEpRet |             322 |
# |      StdTestEpRet |             297 |
# |      MaxTestEpRet |             915 |
# |      MinTestEpRet |             149 |
# |             EpLen |             311 |
# |         TestEpLen |             278 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            88.8 |
# |         StdQ1Vals |            27.5 |
# |         MaxQ1Vals |             126 |
# |         MinQ1Vals |           -47.3 |
# |     AverageQ2Vals |            88.8 |
# |         StdQ2Vals |            27.5 |
# |         MaxQ2Vals |             126 |
# |         MinQ2Vals |           -50.4 |
# |            LossPi |           -90.9 |
# |             LossQ |            12.7 |
# |              Time |        2.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             292 |
# |          StdEpRet |             231 |
# |          MaxEpRet |             880 |
# |          MinEpRet |             135 |
# |  AverageTestEpRet |             253 |
# |      StdTestEpRet |             114 |
# |      MaxTestEpRet |             448 |
# |      MinTestEpRet |             140 |
# |             EpLen |             218 |
# |         TestEpLen |             153 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |              89 |
# |         StdQ1Vals |            26.9 |
# |         MaxQ1Vals |             126 |
# |         MinQ1Vals |           -41.7 |
# |     AverageQ2Vals |              89 |
# |         StdQ2Vals |            26.9 |
# |         MaxQ2Vals |             125 |
# |         MinQ2Vals |           -51.1 |
# |            LossPi |           -90.8 |
# |             LossQ |            11.9 |
# |              Time |        2.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             722 |
# |          StdEpRet |             426 |
# |          MaxEpRet |         1.3e+03 |
# |          MinEpRet |             143 |
# |  AverageTestEpRet |        1.01e+03 |
# |      StdTestEpRet |              61 |
# |      MaxTestEpRet |        1.13e+03 |
# |      MinTestEpRet |             971 |
# |             EpLen |             542 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            89.6 |
# |         StdQ1Vals |            26.7 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |           -46.8 |
# |     AverageQ2Vals |            89.6 |
# |         StdQ2Vals |            26.8 |
# |         MaxQ2Vals |             118 |
# |         MinQ2Vals |           -52.5 |
# |            LossPi |           -91.4 |
# |             LossQ |            11.4 |
# |              Time |        2.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             886 |
# |          StdEpRet |             389 |
# |          MaxEpRet |        1.26e+03 |
# |          MinEpRet |             202 |
# |  AverageTestEpRet |        1.13e+03 |
# |      StdTestEpRet |             275 |
# |      MaxTestEpRet |        1.42e+03 |
# |      MinTestEpRet |             783 |
# |             EpLen |             748 |
# |         TestEpLen |             767 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            90.8 |
# |         StdQ1Vals |            26.6 |
# |         MaxQ1Vals |             128 |
# |         MinQ1Vals |           -40.9 |
# |     AverageQ2Vals |            90.8 |
# |         StdQ2Vals |            26.7 |
# |         MaxQ2Vals |             126 |
# |         MinQ2Vals |           -46.1 |
# |            LossPi |           -92.5 |
# |             LossQ |            11.2 |
# |              Time |        2.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             653 |
# |          StdEpRet |             441 |
# |          MaxEpRet |        1.36e+03 |
# |          MinEpRet |             125 |
# |  AverageTestEpRet |             392 |
# |      StdTestEpRet |            71.9 |
# |      MaxTestEpRet |             499 |
# |      MinTestEpRet |             306 |
# |             EpLen |             470 |
# |         TestEpLen |             237 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            91.8 |
# |         StdQ1Vals |            25.9 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |           -49.5 |
# |     AverageQ2Vals |            91.8 |
# |         StdQ2Vals |            25.9 |
# |         MaxQ2Vals |             133 |
# |         MinQ2Vals |           -43.9 |
# |            LossPi |           -93.5 |
# |             LossQ |            10.6 |
# |              Time |        2.99e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             334 |
# |          StdEpRet |             266 |
# |          MaxEpRet |         1.2e+03 |
# |          MinEpRet |             133 |
# |  AverageTestEpRet |             373 |
# |      StdTestEpRet |             223 |
# |      MaxTestEpRet |             810 |
# |      MinTestEpRet |             216 |
# |             EpLen |             234 |
# |         TestEpLen |             265 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            93.3 |
# |         StdQ1Vals |              26 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |             -46 |
# |     AverageQ2Vals |            93.3 |
# |         StdQ2Vals |              26 |
# |         MaxQ2Vals |             135 |
# |         MinQ2Vals |           -54.6 |
# |            LossPi |             -95 |
# |             LossQ |            10.9 |
# |              Time |         3.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             556 |
# |          StdEpRet |             167 |
# |          MaxEpRet |             825 |
# |          MinEpRet |             222 |
# |  AverageTestEpRet |             345 |
# |      StdTestEpRet |            92.7 |
# |      MaxTestEpRet |             445 |
# |      MinTestEpRet |             178 |
# |             EpLen |             382 |
# |         TestEpLen |             202 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            94.9 |
# |         StdQ1Vals |            26.4 |
# |         MaxQ1Vals |             135 |
# |         MinQ1Vals |             -46 |
# |     AverageQ2Vals |            94.9 |
# |         StdQ2Vals |            26.4 |
# |         MaxQ2Vals |             135 |
# |         MinQ2Vals |           -48.5 |
# |            LossPi |           -96.6 |
# |             LossQ |            11.4 |
# |              Time |         3.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             394 |
# |          StdEpRet |             340 |
# |          MaxEpRet |        1.38e+03 |
# |          MinEpRet |             149 |
# |  AverageTestEpRet |        1.11e+03 |
# |      StdTestEpRet |             130 |
# |      MaxTestEpRet |        1.36e+03 |
# |      MinTestEpRet |        1.01e+03 |
# |             EpLen |             256 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |              96 |
# |         StdQ1Vals |            27.2 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |           -61.4 |
# |     AverageQ2Vals |              96 |
# |         StdQ2Vals |            27.2 |
# |         MaxQ2Vals |             135 |
# |         MinQ2Vals |           -52.7 |
# |            LossPi |           -97.7 |
# |             LossQ |            11.6 |
# |              Time |        3.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             711 |
# |          StdEpRet |             442 |
# |          MaxEpRet |        1.43e+03 |
# |          MinEpRet |             304 |
# |  AverageTestEpRet |         1.1e+03 |
# |      StdTestEpRet |             318 |
# |      MaxTestEpRet |        1.32e+03 |
# |      MinTestEpRet |             473 |
# |             EpLen |             491 |
# |         TestEpLen |             871 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            97.4 |
# |         StdQ1Vals |            27.4 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |           -64.5 |
# |     AverageQ2Vals |            97.4 |
# |         StdQ2Vals |            27.4 |
# |         MaxQ2Vals |             138 |
# |         MinQ2Vals |           -53.7 |
# |            LossPi |             -99 |
# |             LossQ |            12.4 |
# |              Time |        3.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             523 |
# |          StdEpRet |             314 |
# |          MaxEpRet |        1.28e+03 |
# |          MinEpRet |             199 |
# |  AverageTestEpRet |        1.22e+03 |
# |      StdTestEpRet |             302 |
# |      MaxTestEpRet |        1.39e+03 |
# |      MinTestEpRet |             619 |
# |             EpLen |             373 |
# |         TestEpLen |             889 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            98.9 |
# |         StdQ1Vals |            27.2 |
# |         MaxQ1Vals |             135 |
# |         MinQ1Vals |           -56.2 |
# |     AverageQ2Vals |            98.9 |
# |         StdQ2Vals |            27.2 |
# |         MaxQ2Vals |             135 |
# |         MinQ2Vals |           -44.6 |
# |            LossPi |            -101 |
# |             LossQ |            12.5 |
# |              Time |        3.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             781 |
# |          StdEpRet |             446 |
# |          MaxEpRet |        1.38e+03 |
# |          MinEpRet |             250 |
# |  AverageTestEpRet |             900 |
# |      StdTestEpRet |             409 |
# |      MaxTestEpRet |        1.38e+03 |
# |      MinTestEpRet |             237 |
# |             EpLen |             576 |
# |         TestEpLen |             665 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             100 |
# |         StdQ1Vals |            26.5 |
# |         MaxQ1Vals |             135 |
# |         MinQ1Vals |           -43.3 |
# |     AverageQ2Vals |             100 |
# |         StdQ2Vals |            26.5 |
# |         MaxQ2Vals |             140 |
# |         MinQ2Vals |           -51.9 |
# |            LossPi |            -102 |
# |             LossQ |            12.7 |
# |              Time |        3.67e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             673 |
# |          StdEpRet |             428 |
# |          MaxEpRet |        1.33e+03 |
# |          MinEpRet |             146 |
# |  AverageTestEpRet |             766 |
# |      StdTestEpRet |             294 |
# |      MaxTestEpRet |        1.19e+03 |
# |      MinTestEpRet |             398 |
# |             EpLen |             520 |
# |         TestEpLen |             660 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             102 |
# |         StdQ1Vals |            26.3 |
# |         MaxQ1Vals |             135 |
# |         MinQ1Vals |           -39.6 |
# |     AverageQ2Vals |             102 |
# |         StdQ2Vals |            26.3 |
# |         MaxQ2Vals |             137 |
# |         MinQ2Vals |           -47.1 |
# |            LossPi |            -104 |
# |             LossQ |            13.2 |
# |              Time |        3.79e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             442 |
# |          StdEpRet |             237 |
# |          MaxEpRet |             953 |
# |          MinEpRet |             141 |
# |  AverageTestEpRet |             597 |
# |      StdTestEpRet |             257 |
# |      MaxTestEpRet |             963 |
# |      MinTestEpRet |             362 |
# |             EpLen |             331 |
# |         TestEpLen |             448 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             104 |
# |         StdQ1Vals |            26.9 |
# |         MaxQ1Vals |             138 |
# |         MinQ1Vals |           -68.1 |
# |     AverageQ2Vals |             104 |
# |         StdQ2Vals |            26.9 |
# |         MaxQ2Vals |             142 |
# |         MinQ2Vals |             -64 |
# |            LossPi |            -106 |
# |             LossQ |            13.9 |
# |              Time |        3.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             678 |
# |          StdEpRet |             362 |
# |          MaxEpRet |        1.38e+03 |
# |          MinEpRet |             287 |
# |  AverageTestEpRet |        1.27e+03 |
# |      StdTestEpRet |             397 |
# |      MaxTestEpRet |        1.59e+03 |
# |      MinTestEpRet |             687 |
# |             EpLen |             450 |
# |         TestEpLen |             789 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             105 |
# |         StdQ1Vals |            27.8 |
# |         MaxQ1Vals |             137 |
# |         MinQ1Vals |           -38.8 |
# |     AverageQ2Vals |             105 |
# |         StdQ2Vals |            27.8 |
# |         MaxQ2Vals |             142 |
# |         MinQ2Vals |           -46.6 |
# |            LossPi |            -107 |
# |             LossQ |            14.2 |
# |              Time |        4.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             599 |
# |          StdEpRet |             233 |
# |          MaxEpRet |        1.12e+03 |
# |          MinEpRet |             193 |
# |  AverageTestEpRet |             634 |
# |      StdTestEpRet |             128 |
# |      MaxTestEpRet |             803 |
# |      MinTestEpRet |             414 |
# |             EpLen |             378 |
# |         TestEpLen |             376 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             107 |
# |         StdQ1Vals |            27.9 |
# |         MaxQ1Vals |             141 |
# |         MinQ1Vals |           -51.3 |
# |     AverageQ2Vals |             107 |
# |         StdQ2Vals |            27.9 |
# |         MaxQ2Vals |             139 |
# |         MinQ2Vals |           -52.8 |
# |            LossPi |            -108 |
# |             LossQ |            14.5 |
# |              Time |        4.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             484 |
# |          StdEpRet |             252 |
# |          MaxEpRet |        1.26e+03 |
# |          MinEpRet |             257 |
# |  AverageTestEpRet |        1.01e+03 |
# |      StdTestEpRet |             344 |
# |      MaxTestEpRet |        1.58e+03 |
# |      MinTestEpRet |             667 |
# |             EpLen |             306 |
# |         TestEpLen |             569 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             107 |
# |         StdQ1Vals |            28.1 |
# |         MaxQ1Vals |             139 |
# |         MinQ1Vals |           -41.5 |
# |     AverageQ2Vals |             107 |
# |         StdQ2Vals |            28.1 |
# |         MaxQ2Vals |             141 |
# |         MinQ2Vals |           -52.1 |
# |            LossPi |            -109 |
# |             LossQ |              15 |
# |              Time |        4.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |             450 |
# |          StdEpRet |             174 |
# |          MaxEpRet |             908 |
# |          MinEpRet |             188 |
# |  AverageTestEpRet |             434 |
# |      StdTestEpRet |            70.9 |
# |      MaxTestEpRet |             548 |
# |      MinTestEpRet |             348 |
# |             EpLen |             288 |
# |         TestEpLen |             264 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             109 |
# |         StdQ1Vals |            28.1 |
# |         MaxQ1Vals |             141 |
# |         MinQ1Vals |           -59.6 |
# |     AverageQ2Vals |             109 |
# |         StdQ2Vals |            28.1 |
# |         MaxQ2Vals |             140 |
# |         MinQ2Vals |           -55.3 |
# |            LossPi |            -110 |
# |             LossQ |            15.3 |
# |              Time |        4.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |             466 |
# |          StdEpRet |             263 |
# |          MaxEpRet |        1.12e+03 |
# |          MinEpRet |             190 |
# |  AverageTestEpRet |             754 |
# |      StdTestEpRet |             254 |
# |      MaxTestEpRet |        1.02e+03 |
# |      MinTestEpRet |             325 |
# |             EpLen |             287 |
# |         TestEpLen |             624 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             109 |
# |         StdQ1Vals |            28.4 |
# |         MaxQ1Vals |             140 |
# |         MinQ1Vals |           -54.8 |
# |     AverageQ2Vals |             109 |
# |         StdQ2Vals |            28.4 |
# |         MaxQ2Vals |             140 |
# |         MinQ2Vals |           -57.4 |
# |            LossPi |            -111 |
# |             LossQ |            15.3 |
# |              Time |        4.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             628 |
# |          StdEpRet |             333 |
# |          MaxEpRet |        1.06e+03 |
# |          MinEpRet |             246 |
# |  AverageTestEpRet |             386 |
# |      StdTestEpRet |             233 |
# |      MaxTestEpRet |             849 |
# |      MinTestEpRet |             213 |
# |             EpLen |             513 |
# |         TestEpLen |             271 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             109 |
# |         StdQ1Vals |            28.3 |
# |         MaxQ1Vals |             139 |
# |         MinQ1Vals |           -39.6 |
# |     AverageQ2Vals |             109 |
# |         StdQ2Vals |            28.3 |
# |         MaxQ2Vals |             142 |
# |         MinQ2Vals |           -52.7 |
# |            LossPi |            -111 |
# |             LossQ |            15.5 |
# |              Time |        4.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             283 |
# |          StdEpRet |             208 |
# |          MaxEpRet |         1.1e+03 |
# |          MinEpRet |             120 |
# |  AverageTestEpRet |             551 |
# |      StdTestEpRet |             185 |
# |      MaxTestEpRet |             757 |
# |      MinTestEpRet |             307 |
# |             EpLen |             195 |
# |         TestEpLen |             343 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             110 |
# |         StdQ1Vals |            28.2 |
# |         MaxQ1Vals |             145 |
# |         MinQ1Vals |           -54.3 |
# |     AverageQ2Vals |             110 |
# |         StdQ2Vals |            28.2 |
# |         MaxQ2Vals |             144 |
# |         MinQ2Vals |           -52.4 |
# |            LossPi |            -111 |
# |             LossQ |            15.4 |
# |              Time |        4.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             293 |
# |          StdEpRet |             121 |
# |          MaxEpRet |             523 |
# |          MinEpRet |             122 |
# |  AverageTestEpRet |             185 |
# |      StdTestEpRet |            35.7 |
# |      MaxTestEpRet |             256 |
# |      MinTestEpRet |             160 |
# |             EpLen |             187 |
# |         TestEpLen |             106 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             109 |
# |         StdQ1Vals |            28.6 |
# |         MaxQ1Vals |             145 |
# |         MinQ1Vals |           -60.3 |
# |     AverageQ2Vals |             109 |
# |         StdQ2Vals |            28.6 |
# |         MaxQ2Vals |             145 |
# |         MinQ2Vals |           -68.2 |
# |            LossPi |            -111 |
# |             LossQ |            15.7 |
# |              Time |         4.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             268 |
# |          StdEpRet |             137 |
# |          MaxEpRet |             689 |
# |          MinEpRet |             130 |
# |  AverageTestEpRet |             872 |
# |      StdTestEpRet |             515 |
# |      MaxTestEpRet |         1.5e+03 |
# |      MinTestEpRet |             200 |
# |             EpLen |             168 |
# |         TestEpLen |             570 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             110 |
# |         StdQ1Vals |            29.3 |
# |         MaxQ1Vals |             145 |
# |         MinQ1Vals |           -53.2 |
# |     AverageQ2Vals |             110 |
# |         StdQ2Vals |            29.3 |
# |         MaxQ2Vals |             142 |
# |         MinQ2Vals |           -64.3 |
# |            LossPi |            -111 |
# |             LossQ |            16.1 |
# |              Time |        4.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             424 |
# |          StdEpRet |             253 |
# |          MaxEpRet |        1.08e+03 |
# |          MinEpRet |             169 |
# |  AverageTestEpRet |             401 |
# |      StdTestEpRet |            30.8 |
# |      MaxTestEpRet |             449 |
# |      MinTestEpRet |             362 |
# |             EpLen |             282 |
# |         TestEpLen |             209 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             110 |
# |         StdQ1Vals |            29.9 |
# |         MaxQ1Vals |             148 |
# |         MinQ1Vals |           -52.6 |
# |     AverageQ2Vals |             110 |
# |         StdQ2Vals |            29.9 |
# |         MaxQ2Vals |             141 |
# |         MinQ2Vals |           -44.1 |
# |            LossPi |            -112 |
# |             LossQ |            16.5 |
# |              Time |        5.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |             694 |
# |          StdEpRet |             404 |
# |          MaxEpRet |        1.32e+03 |
# |          MinEpRet |             220 |
# |  AverageTestEpRet |             225 |
# |      StdTestEpRet |            47.6 |
# |      MaxTestEpRet |             274 |
# |      MinTestEpRet |             145 |
# |             EpLen |             446 |
# |         TestEpLen |             127 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            30.3 |
# |         MaxQ1Vals |             148 |
# |         MinQ1Vals |             -43 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            30.3 |
# |         MaxQ2Vals |             143 |
# |         MinQ2Vals |           -49.1 |
# |            LossPi |            -112 |
# |             LossQ |            17.3 |
# |              Time |        5.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |             329 |
# |          StdEpRet |             189 |
# |          MaxEpRet |           1e+03 |
# |          MinEpRet |             130 |
# |  AverageTestEpRet |        1.26e+03 |
# |      StdTestEpRet |             342 |
# |      MaxTestEpRet |        1.71e+03 |
# |      MinTestEpRet |             725 |
# |             EpLen |             191 |
# |         TestEpLen |             740 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            30.4 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |           -48.5 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            30.4 |
# |         MaxQ2Vals |             142 |
# |         MinQ2Vals |           -39.3 |
# |            LossPi |            -112 |
# |             LossQ |            17.5 |
# |              Time |        5.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             360 |
# |          StdEpRet |             161 |
# |          MaxEpRet |             830 |
# |          MinEpRet |             183 |
# |  AverageTestEpRet |             458 |
# |      StdTestEpRet |             135 |
# |      MaxTestEpRet |             576 |
# |      MinTestEpRet |             287 |
# |             EpLen |             201 |
# |         TestEpLen |             246 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            30.5 |
# |         MaxQ1Vals |             145 |
# |         MinQ1Vals |           -47.9 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            30.5 |
# |         MaxQ2Vals |             144 |
# |         MinQ2Vals |           -53.6 |
# |            LossPi |            -112 |
# |             LossQ |            17.1 |
# |              Time |        5.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             277 |
# |          StdEpRet |             119 |
# |          MaxEpRet |             548 |
# |          MinEpRet |             124 |
# |  AverageTestEpRet |         1.2e+03 |
# |      StdTestEpRet |             313 |
# |      MaxTestEpRet |        1.46e+03 |
# |      MinTestEpRet |             751 |
# |             EpLen |             166 |
# |         TestEpLen |             809 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            30.4 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |           -51.3 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            30.4 |
# |         MaxQ2Vals |             147 |
# |         MinQ2Vals |           -64.5 |
# |            LossPi |            -112 |
# |             LossQ |            17.8 |
# |              Time |        5.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |             325 |
# |          StdEpRet |             245 |
# |          MaxEpRet |        1.12e+03 |
# |          MinEpRet |             134 |
# |  AverageTestEpRet |         1.1e+03 |
# |      StdTestEpRet |            3.64 |
# |      MaxTestEpRet |        1.11e+03 |
# |      MinTestEpRet |         1.1e+03 |
# |             EpLen |             219 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            30.7 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |           -45.5 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            30.7 |
# |         MaxQ2Vals |             146 |
# |         MinQ2Vals |           -40.7 |
# |            LossPi |            -113 |
# |             LossQ |            17.6 |
# |              Time |        5.65e+03 |
# ---------------------------------------

# %%
args = {'env': 'AntMuJoCoEnv-v0', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'exp_name': 'td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"AntMuJoCoEnv-v0",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D2880FD08>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\\\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
# options=
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |             622 |
# |          StdEpRet |            25.2 |
# |          MaxEpRet |             662 |
# |          MinEpRet |             595 |
# |  AverageTestEpRet |             291 |
# |      StdTestEpRet |            11.1 |
# |      MaxTestEpRet |             308 |
# |      MinTestEpRet |             273 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            5.37 |
# |         StdQ1Vals |            3.02 |
# |         MaxQ1Vals |            13.9 |
# |         MinQ1Vals |         -0.0156 |
# |     AverageQ2Vals |            5.37 |
# |         StdQ2Vals |            3.02 |
# |         MaxQ2Vals |            13.9 |
# |         MinQ2Vals |          0.0567 |
# |            LossPi |           -5.64 |
# |             LossQ |          0.0287 |
# |              Time |            88.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |             607 |
# |          StdEpRet |            52.9 |
# |          MaxEpRet |             671 |
# |          MinEpRet |             526 |
# |  AverageTestEpRet |             247 |
# |      StdTestEpRet |            44.9 |
# |      MaxTestEpRet |             309 |
# |      MinTestEpRet |             206 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            18.2 |
# |         StdQ1Vals |            4.48 |
# |         MaxQ1Vals |            34.9 |
# |         MinQ1Vals |            8.85 |
# |     AverageQ2Vals |            18.2 |
# |         StdQ2Vals |            4.48 |
# |         MaxQ2Vals |            34.4 |
# |         MinQ2Vals |            8.86 |
# |            LossPi |           -18.7 |
# |             LossQ |          0.0637 |
# |              Time |             203 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |             381 |
# |          StdEpRet |             178 |
# |          MaxEpRet |             571 |
# |          MinEpRet |             198 |
# |  AverageTestEpRet |             208 |
# |      StdTestEpRet |            5.18 |
# |      MaxTestEpRet |             214 |
# |      MinTestEpRet |             199 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            30.9 |
# |         StdQ1Vals |            5.54 |
# |         MaxQ1Vals |            47.8 |
# |         MinQ1Vals |            17.7 |
# |     AverageQ2Vals |            30.9 |
# |         StdQ2Vals |            5.54 |
# |         MaxQ2Vals |            46.8 |
# |         MinQ2Vals |            17.9 |
# |            LossPi |           -31.4 |
# |             LossQ |          0.0889 |
# |              Time |             351 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             275 |
# |          StdEpRet |            45.1 |
# |          MaxEpRet |             325 |
# |          MinEpRet |             207 |
# |  AverageTestEpRet |             274 |
# |      StdTestEpRet |            11.1 |
# |      MaxTestEpRet |             291 |
# |      MinTestEpRet |             257 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            41.2 |
# |         StdQ1Vals |            4.06 |
# |         MaxQ1Vals |            55.4 |
# |         MinQ1Vals |            14.7 |
# |     AverageQ2Vals |            41.2 |
# |         StdQ2Vals |            4.06 |
# |         MaxQ2Vals |            55.5 |
# |         MinQ2Vals |            15.6 |
# |            LossPi |           -41.5 |
# |             LossQ |           0.118 |
# |              Time |             486 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             293 |
# |          StdEpRet |            40.1 |
# |          MaxEpRet |             322 |
# |          MinEpRet |             224 |
# |  AverageTestEpRet |             301 |
# |      StdTestEpRet |             8.3 |
# |      MaxTestEpRet |             307 |
# |      MinTestEpRet |             285 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            42.2 |
# |         StdQ1Vals |            5.76 |
# |         MaxQ1Vals |            60.4 |
# |         MinQ1Vals |            20.7 |
# |     AverageQ2Vals |            42.2 |
# |         StdQ2Vals |            5.76 |
# |         MaxQ2Vals |            60.3 |
# |         MinQ2Vals |            20.9 |
# |            LossPi |           -42.4 |
# |             LossQ |          0.0943 |
# |              Time |             608 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             328 |
# |          StdEpRet |            30.6 |
# |          MaxEpRet |             375 |
# |          MinEpRet |             300 |
# |  AverageTestEpRet |             330 |
# |      StdTestEpRet |            55.4 |
# |      MaxTestEpRet |             418 |
# |      MinTestEpRet |             270 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            43.3 |
# |         StdQ1Vals |            7.06 |
# |         MaxQ1Vals |            64.2 |
# |         MinQ1Vals |            18.5 |
# |     AverageQ2Vals |            43.3 |
# |         StdQ2Vals |            7.06 |
# |         MaxQ2Vals |            64.4 |
# |         MinQ2Vals |            18.3 |
# |            LossPi |           -43.6 |
# |             LossQ |          0.0892 |
# |              Time |             733 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             339 |
# |          StdEpRet |            39.4 |
# |          MaxEpRet |             405 |
# |          MinEpRet |             299 |
# |  AverageTestEpRet |             316 |
# |      StdTestEpRet |            3.87 |
# |      MaxTestEpRet |             319 |
# |      MinTestEpRet |             309 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            44.8 |
# |         StdQ1Vals |            7.84 |
# |         MaxQ1Vals |            66.5 |
# |         MinQ1Vals |            16.1 |
# |     AverageQ2Vals |            44.8 |
# |         StdQ2Vals |            7.84 |
# |         MaxQ2Vals |            66.7 |
# |         MinQ2Vals |            15.9 |
# |            LossPi |             -45 |
# |             LossQ |           0.102 |
# |              Time |             868 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             319 |
# |          StdEpRet |              41 |
# |          MaxEpRet |             376 |
# |          MinEpRet |             280 |
# |  AverageTestEpRet |             280 |
# |      StdTestEpRet |            2.44 |
# |      MaxTestEpRet |             284 |
# |      MinTestEpRet |             277 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            45.3 |
# |         StdQ1Vals |            8.36 |
# |         MaxQ1Vals |              69 |
# |         MinQ1Vals |            14.4 |
# |     AverageQ2Vals |            45.3 |
# |         StdQ2Vals |            8.36 |
# |         MaxQ2Vals |            68.8 |
# |         MinQ2Vals |              14 |
# |            LossPi |           -45.4 |
# |             LossQ |           0.107 |
# |              Time |             998 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             283 |
# |          StdEpRet |            9.24 |
# |          MaxEpRet |             295 |
# |          MinEpRet |             270 |
# |  AverageTestEpRet |             279 |
# |      StdTestEpRet |            3.73 |
# |      MaxTestEpRet |             282 |
# |      MinTestEpRet |             273 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            44.2 |
# |         StdQ1Vals |            9.76 |
# |         MaxQ1Vals |            70.1 |
# |         MinQ1Vals |              15 |
# |     AverageQ2Vals |            44.2 |
# |         StdQ2Vals |            9.76 |
# |         MaxQ2Vals |            70.1 |
# |         MinQ2Vals |            14.8 |
# |            LossPi |           -44.4 |
# |             LossQ |           0.126 |
# |              Time |        1.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             290 |
# |          StdEpRet |            7.88 |
# |          MaxEpRet |             301 |
# |          MinEpRet |             279 |
# |  AverageTestEpRet |             432 |
# |      StdTestEpRet |            37.6 |
# |      MaxTestEpRet |             486 |
# |      MinTestEpRet |             386 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            42.9 |
# |         StdQ1Vals |            11.1 |
# |         MaxQ1Vals |            71.7 |
# |         MinQ1Vals |            15.8 |
# |     AverageQ2Vals |            42.9 |
# |         StdQ2Vals |            11.1 |
# |         MaxQ2Vals |            71.8 |
# |         MinQ2Vals |            15.6 |
# |            LossPi |           -43.1 |
# |             LossQ |           0.149 |
# |              Time |        1.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             408 |
# |          StdEpRet |            24.6 |
# |          MaxEpRet |             434 |
# |          MinEpRet |             371 |
# |  AverageTestEpRet |             411 |
# |      StdTestEpRet |            21.5 |
# |      MaxTestEpRet |             429 |
# |      MinTestEpRet |             372 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            42.3 |
# |         StdQ1Vals |            11.5 |
# |         MaxQ1Vals |            84.1 |
# |         MinQ1Vals |            17.8 |
# |     AverageQ2Vals |            42.3 |
# |         StdQ2Vals |            11.5 |
# |         MaxQ2Vals |            84.2 |
# |         MinQ2Vals |            17.9 |
# |            LossPi |           -42.6 |
# |             LossQ |           0.184 |
# |              Time |        1.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             276 |
# |          StdEpRet |            64.2 |
# |          MaxEpRet |             373 |
# |          MinEpRet |             217 |
# |  AverageTestEpRet |             330 |
# |      StdTestEpRet |            35.6 |
# |      MaxTestEpRet |             401 |
# |      MinTestEpRet |             309 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            47.9 |
# |         StdQ1Vals |            14.5 |
# |         MaxQ1Vals |              90 |
# |         MinQ1Vals |            16.3 |
# |     AverageQ2Vals |            47.9 |
# |         StdQ2Vals |            14.5 |
# |         MaxQ2Vals |            89.9 |
# |         MinQ2Vals |            15.9 |
# |            LossPi |           -48.7 |
# |             LossQ |           0.202 |
# |              Time |        1.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             323 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |             369 |
# |          MinEpRet |             305 |
# |  AverageTestEpRet |             378 |
# |      StdTestEpRet |            33.3 |
# |      MaxTestEpRet |             409 |
# |      MinTestEpRet |             326 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            52.7 |
# |         StdQ1Vals |            14.2 |
# |         MaxQ1Vals |            82.4 |
# |         MinQ1Vals |            17.8 |
# |     AverageQ2Vals |            52.7 |
# |         StdQ2Vals |            14.2 |
# |         MaxQ2Vals |            82.2 |
# |         MinQ2Vals |            17.5 |
# |            LossPi |           -53.7 |
# |             LossQ |            0.19 |
# |              Time |        1.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             413 |
# |          StdEpRet |             105 |
# |          MaxEpRet |             584 |
# |          MinEpRet |             300 |
# |  AverageTestEpRet |             424 |
# |      StdTestEpRet |            18.9 |
# |      MaxTestEpRet |             446 |
# |      MinTestEpRet |             389 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            56.2 |
# |         StdQ1Vals |            10.7 |
# |         MaxQ1Vals |            81.2 |
# |         MinQ1Vals |            23.9 |
# |     AverageQ2Vals |            56.2 |
# |         StdQ2Vals |            10.7 |
# |         MaxQ2Vals |            81.7 |
# |         MinQ2Vals |            23.9 |
# |            LossPi |             -57 |
# |             LossQ |           0.155 |
# |              Time |        1.78e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             465 |
# |          StdEpRet |            77.1 |
# |          MaxEpRet |             550 |
# |          MinEpRet |             355 |
# |  AverageTestEpRet |             411 |
# |      StdTestEpRet |            40.1 |
# |      MaxTestEpRet |             465 |
# |      MinTestEpRet |             372 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            58.5 |
# |         StdQ1Vals |            8.93 |
# |         MaxQ1Vals |            81.1 |
# |         MinQ1Vals |            32.4 |
# |     AverageQ2Vals |            58.5 |
# |         StdQ2Vals |            8.93 |
# |         MaxQ2Vals |            80.4 |
# |         MinQ2Vals |              33 |
# |            LossPi |           -59.1 |
# |             LossQ |           0.166 |
# |              Time |        1.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             602 |
# |          StdEpRet |            75.8 |
# |          MaxEpRet |             695 |
# |          MinEpRet |             496 |
# |  AverageTestEpRet |             476 |
# |      StdTestEpRet |             108 |
# |      MaxTestEpRet |             677 |
# |      MinTestEpRet |             353 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            60.9 |
# |         StdQ1Vals |            9.11 |
# |         MaxQ1Vals |            79.7 |
# |         MinQ1Vals |            35.6 |
# |     AverageQ2Vals |            60.9 |
# |         StdQ2Vals |            9.11 |
# |         MaxQ2Vals |            79.6 |
# |         MinQ2Vals |            35.2 |
# |            LossPi |           -61.7 |
# |             LossQ |           0.167 |
# |              Time |        2.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             505 |
# |          StdEpRet |            62.1 |
# |          MaxEpRet |             574 |
# |          MinEpRet |             413 |
# |  AverageTestEpRet |             375 |
# |      StdTestEpRet |            61.3 |
# |      MaxTestEpRet |             462 |
# |      MinTestEpRet |             306 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            62.6 |
# |         StdQ1Vals |            9.04 |
# |         MaxQ1Vals |            79.6 |
# |         MinQ1Vals |            35.4 |
# |     AverageQ2Vals |            62.6 |
# |         StdQ2Vals |            9.04 |
# |         MaxQ2Vals |            79.4 |
# |         MinQ2Vals |            36.2 |
# |            LossPi |           -63.4 |
# |             LossQ |           0.182 |
# |              Time |        2.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             397 |
# |          StdEpRet |             108 |
# |          MaxEpRet |             544 |
# |          MinEpRet |             294 |
# |  AverageTestEpRet |             517 |
# |      StdTestEpRet |            40.5 |
# |      MaxTestEpRet |             574 |
# |      MinTestEpRet |             462 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |              62 |
# |         StdQ1Vals |            8.85 |
# |         MaxQ1Vals |            79.4 |
# |         MinQ1Vals |            29.9 |
# |     AverageQ2Vals |              62 |
# |         StdQ2Vals |            8.85 |
# |         MaxQ2Vals |            79.3 |
# |         MinQ2Vals |            29.4 |
# |            LossPi |           -62.9 |
# |             LossQ |           0.228 |
# |              Time |        2.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             576 |
# |          StdEpRet |            95.9 |
# |          MaxEpRet |             679 |
# |          MinEpRet |             426 |
# |  AverageTestEpRet |             551 |
# |      StdTestEpRet |            44.3 |
# |      MaxTestEpRet |             614 |
# |      MinTestEpRet |             489 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            61.3 |
# |         StdQ1Vals |             7.9 |
# |         MaxQ1Vals |            78.6 |
# |         MinQ1Vals |            36.1 |
# |     AverageQ2Vals |            61.3 |
# |         StdQ2Vals |             7.9 |
# |         MaxQ2Vals |            78.7 |
# |         MinQ2Vals |            36.3 |
# |            LossPi |           -62.2 |
# |             LossQ |            0.27 |
# |              Time |        2.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             614 |
# |          StdEpRet |            63.5 |
# |          MaxEpRet |             698 |
# |          MinEpRet |             522 |
# |  AverageTestEpRet |             651 |
# |      StdTestEpRet |            62.5 |
# |      MaxTestEpRet |             709 |
# |      MinTestEpRet |             567 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            60.8 |
# |         StdQ1Vals |            7.57 |
# |         MaxQ1Vals |            76.5 |
# |         MinQ1Vals |            35.4 |
# |     AverageQ2Vals |            60.8 |
# |         StdQ2Vals |            7.57 |
# |         MaxQ2Vals |            76.5 |
# |         MinQ2Vals |            36.8 |
# |            LossPi |           -61.6 |
# |             LossQ |           0.256 |
# |              Time |        2.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             648 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |             659 |
# |          MinEpRet |             627 |
# |  AverageTestEpRet |             694 |
# |      StdTestEpRet |            58.3 |
# |      MaxTestEpRet |             746 |
# |      MinTestEpRet |             583 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            60.7 |
# |         StdQ1Vals |            6.92 |
# |         MaxQ1Vals |            74.9 |
# |         MinQ1Vals |              36 |
# |     AverageQ2Vals |            60.7 |
# |         StdQ2Vals |            6.92 |
# |         MaxQ2Vals |            75.1 |
# |         MinQ2Vals |              37 |
# |            LossPi |           -61.4 |
# |             LossQ |            0.24 |
# |              Time |        2.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             652 |
# |          StdEpRet |            94.3 |
# |          MaxEpRet |             729 |
# |          MinEpRet |             495 |
# |  AverageTestEpRet |             614 |
# |      StdTestEpRet |            68.3 |
# |      MaxTestEpRet |             680 |
# |      MinTestEpRet |             488 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            60.8 |
# |         StdQ1Vals |            7.39 |
# |         MaxQ1Vals |            75.2 |
# |         MinQ1Vals |            34.3 |
# |     AverageQ2Vals |            60.8 |
# |         StdQ2Vals |            7.39 |
# |         MaxQ2Vals |            75.2 |
# |         MinQ2Vals |            34.4 |
# |            LossPi |           -61.5 |
# |             LossQ |           0.243 |
# |              Time |        2.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             749 |
# |          StdEpRet |            67.3 |
# |          MaxEpRet |             836 |
# |          MinEpRet |             647 |
# |  AverageTestEpRet |             924 |
# |      StdTestEpRet |            53.4 |
# |      MaxTestEpRet |        1.02e+03 |
# |      MinTestEpRet |             859 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            61.5 |
# |         StdQ1Vals |            7.73 |
# |         MaxQ1Vals |            76.8 |
# |         MinQ1Vals |            33.5 |
# |     AverageQ2Vals |            61.5 |
# |         StdQ2Vals |            7.73 |
# |         MaxQ2Vals |              77 |
# |         MinQ2Vals |            33.9 |
# |            LossPi |           -62.3 |
# |             LossQ |           0.286 |
# |              Time |        2.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             750 |
# |          StdEpRet |             148 |
# |          MaxEpRet |             851 |
# |          MinEpRet |             497 |
# |  AverageTestEpRet |             729 |
# |      StdTestEpRet |            37.6 |
# |      MaxTestEpRet |             771 |
# |      MinTestEpRet |             669 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            63.2 |
# |         StdQ1Vals |               7 |
# |         MaxQ1Vals |            81.8 |
# |         MinQ1Vals |            36.9 |
# |     AverageQ2Vals |            63.2 |
# |         StdQ2Vals |            7.01 |
# |         MaxQ2Vals |            80.2 |
# |         MinQ2Vals |              36 |
# |            LossPi |             -64 |
# |             LossQ |           0.303 |
# |              Time |        3.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             740 |
# |          StdEpRet |            50.1 |
# |          MaxEpRet |             811 |
# |          MinEpRet |             673 |
# |  AverageTestEpRet |             748 |
# |      StdTestEpRet |            39.3 |
# |      MaxTestEpRet |             797 |
# |      MinTestEpRet |             689 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            64.7 |
# |         StdQ1Vals |            6.33 |
# |         MaxQ1Vals |            81.4 |
# |         MinQ1Vals |            41.9 |
# |     AverageQ2Vals |            64.7 |
# |         StdQ2Vals |            6.33 |
# |         MaxQ2Vals |            81.1 |
# |         MinQ2Vals |            41.8 |
# |            LossPi |           -65.4 |
# |             LossQ |           0.345 |
# |              Time |        3.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             796 |
# |          StdEpRet |            70.8 |
# |          MaxEpRet |             867 |
# |          MinEpRet |             699 |
# |  AverageTestEpRet |             777 |
# |      StdTestEpRet |            44.8 |
# |      MaxTestEpRet |             862 |
# |      MinTestEpRet |             741 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            66.1 |
# |         StdQ1Vals |            6.28 |
# |         MaxQ1Vals |            83.1 |
# |         MinQ1Vals |            35.6 |
# |     AverageQ2Vals |            66.1 |
# |         StdQ2Vals |            6.28 |
# |         MaxQ2Vals |            83.1 |
# |         MinQ2Vals |              38 |
# |            LossPi |           -66.7 |
# |             LossQ |           0.379 |
# |              Time |        3.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             823 |
# |          StdEpRet |            49.4 |
# |          MaxEpRet |             885 |
# |          MinEpRet |             759 |
# |  AverageTestEpRet |             749 |
# |      StdTestEpRet |             152 |
# |      MaxTestEpRet |             868 |
# |      MinTestEpRet |             454 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |              67 |
# |         StdQ1Vals |            6.44 |
# |         MaxQ1Vals |              88 |
# |         MinQ1Vals |              24 |
# |     AverageQ2Vals |              67 |
# |         StdQ2Vals |            6.45 |
# |         MaxQ2Vals |            86.1 |
# |         MinQ2Vals |            22.4 |
# |            LossPi |           -67.7 |
# |             LossQ |           0.423 |
# |              Time |        3.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             704 |
# |          StdEpRet |             194 |
# |          MaxEpRet |             849 |
# |          MinEpRet |             371 |
# |  AverageTestEpRet |             910 |
# |      StdTestEpRet |            35.1 |
# |      MaxTestEpRet |             944 |
# |      MinTestEpRet |             861 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            66.7 |
# |         StdQ1Vals |            8.32 |
# |         MaxQ1Vals |            90.2 |
# |         MinQ1Vals |            24.8 |
# |     AverageQ2Vals |            66.7 |
# |         StdQ2Vals |            8.32 |
# |         MaxQ2Vals |            90.9 |
# |         MinQ2Vals |            23.9 |
# |            LossPi |           -67.5 |
# |             LossQ |           0.527 |
# |              Time |        3.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             734 |
# |          StdEpRet |             181 |
# |          MaxEpRet |             911 |
# |          MinEpRet |             432 |
# |  AverageTestEpRet |             948 |
# |      StdTestEpRet |              37 |
# |      MaxTestEpRet |             983 |
# |      MinTestEpRet |             892 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            67.3 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |            98.7 |
# |         MinQ1Vals |            23.2 |
# |     AverageQ2Vals |            67.3 |
# |         StdQ2Vals |            10.2 |
# |         MaxQ2Vals |            96.6 |
# |         MinQ2Vals |            21.8 |
# |            LossPi |           -68.1 |
# |             LossQ |           0.606 |
# |              Time |        3.72e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             902 |
# |          StdEpRet |            47.3 |
# |          MaxEpRet |             979 |
# |          MinEpRet |             855 |
# |  AverageTestEpRet |             941 |
# |      StdTestEpRet |            26.9 |
# |      MaxTestEpRet |             964 |
# |      MinTestEpRet |             889 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            68.4 |
# |         StdQ1Vals |            11.1 |
# |         MaxQ1Vals |            98.5 |
# |         MinQ1Vals |            19.8 |
# |     AverageQ2Vals |            68.4 |
# |         StdQ2Vals |            11.1 |
# |         MaxQ2Vals |            96.8 |
# |         MinQ2Vals |            18.8 |
# |            LossPi |           -69.2 |
# |             LossQ |           0.654 |
# |              Time |        3.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             915 |
# |          StdEpRet |            23.6 |
# |          MaxEpRet |             947 |
# |          MinEpRet |             882 |
# |  AverageTestEpRet |             884 |
# |      StdTestEpRet |            51.9 |
# |      MaxTestEpRet |             961 |
# |      MinTestEpRet |             821 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            69.3 |
# |         StdQ1Vals |            11.6 |
# |         MaxQ1Vals |            97.1 |
# |         MinQ1Vals |            13.6 |
# |     AverageQ2Vals |            69.3 |
# |         StdQ2Vals |            11.6 |
# |         MaxQ2Vals |              97 |
# |         MinQ2Vals |            14.6 |
# |            LossPi |           -70.1 |
# |             LossQ |           0.685 |
# |              Time |           4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             786 |
# |          StdEpRet |            96.4 |
# |          MaxEpRet |             874 |
# |          MinEpRet |             623 |
# |  AverageTestEpRet |             894 |
# |      StdTestEpRet |            31.7 |
# |      MaxTestEpRet |             944 |
# |      MinTestEpRet |             846 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            70.6 |
# |         StdQ1Vals |            11.4 |
# |         MaxQ1Vals |              99 |
# |         MinQ1Vals |            14.3 |
# |     AverageQ2Vals |            70.6 |
# |         StdQ2Vals |            11.4 |
# |         MaxQ2Vals |            99.2 |
# |         MinQ2Vals |            14.3 |
# |            LossPi |           -71.4 |
# |             LossQ |           0.782 |
# |              Time |        4.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             864 |
# |          StdEpRet |             104 |
# |          MaxEpRet |             964 |
# |          MinEpRet |             701 |
# |  AverageTestEpRet |        1.08e+03 |
# |      StdTestEpRet |            61.9 |
# |      MaxTestEpRet |        1.15e+03 |
# |      MinTestEpRet |             981 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            71.9 |
# |         StdQ1Vals |              11 |
# |         MaxQ1Vals |             103 |
# |         MinQ1Vals |            20.6 |
# |     AverageQ2Vals |            71.9 |
# |         StdQ2Vals |              11 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |            20.1 |
# |            LossPi |           -72.8 |
# |             LossQ |           0.797 |
# |              Time |        4.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             872 |
# |          StdEpRet |             212 |
# |          MaxEpRet |        1.03e+03 |
# |          MinEpRet |             512 |
# |  AverageTestEpRet |             928 |
# |      StdTestEpRet |             181 |
# |      MaxTestEpRet |        1.12e+03 |
# |      MinTestEpRet |             584 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |            73.3 |
# |         StdQ1Vals |            10.9 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |            22.4 |
# |     AverageQ2Vals |            73.3 |
# |         StdQ2Vals |            10.9 |
# |         MaxQ2Vals |             104 |
# |         MinQ2Vals |            22.5 |
# |            LossPi |           -74.2 |
# |             LossQ |           0.844 |
# |              Time |        4.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |        1.05e+03 |
# |          StdEpRet |            37.2 |
# |          MaxEpRet |         1.1e+03 |
# |          MinEpRet |             996 |
# |  AverageTestEpRet |             990 |
# |      StdTestEpRet |            51.3 |
# |      MaxTestEpRet |        1.06e+03 |
# |      MinTestEpRet |             929 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            74.4 |
# |         StdQ1Vals |            11.5 |
# |         MaxQ1Vals |             106 |
# |         MinQ1Vals |            18.8 |
# |     AverageQ2Vals |            74.4 |
# |         StdQ2Vals |            11.5 |
# |         MaxQ2Vals |             106 |
# |         MinQ2Vals |            15.6 |
# |            LossPi |           -75.3 |
# |             LossQ |           0.794 |
# |              Time |        4.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             885 |
# |          StdEpRet |             156 |
# |          MaxEpRet |        1.04e+03 |
# |          MinEpRet |             631 |
# |  AverageTestEpRet |             846 |
# |      StdTestEpRet |             132 |
# |      MaxTestEpRet |        1.04e+03 |
# |      MinTestEpRet |             629 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |            75.6 |
# |         StdQ1Vals |            11.7 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |              16 |
# |     AverageQ2Vals |            75.6 |
# |         StdQ2Vals |            11.7 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |              16 |
# |            LossPi |           -76.5 |
# |             LossQ |           0.814 |
# |              Time |        4.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |           1e+03 |
# |          StdEpRet |            37.2 |
# |          MaxEpRet |        1.04e+03 |
# |          MinEpRet |             940 |
# |  AverageTestEpRet |             949 |
# |      StdTestEpRet |            44.4 |
# |      MaxTestEpRet |        1.01e+03 |
# |      MinTestEpRet |             891 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            76.9 |
# |         StdQ1Vals |            11.6 |
# |         MaxQ1Vals |             103 |
# |         MinQ1Vals |            21.5 |
# |     AverageQ2Vals |            76.9 |
# |         StdQ2Vals |            11.6 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |            21.3 |
# |            LossPi |           -77.8 |
# |             LossQ |           0.816 |
# |              Time |        4.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             914 |
# |          StdEpRet |            38.5 |
# |          MaxEpRet |             964 |
# |          MinEpRet |             856 |
# |  AverageTestEpRet |             889 |
# |      StdTestEpRet |            32.7 |
# |      MaxTestEpRet |             925 |
# |      MinTestEpRet |             836 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |            78.4 |
# |         StdQ1Vals |            11.3 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |            27.2 |
# |     AverageQ2Vals |            78.4 |
# |         StdQ2Vals |            11.3 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |            26.2 |
# |            LossPi |           -79.3 |
# |             LossQ |           0.787 |
# |              Time |        4.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |             846 |
# |          StdEpRet |            74.7 |
# |          MaxEpRet |             931 |
# |          MinEpRet |             727 |
# |  AverageTestEpRet |             909 |
# |      StdTestEpRet |            64.8 |
# |      MaxTestEpRet |             975 |
# |      MinTestEpRet |             825 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |            79.9 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |             105 |
# |         MinQ1Vals |            33.8 |
# |     AverageQ2Vals |            79.9 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |             105 |
# |         MinQ2Vals |            34.9 |
# |            LossPi |           -80.8 |
# |             LossQ |            0.73 |
# |              Time |        5.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |             942 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |             982 |
# |          MinEpRet |             913 |
# |  AverageTestEpRet |             948 |
# |      StdTestEpRet |            39.6 |
# |      MaxTestEpRet |             997 |
# |      MinTestEpRet |             896 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |            80.7 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |             107 |
# |         MinQ1Vals |            36.2 |
# |     AverageQ2Vals |            80.7 |
# |         StdQ2Vals |            10.8 |
# |         MaxQ2Vals |             106 |
# |         MinQ2Vals |            36.2 |
# |            LossPi |           -81.5 |
# |             LossQ |           0.708 |
# |              Time |        5.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             913 |
# |          StdEpRet |            73.6 |
# |          MaxEpRet |           1e+03 |
# |          MinEpRet |             799 |
# |  AverageTestEpRet |        1.08e+03 |
# |      StdTestEpRet |            51.5 |
# |      MaxTestEpRet |        1.12e+03 |
# |      MinTestEpRet |             990 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |            81.8 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |            36.8 |
# |     AverageQ2Vals |            81.8 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |             107 |
# |         MinQ2Vals |            37.2 |
# |            LossPi |           -82.6 |
# |             LossQ |           0.708 |
# |              Time |        5.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        1.01e+03 |
# |          StdEpRet |            51.9 |
# |          MaxEpRet |        1.08e+03 |
# |          MinEpRet |             938 |
# |  AverageTestEpRet |             966 |
# |      StdTestEpRet |            64.4 |
# |      MaxTestEpRet |        1.07e+03 |
# |      MinTestEpRet |             893 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |            82.9 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |            38.7 |
# |     AverageQ2Vals |            82.9 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |             107 |
# |         MinQ2Vals |            38.7 |
# |            LossPi |           -83.6 |
# |             LossQ |           0.685 |
# |              Time |        5.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        1.01e+03 |
# |          StdEpRet |             133 |
# |          MaxEpRet |        1.13e+03 |
# |          MinEpRet |             796 |
# |  AverageTestEpRet |             997 |
# |      StdTestEpRet |             135 |
# |      MaxTestEpRet |        1.12e+03 |
# |      MinTestEpRet |             741 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |            83.5 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |            35.1 |
# |     AverageQ2Vals |            83.5 |
# |         StdQ2Vals |            10.8 |
# |         MaxQ2Vals |             107 |
# |         MinQ2Vals |            33.1 |
# |            LossPi |           -84.2 |
# |             LossQ |            0.71 |
# |              Time |        5.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             944 |
# |          StdEpRet |             125 |
# |          MaxEpRet |        1.07e+03 |
# |          MinEpRet |             782 |
# |  AverageTestEpRet |             866 |
# |      StdTestEpRet |             107 |
# |      MaxTestEpRet |        1.07e+03 |
# |      MinTestEpRet |             753 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |            83.9 |
# |         StdQ1Vals |            11.7 |
# |         MaxQ1Vals |             109 |
# |         MinQ1Vals |            30.5 |
# |     AverageQ2Vals |            83.9 |
# |         StdQ2Vals |            11.7 |
# |         MaxQ2Vals |             109 |
# |         MinQ2Vals |            28.6 |
# |            LossPi |           -84.7 |
# |             LossQ |           0.701 |
# |              Time |        5.69e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             911 |
# |          StdEpRet |            88.4 |
# |          MaxEpRet |        1.01e+03 |
# |          MinEpRet |             793 |
# |  AverageTestEpRet |             758 |
# |      StdTestEpRet |            63.6 |
# |      MaxTestEpRet |             849 |
# |      MinTestEpRet |             670 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |            84.8 |
# |         StdQ1Vals |            12.2 |
# |         MaxQ1Vals |             111 |
# |         MinQ1Vals |            29.5 |
# |     AverageQ2Vals |            84.8 |
# |         StdQ2Vals |            12.2 |
# |         MaxQ2Vals |             110 |
# |         MinQ2Vals |            28.8 |
# |            LossPi |           -85.6 |
# |             LossQ |           0.742 |
# |              Time |        5.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        1.01e+03 |
# |          StdEpRet |             104 |
# |          MaxEpRet |         1.1e+03 |
# |          MinEpRet |             835 |
# |  AverageTestEpRet |        1.01e+03 |
# |      StdTestEpRet |             102 |
# |      MaxTestEpRet |        1.14e+03 |
# |      MinTestEpRet |             855 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |            85.7 |
# |         StdQ1Vals |            12.4 |
# |         MaxQ1Vals |             113 |
# |         MinQ1Vals |            29.7 |
# |     AverageQ2Vals |            85.7 |
# |         StdQ2Vals |            12.4 |
# |         MaxQ2Vals |             112 |
# |         MinQ2Vals |            27.7 |
# |            LossPi |           -86.5 |
# |             LossQ |           0.765 |
# |              Time |        5.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        1.09e+03 |
# |          StdEpRet |            77.8 |
# |          MaxEpRet |        1.16e+03 |
# |          MinEpRet |             979 |
# |  AverageTestEpRet |             967 |
# |      StdTestEpRet |             135 |
# |      MaxTestEpRet |        1.05e+03 |
# |      MinTestEpRet |             701 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |              87 |
# |         StdQ1Vals |            12.5 |
# |         MaxQ1Vals |             114 |
# |         MinQ1Vals |            35.3 |
# |     AverageQ2Vals |              87 |
# |         StdQ2Vals |            12.5 |
# |         MaxQ2Vals |             114 |
# |         MinQ2Vals |            33.8 |
# |            LossPi |           -87.8 |
# |             LossQ |           0.772 |
# |              Time |        6.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        1.06e+03 |
# |          StdEpRet |              54 |
# |          MaxEpRet |        1.11e+03 |
# |          MinEpRet |             970 |
# |  AverageTestEpRet |        1.08e+03 |
# |      StdTestEpRet |            39.2 |
# |      MaxTestEpRet |        1.11e+03 |
# |      MinTestEpRet |           1e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |            87.6 |
# |         StdQ1Vals |            13.7 |
# |         MaxQ1Vals |             120 |
# |         MinQ1Vals |            33.8 |
# |     AverageQ2Vals |            87.6 |
# |         StdQ2Vals |            13.7 |
# |         MaxQ2Vals |             120 |
# |         MinQ2Vals |            32.6 |
# |            LossPi |           -88.5 |
# |             LossQ |           0.827 |
# |              Time |        6.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        1.06e+03 |
# |          StdEpRet |            18.3 |
# |          MaxEpRet |        1.09e+03 |
# |          MinEpRet |        1.04e+03 |
# |  AverageTestEpRet |        1.04e+03 |
# |      StdTestEpRet |            92.9 |
# |      MaxTestEpRet |        1.12e+03 |
# |      MinTestEpRet |             868 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |            87.8 |
# |         StdQ1Vals |            14.8 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            26.7 |
# |     AverageQ2Vals |            87.8 |
# |         StdQ2Vals |            14.8 |
# |         MaxQ2Vals |             123 |
# |         MinQ2Vals |            21.8 |
# |            LossPi |           -88.7 |
# |             LossQ |           0.872 |
# |              Time |        6.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        1.03e+03 |
# |          StdEpRet |            21.2 |
# |          MaxEpRet |        1.06e+03 |
# |          MinEpRet |        1.01e+03 |
# |  AverageTestEpRet |             921 |
# |      StdTestEpRet |             126 |
# |      MaxTestEpRet |        1.04e+03 |
# |      MinTestEpRet |             710 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |              88 |
# |         StdQ1Vals |            15.6 |
# |         MaxQ1Vals |             130 |
# |         MinQ1Vals |            23.4 |
# |     AverageQ2Vals |              88 |
# |         StdQ2Vals |            15.6 |
# |         MaxQ2Vals |             131 |
# |         MinQ2Vals |            18.6 |
# |            LossPi |           -88.8 |
# |             LossQ |           0.963 |
# |              Time |        6.47e+03 |
# ---------------------------------------

# %%
args = {'env': 'AntMuJoCoEnv-v0', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': False,
        'exp_name': 'td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"AntMuJoCoEnv-v0",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D1E23EAC8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False\\\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False\\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	false,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
# options=
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |             600 |
# |          StdEpRet |            18.8 |
# |          MaxEpRet |             627 |
# |          MinEpRet |             574 |
# |  AverageTestEpRet |             201 |
# |      StdTestEpRet |             2.4 |
# |      MaxTestEpRet |             205 |
# |      MinTestEpRet |             198 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            8.62 |
# |         StdQ1Vals |            5.27 |
# |         MaxQ1Vals |            27.2 |
# |         MinQ1Vals |          -0.163 |
# |     AverageQ2Vals |            8.62 |
# |         StdQ2Vals |            5.27 |
# |         MaxQ2Vals |            27.2 |
# |         MinQ2Vals |         -0.0209 |
# |            LossPi |           -9.47 |
# |             LossQ |          0.0692 |
# |              Time |              84 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |             569 |
# |          StdEpRet |            4.21 |
# |          MaxEpRet |             576 |
# |          MinEpRet |             565 |
# |  AverageTestEpRet |             220 |
# |      StdTestEpRet |            31.1 |
# |      MaxTestEpRet |             282 |
# |      MinTestEpRet |             200 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            38.9 |
# |         StdQ1Vals |            15.5 |
# |         MaxQ1Vals |             106 |
# |         MinQ1Vals |            13.2 |
# |     AverageQ2Vals |            38.9 |
# |         StdQ2Vals |            15.5 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |            13.1 |
# |            LossPi |           -41.7 |
# |             LossQ |           0.892 |
# |              Time |             193 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |             439 |
# |          StdEpRet |             139 |
# |          MaxEpRet |             595 |
# |          MinEpRet |             299 |
# |  AverageTestEpRet |             250 |
# |      StdTestEpRet |            32.8 |
# |      MaxTestEpRet |             280 |
# |      MinTestEpRet |             201 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            97.8 |
# |         StdQ1Vals |            33.8 |
# |         MaxQ1Vals |             234 |
# |         MinQ1Vals |            35.1 |
# |     AverageQ2Vals |            97.8 |
# |         StdQ2Vals |            33.8 |
# |         MaxQ2Vals |             233 |
# |         MinQ2Vals |            35.4 |
# |            LossPi |            -103 |
# |             LossQ |            5.71 |
# |              Time |             307 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             260 |
# |          StdEpRet |            38.8 |
# |          MaxEpRet |             305 |
# |          MinEpRet |             206 |
# |  AverageTestEpRet |             299 |
# |      StdTestEpRet |            13.1 |
# |      MaxTestEpRet |             308 |
# |      MinTestEpRet |             273 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |             125 |
# |         StdQ1Vals |            21.5 |
# |         MaxQ1Vals |             211 |
# |         MinQ1Vals |            80.7 |
# |     AverageQ2Vals |             125 |
# |         StdQ2Vals |            21.5 |
# |         MaxQ2Vals |             214 |
# |         MinQ2Vals |            80.9 |
# |            LossPi |            -125 |
# |             LossQ |            2.96 |
# |              Time |             421 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             287 |
# |          StdEpRet |            41.7 |
# |          MaxEpRet |             322 |
# |          MinEpRet |             216 |
# |  AverageTestEpRet |             216 |
# |      StdTestEpRet |            3.95 |
# |      MaxTestEpRet |             222 |
# |      MinTestEpRet |             210 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |             123 |
# |         StdQ1Vals |            16.3 |
# |         MaxQ1Vals |             227 |
# |         MinQ1Vals |              83 |
# |     AverageQ2Vals |             123 |
# |         StdQ2Vals |            16.3 |
# |         MaxQ2Vals |             229 |
# |         MinQ2Vals |            82.5 |
# |            LossPi |            -124 |
# |             LossQ |            1.79 |
# |              Time |             549 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             261 |
# |          StdEpRet |            48.1 |
# |          MaxEpRet |             343 |
# |          MinEpRet |             226 |
# |  AverageTestEpRet |             315 |
# |      StdTestEpRet |               4 |
# |      MaxTestEpRet |             320 |
# |      MinTestEpRet |             309 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |             128 |
# |         StdQ1Vals |            13.8 |
# |         MaxQ1Vals |             205 |
# |         MinQ1Vals |            86.2 |
# |     AverageQ2Vals |             128 |
# |         StdQ2Vals |            13.8 |
# |         MaxQ2Vals |             201 |
# |         MinQ2Vals |            81.3 |
# |            LossPi |            -130 |
# |             LossQ |            1.16 |
# |              Time |             676 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             321 |
# |          StdEpRet |              40 |
# |          MaxEpRet |             386 |
# |          MinEpRet |             276 |
# |  AverageTestEpRet |             273 |
# |      StdTestEpRet |            31.9 |
# |      MaxTestEpRet |             294 |
# |      MinTestEpRet |             210 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |             130 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |             162 |
# |         MinQ1Vals |            95.7 |
# |     AverageQ2Vals |             130 |
# |         StdQ2Vals |            10.8 |
# |         MaxQ2Vals |             161 |
# |         MinQ2Vals |            95.6 |
# |            LossPi |            -131 |
# |             LossQ |           0.676 |
# |              Time |             805 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             337 |
# |          StdEpRet |            59.7 |
# |          MaxEpRet |             417 |
# |          MinEpRet |             272 |
# |  AverageTestEpRet |             378 |
# |      StdTestEpRet |            55.3 |
# |      MaxTestEpRet |             479 |
# |      MinTestEpRet |             318 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |             123 |
# |         StdQ1Vals |            5.97 |
# |         MaxQ1Vals |             156 |
# |         MinQ1Vals |             108 |
# |     AverageQ2Vals |             123 |
# |         StdQ2Vals |            5.97 |
# |         MaxQ2Vals |             156 |
# |         MinQ2Vals |             108 |
# |            LossPi |            -124 |
# |             LossQ |           0.545 |
# |              Time |             928 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             438 |
# |          StdEpRet |             120 |
# |          MaxEpRet |             596 |
# |          MinEpRet |             280 |
# |  AverageTestEpRet |             626 |
# |      StdTestEpRet |            64.2 |
# |      MaxTestEpRet |             717 |
# |      MinTestEpRet |             543 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |             115 |
# |         StdQ1Vals |            5.24 |
# |         MaxQ1Vals |             137 |
# |         MinQ1Vals |            99.3 |
# |     AverageQ2Vals |             115 |
# |         StdQ2Vals |            5.24 |
# |         MaxQ2Vals |             148 |
# |         MinQ2Vals |            99.7 |
# |            LossPi |            -115 |
# |             LossQ |            0.46 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             586 |
# |          StdEpRet |            65.4 |
# |          MaxEpRet |             651 |
# |          MinEpRet |             505 |
# |  AverageTestEpRet |             601 |
# |      StdTestEpRet |            19.2 |
# |      MaxTestEpRet |             627 |
# |      MinTestEpRet |             573 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |             105 |
# |         StdQ1Vals |            6.83 |
# |         MaxQ1Vals |             126 |
# |         MinQ1Vals |            50.6 |
# |     AverageQ2Vals |             105 |
# |         StdQ2Vals |            6.83 |
# |         MaxQ2Vals |             126 |
# |         MinQ2Vals |            49.9 |
# |            LossPi |            -106 |
# |             LossQ |           0.467 |
# |              Time |        1.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             563 |
# |          StdEpRet |            44.4 |
# |          MaxEpRet |             637 |
# |          MinEpRet |             526 |
# |  AverageTestEpRet |             566 |
# |      StdTestEpRet |            73.8 |
# |      MaxTestEpRet |             654 |
# |      MinTestEpRet |             437 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            99.4 |
# |         StdQ1Vals |            5.97 |
# |         MaxQ1Vals |             120 |
# |         MinQ1Vals |            50.3 |
# |     AverageQ2Vals |            99.4 |
# |         StdQ2Vals |            5.97 |
# |         MaxQ2Vals |             121 |
# |         MinQ2Vals |            49.7 |
# |            LossPi |            -100 |
# |             LossQ |           0.469 |
# |              Time |        1.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             623 |
# |          StdEpRet |            92.4 |
# |          MaxEpRet |             720 |
# |          MinEpRet |             476 |
# |  AverageTestEpRet |             595 |
# |      StdTestEpRet |            48.8 |
# |      MaxTestEpRet |             668 |
# |      MinTestEpRet |             532 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            95.1 |
# |         StdQ1Vals |            5.52 |
# |         MaxQ1Vals |             113 |
# |         MinQ1Vals |              43 |
# |     AverageQ2Vals |            95.1 |
# |         StdQ2Vals |            5.52 |
# |         MaxQ2Vals |             115 |
# |         MinQ2Vals |            43.4 |
# |            LossPi |           -95.9 |
# |             LossQ |           0.507 |
# |              Time |        1.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             649 |
# |          StdEpRet |            64.9 |
# |          MaxEpRet |             751 |
# |          MinEpRet |             574 |
# |  AverageTestEpRet |             510 |
# |      StdTestEpRet |             135 |
# |      MaxTestEpRet |             752 |
# |      MinTestEpRet |             398 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |              92 |
# |         StdQ1Vals |            5.51 |
# |         MaxQ1Vals |             114 |
# |         MinQ1Vals |            42.6 |
# |     AverageQ2Vals |              92 |
# |         StdQ2Vals |            5.51 |
# |         MaxQ2Vals |             114 |
# |         MinQ2Vals |            42.4 |
# |            LossPi |           -92.7 |
# |             LossQ |           0.509 |
# |              Time |        1.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             637 |
# |          StdEpRet |            68.1 |
# |          MaxEpRet |             691 |
# |          MinEpRet |             522 |
# |  AverageTestEpRet |             599 |
# |      StdTestEpRet |            74.6 |
# |      MaxTestEpRet |             745 |
# |      MinTestEpRet |             542 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            89.8 |
# |         StdQ1Vals |            5.42 |
# |         MaxQ1Vals |             109 |
# |         MinQ1Vals |            43.1 |
# |     AverageQ2Vals |            89.8 |
# |         StdQ2Vals |            5.42 |
# |         MaxQ2Vals |             109 |
# |         MinQ2Vals |            42.8 |
# |            LossPi |           -90.4 |
# |             LossQ |           0.584 |
# |              Time |        1.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             563 |
# |          StdEpRet |             109 |
# |          MaxEpRet |             665 |
# |          MinEpRet |             383 |
# |  AverageTestEpRet |             520 |
# |      StdTestEpRet |            66.3 |
# |      MaxTestEpRet |             607 |
# |      MinTestEpRet |             436 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            87.6 |
# |         StdQ1Vals |            6.23 |
# |         MaxQ1Vals |             112 |
# |         MinQ1Vals |            42.7 |
# |     AverageQ2Vals |            87.6 |
# |         StdQ2Vals |            6.23 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |            42.6 |
# |            LossPi |           -88.1 |
# |             LossQ |           0.673 |
# |              Time |        1.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             679 |
# |          StdEpRet |              49 |
# |          MaxEpRet |             758 |
# |          MinEpRet |             631 |
# |  AverageTestEpRet |             777 |
# |      StdTestEpRet |            69.2 |
# |      MaxTestEpRet |             834 |
# |      MinTestEpRet |             644 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            85.5 |
# |         StdQ1Vals |            6.44 |
# |         MaxQ1Vals |             107 |
# |         MinQ1Vals |            45.7 |
# |     AverageQ2Vals |            85.5 |
# |         StdQ2Vals |            6.44 |
# |         MaxQ2Vals |             107 |
# |         MinQ2Vals |            45.2 |
# |            LossPi |           -86.1 |
# |             LossQ |           0.644 |
# |              Time |        1.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             789 |
# |          StdEpRet |            42.5 |
# |          MaxEpRet |             827 |
# |          MinEpRet |             722 |
# |  AverageTestEpRet |             813 |
# |      StdTestEpRet |             126 |
# |      MaxTestEpRet |             920 |
# |      MinTestEpRet |             575 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            84.2 |
# |         StdQ1Vals |            6.03 |
# |         MaxQ1Vals |             109 |
# |         MinQ1Vals |            44.1 |
# |     AverageQ2Vals |            84.2 |
# |         StdQ2Vals |            6.03 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |            44.6 |
# |            LossPi |           -84.8 |
# |             LossQ |           0.678 |
# |              Time |        2.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             767 |
# |          StdEpRet |            44.8 |
# |          MaxEpRet |             826 |
# |          MinEpRet |             709 |
# |  AverageTestEpRet |             959 |
# |      StdTestEpRet |            28.1 |
# |      MaxTestEpRet |             995 |
# |      MinTestEpRet |             931 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            84.2 |
# |         StdQ1Vals |            5.97 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |            44.4 |
# |     AverageQ2Vals |            84.2 |
# |         StdQ2Vals |            5.97 |
# |         MaxQ2Vals |             144 |
# |         MinQ2Vals |            44.7 |
# |            LossPi |           -84.9 |
# |             LossQ |           0.842 |
# |              Time |        2.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             928 |
# |          StdEpRet |             118 |
# |          MaxEpRet |        1.11e+03 |
# |          MinEpRet |             809 |
# |  AverageTestEpRet |             899 |
# |      StdTestEpRet |             155 |
# |      MaxTestEpRet |        1.08e+03 |
# |      MinTestEpRet |             646 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            84.9 |
# |         StdQ1Vals |            6.08 |
# |         MaxQ1Vals |             153 |
# |         MinQ1Vals |            46.3 |
# |     AverageQ2Vals |            84.9 |
# |         StdQ2Vals |            6.08 |
# |         MaxQ2Vals |             155 |
# |         MinQ2Vals |            45.9 |
# |            LossPi |           -85.6 |
# |             LossQ |           0.872 |
# |              Time |        2.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             905 |
# |          StdEpRet |            93.3 |
# |          MaxEpRet |        1.03e+03 |
# |          MinEpRet |             775 |
# |  AverageTestEpRet |             718 |
# |      StdTestEpRet |             153 |
# |      MaxTestEpRet |             867 |
# |      MinTestEpRet |             497 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            84.7 |
# |         StdQ1Vals |            6.29 |
# |         MaxQ1Vals |             151 |
# |         MinQ1Vals |            45.8 |
# |     AverageQ2Vals |            84.7 |
# |         StdQ2Vals |            6.29 |
# |         MaxQ2Vals |             155 |
# |         MinQ2Vals |            46.9 |
# |            LossPi |           -85.3 |
# |             LossQ |           0.897 |
# |              Time |        2.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             894 |
# |          StdEpRet |            63.4 |
# |          MaxEpRet |             947 |
# |          MinEpRet |             789 |
# |  AverageTestEpRet |             937 |
# |      StdTestEpRet |              55 |
# |      MaxTestEpRet |             994 |
# |      MinTestEpRet |             834 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            84.8 |
# |         StdQ1Vals |            6.75 |
# |         MaxQ1Vals |             133 |
# |         MinQ1Vals |            47.3 |
# |     AverageQ2Vals |            84.8 |
# |         StdQ2Vals |            6.74 |
# |         MaxQ2Vals |             133 |
# |         MinQ2Vals |            48.9 |
# |            LossPi |           -85.5 |
# |             LossQ |           0.968 |
# |              Time |        2.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        1.04e+03 |
# |          StdEpRet |              58 |
# |          MaxEpRet |        1.11e+03 |
# |          MinEpRet |             949 |
# |  AverageTestEpRet |           1e+03 |
# |      StdTestEpRet |            79.7 |
# |      MaxTestEpRet |        1.11e+03 |
# |      MinTestEpRet |             915 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |              86 |
# |         StdQ1Vals |            7.21 |
# |         MaxQ1Vals |             140 |
# |         MinQ1Vals |            51.8 |
# |     AverageQ2Vals |              86 |
# |         StdQ2Vals |            7.21 |
# |         MaxQ2Vals |             140 |
# |         MinQ2Vals |            50.2 |
# |            LossPi |           -86.7 |
# |             LossQ |            1.04 |
# |              Time |        2.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             945 |
# |          StdEpRet |            61.5 |
# |          MaxEpRet |        1.02e+03 |
# |          MinEpRet |             855 |
# |  AverageTestEpRet |             867 |
# |      StdTestEpRet |            81.6 |
# |      MaxTestEpRet |             937 |
# |      MinTestEpRet |             721 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            87.5 |
# |         StdQ1Vals |            7.67 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |            49.8 |
# |     AverageQ2Vals |            87.5 |
# |         StdQ2Vals |            7.67 |
# |         MaxQ2Vals |             136 |
# |         MinQ2Vals |              49 |
# |            LossPi |           -88.2 |
# |             LossQ |            1.12 |
# |              Time |        2.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        1.17e+03 |
# |          StdEpRet |             129 |
# |          MaxEpRet |        1.26e+03 |
# |          MinEpRet |             950 |
# |  AverageTestEpRet |        1.01e+03 |
# |      StdTestEpRet |             208 |
# |      MaxTestEpRet |        1.31e+03 |
# |      MinTestEpRet |             771 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            88.9 |
# |         StdQ1Vals |            8.12 |
# |         MaxQ1Vals |             130 |
# |         MinQ1Vals |              47 |
# |     AverageQ2Vals |            88.9 |
# |         StdQ2Vals |            8.12 |
# |         MaxQ2Vals |             131 |
# |         MinQ2Vals |            46.5 |
# |            LossPi |           -89.6 |
# |             LossQ |             1.1 |
# |              Time |           3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             779 |
# |          StdEpRet |             125 |
# |          MaxEpRet |             989 |
# |          MinEpRet |             670 |
# |  AverageTestEpRet |             828 |
# |      StdTestEpRet |             128 |
# |      MaxTestEpRet |        1.03e+03 |
# |      MinTestEpRet |             641 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |              91 |
# |         StdQ1Vals |             8.9 |
# |         MaxQ1Vals |             135 |
# |         MinQ1Vals |            41.8 |
# |     AverageQ2Vals |              91 |
# |         StdQ2Vals |             8.9 |
# |         MaxQ2Vals |             136 |
# |         MinQ2Vals |            41.8 |
# |            LossPi |           -91.7 |
# |             LossQ |            1.27 |
# |              Time |        3.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             981 |
# |          StdEpRet |             153 |
# |          MaxEpRet |        1.23e+03 |
# |          MinEpRet |             827 |
# |  AverageTestEpRet |        1.25e+03 |
# |      StdTestEpRet |            46.9 |
# |      MaxTestEpRet |        1.31e+03 |
# |      MinTestEpRet |        1.18e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            92.8 |
# |         StdQ1Vals |            9.58 |
# |         MaxQ1Vals |             146 |
# |         MinQ1Vals |            41.3 |
# |     AverageQ2Vals |            92.8 |
# |         StdQ2Vals |            9.58 |
# |         MaxQ2Vals |             146 |
# |         MinQ2Vals |            41.7 |
# |            LossPi |           -93.5 |
# |             LossQ |            1.33 |
# |              Time |        3.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             928 |
# |          StdEpRet |             145 |
# |          MaxEpRet |        1.07e+03 |
# |          MinEpRet |             736 |
# |  AverageTestEpRet |             905 |
# |      StdTestEpRet |             168 |
# |      MaxTestEpRet |        1.17e+03 |
# |      MinTestEpRet |             680 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            94.6 |
# |         StdQ1Vals |            9.89 |
# |         MaxQ1Vals |             157 |
# |         MinQ1Vals |            40.2 |
# |     AverageQ2Vals |            94.6 |
# |         StdQ2Vals |            9.89 |
# |         MaxQ2Vals |             156 |
# |         MinQ2Vals |            41.5 |
# |            LossPi |           -95.4 |
# |             LossQ |            1.46 |
# |              Time |         3.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             785 |
# |          StdEpRet |             213 |
# |          MaxEpRet |        1.13e+03 |
# |          MinEpRet |             556 |
# |  AverageTestEpRet |             883 |
# |      StdTestEpRet |             128 |
# |      MaxTestEpRet |        1.02e+03 |
# |      MinTestEpRet |             699 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            95.9 |
# |         StdQ1Vals |            10.7 |
# |         MaxQ1Vals |             190 |
# |         MinQ1Vals |            40.3 |
# |     AverageQ2Vals |            95.9 |
# |         StdQ2Vals |            10.7 |
# |         MaxQ2Vals |             185 |
# |         MinQ2Vals |            40.8 |
# |            LossPi |           -96.6 |
# |             LossQ |            1.61 |
# |              Time |        3.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        1.15e+03 |
# |          StdEpRet |            91.7 |
# |          MaxEpRet |        1.26e+03 |
# |          MinEpRet |           1e+03 |
# |  AverageTestEpRet |             995 |
# |      StdTestEpRet |             121 |
# |      MaxTestEpRet |        1.12e+03 |
# |      MinTestEpRet |             770 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            96.4 |
# |         StdQ1Vals |            11.9 |
# |         MaxQ1Vals |             207 |
# |         MinQ1Vals |            43.4 |
# |     AverageQ2Vals |            96.4 |
# |         StdQ2Vals |            11.9 |
# |         MaxQ2Vals |             207 |
# |         MinQ2Vals |            43.1 |
# |            LossPi |           -97.1 |
# |             LossQ |            1.82 |
# |              Time |        3.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             978 |
# |          StdEpRet |             128 |
# |          MaxEpRet |        1.14e+03 |
# |          MinEpRet |             784 |
# |  AverageTestEpRet |        1.01e+03 |
# |      StdTestEpRet |             150 |
# |      MaxTestEpRet |         1.3e+03 |
# |      MinTestEpRet |             869 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |              97 |
# |         StdQ1Vals |            12.7 |
# |         MaxQ1Vals |             212 |
# |         MinQ1Vals |            44.7 |
# |     AverageQ2Vals |              97 |
# |         StdQ2Vals |            12.7 |
# |         MaxQ2Vals |             211 |
# |         MinQ2Vals |            44.9 |
# |            LossPi |           -97.8 |
# |             LossQ |            1.99 |
# |              Time |        3.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             818 |
# |          StdEpRet |             309 |
# |          MaxEpRet |        1.27e+03 |
# |          MinEpRet |             459 |
# |  AverageTestEpRet |             979 |
# |      StdTestEpRet |             185 |
# |      MaxTestEpRet |        1.25e+03 |
# |      MinTestEpRet |             734 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |              98 |
# |         StdQ1Vals |            13.5 |
# |         MaxQ1Vals |             201 |
# |         MinQ1Vals |            50.1 |
# |     AverageQ2Vals |              98 |
# |         StdQ2Vals |            13.5 |
# |         MaxQ2Vals |             197 |
# |         MinQ2Vals |            50.7 |
# |            LossPi |           -98.8 |
# |             LossQ |            2.57 |
# |              Time |        4.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        1.06e+03 |
# |          StdEpRet |            85.4 |
# |          MaxEpRet |        1.15e+03 |
# |          MinEpRet |             964 |
# |  AverageTestEpRet |        1.42e+03 |
# |      StdTestEpRet |            96.6 |
# |      MaxTestEpRet |        1.54e+03 |
# |      MinTestEpRet |        1.29e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |              99 |
# |         StdQ1Vals |            13.9 |
# |         MaxQ1Vals |             187 |
# |         MinQ1Vals |            45.9 |
# |     AverageQ2Vals |              99 |
# |         StdQ2Vals |            13.9 |
# |         MaxQ2Vals |             186 |
# |         MinQ2Vals |              47 |
# |            LossPi |           -99.9 |
# |             LossQ |            2.83 |
# |              Time |        4.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             976 |
# |          StdEpRet |             228 |
# |          MaxEpRet |        1.33e+03 |
# |          MinEpRet |             700 |
# |  AverageTestEpRet |        1.07e+03 |
# |      StdTestEpRet |             326 |
# |      MaxTestEpRet |        1.43e+03 |
# |      MinTestEpRet |             667 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             101 |
# |         StdQ1Vals |            13.5 |
# |         MaxQ1Vals |             182 |
# |         MinQ1Vals |            49.3 |
# |     AverageQ2Vals |             101 |
# |         StdQ2Vals |            13.5 |
# |         MaxQ2Vals |             181 |
# |         MinQ2Vals |            50.4 |
# |            LossPi |            -102 |
# |             LossQ |            2.78 |
# |              Time |        4.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |         1.4e+03 |
# |          StdEpRet |            66.3 |
# |          MaxEpRet |        1.52e+03 |
# |          MinEpRet |        1.35e+03 |
# |  AverageTestEpRet |        1.27e+03 |
# |      StdTestEpRet |             455 |
# |      MaxTestEpRet |        1.61e+03 |
# |      MinTestEpRet |             386 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             103 |
# |         StdQ1Vals |            13.1 |
# |         MaxQ1Vals |             182 |
# |         MinQ1Vals |            47.7 |
# |     AverageQ2Vals |             103 |
# |         StdQ2Vals |            13.1 |
# |         MaxQ2Vals |             181 |
# |         MinQ2Vals |            48.9 |
# |            LossPi |            -104 |
# |             LossQ |            2.78 |
# |              Time |        4.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |        1.18e+03 |
# |          StdEpRet |             289 |
# |          MaxEpRet |         1.6e+03 |
# |          MinEpRet |             867 |
# |  AverageTestEpRet |        1.51e+03 |
# |      StdTestEpRet |             271 |
# |      MaxTestEpRet |        1.72e+03 |
# |      MinTestEpRet |             996 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             104 |
# |         StdQ1Vals |            13.2 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |            36.4 |
# |     AverageQ2Vals |             104 |
# |         StdQ2Vals |            13.2 |
# |         MaxQ2Vals |             170 |
# |         MinQ2Vals |            35.6 |
# |            LossPi |            -105 |
# |             LossQ |            2.72 |
# |              Time |        4.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |        1.36e+03 |
# |          StdEpRet |             113 |
# |          MaxEpRet |        1.53e+03 |
# |          MinEpRet |        1.21e+03 |
# |  AverageTestEpRet |        1.65e+03 |
# |      StdTestEpRet |             238 |
# |      MaxTestEpRet |        1.88e+03 |
# |      MinTestEpRet |        1.19e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             106 |
# |         StdQ1Vals |              14 |
# |         MaxQ1Vals |             156 |
# |         MinQ1Vals |            37.9 |
# |     AverageQ2Vals |             106 |
# |         StdQ2Vals |              14 |
# |         MaxQ2Vals |             156 |
# |         MinQ2Vals |            37.6 |
# |            LossPi |            -107 |
# |             LossQ |            2.81 |
# |              Time |        4.78e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |        1.43e+03 |
# |          StdEpRet |             157 |
# |          MaxEpRet |        1.64e+03 |
# |          MinEpRet |        1.25e+03 |
# |  AverageTestEpRet |        1.47e+03 |
# |      StdTestEpRet |             243 |
# |      MaxTestEpRet |        1.73e+03 |
# |      MinTestEpRet |        1.03e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             107 |
# |         StdQ1Vals |            15.2 |
# |         MaxQ1Vals |             155 |
# |         MinQ1Vals |              38 |
# |     AverageQ2Vals |             107 |
# |         StdQ2Vals |            15.2 |
# |         MaxQ2Vals |             157 |
# |         MinQ2Vals |              38 |
# |            LossPi |            -108 |
# |             LossQ |            2.91 |
# |              Time |        4.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        1.16e+03 |
# |          StdEpRet |             347 |
# |          MaxEpRet |        1.59e+03 |
# |          MinEpRet |             783 |
# |  AverageTestEpRet |        1.37e+03 |
# |      StdTestEpRet |             130 |
# |      MaxTestEpRet |        1.46e+03 |
# |      MinTestEpRet |        1.12e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             109 |
# |         StdQ1Vals |            16.8 |
# |         MaxQ1Vals |             160 |
# |         MinQ1Vals |            36.3 |
# |     AverageQ2Vals |             109 |
# |         StdQ2Vals |            16.8 |
# |         MaxQ2Vals |             160 |
# |         MinQ2Vals |            37.1 |
# |            LossPi |            -109 |
# |             LossQ |            3.12 |
# |              Time |        5.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        1.23e+03 |
# |          StdEpRet |             246 |
# |          MaxEpRet |        1.56e+03 |
# |          MinEpRet |             918 |
# |  AverageTestEpRet |        1.48e+03 |
# |      StdTestEpRet |             180 |
# |      MaxTestEpRet |        1.66e+03 |
# |      MinTestEpRet |        1.16e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             110 |
# |         StdQ1Vals |            18.1 |
# |         MaxQ1Vals |             163 |
# |         MinQ1Vals |            38.4 |
# |     AverageQ2Vals |             110 |
# |         StdQ2Vals |            18.1 |
# |         MaxQ2Vals |             163 |
# |         MinQ2Vals |            38.8 |
# |            LossPi |            -111 |
# |             LossQ |            3.26 |
# |              Time |         5.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        1.32e+03 |
# |          StdEpRet |             178 |
# |          MaxEpRet |        1.55e+03 |
# |          MinEpRet |        1.12e+03 |
# |  AverageTestEpRet |        1.02e+03 |
# |      StdTestEpRet |             151 |
# |      MaxTestEpRet |        1.26e+03 |
# |      MinTestEpRet |             802 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            19.6 |
# |         MaxQ1Vals |             167 |
# |         MinQ1Vals |            28.2 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            19.6 |
# |         MaxQ2Vals |             166 |
# |         MinQ2Vals |            27.7 |
# |            LossPi |            -112 |
# |             LossQ |            3.63 |
# |              Time |        5.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        1.33e+03 |
# |          StdEpRet |             326 |
# |          MaxEpRet |        1.85e+03 |
# |          MinEpRet |             946 |
# |  AverageTestEpRet |        1.12e+03 |
# |      StdTestEpRet |             174 |
# |      MaxTestEpRet |        1.41e+03 |
# |      MinTestEpRet |             938 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             112 |
# |         StdQ1Vals |            20.8 |
# |         MaxQ1Vals |             169 |
# |         MinQ1Vals |            23.5 |
# |     AverageQ2Vals |             112 |
# |         StdQ2Vals |            20.8 |
# |         MaxQ2Vals |             167 |
# |         MinQ2Vals |            21.6 |
# |            LossPi |            -113 |
# |             LossQ |            3.69 |
# |              Time |        5.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        1.26e+03 |
# |          StdEpRet |             121 |
# |          MaxEpRet |        1.42e+03 |
# |          MinEpRet |        1.08e+03 |
# |  AverageTestEpRet |        1.42e+03 |
# |      StdTestEpRet |             268 |
# |      MaxTestEpRet |        1.74e+03 |
# |      MinTestEpRet |        1.02e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             113 |
# |         StdQ1Vals |            21.8 |
# |         MaxQ1Vals |             168 |
# |         MinQ1Vals |            25.1 |
# |     AverageQ2Vals |             113 |
# |         StdQ2Vals |            21.8 |
# |         MaxQ2Vals |             168 |
# |         MinQ2Vals |            23.1 |
# |            LossPi |            -114 |
# |             LossQ |            3.89 |
# |              Time |        5.57e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        1.51e+03 |
# |          StdEpRet |             140 |
# |          MaxEpRet |        1.73e+03 |
# |          MinEpRet |        1.34e+03 |
# |  AverageTestEpRet |         1.7e+03 |
# |      StdTestEpRet |              89 |
# |      MaxTestEpRet |         1.8e+03 |
# |      MinTestEpRet |        1.54e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             113 |
# |         StdQ1Vals |            22.9 |
# |         MaxQ1Vals |             172 |
# |         MinQ1Vals |            26.7 |
# |     AverageQ2Vals |             113 |
# |         StdQ2Vals |            22.9 |
# |         MaxQ2Vals |             171 |
# |         MinQ2Vals |            27.2 |
# |            LossPi |            -114 |
# |             LossQ |            4.07 |
# |              Time |         5.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        1.61e+03 |
# |          StdEpRet |            87.6 |
# |          MaxEpRet |        1.76e+03 |
# |          MinEpRet |        1.54e+03 |
# |  AverageTestEpRet |        1.83e+03 |
# |      StdTestEpRet |              68 |
# |      MaxTestEpRet |        1.89e+03 |
# |      MinTestEpRet |        1.72e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             114 |
# |         StdQ1Vals |              24 |
# |         MaxQ1Vals |             172 |
# |         MinQ1Vals |            20.4 |
# |     AverageQ2Vals |             114 |
# |         StdQ2Vals |              24 |
# |         MaxQ2Vals |             172 |
# |         MinQ2Vals |            24.3 |
# |            LossPi |            -115 |
# |             LossQ |             4.2 |
# |              Time |        5.83e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        1.86e+03 |
# |          StdEpRet |            58.5 |
# |          MaxEpRet |        1.96e+03 |
# |          MinEpRet |        1.82e+03 |
# |  AverageTestEpRet |           2e+03 |
# |      StdTestEpRet |              72 |
# |      MaxTestEpRet |        2.06e+03 |
# |      MinTestEpRet |        1.86e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             115 |
# |         StdQ1Vals |            25.1 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |              13 |
# |     AverageQ2Vals |             115 |
# |         StdQ2Vals |            25.1 |
# |         MaxQ2Vals |             175 |
# |         MinQ2Vals |            12.2 |
# |            LossPi |            -116 |
# |             LossQ |            4.33 |
# |              Time |        5.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        1.89e+03 |
# |          StdEpRet |            54.7 |
# |          MaxEpRet |        1.96e+03 |
# |          MinEpRet |        1.82e+03 |
# |  AverageTestEpRet |        1.85e+03 |
# |      StdTestEpRet |             127 |
# |      MaxTestEpRet |        2.01e+03 |
# |      MinTestEpRet |        1.63e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             118 |
# |         StdQ1Vals |            26.3 |
# |         MaxQ1Vals |             175 |
# |         MinQ1Vals |            5.21 |
# |     AverageQ2Vals |             118 |
# |         StdQ2Vals |            26.3 |
# |         MaxQ2Vals |             176 |
# |         MinQ2Vals |            5.35 |
# |            LossPi |            -119 |
# |             LossQ |            4.49 |
# |              Time |        6.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        1.78e+03 |
# |          StdEpRet |             302 |
# |          MaxEpRet |        2.05e+03 |
# |          MinEpRet |        1.26e+03 |
# |  AverageTestEpRet |        1.99e+03 |
# |      StdTestEpRet |             183 |
# |      MaxTestEpRet |        2.24e+03 |
# |      MinTestEpRet |        1.68e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             120 |
# |         StdQ1Vals |              27 |
# |         MaxQ1Vals |             178 |
# |         MinQ1Vals |            14.3 |
# |     AverageQ2Vals |             120 |
# |         StdQ2Vals |              27 |
# |         MaxQ2Vals |             178 |
# |         MinQ2Vals |            14.1 |
# |            LossPi |            -121 |
# |             LossQ |             4.7 |
# |              Time |        6.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        1.91e+03 |
# |          StdEpRet |             113 |
# |          MaxEpRet |        2.04e+03 |
# |          MinEpRet |        1.73e+03 |
# |  AverageTestEpRet |        1.96e+03 |
# |      StdTestEpRet |            73.6 |
# |      MaxTestEpRet |        2.02e+03 |
# |      MinTestEpRet |        1.82e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             123 |
# |         StdQ1Vals |            27.8 |
# |         MaxQ1Vals |             182 |
# |         MinQ1Vals |            17.7 |
# |     AverageQ2Vals |             123 |
# |         StdQ2Vals |            27.8 |
# |         MaxQ2Vals |             182 |
# |         MinQ2Vals |            18.5 |
# |            LossPi |            -124 |
# |             LossQ |            4.86 |
# |              Time |        6.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        1.97e+03 |
# |          StdEpRet |            58.4 |
# |          MaxEpRet |        2.03e+03 |
# |          MinEpRet |        1.88e+03 |
# |  AverageTestEpRet |        1.99e+03 |
# |      StdTestEpRet |             103 |
# |      MaxTestEpRet |        2.18e+03 |
# |      MinTestEpRet |        1.88e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             125 |
# |         StdQ1Vals |            28.3 |
# |         MaxQ1Vals |             185 |
# |         MinQ1Vals |            19.4 |
# |     AverageQ2Vals |             125 |
# |         StdQ2Vals |            28.3 |
# |         MaxQ2Vals |             186 |
# |         MinQ2Vals |            17.8 |
# |            LossPi |            -126 |
# |             LossQ |            5.05 |
# |              Time |        6.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        1.97e+03 |
# |          StdEpRet |            82.8 |
# |          MaxEpRet |         2.1e+03 |
# |          MinEpRet |        1.89e+03 |
# |  AverageTestEpRet |        1.73e+03 |
# |      StdTestEpRet |             128 |
# |      MaxTestEpRet |        1.94e+03 |
# |      MinTestEpRet |        1.56e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             127 |
# |         StdQ1Vals |            28.9 |
# |         MaxQ1Vals |             188 |
# |         MinQ1Vals |            16.6 |
# |     AverageQ2Vals |             127 |
# |         StdQ2Vals |            28.9 |
# |         MaxQ2Vals |             189 |
# |         MinQ2Vals |            13.2 |
# |            LossPi |            -129 |
# |             LossQ |            5.31 |
# |              Time |        6.59e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetahMuJoCoEnv-v0', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': False,
        'exp_name': 'td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetahMuJoCoEnv-v0",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D20582508>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\\\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	false,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
# options=
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            45.9 |
# |          MaxEpRet |            -138 |
# |          MinEpRet |            -257 |
# |  AverageTestEpRet |            -568 |
# |      StdTestEpRet |            9.27 |
# |      MaxTestEpRet |            -550 |
# |      MinTestEpRet |            -576 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            18.8 |
# |         StdQ1Vals |              19 |
# |         MaxQ1Vals |            94.1 |
# |         MinQ1Vals |           -6.81 |
# |     AverageQ2Vals |            18.8 |
# |         StdQ2Vals |              19 |
# |         MaxQ2Vals |            94.1 |
# |         MinQ2Vals |           -6.72 |
# |            LossPi |           -24.2 |
# |             LossQ |            2.57 |
# |              Time |            71.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            57.4 |
# |          MaxEpRet |            -118 |
# |          MinEpRet |            -275 |
# |  AverageTestEpRet |            -605 |
# |      StdTestEpRet |            26.3 |
# |      MaxTestEpRet |            -567 |
# |      MinTestEpRet |            -635 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |             128 |
# |         StdQ1Vals |            38.1 |
# |         MaxQ1Vals |             266 |
# |         MinQ1Vals |            38.4 |
# |     AverageQ2Vals |             128 |
# |         StdQ2Vals |            38.1 |
# |         MaxQ2Vals |             264 |
# |         MinQ2Vals |            38.4 |
# |            LossPi |            -137 |
# |             LossQ |            23.1 |
# |              Time |             183 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -345 |
# |          StdEpRet |             218 |
# |          MaxEpRet |            -102 |
# |          MinEpRet |            -565 |
# |  AverageTestEpRet |            -606 |
# |      StdTestEpRet |            3.48 |
# |      MaxTestEpRet |            -601 |
# |      MinTestEpRet |            -611 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |             231 |
# |         StdQ1Vals |            48.1 |
# |         MaxQ1Vals |             384 |
# |         MinQ1Vals |             105 |
# |     AverageQ2Vals |             231 |
# |         StdQ2Vals |            48.1 |
# |         MaxQ2Vals |             381 |
# |         MinQ2Vals |             103 |
# |            LossPi |            -240 |
# |             LossQ |            49.1 |
# |              Time |             287 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -579 |
# |          StdEpRet |            23.1 |
# |          MaxEpRet |            -557 |
# |          MinEpRet |            -618 |
# |  AverageTestEpRet |            -605 |
# |      StdTestEpRet |            5.22 |
# |      MaxTestEpRet |            -600 |
# |      MinTestEpRet |            -614 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |             279 |
# |         StdQ1Vals |            36.6 |
# |         MaxQ1Vals |             435 |
# |         MinQ1Vals |             167 |
# |     AverageQ2Vals |             279 |
# |         StdQ2Vals |            36.6 |
# |         MaxQ2Vals |             437 |
# |         MinQ2Vals |             168 |
# |            LossPi |            -286 |
# |             LossQ |            38.1 |
# |              Time |             396 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -568 |
# |          StdEpRet |            13.3 |
# |          MaxEpRet |            -558 |
# |          MinEpRet |            -591 |
# |  AverageTestEpRet |            -605 |
# |      StdTestEpRet |             4.4 |
# |      MaxTestEpRet |            -598 |
# |      MinTestEpRet |            -610 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |             297 |
# |         StdQ1Vals |            18.5 |
# |         MaxQ1Vals |             388 |
# |         MinQ1Vals |             202 |
# |     AverageQ2Vals |             297 |
# |         StdQ2Vals |            18.5 |
# |         MaxQ2Vals |             392 |
# |         MinQ2Vals |             204 |
# |            LossPi |            -300 |
# |             LossQ |            17.8 |
# |              Time |             509 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -546 |
# |          StdEpRet |            6.68 |
# |          MaxEpRet |            -538 |
# |          MinEpRet |            -555 |
# |  AverageTestEpRet |            -594 |
# |      StdTestEpRet |            8.91 |
# |      MaxTestEpRet |            -586 |
# |      MinTestEpRet |            -611 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |             256 |
# |         StdQ1Vals |              14 |
# |         MaxQ1Vals |             313 |
# |         MinQ1Vals |             194 |
# |     AverageQ2Vals |             256 |
# |         StdQ2Vals |            13.9 |
# |         MaxQ2Vals |             311 |
# |         MinQ2Vals |             193 |
# |            LossPi |            -258 |
# |             LossQ |            8.82 |
# |              Time |             618 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -545 |
# |          StdEpRet |            6.51 |
# |          MaxEpRet |            -535 |
# |          MinEpRet |            -551 |
# |  AverageTestEpRet |            -592 |
# |      StdTestEpRet |            1.29 |
# |      MaxTestEpRet |            -591 |
# |      MinTestEpRet |            -594 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |             207 |
# |         StdQ1Vals |            17.1 |
# |         MaxQ1Vals |             266 |
# |         MinQ1Vals |             154 |
# |     AverageQ2Vals |             207 |
# |         StdQ2Vals |            17.1 |
# |         MaxQ2Vals |             267 |
# |         MinQ2Vals |             155 |
# |            LossPi |            -208 |
# |             LossQ |            3.02 |
# |              Time |             734 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -528 |
# |          StdEpRet |            13.1 |
# |          MaxEpRet |            -512 |
# |          MinEpRet |            -543 |
# |  AverageTestEpRet |            -530 |
# |      StdTestEpRet |            3.68 |
# |      MaxTestEpRet |            -523 |
# |      MinTestEpRet |            -533 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |             161 |
# |         StdQ1Vals |            13.3 |
# |         MaxQ1Vals |             203 |
# |         MinQ1Vals |             116 |
# |     AverageQ2Vals |             161 |
# |         StdQ2Vals |            13.3 |
# |         MaxQ2Vals |             206 |
# |         MinQ2Vals |             111 |
# |            LossPi |            -162 |
# |             LossQ |            1.76 |
# |              Time |             845 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -481 |
# |          StdEpRet |            45.3 |
# |          MaxEpRet |            -415 |
# |          MinEpRet |            -537 |
# |  AverageTestEpRet |            -510 |
# |      StdTestEpRet |            15.1 |
# |      MaxTestEpRet |            -484 |
# |      MinTestEpRet |            -525 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |             131 |
# |         StdQ1Vals |            15.7 |
# |         MaxQ1Vals |             178 |
# |         MinQ1Vals |            93.3 |
# |     AverageQ2Vals |             131 |
# |         StdQ2Vals |            15.7 |
# |         MaxQ2Vals |             178 |
# |         MinQ2Vals |            93.1 |
# |            LossPi |            -132 |
# |             LossQ |            1.15 |
# |              Time |             955 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -297 |
# |          StdEpRet |             184 |
# |          MaxEpRet |           -42.9 |
# |          MinEpRet |            -502 |
# |  AverageTestEpRet |             132 |
# |      StdTestEpRet |             341 |
# |      MaxTestEpRet |             376 |
# |      MinTestEpRet |            -543 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |             105 |
# |         StdQ1Vals |            8.66 |
# |         MaxQ1Vals |             132 |
# |         MinQ1Vals |              71 |
# |     AverageQ2Vals |             105 |
# |         StdQ2Vals |            8.66 |
# |         MaxQ2Vals |             134 |
# |         MinQ2Vals |            70.7 |
# |            LossPi |            -107 |
# |             LossQ |           0.723 |
# |              Time |        1.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             457 |
# |          StdEpRet |             299 |
# |          MaxEpRet |             797 |
# |          MinEpRet |            69.5 |
# |  AverageTestEpRet |             622 |
# |      StdTestEpRet |            91.3 |
# |      MaxTestEpRet |             772 |
# |      MinTestEpRet |             494 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            89.2 |
# |         StdQ1Vals |            8.42 |
# |         MaxQ1Vals |             118 |
# |         MinQ1Vals |            60.2 |
# |     AverageQ2Vals |            89.2 |
# |         StdQ2Vals |            8.43 |
# |         MaxQ2Vals |             117 |
# |         MinQ2Vals |            60.4 |
# |            LossPi |           -90.6 |
# |             LossQ |           0.768 |
# |              Time |        1.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             858 |
# |          StdEpRet |            44.3 |
# |          MaxEpRet |             935 |
# |          MinEpRet |             832 |
# |  AverageTestEpRet |             925 |
# |      StdTestEpRet |            41.7 |
# |      MaxTestEpRet |           1e+03 |
# |      MinTestEpRet |             880 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            80.2 |
# |         StdQ1Vals |            6.86 |
# |         MaxQ1Vals |             104 |
# |         MinQ1Vals |            52.2 |
# |     AverageQ2Vals |            80.2 |
# |         StdQ2Vals |            6.86 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |            51.5 |
# |            LossPi |           -81.9 |
# |             LossQ |            1.24 |
# |              Time |        1.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |        1.17e+03 |
# |          StdEpRet |              81 |
# |          MaxEpRet |        1.24e+03 |
# |          MinEpRet |        1.04e+03 |
# |  AverageTestEpRet |             919 |
# |      StdTestEpRet |             690 |
# |      MaxTestEpRet |        1.33e+03 |
# |      MinTestEpRet |            -459 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            78.8 |
# |         StdQ1Vals |             8.2 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |            47.7 |
# |     AverageQ2Vals |            78.8 |
# |         StdQ2Vals |             8.2 |
# |         MaxQ2Vals |             107 |
# |         MinQ2Vals |            50.9 |
# |            LossPi |           -80.7 |
# |             LossQ |            1.71 |
# |              Time |         1.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        1.19e+03 |
# |          StdEpRet |             100 |
# |          MaxEpRet |        1.28e+03 |
# |          MinEpRet |        1.02e+03 |
# |  AverageTestEpRet |             884 |
# |      StdTestEpRet |             644 |
# |      MaxTestEpRet |        1.22e+03 |
# |      MinTestEpRet |            -404 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            81.5 |
# |         StdQ1Vals |            9.95 |
# |         MaxQ1Vals |             115 |
# |         MinQ1Vals |            49.3 |
# |     AverageQ2Vals |            81.5 |
# |         StdQ2Vals |            9.95 |
# |         MaxQ2Vals |             116 |
# |         MinQ2Vals |            50.8 |
# |            LossPi |           -83.5 |
# |             LossQ |             2.1 |
# |              Time |        1.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        1.31e+03 |
# |          StdEpRet |            8.79 |
# |          MaxEpRet |        1.32e+03 |
# |          MinEpRet |        1.29e+03 |
# |  AverageTestEpRet |        1.44e+03 |
# |      StdTestEpRet |            14.1 |
# |      MaxTestEpRet |        1.46e+03 |
# |      MinTestEpRet |        1.42e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |              87 |
# |         StdQ1Vals |            11.3 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            53.4 |
# |     AverageQ2Vals |              87 |
# |         StdQ2Vals |            11.3 |
# |         MaxQ2Vals |             120 |
# |         MinQ2Vals |              53 |
# |            LossPi |           -89.1 |
# |             LossQ |            2.45 |
# |              Time |        1.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |        1.29e+03 |
# |          StdEpRet |            55.3 |
# |          MaxEpRet |        1.35e+03 |
# |          MinEpRet |        1.21e+03 |
# |  AverageTestEpRet |        1.39e+03 |
# |      StdTestEpRet |            90.3 |
# |      MaxTestEpRet |         1.5e+03 |
# |      MinTestEpRet |        1.24e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            92.1 |
# |         StdQ1Vals |            12.7 |
# |         MaxQ1Vals |             127 |
# |         MinQ1Vals |            52.8 |
# |     AverageQ2Vals |            92.1 |
# |         StdQ2Vals |            12.7 |
# |         MaxQ2Vals |             127 |
# |         MinQ2Vals |            51.8 |
# |            LossPi |           -94.3 |
# |             LossQ |            2.62 |
# |              Time |        1.74e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        1.36e+03 |
# |          StdEpRet |            43.1 |
# |          MaxEpRet |        1.43e+03 |
# |          MinEpRet |        1.32e+03 |
# |  AverageTestEpRet |             938 |
# |      StdTestEpRet |             771 |
# |      MaxTestEpRet |        1.38e+03 |
# |      MinTestEpRet |            -601 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            97.4 |
# |         StdQ1Vals |            13.9 |
# |         MaxQ1Vals |             134 |
# |         MinQ1Vals |            55.5 |
# |     AverageQ2Vals |            97.4 |
# |         StdQ2Vals |            13.9 |
# |         MaxQ2Vals |             133 |
# |         MinQ2Vals |            54.7 |
# |            LossPi |           -99.5 |
# |             LossQ |            2.89 |
# |              Time |        1.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             856 |
# |          StdEpRet |             827 |
# |          MaxEpRet |        1.38e+03 |
# |          MinEpRet |            -573 |
# |  AverageTestEpRet |        1.55e+03 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |        1.58e+03 |
# |      MinTestEpRet |        1.53e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             102 |
# |         StdQ1Vals |            16.3 |
# |         MaxQ1Vals |             139 |
# |         MinQ1Vals |           -6.83 |
# |     AverageQ2Vals |             102 |
# |         StdQ2Vals |            16.3 |
# |         MaxQ2Vals |             138 |
# |         MinQ2Vals |           -2.07 |
# |            LossPi |            -103 |
# |             LossQ |            3.19 |
# |              Time |        1.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |        1.42e+03 |
# |          StdEpRet |            49.6 |
# |          MaxEpRet |        1.47e+03 |
# |          MinEpRet |        1.34e+03 |
# |  AverageTestEpRet |        1.48e+03 |
# |      StdTestEpRet |            52.8 |
# |      MaxTestEpRet |        1.56e+03 |
# |      MinTestEpRet |        1.41e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             104 |
# |         StdQ1Vals |            20.4 |
# |         MaxQ1Vals |             150 |
# |         MinQ1Vals |           -42.9 |
# |     AverageQ2Vals |             104 |
# |         StdQ2Vals |            20.4 |
# |         MaxQ2Vals |             149 |
# |         MinQ2Vals |           -39.1 |
# |            LossPi |            -106 |
# |             LossQ |            3.65 |
# |              Time |        2.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |        1.44e+03 |
# |          StdEpRet |              58 |
# |          MaxEpRet |        1.53e+03 |
# |          MinEpRet |        1.38e+03 |
# |  AverageTestEpRet |        1.29e+03 |
# |      StdTestEpRet |             520 |
# |      MaxTestEpRet |        1.58e+03 |
# |      MinTestEpRet |             255 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             108 |
# |         StdQ1Vals |            24.3 |
# |         MaxQ1Vals |             153 |
# |         MinQ1Vals |           -87.1 |
# |     AverageQ2Vals |             108 |
# |         StdQ2Vals |            24.3 |
# |         MaxQ2Vals |             155 |
# |         MinQ2Vals |           -90.7 |
# |            LossPi |            -110 |
# |             LossQ |            4.24 |
# |              Time |        2.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        1.55e+03 |
# |          StdEpRet |            18.6 |
# |          MaxEpRet |        1.58e+03 |
# |          MinEpRet |        1.53e+03 |
# |  AverageTestEpRet |        1.46e+03 |
# |      StdTestEpRet |            34.5 |
# |      MaxTestEpRet |        1.51e+03 |
# |      MinTestEpRet |         1.4e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            27.9 |
# |         MaxQ1Vals |             158 |
# |         MinQ1Vals |            -123 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            27.9 |
# |         MaxQ2Vals |             158 |
# |         MinQ2Vals |            -125 |
# |            LossPi |            -113 |
# |             LossQ |            4.45 |
# |              Time |        2.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        1.55e+03 |
# |          StdEpRet |            16.5 |
# |          MaxEpRet |        1.58e+03 |
# |          MinEpRet |        1.53e+03 |
# |  AverageTestEpRet |        1.59e+03 |
# |      StdTestEpRet |            80.3 |
# |      MaxTestEpRet |        1.65e+03 |
# |      MinTestEpRet |        1.43e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             116 |
# |         StdQ1Vals |            29.4 |
# |         MaxQ1Vals |             161 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |             116 |
# |         StdQ2Vals |            29.4 |
# |         MaxQ2Vals |             160 |
# |         MinQ2Vals |            -137 |
# |            LossPi |            -117 |
# |             LossQ |             4.4 |
# |              Time |        2.43e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |         1.6e+03 |
# |          StdEpRet |            34.7 |
# |          MaxEpRet |        1.66e+03 |
# |          MinEpRet |        1.58e+03 |
# |  AverageTestEpRet |        1.65e+03 |
# |      StdTestEpRet |            18.3 |
# |      MaxTestEpRet |        1.68e+03 |
# |      MinTestEpRet |        1.62e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             121 |
# |         StdQ1Vals |            26.9 |
# |         MaxQ1Vals |             168 |
# |         MinQ1Vals |            -102 |
# |     AverageQ2Vals |             121 |
# |         StdQ2Vals |            26.9 |
# |         MaxQ2Vals |             167 |
# |         MinQ2Vals |            -102 |
# |            LossPi |            -123 |
# |             LossQ |            4.37 |
# |              Time |        2.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        1.62e+03 |
# |          StdEpRet |            29.9 |
# |          MaxEpRet |        1.67e+03 |
# |          MinEpRet |        1.59e+03 |
# |  AverageTestEpRet |        1.62e+03 |
# |      StdTestEpRet |            61.1 |
# |      MaxTestEpRet |        1.68e+03 |
# |      MinTestEpRet |        1.51e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             126 |
# |         StdQ1Vals |            25.7 |
# |         MaxQ1Vals |             173 |
# |         MinQ1Vals |           -62.2 |
# |     AverageQ2Vals |             126 |
# |         StdQ2Vals |            25.7 |
# |         MaxQ2Vals |             171 |
# |         MinQ2Vals |           -65.1 |
# |            LossPi |            -128 |
# |             LossQ |            4.17 |
# |              Time |        2.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        1.59e+03 |
# |          StdEpRet |            88.2 |
# |          MaxEpRet |        1.66e+03 |
# |          MinEpRet |        1.44e+03 |
# |  AverageTestEpRet |        1.63e+03 |
# |      StdTestEpRet |            46.6 |
# |      MaxTestEpRet |        1.69e+03 |
# |      MinTestEpRet |        1.56e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             131 |
# |         StdQ1Vals |            24.4 |
# |         MaxQ1Vals |             171 |
# |         MinQ1Vals |           -23.8 |
# |     AverageQ2Vals |             131 |
# |         StdQ2Vals |            24.4 |
# |         MaxQ2Vals |             172 |
# |         MinQ2Vals |           -20.8 |
# |            LossPi |            -132 |
# |             LossQ |            4.11 |
# |              Time |        2.78e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |         1.7e+03 |
# |          StdEpRet |            18.7 |
# |          MaxEpRet |        1.73e+03 |
# |          MinEpRet |        1.68e+03 |
# |  AverageTestEpRet |        1.76e+03 |
# |      StdTestEpRet |            30.8 |
# |      MaxTestEpRet |        1.79e+03 |
# |      MinTestEpRet |         1.7e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             135 |
# |         StdQ1Vals |            23.9 |
# |         MaxQ1Vals |             175 |
# |         MinQ1Vals |           -4.33 |
# |     AverageQ2Vals |             135 |
# |         StdQ2Vals |            23.9 |
# |         MaxQ2Vals |             176 |
# |         MinQ2Vals |          -0.927 |
# |            LossPi |            -137 |
# |             LossQ |            4.15 |
# |              Time |        2.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |         1.7e+03 |
# |          StdEpRet |            91.6 |
# |          MaxEpRet |        1.78e+03 |
# |          MinEpRet |        1.55e+03 |
# |  AverageTestEpRet |        1.28e+03 |
# |      StdTestEpRet |             887 |
# |      MaxTestEpRet |        1.75e+03 |
# |      MinTestEpRet |            -491 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             139 |
# |         StdQ1Vals |            23.9 |
# |         MaxQ1Vals |             179 |
# |         MinQ1Vals |            17.2 |
# |     AverageQ2Vals |             139 |
# |         StdQ2Vals |            23.9 |
# |         MaxQ2Vals |             180 |
# |         MinQ2Vals |            15.7 |
# |            LossPi |            -141 |
# |             LossQ |            4.37 |
# |              Time |        3.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        1.74e+03 |
# |          StdEpRet |            24.3 |
# |          MaxEpRet |        1.78e+03 |
# |          MinEpRet |        1.72e+03 |
# |  AverageTestEpRet |         1.8e+03 |
# |      StdTestEpRet |             109 |
# |      MaxTestEpRet |        1.93e+03 |
# |      MinTestEpRet |         1.6e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             143 |
# |         StdQ1Vals |            23.5 |
# |         MaxQ1Vals |             182 |
# |         MinQ1Vals |              10 |
# |     AverageQ2Vals |             143 |
# |         StdQ2Vals |            23.5 |
# |         MaxQ2Vals |             181 |
# |         MinQ2Vals |            10.7 |
# |            LossPi |            -145 |
# |             LossQ |            4.16 |
# |              Time |        3.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        1.81e+03 |
# |          StdEpRet |            48.7 |
# |          MaxEpRet |        1.87e+03 |
# |          MinEpRet |        1.74e+03 |
# |  AverageTestEpRet |         1.3e+03 |
# |      StdTestEpRet |             918 |
# |      MaxTestEpRet |        1.77e+03 |
# |      MinTestEpRet |            -538 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |             147 |
# |         StdQ1Vals |            24.1 |
# |         MaxQ1Vals |             189 |
# |         MinQ1Vals |            34.3 |
# |     AverageQ2Vals |             147 |
# |         StdQ2Vals |            24.1 |
# |         MaxQ2Vals |             188 |
# |         MinQ2Vals |            34.1 |
# |            LossPi |            -148 |
# |             LossQ |             4.2 |
# |              Time |        3.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        1.83e+03 |
# |          StdEpRet |            53.5 |
# |          MaxEpRet |        1.87e+03 |
# |          MinEpRet |        1.74e+03 |
# |  AverageTestEpRet |         1.9e+03 |
# |      StdTestEpRet |            76.1 |
# |      MaxTestEpRet |        1.96e+03 |
# |      MinTestEpRet |        1.75e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |             149 |
# |         StdQ1Vals |            25.9 |
# |         MaxQ1Vals |             188 |
# |         MinQ1Vals |              14 |
# |     AverageQ2Vals |             149 |
# |         StdQ2Vals |            25.9 |
# |         MaxQ2Vals |             188 |
# |         MinQ2Vals |            12.5 |
# |            LossPi |            -151 |
# |             LossQ |            4.48 |
# |              Time |        3.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |        1.87e+03 |
# |          StdEpRet |            16.4 |
# |          MaxEpRet |         1.9e+03 |
# |          MinEpRet |        1.86e+03 |
# |  AverageTestEpRet |        1.83e+03 |
# |      StdTestEpRet |            16.4 |
# |      MaxTestEpRet |        1.84e+03 |
# |      MinTestEpRet |         1.8e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             153 |
# |         StdQ1Vals |            26.6 |
# |         MaxQ1Vals |             193 |
# |         MinQ1Vals |            33.6 |
# |     AverageQ2Vals |             153 |
# |         StdQ2Vals |            26.6 |
# |         MaxQ2Vals |             191 |
# |         MinQ2Vals |              32 |
# |            LossPi |            -155 |
# |             LossQ |             4.3 |
# |              Time |        3.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        1.86e+03 |
# |          StdEpRet |            32.3 |
# |          MaxEpRet |         1.9e+03 |
# |          MinEpRet |        1.81e+03 |
# |  AverageTestEpRet |        1.85e+03 |
# |      StdTestEpRet |            38.6 |
# |      MaxTestEpRet |         1.9e+03 |
# |      MinTestEpRet |        1.79e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             157 |
# |         StdQ1Vals |            26.3 |
# |         MaxQ1Vals |             195 |
# |         MinQ1Vals |            31.7 |
# |     AverageQ2Vals |             157 |
# |         StdQ2Vals |            26.3 |
# |         MaxQ2Vals |             196 |
# |         MinQ2Vals |            32.3 |
# |            LossPi |            -159 |
# |             LossQ |            4.32 |
# |              Time |        3.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |        1.92e+03 |
# |          StdEpRet |            13.6 |
# |          MaxEpRet |        1.93e+03 |
# |          MinEpRet |         1.9e+03 |
# |  AverageTestEpRet |         1.8e+03 |
# |      StdTestEpRet |            32.9 |
# |      MaxTestEpRet |        1.84e+03 |
# |      MinTestEpRet |        1.75e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             161 |
# |         StdQ1Vals |            25.9 |
# |         MaxQ1Vals |             199 |
# |         MinQ1Vals |            23.4 |
# |     AverageQ2Vals |             161 |
# |         StdQ2Vals |            25.9 |
# |         MaxQ2Vals |             200 |
# |         MinQ2Vals |            21.2 |
# |            LossPi |            -162 |
# |             LossQ |            4.45 |
# |              Time |         3.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |        1.93e+03 |
# |          StdEpRet |            29.9 |
# |          MaxEpRet |        1.98e+03 |
# |          MinEpRet |        1.91e+03 |
# |  AverageTestEpRet |        1.88e+03 |
# |      StdTestEpRet |              27 |
# |      MaxTestEpRet |         1.9e+03 |
# |      MinTestEpRet |        1.83e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             163 |
# |         StdQ1Vals |            26.6 |
# |         MaxQ1Vals |             203 |
# |         MinQ1Vals |              42 |
# |     AverageQ2Vals |             163 |
# |         StdQ2Vals |            26.6 |
# |         MaxQ2Vals |             202 |
# |         MinQ2Vals |            33.6 |
# |            LossPi |            -165 |
# |             LossQ |            4.31 |
# |              Time |        3.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |        1.91e+03 |
# |          StdEpRet |            39.9 |
# |          MaxEpRet |        1.96e+03 |
# |          MinEpRet |        1.86e+03 |
# |  AverageTestEpRet |        1.93e+03 |
# |      StdTestEpRet |            7.11 |
# |      MaxTestEpRet |        1.94e+03 |
# |      MinTestEpRet |        1.92e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             167 |
# |         StdQ1Vals |            26.6 |
# |         MaxQ1Vals |             205 |
# |         MinQ1Vals |            49.2 |
# |     AverageQ2Vals |             167 |
# |         StdQ2Vals |            26.6 |
# |         MaxQ2Vals |             205 |
# |         MinQ2Vals |            45.8 |
# |            LossPi |            -168 |
# |             LossQ |            4.49 |
# |              Time |        3.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |        1.95e+03 |
# |          StdEpRet |            34.7 |
# |          MaxEpRet |        1.99e+03 |
# |          MinEpRet |         1.9e+03 |
# |  AverageTestEpRet |        1.51e+03 |
# |      StdTestEpRet |        1.02e+03 |
# |      MaxTestEpRet |        2.04e+03 |
# |      MinTestEpRet |            -535 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             170 |
# |         StdQ1Vals |            26.4 |
# |         MaxQ1Vals |             207 |
# |         MinQ1Vals |              66 |
# |     AverageQ2Vals |             170 |
# |         StdQ2Vals |            26.4 |
# |         MaxQ2Vals |             209 |
# |         MinQ2Vals |            62.3 |
# |            LossPi |            -171 |
# |             LossQ |            4.43 |
# |              Time |        4.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |         1.3e+03 |
# |          StdEpRet |        1.08e+03 |
# |          MaxEpRet |        1.95e+03 |
# |          MinEpRet |            -563 |
# |  AverageTestEpRet |        1.98e+03 |
# |      StdTestEpRet |            27.4 |
# |      MaxTestEpRet |           2e+03 |
# |      MinTestEpRet |        1.92e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             172 |
# |         StdQ1Vals |            26.7 |
# |         MaxQ1Vals |             209 |
# |         MinQ1Vals |            73.8 |
# |     AverageQ2Vals |             172 |
# |         StdQ2Vals |            26.7 |
# |         MaxQ2Vals |             210 |
# |         MinQ2Vals |            64.1 |
# |            LossPi |            -173 |
# |             LossQ |            4.43 |
# |              Time |        4.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        1.34e+03 |
# |          StdEpRet |        1.06e+03 |
# |          MaxEpRet |        1.98e+03 |
# |          MinEpRet |            -494 |
# |  AverageTestEpRet |         1.9e+03 |
# |      StdTestEpRet |             313 |
# |      MaxTestEpRet |        2.07e+03 |
# |      MinTestEpRet |        1.28e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             173 |
# |         StdQ1Vals |            27.8 |
# |         MaxQ1Vals |             212 |
# |         MinQ1Vals |            69.8 |
# |     AverageQ2Vals |             173 |
# |         StdQ2Vals |            27.8 |
# |         MaxQ2Vals |             211 |
# |         MinQ2Vals |            69.5 |
# |            LossPi |            -175 |
# |             LossQ |            4.28 |
# |              Time |        4.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        1.34e+03 |
# |          StdEpRet |         1.1e+03 |
# |          MaxEpRet |        2.03e+03 |
# |          MinEpRet |            -564 |
# |  AverageTestEpRet |         1.5e+03 |
# |      StdTestEpRet |        1.06e+03 |
# |      MaxTestEpRet |        2.05e+03 |
# |      MinTestEpRet |            -622 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             174 |
# |         StdQ1Vals |            30.9 |
# |         MaxQ1Vals |             213 |
# |         MinQ1Vals |           -15.3 |
# |     AverageQ2Vals |             174 |
# |         StdQ2Vals |            30.9 |
# |         MaxQ2Vals |             213 |
# |         MinQ2Vals |           -2.67 |
# |            LossPi |            -176 |
# |             LossQ |             4.7 |
# |              Time |        4.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        1.34e+03 |
# |          StdEpRet |        1.05e+03 |
# |          MaxEpRet |        1.98e+03 |
# |          MinEpRet |            -487 |
# |  AverageTestEpRet |        2.05e+03 |
# |      StdTestEpRet |            55.4 |
# |      MaxTestEpRet |        2.08e+03 |
# |      MinTestEpRet |        1.94e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             175 |
# |         StdQ1Vals |              35 |
# |         MaxQ1Vals |             214 |
# |         MinQ1Vals |           -27.4 |
# |     AverageQ2Vals |             175 |
# |         StdQ2Vals |              35 |
# |         MaxQ2Vals |             215 |
# |         MinQ2Vals |           -24.6 |
# |            LossPi |            -176 |
# |             LossQ |            4.84 |
# |              Time |        4.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        1.95e+03 |
# |          StdEpRet |            43.2 |
# |          MaxEpRet |        1.99e+03 |
# |          MinEpRet |        1.89e+03 |
# |  AverageTestEpRet |        1.97e+03 |
# |      StdTestEpRet |            54.1 |
# |      MaxTestEpRet |        2.02e+03 |
# |      MinTestEpRet |        1.87e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             176 |
# |         StdQ1Vals |            37.9 |
# |         MaxQ1Vals |             216 |
# |         MinQ1Vals |             -58 |
# |     AverageQ2Vals |             176 |
# |         StdQ2Vals |            37.9 |
# |         MaxQ2Vals |             216 |
# |         MinQ2Vals |           -54.7 |
# |            LossPi |            -178 |
# |             LossQ |            5.14 |
# |              Time |        4.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        1.34e+03 |
# |          StdEpRet |        1.06e+03 |
# |          MaxEpRet |        1.97e+03 |
# |          MinEpRet |            -501 |
# |  AverageTestEpRet |        1.87e+03 |
# |      StdTestEpRet |            16.4 |
# |      MaxTestEpRet |         1.9e+03 |
# |      MinTestEpRet |        1.85e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             177 |
# |         StdQ1Vals |            41.3 |
# |         MaxQ1Vals |             220 |
# |         MinQ1Vals |           -82.3 |
# |     AverageQ2Vals |             177 |
# |         StdQ2Vals |            41.3 |
# |         MaxQ2Vals |             218 |
# |         MinQ2Vals |           -87.1 |
# |            LossPi |            -178 |
# |             LossQ |            5.76 |
# |              Time |        4.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        1.97e+03 |
# |          StdEpRet |              45 |
# |          MaxEpRet |        2.01e+03 |
# |          MinEpRet |        1.89e+03 |
# |  AverageTestEpRet |        1.92e+03 |
# |      StdTestEpRet |            12.6 |
# |      MaxTestEpRet |        1.94e+03 |
# |      MinTestEpRet |        1.91e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             177 |
# |         StdQ1Vals |            44.1 |
# |         MaxQ1Vals |             219 |
# |         MinQ1Vals |           -90.3 |
# |     AverageQ2Vals |             177 |
# |         StdQ2Vals |            44.1 |
# |         MaxQ2Vals |             220 |
# |         MinQ2Vals |           -86.3 |
# |            LossPi |            -179 |
# |             LossQ |            6.58 |
# |              Time |        4.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        1.92e+03 |
# |          StdEpRet |            39.9 |
# |          MaxEpRet |        1.95e+03 |
# |          MinEpRet |        1.85e+03 |
# |  AverageTestEpRet |        1.97e+03 |
# |      StdTestEpRet |            27.6 |
# |      MaxTestEpRet |        2.01e+03 |
# |      MinTestEpRet |        1.93e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             179 |
# |         StdQ1Vals |            43.3 |
# |         MaxQ1Vals |             222 |
# |         MinQ1Vals |            -125 |
# |     AverageQ2Vals |             179 |
# |         StdQ2Vals |            43.3 |
# |         MaxQ2Vals |             221 |
# |         MinQ2Vals |            -115 |
# |            LossPi |            -180 |
# |             LossQ |            6.94 |
# |              Time |           5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |         1.9e+03 |
# |          StdEpRet |             160 |
# |          MaxEpRet |        2.05e+03 |
# |          MinEpRet |        1.63e+03 |
# |  AverageTestEpRet |        1.97e+03 |
# |      StdTestEpRet |            31.1 |
# |      MaxTestEpRet |        2.01e+03 |
# |      MinTestEpRet |        1.92e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             181 |
# |         StdQ1Vals |            43.4 |
# |         MaxQ1Vals |             222 |
# |         MinQ1Vals |            -133 |
# |     AverageQ2Vals |             181 |
# |         StdQ2Vals |            43.4 |
# |         MaxQ2Vals |             223 |
# |         MinQ2Vals |            -122 |
# |            LossPi |            -182 |
# |             LossQ |            6.88 |
# |              Time |        5.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        1.99e+03 |
# |          StdEpRet |            30.1 |
# |          MaxEpRet |        2.01e+03 |
# |          MinEpRet |        1.94e+03 |
# |  AverageTestEpRet |        2.04e+03 |
# |      StdTestEpRet |            12.8 |
# |      MaxTestEpRet |        2.06e+03 |
# |      MinTestEpRet |        2.03e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             182 |
# |         StdQ1Vals |              44 |
# |         MaxQ1Vals |             224 |
# |         MinQ1Vals |            -134 |
# |     AverageQ2Vals |             182 |
# |         StdQ2Vals |              44 |
# |         MaxQ2Vals |             226 |
# |         MinQ2Vals |            -120 |
# |            LossPi |            -183 |
# |             LossQ |            7.19 |
# |              Time |        5.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        1.98e+03 |
# |          StdEpRet |            7.38 |
# |          MaxEpRet |        1.99e+03 |
# |          MinEpRet |        1.97e+03 |
# |  AverageTestEpRet |        1.96e+03 |
# |      StdTestEpRet |            23.1 |
# |      MaxTestEpRet |           2e+03 |
# |      MinTestEpRet |        1.93e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             182 |
# |         StdQ1Vals |            46.5 |
# |         MaxQ1Vals |             224 |
# |         MinQ1Vals |            -132 |
# |     AverageQ2Vals |             182 |
# |         StdQ2Vals |            46.5 |
# |         MaxQ2Vals |             225 |
# |         MinQ2Vals |            -134 |
# |            LossPi |            -184 |
# |             LossQ |            8.02 |
# |              Time |        5.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        1.93e+03 |
# |          StdEpRet |              22 |
# |          MaxEpRet |        1.96e+03 |
# |          MinEpRet |        1.89e+03 |
# |  AverageTestEpRet |        1.97e+03 |
# |      StdTestEpRet |            14.3 |
# |      MaxTestEpRet |        1.99e+03 |
# |      MinTestEpRet |        1.95e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             182 |
# |         StdQ1Vals |            47.4 |
# |         MaxQ1Vals |             227 |
# |         MinQ1Vals |            -144 |
# |     AverageQ2Vals |             182 |
# |         StdQ2Vals |            47.4 |
# |         MaxQ2Vals |             226 |
# |         MinQ2Vals |            -132 |
# |            LossPi |            -184 |
# |             LossQ |            7.65 |
# |              Time |        5.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        1.97e+03 |
# |          StdEpRet |            29.4 |
# |          MaxEpRet |        2.02e+03 |
# |          MinEpRet |        1.94e+03 |
# |  AverageTestEpRet |        1.88e+03 |
# |      StdTestEpRet |            41.6 |
# |      MaxTestEpRet |        1.94e+03 |
# |      MinTestEpRet |        1.81e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             182 |
# |         StdQ1Vals |            48.7 |
# |         MaxQ1Vals |             226 |
# |         MinQ1Vals |            -132 |
# |     AverageQ2Vals |             182 |
# |         StdQ2Vals |            48.7 |
# |         MaxQ2Vals |             227 |
# |         MinQ2Vals |            -138 |
# |            LossPi |            -184 |
# |             LossQ |            8.17 |
# |              Time |        5.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        2.02e+03 |
# |          StdEpRet |            27.7 |
# |          MaxEpRet |        2.06e+03 |
# |          MinEpRet |        1.99e+03 |
# |  AverageTestEpRet |        2.04e+03 |
# |      StdTestEpRet |            19.5 |
# |      MaxTestEpRet |        2.06e+03 |
# |      MinTestEpRet |        2.01e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             183 |
# |         StdQ1Vals |            49.2 |
# |         MaxQ1Vals |             226 |
# |         MinQ1Vals |            -137 |
# |     AverageQ2Vals |             183 |
# |         StdQ2Vals |            49.2 |
# |         MaxQ2Vals |             225 |
# |         MinQ2Vals |            -148 |
# |            LossPi |            -185 |
# |             LossQ |            7.05 |
# |              Time |        5.71e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetahMuJoCoEnv-v0', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':False,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'exp_name': 'td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetahMuJoCoEnv-v0",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D1073C388>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	false,
#     "num_test_episodes":	5,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# WalkerBase::__init__
# WalkerBase::__init__
# options=
# options=
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -196 |
# |          StdEpRet |            42.9 |
# |          MaxEpRet |            -140 |
# |          MinEpRet |            -253 |
# |  AverageTestEpRet |            -580 |
# |      StdTestEpRet |            2.39 |
# |      MaxTestEpRet |            -577 |
# |      MinTestEpRet |            -584 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            3.72 |
# |         StdQ1Vals |            3.87 |
# |         MaxQ1Vals |            17.7 |
# |         MinQ1Vals |           -3.97 |
# |     AverageQ2Vals |            3.72 |
# |         StdQ2Vals |            3.87 |
# |         MaxQ2Vals |            17.9 |
# |         MinQ2Vals |           -4.13 |
# |            LossPi |           -5.01 |
# |             LossQ |           0.545 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            46.3 |
# |          MaxEpRet |            -124 |
# |          MinEpRet |            -242 |
# |  AverageTestEpRet |            -500 |
# |      StdTestEpRet |            28.3 |
# |      MaxTestEpRet |            -468 |
# |      MinTestEpRet |            -538 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            15.3 |
# |         StdQ1Vals |            7.49 |
# |         MaxQ1Vals |            53.5 |
# |         MinQ1Vals |           -3.11 |
# |     AverageQ2Vals |            15.3 |
# |         StdQ2Vals |            7.49 |
# |         MaxQ2Vals |            54.5 |
# |         MinQ2Vals |           -2.27 |
# |            LossPi |           -17.3 |
# |             LossQ |            1.67 |
# |              Time |             265 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -343 |
# |          StdEpRet |             146 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |            -539 |
# |  AverageTestEpRet |            -499 |
# |      StdTestEpRet |            16.8 |
# |      MaxTestEpRet |            -467 |
# |      MinTestEpRet |            -512 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            28.8 |
# |         StdQ1Vals |            14.2 |
# |         MaxQ1Vals |            89.5 |
# |         MinQ1Vals |          -0.349 |
# |     AverageQ2Vals |            28.8 |
# |         StdQ2Vals |            14.2 |
# |         MaxQ2Vals |            88.9 |
# |         MinQ2Vals |          -0.839 |
# |            LossPi |           -30.7 |
# |             LossQ |            2.38 |
# |              Time |             415 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -479 |
# |          StdEpRet |            38.3 |
# |          MaxEpRet |            -428 |
# |          MinEpRet |            -536 |
# |  AverageTestEpRet |            -472 |
# |      StdTestEpRet |            89.4 |
# |      MaxTestEpRet |            -333 |
# |      MinTestEpRet |            -593 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            36.5 |
# |         StdQ1Vals |            17.1 |
# |         MaxQ1Vals |            82.6 |
# |         MinQ1Vals |            2.95 |
# |     AverageQ2Vals |            36.5 |
# |         StdQ2Vals |            17.1 |
# |         MaxQ2Vals |            82.5 |
# |         MinQ2Vals |            1.08 |
# |            LossPi |           -37.9 |
# |             LossQ |            1.89 |
# |              Time |             578 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -229 |
# |          StdEpRet |            95.3 |
# |          MaxEpRet |            -119 |
# |          MinEpRet |            -377 |
# |  AverageTestEpRet |            -358 |
# |      StdTestEpRet |            17.1 |
# |      MaxTestEpRet |            -338 |
# |      MinTestEpRet |            -389 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            30.7 |
# |         StdQ1Vals |            17.6 |
# |         MaxQ1Vals |            74.3 |
# |         MinQ1Vals |           -11.8 |
# |     AverageQ2Vals |            30.7 |
# |         StdQ2Vals |            17.6 |
# |         MaxQ2Vals |            74.1 |
# |         MinQ2Vals |           -11.5 |
# |            LossPi |           -31.7 |
# |             LossQ |            1.16 |
# |              Time |             736 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -325 |
# |          StdEpRet |             130 |
# |          MaxEpRet |            -211 |
# |          MinEpRet |            -543 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            50.7 |
# |      MaxTestEpRet |            -133 |
# |      MinTestEpRet |            -288 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            28.3 |
# |         StdQ1Vals |            16.8 |
# |         MaxQ1Vals |            75.1 |
# |         MinQ1Vals |           -27.9 |
# |     AverageQ2Vals |            28.3 |
# |         StdQ2Vals |            16.8 |
# |         MaxQ2Vals |            77.3 |
# |         MinQ2Vals |           -27.9 |
# |            LossPi |           -29.3 |
# |             LossQ |           0.717 |
# |              Time |             890 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -334 |
# |          StdEpRet |            87.6 |
# |          MaxEpRet |            -245 |
# |          MinEpRet |            -474 |
# |  AverageTestEpRet |            -326 |
# |      StdTestEpRet |            43.8 |
# |      MaxTestEpRet |            -252 |
# |      MinTestEpRet |            -381 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            26.4 |
# |         StdQ1Vals |            11.7 |
# |         MaxQ1Vals |            64.2 |
# |         MinQ1Vals |           -18.5 |
# |     AverageQ2Vals |            26.4 |
# |         StdQ2Vals |            11.7 |
# |         MaxQ2Vals |            65.5 |
# |         MinQ2Vals |           -18.5 |
# |            LossPi |           -27.3 |
# |             LossQ |           0.603 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -363 |
# |          StdEpRet |             104 |
# |          MaxEpRet |            -199 |
# |          MinEpRet |            -455 |
# |  AverageTestEpRet |            -414 |
# |      StdTestEpRet |            91.6 |
# |      MaxTestEpRet |            -251 |
# |      MinTestEpRet |            -498 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            22.2 |
# |         StdQ1Vals |               9 |
# |         MaxQ1Vals |            79.6 |
# |         MinQ1Vals |           -7.48 |
# |     AverageQ2Vals |            22.2 |
# |         StdQ2Vals |               9 |
# |         MaxQ2Vals |            78.1 |
# |         MinQ2Vals |           -7.62 |
# |            LossPi |           -22.9 |
# |             LossQ |           0.546 |
# |              Time |        1.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -181 |
# |          StdEpRet |            65.9 |
# |          MaxEpRet |           -86.3 |
# |          MinEpRet |            -268 |
# |  AverageTestEpRet |           -61.5 |
# |      StdTestEpRet |            19.3 |
# |      MaxTestEpRet |           -29.4 |
# |      MinTestEpRet |           -87.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            18.5 |
# |         StdQ1Vals |            10.7 |
# |         MaxQ1Vals |            72.1 |
# |         MinQ1Vals |           -12.8 |
# |     AverageQ2Vals |            18.5 |
# |         StdQ2Vals |            10.7 |
# |         MaxQ2Vals |            71.4 |
# |         MinQ2Vals |           -12.9 |
# |            LossPi |           -19.2 |
# |             LossQ |           0.509 |
# |              Time |        1.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -178 |
# |          StdEpRet |             166 |
# |          MaxEpRet |           -62.4 |
# |          MinEpRet |            -464 |
# |  AverageTestEpRet |            -123 |
# |      StdTestEpRet |             117 |
# |      MaxTestEpRet |           -34.1 |
# |      MinTestEpRet |            -354 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            14.8 |
# |         StdQ1Vals |            9.72 |
# |         MaxQ1Vals |            55.8 |
# |         MinQ1Vals |           -19.4 |
# |     AverageQ2Vals |            14.8 |
# |         StdQ2Vals |            9.72 |
# |         MaxQ2Vals |              55 |
# |         MinQ2Vals |           -19.3 |
# |            LossPi |           -15.5 |
# |             LossQ |           0.477 |
# |              Time |         1.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           -52.4 |
# |          StdEpRet |             116 |
# |          MaxEpRet |             111 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -164 |
# |      StdTestEpRet |             178 |
# |      MaxTestEpRet |            36.2 |
# |      MinTestEpRet |            -438 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            12.4 |
# |         StdQ1Vals |            9.31 |
# |         MaxQ1Vals |            47.3 |
# |         MinQ1Vals |           -19.2 |
# |     AverageQ2Vals |            12.4 |
# |         StdQ2Vals |            9.31 |
# |         MaxQ2Vals |            47.3 |
# |         MinQ2Vals |           -18.9 |
# |            LossPi |           -13.1 |
# |             LossQ |           0.415 |
# |              Time |        1.62e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -138 |
# |          StdEpRet |             154 |
# |          MaxEpRet |            98.2 |
# |          MinEpRet |            -333 |
# |  AverageTestEpRet |             184 |
# |      StdTestEpRet |             104 |
# |      MaxTestEpRet |             303 |
# |      MinTestEpRet |            12.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |             9.7 |
# |         StdQ1Vals |            7.74 |
# |         MaxQ1Vals |            33.3 |
# |         MinQ1Vals |           -19.5 |
# |     AverageQ2Vals |             9.7 |
# |         StdQ2Vals |            7.74 |
# |         MaxQ2Vals |              33 |
# |         MinQ2Vals |           -19.5 |
# |            LossPi |           -10.3 |
# |             LossQ |           0.407 |
# |              Time |        1.74e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            46.4 |
# |          StdEpRet |            75.7 |
# |          MaxEpRet |             144 |
# |          MinEpRet |           -48.9 |
# |  AverageTestEpRet |           -11.6 |
# |      StdTestEpRet |            70.7 |
# |      MaxTestEpRet |             116 |
# |      MinTestEpRet |           -82.6 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            7.51 |
# |         StdQ1Vals |            6.67 |
# |         MaxQ1Vals |            23.2 |
# |         MinQ1Vals |           -15.8 |
# |     AverageQ2Vals |            7.51 |
# |         StdQ2Vals |            6.67 |
# |         MaxQ2Vals |            23.3 |
# |         MinQ2Vals |             -16 |
# |            LossPi |           -8.16 |
# |             LossQ |            0.43 |
# |              Time |        1.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            30.6 |
# |          StdEpRet |            51.9 |
# |          MaxEpRet |             117 |
# |          MinEpRet |           -18.2 |
# |  AverageTestEpRet |           -6.83 |
# |      StdTestEpRet |             111 |
# |      MaxTestEpRet |             153 |
# |      MinTestEpRet |            -120 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            5.99 |
# |         StdQ1Vals |            6.37 |
# |         MaxQ1Vals |            21.9 |
# |         MinQ1Vals |           -21.2 |
# |     AverageQ2Vals |            5.99 |
# |         StdQ2Vals |            6.37 |
# |         MaxQ2Vals |            22.1 |
# |         MinQ2Vals |             -22 |
# |            LossPi |           -6.75 |
# |             LossQ |           0.463 |
# |              Time |        1.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            94.4 |
# |          StdEpRet |              65 |
# |          MaxEpRet |             166 |
# |          MinEpRet |           -9.59 |
# |  AverageTestEpRet |             176 |
# |      StdTestEpRet |            37.3 |
# |      MaxTestEpRet |             228 |
# |      MinTestEpRet |             129 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            5.95 |
# |         StdQ1Vals |            6.39 |
# |         MaxQ1Vals |            21.2 |
# |         MinQ1Vals |           -23.1 |
# |     AverageQ2Vals |            5.95 |
# |         StdQ2Vals |            6.39 |
# |         MaxQ2Vals |            21.4 |
# |         MinQ2Vals |           -24.2 |
# |            LossPi |           -6.76 |
# |             LossQ |           0.483 |
# |              Time |        2.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            48.1 |
# |          StdEpRet |            43.7 |
# |          MaxEpRet |             116 |
# |          MinEpRet |            -3.2 |
# |  AverageTestEpRet |           -31.1 |
# |      StdTestEpRet |            15.4 |
# |      MaxTestEpRet |           -7.14 |
# |      MinTestEpRet |             -52 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            6.73 |
# |         StdQ1Vals |            7.08 |
# |         MaxQ1Vals |            22.5 |
# |         MinQ1Vals |             -26 |
# |     AverageQ2Vals |            6.73 |
# |         StdQ2Vals |            7.08 |
# |         MaxQ2Vals |            22.5 |
# |         MinQ2Vals |             -26 |
# |            LossPi |           -7.54 |
# |             LossQ |           0.487 |
# |              Time |         2.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             107 |
# |          StdEpRet |            33.4 |
# |          MaxEpRet |             162 |
# |          MinEpRet |            72.1 |
# |  AverageTestEpRet |             176 |
# |      StdTestEpRet |            94.1 |
# |      MaxTestEpRet |             260 |
# |      MinTestEpRet |            38.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            7.72 |
# |         StdQ1Vals |            6.94 |
# |         MaxQ1Vals |            23.5 |
# |         MinQ1Vals |           -24.9 |
# |     AverageQ2Vals |            7.72 |
# |         StdQ2Vals |            6.94 |
# |         MaxQ2Vals |            23.5 |
# |         MinQ2Vals |           -24.9 |
# |            LossPi |            -8.5 |
# |             LossQ |           0.487 |
# |              Time |        2.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             122 |
# |          StdEpRet |            23.2 |
# |          MaxEpRet |             154 |
# |          MinEpRet |            92.3 |
# |  AverageTestEpRet |             279 |
# |      StdTestEpRet |            41.4 |
# |      MaxTestEpRet |             354 |
# |      MinTestEpRet |             233 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            7.73 |
# |         StdQ1Vals |            6.94 |
# |         MaxQ1Vals |              23 |
# |         MinQ1Vals |           -27.1 |
# |     AverageQ2Vals |            7.73 |
# |         StdQ2Vals |            6.94 |
# |         MaxQ2Vals |              23 |
# |         MinQ2Vals |           -27.1 |
# |            LossPi |           -8.52 |
# |             LossQ |           0.482 |
# |              Time |        2.42e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             112 |
# |          StdEpRet |            34.8 |
# |          MaxEpRet |             150 |
# |          MinEpRet |            56.9 |
# |  AverageTestEpRet |             176 |
# |      StdTestEpRet |            16.8 |
# |      MaxTestEpRet |             208 |
# |      MinTestEpRet |             163 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            7.97 |
# |         StdQ1Vals |            5.81 |
# |         MaxQ1Vals |            22.2 |
# |         MinQ1Vals |             -23 |
# |     AverageQ2Vals |            7.97 |
# |         StdQ2Vals |            5.81 |
# |         MaxQ2Vals |            22.2 |
# |         MinQ2Vals |           -22.6 |
# |            LossPi |           -8.67 |
# |             LossQ |           0.492 |
# |              Time |        2.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             234 |
# |          StdEpRet |            78.1 |
# |          MaxEpRet |             312 |
# |          MinEpRet |             104 |
# |  AverageTestEpRet |             290 |
# |      StdTestEpRet |            37.6 |
# |      MaxTestEpRet |             349 |
# |      MinTestEpRet |             249 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            8.41 |
# |         StdQ1Vals |            5.82 |
# |         MaxQ1Vals |            25.8 |
# |         MinQ1Vals |           -27.7 |
# |     AverageQ2Vals |            8.41 |
# |         StdQ2Vals |            5.82 |
# |         MaxQ2Vals |            27.7 |
# |         MinQ2Vals |           -27.6 |
# |            LossPi |           -9.06 |
# |             LossQ |           0.497 |
# |              Time |        2.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             199 |
# |          StdEpRet |            28.7 |
# |          MaxEpRet |             221 |
# |          MinEpRet |             150 |
# |  AverageTestEpRet |             189 |
# |      StdTestEpRet |            42.2 |
# |      MaxTestEpRet |             257 |
# |      MinTestEpRet |             131 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             9.5 |
# |         StdQ1Vals |            6.54 |
# |         MaxQ1Vals |              28 |
# |         MinQ1Vals |           -36.4 |
# |     AverageQ2Vals |             9.5 |
# |         StdQ2Vals |            6.54 |
# |         MaxQ2Vals |            28.2 |
# |         MinQ2Vals |           -36.2 |
# |            LossPi |           -10.2 |
# |             LossQ |           0.536 |
# |              Time |        2.79e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             211 |
# |          StdEpRet |            77.4 |
# |          MaxEpRet |             296 |
# |          MinEpRet |              85 |
# |  AverageTestEpRet |             303 |
# |      StdTestEpRet |            16.3 |
# |      MaxTestEpRet |             322 |
# |      MinTestEpRet |             278 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            10.8 |
# |         StdQ1Vals |            6.58 |
# |         MaxQ1Vals |            28.1 |
# |         MinQ1Vals |           -34.4 |
# |     AverageQ2Vals |            10.8 |
# |         StdQ2Vals |            6.58 |
# |         MaxQ2Vals |            26.9 |
# |         MinQ2Vals |           -34.3 |
# |            LossPi |           -11.4 |
# |             LossQ |           0.532 |
# |              Time |        2.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             237 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |             273 |
# |          MinEpRet |             201 |
# |  AverageTestEpRet |             255 |
# |      StdTestEpRet |            24.2 |
# |      MaxTestEpRet |             291 |
# |      MinTestEpRet |             227 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |              12 |
# |         StdQ1Vals |            6.62 |
# |         MaxQ1Vals |            29.5 |
# |         MinQ1Vals |           -27.9 |
# |     AverageQ2Vals |              12 |
# |         StdQ2Vals |            6.62 |
# |         MaxQ2Vals |            29.1 |
# |         MinQ2Vals |           -26.2 |
# |            LossPi |           -12.7 |
# |             LossQ |           0.576 |
# |              Time |        3.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             295 |
# |          StdEpRet |            33.8 |
# |          MaxEpRet |             340 |
# |          MinEpRet |             251 |
# |  AverageTestEpRet |             411 |
# |      StdTestEpRet |            38.7 |
# |      MaxTestEpRet |             448 |
# |      MinTestEpRet |             342 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            13.7 |
# |         StdQ1Vals |               7 |
# |         MaxQ1Vals |              30 |
# |         MinQ1Vals |           -33.3 |
# |     AverageQ2Vals |            13.7 |
# |         StdQ2Vals |               7 |
# |         MaxQ2Vals |            29.6 |
# |         MinQ2Vals |           -33.1 |
# |            LossPi |           -14.3 |
# |             LossQ |           0.565 |
# |              Time |        3.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             150 |
# |          StdEpRet |             411 |
# |          MaxEpRet |             401 |
# |          MinEpRet |            -563 |
# |  AverageTestEpRet |             221 |
# |      StdTestEpRet |             381 |
# |      MaxTestEpRet |             441 |
# |      MinTestEpRet |            -538 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            15.1 |
# |         StdQ1Vals |            8.01 |
# |         MaxQ1Vals |            32.9 |
# |         MinQ1Vals |           -81.2 |
# |     AverageQ2Vals |            15.1 |
# |         StdQ2Vals |            8.01 |
# |         MaxQ2Vals |              32 |
# |         MinQ2Vals |           -88.3 |
# |            LossPi |           -15.8 |
# |             LossQ |           0.628 |
# |              Time |        3.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             304 |
# |          StdEpRet |            54.1 |
# |          MaxEpRet |             363 |
# |          MinEpRet |             218 |
# |  AverageTestEpRet |             268 |
# |      StdTestEpRet |            28.1 |
# |      MaxTestEpRet |             316 |
# |      MinTestEpRet |             230 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            15.9 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |            32.2 |
# |         MinQ1Vals |           -83.5 |
# |     AverageQ2Vals |            15.9 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |            31.3 |
# |         MinQ2Vals |           -77.7 |
# |            LossPi |           -16.6 |
# |             LossQ |           0.681 |
# |              Time |        3.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             232 |
# |          StdEpRet |            50.7 |
# |          MaxEpRet |             297 |
# |          MinEpRet |             167 |
# |  AverageTestEpRet |            47.7 |
# |      StdTestEpRet |             333 |
# |      MaxTestEpRet |             252 |
# |      MinTestEpRet |            -617 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            17.2 |
# |         StdQ1Vals |              10 |
# |         MaxQ1Vals |            30.1 |
# |         MinQ1Vals |           -77.1 |
# |     AverageQ2Vals |            17.2 |
# |         StdQ2Vals |              10 |
# |         MaxQ2Vals |            30.5 |
# |         MinQ2Vals |           -75.8 |
# |            LossPi |           -17.8 |
# |             LossQ |            0.69 |
# |              Time |        3.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             251 |
# |          StdEpRet |            47.5 |
# |          MaxEpRet |             325 |
# |          MinEpRet |             209 |
# |  AverageTestEpRet |             244 |
# |      StdTestEpRet |            53.3 |
# |      MaxTestEpRet |             277 |
# |      MinTestEpRet |             138 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            18.9 |
# |         StdQ1Vals |            9.79 |
# |         MaxQ1Vals |            33.9 |
# |         MinQ1Vals |           -75.7 |
# |     AverageQ2Vals |            18.9 |
# |         StdQ2Vals |            9.79 |
# |         MaxQ2Vals |            34.9 |
# |         MinQ2Vals |           -79.5 |
# |            LossPi |           -19.6 |
# |             LossQ |           0.743 |
# |              Time |        3.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             241 |
# |          StdEpRet |            74.6 |
# |          MaxEpRet |             349 |
# |          MinEpRet |             151 |
# |  AverageTestEpRet |             343 |
# |      StdTestEpRet |            38.8 |
# |      MaxTestEpRet |             392 |
# |      MinTestEpRet |             283 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            20.1 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |            35.8 |
# |         MinQ1Vals |           -86.6 |
# |     AverageQ2Vals |            20.1 |
# |         StdQ2Vals |            10.2 |
# |         MaxQ2Vals |            36.7 |
# |         MinQ2Vals |           -89.1 |
# |            LossPi |           -20.7 |
# |             LossQ |           0.767 |
# |              Time |        3.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             295 |
# |          StdEpRet |            43.1 |
# |          MaxEpRet |             363 |
# |          MinEpRet |             252 |
# |  AverageTestEpRet |             342 |
# |      StdTestEpRet |            53.8 |
# |      MaxTestEpRet |             425 |
# |      MinTestEpRet |             275 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |              21 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |            35.3 |
# |         MinQ1Vals |           -84.3 |
# |     AverageQ2Vals |              21 |
# |         StdQ2Vals |            10.2 |
# |         MaxQ2Vals |            36.1 |
# |         MinQ2Vals |           -85.1 |
# |            LossPi |           -21.7 |
# |             LossQ |           0.794 |
# |              Time |        3.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             271 |
# |          StdEpRet |            55.2 |
# |          MaxEpRet |             351 |
# |          MinEpRet |             218 |
# |  AverageTestEpRet |             205 |
# |      StdTestEpRet |            12.6 |
# |      MaxTestEpRet |             219 |
# |      MinTestEpRet |             187 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            21.8 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |            32.5 |
# |         MinQ1Vals |             -81 |
# |     AverageQ2Vals |            21.8 |
# |         StdQ2Vals |            10.2 |
# |         MaxQ2Vals |            32.6 |
# |         MinQ2Vals |           -81.6 |
# |            LossPi |           -22.4 |
# |             LossQ |           0.786 |
# |              Time |        4.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             297 |
# |          StdEpRet |            69.3 |
# |          MaxEpRet |             377 |
# |          MinEpRet |             193 |
# |  AverageTestEpRet |             287 |
# |      StdTestEpRet |            44.5 |
# |      MaxTestEpRet |             353 |
# |      MinTestEpRet |             219 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            22.7 |
# |         StdQ1Vals |            10.1 |
# |         MaxQ1Vals |            34.9 |
# |         MinQ1Vals |             -78 |
# |     AverageQ2Vals |            22.7 |
# |         StdQ2Vals |            10.1 |
# |         MaxQ2Vals |            35.2 |
# |         MinQ2Vals |             -78 |
# |            LossPi |           -23.4 |
# |             LossQ |           0.799 |
# |              Time |        4.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             316 |
# |          StdEpRet |            68.6 |
# |          MaxEpRet |             387 |
# |          MinEpRet |             206 |
# |  AverageTestEpRet |             350 |
# |      StdTestEpRet |            46.5 |
# |      MaxTestEpRet |             399 |
# |      MinTestEpRet |             288 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            23.8 |
# |         StdQ1Vals |            10.1 |
# |         MaxQ1Vals |              38 |
# |         MinQ1Vals |           -75.8 |
# |     AverageQ2Vals |            23.8 |
# |         StdQ2Vals |            10.1 |
# |         MaxQ2Vals |            38.1 |
# |         MinQ2Vals |           -77.5 |
# |            LossPi |           -24.4 |
# |             LossQ |            0.81 |
# |              Time |        4.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             321 |
# |          StdEpRet |            40.4 |
# |          MaxEpRet |             369 |
# |          MinEpRet |             258 |
# |  AverageTestEpRet |             412 |
# |      StdTestEpRet |            29.1 |
# |      MaxTestEpRet |             456 |
# |      MinTestEpRet |             370 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |            24.5 |
# |         StdQ1Vals |            9.54 |
# |         MaxQ1Vals |            38.6 |
# |         MinQ1Vals |           -66.5 |
# |     AverageQ2Vals |            24.5 |
# |         StdQ2Vals |            9.54 |
# |         MaxQ2Vals |            39.1 |
# |         MinQ2Vals |             -67 |
# |            LossPi |           -25.2 |
# |             LossQ |           0.833 |
# |              Time |        4.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             319 |
# |          StdEpRet |            62.4 |
# |          MaxEpRet |             379 |
# |          MinEpRet |             223 |
# |  AverageTestEpRet |             369 |
# |      StdTestEpRet |            26.1 |
# |      MaxTestEpRet |             415 |
# |      MinTestEpRet |             346 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            25.2 |
# |         StdQ1Vals |            8.67 |
# |         MaxQ1Vals |            38.5 |
# |         MinQ1Vals |           -51.5 |
# |     AverageQ2Vals |            25.2 |
# |         StdQ2Vals |            8.67 |
# |         MaxQ2Vals |            38.4 |
# |         MinQ2Vals |             -48 |
# |            LossPi |           -25.8 |
# |             LossQ |            0.83 |
# |              Time |        4.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             153 |
# |          StdEpRet |             447 |
# |          MaxEpRet |             426 |
# |          MinEpRet |            -621 |
# |  AverageTestEpRet |             321 |
# |      StdTestEpRet |            47.7 |
# |      MaxTestEpRet |             397 |
# |      MinTestEpRet |             263 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |            25.3 |
# |         StdQ1Vals |            8.85 |
# |         MaxQ1Vals |            38.2 |
# |         MinQ1Vals |           -49.5 |
# |     AverageQ2Vals |            25.3 |
# |         StdQ2Vals |            8.85 |
# |         MaxQ2Vals |            37.9 |
# |         MinQ2Vals |           -49.5 |
# |            LossPi |           -25.9 |
# |             LossQ |           0.906 |
# |              Time |        4.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             250 |
# |          StdEpRet |            48.9 |
# |          MaxEpRet |             287 |
# |          MinEpRet |             167 |
# |  AverageTestEpRet |             316 |
# |      StdTestEpRet |            20.3 |
# |      MaxTestEpRet |             341 |
# |      MinTestEpRet |             283 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            25.7 |
# |         StdQ1Vals |            9.79 |
# |         MaxQ1Vals |            40.3 |
# |         MinQ1Vals |           -61.5 |
# |     AverageQ2Vals |            25.7 |
# |         StdQ2Vals |            9.79 |
# |         MaxQ2Vals |            40.9 |
# |         MinQ2Vals |           -59.9 |
# |            LossPi |           -26.3 |
# |             LossQ |           0.962 |
# |              Time |        4.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             269 |
# |          StdEpRet |            45.7 |
# |          MaxEpRet |             348 |
# |          MinEpRet |             237 |
# |  AverageTestEpRet |             383 |
# |      StdTestEpRet |            63.2 |
# |      MaxTestEpRet |             501 |
# |      MinTestEpRet |             316 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |              26 |
# |         StdQ1Vals |            10.9 |
# |         MaxQ1Vals |            40.7 |
# |         MinQ1Vals |           -65.1 |
# |     AverageQ2Vals |              26 |
# |         StdQ2Vals |            10.9 |
# |         MaxQ2Vals |            42.2 |
# |         MinQ2Vals |           -63.9 |
# |            LossPi |           -26.6 |
# |             LossQ |           0.948 |
# |              Time |        5.11e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |             371 |
# |          StdEpRet |            82.7 |
# |          MaxEpRet |             485 |
# |          MinEpRet |             284 |
# |  AverageTestEpRet |             441 |
# |      StdTestEpRet |            29.3 |
# |      MaxTestEpRet |             476 |
# |      MinTestEpRet |             399 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |            26.4 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |            40.2 |
# |         MinQ1Vals |           -65.6 |
# |     AverageQ2Vals |            26.4 |
# |         StdQ2Vals |            10.9 |
# |         MaxQ2Vals |            40.5 |
# |         MinQ2Vals |           -68.3 |
# |            LossPi |           -26.9 |
# |             LossQ |           0.911 |
# |              Time |        5.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |             158 |
# |          StdEpRet |             386 |
# |          MaxEpRet |             420 |
# |          MinEpRet |            -509 |
# |  AverageTestEpRet |             452 |
# |      StdTestEpRet |            26.2 |
# |      MaxTestEpRet |             495 |
# |      MinTestEpRet |             415 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |            26.8 |
# |         StdQ1Vals |            10.5 |
# |         MaxQ1Vals |            43.2 |
# |         MinQ1Vals |           -74.8 |
# |     AverageQ2Vals |            26.8 |
# |         StdQ2Vals |            10.5 |
# |         MaxQ2Vals |            43.6 |
# |         MinQ2Vals |           -72.6 |
# |            LossPi |           -27.4 |
# |             LossQ |           0.845 |
# |              Time |        5.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             106 |
# |          StdEpRet |             394 |
# |          MaxEpRet |             410 |
# |          MinEpRet |            -569 |
# |  AverageTestEpRet |             315 |
# |      StdTestEpRet |              45 |
# |      MaxTestEpRet |             404 |
# |      MinTestEpRet |             279 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |            27.2 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |            44.2 |
# |         MinQ1Vals |             -63 |
# |     AverageQ2Vals |            27.2 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |              44 |
# |         MinQ2Vals |           -64.5 |
# |            LossPi |           -27.7 |
# |             LossQ |           0.899 |
# |              Time |        5.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             364 |
# |          StdEpRet |            29.1 |
# |          MaxEpRet |             397 |
# |          MinEpRet |             327 |
# |  AverageTestEpRet |             311 |
# |      StdTestEpRet |            25.8 |
# |      MaxTestEpRet |             345 |
# |      MinTestEpRet |             282 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |            27.5 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |            41.5 |
# |         MinQ1Vals |           -55.9 |
# |     AverageQ2Vals |            27.5 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |            41.8 |
# |         MinQ2Vals |           -70.6 |
# |            LossPi |             -28 |
# |             LossQ |           0.943 |
# |              Time |        5.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             354 |
# |          StdEpRet |             123 |
# |          MaxEpRet |             551 |
# |          MinEpRet |             213 |
# |  AverageTestEpRet |             355 |
# |      StdTestEpRet |            28.9 |
# |      MaxTestEpRet |             400 |
# |      MinTestEpRet |             312 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |            27.7 |
# |         StdQ1Vals |            11.5 |
# |         MaxQ1Vals |            40.7 |
# |         MinQ1Vals |           -55.2 |
# |     AverageQ2Vals |            27.7 |
# |         StdQ2Vals |            11.5 |
# |         MaxQ2Vals |            41.1 |
# |         MinQ2Vals |           -56.3 |
# |            LossPi |           -28.2 |
# |             LossQ |           0.965 |
# |              Time |         5.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             368 |
# |          StdEpRet |            63.4 |
# |          MaxEpRet |             466 |
# |          MinEpRet |             309 |
# |  AverageTestEpRet |             189 |
# |      StdTestEpRet |             326 |
# |      MaxTestEpRet |             423 |
# |      MinTestEpRet |            -454 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |            28.1 |
# |         StdQ1Vals |            12.2 |
# |         MaxQ1Vals |            42.8 |
# |         MinQ1Vals |           -59.5 |
# |     AverageQ2Vals |            28.1 |
# |         StdQ2Vals |            12.2 |
# |         MaxQ2Vals |            42.6 |
# |         MinQ2Vals |             -59 |
# |            LossPi |           -28.6 |
# |             LossQ |           0.953 |
# |              Time |        5.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             341 |
# |          StdEpRet |            40.9 |
# |          MaxEpRet |             410 |
# |          MinEpRet |             307 |
# |  AverageTestEpRet |             451 |
# |      StdTestEpRet |            56.6 |
# |      MaxTestEpRet |             526 |
# |      MinTestEpRet |             386 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |            28.6 |
# |         StdQ1Vals |            11.7 |
# |         MaxQ1Vals |            42.7 |
# |         MinQ1Vals |           -66.1 |
# |     AverageQ2Vals |            28.6 |
# |         StdQ2Vals |            11.7 |
# |         MaxQ2Vals |            42.4 |
# |         MinQ2Vals |           -63.8 |
# |            LossPi |           -29.2 |
# |             LossQ |           0.957 |
# |              Time |        6.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |             364 |
# |          StdEpRet |            46.3 |
# |          MaxEpRet |             420 |
# |          MinEpRet |             296 |
# |  AverageTestEpRet |             411 |
# |      StdTestEpRet |            57.7 |
# |      MaxTestEpRet |             486 |
# |      MinTestEpRet |             344 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |            28.8 |
# |         StdQ1Vals |            11.4 |
# |         MaxQ1Vals |            46.9 |
# |         MinQ1Vals |           -61.6 |
# |     AverageQ2Vals |            28.8 |
# |         StdQ2Vals |            11.4 |
# |         MaxQ2Vals |            47.3 |
# |         MinQ2Vals |           -61.1 |
# |            LossPi |           -29.3 |
# |             LossQ |           0.993 |
# |              Time |        6.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |             411 |
# |          StdEpRet |            18.7 |
# |          MaxEpRet |             426 |
# |          MinEpRet |             379 |
# |  AverageTestEpRet |             423 |
# |      StdTestEpRet |            43.1 |
# |      MaxTestEpRet |             470 |
# |      MinTestEpRet |             354 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |            29.2 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |            53.7 |
# |         MinQ1Vals |             -59 |
# |     AverageQ2Vals |            29.2 |
# |         StdQ2Vals |            10.8 |
# |         MaxQ2Vals |            52.2 |
# |         MinQ2Vals |           -59.4 |
# |            LossPi |           -29.7 |
# |             LossQ |           0.978 |
# |              Time |        6.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             332 |
# |          StdEpRet |            84.4 |
# |          MaxEpRet |             426 |
# |          MinEpRet |             213 |
# |  AverageTestEpRet |             176 |
# |      StdTestEpRet |             302 |
# |      MaxTestEpRet |             399 |
# |      MinTestEpRet |            -421 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |            29.8 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |            55.5 |
# |         MinQ1Vals |           -61.9 |
# |     AverageQ2Vals |            29.8 |
# |         StdQ2Vals |            10.2 |
# |         MaxQ2Vals |            53.7 |
# |         MinQ2Vals |           -67.1 |
# |            LossPi |           -30.3 |
# |             LossQ |           0.983 |
# |              Time |         6.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             291 |
# |          StdEpRet |            20.1 |
# |          MaxEpRet |             318 |
# |          MinEpRet |             267 |
# |  AverageTestEpRet |             350 |
# |      StdTestEpRet |            40.7 |
# |      MaxTestEpRet |             412 |
# |      MinTestEpRet |             292 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |              30 |
# |         StdQ1Vals |            9.86 |
# |         MaxQ1Vals |            53.2 |
# |         MinQ1Vals |           -52.9 |
# |     AverageQ2Vals |              30 |
# |         StdQ2Vals |            9.87 |
# |         MaxQ2Vals |            54.8 |
# |         MinQ2Vals |           -53.3 |
# |            LossPi |           -30.5 |
# |             LossQ |           0.974 |
# |              Time |        6.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |             361 |
# |          StdEpRet |              35 |
# |          MaxEpRet |             408 |
# |          MinEpRet |             319 |
# |  AverageTestEpRet |             123 |
# |      StdTestEpRet |             303 |
# |      MaxTestEpRet |             330 |
# |      MinTestEpRet |            -479 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |            30.3 |
# |         StdQ1Vals |            9.65 |
# |         MaxQ1Vals |            56.5 |
# |         MinQ1Vals |           -55.3 |
# |     AverageQ2Vals |            30.3 |
# |         StdQ2Vals |            9.65 |
# |         MaxQ2Vals |              56 |
# |         MinQ2Vals |           -56.6 |
# |            LossPi |           -30.8 |
# |             LossQ |           0.928 |
# |              Time |        6.77e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':True,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': False,
        'exp_name': 'td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D20E52588>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	true,
#     "num_test_episodes":	10,
#     "partially_observable":	false,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -304 |
# |          StdEpRet |            82.3 |
# |          MaxEpRet |            -206 |
# |          MinEpRet |            -388 |
# |  AverageTestEpRet |            -401 |
# |      StdTestEpRet |             101 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -599 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            1.58 |
# |         StdQ1Vals |            2.92 |
# |         MaxQ1Vals |            15.5 |
# |         MinQ1Vals |           -4.96 |
# |     AverageQ2Vals |            1.58 |
# |         StdQ2Vals |            2.92 |
# |         MaxQ2Vals |            15.7 |
# |         MinQ2Vals |            -4.9 |
# |            LossPi |           -2.56 |
# |             LossQ |           0.803 |
# |              Time |            86.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -267 |
# |          StdEpRet |             107 |
# |          MaxEpRet |           -93.2 |
# |          MinEpRet |            -383 |
# |  AverageTestEpRet |            -520 |
# |      StdTestEpRet |             134 |
# |      MaxTestEpRet |            -264 |
# |      MinTestEpRet |            -762 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            14.9 |
# |         StdQ1Vals |            7.94 |
# |         MaxQ1Vals |            43.1 |
# |         MinQ1Vals |           -3.73 |
# |     AverageQ2Vals |            14.9 |
# |         StdQ2Vals |            7.93 |
# |         MaxQ2Vals |            42.3 |
# |         MinQ2Vals |           -3.56 |
# |            LossPi |           -17.3 |
# |             LossQ |            2.49 |
# |              Time |             197 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -330 |
# |          StdEpRet |            94.5 |
# |          MaxEpRet |            -197 |
# |          MinEpRet |            -427 |
# |  AverageTestEpRet |            -425 |
# |      StdTestEpRet |             105 |
# |      MaxTestEpRet |            -267 |
# |      MinTestEpRet |            -561 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            36.5 |
# |         StdQ1Vals |            7.68 |
# |         MaxQ1Vals |            65.5 |
# |         MinQ1Vals |            12.7 |
# |     AverageQ2Vals |            36.5 |
# |         StdQ2Vals |            7.68 |
# |         MaxQ2Vals |            66.1 |
# |         MinQ2Vals |            12.3 |
# |            LossPi |             -39 |
# |             LossQ |            4.91 |
# |              Time |             313 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |             159 |
# |          MaxEpRet |             154 |
# |          MinEpRet |            -251 |
# |  AverageTestEpRet |             180 |
# |      StdTestEpRet |            48.3 |
# |      MaxTestEpRet |             236 |
# |      MinTestEpRet |             104 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            34.4 |
# |         StdQ1Vals |            10.2 |
# |         MaxQ1Vals |            61.9 |
# |         MinQ1Vals |            5.72 |
# |     AverageQ2Vals |            34.4 |
# |         StdQ2Vals |            10.2 |
# |         MaxQ2Vals |            65.6 |
# |         MinQ2Vals |            4.87 |
# |            LossPi |           -35.4 |
# |             LossQ |            4.44 |
# |              Time |             435 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             377 |
# |          StdEpRet |             176 |
# |          MaxEpRet |             618 |
# |          MinEpRet |             175 |
# |  AverageTestEpRet |             334 |
# |      StdTestEpRet |             579 |
# |      MaxTestEpRet |        1.02e+03 |
# |      MinTestEpRet |            -507 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            29.2 |
# |         StdQ1Vals |              11 |
# |         MaxQ1Vals |            56.8 |
# |         MinQ1Vals |           -2.84 |
# |     AverageQ2Vals |            29.2 |
# |         StdQ2Vals |              11 |
# |         MaxQ2Vals |            56.8 |
# |         MinQ2Vals |           -4.11 |
# |            LossPi |           -30.1 |
# |             LossQ |            3.45 |
# |              Time |             541 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             300 |
# |          StdEpRet |            86.7 |
# |          MaxEpRet |             387 |
# |          MinEpRet |             163 |
# |  AverageTestEpRet |             986 |
# |      StdTestEpRet |             564 |
# |      MaxTestEpRet |        1.81e+03 |
# |      MinTestEpRet |            91.9 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            29.2 |
# |         StdQ1Vals |            15.5 |
# |         MaxQ1Vals |            66.9 |
# |         MinQ1Vals |           -27.1 |
# |     AverageQ2Vals |            29.2 |
# |         StdQ2Vals |            15.5 |
# |         MaxQ2Vals |            69.8 |
# |         MinQ2Vals |           -25.6 |
# |            LossPi |           -30.4 |
# |             LossQ |            4.57 |
# |              Time |             645 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             522 |
# |          StdEpRet |             229 |
# |          MaxEpRet |             744 |
# |          MinEpRet |             209 |
# |  AverageTestEpRet |        1.39e+03 |
# |      StdTestEpRet |             422 |
# |      MaxTestEpRet |        1.78e+03 |
# |      MinTestEpRet |             769 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            32.6 |
# |         StdQ1Vals |            22.6 |
# |         MaxQ1Vals |            81.6 |
# |         MinQ1Vals |           -30.4 |
# |     AverageQ2Vals |            32.6 |
# |         StdQ2Vals |            22.6 |
# |         MaxQ2Vals |            81.4 |
# |         MinQ2Vals |           -28.9 |
# |            LossPi |             -34 |
# |             LossQ |            5.86 |
# |              Time |             748 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             967 |
# |          StdEpRet |             591 |
# |          MaxEpRet |        1.66e+03 |
# |          MinEpRet |            99.9 |
# |  AverageTestEpRet |        1.61e+03 |
# |      StdTestEpRet |             480 |
# |      MaxTestEpRet |         1.9e+03 |
# |      MinTestEpRet |             190 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            38.4 |
# |         StdQ1Vals |            30.5 |
# |         MaxQ1Vals |             101 |
# |         MinQ1Vals |           -35.8 |
# |     AverageQ2Vals |            38.4 |
# |         StdQ2Vals |            30.5 |
# |         MaxQ2Vals |             102 |
# |         MinQ2Vals |           -34.7 |
# |            LossPi |           -39.9 |
# |             LossQ |            7.53 |
# |              Time |             854 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |        1.52e+03 |
# |          StdEpRet |             432 |
# |          MaxEpRet |        1.86e+03 |
# |          MinEpRet |             783 |
# |  AverageTestEpRet |        1.89e+03 |
# |      StdTestEpRet |            50.1 |
# |      MaxTestEpRet |        1.98e+03 |
# |      MinTestEpRet |        1.81e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            47.3 |
# |         StdQ1Vals |            38.6 |
# |         MaxQ1Vals |             117 |
# |         MinQ1Vals |           -40.9 |
# |     AverageQ2Vals |            47.3 |
# |         StdQ2Vals |            38.6 |
# |         MaxQ2Vals |             118 |
# |         MinQ2Vals |           -41.8 |
# |            LossPi |           -48.9 |
# |             LossQ |             9.5 |
# |              Time |             969 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |        1.57e+03 |
# |          StdEpRet |             499 |
# |          MaxEpRet |        1.93e+03 |
# |          MinEpRet |             714 |
# |  AverageTestEpRet |        2.08e+03 |
# |      StdTestEpRet |            92.6 |
# |      MaxTestEpRet |        2.26e+03 |
# |      MinTestEpRet |        1.94e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            59.5 |
# |         StdQ1Vals |            45.1 |
# |         MaxQ1Vals |             136 |
# |         MinQ1Vals |           -46.5 |
# |     AverageQ2Vals |            59.5 |
# |         StdQ2Vals |            45.1 |
# |         MaxQ2Vals |             135 |
# |         MinQ2Vals |           -46.8 |
# |            LossPi |           -61.2 |
# |             LossQ |            10.9 |
# |              Time |         1.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |        1.39e+03 |
# |          StdEpRet |             625 |
# |          MaxEpRet |        2.03e+03 |
# |          MinEpRet |             748 |
# |  AverageTestEpRet |        2.09e+03 |
# |      StdTestEpRet |            68.2 |
# |      MaxTestEpRet |        2.18e+03 |
# |      MinTestEpRet |        1.93e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            70.3 |
# |         StdQ1Vals |              51 |
# |         MaxQ1Vals |             159 |
# |         MinQ1Vals |           -49.2 |
# |     AverageQ2Vals |            70.3 |
# |         StdQ2Vals |              51 |
# |         MaxQ2Vals |             159 |
# |         MinQ2Vals |           -49.3 |
# |            LossPi |             -72 |
# |             LossQ |            12.1 |
# |              Time |        1.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |        1.35e+03 |
# |          StdEpRet |             695 |
# |          MaxEpRet |        2.01e+03 |
# |          MinEpRet |             329 |
# |  AverageTestEpRet |        2.16e+03 |
# |      StdTestEpRet |             125 |
# |      MaxTestEpRet |        2.33e+03 |
# |      MinTestEpRet |        1.86e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            79.1 |
# |         StdQ1Vals |            57.8 |
# |         MaxQ1Vals |             172 |
# |         MinQ1Vals |           -50.3 |
# |     AverageQ2Vals |            79.1 |
# |         StdQ2Vals |            57.8 |
# |         MaxQ2Vals |             172 |
# |         MinQ2Vals |           -50.4 |
# |            LossPi |           -80.7 |
# |             LossQ |            13.5 |
# |              Time |        1.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |        1.72e+03 |
# |          StdEpRet |             446 |
# |          MaxEpRet |        2.14e+03 |
# |          MinEpRet |             983 |
# |  AverageTestEpRet |         2.2e+03 |
# |      StdTestEpRet |             245 |
# |      MaxTestEpRet |        2.54e+03 |
# |      MinTestEpRet |        1.59e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            87.3 |
# |         StdQ1Vals |            63.6 |
# |         MaxQ1Vals |             185 |
# |         MinQ1Vals |           -69.1 |
# |     AverageQ2Vals |            87.3 |
# |         StdQ2Vals |            63.6 |
# |         MaxQ2Vals |             186 |
# |         MinQ2Vals |           -70.5 |
# |            LossPi |             -89 |
# |             LossQ |            15.3 |
# |              Time |        1.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        1.58e+03 |
# |          StdEpRet |             710 |
# |          MaxEpRet |        2.32e+03 |
# |          MinEpRet |             847 |
# |  AverageTestEpRet |        2.44e+03 |
# |      StdTestEpRet |              85 |
# |      MaxTestEpRet |        2.55e+03 |
# |      MinTestEpRet |        2.27e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            95.5 |
# |         StdQ1Vals |            69.4 |
# |         MaxQ1Vals |             202 |
# |         MinQ1Vals |           -68.3 |
# |     AverageQ2Vals |            95.5 |
# |         StdQ2Vals |            69.4 |
# |         MaxQ2Vals |             206 |
# |         MinQ2Vals |           -67.6 |
# |            LossPi |           -97.2 |
# |             LossQ |            16.5 |
# |              Time |        1.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        2.04e+03 |
# |          StdEpRet |             514 |
# |          MaxEpRet |        2.37e+03 |
# |          MinEpRet |        1.15e+03 |
# |  AverageTestEpRet |        2.27e+03 |
# |      StdTestEpRet |             695 |
# |      MaxTestEpRet |        2.79e+03 |
# |      MinTestEpRet |             228 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             103 |
# |         StdQ1Vals |            74.6 |
# |         MaxQ1Vals |             211 |
# |         MinQ1Vals |           -64.6 |
# |     AverageQ2Vals |             103 |
# |         StdQ2Vals |            74.6 |
# |         MaxQ2Vals |             212 |
# |         MinQ2Vals |           -66.7 |
# |            LossPi |            -104 |
# |             LossQ |            17.6 |
# |              Time |        1.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |        1.75e+03 |
# |          StdEpRet |             618 |
# |          MaxEpRet |        2.38e+03 |
# |          MinEpRet |        1.08e+03 |
# |  AverageTestEpRet |        2.56e+03 |
# |      StdTestEpRet |            88.6 |
# |      MaxTestEpRet |        2.68e+03 |
# |      MinTestEpRet |        2.36e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             111 |
# |         StdQ1Vals |            78.7 |
# |         MaxQ1Vals |             227 |
# |         MinQ1Vals |           -62.9 |
# |     AverageQ2Vals |             111 |
# |         StdQ2Vals |            78.7 |
# |         MaxQ2Vals |             227 |
# |         MinQ2Vals |             -64 |
# |            LossPi |            -113 |
# |             LossQ |            17.8 |
# |              Time |        1.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        1.98e+03 |
# |          StdEpRet |             586 |
# |          MaxEpRet |        2.37e+03 |
# |          MinEpRet |             966 |
# |  AverageTestEpRet |        2.54e+03 |
# |      StdTestEpRet |             140 |
# |      MaxTestEpRet |        2.77e+03 |
# |      MinTestEpRet |        2.26e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             118 |
# |         StdQ1Vals |            82.8 |
# |         MaxQ1Vals |             236 |
# |         MinQ1Vals |           -60.5 |
# |     AverageQ2Vals |             118 |
# |         StdQ2Vals |            82.8 |
# |         MaxQ2Vals |             237 |
# |         MinQ2Vals |           -61.3 |
# |            LossPi |            -120 |
# |             LossQ |            18.9 |
# |              Time |        1.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        2.53e+03 |
# |          StdEpRet |             103 |
# |          MaxEpRet |        2.71e+03 |
# |          MinEpRet |        2.46e+03 |
# |  AverageTestEpRet |        2.53e+03 |
# |      StdTestEpRet |             382 |
# |      MaxTestEpRet |        2.88e+03 |
# |      MinTestEpRet |        1.81e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             127 |
# |         StdQ1Vals |            85.4 |
# |         MaxQ1Vals |             245 |
# |         MinQ1Vals |           -54.3 |
# |     AverageQ2Vals |             127 |
# |         StdQ2Vals |            85.4 |
# |         MaxQ2Vals |             244 |
# |         MinQ2Vals |           -57.2 |
# |            LossPi |            -129 |
# |             LossQ |              20 |
# |              Time |        1.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |        2.07e+03 |
# |          StdEpRet |             539 |
# |          MaxEpRet |        2.45e+03 |
# |          MinEpRet |        1.14e+03 |
# |  AverageTestEpRet |        2.86e+03 |
# |      StdTestEpRet |             105 |
# |      MaxTestEpRet |           3e+03 |
# |      MinTestEpRet |        2.67e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             136 |
# |         StdQ1Vals |            87.5 |
# |         MaxQ1Vals |             253 |
# |         MinQ1Vals |           -48.3 |
# |     AverageQ2Vals |             136 |
# |         StdQ2Vals |            87.5 |
# |         MaxQ2Vals |             252 |
# |         MinQ2Vals |           -49.6 |
# |            LossPi |            -138 |
# |             LossQ |            21.8 |
# |              Time |        2.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |        2.22e+03 |
# |          StdEpRet |             558 |
# |          MaxEpRet |        2.69e+03 |
# |          MinEpRet |        1.27e+03 |
# |  AverageTestEpRet |        2.97e+03 |
# |      StdTestEpRet |             140 |
# |      MaxTestEpRet |        3.13e+03 |
# |      MinTestEpRet |        2.78e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             143 |
# |         StdQ1Vals |            90.2 |
# |         MaxQ1Vals |             263 |
# |         MinQ1Vals |           -47.5 |
# |     AverageQ2Vals |             143 |
# |         StdQ2Vals |            90.2 |
# |         MaxQ2Vals |             264 |
# |         MinQ2Vals |           -51.9 |
# |            LossPi |            -145 |
# |             LossQ |            23.5 |
# |              Time |        2.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        2.64e+03 |
# |          StdEpRet |             137 |
# |          MaxEpRet |        2.81e+03 |
# |          MinEpRet |        2.47e+03 |
# |  AverageTestEpRet |        2.88e+03 |
# |      StdTestEpRet |             123 |
# |      MaxTestEpRet |        3.06e+03 |
# |      MinTestEpRet |        2.72e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             149 |
# |         StdQ1Vals |              93 |
# |         MaxQ1Vals |             273 |
# |         MinQ1Vals |           -50.6 |
# |     AverageQ2Vals |             149 |
# |         StdQ2Vals |              93 |
# |         MaxQ2Vals |             272 |
# |         MinQ2Vals |           -59.1 |
# |            LossPi |            -151 |
# |             LossQ |              25 |
# |              Time |        2.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        2.42e+03 |
# |          StdEpRet |             697 |
# |          MaxEpRet |         3.1e+03 |
# |          MinEpRet |        1.26e+03 |
# |  AverageTestEpRet |        3.07e+03 |
# |      StdTestEpRet |            68.8 |
# |      MaxTestEpRet |        3.16e+03 |
# |      MinTestEpRet |        2.95e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             156 |
# |         StdQ1Vals |            94.5 |
# |         MaxQ1Vals |             283 |
# |         MinQ1Vals |           -55.9 |
# |     AverageQ2Vals |             156 |
# |         StdQ2Vals |            94.5 |
# |         MaxQ2Vals |             282 |
# |         MinQ2Vals |           -58.9 |
# |            LossPi |            -158 |
# |             LossQ |            25.5 |
# |              Time |        2.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        2.92e+03 |
# |          StdEpRet |            93.5 |
# |          MaxEpRet |        3.08e+03 |
# |          MinEpRet |        2.85e+03 |
# |  AverageTestEpRet |        3.07e+03 |
# |      StdTestEpRet |             147 |
# |      MaxTestEpRet |        3.32e+03 |
# |      MinTestEpRet |        2.82e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             164 |
# |         StdQ1Vals |            95.6 |
# |         MaxQ1Vals |             290 |
# |         MinQ1Vals |           -55.1 |
# |     AverageQ2Vals |             164 |
# |         StdQ2Vals |            95.6 |
# |         MaxQ2Vals |             292 |
# |         MinQ2Vals |           -54.6 |
# |            LossPi |            -166 |
# |             LossQ |            26.2 |
# |              Time |        2.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        2.95e+03 |
# |          StdEpRet |             133 |
# |          MaxEpRet |        3.05e+03 |
# |          MinEpRet |        2.73e+03 |
# |  AverageTestEpRet |         3.4e+03 |
# |      StdTestEpRet |            90.1 |
# |      MaxTestEpRet |        3.53e+03 |
# |      MinTestEpRet |        3.27e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             172 |
# |         StdQ1Vals |            96.7 |
# |         MaxQ1Vals |             297 |
# |         MinQ1Vals |           -50.2 |
# |     AverageQ2Vals |             172 |
# |         StdQ2Vals |            96.7 |
# |         MaxQ2Vals |             298 |
# |         MinQ2Vals |           -54.6 |
# |            LossPi |            -174 |
# |             LossQ |            26.8 |
# |              Time |        2.65e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        2.56e+03 |
# |          StdEpRet |             783 |
# |          MaxEpRet |        3.12e+03 |
# |          MinEpRet |        1.21e+03 |
# |  AverageTestEpRet |        3.23e+03 |
# |      StdTestEpRet |            84.4 |
# |      MaxTestEpRet |        3.39e+03 |
# |      MinTestEpRet |         3.1e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             179 |
# |         StdQ1Vals |            98.7 |
# |         MaxQ1Vals |             308 |
# |         MinQ1Vals |           -68.1 |
# |     AverageQ2Vals |             179 |
# |         StdQ2Vals |            98.7 |
# |         MaxQ2Vals |             307 |
# |         MinQ2Vals |           -73.5 |
# |            LossPi |            -181 |
# |             LossQ |            29.2 |
# |              Time |        2.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        3.03e+03 |
# |          StdEpRet |             105 |
# |          MaxEpRet |        3.13e+03 |
# |          MinEpRet |        2.89e+03 |
# |  AverageTestEpRet |        3.33e+03 |
# |      StdTestEpRet |            76.6 |
# |      MaxTestEpRet |        3.43e+03 |
# |      MinTestEpRet |         3.2e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             186 |
# |         StdQ1Vals |             101 |
# |         MaxQ1Vals |             314 |
# |         MinQ1Vals |           -78.3 |
# |     AverageQ2Vals |             186 |
# |         StdQ2Vals |             101 |
# |         MaxQ2Vals |             315 |
# |         MinQ2Vals |           -89.5 |
# |            LossPi |            -188 |
# |             LossQ |            31.5 |
# |              Time |        2.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |         2.9e+03 |
# |          StdEpRet |             572 |
# |          MaxEpRet |         3.3e+03 |
# |          MinEpRet |        1.91e+03 |
# |  AverageTestEpRet |        3.37e+03 |
# |      StdTestEpRet |             122 |
# |      MaxTestEpRet |        3.53e+03 |
# |      MinTestEpRet |        3.12e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             193 |
# |         StdQ1Vals |             102 |
# |         MaxQ1Vals |             318 |
# |         MinQ1Vals |           -78.4 |
# |     AverageQ2Vals |             193 |
# |         StdQ2Vals |             102 |
# |         MaxQ2Vals |             320 |
# |         MinQ2Vals |           -81.4 |
# |            LossPi |            -195 |
# |             LossQ |            33.1 |
# |              Time |        2.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        3.25e+03 |
# |          StdEpRet |             184 |
# |          MaxEpRet |        3.49e+03 |
# |          MinEpRet |           3e+03 |
# |  AverageTestEpRet |        3.27e+03 |
# |      StdTestEpRet |             200 |
# |      MaxTestEpRet |         3.6e+03 |
# |      MinTestEpRet |        2.88e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             200 |
# |         StdQ1Vals |             104 |
# |         MaxQ1Vals |             328 |
# |         MinQ1Vals |           -63.1 |
# |     AverageQ2Vals |             200 |
# |         StdQ2Vals |             104 |
# |         MaxQ2Vals |             329 |
# |         MinQ2Vals |             -71 |
# |            LossPi |            -201 |
# |             LossQ |            34.9 |
# |              Time |        3.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        3.37e+03 |
# |          StdEpRet |            86.7 |
# |          MaxEpRet |        3.51e+03 |
# |          MinEpRet |        3.28e+03 |
# |  AverageTestEpRet |        3.56e+03 |
# |      StdTestEpRet |             102 |
# |      MaxTestEpRet |        3.69e+03 |
# |      MinTestEpRet |        3.37e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |             207 |
# |         StdQ1Vals |             104 |
# |         MaxQ1Vals |             334 |
# |         MinQ1Vals |           -57.5 |
# |     AverageQ2Vals |             207 |
# |         StdQ2Vals |             104 |
# |         MaxQ2Vals |             332 |
# |         MinQ2Vals |           -70.7 |
# |            LossPi |            -209 |
# |             LossQ |              35 |
# |              Time |        3.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        3.44e+03 |
# |          StdEpRet |             182 |
# |          MaxEpRet |        3.67e+03 |
# |          MinEpRet |        3.23e+03 |
# |  AverageTestEpRet |        3.47e+03 |
# |      StdTestEpRet |             164 |
# |      MaxTestEpRet |        3.73e+03 |
# |      MinTestEpRet |        3.26e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |             214 |
# |         StdQ1Vals |             104 |
# |         MaxQ1Vals |             340 |
# |         MinQ1Vals |           -49.9 |
# |     AverageQ2Vals |             214 |
# |         StdQ2Vals |             104 |
# |         MaxQ2Vals |             339 |
# |         MinQ2Vals |           -59.3 |
# |            LossPi |            -216 |
# |             LossQ |            37.5 |
# |              Time |         3.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |        3.45e+03 |
# |          StdEpRet |            96.3 |
# |          MaxEpRet |        3.56e+03 |
# |          MinEpRet |        3.31e+03 |
# |  AverageTestEpRet |        3.68e+03 |
# |      StdTestEpRet |             113 |
# |      MaxTestEpRet |        3.84e+03 |
# |      MinTestEpRet |        3.51e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             221 |
# |         StdQ1Vals |             104 |
# |         MaxQ1Vals |             344 |
# |         MinQ1Vals |           -56.5 |
# |     AverageQ2Vals |             221 |
# |         StdQ2Vals |             104 |
# |         MaxQ2Vals |             342 |
# |         MinQ2Vals |           -54.7 |
# |            LossPi |            -223 |
# |             LossQ |            36.5 |
# |              Time |        3.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        3.55e+03 |
# |          StdEpRet |            53.5 |
# |          MaxEpRet |        3.61e+03 |
# |          MinEpRet |        3.48e+03 |
# |  AverageTestEpRet |        3.64e+03 |
# |      StdTestEpRet |             114 |
# |      MaxTestEpRet |        3.84e+03 |
# |      MinTestEpRet |        3.42e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             228 |
# |         StdQ1Vals |             105 |
# |         MaxQ1Vals |             351 |
# |         MinQ1Vals |           -41.3 |
# |     AverageQ2Vals |             228 |
# |         StdQ2Vals |             105 |
# |         MaxQ2Vals |             351 |
# |         MinQ2Vals |           -44.7 |
# |            LossPi |            -230 |
# |             LossQ |            37.3 |
# |              Time |        3.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |         3.5e+03 |
# |          StdEpRet |             186 |
# |          MaxEpRet |         3.8e+03 |
# |          MinEpRet |        3.33e+03 |
# |  AverageTestEpRet |        3.63e+03 |
# |      StdTestEpRet |             111 |
# |      MaxTestEpRet |        3.82e+03 |
# |      MinTestEpRet |        3.41e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             235 |
# |         StdQ1Vals |             106 |
# |         MaxQ1Vals |             358 |
# |         MinQ1Vals |           -60.2 |
# |     AverageQ2Vals |             235 |
# |         StdQ2Vals |             106 |
# |         MaxQ2Vals |             355 |
# |         MinQ2Vals |           -62.3 |
# |            LossPi |            -237 |
# |             LossQ |            38.8 |
# |              Time |        3.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |        3.54e+03 |
# |          StdEpRet |             166 |
# |          MaxEpRet |        3.68e+03 |
# |          MinEpRet |        3.26e+03 |
# |  AverageTestEpRet |        3.85e+03 |
# |      StdTestEpRet |            95.6 |
# |      MaxTestEpRet |        4.05e+03 |
# |      MinTestEpRet |        3.71e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             241 |
# |         StdQ1Vals |             106 |
# |         MaxQ1Vals |             365 |
# |         MinQ1Vals |           -83.7 |
# |     AverageQ2Vals |             241 |
# |         StdQ2Vals |             106 |
# |         MaxQ2Vals |             363 |
# |         MinQ2Vals |           -89.6 |
# |            LossPi |            -243 |
# |             LossQ |            41.2 |
# |              Time |        3.72e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |        3.78e+03 |
# |          StdEpRet |             308 |
# |          MaxEpRet |        4.28e+03 |
# |          MinEpRet |        3.44e+03 |
# |  AverageTestEpRet |        3.86e+03 |
# |      StdTestEpRet |             107 |
# |      MaxTestEpRet |        4.04e+03 |
# |      MinTestEpRet |        3.68e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             249 |
# |         StdQ1Vals |             106 |
# |         MaxQ1Vals |             371 |
# |         MinQ1Vals |           -81.9 |
# |     AverageQ2Vals |             249 |
# |         StdQ2Vals |             106 |
# |         MaxQ2Vals |             370 |
# |         MinQ2Vals |           -90.4 |
# |            LossPi |            -251 |
# |             LossQ |            42.2 |
# |              Time |        3.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |        3.81e+03 |
# |          StdEpRet |             138 |
# |          MaxEpRet |        4.01e+03 |
# |          MinEpRet |        3.63e+03 |
# |  AverageTestEpRet |         3.9e+03 |
# |      StdTestEpRet |             107 |
# |      MaxTestEpRet |        4.07e+03 |
# |      MinTestEpRet |        3.68e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             255 |
# |         StdQ1Vals |             106 |
# |         MaxQ1Vals |             381 |
# |         MinQ1Vals |           -73.3 |
# |     AverageQ2Vals |             255 |
# |         StdQ2Vals |             106 |
# |         MaxQ2Vals |             379 |
# |         MinQ2Vals |            -106 |
# |            LossPi |            -257 |
# |             LossQ |            42.4 |
# |              Time |        3.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |         3.7e+03 |
# |          StdEpRet |            46.6 |
# |          MaxEpRet |        3.77e+03 |
# |          MinEpRet |        3.65e+03 |
# |  AverageTestEpRet |        3.98e+03 |
# |      StdTestEpRet |            93.5 |
# |      MaxTestEpRet |        4.11e+03 |
# |      MinTestEpRet |        3.81e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             262 |
# |         StdQ1Vals |             106 |
# |         MaxQ1Vals |             383 |
# |         MinQ1Vals |           -73.1 |
# |     AverageQ2Vals |             262 |
# |         StdQ2Vals |             106 |
# |         MaxQ2Vals |             383 |
# |         MinQ2Vals |            -103 |
# |            LossPi |            -264 |
# |             LossQ |              43 |
# |              Time |        4.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        3.94e+03 |
# |          StdEpRet |             125 |
# |          MaxEpRet |        4.12e+03 |
# |          MinEpRet |        3.81e+03 |
# |  AverageTestEpRet |        4.13e+03 |
# |      StdTestEpRet |            87.8 |
# |      MaxTestEpRet |        4.28e+03 |
# |      MinTestEpRet |        3.99e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             268 |
# |         StdQ1Vals |             106 |
# |         MaxQ1Vals |             389 |
# |         MinQ1Vals |           -69.7 |
# |     AverageQ2Vals |             268 |
# |         StdQ2Vals |             106 |
# |         MaxQ2Vals |             392 |
# |         MinQ2Vals |             -63 |
# |            LossPi |            -270 |
# |             LossQ |            41.5 |
# |              Time |        4.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        3.98e+03 |
# |          StdEpRet |             176 |
# |          MaxEpRet |        4.24e+03 |
# |          MinEpRet |        3.75e+03 |
# |  AverageTestEpRet |        4.14e+03 |
# |      StdTestEpRet |             206 |
# |      MaxTestEpRet |        4.37e+03 |
# |      MinTestEpRet |        3.68e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             274 |
# |         StdQ1Vals |             107 |
# |         MaxQ1Vals |             398 |
# |         MinQ1Vals |           -59.6 |
# |     AverageQ2Vals |             274 |
# |         StdQ2Vals |             107 |
# |         MaxQ2Vals |             397 |
# |         MinQ2Vals |           -66.4 |
# |            LossPi |            -276 |
# |             LossQ |            42.2 |
# |              Time |        4.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        4.02e+03 |
# |          StdEpRet |            98.5 |
# |          MaxEpRet |        4.17e+03 |
# |          MinEpRet |         3.9e+03 |
# |  AverageTestEpRet |        4.21e+03 |
# |      StdTestEpRet |            97.2 |
# |      MaxTestEpRet |        4.39e+03 |
# |      MinTestEpRet |        4.06e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             280 |
# |         StdQ1Vals |             108 |
# |         MaxQ1Vals |             404 |
# |         MinQ1Vals |           -74.8 |
# |     AverageQ2Vals |             280 |
# |         StdQ2Vals |             108 |
# |         MaxQ2Vals |             404 |
# |         MinQ2Vals |             -78 |
# |            LossPi |            -282 |
# |             LossQ |            43.3 |
# |              Time |        4.35e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        3.53e+03 |
# |          StdEpRet |             867 |
# |          MaxEpRet |        4.18e+03 |
# |          MinEpRet |        2.04e+03 |
# |  AverageTestEpRet |        4.19e+03 |
# |      StdTestEpRet |             116 |
# |      MaxTestEpRet |        4.38e+03 |
# |      MinTestEpRet |        3.96e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             285 |
# |         StdQ1Vals |             110 |
# |         MaxQ1Vals |             406 |
# |         MinQ1Vals |           -85.4 |
# |     AverageQ2Vals |             285 |
# |         StdQ2Vals |             110 |
# |         MaxQ2Vals |             406 |
# |         MinQ2Vals |           -84.7 |
# |            LossPi |            -287 |
# |             LossQ |            43.8 |
# |              Time |        4.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |         4.1e+03 |
# |          StdEpRet |             143 |
# |          MaxEpRet |        4.27e+03 |
# |          MinEpRet |        3.95e+03 |
# |  AverageTestEpRet |        4.43e+03 |
# |      StdTestEpRet |             192 |
# |      MaxTestEpRet |        4.84e+03 |
# |      MinTestEpRet |        4.19e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             290 |
# |         StdQ1Vals |             112 |
# |         MaxQ1Vals |             416 |
# |         MinQ1Vals |           -65.6 |
# |     AverageQ2Vals |             290 |
# |         StdQ2Vals |             112 |
# |         MaxQ2Vals |             414 |
# |         MinQ2Vals |           -63.2 |
# |            LossPi |            -292 |
# |             LossQ |            45.7 |
# |              Time |        4.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        2.82e+03 |
# |          StdEpRet |        1.13e+03 |
# |          MaxEpRet |        4.04e+03 |
# |          MinEpRet |        1.35e+03 |
# |  AverageTestEpRet |        4.39e+03 |
# |      StdTestEpRet |             160 |
# |      MaxTestEpRet |        4.52e+03 |
# |      MinTestEpRet |        4.04e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             294 |
# |         StdQ1Vals |             115 |
# |         MaxQ1Vals |             420 |
# |         MinQ1Vals |            -119 |
# |     AverageQ2Vals |             294 |
# |         StdQ2Vals |             115 |
# |         MaxQ2Vals |             421 |
# |         MinQ2Vals |           -85.2 |
# |            LossPi |            -296 |
# |             LossQ |            47.6 |
# |              Time |        4.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        4.16e+03 |
# |          StdEpRet |            74.1 |
# |          MaxEpRet |        4.24e+03 |
# |          MinEpRet |        4.05e+03 |
# |  AverageTestEpRet |        4.39e+03 |
# |      StdTestEpRet |             123 |
# |      MaxTestEpRet |        4.58e+03 |
# |      MinTestEpRet |        4.09e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             297 |
# |         StdQ1Vals |             118 |
# |         MaxQ1Vals |             432 |
# |         MinQ1Vals |           -95.2 |
# |     AverageQ2Vals |             297 |
# |         StdQ2Vals |             118 |
# |         MaxQ2Vals |             432 |
# |         MinQ2Vals |           -66.4 |
# |            LossPi |            -299 |
# |             LossQ |            52.3 |
# |              Time |        4.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        4.15e+03 |
# |          StdEpRet |            54.8 |
# |          MaxEpRet |        4.24e+03 |
# |          MinEpRet |        4.09e+03 |
# |  AverageTestEpRet |        4.53e+03 |
# |      StdTestEpRet |             156 |
# |      MaxTestEpRet |        4.78e+03 |
# |      MinTestEpRet |        4.29e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             302 |
# |         StdQ1Vals |             120 |
# |         MaxQ1Vals |             434 |
# |         MinQ1Vals |            -106 |
# |     AverageQ2Vals |             302 |
# |         StdQ2Vals |             120 |
# |         MaxQ2Vals |             436 |
# |         MinQ2Vals |            -127 |
# |            LossPi |            -304 |
# |             LossQ |            53.5 |
# |              Time |        4.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        3.68e+03 |
# |          StdEpRet |             842 |
# |          MaxEpRet |         4.2e+03 |
# |          MinEpRet |        2.23e+03 |
# |  AverageTestEpRet |        4.38e+03 |
# |      StdTestEpRet |             129 |
# |      MaxTestEpRet |        4.61e+03 |
# |      MinTestEpRet |        4.22e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             306 |
# |         StdQ1Vals |             121 |
# |         MaxQ1Vals |             440 |
# |         MinQ1Vals |            -110 |
# |     AverageQ2Vals |             306 |
# |         StdQ2Vals |             121 |
# |         MaxQ2Vals |             438 |
# |         MinQ2Vals |            -120 |
# |            LossPi |            -308 |
# |             LossQ |            53.3 |
# |              Time |        4.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        4.24e+03 |
# |          StdEpRet |              16 |
# |          MaxEpRet |        4.27e+03 |
# |          MinEpRet |        4.23e+03 |
# |  AverageTestEpRet |        4.61e+03 |
# |      StdTestEpRet |             141 |
# |      MaxTestEpRet |        4.93e+03 |
# |      MinTestEpRet |        4.42e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             310 |
# |         StdQ1Vals |             123 |
# |         MaxQ1Vals |             441 |
# |         MinQ1Vals |            -115 |
# |     AverageQ2Vals |             310 |
# |         StdQ2Vals |             123 |
# |         MaxQ2Vals |             444 |
# |         MinQ2Vals |            -116 |
# |            LossPi |            -312 |
# |             LossQ |            54.5 |
# |              Time |        5.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        4.14e+03 |
# |          StdEpRet |            24.5 |
# |          MaxEpRet |        4.18e+03 |
# |          MinEpRet |        4.11e+03 |
# |  AverageTestEpRet |        4.21e+03 |
# |      StdTestEpRet |             111 |
# |      MaxTestEpRet |        4.42e+03 |
# |      MinTestEpRet |           4e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             314 |
# |         StdQ1Vals |             124 |
# |         MaxQ1Vals |             446 |
# |         MinQ1Vals |            -109 |
# |     AverageQ2Vals |             314 |
# |         StdQ2Vals |             124 |
# |         MaxQ2Vals |             448 |
# |         MinQ2Vals |            -121 |
# |            LossPi |            -316 |
# |             LossQ |            55.8 |
# |              Time |        5.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |        4.45e+03 |
# |          StdEpRet |             139 |
# |          MaxEpRet |        4.61e+03 |
# |          MinEpRet |        4.25e+03 |
# |  AverageTestEpRet |         4.6e+03 |
# |      StdTestEpRet |             154 |
# |      MaxTestEpRet |         4.8e+03 |
# |      MinTestEpRet |         4.3e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             318 |
# |         StdQ1Vals |             125 |
# |         MaxQ1Vals |             449 |
# |         MinQ1Vals |            -140 |
# |     AverageQ2Vals |             318 |
# |         StdQ2Vals |             125 |
# |         MaxQ2Vals |             448 |
# |         MinQ2Vals |            -112 |
# |            LossPi |            -320 |
# |             LossQ |            57.2 |
# |              Time |        5.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        4.45e+03 |
# |          StdEpRet |             131 |
# |          MaxEpRet |        4.64e+03 |
# |          MinEpRet |        4.26e+03 |
# |  AverageTestEpRet |        4.53e+03 |
# |      StdTestEpRet |             115 |
# |      MaxTestEpRet |        4.72e+03 |
# |      MinTestEpRet |        4.36e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             322 |
# |         StdQ1Vals |             126 |
# |         MaxQ1Vals |             453 |
# |         MinQ1Vals |            -134 |
# |     AverageQ2Vals |             322 |
# |         StdQ2Vals |             126 |
# |         MaxQ2Vals |             453 |
# |         MinQ2Vals |            -145 |
# |            LossPi |            -324 |
# |             LossQ |            56.4 |
# |              Time |        5.39e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':True,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'partially_observable': True,
        'exp_name': 'td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
    partially_observable=args['partially_observable'],
     logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000024D209EEF48>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	true,
#     "num_test_episodes":	10,
#     "partially_observable":	true,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -281 |
# |          StdEpRet |            98.9 |
# |          MaxEpRet |            -166 |
# |          MinEpRet |            -424 |
# |  AverageTestEpRet |            -561 |
# |      StdTestEpRet |           0.678 |
# |      MaxTestEpRet |            -560 |
# |      MinTestEpRet |            -562 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |             2.2 |
# |         StdQ1Vals |            1.53 |
# |         MaxQ1Vals |            8.02 |
# |         MinQ1Vals |           -1.33 |
# |     AverageQ2Vals |             2.2 |
# |         StdQ2Vals |            1.53 |
# |         MaxQ2Vals |            8.83 |
# |         MinQ2Vals |           -1.37 |
# |            LossPi |              -3 |
# |             LossQ |           0.273 |
# |              Time |            72.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -302 |
# |          StdEpRet |             107 |
# |          MaxEpRet |            -223 |
# |          MinEpRet |            -485 |
# |  AverageTestEpRet |            -731 |
# |      StdTestEpRet |             104 |
# |      MaxTestEpRet |            -580 |
# |      MinTestEpRet |            -847 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            7.28 |
# |         StdQ1Vals |            2.26 |
# |         MaxQ1Vals |            16.4 |
# |         MinQ1Vals |           -3.15 |
# |     AverageQ2Vals |            7.28 |
# |         StdQ2Vals |            2.27 |
# |         MaxQ2Vals |            16.9 |
# |         MinQ2Vals |           -2.77 |
# |            LossPi |           -8.37 |
# |             LossQ |           0.591 |
# |              Time |             166 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -278 |
# |          StdEpRet |             129 |
# |          MaxEpRet |            -144 |
# |          MinEpRet |            -462 |
# |  AverageTestEpRet |            -449 |
# |      StdTestEpRet |            3.23 |
# |      MaxTestEpRet |            -442 |
# |      MinTestEpRet |            -453 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            15.3 |
# |         StdQ1Vals |            4.54 |
# |         MaxQ1Vals |            33.4 |
# |         MinQ1Vals |          -0.621 |
# |     AverageQ2Vals |            15.3 |
# |         StdQ2Vals |            4.55 |
# |         MaxQ2Vals |            33.8 |
# |         MinQ2Vals |          -0.312 |
# |            LossPi |           -16.6 |
# |             LossQ |           0.579 |
# |              Time |             264 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -413 |
# |          StdEpRet |            59.3 |
# |          MaxEpRet |            -323 |
# |          MinEpRet |            -488 |
# |  AverageTestEpRet |            -478 |
# |      StdTestEpRet |            37.7 |
# |      MaxTestEpRet |            -403 |
# |      MinTestEpRet |            -515 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |              17 |
# |         StdQ1Vals |            4.21 |
# |         MaxQ1Vals |            33.4 |
# |         MinQ1Vals |            8.88 |
# |     AverageQ2Vals |              17 |
# |         StdQ2Vals |            4.21 |
# |         MaxQ2Vals |            33.4 |
# |         MinQ2Vals |            9.11 |
# |            LossPi |           -17.8 |
# |             LossQ |           0.403 |
# |              Time |             367 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -241 |
# |          StdEpRet |             166 |
# |          MaxEpRet |           -43.2 |
# |          MinEpRet |            -504 |
# |  AverageTestEpRet |            -251 |
# |      StdTestEpRet |            80.6 |
# |      MaxTestEpRet |            -148 |
# |      MinTestEpRet |            -415 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            14.4 |
# |         StdQ1Vals |            2.07 |
# |         MaxQ1Vals |            25.9 |
# |         MinQ1Vals |            8.22 |
# |     AverageQ2Vals |            14.4 |
# |         StdQ2Vals |            2.07 |
# |         MaxQ2Vals |              26 |
# |         MinQ2Vals |             8.5 |
# |            LossPi |           -15.4 |
# |             LossQ |           0.353 |
# |              Time |             469 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -358 |
# |          StdEpRet |             127 |
# |          MaxEpRet |            -207 |
# |          MinEpRet |            -512 |
# |  AverageTestEpRet |            -587 |
# |      StdTestEpRet |            0.51 |
# |      MaxTestEpRet |            -586 |
# |      MinTestEpRet |            -588 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            14.5 |
# |         StdQ1Vals |            1.55 |
# |         MaxQ1Vals |              27 |
# |         MinQ1Vals |            8.52 |
# |     AverageQ2Vals |            14.5 |
# |         StdQ2Vals |            1.55 |
# |         MaxQ2Vals |              27 |
# |         MinQ2Vals |            8.52 |
# |            LossPi |           -15.4 |
# |             LossQ |           0.279 |
# |              Time |             571 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -496 |
# |          StdEpRet |            88.8 |
# |          MaxEpRet |            -402 |
# |          MinEpRet |            -603 |
# |  AverageTestEpRet |            -339 |
# |      StdTestEpRet |             282 |
# |      MaxTestEpRet |            22.8 |
# |      MinTestEpRet |            -586 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            12.9 |
# |         StdQ1Vals |            4.81 |
# |         MaxQ1Vals |            27.6 |
# |         MinQ1Vals |          -0.277 |
# |     AverageQ2Vals |            12.9 |
# |         StdQ2Vals |            4.81 |
# |         MaxQ2Vals |              28 |
# |         MinQ2Vals |          -0.261 |
# |            LossPi |             -14 |
# |             LossQ |           0.327 |
# |              Time |             674 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -405 |
# |          StdEpRet |             201 |
# |          MaxEpRet |           -56.1 |
# |          MinEpRet |            -529 |
# |  AverageTestEpRet |            -448 |
# |      StdTestEpRet |            73.1 |
# |      MaxTestEpRet |            -229 |
# |      MinTestEpRet |            -476 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            11.9 |
# |         StdQ1Vals |            10.9 |
# |         MaxQ1Vals |            25.6 |
# |         MinQ1Vals |           -8.41 |
# |     AverageQ2Vals |            11.9 |
# |         StdQ2Vals |            10.9 |
# |         MaxQ2Vals |            25.1 |
# |         MinQ2Vals |           -8.34 |
# |            LossPi |             -13 |
# |             LossQ |           0.265 |
# |              Time |             775 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -255 |
# |          StdEpRet |             155 |
# |          MaxEpRet |           -35.2 |
# |          MinEpRet |            -422 |
# |  AverageTestEpRet |            -279 |
# |      StdTestEpRet |            16.5 |
# |      MaxTestEpRet |            -254 |
# |      MinTestEpRet |            -314 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            9.93 |
# |         StdQ1Vals |            11.4 |
# |         MaxQ1Vals |            25.4 |
# |         MinQ1Vals |           -9.06 |
# |     AverageQ2Vals |            9.93 |
# |         StdQ2Vals |            11.4 |
# |         MaxQ2Vals |            24.5 |
# |         MinQ2Vals |           -9.52 |
# |            LossPi |           -10.9 |
# |             LossQ |           0.212 |
# |              Time |             878 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           -93.5 |
# |          StdEpRet |            36.9 |
# |          MaxEpRet |           -57.4 |
# |          MinEpRet |            -154 |
# |  AverageTestEpRet |           -90.1 |
# |      StdTestEpRet |            34.2 |
# |      MaxTestEpRet |           -32.7 |
# |      MinTestEpRet |            -115 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            6.43 |
# |         StdQ1Vals |            11.7 |
# |         MaxQ1Vals |            21.5 |
# |         MinQ1Vals |           -10.3 |
# |     AverageQ2Vals |            6.43 |
# |         StdQ2Vals |            11.7 |
# |         MaxQ2Vals |            21.5 |
# |         MinQ2Vals |             -11 |
# |            LossPi |           -7.25 |
# |             LossQ |            0.19 |
# |              Time |             980 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           -15.8 |
# |          StdEpRet |            70.2 |
# |          MaxEpRet |            56.2 |
# |          MinEpRet |            -114 |
# |  AverageTestEpRet |            7.91 |
# |      StdTestEpRet |            57.9 |
# |      MaxTestEpRet |            82.7 |
# |      MinTestEpRet |           -88.4 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            4.68 |
# |         StdQ1Vals |            10.4 |
# |         MaxQ1Vals |            21.7 |
# |         MinQ1Vals |           -9.75 |
# |     AverageQ2Vals |            4.68 |
# |         StdQ2Vals |            10.4 |
# |         MaxQ2Vals |            21.6 |
# |         MinQ2Vals |           -10.2 |
# |            LossPi |           -5.31 |
# |             LossQ |            0.17 |
# |              Time |        1.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |              53 |
# |          StdEpRet |            59.5 |
# |          MaxEpRet |             123 |
# |          MinEpRet |              -6 |
# |  AverageTestEpRet |            -112 |
# |      StdTestEpRet |           0.892 |
# |      MaxTestEpRet |            -111 |
# |      MinTestEpRet |            -114 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |             4.3 |
# |         StdQ1Vals |            9.39 |
# |         MaxQ1Vals |            18.9 |
# |         MinQ1Vals |           -8.92 |
# |     AverageQ2Vals |             4.3 |
# |         StdQ2Vals |            9.39 |
# |         MaxQ2Vals |            18.8 |
# |         MinQ2Vals |           -8.99 |
# |            LossPi |           -4.93 |
# |             LossQ |           0.147 |
# |              Time |        1.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            8.78 |
# |          StdEpRet |             140 |
# |          MaxEpRet |             230 |
# |          MinEpRet |            -139 |
# |  AverageTestEpRet |             412 |
# |      StdTestEpRet |            25.6 |
# |      MaxTestEpRet |             459 |
# |      MinTestEpRet |             371 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            4.74 |
# |         StdQ1Vals |            8.52 |
# |         MaxQ1Vals |            18.9 |
# |         MinQ1Vals |           -8.26 |
# |     AverageQ2Vals |            4.74 |
# |         StdQ2Vals |            8.52 |
# |         MaxQ2Vals |            18.8 |
# |         MinQ2Vals |           -8.23 |
# |            LossPi |           -5.33 |
# |             LossQ |           0.157 |
# |              Time |         1.3e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             121 |
# |          StdEpRet |             162 |
# |          MaxEpRet |             362 |
# |          MinEpRet |           -89.6 |
# |  AverageTestEpRet |           -44.3 |
# |      StdTestEpRet |            7.11 |
# |      MaxTestEpRet |           -27.8 |
# |      MinTestEpRet |           -54.2 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            6.03 |
# |         StdQ1Vals |            8.67 |
# |         MaxQ1Vals |            18.7 |
# |         MinQ1Vals |           -8.34 |
# |     AverageQ2Vals |            6.03 |
# |         StdQ2Vals |            8.67 |
# |         MaxQ2Vals |            18.4 |
# |         MinQ2Vals |           -8.28 |
# |            LossPi |           -6.69 |
# |             LossQ |           0.192 |
# |              Time |         1.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            71.8 |
# |          StdEpRet |             115 |
# |          MaxEpRet |             267 |
# |          MinEpRet |           -26.7 |
# |  AverageTestEpRet |             226 |
# |      StdTestEpRet |             180 |
# |      MaxTestEpRet |             550 |
# |      MinTestEpRet |            41.3 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            7.76 |
# |         StdQ1Vals |            9.83 |
# |         MaxQ1Vals |            22.3 |
# |         MinQ1Vals |           -11.5 |
# |     AverageQ2Vals |            7.76 |
# |         StdQ2Vals |            9.83 |
# |         MaxQ2Vals |              22 |
# |         MinQ2Vals |           -10.6 |
# |            LossPi |           -8.38 |
# |             LossQ |            0.22 |
# |              Time |        1.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            46.1 |
# |          StdEpRet |            34.4 |
# |          MaxEpRet |            91.8 |
# |          MinEpRet |           0.707 |
# |  AverageTestEpRet |             184 |
# |      StdTestEpRet |             210 |
# |      MaxTestEpRet |             535 |
# |      MinTestEpRet |           -4.61 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            8.76 |
# |         StdQ1Vals |            10.9 |
# |         MaxQ1Vals |            26.4 |
# |         MinQ1Vals |           -11.7 |
# |     AverageQ2Vals |            8.76 |
# |         StdQ2Vals |            10.9 |
# |         MaxQ2Vals |            26.1 |
# |         MinQ2Vals |             -12 |
# |            LossPi |           -9.39 |
# |             LossQ |           0.251 |
# |              Time |        1.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            71.3 |
# |          StdEpRet |            97.2 |
# |          MaxEpRet |             236 |
# |          MinEpRet |           -2.72 |
# |  AverageTestEpRet |            24.6 |
# |      StdTestEpRet |            34.2 |
# |      MaxTestEpRet |             114 |
# |      MinTestEpRet |           -6.76 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            9.46 |
# |         StdQ1Vals |            11.3 |
# |         MaxQ1Vals |            29.8 |
# |         MinQ1Vals |           -11.9 |
# |     AverageQ2Vals |            9.46 |
# |         StdQ2Vals |            11.3 |
# |         MaxQ2Vals |            29.5 |
# |         MinQ2Vals |           -11.5 |
# |            LossPi |           -10.1 |
# |             LossQ |           0.249 |
# |              Time |        1.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            86.4 |
# |          StdEpRet |            83.5 |
# |          MaxEpRet |             220 |
# |          MinEpRet |           0.883 |
# |  AverageTestEpRet |             111 |
# |      StdTestEpRet |             184 |
# |      MaxTestEpRet |             329 |
# |      MinTestEpRet |            -144 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             9.9 |
# |         StdQ1Vals |            11.6 |
# |         MaxQ1Vals |            31.8 |
# |         MinQ1Vals |           -11.1 |
# |     AverageQ2Vals |             9.9 |
# |         StdQ2Vals |            11.6 |
# |         MaxQ2Vals |              31 |
# |         MinQ2Vals |           -10.9 |
# |            LossPi |           -10.5 |
# |             LossQ |           0.237 |
# |              Time |        1.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             249 |
# |          StdEpRet |             105 |
# |          MaxEpRet |             360 |
# |          MinEpRet |             138 |
# |  AverageTestEpRet |             523 |
# |      StdTestEpRet |             121 |
# |      MaxTestEpRet |             786 |
# |      MinTestEpRet |             392 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |            10.3 |
# |         StdQ1Vals |            11.6 |
# |         MaxQ1Vals |            30.7 |
# |         MinQ1Vals |           -8.11 |
# |     AverageQ2Vals |            10.3 |
# |         StdQ2Vals |            11.6 |
# |         MaxQ2Vals |              31 |
# |         MinQ2Vals |           -8.43 |
# |            LossPi |           -10.9 |
# |             LossQ |           0.212 |
# |              Time |        1.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             413 |
# |          StdEpRet |            96.9 |
# |          MaxEpRet |             540 |
# |          MinEpRet |             291 |
# |  AverageTestEpRet |             709 |
# |      StdTestEpRet |             183 |
# |      MaxTestEpRet |        1.01e+03 |
# |      MinTestEpRet |             427 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |            12.2 |
# |         StdQ1Vals |            11.7 |
# |         MaxQ1Vals |            33.6 |
# |         MinQ1Vals |           -5.72 |
# |     AverageQ2Vals |            12.2 |
# |         StdQ2Vals |            11.7 |
# |         MaxQ2Vals |              34 |
# |         MinQ2Vals |            -5.6 |
# |            LossPi |           -12.8 |
# |             LossQ |           0.229 |
# |              Time |        2.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             495 |
# |          StdEpRet |              80 |
# |          MaxEpRet |             613 |
# |          MinEpRet |             397 |
# |  AverageTestEpRet |             365 |
# |      StdTestEpRet |            80.2 |
# |      MaxTestEpRet |             540 |
# |      MinTestEpRet |             266 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            16.2 |
# |         StdQ1Vals |            13.2 |
# |         MaxQ1Vals |            45.1 |
# |         MinQ1Vals |           -2.81 |
# |     AverageQ2Vals |            16.2 |
# |         StdQ2Vals |            13.2 |
# |         MaxQ2Vals |            45.1 |
# |         MinQ2Vals |           -4.27 |
# |            LossPi |             -17 |
# |             LossQ |           0.402 |
# |              Time |        2.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             717 |
# |          StdEpRet |             275 |
# |          MaxEpRet |        1.06e+03 |
# |          MinEpRet |             296 |
# |  AverageTestEpRet |        1.28e+03 |
# |      StdTestEpRet |             138 |
# |      MaxTestEpRet |        1.53e+03 |
# |      MinTestEpRet |        1.06e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |            20.5 |
# |         StdQ1Vals |            16.3 |
# |         MaxQ1Vals |            56.7 |
# |         MinQ1Vals |           0.123 |
# |     AverageQ2Vals |            20.5 |
# |         StdQ2Vals |            16.3 |
# |         MaxQ2Vals |            56.7 |
# |         MinQ2Vals |          -0.139 |
# |            LossPi |           -21.4 |
# |             LossQ |           0.759 |
# |              Time |        2.23e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        1.12e+03 |
# |          StdEpRet |             111 |
# |          MaxEpRet |        1.25e+03 |
# |          MinEpRet |             947 |
# |  AverageTestEpRet |        1.19e+03 |
# |      StdTestEpRet |             474 |
# |      MaxTestEpRet |        1.51e+03 |
# |      MinTestEpRet |           -12.5 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            27.3 |
# |         StdQ1Vals |            20.5 |
# |         MaxQ1Vals |            68.7 |
# |         MinQ1Vals |           -2.81 |
# |     AverageQ2Vals |            27.3 |
# |         StdQ2Vals |            20.5 |
# |         MaxQ2Vals |            68.9 |
# |         MinQ2Vals |           -2.96 |
# |            LossPi |           -28.4 |
# |             LossQ |            1.43 |
# |              Time |        2.33e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             704 |
# |          StdEpRet |             291 |
# |          MaxEpRet |        1.16e+03 |
# |          MinEpRet |             425 |
# |  AverageTestEpRet |             224 |
# |      StdTestEpRet |             313 |
# |      MaxTestEpRet |             781 |
# |      MinTestEpRet |            -128 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |              36 |
# |         StdQ1Vals |            24.9 |
# |         MaxQ1Vals |            79.2 |
# |         MinQ1Vals |           -17.3 |
# |     AverageQ2Vals |              36 |
# |         StdQ2Vals |            24.9 |
# |         MaxQ2Vals |            79.1 |
# |         MinQ2Vals |           -17.9 |
# |            LossPi |           -37.3 |
# |             LossQ |            2.38 |
# |              Time |        2.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             434 |
# |          StdEpRet |             300 |
# |          MaxEpRet |             953 |
# |          MinEpRet |             245 |
# |  AverageTestEpRet |             525 |
# |      StdTestEpRet |             197 |
# |      MaxTestEpRet |             839 |
# |      MinTestEpRet |             239 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            42.9 |
# |         StdQ1Vals |            28.7 |
# |         MaxQ1Vals |            86.7 |
# |         MinQ1Vals |           -21.4 |
# |     AverageQ2Vals |            42.9 |
# |         StdQ2Vals |            28.7 |
# |         MaxQ2Vals |            86.4 |
# |         MinQ2Vals |           -21.7 |
# |            LossPi |           -44.1 |
# |             LossQ |            2.73 |
# |              Time |        2.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             493 |
# |          StdEpRet |             183 |
# |          MaxEpRet |             695 |
# |          MinEpRet |             215 |
# |  AverageTestEpRet |             550 |
# |      StdTestEpRet |             251 |
# |      MaxTestEpRet |        1.17e+03 |
# |      MinTestEpRet |             303 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            48.4 |
# |         StdQ1Vals |            31.9 |
# |         MaxQ1Vals |              93 |
# |         MinQ1Vals |           -19.2 |
# |     AverageQ2Vals |            48.4 |
# |         StdQ2Vals |            31.9 |
# |         MaxQ2Vals |            92.5 |
# |         MinQ2Vals |           -21.1 |
# |            LossPi |           -49.6 |
# |             LossQ |            2.64 |
# |              Time |        2.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             500 |
# |          StdEpRet |             169 |
# |          MaxEpRet |             729 |
# |          MinEpRet |             254 |
# |  AverageTestEpRet |             264 |
# |      StdTestEpRet |             119 |
# |      MaxTestEpRet |             487 |
# |      MinTestEpRet |             126 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            51.5 |
# |         StdQ1Vals |            34.4 |
# |         MaxQ1Vals |            97.6 |
# |         MinQ1Vals |           -18.5 |
# |     AverageQ2Vals |            51.5 |
# |         StdQ2Vals |            34.4 |
# |         MaxQ2Vals |            97.6 |
# |         MinQ2Vals |           -19.6 |
# |            LossPi |           -52.5 |
# |             LossQ |            2.28 |
# |              Time |        2.75e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             441 |
# |          StdEpRet |            93.2 |
# |          MaxEpRet |             599 |
# |          MinEpRet |             364 |
# |  AverageTestEpRet |             753 |
# |      StdTestEpRet |             424 |
# |      MaxTestEpRet |         1.2e+03 |
# |      MinTestEpRet |            -247 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |              54 |
# |         StdQ1Vals |            36.1 |
# |         MaxQ1Vals |             101 |
# |         MinQ1Vals |           -18.7 |
# |     AverageQ2Vals |              54 |
# |         StdQ2Vals |            36.1 |
# |         MaxQ2Vals |             102 |
# |         MinQ2Vals |             -18 |
# |            LossPi |             -55 |
# |             LossQ |            2.16 |
# |              Time |        2.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             682 |
# |          StdEpRet |             110 |
# |          MaxEpRet |             808 |
# |          MinEpRet |             516 |
# |  AverageTestEpRet |             703 |
# |      StdTestEpRet |             366 |
# |      MaxTestEpRet |        1.27e+03 |
# |      MinTestEpRet |             184 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            55.7 |
# |         StdQ1Vals |            37.2 |
# |         MaxQ1Vals |             105 |
# |         MinQ1Vals |           -5.74 |
# |     AverageQ2Vals |            55.7 |
# |         StdQ2Vals |            37.2 |
# |         MaxQ2Vals |             105 |
# |         MinQ2Vals |           -8.89 |
# |            LossPi |           -56.7 |
# |             LossQ |            2.18 |
# |              Time |        2.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             408 |
# |          StdEpRet |             250 |
# |          MaxEpRet |             691 |
# |          MinEpRet |             109 |
# |  AverageTestEpRet |             369 |
# |      StdTestEpRet |             266 |
# |      MaxTestEpRet |             918 |
# |      MinTestEpRet |             106 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            56.9 |
# |         StdQ1Vals |            38.2 |
# |         MaxQ1Vals |             108 |
# |         MinQ1Vals |           -2.49 |
# |     AverageQ2Vals |            56.9 |
# |         StdQ2Vals |            38.2 |
# |         MaxQ2Vals |             108 |
# |         MinQ2Vals |           -5.73 |
# |            LossPi |           -57.9 |
# |             LossQ |            2.59 |
# |              Time |        3.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             545 |
# |          StdEpRet |             121 |
# |          MaxEpRet |             704 |
# |          MinEpRet |             364 |
# |  AverageTestEpRet |             599 |
# |      StdTestEpRet |             272 |
# |      MaxTestEpRet |        1.18e+03 |
# |      MinTestEpRet |             297 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            57.9 |
# |         StdQ1Vals |            39.7 |
# |         MaxQ1Vals |             110 |
# |         MinQ1Vals |           -4.91 |
# |     AverageQ2Vals |            57.9 |
# |         StdQ2Vals |            39.7 |
# |         MaxQ2Vals |             110 |
# |         MinQ2Vals |           -3.95 |
# |            LossPi |           -58.9 |
# |             LossQ |            2.98 |
# |              Time |        3.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             554 |
# |          StdEpRet |             143 |
# |          MaxEpRet |             748 |
# |          MinEpRet |             388 |
# |  AverageTestEpRet |             377 |
# |      StdTestEpRet |            98.4 |
# |      MaxTestEpRet |             601 |
# |      MinTestEpRet |             227 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |              59 |
# |         StdQ1Vals |            40.7 |
# |         MaxQ1Vals |             113 |
# |         MinQ1Vals |             1.6 |
# |     AverageQ2Vals |              59 |
# |         StdQ2Vals |            40.7 |
# |         MaxQ2Vals |             113 |
# |         MinQ2Vals |            2.06 |
# |            LossPi |           -60.2 |
# |             LossQ |            2.98 |
# |              Time |        3.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             516 |
# |          StdEpRet |             230 |
# |          MaxEpRet |             870 |
# |          MinEpRet |             244 |
# |  AverageTestEpRet |             380 |
# |      StdTestEpRet |             109 |
# |      MaxTestEpRet |             641 |
# |      MinTestEpRet |             261 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            59.1 |
# |         StdQ1Vals |            41.5 |
# |         MaxQ1Vals |             116 |
# |         MinQ1Vals |           -1.07 |
# |     AverageQ2Vals |            59.1 |
# |         StdQ2Vals |            41.5 |
# |         MaxQ2Vals |             116 |
# |         MinQ2Vals |           -1.25 |
# |            LossPi |           -60.2 |
# |             LossQ |            3.71 |
# |              Time |        3.38e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             519 |
# |          StdEpRet |             340 |
# |          MaxEpRet |             993 |
# |          MinEpRet |            42.5 |
# |  AverageTestEpRet |             938 |
# |      StdTestEpRet |             360 |
# |      MaxTestEpRet |        1.39e+03 |
# |      MinTestEpRet |             305 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |              59 |
# |         StdQ1Vals |            42.1 |
# |         MaxQ1Vals |             118 |
# |         MinQ1Vals |           -1.48 |
# |     AverageQ2Vals |              59 |
# |         StdQ2Vals |            42.1 |
# |         MaxQ2Vals |             118 |
# |         MinQ2Vals |           -2.36 |
# |            LossPi |           -60.2 |
# |             LossQ |            4.08 |
# |              Time |        3.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             773 |
# |          StdEpRet |             288 |
# |          MaxEpRet |        1.14e+03 |
# |          MinEpRet |             356 |
# |  AverageTestEpRet |             604 |
# |      StdTestEpRet |             494 |
# |      MaxTestEpRet |         1.3e+03 |
# |      MinTestEpRet |            -201 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            59.8 |
# |         StdQ1Vals |            42.6 |
# |         MaxQ1Vals |             118 |
# |         MinQ1Vals |            6.75 |
# |     AverageQ2Vals |            59.8 |
# |         StdQ2Vals |            42.6 |
# |         MaxQ2Vals |             119 |
# |         MinQ2Vals |             5.4 |
# |            LossPi |             -61 |
# |             LossQ |            4.03 |
# |              Time |        3.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             870 |
# |          StdEpRet |             365 |
# |          MaxEpRet |        1.08e+03 |
# |          MinEpRet |             238 |
# |  AverageTestEpRet |             893 |
# |      StdTestEpRet |             294 |
# |      MaxTestEpRet |        1.29e+03 |
# |      MinTestEpRet |             452 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |              61 |
# |         StdQ1Vals |            43.6 |
# |         MaxQ1Vals |             119 |
# |         MinQ1Vals |            3.77 |
# |     AverageQ2Vals |              61 |
# |         StdQ2Vals |            43.6 |
# |         MaxQ2Vals |             120 |
# |         MinQ2Vals |            2.32 |
# |            LossPi |             -62 |
# |             LossQ |            3.97 |
# |              Time |         3.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             670 |
# |          StdEpRet |             229 |
# |          MaxEpRet |        1.05e+03 |
# |          MinEpRet |             471 |
# |  AverageTestEpRet |             541 |
# |      StdTestEpRet |             156 |
# |      MaxTestEpRet |             821 |
# |      MinTestEpRet |             306 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            61.7 |
# |         StdQ1Vals |              45 |
# |         MaxQ1Vals |             121 |
# |         MinQ1Vals |          -0.424 |
# |     AverageQ2Vals |            61.7 |
# |         StdQ2Vals |              45 |
# |         MaxQ2Vals |             121 |
# |         MinQ2Vals |            2.29 |
# |            LossPi |           -62.7 |
# |             LossQ |            4.15 |
# |              Time |         3.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             847 |
# |          StdEpRet |             354 |
# |          MaxEpRet |        1.29e+03 |
# |          MinEpRet |             487 |
# |  AverageTestEpRet |             581 |
# |      StdTestEpRet |             243 |
# |      MaxTestEpRet |        1.11e+03 |
# |      MinTestEpRet |             306 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |            62.7 |
# |         StdQ1Vals |            46.2 |
# |         MaxQ1Vals |             120 |
# |         MinQ1Vals |           -2.97 |
# |     AverageQ2Vals |            62.7 |
# |         StdQ2Vals |            46.2 |
# |         MaxQ2Vals |             121 |
# |         MinQ2Vals |            0.19 |
# |            LossPi |           -63.7 |
# |             LossQ |            4.13 |
# |              Time |        3.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |             440 |
# |          StdEpRet |             171 |
# |          MaxEpRet |             645 |
# |          MinEpRet |             231 |
# |  AverageTestEpRet |             440 |
# |      StdTestEpRet |            82.5 |
# |      MaxTestEpRet |             633 |
# |      MinTestEpRet |             345 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |            63.5 |
# |         StdQ1Vals |            46.9 |
# |         MaxQ1Vals |             121 |
# |         MinQ1Vals |            -2.5 |
# |     AverageQ2Vals |            63.5 |
# |         StdQ2Vals |            46.9 |
# |         MaxQ2Vals |             121 |
# |         MinQ2Vals |          -0.148 |
# |            LossPi |           -64.5 |
# |             LossQ |            3.97 |
# |              Time |        4.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |             509 |
# |          StdEpRet |             357 |
# |          MaxEpRet |        1.13e+03 |
# |          MinEpRet |             278 |
# |  AverageTestEpRet |             838 |
# |      StdTestEpRet |             352 |
# |      MaxTestEpRet |         1.4e+03 |
# |      MinTestEpRet |             436 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |            63.7 |
# |         StdQ1Vals |            47.2 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            -1.4 |
# |     AverageQ2Vals |            63.7 |
# |         StdQ2Vals |            47.2 |
# |         MaxQ2Vals |             122 |
# |         MinQ2Vals |           -1.65 |
# |            LossPi |           -64.6 |
# |             LossQ |            3.98 |
# |              Time |        4.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             690 |
# |          StdEpRet |             375 |
# |          MaxEpRet |        1.24e+03 |
# |          MinEpRet |             223 |
# |  AverageTestEpRet |             590 |
# |      StdTestEpRet |             317 |
# |      MaxTestEpRet |        1.09e+03 |
# |      MinTestEpRet |             144 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |            63.2 |
# |         StdQ1Vals |            47.5 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |           -7.58 |
# |     AverageQ2Vals |            63.2 |
# |         StdQ2Vals |            47.5 |
# |         MaxQ2Vals |             124 |
# |         MinQ2Vals |           -7.05 |
# |            LossPi |           -64.1 |
# |             LossQ |            4.29 |
# |              Time |        4.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             625 |
# |          StdEpRet |             256 |
# |          MaxEpRet |             991 |
# |          MinEpRet |             338 |
# |  AverageTestEpRet |             572 |
# |      StdTestEpRet |             164 |
# |      MaxTestEpRet |             886 |
# |      MinTestEpRet |             327 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |              63 |
# |         StdQ1Vals |            47.2 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |           -5.41 |
# |     AverageQ2Vals |              63 |
# |         StdQ2Vals |            47.2 |
# |         MaxQ2Vals |             123 |
# |         MinQ2Vals |           -6.76 |
# |            LossPi |             -64 |
# |             LossQ |            5.09 |
# |              Time |        4.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             684 |
# |          StdEpRet |             278 |
# |          MaxEpRet |        1.13e+03 |
# |          MinEpRet |             391 |
# |  AverageTestEpRet |             742 |
# |      StdTestEpRet |             409 |
# |      MaxTestEpRet |        1.36e+03 |
# |      MinTestEpRet |             295 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |            63.5 |
# |         StdQ1Vals |            47.1 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |           0.149 |
# |     AverageQ2Vals |            63.5 |
# |         StdQ2Vals |            47.1 |
# |         MaxQ2Vals |             123 |
# |         MinQ2Vals |          -0.451 |
# |            LossPi |           -64.5 |
# |             LossQ |            4.89 |
# |              Time |        4.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             828 |
# |          StdEpRet |             144 |
# |          MaxEpRet |        1.05e+03 |
# |          MinEpRet |             688 |
# |  AverageTestEpRet |             677 |
# |      StdTestEpRet |             307 |
# |      MaxTestEpRet |         1.2e+03 |
# |      MinTestEpRet |             263 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |            63.7 |
# |         StdQ1Vals |            46.9 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |            2.08 |
# |     AverageQ2Vals |            63.7 |
# |         StdQ2Vals |            46.9 |
# |         MaxQ2Vals |             123 |
# |         MinQ2Vals |            2.49 |
# |            LossPi |           -64.6 |
# |             LossQ |            5.07 |
# |              Time |        4.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             576 |
# |          StdEpRet |             198 |
# |          MaxEpRet |             795 |
# |          MinEpRet |             308 |
# |  AverageTestEpRet |             542 |
# |      StdTestEpRet |             405 |
# |      MaxTestEpRet |        1.07e+03 |
# |      MinTestEpRet |            -482 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |            64.7 |
# |         StdQ1Vals |            46.8 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |             4.5 |
# |     AverageQ2Vals |            64.7 |
# |         StdQ2Vals |            46.8 |
# |         MaxQ2Vals |             123 |
# |         MinQ2Vals |            5.02 |
# |            LossPi |           -65.6 |
# |             LossQ |            4.91 |
# |              Time |        4.67e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |             767 |
# |          StdEpRet |             359 |
# |          MaxEpRet |        1.31e+03 |
# |          MinEpRet |             311 |
# |  AverageTestEpRet |             421 |
# |      StdTestEpRet |             265 |
# |      MaxTestEpRet |             660 |
# |      MinTestEpRet |            -306 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |              65 |
# |         StdQ1Vals |            46.9 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            5.79 |
# |     AverageQ2Vals |              65 |
# |         StdQ2Vals |            46.9 |
# |         MaxQ2Vals |             122 |
# |         MinQ2Vals |            7.12 |
# |            LossPi |             -66 |
# |             LossQ |            4.63 |
# |              Time |         4.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |             548 |
# |          StdEpRet |             116 |
# |          MaxEpRet |             706 |
# |          MinEpRet |             404 |
# |  AverageTestEpRet |             942 |
# |      StdTestEpRet |             306 |
# |      MaxTestEpRet |        1.45e+03 |
# |      MinTestEpRet |             484 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |            65.3 |
# |         StdQ1Vals |            47.2 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            7.18 |
# |     AverageQ2Vals |            65.3 |
# |         StdQ2Vals |            47.2 |
# |         MaxQ2Vals |             123 |
# |         MinQ2Vals |            7.99 |
# |            LossPi |           -66.2 |
# |             LossQ |            4.59 |
# |              Time |        4.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             686 |
# |          StdEpRet |            77.9 |
# |          MaxEpRet |             785 |
# |          MinEpRet |             575 |
# |  AverageTestEpRet |             809 |
# |      StdTestEpRet |             377 |
# |      MaxTestEpRet |        1.46e+03 |
# |      MinTestEpRet |             297 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |            65.2 |
# |         StdQ1Vals |            47.2 |
# |         MaxQ1Vals |             122 |
# |         MinQ1Vals |            4.67 |
# |     AverageQ2Vals |            65.2 |
# |         StdQ2Vals |            47.2 |
# |         MaxQ2Vals |             122 |
# |         MinQ2Vals |            4.36 |
# |            LossPi |           -66.1 |
# |             LossQ |            4.47 |
# |              Time |        5.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             765 |
# |          StdEpRet |             564 |
# |          MaxEpRet |        1.54e+03 |
# |          MinEpRet |            57.6 |
# |  AverageTestEpRet |             759 |
# |      StdTestEpRet |             369 |
# |      MaxTestEpRet |        1.34e+03 |
# |      MinTestEpRet |            68.8 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |            65.5 |
# |         StdQ1Vals |            47.7 |
# |         MaxQ1Vals |             123 |
# |         MinQ1Vals |            1.09 |
# |     AverageQ2Vals |            65.5 |
# |         StdQ2Vals |            47.7 |
# |         MaxQ2Vals |             124 |
# |         MinQ2Vals |            3.36 |
# |            LossPi |           -66.4 |
# |             LossQ |            4.32 |
# |              Time |        5.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |             770 |
# |          StdEpRet |             350 |
# |          MaxEpRet |        1.33e+03 |
# |          MinEpRet |             427 |
# |  AverageTestEpRet |             905 |
# |      StdTestEpRet |             350 |
# |      MaxTestEpRet |        1.49e+03 |
# |      MinTestEpRet |             270 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |              66 |
# |         StdQ1Vals |            48.5 |
# |         MaxQ1Vals |             124 |
# |         MinQ1Vals |            2.91 |
# |     AverageQ2Vals |              66 |
# |         StdQ2Vals |            48.5 |
# |         MaxQ2Vals |             124 |
# |         MinQ2Vals |            3.17 |
# |            LossPi |           -66.8 |
# |             LossQ |            4.58 |
# |              Time |        5.25e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':True,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'exp_name': 'td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
     logger_kwargs=logger_kwargs)
# Out:
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_name":	"HalfCheetah-v2",
#     "epochs":	50,
#     "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#     "gamma":	0.99,
#     "gravity_change_pattern":	"gravity_averagely_equal",
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000021F94475D48>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "nonstationary_env":	true,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -281 |
# |          StdEpRet |            97.6 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -436 |
# |  AverageTestEpRet |            -359 |
# |      StdTestEpRet |            52.2 |
# |      MaxTestEpRet |            -266 |
# |      MinTestEpRet |            -455 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            1.72 |
# |         StdQ1Vals |            2.88 |
# |         MaxQ1Vals |            14.8 |
# |         MinQ1Vals |           -4.98 |
# |     AverageQ2Vals |            1.72 |
# |         StdQ2Vals |            2.88 |
# |         MaxQ2Vals |            14.8 |
# |         MinQ2Vals |           -4.87 |
# |            LossPi |           -2.55 |
# |             LossQ |           0.636 |
# |              Time |            91.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -265 |
# |          StdEpRet |            40.6 |
# |          MaxEpRet |            -220 |
# |          MinEpRet |            -328 |
# |  AverageTestEpRet |            -667 |
# |      StdTestEpRet |              92 |
# |      MaxTestEpRet |            -546 |
# |      MinTestEpRet |            -805 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            12.3 |
# |         StdQ1Vals |            8.61 |
# |         MaxQ1Vals |            42.6 |
# |         MinQ1Vals |           -4.41 |
# |     AverageQ2Vals |            12.3 |
# |         StdQ2Vals |            8.61 |
# |         MaxQ2Vals |            42.7 |
# |         MinQ2Vals |           -4.13 |
# |            LossPi |             -14 |
# |             LossQ |             2.8 |
# |              Time |             207 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -481 |
# |          StdEpRet |             256 |
# |          MaxEpRet |            -294 |
# |          MinEpRet |            -917 |
# |  AverageTestEpRet |            -326 |
# |      StdTestEpRet |            62.3 |
# |      MaxTestEpRet |            -244 |
# |      MinTestEpRet |            -440 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            28.4 |
# |         StdQ1Vals |            11.8 |
# |         MaxQ1Vals |            69.5 |
# |         MinQ1Vals |           -9.48 |
# |     AverageQ2Vals |            28.4 |
# |         StdQ2Vals |            11.8 |
# |         MaxQ2Vals |            73.7 |
# |         MinQ2Vals |           -11.3 |
# |            LossPi |           -30.3 |
# |             LossQ |            3.67 |
# |              Time |             328 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -374 |
# |          StdEpRet |             187 |
# |          MaxEpRet |           -95.4 |
# |          MinEpRet |            -612 |
# |  AverageTestEpRet |           -58.8 |
# |      StdTestEpRet |            73.6 |
# |      MaxTestEpRet |             102 |
# |      MinTestEpRet |            -142 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            24.7 |
# |         StdQ1Vals |            12.8 |
# |         MaxQ1Vals |            51.3 |
# |         MinQ1Vals |           -15.1 |
# |     AverageQ2Vals |            24.7 |
# |         StdQ2Vals |            12.8 |
# |         MaxQ2Vals |            51.4 |
# |         MinQ2Vals |           -14.8 |
# |            LossPi |           -25.6 |
# |             LossQ |            3.42 |
# |              Time |             446 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             349 |
# |          StdEpRet |             197 |
# |          MaxEpRet |             644 |
# |          MinEpRet |             102 |
# |  AverageTestEpRet |             706 |
# |      StdTestEpRet |             370 |
# |      MaxTestEpRet |        1.28e+03 |
# |      MinTestEpRet |             167 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            18.9 |
# |         StdQ1Vals |            14.4 |
# |         MaxQ1Vals |            55.1 |
# |         MinQ1Vals |           -19.7 |
# |     AverageQ2Vals |            18.9 |
# |         StdQ2Vals |            14.4 |
# |         MaxQ2Vals |            55.1 |
# |         MinQ2Vals |           -20.9 |
# |            LossPi |           -19.9 |
# |             LossQ |            2.99 |
# |              Time |             562 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             741 |
# |          StdEpRet |             220 |
# |          MaxEpRet |        1.03e+03 |
# |          MinEpRet |             494 |
# |  AverageTestEpRet |        1.57e+03 |
# |      StdTestEpRet |             354 |
# |      MaxTestEpRet |        1.95e+03 |
# |      MinTestEpRet |             619 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            21.4 |
# |         StdQ1Vals |            18.9 |
# |         MaxQ1Vals |            75.9 |
# |         MinQ1Vals |           -26.1 |
# |     AverageQ2Vals |            21.4 |
# |         StdQ2Vals |            18.9 |
# |         MaxQ2Vals |            75.3 |
# |         MinQ2Vals |           -25.4 |
# |            LossPi |           -22.6 |
# |             LossQ |            4.21 |
# |              Time |             688 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |        1.18e+03 |
# |          StdEpRet |             285 |
# |          MaxEpRet |        1.63e+03 |
# |          MinEpRet |             913 |
# |  AverageTestEpRet |        1.78e+03 |
# |      StdTestEpRet |             108 |
# |      MaxTestEpRet |        1.96e+03 |
# |      MinTestEpRet |         1.6e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            29.5 |
# |         StdQ1Vals |            26.3 |
# |         MaxQ1Vals |             103 |
# |         MinQ1Vals |           -26.8 |
# |     AverageQ2Vals |            29.5 |
# |         StdQ2Vals |            26.3 |
# |         MaxQ2Vals |             103 |
# |         MinQ2Vals |           -28.7 |
# |            LossPi |           -30.8 |
# |             LossQ |            6.48 |
# |              Time |             820 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |        1.87e+03 |
# |          StdEpRet |             445 |
# |          MaxEpRet |        2.23e+03 |
# |          MinEpRet |         1.1e+03 |
# |  AverageTestEpRet |        2.75e+03 |
# |      StdTestEpRet |             102 |
# |      MaxTestEpRet |        2.93e+03 |
# |      MinTestEpRet |        2.57e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            42.6 |
# |         StdQ1Vals |            35.4 |
# |         MaxQ1Vals |             130 |
# |         MinQ1Vals |           -28.9 |
# |     AverageQ2Vals |            42.6 |
# |         StdQ2Vals |            35.4 |
# |         MaxQ2Vals |             132 |
# |         MinQ2Vals |             -24 |
# |            LossPi |           -44.2 |
# |             LossQ |            8.71 |
# |              Time |             937 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |         1.9e+03 |
# |          StdEpRet |             472 |
# |          MaxEpRet |        2.39e+03 |
# |          MinEpRet |        1.37e+03 |
# |  AverageTestEpRet |         2.8e+03 |
# |      StdTestEpRet |            54.6 |
# |      MaxTestEpRet |        2.91e+03 |
# |      MinTestEpRet |        2.73e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            59.9 |
# |         StdQ1Vals |            45.4 |
# |         MaxQ1Vals |             160 |
# |         MinQ1Vals |           -22.5 |
# |     AverageQ2Vals |            59.9 |
# |         StdQ2Vals |            45.4 |
# |         MaxQ2Vals |             159 |
# |         MinQ2Vals |           -23.2 |
# |            LossPi |           -61.7 |
# |             LossQ |            11.7 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |        2.35e+03 |
# |          StdEpRet |             662 |
# |          MaxEpRet |        2.93e+03 |
# |          MinEpRet |        1.22e+03 |
# |  AverageTestEpRet |        2.86e+03 |
# |      StdTestEpRet |            48.7 |
# |      MaxTestEpRet |        2.92e+03 |
# |      MinTestEpRet |        2.78e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            77.8 |
# |         StdQ1Vals |            56.3 |
# |         MaxQ1Vals |             182 |
# |         MinQ1Vals |           -24.8 |
# |     AverageQ2Vals |            77.8 |
# |         StdQ2Vals |            56.3 |
# |         MaxQ2Vals |             179 |
# |         MinQ2Vals |           -24.1 |
# |            LossPi |           -79.8 |
# |             LossQ |            14.4 |
# |              Time |        1.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |        2.85e+03 |
# |          StdEpRet |            95.3 |
# |          MaxEpRet |        2.95e+03 |
# |          MinEpRet |        2.74e+03 |
# |  AverageTestEpRet |        3.13e+03 |
# |      StdTestEpRet |            70.3 |
# |      MaxTestEpRet |        3.24e+03 |
# |      MinTestEpRet |        2.99e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            98.5 |
# |         StdQ1Vals |            67.3 |
# |         MaxQ1Vals |             203 |
# |         MinQ1Vals |           -25.1 |
# |     AverageQ2Vals |            98.5 |
# |         StdQ2Vals |            67.3 |
# |         MaxQ2Vals |             204 |
# |         MinQ2Vals |           -24.8 |
# |            LossPi |            -101 |
# |             LossQ |            15.9 |
# |              Time |        1.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |        2.94e+03 |
# |          StdEpRet |             142 |
# |          MaxEpRet |        3.11e+03 |
# |          MinEpRet |        2.72e+03 |
# |  AverageTestEpRet |        3.18e+03 |
# |      StdTestEpRet |            48.5 |
# |      MaxTestEpRet |        3.26e+03 |
# |      MinTestEpRet |        3.09e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |             120 |
# |         StdQ1Vals |            76.1 |
# |         MaxQ1Vals |             227 |
# |         MinQ1Vals |           -23.7 |
# |     AverageQ2Vals |             120 |
# |         StdQ2Vals |            76.1 |
# |         MaxQ2Vals |             227 |
# |         MinQ2Vals |           -24.3 |
# |            LossPi |            -122 |
# |             LossQ |            16.9 |
# |              Time |        1.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |        3.12e+03 |
# |          StdEpRet |            81.4 |
# |          MaxEpRet |        3.22e+03 |
# |          MinEpRet |        3.01e+03 |
# |  AverageTestEpRet |        3.27e+03 |
# |      StdTestEpRet |            30.9 |
# |      MaxTestEpRet |        3.33e+03 |
# |      MinTestEpRet |        3.22e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |             140 |
# |         StdQ1Vals |            83.7 |
# |         MaxQ1Vals |             247 |
# |         MinQ1Vals |           -25.8 |
# |     AverageQ2Vals |             140 |
# |         StdQ2Vals |            83.7 |
# |         MaxQ2Vals |             245 |
# |         MinQ2Vals |           -27.2 |
# |            LossPi |            -142 |
# |             LossQ |            16.9 |
# |              Time |        1.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        3.21e+03 |
# |          StdEpRet |            81.6 |
# |          MaxEpRet |         3.3e+03 |
# |          MinEpRet |        3.11e+03 |
# |  AverageTestEpRet |        3.29e+03 |
# |      StdTestEpRet |            57.4 |
# |      MaxTestEpRet |        3.38e+03 |
# |      MinTestEpRet |        3.19e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |             159 |
# |         StdQ1Vals |            89.6 |
# |         MaxQ1Vals |             264 |
# |         MinQ1Vals |           -25.1 |
# |     AverageQ2Vals |             159 |
# |         StdQ2Vals |            89.6 |
# |         MaxQ2Vals |             264 |
# |         MinQ2Vals |           -24.3 |
# |            LossPi |            -161 |
# |             LossQ |            16.5 |
# |              Time |        1.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        3.35e+03 |
# |          StdEpRet |            92.6 |
# |          MaxEpRet |        3.47e+03 |
# |          MinEpRet |        3.21e+03 |
# |  AverageTestEpRet |        3.52e+03 |
# |      StdTestEpRet |            64.3 |
# |      MaxTestEpRet |        3.61e+03 |
# |      MinTestEpRet |         3.4e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |             178 |
# |         StdQ1Vals |            92.8 |
# |         MaxQ1Vals |             291 |
# |         MinQ1Vals |           -21.5 |
# |     AverageQ2Vals |             178 |
# |         StdQ2Vals |            92.8 |
# |         MaxQ2Vals |             291 |
# |         MinQ2Vals |           -19.1 |
# |            LossPi |            -180 |
# |             LossQ |            17.1 |
# |              Time |        1.78e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |        3.56e+03 |
# |          StdEpRet |            78.1 |
# |          MaxEpRet |        3.67e+03 |
# |          MinEpRet |        3.47e+03 |
# |  AverageTestEpRet |        3.48e+03 |
# |      StdTestEpRet |            43.5 |
# |      MaxTestEpRet |        3.56e+03 |
# |      MinTestEpRet |         3.4e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |             196 |
# |         StdQ1Vals |            93.3 |
# |         MaxQ1Vals |             320 |
# |         MinQ1Vals |           -10.8 |
# |     AverageQ2Vals |             196 |
# |         StdQ2Vals |            93.3 |
# |         MaxQ2Vals |             321 |
# |         MinQ2Vals |           -16.2 |
# |            LossPi |            -198 |
# |             LossQ |            17.3 |
# |              Time |         1.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        3.57e+03 |
# |          StdEpRet |            56.7 |
# |          MaxEpRet |        3.66e+03 |
# |          MinEpRet |        3.52e+03 |
# |  AverageTestEpRet |        3.77e+03 |
# |      StdTestEpRet |            69.6 |
# |      MaxTestEpRet |        3.86e+03 |
# |      MinTestEpRet |        3.62e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |             214 |
# |         StdQ1Vals |            92.9 |
# |         MaxQ1Vals |             333 |
# |         MinQ1Vals |           -2.44 |
# |     AverageQ2Vals |             214 |
# |         StdQ2Vals |            92.9 |
# |         MaxQ2Vals |             335 |
# |         MinQ2Vals |           -5.44 |
# |            LossPi |            -217 |
# |             LossQ |            17.2 |
# |              Time |        2.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        3.37e+03 |
# |          StdEpRet |             855 |
# |          MaxEpRet |        3.92e+03 |
# |          MinEpRet |         1.9e+03 |
# |  AverageTestEpRet |        4.24e+03 |
# |      StdTestEpRet |            65.3 |
# |      MaxTestEpRet |         4.3e+03 |
# |      MinTestEpRet |        4.09e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |             232 |
# |         StdQ1Vals |            92.3 |
# |         MaxQ1Vals |             350 |
# |         MinQ1Vals |            15.5 |
# |     AverageQ2Vals |             232 |
# |         StdQ2Vals |            92.3 |
# |         MaxQ2Vals |             348 |
# |         MinQ2Vals |            11.6 |
# |            LossPi |            -235 |
# |             LossQ |            17.8 |
# |              Time |        2.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |        3.74e+03 |
# |          StdEpRet |             140 |
# |          MaxEpRet |        3.96e+03 |
# |          MinEpRet |        3.57e+03 |
# |  AverageTestEpRet |        4.15e+03 |
# |      StdTestEpRet |            39.9 |
# |      MaxTestEpRet |        4.21e+03 |
# |      MinTestEpRet |        4.09e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |             248 |
# |         StdQ1Vals |            92.1 |
# |         MaxQ1Vals |             366 |
# |         MinQ1Vals |            35.7 |
# |     AverageQ2Vals |             248 |
# |         StdQ2Vals |            92.1 |
# |         MaxQ2Vals |             365 |
# |         MinQ2Vals |            28.5 |
# |            LossPi |            -251 |
# |             LossQ |            20.1 |
# |              Time |        2.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |        3.97e+03 |
# |          StdEpRet |             291 |
# |          MaxEpRet |        4.23e+03 |
# |          MinEpRet |        3.47e+03 |
# |  AverageTestEpRet |        4.52e+03 |
# |      StdTestEpRet |            64.7 |
# |      MaxTestEpRet |         4.6e+03 |
# |      MinTestEpRet |        4.39e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |             264 |
# |         StdQ1Vals |            92.3 |
# |         MaxQ1Vals |             382 |
# |         MinQ1Vals |            38.2 |
# |     AverageQ2Vals |             264 |
# |         StdQ2Vals |            92.3 |
# |         MaxQ2Vals |             381 |
# |         MinQ2Vals |              48 |
# |            LossPi |            -266 |
# |             LossQ |            21.3 |
# |              Time |        2.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        3.56e+03 |
# |          StdEpRet |             919 |
# |          MaxEpRet |         4.2e+03 |
# |          MinEpRet |        1.98e+03 |
# |  AverageTestEpRet |        4.41e+03 |
# |      StdTestEpRet |            68.4 |
# |      MaxTestEpRet |        4.53e+03 |
# |      MinTestEpRet |        4.31e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |             279 |
# |         StdQ1Vals |            92.2 |
# |         MaxQ1Vals |             397 |
# |         MinQ1Vals |              36 |
# |     AverageQ2Vals |             279 |
# |         StdQ2Vals |            92.2 |
# |         MaxQ2Vals |             398 |
# |         MinQ2Vals |            27.6 |
# |            LossPi |            -281 |
# |             LossQ |            23.8 |
# |              Time |        2.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |         4.1e+03 |
# |          StdEpRet |             114 |
# |          MaxEpRet |        4.27e+03 |
# |          MinEpRet |        3.97e+03 |
# |  AverageTestEpRet |        4.46e+03 |
# |      StdTestEpRet |            43.2 |
# |      MaxTestEpRet |        4.52e+03 |
# |      MinTestEpRet |        4.39e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |             292 |
# |         StdQ1Vals |            92.9 |
# |         MaxQ1Vals |             412 |
# |         MinQ1Vals |              44 |
# |     AverageQ2Vals |             292 |
# |         StdQ2Vals |            92.9 |
# |         MaxQ2Vals |             414 |
# |         MinQ2Vals |            45.9 |
# |            LossPi |            -294 |
# |             LossQ |            26.9 |
# |              Time |        2.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |        3.98e+03 |
# |          StdEpRet |             342 |
# |          MaxEpRet |        4.31e+03 |
# |          MinEpRet |         3.5e+03 |
# |  AverageTestEpRet |        4.37e+03 |
# |      StdTestEpRet |            48.9 |
# |      MaxTestEpRet |        4.46e+03 |
# |      MinTestEpRet |        4.29e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |             307 |
# |         StdQ1Vals |            88.7 |
# |         MaxQ1Vals |             426 |
# |         MinQ1Vals |            65.4 |
# |     AverageQ2Vals |             307 |
# |         StdQ2Vals |            88.7 |
# |         MaxQ2Vals |             425 |
# |         MinQ2Vals |            61.7 |
# |            LossPi |            -310 |
# |             LossQ |            28.4 |
# |              Time |        2.73e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        3.81e+03 |
# |          StdEpRet |        1.18e+03 |
# |          MaxEpRet |        4.58e+03 |
# |          MinEpRet |        1.77e+03 |
# |  AverageTestEpRet |         4.7e+03 |
# |      StdTestEpRet |            89.9 |
# |      MaxTestEpRet |         4.8e+03 |
# |      MinTestEpRet |        4.52e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |             320 |
# |         StdQ1Vals |            86.6 |
# |         MaxQ1Vals |             438 |
# |         MinQ1Vals |            87.3 |
# |     AverageQ2Vals |             320 |
# |         StdQ2Vals |            86.6 |
# |         MaxQ2Vals |             438 |
# |         MinQ2Vals |             101 |
# |            LossPi |            -323 |
# |             LossQ |              31 |
# |              Time |        2.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |         4.6e+03 |
# |          StdEpRet |             106 |
# |          MaxEpRet |        4.76e+03 |
# |          MinEpRet |        4.49e+03 |
# |  AverageTestEpRet |        4.81e+03 |
# |      StdTestEpRet |             107 |
# |      MaxTestEpRet |        4.97e+03 |
# |      MinTestEpRet |         4.6e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |             333 |
# |         StdQ1Vals |            85.6 |
# |         MaxQ1Vals |             451 |
# |         MinQ1Vals |            52.2 |
# |     AverageQ2Vals |             333 |
# |         StdQ2Vals |            85.6 |
# |         MaxQ2Vals |             451 |
# |         MinQ2Vals |            43.1 |
# |            LossPi |            -336 |
# |             LossQ |            33.1 |
# |              Time |        2.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |        4.33e+03 |
# |          StdEpRet |             153 |
# |          MaxEpRet |        4.46e+03 |
# |          MinEpRet |        4.09e+03 |
# |  AverageTestEpRet |        4.69e+03 |
# |      StdTestEpRet |            47.7 |
# |      MaxTestEpRet |        4.77e+03 |
# |      MinTestEpRet |        4.62e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |             345 |
# |         StdQ1Vals |            85.8 |
# |         MaxQ1Vals |             459 |
# |         MinQ1Vals |              20 |
# |     AverageQ2Vals |             345 |
# |         StdQ2Vals |            85.8 |
# |         MaxQ2Vals |             460 |
# |         MinQ2Vals |            34.7 |
# |            LossPi |            -348 |
# |             LossQ |            36.2 |
# |              Time |        3.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |         4.5e+03 |
# |          StdEpRet |             146 |
# |          MaxEpRet |        4.63e+03 |
# |          MinEpRet |        4.26e+03 |
# |  AverageTestEpRet |        4.91e+03 |
# |      StdTestEpRet |            67.7 |
# |      MaxTestEpRet |           5e+03 |
# |      MinTestEpRet |        4.79e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |             356 |
# |         StdQ1Vals |            87.1 |
# |         MaxQ1Vals |             471 |
# |         MinQ1Vals |           -6.62 |
# |     AverageQ2Vals |             356 |
# |         StdQ2Vals |            87.2 |
# |         MaxQ2Vals |             472 |
# |         MinQ2Vals |           -14.3 |
# |            LossPi |            -359 |
# |             LossQ |              36 |
# |              Time |         3.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        4.56e+03 |
# |          StdEpRet |             155 |
# |          MaxEpRet |        4.79e+03 |
# |          MinEpRet |        4.36e+03 |
# |  AverageTestEpRet |         4.8e+03 |
# |      StdTestEpRet |             152 |
# |      MaxTestEpRet |        4.97e+03 |
# |      MinTestEpRet |        4.41e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |             367 |
# |         StdQ1Vals |              88 |
# |         MaxQ1Vals |             484 |
# |         MinQ1Vals |           -64.7 |
# |     AverageQ2Vals |             367 |
# |         StdQ2Vals |              88 |
# |         MaxQ2Vals |             483 |
# |         MinQ2Vals |             -58 |
# |            LossPi |            -370 |
# |             LossQ |              33 |
# |              Time |        3.32e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        4.76e+03 |
# |          StdEpRet |             175 |
# |          MaxEpRet |        4.94e+03 |
# |          MinEpRet |         4.5e+03 |
# |  AverageTestEpRet |        5.19e+03 |
# |      StdTestEpRet |            43.9 |
# |      MaxTestEpRet |        5.26e+03 |
# |      MinTestEpRet |        5.12e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |             378 |
# |         StdQ1Vals |            88.7 |
# |         MaxQ1Vals |             497 |
# |         MinQ1Vals |           -97.4 |
# |     AverageQ2Vals |             378 |
# |         StdQ2Vals |            88.7 |
# |         MaxQ2Vals |             493 |
# |         MinQ2Vals |           -94.3 |
# |            LossPi |            -381 |
# |             LossQ |            33.3 |
# |              Time |        3.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        4.77e+03 |
# |          StdEpRet |            99.6 |
# |          MaxEpRet |        4.88e+03 |
# |          MinEpRet |        4.62e+03 |
# |  AverageTestEpRet |        5.11e+03 |
# |      StdTestEpRet |            57.4 |
# |      MaxTestEpRet |        5.19e+03 |
# |      MinTestEpRet |        5.01e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |             389 |
# |         StdQ1Vals |            89.3 |
# |         MaxQ1Vals |             502 |
# |         MinQ1Vals |           -70.8 |
# |     AverageQ2Vals |             389 |
# |         StdQ2Vals |            89.3 |
# |         MaxQ2Vals |             503 |
# |         MinQ2Vals |           -39.5 |
# |            LossPi |            -391 |
# |             LossQ |            35.3 |
# |              Time |        3.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |        4.75e+03 |
# |          StdEpRet |             154 |
# |          MaxEpRet |         4.9e+03 |
# |          MinEpRet |        4.49e+03 |
# |  AverageTestEpRet |        5.18e+03 |
# |      StdTestEpRet |            50.7 |
# |      MaxTestEpRet |        5.25e+03 |
# |      MinTestEpRet |        5.07e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |             398 |
# |         StdQ1Vals |            90.7 |
# |         MaxQ1Vals |             509 |
# |         MinQ1Vals |             -36 |
# |     AverageQ2Vals |             398 |
# |         StdQ2Vals |            90.7 |
# |         MaxQ2Vals |             512 |
# |         MinQ2Vals |           -46.9 |
# |            LossPi |            -401 |
# |             LossQ |            34.9 |
# |              Time |        3.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        5.04e+03 |
# |          StdEpRet |             215 |
# |          MaxEpRet |        5.39e+03 |
# |          MinEpRet |        4.82e+03 |
# |  AverageTestEpRet |        5.46e+03 |
# |      StdTestEpRet |            38.3 |
# |      MaxTestEpRet |        5.54e+03 |
# |      MinTestEpRet |        5.41e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |             407 |
# |         StdQ1Vals |            92.9 |
# |         MaxQ1Vals |             521 |
# |         MinQ1Vals |           -87.5 |
# |     AverageQ2Vals |             407 |
# |         StdQ2Vals |            92.9 |
# |         MaxQ2Vals |             522 |
# |         MinQ2Vals |           -97.3 |
# |            LossPi |            -409 |
# |             LossQ |            33.3 |
# |              Time |        3.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |        4.99e+03 |
# |          StdEpRet |             175 |
# |          MaxEpRet |        5.28e+03 |
# |          MinEpRet |        4.83e+03 |
# |  AverageTestEpRet |        5.51e+03 |
# |      StdTestEpRet |            80.3 |
# |      MaxTestEpRet |        5.64e+03 |
# |      MinTestEpRet |         5.4e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |             416 |
# |         StdQ1Vals |            93.8 |
# |         MaxQ1Vals |             527 |
# |         MinQ1Vals |            -182 |
# |     AverageQ2Vals |             416 |
# |         StdQ2Vals |            93.8 |
# |         MaxQ2Vals |             529 |
# |         MinQ2Vals |            -160 |
# |            LossPi |            -419 |
# |             LossQ |              33 |
# |              Time |        3.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |        4.99e+03 |
# |          StdEpRet |            73.2 |
# |          MaxEpRet |        5.09e+03 |
# |          MinEpRet |        4.89e+03 |
# |  AverageTestEpRet |        5.77e+03 |
# |      StdTestEpRet |            70.2 |
# |      MaxTestEpRet |        5.85e+03 |
# |      MinTestEpRet |        5.63e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |             425 |
# |         StdQ1Vals |            94.2 |
# |         MaxQ1Vals |             537 |
# |         MinQ1Vals |            -161 |
# |     AverageQ2Vals |             425 |
# |         StdQ2Vals |            94.2 |
# |         MaxQ2Vals |             538 |
# |         MinQ2Vals |            -149 |
# |            LossPi |            -427 |
# |             LossQ |            32.8 |
# |              Time |        4.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |         5.1e+03 |
# |          StdEpRet |             202 |
# |          MaxEpRet |        5.34e+03 |
# |          MinEpRet |        4.78e+03 |
# |  AverageTestEpRet |        5.66e+03 |
# |      StdTestEpRet |             157 |
# |      MaxTestEpRet |         5.9e+03 |
# |      MinTestEpRet |        5.34e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |             432 |
# |         StdQ1Vals |            95.9 |
# |         MaxQ1Vals |             547 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |             432 |
# |         StdQ2Vals |            95.9 |
# |         MaxQ2Vals |             550 |
# |         MinQ2Vals |           -95.4 |
# |            LossPi |            -435 |
# |             LossQ |            33.1 |
# |              Time |        4.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |        5.15e+03 |
# |          StdEpRet |             196 |
# |          MaxEpRet |        5.38e+03 |
# |          MinEpRet |        4.87e+03 |
# |  AverageTestEpRet |        5.36e+03 |
# |      StdTestEpRet |             249 |
# |      MaxTestEpRet |        5.66e+03 |
# |      MinTestEpRet |        4.91e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |             440 |
# |         StdQ1Vals |            96.4 |
# |         MaxQ1Vals |             558 |
# |         MinQ1Vals |            -181 |
# |     AverageQ2Vals |             440 |
# |         StdQ2Vals |            96.4 |
# |         MaxQ2Vals |             556 |
# |         MinQ2Vals |            -153 |
# |            LossPi |            -442 |
# |             LossQ |            35.2 |
# |              Time |        4.28e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |        5.23e+03 |
# |          StdEpRet |             316 |
# |          MaxEpRet |        5.57e+03 |
# |          MinEpRet |        4.74e+03 |
# |  AverageTestEpRet |        5.74e+03 |
# |      StdTestEpRet |             102 |
# |      MaxTestEpRet |        5.93e+03 |
# |      MinTestEpRet |        5.61e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |             448 |
# |         StdQ1Vals |              96 |
# |         MaxQ1Vals |             563 |
# |         MinQ1Vals |            -127 |
# |     AverageQ2Vals |             448 |
# |         StdQ2Vals |              96 |
# |         MaxQ2Vals |             564 |
# |         MinQ2Vals |            -137 |
# |            LossPi |            -450 |
# |             LossQ |            35.8 |
# |              Time |         4.4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        5.25e+03 |
# |          StdEpRet |             121 |
# |          MaxEpRet |        5.41e+03 |
# |          MinEpRet |        5.12e+03 |
# |  AverageTestEpRet |        5.76e+03 |
# |      StdTestEpRet |            56.3 |
# |      MaxTestEpRet |        5.88e+03 |
# |      MinTestEpRet |        5.66e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |             454 |
# |         StdQ1Vals |            96.9 |
# |         MaxQ1Vals |             568 |
# |         MinQ1Vals |           -86.3 |
# |     AverageQ2Vals |             454 |
# |         StdQ2Vals |            96.9 |
# |         MaxQ2Vals |             568 |
# |         MinQ2Vals |           -89.5 |
# |            LossPi |            -456 |
# |             LossQ |            34.7 |
# |              Time |        4.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |         5.2e+03 |
# |          StdEpRet |             207 |
# |          MaxEpRet |        5.44e+03 |
# |          MinEpRet |        4.88e+03 |
# |  AverageTestEpRet |        5.97e+03 |
# |      StdTestEpRet |            79.2 |
# |      MaxTestEpRet |         6.1e+03 |
# |      MinTestEpRet |        5.83e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |             459 |
# |         StdQ1Vals |            98.7 |
# |         MaxQ1Vals |             574 |
# |         MinQ1Vals |            -171 |
# |     AverageQ2Vals |             459 |
# |         StdQ2Vals |            98.7 |
# |         MaxQ2Vals |             573 |
# |         MinQ2Vals |            -205 |
# |            LossPi |            -462 |
# |             LossQ |            36.6 |
# |              Time |        4.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        5.43e+03 |
# |          StdEpRet |             127 |
# |          MaxEpRet |        5.62e+03 |
# |          MinEpRet |         5.3e+03 |
# |  AverageTestEpRet |        5.68e+03 |
# |      StdTestEpRet |            55.7 |
# |      MaxTestEpRet |        5.75e+03 |
# |      MinTestEpRet |        5.61e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |             464 |
# |         StdQ1Vals |            98.4 |
# |         MaxQ1Vals |             578 |
# |         MinQ1Vals |            -107 |
# |     AverageQ2Vals |             464 |
# |         StdQ2Vals |            98.5 |
# |         MaxQ2Vals |             578 |
# |         MinQ2Vals |            -137 |
# |            LossPi |            -467 |
# |             LossQ |            36.9 |
# |              Time |        4.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        5.36e+03 |
# |          StdEpRet |             187 |
# |          MaxEpRet |        5.61e+03 |
# |          MinEpRet |         5.1e+03 |
# |  AverageTestEpRet |        5.61e+03 |
# |      StdTestEpRet |             130 |
# |      MaxTestEpRet |        5.82e+03 |
# |      MinTestEpRet |        5.38e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |             469 |
# |         StdQ1Vals |            99.4 |
# |         MaxQ1Vals |             582 |
# |         MinQ1Vals |            -111 |
# |     AverageQ2Vals |             469 |
# |         StdQ2Vals |            99.4 |
# |         MaxQ2Vals |             584 |
# |         MinQ2Vals |            -116 |
# |            LossPi |            -472 |
# |             LossQ |            37.7 |
# |              Time |        4.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |        5.34e+03 |
# |          StdEpRet |             105 |
# |          MaxEpRet |        5.47e+03 |
# |          MinEpRet |        5.18e+03 |
# |  AverageTestEpRet |        5.84e+03 |
# |      StdTestEpRet |            80.6 |
# |      MaxTestEpRet |        5.95e+03 |
# |      MinTestEpRet |        5.69e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |             475 |
# |         StdQ1Vals |            99.4 |
# |         MaxQ1Vals |             591 |
# |         MinQ1Vals |            -125 |
# |     AverageQ2Vals |             475 |
# |         StdQ2Vals |            99.4 |
# |         MaxQ2Vals |             590 |
# |         MinQ2Vals |            -131 |
# |            LossPi |            -477 |
# |             LossQ |            36.6 |
# |              Time |        5.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |        5.22e+03 |
# |          StdEpRet |             330 |
# |          MaxEpRet |         5.5e+03 |
# |          MinEpRet |        4.69e+03 |
# |  AverageTestEpRet |        6.18e+03 |
# |      StdTestEpRet |            69.8 |
# |      MaxTestEpRet |        6.28e+03 |
# |      MinTestEpRet |        6.04e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |             478 |
# |         StdQ1Vals |             102 |
# |         MaxQ1Vals |             594 |
# |         MinQ1Vals |           -84.1 |
# |     AverageQ2Vals |             478 |
# |         StdQ2Vals |             102 |
# |         MaxQ2Vals |             593 |
# |         MinQ2Vals |             -89 |
# |            LossPi |            -480 |
# |             LossQ |            37.7 |
# |              Time |        5.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |        5.35e+03 |
# |          StdEpRet |             105 |
# |          MaxEpRet |        5.43e+03 |
# |          MinEpRet |        5.17e+03 |
# |  AverageTestEpRet |        6.12e+03 |
# |      StdTestEpRet |            93.8 |
# |      MaxTestEpRet |        6.31e+03 |
# |      MinTestEpRet |        5.96e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |             483 |
# |         StdQ1Vals |             102 |
# |         MaxQ1Vals |             599 |
# |         MinQ1Vals |           -4.87 |
# |     AverageQ2Vals |             483 |
# |         StdQ2Vals |             102 |
# |         MaxQ2Vals |             597 |
# |         MinQ2Vals |           -2.77 |
# |            LossPi |            -485 |
# |             LossQ |            40.8 |
# |              Time |        5.25e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        5.45e+03 |
# |          StdEpRet |            71.4 |
# |          MaxEpRet |        5.55e+03 |
# |          MinEpRet |        5.37e+03 |
# |  AverageTestEpRet |        5.76e+03 |
# |      StdTestEpRet |             291 |
# |      MaxTestEpRet |        6.13e+03 |
# |      MinTestEpRet |        5.08e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |             487 |
# |         StdQ1Vals |             100 |
# |         MaxQ1Vals |             606 |
# |         MinQ1Vals |           -18.9 |
# |     AverageQ2Vals |             487 |
# |         StdQ2Vals |             100 |
# |         MaxQ2Vals |             610 |
# |         MinQ2Vals |           -44.2 |
# |            LossPi |            -490 |
# |             LossQ |            41.8 |
# |              Time |        5.37e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |        5.46e+03 |
# |          StdEpRet |            26.3 |
# |          MaxEpRet |        5.49e+03 |
# |          MinEpRet |        5.42e+03 |
# |  AverageTestEpRet |        6.24e+03 |
# |      StdTestEpRet |            63.6 |
# |      MaxTestEpRet |        6.34e+03 |
# |      MinTestEpRet |        6.12e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |             491 |
# |         StdQ1Vals |            99.5 |
# |         MaxQ1Vals |             607 |
# |         MinQ1Vals |           -12.5 |
# |     AverageQ2Vals |             491 |
# |         StdQ2Vals |            99.5 |
# |         MaxQ2Vals |             610 |
# |         MinQ2Vals |           -40.6 |
# |            LossPi |            -494 |
# |             LossQ |            41.7 |
# |              Time |        5.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |        5.45e+03 |
# |          StdEpRet |              97 |
# |          MaxEpRet |        5.61e+03 |
# |          MinEpRet |        5.34e+03 |
# |  AverageTestEpRet |        5.52e+03 |
# |      StdTestEpRet |             465 |
# |      MaxTestEpRet |        6.23e+03 |
# |      MinTestEpRet |        4.53e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |             496 |
# |         StdQ1Vals |            96.4 |
# |         MaxQ1Vals |             612 |
# |         MinQ1Vals |            20.2 |
# |     AverageQ2Vals |             496 |
# |         StdQ2Vals |            96.4 |
# |         MaxQ2Vals |             615 |
# |         MinQ2Vals |            10.5 |
# |            LossPi |            -499 |
# |             LossQ |            40.4 |
# |              Time |        5.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |        5.41e+03 |
# |          StdEpRet |            39.2 |
# |          MaxEpRet |        5.48e+03 |
# |          MinEpRet |        5.37e+03 |
# |  AverageTestEpRet |        6.37e+03 |
# |      StdTestEpRet |            79.1 |
# |      MaxTestEpRet |        6.53e+03 |
# |      MinTestEpRet |        6.25e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.92e+05 |
# |     AverageQ1Vals |             500 |
# |         StdQ1Vals |              96 |
# |         MaxQ1Vals |             615 |
# |         MinQ1Vals |            16.1 |
# |     AverageQ2Vals |             500 |
# |         StdQ2Vals |              96 |
# |         MaxQ2Vals |             617 |
# |         MinQ2Vals |            14.2 |
# |            LossPi |            -502 |
# |             LossQ |            38.1 |
# |              Time |        5.72e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |         5.4e+03 |
# |          StdEpRet |             154 |
# |          MaxEpRet |        5.65e+03 |
# |          MinEpRet |        5.23e+03 |
# |  AverageTestEpRet |        6.07e+03 |
# |      StdTestEpRet |            89.6 |
# |      MaxTestEpRet |        6.31e+03 |
# |      MinTestEpRet |        5.95e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |        1.96e+05 |
# |     AverageQ1Vals |             503 |
# |         StdQ1Vals |            96.6 |
# |         MaxQ1Vals |             616 |
# |         MinQ1Vals |           -44.5 |
# |     AverageQ2Vals |             503 |
# |         StdQ2Vals |            96.6 |
# |         MaxQ2Vals |             620 |
# |         MinQ2Vals |           -24.7 |
# |            LossPi |            -505 |
# |             LossQ |            38.7 |
# |              Time |        5.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        5.46e+03 |
# |          StdEpRet |             226 |
# |          MaxEpRet |        5.74e+03 |
# |          MinEpRet |        5.23e+03 |
# |  AverageTestEpRet |         6.3e+03 |
# |      StdTestEpRet |             106 |
# |      MaxTestEpRet |        6.44e+03 |
# |      MinTestEpRet |        6.07e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+05 |
# |     AverageQ1Vals |             506 |
# |         StdQ1Vals |            96.7 |
# |         MaxQ1Vals |             622 |
# |         MinQ1Vals |           -83.5 |
# |     AverageQ2Vals |             506 |
# |         StdQ2Vals |            96.7 |
# |         MaxQ2Vals |             624 |
# |         MinQ2Vals |           -69.5 |
# |            LossPi |            -508 |
# |             LossQ |            40.5 |
# |              Time |        5.95e+03 |
# ---------------------------------------

# %%
args = {'env': 'HalfCheetah-v2', 'hid': 256, 'l': 2, 'gamma': 0.99, 
        'seed': 0, 'epochs': 50,
        'nonstationary_env':True,
        'gravity_change_pattern': 'gravity_averagely_equal',
        'exp_name': 'td3_HalfCheetah_NoTargSmooth_NoDelayUpdate'}

from spinup.utils.run_utils import setup_logger_kwargs
logger_kwargs = setup_logger_kwargs(args['exp_name'], args['seed'])

td3(env_name=args['env'], actor_critic=core.MLPActorCritic,
     ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']), 
     gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
    nonstationary_env=args['nonstationary_env'], 
    gravity_change_pattern=args['gravity_change_pattern'],
     logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0 already exists! Storing info there anyway.
# Logging data to c:\users\lingheng\google drive\git_repos\spinningup-new\data\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             256,
#             256
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"<function <lambda> at 0x0000021F944728B8>",
#     "epochs":	50,
#     "exp_name":	"td3_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x0000021FDE4066C8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='c:\\\\users\\\\lingheng\\\\google drive\\\\git_repos\\\\spinningup-new\\\\data\\\\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate\\\\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\\\\progress.txt' mode='w' encoding='cp1252'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_HalfCheetah_NoTargSmooth_NoDelayUpdate",
#         "output_dir":	"c:\\users\\lingheng\\google drive\\git_repos\\spinningup-new\\data\\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate\\td3_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0"
#     },
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -303 |
# |          StdEpRet |             114 |
# |          MaxEpRet |            -147 |
# |          MinEpRet |            -416 |
# |  AverageTestEpRet |            -582 |
# |      StdTestEpRet |            3.42 |
# |      MaxTestEpRet |            -578 |
# |      MinTestEpRet |            -591 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            1.12 |
# |         StdQ1Vals |            2.05 |
# |         MaxQ1Vals |            12.5 |
# |         MinQ1Vals |           -8.99 |
# |     AverageQ2Vals |            1.12 |
# |         StdQ2Vals |            2.05 |
# |         MaxQ2Vals |            12.1 |
# |         MinQ2Vals |           -8.91 |
# |            LossPi |           -1.85 |
# |             LossQ |           0.634 |
# |              Time |            80.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -305 |
# |          StdEpRet |            99.1 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |            -436 |
# |  AverageTestEpRet |            -488 |
# |      StdTestEpRet |            6.44 |
# |      MaxTestEpRet |            -475 |
# |      MinTestEpRet |            -498 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            5.38 |
# |         StdQ1Vals |            5.51 |
# |         MaxQ1Vals |            25.7 |
# |         MinQ1Vals |           -19.5 |
# |     AverageQ2Vals |            5.39 |
# |         StdQ2Vals |            5.52 |
# |         MaxQ2Vals |            25.6 |
# |         MinQ2Vals |           -18.1 |
# |            LossPi |            -6.9 |
# |             LossQ |            1.73 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -455 |
# |          StdEpRet |             178 |
# |          MaxEpRet |            -256 |
# |          MinEpRet |            -664 |
# |  AverageTestEpRet |            -643 |
# |      StdTestEpRet |            89.3 |
# |      MaxTestEpRet |            -535 |
# |      MinTestEpRet |            -831 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            18.5 |
# |         StdQ1Vals |            12.1 |
# |         MaxQ1Vals |            44.6 |
# |         MinQ1Vals |           -17.4 |
# |     AverageQ2Vals |            18.5 |
# |         StdQ2Vals |            12.1 |
# |         MaxQ2Vals |            44.3 |
# |         MinQ2Vals |           -17.3 |
# |            LossPi |           -20.6 |
# |             LossQ |             2.7 |
# |              Time |             339 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             579 |
# |          StdEpRet |             442 |
# |          MaxEpRet |        1.19e+03 |
# |          MinEpRet |             -30 |
# |  AverageTestEpRet |        1.17e+03 |
# |      StdTestEpRet |             248 |
# |      MaxTestEpRet |        1.37e+03 |
# |      MinTestEpRet |             468 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            24.9 |
# |         StdQ1Vals |            11.9 |
# |         MaxQ1Vals |            60.5 |
# |         MinQ1Vals |           -12.1 |
# |     AverageQ2Vals |            24.9 |
# |         StdQ2Vals |              12 |
# |         MaxQ2Vals |            61.3 |
# |         MinQ2Vals |           -11.5 |
# |            LossPi |           -26.3 |
# |             LossQ |             3.8 |
# |              Time |             481 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             845 |
# |          StdEpRet |             939 |
# |          MaxEpRet |        2.06e+03 |
# |          MinEpRet |            -273 |
# |  AverageTestEpRet |        1.51e+03 |
# |      StdTestEpRet |             109 |
# |      MaxTestEpRet |        1.64e+03 |
# |      MinTestEpRet |        1.28e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            30.9 |
# |         StdQ1Vals |            17.4 |
# |         MaxQ1Vals |            90.2 |
# |         MinQ1Vals |           -32.1 |
# |     AverageQ2Vals |            30.9 |
# |         StdQ2Vals |            17.4 |
# |         MaxQ2Vals |            90.6 |
# |         MinQ2Vals |           -31.9 |
# |            LossPi |           -32.4 |
# |             LossQ |            5.11 |
# |              Time |             605 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |        2.29e+03 |
# |          StdEpRet |             253 |
# |          MaxEpRet |        2.47e+03 |
# |          MinEpRet |        1.86e+03 |
# |  AverageTestEpRet |        2.57e+03 |
# |      StdTestEpRet |             617 |
# |      MaxTestEpRet |         2.9e+03 |
# |      MinTestEpRet |             745 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            46.6 |
# |         StdQ1Vals |            29.3 |
# |         MaxQ1Vals |             127 |
# |         MinQ1Vals |           -46.3 |
# |     AverageQ2Vals |            46.6 |
# |         StdQ2Vals |            29.3 |
# |         MaxQ2Vals |             127 |
# |         MinQ2Vals |           -44.9 |
# |            LossPi |           -48.5 |
# |             LossQ |            8.78 |
# |              Time |             729 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |        2.45e+03 |
# |          StdEpRet |             793 |
# |          MaxEpRet |        3.08e+03 |
# |          MinEpRet |        1.09e+03 |
# |  AverageTestEpRet |        3.15e+03 |
# |      StdTestEpRet |             163 |
# |      MaxTestEpRet |        3.43e+03 |
# |      MinTestEpRet |        2.91e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            70.7 |
# |         StdQ1Vals |            40.3 |
# |         MaxQ1Vals |             156 |
# |         MinQ1Vals |             -58 |
# |     AverageQ2Vals |            70.7 |
# |         StdQ2Vals |            40.3 |
# |         MaxQ2Vals |             156 |
# |         MinQ2Vals |           -54.4 |
# |            LossPi |           -72.9 |
# |             LossQ |              12 |
# |              Time |             847 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |        3.25e+03 |
# |          StdEpRet |            87.1 |
# |          MaxEpRet |        3.37e+03 |
# |          MinEpRet |        3.16e+03 |
# |  AverageTestEpRet |        3.57e+03 |
# |      StdTestEpRet |            86.3 |
# |      MaxTestEpRet |         3.7e+03 |
# |      MinTestEpRet |        3.42e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            98.9 |
# |         StdQ1Vals |            50.4 |
# |         MaxQ1Vals |             198 |
# |         MinQ1Vals |           -62.1 |
# |     AverageQ2Vals |            98.9 |
# |         StdQ2Vals |            50.4 |
# |         MaxQ2Vals |             199 |
# |         MinQ2Vals |           -60.8 |
# |            LossPi |            -101 |
# |             LossQ |            15.6 |
# |              Time |             971 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |        3.53e+03 |
# |          StdEpRet |            85.2 |
# |          MaxEpRet |        3.65e+03 |
# |          MinEpRet |        3.44e+03 |
# |  AverageTestEpRet |         3.4e+03 |
# |      StdTestEpRet |             111 |
# |      MaxTestEpRet |        3.64e+03 |
# |      MinTestEpRet |        3.27e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |             131 |
# |         StdQ1Vals |            59.3 |
# |         MaxQ1Vals |             237 |
# |         MinQ1Vals |           -63.5 |
# |     AverageQ2Vals |             131 |
# |         StdQ2Vals |            59.3 |
# |         MaxQ2Vals |             234 |
# |         MinQ2Vals |           -61.4 |
# |            LossPi |            -134 |
# |             LossQ |            19.1 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |        3.79e+03 |
# |          StdEpRet |            88.3 |
# |          MaxEpRet |         3.9e+03 |
# |          MinEpRet |        3.66e+03 |
# |  AverageTestEpRet |        3.81e+03 |
# |      StdTestEpRet |             155 |
# |      MaxTestEpRet |        4.06e+03 |
# |      MinTestEpRet |        3.49e+03 |
# |             EpLen |           1e+03 |
# |         TestEpLen |           1e+03 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |             165 |
# |         StdQ1Vals |              66 |
# |         MaxQ1Vals |             273 |
# |         MinQ1Vals |           -61.1 |
# |     AverageQ2Vals |             165 |
# |         StdQ2Vals |              66 |
# |         MaxQ2Vals |             272 |
# |         MinQ2Vals |           -61.6 |
# |            LossPi |            -167 |
# |             LossQ |              21 |
# |              Time |        1.21e+03 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-5f143cec73b0> in <module>
#       7      ac_kwargs=dict(hidden_sizes=[args['hid']]*args['l']),
#       8      gamma=args['gamma'], seed=args['seed'], epochs=args['epochs'],
# ----> 9      logger_kwargs=logger_kwargs)
#
# <ipython-input-7-c3b93ee5aad2> in td3(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, pi_lr, q_lr, batch_size, start_steps, update_after, update_every, act_noise, target_noise, noise_clip, policy_delay, num_test_episodes, max_ep_len, logger_kwargs, save_freq)
#     291             for j in range(update_every):
#     292                 batch = replay_buffer.sample_batch(batch_size)
# --> 293                 update(data=batch, timer=j)
#     294
#     295         # End of epoch handling
#
# <ipython-input-7-c3b93ee5aad2> in update(data, timer)
#     209         pi_optimizer.zero_grad()
#     210         loss_pi = compute_loss_pi(data)
# --> 211         loss_pi.backward()
#     212         pi_optimizer.step()
#     213
#
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# c:\programdata\anaconda3\envs\app_cloud\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# KeyboardInterrupt:
