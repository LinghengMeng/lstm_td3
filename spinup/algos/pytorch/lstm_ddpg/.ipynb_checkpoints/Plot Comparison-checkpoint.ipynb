# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\progress.txt"
td3_AntMuJoCoEnv_POMDP_df = pd.read_csv(f_name, sep='\t')

f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False\td3_NonStationary_False_Ant_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\progress.txt"
td3_AntMuJoCoEnv_MDP_df = pd.read_csv(f_name, sep='\t')

f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate\td3_NonStationary_HalfCheetah_NoTargSmooth_NoDelayUpdate_s0\progress.txt"
td3_HalfCheetahMuJoCoEnv_POMDP_df = pd.read_csv(f_name, sep='\t')



f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\lstm_td3_POMDP_HalfCheetahMuJoCoEnv_PreLSTM1L128_HistMemory5Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze\lstm_td3_POMDP_HalfCheetahMuJoCoEnv_PreLSTM1L128_HistMemory5Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze_s0\progress.txt"
RTd3_HalfCheetahMuJoCoEnv_MDP_df = pd.read_csv(f_name, sep='\t')

f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\lstm_td3_POMDP_HalfCheetahMuJoCoEnv_PreLSTM1L128_HistMemory2Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze_WithWM\lstm_td3_POMDP_HalfCheetahMuJoCoEnv_PreLSTM1L128_HistMemory2Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze_WithWM_s0\progress.txt"
RTd3_WM_HalfCheetahMuJoCoEnv_MDP_df = pd.read_csv(f_name, sep='\t')

# HalfCheetah-v2
f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_False_s0\progress.txt"
td3_HalfCheetah_MDP_df = pd.read_csv(f_name, sep='\t')

f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\lstm_td3_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze\lstm_td3_MDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze_s0\progress.txt"
RTD3_HalfCheetah_MDP_df = pd.read_csv(f_name, sep='\t')

f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True\td3_NonStationary_False_HalfCheetah_NoTargSmooth_NoDelayUpdate_POMDP_True_s0\progress.txt"
TD3_HalfCheetah_POMDP_df = pd.read_csv(f_name, sep='\t')

f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\lstm_td3_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze\lstm_td3_POMDP_HalfCheetah_PreLSTM1L128_HistMemory5Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze_s0\progress.txt"
RTD3_HalfCheetah_POMDP_df = pd.read_csv(f_name, sep='\t')

f_name=r"C:\Users\Lingheng\Google Drive\git_repos\spinningup-new\data\lstm_td3_POMDP_HalfCheetah_PreLSTM1L128_HistMemory2Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze_WithWM\lstm_td3_POMDP_HalfCheetah_PreLSTM1L128_HistMemory2Len_LSTM2L128_HidStateLayer0_2L128_NoFreeze_WithWM_s0\progress.txt"
RTD3_WM_HalfCheetah_MDP_df = pd.read_csv(f_name, sep='\t')

# %%
td3_AntMuJoCoEnv_POMDP_df.columns
# Out:
# Index(['Epoch', 'AverageEpRet', 'StdEpRet', 'MaxEpRet', 'MinEpRet',
#        'AverageTestEpRet', 'StdTestEpRet', 'MaxTestEpRet', 'MinTestEpRet',
#        'EpLen', 'TestEpLen', 'TotalEnvInteracts', 'AverageQ1Vals', 'StdQ1Vals',
#        'MaxQ1Vals', 'MinQ1Vals', 'AverageQ2Vals', 'StdQ2Vals', 'MaxQ2Vals',
#        'MinQ2Vals', 'LossPi', 'LossQ', 'Time'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1,3, figsize=(12,4))
ax[0].plot(td3_AntMuJoCoEnv_POMDP_df['AverageTestEpRet'], label='POMDP')
ax[0].plot(td3_AntMuJoCoEnv_MDP_df['AverageTestEpRet'], label='MDP')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accumulated Rewards')
ax[0].legend()
ax[0].set_title('AntMuJoCoEnv')

ax[1].plot(td3_HalfCheetahMuJoCoEnv_POMDP_df['AverageTestEpRet'], label='TD3 POMDP')
ax[1].plot(RTd3_HalfCheetahMuJoCoEnv_MDP_df['AverageTestEpRet'], label='RTD3 MDP')
ax[1].plot(RTd3_WM_HalfCheetahMuJoCoEnv_MDP_df['AverageTestEpRet'], label='RTD3-WorldModel MDP')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accumulated Rewards')
ax[1].legend()
ax[1].set_title('HalfCheetahMuJoCoEnv')

ax[2].plot(td3_HalfCheetah_MDP_df['AverageTestEpRet'], label='TD3 MDP')
ax[2].plot(RTD3_HalfCheetah_MDP_df['AverageTestEpRet'], label='RTD3 MDP')
ax[2].plot(TD3_HalfCheetah_POMDP_df['AverageTestEpRet'], label='TD3 POMDP')
ax[2].plot(RTD3_HalfCheetah_POMDP_df['AverageTestEpRet'], label='RTD3 POMDP')
# ax[2].plot(RTD3_HalfCheetah_MDP_df['AverageTestEpRet'], label='RTD3 MDP')
ax[2].plot(RTD3_WM_HalfCheetah_MDP_df['AverageTestEpRet'], label='RTD3-WorldModel MDP')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Accumulated Rewards')
ax[2].legend()
ax[2].set_title('HalfCheetah')


plt.tight_layout()
